# %% [markdown]
# This notebook contains the SPARQL queries useful to have a general overview of the dataset itself (e.g. number of triples, number of subjects etc.)

# %%
import rdflib
from rdflib.namespace import CSVW, DC, DCAT, DCTERMS, DOAP, FOAF, ODRL2, ORG, OWL, \
                           PROF, PROV, RDF, RDFS, SDO, SH, SKOS, SOSA, SSN, TIME, \
                           VOID, XMLNS, XSD
from rdflib import Namespace
from rdflib import URIRef

# %%
newg = rdflib.Graph() # we create a new graph
newg.parse("210622_output2.ttl", format="ttl")
# Out:
# <Graph identifier=N1cae0a038a7e43809dd5b5460f18f300 (<class 'rdflib.graph.Graph'>)>

# %% [raw]
# Number of triples

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 


SELECT (count(?subj) as ?tot) WHERE {
# ?subj ?rel ?obj. 

}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('68455', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %%
Number of artworks

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT (count(distinct ?art) as ?tot) WHERE {
# ?obj a crm:E22_Human_Made_Object; 
    crm:P65_shows_visual_item ?art. 
# ?art a icon:Artwork. 
# ?rec icon:aboutWorkOfArt ?art.  

}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('602', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# Number of level 1 recognitions

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 


SELECT (count(distinct ?preic) as ?tot) WHERE {
{?preic a icon:PreiconographicalRecognition} UNION {?preic a icon:FormalMotifRecognition} 
}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('3519', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %%
Number of level 2 recognitions

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 


SELECT (count(distinct ?icrec) as ?tot) WHERE {
# ?icrec a icon:IconographicalRecognition. 
}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('1034', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %%
Number of level 3 recognitions

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 


SELECT (count(distinct ?rec) as ?tot) WHERE {
# ?rec a icon:IconologicalRecognition. 
}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('877', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# Number of level 1 subjects

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 


SELECT (count(distinct ?lev1) as ?tot) WHERE {
# ?rec a icon:PreiconographicalRecognition. 
{?rec icon:recognizedArtisticMotif ?am} UNION {?rec icon:recognizedComposition ?comp. ?comp icon:hasPart ?am}
# ?am icon:hasFactualMeaning | icon:hasExpressionalMeaning ?lev1. 
}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('942', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# Number of level 2 subjects

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>


SELECT (count(distinct ?lev2) as ?tot) WHERE {
VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasPlace icon:hasPersonification icon:hasNamedObject icon:hasSymbol}
# ?rec a icon:IconographicalRecognition. 
{?rec icon:recognizedImage ?img. ?img ?rel ?lev2} UNION {?rec icon:recognizedInvenzione ?inv. ?inv icon:composedOf ?lev2}

}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('555', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# Number of level 3 subjects

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>


SELECT (count(distinct ?lev3) as ?tot) WHERE {
VALUES ?rel {icon:recognizedConceptualObject icon:recognizedCulturalPhenomenon}
# ?rec a icon:IconologicalRecognition. 
# ?rec icon:recognizedIntrinsicMeaning ?intrinsic. ?intrinsic ?rel ?lev3. 
}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('422', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %%
Number of people

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT (count(distinct ?people) as ?tot) WHERE {

# ?people a crm:E21_Person. 

}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('236', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %%
Number of books

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT (count(distinct ?book) as ?tot) WHERE {

{?book crm:P2_has_type ?type. 
# ?type crm:P2_has_type <http://vocab.getty.edu/page/aat/300028051>. } 
UNION 
{?book crm:P2_has_type <http://vocab.getty.edu/page/aat/300028051>}

}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('175', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# # Case-study analysis
# How is Mercury represented at level 1, according to the time of production? Order by time

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?timeStart ?timeEnd ?artwork ?lev1 WHERE {

VALUES ?subj {d:mercury-hermes d:mercury}
# ?production crm:P108_has_produced ?object; 
 crm:P4_has_time_span ?time. 
# ?object crm:P65_shows_visual_item ?artwork. 
# ?icrec icon:aboutWorkOfArt ?artwork;
    icon:recognizedImage ?img.
# ?img icon:hasCharacter ?subj. 
# ?comp icon:hasPart ?am.
{?icrec icon:refersToArtisticMotif ?comp. ?comp icon:hasPart ?am} 
UNION 
{?icrec icon:refersToArtisticMotif ?am. ?am a icon:ArtisticMotif}
# ?am icon:hasFactualMeaning | icon:hasExpressionalMeaning ?lev1. 
# ?time crm:P82a_begin_of_the_begin ?timeStart; 
    crm:P82b_end_of_the_end ?timeEnd. 

} ORDER BY ?time ?artwork 
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('1023-01-01T0:00:00'), rdflib.term.Literal('1023-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1041'), rdflib.term.URIRef('http://icondataset.org/killing-a-serpent'))
# (rdflib.term.Literal('1023-01-01T0:00:00'), rdflib.term.Literal('1023-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1041'), rdflib.term.URIRef('http://icondataset.org/staff'))
# (rdflib.term.Literal('1023-01-01T0:00:00'), rdflib.term.Literal('1023-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1041'), rdflib.term.URIRef('http://icondataset.org/serpent'))
# (rdflib.term.Literal('1023-01-01T0:00:00'), rdflib.term.Literal('1023-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1041'), rdflib.term.URIRef('http://icondataset.org/bird'))
# (rdflib.term.Literal('1023-01-01T0:00:00'), rdflib.term.Literal('1023-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1041'), rdflib.term.URIRef('http://icondataset.org/man'))
# (rdflib.term.Literal('1403-01-01T0:00:00'), rdflib.term.Literal('1403-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1147'), rdflib.term.URIRef('http://icondataset.org/cleric'))
# (rdflib.term.Literal('1403-01-01T0:00:00'), rdflib.term.Literal('1403-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1147'), rdflib.term.URIRef('http://icondataset.org/reading'))
# (rdflib.term.Literal('1403-01-01T0:00:00'), rdflib.term.Literal('1403-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1147'), rdflib.term.URIRef('http://icondataset.org/book'))
# (rdflib.term.Literal('1403-01-01T0:00:00'), rdflib.term.Literal('1403-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1147'), rdflib.term.URIRef('http://icondataset.org/holding'))
# (rdflib.term.Literal('1403-01-01T0:00:00'), rdflib.term.Literal('1403-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1147'), rdflib.term.URIRef('http://icondataset.org/musical-instrument'))
# (rdflib.term.Literal('1420-01-01T0:00:00'), rdflib.term.Literal('1420-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/playing-music'))
# (rdflib.term.Literal('1420-01-01T0:00:00'), rdflib.term.Literal('1420-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/man'))
# (rdflib.term.Literal('1420-01-01T0:00:00'), rdflib.term.Literal('1420-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/flute'))
# (rdflib.term.Literal('1420-01-01T0:00:00'), rdflib.term.Literal('1420-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/staff'))
# (rdflib.term.Literal('1420-01-01T0:00:00'), rdflib.term.Literal('1420-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/serpents'))
# (rdflib.term.Literal('1420-01-01T0:00:00'), rdflib.term.Literal('1420-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1420-01-01T0:00:00'), rdflib.term.Literal('1420-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/lance'))
# (rdflib.term.Literal('1420-01-01T0:00:00'), rdflib.term.Literal('1420-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/sword'))
# (rdflib.term.Literal('1420-01-01T0:00:00'), rdflib.term.Literal('1420-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/cutten-head'))
# (rdflib.term.Literal('1420-01-01T0:00:00'), rdflib.term.Literal('1420-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/eyes'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/man'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/indifference'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/raising-the-right-hand'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/stick-with-two-coiled-snakes'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/endeavoring-to-dispel-the-wisps-of-mist'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/mist'))
# (rdflib.term.Literal('1480-01-01T0:00:00'), rdflib.term.Literal('1480-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1046'), rdflib.term.URIRef('http://icondataset.org/man'))
# (rdflib.term.Literal('1480-01-01T0:00:00'), rdflib.term.Literal('1480-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1046'), rdflib.term.URIRef('http://icondataset.org/cock'))
# (rdflib.term.Literal('1480-01-01T0:00:00'), rdflib.term.Literal('1480-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1046'), rdflib.term.URIRef('http://icondataset.org/flute'))
# (rdflib.term.Literal('1480-01-01T0:00:00'), rdflib.term.Literal('1480-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1046'), rdflib.term.URIRef('http://icondataset.org/playing-music'))
# (rdflib.term.Literal('1480-01-01T0:00:00'), rdflib.term.Literal('1480-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1046'), rdflib.term.URIRef('http://icondataset.org/sword'))
# (rdflib.term.Literal('1490-01-01T0:00:00'), rdflib.term.Literal('1490-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1033'), rdflib.term.URIRef('http://icondataset.org/man'))
# (rdflib.term.Literal('1490-01-01T0:00:00'), rdflib.term.Literal('1490-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1033'), rdflib.term.URIRef('http://icondataset.org/riding-a-horse'))
# (rdflib.term.Literal('1490-01-01T0:00:00'), rdflib.term.Literal('1490-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1033'), rdflib.term.URIRef('http://icondataset.org/horse'))
# (rdflib.term.Literal('1490-01-01T0:00:00'), rdflib.term.Literal('1490-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1033'), rdflib.term.URIRef('http://icondataset.org/protecting-people-below'))
# (rdflib.term.Literal('1545-01-01T0:00:00'), rdflib.term.Literal('1545-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1201'), rdflib.term.URIRef('http://icondataset.org/man'))
# (rdflib.term.Literal('1545-01-01T0:00:00'), rdflib.term.Literal('1545-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1201'), rdflib.term.URIRef('http://icondataset.org/winged-hat'))
# (rdflib.term.Literal('1554-01-01T0:00:00'), rdflib.term.Literal('1554-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1316'), rdflib.term.URIRef('http://icondataset.org/man'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1434-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1034'), rdflib.term.URIRef('http://icondataset.org/man'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1434-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1034'), rdflib.term.URIRef('http://icondataset.org/sitting-down'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1434-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1034'), rdflib.term.URIRef('http://icondataset.org/rainbow'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1434-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1034'), rdflib.term.URIRef('http://icondataset.org/sky'))
# (rdflib.term.Literal('1301-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1030'), rdflib.term.URIRef('http://icondataset.org/bishop'))
# (rdflib.term.Literal('1301-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1030'), rdflib.term.URIRef('http://icondataset.org/crosier'))
# (rdflib.term.Literal('1301-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1030'), rdflib.term.URIRef('http://icondataset.org/book'))
# (rdflib.term.Literal('1301-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1030'), rdflib.term.URIRef('http://icondataset.org/holding'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1315'), rdflib.term.URIRef('http://icondataset.org/man'))

# %%
import csv
with open('mercury_attr_time4.csv', mode='w') as my_file:
    my_writer = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
    # write the column names
    my_writer.writerow(['Date' , 'Century', 'Artwork', 'Level1Representation'])
    
    # access the rows of the query results
    for timeStart, timeEnd, artwork, lev1 in cqres:
        lev1_cleaned1 = lev1.replace("http://icondataset.org/", "")
        lev1_cleaned2 = lev1_cleaned1.replace("-", " ")
        start = int(timeStart[:4])
        end = int(timeEnd[:4])
        if start != end: 
            time = str((start+end)/2)
        else: 
            time = str(start)
        if time.startswith("10"): 
            century = "XI"
            year = 11
        elif time.startswith("11"): 
            century = "XII"
            year = 12
        elif time.startswith("12"): 
            century = "XIII"
            year = 13
        elif time.startswith("13"): 
            century = "XIV"
            year = 14
        elif time.startswith("14"): 
            century = "XV"
            year = 15
        elif time.startswith("15"): 
            century = "XVI"
            year = 16
        # write in the cv
        my_writer.writerow([year, century, artwork, lev1_cleaned2])

# %%
import pandas as pd
# parse the csv into a dataframe
data = pd.read_csv("mercury_attr_time4.csv")
# print the first 5 rows
data.head()
# Out:
#    Date Century                         Artwork Level1Representation
# 0    11      XI  http://icondataset.org/ART1041    killing a serpent
# 1    11      XI  http://icondataset.org/ART1041                staff
# 2    11      XI  http://icondataset.org/ART1041              serpent
# 3    11      XI  http://icondataset.org/ART1041                 bird
# 4    11      XI  http://icondataset.org/ART1041                  man

# %%
frequency_dict = {} # key = date, 
with open('mercury_attr_time4.csv', mode='r') as my_file:
    mercury_data = csv.DictReader(my_file)
    
    for row in mercury_data:
        print(row)
        date = row["Date"]
        century = row["Century"]
        subject = row["Level1Representation"]
        if date not in frequency_dict: 
            frequency_dict[date] ={}
            frequency_dict[date][century] = {}
        if subject not in frequency_dict[date][century]:
            frequency_dict[date][century][subject] = 0
        frequency_dict[date][century][subject] += 1
                
print(frequency_dict)
# Out:
# {'Date': '11', 'Century': 'XI', 'Artwork': 'http://icondataset.org/ART1041', 'Level1Representation': 'killing a serpent'}
# {'Date': '11', 'Century': 'XI', 'Artwork': 'http://icondataset.org/ART1041', 'Level1Representation': 'staff'}
# {'Date': '11', 'Century': 'XI', 'Artwork': 'http://icondataset.org/ART1041', 'Level1Representation': 'serpent'}
# {'Date': '11', 'Century': 'XI', 'Artwork': 'http://icondataset.org/ART1041', 'Level1Representation': 'bird'}
# {'Date': '11', 'Century': 'XI', 'Artwork': 'http://icondataset.org/ART1041', 'Level1Representation': 'man'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1147', 'Level1Representation': 'cleric'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1147', 'Level1Representation': 'reading'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1147', 'Level1Representation': 'book'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1147', 'Level1Representation': 'holding'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1147', 'Level1Representation': 'musical instrument'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1021', 'Level1Representation': 'playing music'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1021', 'Level1Representation': 'man'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1021', 'Level1Representation': 'flute'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1021', 'Level1Representation': 'staff'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1021', 'Level1Representation': 'serpents'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1021', 'Level1Representation': 'wings'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1021', 'Level1Representation': 'lance'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1021', 'Level1Representation': 'sword'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1021', 'Level1Representation': 'cutten head'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1021', 'Level1Representation': 'eyes'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1203', 'Level1Representation': 'man'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1203', 'Level1Representation': 'indifference'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1203', 'Level1Representation': 'raising the right hand'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1203', 'Level1Representation': 'stick with two coiled snakes'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1203', 'Level1Representation': 'endeavoring to dispel the wisps of mist'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1203', 'Level1Representation': 'mist'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1046', 'Level1Representation': 'man'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1046', 'Level1Representation': 'cock'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1046', 'Level1Representation': 'flute'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1046', 'Level1Representation': 'playing music'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1046', 'Level1Representation': 'sword'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1033', 'Level1Representation': 'man'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1033', 'Level1Representation': 'riding a horse'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1033', 'Level1Representation': 'horse'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1033', 'Level1Representation': 'protecting people below'}
# {'Date': '16', 'Century': 'XVI', 'Artwork': 'http://icondataset.org/ART1201', 'Level1Representation': 'man'}
# {'Date': '16', 'Century': 'XVI', 'Artwork': 'http://icondataset.org/ART1201', 'Level1Representation': 'winged hat'}
# {'Date': '16', 'Century': 'XVI', 'Artwork': 'http://icondataset.org/ART1316', 'Level1Representation': 'man'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1034', 'Level1Representation': 'man'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1034', 'Level1Representation': 'sitting down'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1034', 'Level1Representation': 'rainbow'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1034', 'Level1Representation': 'sky'}
# {'Date': '14', 'Century': 'XIV', 'Artwork': 'http://icondataset.org/ART1030', 'Level1Representation': 'bishop'}
# {'Date': '14', 'Century': 'XIV', 'Artwork': 'http://icondataset.org/ART1030', 'Level1Representation': 'crosier'}
# {'Date': '14', 'Century': 'XIV', 'Artwork': 'http://icondataset.org/ART1030', 'Level1Representation': 'book'}
# {'Date': '14', 'Century': 'XIV', 'Artwork': 'http://icondataset.org/ART1030', 'Level1Representation': 'holding'}
# {'Date': '15', 'Century': 'XV', 'Artwork': 'http://icondataset.org/ART1315', 'Level1Representation': 'man'}
# {'11': {'XI': {'killing a serpent': 1, 'staff': 1, 'serpent': 1, 'bird': 1, 'man': 1}}, '15': {'XV': {'cleric': 1, 'reading': 1, 'book': 1, 'holding': 1, 'musical instrument': 1, 'playing music': 2, 'man': 6, 'flute': 2, 'staff': 1, 'serpents': 1, 'wings': 1, 'lance': 1, 'sword': 2, 'cutten head': 1, 'eyes': 1, 'indifference': 1, 'raising the right hand': 1, 'stick with two coiled snakes': 1, 'endeavoring to dispel the wisps of mist': 1, 'mist': 1, 'cock': 1, 'riding a horse': 1, 'horse': 1, 'protecting people below': 1, 'sitting down': 1, 'rainbow': 1, 'sky': 1}}, '16': {'XVI': {'man': 2, 'winged hat': 1}}, '14': {'XIV': {'bishop': 1, 'crosier': 1, 'book': 1, 'holding': 1}}}

# %%
with open('mercury_final.csv', mode='w') as my_file:
    my_writer = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
    # write the column names
    my_writer.writerow(['Date' , 'Century', 'Attribute', 'Frequency'])

    for date in frequency_dict.items(): # date: tuple with tuple[0] = number, tuple[1] = dict
        year= date[0]
        for cent in date[1].items(): 
            century = cent[0]
            for term in cent[1].items(): 
                attribute = term[0]
                frequency = term[1]
                my_writer.writerow([year, century, attribute, int(frequency)])
    my_writer.writerow([12, "XII", "", 0])
    my_writer.writerow([13, "XIII", "", 0])
# write a csv with them, ordered

# %%
data = pd.read_csv("mercury_final.csv")
# print the first 5 rows
df = data.sort_values(by=['Date'])
# print(df)
df.head()
# Out:
#    Date Century          Attribute  Frequency
# 0    11      XI  killing a serpent          1
# 1    11      XI              staff          1
# 2    11      XI            serpent          1
# 3    11      XI               bird          1
# 4    11      XI                man          1

# %%
print(df)
# Out:
#     Date Century                                Attribute  Frequency
# 0     11      XI                        killing a serpent          1
# 1     11      XI                                    staff          1
# 2     11      XI                                  serpent          1
# 3     11      XI                                     bird          1
# 4     11      XI                                      man          1
# 38    12     XII                                      NaN          0
# 39    13    XIII                                      NaN          0
# 37    14     XIV                                  holding          1
# 36    14     XIV                                     book          1
# 35    14     XIV                                  crosier          1
# 34    14     XIV                                   bishop          1
# 7     15      XV                                     book          1
# 31    15      XV                                      sky          1
# 30    15      XV                                  rainbow          1
# 29    15      XV                             sitting down          1
# 28    15      XV                  protecting people below          1
# 27    15      XV                                    horse          1
# 26    15      XV                           riding a horse          1
# 25    15      XV                                     cock          1
# 24    15      XV                                     mist          1
# 6     15      XV                                  reading          1
# 22    15      XV             stick with two coiled snakes          1
# 23    15      XV  endeavoring to dispel the wisps of mist          1
# 20    15      XV                             indifference          1
# 8     15      XV                                  holding          1
# 9     15      XV                       musical instrument          1
# 10    15      XV                            playing music          2
# 11    15      XV                                      man          6
# 21    15      XV                   raising the right hand          1
# 13    15      XV                                    staff          1
# 12    15      XV                                    flute          2
# 15    15      XV                                    wings          1
# 16    15      XV                                    lance          1
# 17    15      XV                                    sword          2
# 18    15      XV                              cutten head          1
# 5     15      XV                                   cleric          1
# 14    15      XV                                 serpents          1
# 19    15      XV                                     eyes          1
# 32    16     XVI                                      man          2
# 33    16     XVI                               winged hat          1

# %%
https://www.python-graph-gallery.com/bubble-plot-with-seaborn

# %%
# libraries
import matplotlib.pyplot as plt
import seaborn as sns
#from gapminder import gapminder # import data set 
sns.set_style("white")
# Control figure size for this notebook:
plt.rcParams['figure.figsize'] = [2.5, 6] # 2.5, 6 ha le proporzioni che voglio io 
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300
 
# use the scatterplot function to build the bubble map
sns.scatterplot(data=df, x="Century", y="Attribute", size="Frequency", sizes=(10, 140), legend=True) # 10, 140

# show the graph
plt.show()

# %% [markdown]
# # Case study 2
# 1. detect the most frequently represented Characters to see if it is possible to do the previous analysis with more numbers

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 


SELECT DISTINCT ?char (count (?char) as ?tot) WHERE { #
# ?img icon:hasCharacter ?char. 
# ?char a icon:Character. 
# ?img a icon:Image. 
} GROUP BY ?char
ORDER BY DESC(?tot)
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.Literal('29', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.Literal('18', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.Literal('14', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.Literal('12', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/mercury'), rdflib.term.Literal('12', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/satyr'), rdflib.term.Literal('11', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.Literal('10', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.Literal('9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.Literal('9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/jupiter'), rdflib.term.Literal('9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/apollo'), rdflib.term.Literal('9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.Literal('8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/silenus'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/archangel-gabriel'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/centaur'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/christ-as-a-child'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/member-of-the-procession'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/the-three-graces'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/virgil'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/vulcan'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/bacchus'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/phaeton'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/crocodile'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/eve'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/member-of-medici-family'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/planetary-deities'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/pope-julius-ii'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/prometheus'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/saint-cosmas'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/saint-damian'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/saint-luke'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/angels'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/moses'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/aglauros'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/antiphas-son-of-laoocoon'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/argus'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/ariadne'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/david'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/europas-companions'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/ganymede'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/giuliano-de-medici'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/laocoon'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/lapiths'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/lorenzo-de-medici'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/marine-snakes'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/member-of-the-crowd-of-faithful-in-prayer'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/mercury-hermes'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/mithras'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/neptune'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/olympian-gods'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/polyxena'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/saint-john-the-evangelist'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/saint-theodora-of-alexandria'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/serapis'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/the-children-of-mercury'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/the-children-of-saturn'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/the-resurrected'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/thymbraeus-son-of-laoocoon'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/tityus'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/zeus'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/cerberus'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/devil'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/god'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/venus-coelestis'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/adam'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/aeneas'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/aeolus'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/aion/phanes'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/angel'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/antoninus-pius'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/apollo-god-of-sun'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/apollo-medicus-or-aesculapius'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/apostles'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/athene'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/bacchant'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/bishop-simone-saltarelli'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/cacus'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/centaurs'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/cybele'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/diana'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/dionysus'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/erato'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/erymanthian-boar'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/fedro'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/female-pan'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/four-saints'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/geminae-veneres'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/gods-hand'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/hecuba'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/helen'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/herse'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/hespontine-sibyl'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/hylas'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/jest'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/joachim'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/judith'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/jupiter-as-an-eagle'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/king-eurystheus'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/leach'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/mida'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/minerva'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/muses'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/noah'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/nymphs'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/orpheus'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/pan'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/pan-god-of-panic'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/paris'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/presbyter-bruno'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/prophet'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/pygmalion'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/rachel'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/rhea'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/roman-emperors'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/saint-anne'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/saint-basilius'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/saint-mark'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/saint-peter'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/satan'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/simeon'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/sol-invictus'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/sol-iustitiae'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/son-of-the-widow-of-nain'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/sybil'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/the-adult-mago-balthasar'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/the-children-of-each-planet'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/the-children-of-jupiter'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/the-elder-mago-balthasar'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/the-ilde'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/the-young-mago-caspar'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/thisbe'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/troilus'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/unconsciuous-creatures'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/venus-carnalis'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/venus-pudica'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/venus-verticordia'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/votary-of-jupiter'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/votary-of-saturn'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/dido'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/europa'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/ixion'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/natural-venus'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/puer-mingens'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/saint-paul'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/salamander'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/sisyphus'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/tantalus'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/venus-vulgaris'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://icondataset.org/flora'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))

# %%
Try the same analysis with Cupid

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?timeStart ?timeEnd ?artwork ?lev1 WHERE {

VALUES ?subj {d:blindfold-cupid d:cupid}
# ?production crm:P108_has_produced ?object; 
 crm:P4_has_time_span ?time. 
# ?object crm:P65_shows_visual_item ?artwork. 
# ?icrec icon:aboutWorkOfArt ?artwork;
    icon:recognizedImage ?img.
# ?img icon:hasCharacter ?subj. 
# ?comp icon:hasPart ?am.
{?icrec icon:refersToArtisticMotif ?comp. ?comp icon:hasPart ?am} 
UNION 
{?icrec icon:refersToArtisticMotif ?am. ?am a icon:ArtisticMotif}
# ?am icon:hasFactualMeaning | icon:hasExpressionalMeaning ?lev1. 
# ?time crm:P82a_begin_of_the_begin ?timeStart; 
    crm:P82b_end_of_the_end ?timeEnd. 

} ORDER BY ?time ?artwork 
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
# Out:
# (rdflib.term.Literal('1000-01-01T0:00:00'), rdflib.term.Literal('1000-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1291'), rdflib.term.URIRef('http://icondataset.org/putto'))
# (rdflib.term.Literal('1000-01-01T0:00:00'), rdflib.term.Literal('1000-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1291'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1023-01-01T0:00:00'), rdflib.term.Literal('1023-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1293'), rdflib.term.URIRef('http://icondataset.org/boy'))
# (rdflib.term.Literal('1023-01-01T0:00:00'), rdflib.term.Literal('1023-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1293'), rdflib.term.URIRef('http://icondataset.org/mantle'))
# (rdflib.term.Literal('1023-01-01T0:00:00'), rdflib.term.Literal('1023-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1293'), rdflib.term.URIRef('http://icondataset.org/torch'))
# (rdflib.term.Literal('1023-01-01T0:00:00'), rdflib.term.Literal('1023-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1293'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1023-01-01T0:00:00'), rdflib.term.Literal('1023-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1293'), rdflib.term.URIRef('http://icondataset.org/arrow'))
# (rdflib.term.Literal('1100-01-01T0:00:00'), rdflib.term.Literal('1100-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1130'), rdflib.term.URIRef('http://icondataset.org/boy'))
# (rdflib.term.Literal('1100-01-01T0:00:00'), rdflib.term.Literal('1100-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1130'), rdflib.term.URIRef('http://icondataset.org/flying'))
# (rdflib.term.Literal('1100-01-01T0:00:00'), rdflib.term.Literal('1100-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1130'), rdflib.term.URIRef('http://icondataset.org/holding-with-a-hand'))
# (rdflib.term.Literal('1100-01-01T0:00:00'), rdflib.term.Literal('1100-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1130'), rdflib.term.URIRef('http://icondataset.org/torch'))
# (rdflib.term.Literal('1100-01-01T0:00:00'), rdflib.term.Literal('1100-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1130'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1170-01-01T0:00:00'), rdflib.term.Literal('1170-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1131'), rdflib.term.URIRef('http://icondataset.org/putto'))
# (rdflib.term.Literal('1170-01-01T0:00:00'), rdflib.term.Literal('1170-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1131'), rdflib.term.URIRef('http://icondataset.org/wreath'))
# (rdflib.term.Literal('1170-01-01T0:00:00'), rdflib.term.Literal('1170-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1131'), rdflib.term.URIRef('http://icondataset.org/grabbing-with-one-hand'))
# (rdflib.term.Literal('1170-01-01T0:00:00'), rdflib.term.Literal('1170-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1132'), rdflib.term.URIRef('http://icondataset.org/putto'))
# (rdflib.term.Literal('1170-01-01T0:00:00'), rdflib.term.Literal('1170-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1132'), rdflib.term.URIRef('http://icondataset.org/wreath'))
# (rdflib.term.Literal('1170-01-01T0:00:00'), rdflib.term.Literal('1170-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1132'), rdflib.term.URIRef('http://icondataset.org/grabbing-with-one-hand'))
# (rdflib.term.Literal('1280-01-01T0:00:00'), rdflib.term.Literal('1280-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1129'), rdflib.term.URIRef('http://icondataset.org/boy'))
# (rdflib.term.Literal('1280-01-01T0:00:00'), rdflib.term.Literal('1280-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1129'), rdflib.term.URIRef('http://icondataset.org/sleeping'))
# (rdflib.term.Literal('1280-01-01T0:00:00'), rdflib.term.Literal('1280-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1129'), rdflib.term.URIRef('http://icondataset.org/leaning-upon'))
# (rdflib.term.Literal('1280-01-01T0:00:00'), rdflib.term.Literal('1280-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1129'), rdflib.term.URIRef('http://icondataset.org/torch'))
# (rdflib.term.Literal('1280-01-01T0:00:00'), rdflib.term.Literal('1280-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1129'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1320-01-01T0:00:00'), rdflib.term.Literal('25-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1310'), rdflib.term.URIRef('http://icondataset.org/boy'))
# (rdflib.term.Literal('1320-01-01T0:00:00'), rdflib.term.Literal('25-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1310'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1320-01-01T0:00:00'), rdflib.term.Literal('25-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1310'), rdflib.term.URIRef('http://icondataset.org/bandage'))
# (rdflib.term.Literal('1320-01-01T0:00:00'), rdflib.term.Literal('25-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1310'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1320-01-01T0:00:00'), rdflib.term.Literal('25-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1310'), rdflib.term.URIRef('http://icondataset.org/arrows'))
# (rdflib.term.Literal('1320-01-01T0:00:00'), rdflib.term.Literal('25-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1310'), rdflib.term.URIRef('http://icondataset.org/griffon-claws'))
# (rdflib.term.Literal('1320-01-01T0:00:00'), rdflib.term.Literal('25-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1310'), rdflib.term.URIRef('http://icondataset.org/crown-of-roses'))
# (rdflib.term.Literal('1320-01-01T0:00:00'), rdflib.term.Literal('25-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1310'), rdflib.term.URIRef('http://icondataset.org/hearts'))
# (rdflib.term.Literal('1370-01-01T0:00:00'), rdflib.term.Literal('1370-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1313'), rdflib.term.URIRef('http://icondataset.org/horse'))
# (rdflib.term.Literal('1370-01-01T0:00:00'), rdflib.term.Literal('1370-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1313'), rdflib.term.URIRef('http://icondataset.org/boy'))
# (rdflib.term.Literal('1370-01-01T0:00:00'), rdflib.term.Literal('1370-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1313'), rdflib.term.URIRef('http://icondataset.org/band'))
# (rdflib.term.Literal('1370-01-01T0:00:00'), rdflib.term.Literal('1370-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1313'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1370-01-01T0:00:00'), rdflib.term.Literal('1370-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1313'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1370-01-01T0:00:00'), rdflib.term.Literal('1370-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1313'), rdflib.term.URIRef('http://icondataset.org/arrow'))
# (rdflib.term.Literal('1370-01-01T0:00:00'), rdflib.term.Literal('1370-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1313'), rdflib.term.URIRef('http://icondataset.org/griffon-claws'))
# (rdflib.term.Literal('1370-01-01T0:00:00'), rdflib.term.Literal('1370-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1313'), rdflib.term.URIRef('http://icondataset.org/spear'))
# (rdflib.term.Literal('1370-01-01T0:00:00'), rdflib.term.Literal('1370-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1313'), rdflib.term.URIRef('http://icondataset.org/standing-on-a-horse'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/arrow'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/putto'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/taking-aim'))
# (rdflib.term.Literal('1478-01-01T0:00:00'), rdflib.term.Literal('1478-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1203'), rdflib.term.URIRef('http://icondataset.org/fire'))
# (rdflib.term.Literal('1480-01-01T0:00:00'), rdflib.term.Literal('1480-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1123'), rdflib.term.URIRef('http://icondataset.org/bandage'))
# (rdflib.term.Literal('1480-01-01T0:00:00'), rdflib.term.Literal('1480-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1123'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1480-01-01T0:00:00'), rdflib.term.Literal('1480-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1123'), rdflib.term.URIRef('http://icondataset.org/court-dress'))
# (rdflib.term.Literal('1480-01-01T0:00:00'), rdflib.term.Literal('1480-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1123'), rdflib.term.URIRef('http://icondataset.org/arrows'))
# (rdflib.term.Literal('1480-01-01T0:00:00'), rdflib.term.Literal('1480-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1123'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1480-01-01T0:00:00'), rdflib.term.Literal('1480-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1123'), rdflib.term.URIRef('http://icondataset.org/boy'))
# (rdflib.term.Literal('1496-01-01T0:00:00'), rdflib.term.Literal('1496-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1317'), rdflib.term.URIRef('http://icondataset.org/child'))
# (rdflib.term.Literal('1496-01-01T0:00:00'), rdflib.term.Literal('1496-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1317'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1496-01-01T0:00:00'), rdflib.term.Literal('1496-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1317'), rdflib.term.URIRef('http://icondataset.org/bandage'))
# (rdflib.term.Literal('1496-01-01T0:00:00'), rdflib.term.Literal('1496-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1317'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1496-01-01T0:00:00'), rdflib.term.Literal('1496-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1317'), rdflib.term.URIRef('http://icondataset.org/arrows'))
# (rdflib.term.Literal('1515-01-01T0:00:00'), rdflib.term.Literal('1515-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1329'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1515-01-01T0:00:00'), rdflib.term.Literal('1515-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1329'), rdflib.term.URIRef('http://icondataset.org/stirring-water'))
# (rdflib.term.Literal('1515-01-01T0:00:00'), rdflib.term.Literal('1515-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1329'), rdflib.term.URIRef('http://icondataset.org/putto'))
# (rdflib.term.Literal('1520-01-01T0:00:00'), rdflib.term.Literal('1520-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1002test'), rdflib.term.URIRef('http://icondataset.org/putto'))
# (rdflib.term.Literal('1520-01-01T0:00:00'), rdflib.term.Literal('1520-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1002test'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1520-01-01T0:00:00'), rdflib.term.Literal('1520-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1002test'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1520-01-01T0:00:00'), rdflib.term.Literal('1520-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1002test'), rdflib.term.URIRef('http://icondataset.org/holding-a-wreath'))
# (rdflib.term.Literal('1520-01-01T0:00:00'), rdflib.term.Literal('1520-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1002test'), rdflib.term.URIRef('http://icondataset.org/playful-attitude'))
# (rdflib.term.Literal('1525-01-01T0:00:00'), rdflib.term.Literal('1530-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1200'), rdflib.term.URIRef('http://icondataset.org/child'))
# (rdflib.term.Literal('1525-01-01T0:00:00'), rdflib.term.Literal('1530-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1200'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1525-01-01T0:00:00'), rdflib.term.Literal('1530-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1200'), rdflib.term.URIRef('http://icondataset.org/arrow'))
# (rdflib.term.Literal('1534-01-01T0:00:00'), rdflib.term.Literal('1534-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1321'), rdflib.term.URIRef('http://icondataset.org/boy'))
# (rdflib.term.Literal('1534-01-01T0:00:00'), rdflib.term.Literal('1534-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1321'), rdflib.term.URIRef('http://icondataset.org/bandage'))
# (rdflib.term.Literal('1534-01-01T0:00:00'), rdflib.term.Literal('1534-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1321'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1534-01-01T0:00:00'), rdflib.term.Literal('1534-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1321'), rdflib.term.URIRef('http://icondataset.org/arrows'))
# (rdflib.term.Literal('1534-01-01T0:00:00'), rdflib.term.Literal('1534-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1323'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1534-01-01T0:00:00'), rdflib.term.Literal('1534-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1323'), rdflib.term.URIRef('http://icondataset.org/arrows'))
# (rdflib.term.Literal('1534-01-01T0:00:00'), rdflib.term.Literal('1534-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1323'), rdflib.term.URIRef('http://icondataset.org/child'))
# (rdflib.term.Literal('1534-01-01T0:00:00'), rdflib.term.Literal('1534-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1323'), rdflib.term.URIRef('http://icondataset.org/sleeping'))
# (rdflib.term.Literal('1534-01-01T0:00:00'), rdflib.term.Literal('1534-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1323'), rdflib.term.URIRef('http://icondataset.org/bandage'))
# (rdflib.term.Literal('1534-01-01T0:00:00'), rdflib.term.Literal('1534-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1323'), rdflib.term.URIRef('http://icondataset.org/natural-landscape'))
# (rdflib.term.Literal('1545-01-01T0:00:00'), rdflib.term.Literal('1545-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1201'), rdflib.term.URIRef('http://icondataset.org/young'))
# (rdflib.term.Literal('1545-01-01T0:00:00'), rdflib.term.Literal('1545-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1201'), rdflib.term.URIRef('http://icondataset.org/shooting-an-arrow'))
# (rdflib.term.Literal('1545-01-01T0:00:00'), rdflib.term.Literal('1545-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1201'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1545-01-01T0:00:00'), rdflib.term.Literal('1545-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1201'), rdflib.term.URIRef('http://icondataset.org/arrow'))
# (rdflib.term.Literal('1545-01-01T0:00:00'), rdflib.term.Literal('1545-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1201'), rdflib.term.URIRef('http://icondataset.org/man'))
# (rdflib.term.Literal('1546-01-01T0:00:00'), rdflib.term.Literal('1546-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1288'), rdflib.term.URIRef('http://icondataset.org/removing'))
# (rdflib.term.Literal('1554-01-01T0:00:00'), rdflib.term.Literal('1554-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1316'), rdflib.term.URIRef('http://icondataset.org/putto'))
# (rdflib.term.Literal('1554-01-01T0:00:00'), rdflib.term.Literal('1554-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1316'), rdflib.term.URIRef('http://icondataset.org/shooting-an-arrow'))
# (rdflib.term.Literal('1554-01-01T0:00:00'), rdflib.term.Literal('1554-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1316'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1554-01-01T0:00:00'), rdflib.term.Literal('1554-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1316'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1554-01-01T0:00:00'), rdflib.term.Literal('1554-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1316'), rdflib.term.URIRef('http://icondataset.org/arrow'))
# (rdflib.term.Literal('1554-01-01T0:00:00'), rdflib.term.Literal('1554-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1316'), rdflib.term.URIRef('http://icondataset.org/bandage'))
# (rdflib.term.Literal('1560-01-01T0:00:00'), rdflib.term.Literal('1565-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1339'), rdflib.term.URIRef('http://icondataset.org/putto'))
# (rdflib.term.Literal('1560-01-01T0:00:00'), rdflib.term.Literal('1565-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1339'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1560-01-01T0:00:00'), rdflib.term.Literal('1565-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1339'), rdflib.term.URIRef('http://icondataset.org/snuggling-in-her-lap'))
# (rdflib.term.Literal('1560-01-01T0:00:00'), rdflib.term.Literal('1565-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1339'), rdflib.term.URIRef('http://icondataset.org/woman'))
# (rdflib.term.Literal('1560-01-01T0:00:00'), rdflib.term.Literal('1565-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1339'), rdflib.term.URIRef('http://icondataset.org/leaning-on-her-shoulder'))
# (rdflib.term.Literal('1574-01-01T0:00:00'), rdflib.term.Literal('1574-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1322'), rdflib.term.URIRef('http://icondataset.org/child'))
# (rdflib.term.Literal('1574-01-01T0:00:00'), rdflib.term.Literal('1574-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1322'), rdflib.term.URIRef('http://icondataset.org/running'))
# (rdflib.term.Literal('1574-01-01T0:00:00'), rdflib.term.Literal('1574-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1322'), rdflib.term.URIRef('http://icondataset.org/bandage'))
# (rdflib.term.Literal('1574-01-01T0:00:00'), rdflib.term.Literal('1574-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1322'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1584-01-01T0:00:00'), rdflib.term.Literal('1584-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1308'), rdflib.term.URIRef('http://icondataset.org/putto'))
# (rdflib.term.Literal('1584-01-01T0:00:00'), rdflib.term.Literal('1584-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1308'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1631-01-01T0:00:00'), rdflib.term.Literal('1631-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1324'), rdflib.term.URIRef('http://icondataset.org/child'))
# (rdflib.term.Literal('1631-01-01T0:00:00'), rdflib.term.Literal('1631-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1324'), rdflib.term.URIRef('http://icondataset.org/bandage'))
# (rdflib.term.Literal('1631-01-01T0:00:00'), rdflib.term.Literal('1631-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1324'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1631-01-01T0:00:00'), rdflib.term.Literal('1631-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1324'), rdflib.term.URIRef('http://icondataset.org/fishing'))
# (rdflib.term.Literal('1667-01-01T0:00:00'), rdflib.term.Literal('1667-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1326'), rdflib.term.URIRef('http://icondataset.org/child'))
# (rdflib.term.Literal('1667-01-01T0:00:00'), rdflib.term.Literal('1667-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1326'), rdflib.term.URIRef('http://icondataset.org/bandage'))
# (rdflib.term.Literal('1667-01-01T0:00:00'), rdflib.term.Literal('1667-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1326'), rdflib.term.URIRef('http://icondataset.org/sphere'))
# (rdflib.term.Literal('1667-01-01T0:00:00'), rdflib.term.Literal('1667-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1326'), rdflib.term.URIRef('http://icondataset.org/standing-on'))
# (rdflib.term.Literal('1667-01-01T0:00:00'), rdflib.term.Literal('1667-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1326'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1667-01-01T0:00:00'), rdflib.term.Literal('1667-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1326'), rdflib.term.URIRef('http://icondataset.org/arrows'))
# (rdflib.term.Literal('None'), rdflib.term.Literal('1318-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1312'), rdflib.term.URIRef('http://icondataset.org/horse'))
# (rdflib.term.Literal('None'), rdflib.term.Literal('1318-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1312'), rdflib.term.URIRef('http://icondataset.org/string-of-hearts'))
# (rdflib.term.Literal('None'), rdflib.term.Literal('1318-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1312'), rdflib.term.URIRef('http://icondataset.org/boy'))
# (rdflib.term.Literal('None'), rdflib.term.Literal('1318-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1312'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('None'), rdflib.term.Literal('1318-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1312'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('None'), rdflib.term.Literal('1318-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1312'), rdflib.term.URIRef('http://icondataset.org/arrow'))
# (rdflib.term.Literal('None'), rdflib.term.Literal('1318-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1312'), rdflib.term.URIRef('http://icondataset.org/griffon-claws'))
# (rdflib.term.Literal('None'), rdflib.term.Literal('1318-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1312'), rdflib.term.URIRef('http://icondataset.org/roses'))
# (rdflib.term.Literal('None'), rdflib.term.Literal('1318-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1312'), rdflib.term.URIRef('http://icondataset.org/standing-on-a-horse'))
# (rdflib.term.Literal('1368-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1122'), rdflib.term.URIRef('http://icondataset.org/arrows'))
# (rdflib.term.Literal('1368-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1122'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1368-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1122'), rdflib.term.URIRef('http://icondataset.org/crown'))
# (rdflib.term.Literal('1368-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1122'), rdflib.term.URIRef('http://icondataset.org/boy'))
# (rdflib.term.Literal('1368-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1122'), rdflib.term.URIRef('http://icondataset.org/bandage'))
# (rdflib.term.Literal('1368-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1122'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1368-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1122'), rdflib.term.URIRef('http://icondataset.org/court-dress'))
# (rdflib.term.Literal('801-01-01T0:00:00'), rdflib.term.Literal('1000-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1294'), rdflib.term.URIRef('http://icondataset.org/boy'))
# (rdflib.term.Literal('801-01-01T0:00:00'), rdflib.term.Literal('1000-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1294'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('801-01-01T0:00:00'), rdflib.term.Literal('1000-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1294'), rdflib.term.URIRef('http://icondataset.org/flying'))
# (rdflib.term.Literal('801-01-01T0:00:00'), rdflib.term.Literal('1000-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1294'), rdflib.term.URIRef('http://icondataset.org/arrows'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1292'), rdflib.term.URIRef('http://icondataset.org/putto'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1292'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1292'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1292'), rdflib.term.URIRef('http://icondataset.org/arrow'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1292'), rdflib.term.URIRef('http://icondataset.org/shooting-an-arrow'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1292'), rdflib.term.URIRef('http://icondataset.org/mantle'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1315'), rdflib.term.URIRef('http://icondataset.org/putto'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1315'), rdflib.term.URIRef('http://icondataset.org/shooting-an-arrow'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1315'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1315'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1315'), rdflib.term.URIRef('http://icondataset.org/arrow'))
# (rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1315'), rdflib.term.URIRef('http://icondataset.org/mantle'))
# (rdflib.term.Literal('1501-01-01T0:00:00'), rdflib.term.Literal('1600-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1311'), rdflib.term.URIRef('http://icondataset.org/boy'))
# (rdflib.term.Literal('1501-01-01T0:00:00'), rdflib.term.Literal('1600-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1311'), rdflib.term.URIRef('http://icondataset.org/wings'))
# (rdflib.term.Literal('1501-01-01T0:00:00'), rdflib.term.Literal('1600-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1311'), rdflib.term.URIRef('http://icondataset.org/bandage'))
# (rdflib.term.Literal('1501-01-01T0:00:00'), rdflib.term.Literal('1600-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1311'), rdflib.term.URIRef('http://icondataset.org/bow'))
# (rdflib.term.Literal('1501-01-01T0:00:00'), rdflib.term.Literal('1600-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1311'), rdflib.term.URIRef('http://icondataset.org/arrows'))
# (rdflib.term.Literal('1501-01-01T0:00:00'), rdflib.term.Literal('1600-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1311'), rdflib.term.URIRef('http://icondataset.org/griffon-claws'))
# (rdflib.term.Literal('1501-01-01T0:00:00'), rdflib.term.Literal('1600-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1311'), rdflib.term.URIRef('http://icondataset.org/crown-of-roses'))
# (rdflib.term.Literal('1501-01-01T0:00:00'), rdflib.term.Literal('1600-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1311'), rdflib.term.URIRef('http://icondataset.org/string-of-hearts'))
# (rdflib.term.Literal('1501-01-01T0:00:00'), rdflib.term.Literal('1600-12-31T23:59:59'), rdflib.term.URIRef('http://icondataset.org/ART1311'), rdflib.term.URIRef('http://icondataset.org/throne'))

# %%
with open('cupid_attr_time.csv', mode='w') as my_file:
    more_centuries = []
    my_writer = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
    # write the column names
    my_writer.writerow(['Date' , 'Century', 'Artwork', 'Level1Representation'])
    
    # access the rows of the query results
    for timeStart, timeEnd, artwork, lev1 in cqres:
        lev1_cleaned1 = lev1.replace("http://icondataset.org/", "")
        lev1_cleaned2 = lev1_cleaned1.replace("-", " ")
        artwork_cleaned = artwork.replace("http://icondataset.org/", "")
        if timeEnd == "None" and timeStart != "None":# or timeEnd == "None":
            time = int(timeStart[:4])
        elif timeStart == "None" and timeEnd != "None": 
            time = int(timeEnd[:4])
            print(time)
            
        if len(timeEnd) == 17: 
            end = 1325
        if len(timeStart) == 19: # ci deve essere qualcosa che non va tra questo e le istruzioni dopo
           # print(len(timeEnd), timeEnd)
            start = int(timeStart[:4])
            end = int(timeEnd[:4])
           # print(timeStart, artwork)

            if start != end: 
                time = str((start+end)/2)
            else: 
                time = str(end)
                
        if time.startswith("8"): 
            century = "IX"
            year = 9
        elif time.startswith("9"): 
            century = "X"
            year = 10
        elif time.startswith("10"): 
            century = "XI"
            year = 11
        elif time.startswith("11"): 
            century = "XII"
            year = 12
        elif time.startswith("12"): 
            century = "XIII"
            year = 13
        elif time.startswith("13"): 
            century = "XIV"
            year = 14
        elif time.startswith("14"): 
            century = "XV"
            year = 15
        elif time.startswith("15"): 
            century = "XVI"
            year = 16
        elif time.startswith("16"): 
            century = "XVII"
            year = 17

        # write in the cv
        my_writer.writerow([year, century, artwork_cleaned, lev1_cleaned2])

# %%
frequency_dict = {} # key = date, 
with open('cupid_attr_time.csv', mode='r') as my_file:
    cupid_data = csv.DictReader(my_file)
    
    for row in cupid_data:
        print(row)
        date = row["Date"]
        century = row["Century"]
        subject = row["Level1Representation"]
        if date not in frequency_dict: 
            frequency_dict[date] ={}
            frequency_dict[date][century] = {}
        if subject not in frequency_dict[date][century]:
            frequency_dict[date][century][subject] = 0
        frequency_dict[date][century][subject] += 1
                
print(frequency_dict)
# Out:
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1291', 'Level1Representation': 'putto'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1291', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1293', 'Level1Representation': 'boy'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1293', 'Level1Representation': 'mantle'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1293', 'Level1Representation': 'torch'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1293', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1293', 'Level1Representation': 'arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1130', 'Level1Representation': 'boy'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1130', 'Level1Representation': 'flying'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1130', 'Level1Representation': 'holding with a hand'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1130', 'Level1Representation': 'torch'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1130', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1131', 'Level1Representation': 'putto'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1131', 'Level1Representation': 'wreath'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1131', 'Level1Representation': 'grabbing with one hand'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1132', 'Level1Representation': 'putto'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1132', 'Level1Representation': 'wreath'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1132', 'Level1Representation': 'grabbing with one hand'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1129', 'Level1Representation': 'boy'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1129', 'Level1Representation': 'sleeping'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1129', 'Level1Representation': 'leaning upon'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1129', 'Level1Representation': 'torch'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1129', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1310', 'Level1Representation': 'boy'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1310', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1310', 'Level1Representation': 'bandage'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1310', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1310', 'Level1Representation': 'arrows'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1310', 'Level1Representation': 'griffon claws'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1310', 'Level1Representation': 'crown of roses'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1310', 'Level1Representation': 'hearts'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1313', 'Level1Representation': 'horse'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1313', 'Level1Representation': 'boy'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1313', 'Level1Representation': 'band'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1313', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1313', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1313', 'Level1Representation': 'arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1313', 'Level1Representation': 'griffon claws'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1313', 'Level1Representation': 'spear'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1313', 'Level1Representation': 'standing on a horse'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1203', 'Level1Representation': 'arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1203', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1203', 'Level1Representation': 'putto'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1203', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1203', 'Level1Representation': 'taking aim'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1203', 'Level1Representation': 'fire'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1123', 'Level1Representation': 'bandage'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1123', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1123', 'Level1Representation': 'court dress'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1123', 'Level1Representation': 'arrows'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1123', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1123', 'Level1Representation': 'boy'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1317', 'Level1Representation': 'child'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1317', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1317', 'Level1Representation': 'bandage'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1317', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1317', 'Level1Representation': 'arrows'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1329', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1329', 'Level1Representation': 'stirring water'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1329', 'Level1Representation': 'putto'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1002test', 'Level1Representation': 'putto'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1002test', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1002test', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1002test', 'Level1Representation': 'holding a wreath'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1002test', 'Level1Representation': 'playful attitude'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1200', 'Level1Representation': 'child'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1200', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1200', 'Level1Representation': 'arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1321', 'Level1Representation': 'boy'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1321', 'Level1Representation': 'bandage'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1321', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1321', 'Level1Representation': 'arrows'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1323', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1323', 'Level1Representation': 'arrows'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1323', 'Level1Representation': 'child'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1323', 'Level1Representation': 'sleeping'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1323', 'Level1Representation': 'bandage'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1323', 'Level1Representation': 'natural landscape'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1201', 'Level1Representation': 'young'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1201', 'Level1Representation': 'shooting an arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1201', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1201', 'Level1Representation': 'arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1201', 'Level1Representation': 'man'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1288', 'Level1Representation': 'removing'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1316', 'Level1Representation': 'putto'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1316', 'Level1Representation': 'shooting an arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1316', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1316', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1316', 'Level1Representation': 'arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1316', 'Level1Representation': 'bandage'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1339', 'Level1Representation': 'putto'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1339', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1339', 'Level1Representation': 'snuggling in her lap'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1339', 'Level1Representation': 'woman'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1339', 'Level1Representation': 'leaning on her shoulder'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1322', 'Level1Representation': 'child'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1322', 'Level1Representation': 'running'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1322', 'Level1Representation': 'bandage'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1322', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1308', 'Level1Representation': 'putto'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1308', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1324', 'Level1Representation': 'child'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1324', 'Level1Representation': 'bandage'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1324', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1324', 'Level1Representation': 'fishing'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1326', 'Level1Representation': 'child'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1326', 'Level1Representation': 'bandage'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1326', 'Level1Representation': 'sphere'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1326', 'Level1Representation': 'standing on'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1326', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1326', 'Level1Representation': 'arrows'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1312', 'Level1Representation': 'horse'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1312', 'Level1Representation': 'string of hearts'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1312', 'Level1Representation': 'boy'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1312', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1312', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1312', 'Level1Representation': 'arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1312', 'Level1Representation': 'griffon claws'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1312', 'Level1Representation': 'roses'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1312', 'Level1Representation': 'standing on a horse'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1122', 'Level1Representation': 'arrows'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1122', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1122', 'Level1Representation': 'crown'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1122', 'Level1Representation': 'boy'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1122', 'Level1Representation': 'bandage'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1122', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1122', 'Level1Representation': 'court dress'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1294', 'Level1Representation': 'boy'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1294', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1294', 'Level1Representation': 'flying'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1294', 'Level1Representation': 'arrows'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1292', 'Level1Representation': 'putto'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1292', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1292', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1292', 'Level1Representation': 'arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1292', 'Level1Representation': 'shooting an arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1292', 'Level1Representation': 'mantle'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1315', 'Level1Representation': 'putto'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1315', 'Level1Representation': 'shooting an arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1315', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1315', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1315', 'Level1Representation': 'arrow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1315', 'Level1Representation': 'mantle'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1311', 'Level1Representation': 'boy'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1311', 'Level1Representation': 'wings'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1311', 'Level1Representation': 'bandage'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1311', 'Level1Representation': 'bow'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1311', 'Level1Representation': 'arrows'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1311', 'Level1Representation': 'griffon claws'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1311', 'Level1Representation': 'crown of roses'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1311', 'Level1Representation': 'string of hearts'}
# {'Date': '17', 'Century': 'XVII', 'Artwork': 'ART1311', 'Level1Representation': 'throne'}
# {'17': {'XVII': {'putto': 11, 'wings': 24, 'boy': 11, 'mantle': 3, 'torch': 3, 'arrow': 9, 'flying': 2, 'holding with a hand': 1, 'wreath': 2, 'grabbing with one hand': 2, 'sleeping': 2, 'leaning upon': 1, 'bandage': 11, 'bow': 15, 'arrows': 9, 'griffon claws': 4, 'crown of roses': 2, 'hearts': 1, 'horse': 2, 'band': 1, 'spear': 1, 'standing on a horse': 2, 'taking aim': 1, 'fire': 1, 'court dress': 2, 'child': 6, 'stirring water': 1, 'holding a wreath': 1, 'playful attitude': 1, 'natural landscape': 1, 'young': 1, 'shooting an arrow': 4, 'man': 1, 'removing': 1, 'snuggling in her lap': 1, 'woman': 1, 'leaning on her shoulder': 1, 'running': 1, 'fishing': 1, 'sphere': 1, 'standing on': 1, 'string of hearts': 2, 'roses': 1, 'crown': 1, 'throne': 1}}}

# %%
with open('cupid_final.csv', mode='w') as my_file:
    my_writer = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
    # write the column names
    my_writer.writerow(['Date' , 'Century', 'Attribute', 'Frequency'])

    for date in frequency_dict.items(): # date: tuple with tuple[0] = number, tuple[1] = dict
        year= date[0]
        for cent in date[1].items(): 
            century = cent[0]
            for term in cent[1].items(): 
                attribute = term[0]
                frequency = term[1]
                my_writer.writerow([year, century, attribute, int(frequency)])
    my_writer.writerow([12, "XII", "", 0])
    my_writer.writerow([13, "XIII", "", 0])
# write a csv with them, ordered

# %%
data = pd.read_csv("cupid_attr_time.csv")
# print the first 5 rows
df = data.sort_values(by=['Date'])
# print(df)
df.head()
# Out:
#      Date Century  Artwork Level1Representation
# 0      16     XVI  ART1291                putto
# 97     16     XVI  ART1322              bandage
# 98     16     XVI  ART1322                wings
# 99     16     XVI  ART1308                putto
# 100    16     XVI  ART1308                wings
