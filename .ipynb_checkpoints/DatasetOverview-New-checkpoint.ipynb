# %% [markdown]
# # Dataset overview

# %% [markdown]
# This notebook contains the SPARQL queries useful to have a general overview of the dataset itself (e.g. number of triples, number of subjects etc.). </br>
# It is structured ad follows. Section 1 gives an overview of the numbers of objects present in the dataset. Section 2 gives an overview on cultural phenomena and the exploratory analisis of the correlation between cultural phenomena and subjects of other levels. Section 3 presents the relations between subjects of different levels.

# %% [markdown]
# ## Table of contents:
# * [1.The dataset in numbers](#first-bullet)
# * [2.Overview of Cultural Phenomena](#second-bullet)
# * [3.Overview of subjects relations](#third-bullet)

# %%
import rdflib
from rdflib.namespace import CSVW, DC, DCAT, DCTERMS, DOAP, FOAF, ODRL2, ORG, OWL, \
                           PROF, PROV, RDF, RDFS, SDO, SH, SKOS, SOSA, SSN, TIME, \
                           VOID, XMLNS, XSD
from rdflib import Namespace
from rdflib import URIRef

import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from collections import defaultdict , Counter
import plotly.graph_objects as go

# %%
newg = rdflib.Graph() # we create a new graph
newg.parse("07112022output3.ttl", format="ttl")
# Out:
# <Graph identifier=Ndf073fe11fa14f3ba699dea436914d16 (<class 'rdflib.graph.Graph'>)>

# %%
# useful functions
import json
def store_in_json(file_name, dictName): 
  with open(file_name, mode='w', encoding="utf-8") as jsonfile:
    json.dump(dictName, jsonfile)
    
# open dictionaries stored in json
def open_json(json_file): 
  with open(json_file, mode='r', encoding="utf-8") as jsonfile:
    dictName = json.load(jsonfile)
    return dictName


import csv 
def store_csv(file_name, first_line, list_of_lists): 
    with open(file_name, mode='w', newline='', encoding='UTF-8') as my_file:
        file = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
        file.writerow(first_line) 
        for l in list_of_lists: 
            file.writerow(l) 
    return(file_name)

# wrap x labels in graphs
import textwrap
def wrap_labels(ax, width, break_long_words=False):
    labels = []
    for label in ax.get_xticklabels():
        text = label.get_text()
        labels.append(textwrap.fill(text, width=width,
                      break_long_words=break_long_words))
    ax.set_xticklabels(labels, rotation=0)

# %% [markdown]
# # 1.The dataset in numbers<a class="anchor" id="first-bullet"></a>

# %%
counting_overview = []

# %% [markdown]
# ### Number of triples

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 


SELECT (count(?subj) as ?tot) WHERE {
# ?subj ?rel ?obj. 

}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["Triples", int(row[0])])
# Out:
# (rdflib.term.Literal('71318', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# ### Number of artworks

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT (count(distinct ?art) as ?tot) WHERE {
#?obj a crm:E22_Human_Made_Object; 
#    crm:P65_shows_visual_item ?art. 
# ?art a icon:Artwork. 
# ?rec icon:aboutWorkOfArt ?art.  

}
'''

cqres = newg.query(cq)

for row in cqres:
    counting_overview.append(["Artworks", int(row[0])])
    print(row)
# Out:
# (rdflib.term.Literal('423', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# ### Number of level 1 recognitions

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 


SELECT (count(distinct ?preic) as ?tot) WHERE {
{?preic a icon:PreiconographicalRecognition} UNION {?preic a icon:FormalMotifRecognition} 
}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["Level 1 Recognitions", int(row[0])])
# Out:
# (rdflib.term.Literal('3517', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %%
### Number of level 2 recognitions

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 


SELECT (count(distinct ?icrec) as ?tot) WHERE {
# ?icrec a icon:IconographicalRecognition. 
}
'''

cqres = newg.query(cq)

for row in cqres:
    counting_overview.append(["Level 2 Recognitions", int(row[0])])
    print(row)
# Out:
# (rdflib.term.Literal('1035', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %%
### Number of level 3 recognitions

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 


SELECT (count(distinct ?rec) as ?tot) WHERE {
# ?rec a icon:IconologicalRecognition. 
}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["Level 3 Recognitions", int(row[0])])
# Out:
# (rdflib.term.Literal('877', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# ### Number of level 1 subjects

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 


SELECT (count(distinct ?lev1) as ?tot) WHERE {
# ?rec a icon:PreiconographicalRecognition. 
{?rec icon:recognizedArtisticMotif ?am} UNION {?rec icon:recognizedComposition ?comp. ?comp icon:hasPart ?am}
# ?am icon:hasFactualMeaning | icon:hasExpressionalMeaning | crm:P138_represents ?lev1. 
}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["Level 1 subjects", int(row[0])])
# Out:
# (rdflib.term.Literal('923', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# ### Number of level 2 subjects

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>


SELECT (count(distinct ?lev2) as ?tot) WHERE {
VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasPlace icon:hasPersonification icon:hasNamedObject icon:hasSymbol}
# ?rec a icon:IconographicalRecognition. 
{?rec icon:recognizedImage ?img. ?img ?rel ?lev2} UNION {?rec icon:recognizedInvenzione ?inv. ?inv icon:composedOf ?lev2}

}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["Level 2 subjects", int(row[0])])
counting_overview
# Out:
# (rdflib.term.Literal('555', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)
# [['Triples', 71318],
#  ['Artworks', 423],
#  ['Level 1 Recognitions', 3517],
#  ['Level 2 Recognitions', 1035],
#  ['Level 3 Recognitions', 877],
#  ['Level 1 subjects', 888],
#  ['Level 2 subjects', 555]]

# %% [markdown]
# ### Number of level 3 subjects

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>


SELECT (count(distinct ?lev3) as ?tot) WHERE {
VALUES ?rel {icon:recognizedConceptualObject icon:recognizedCulturalPhenomenon}
# ?rec a icon:IconologicalRecognition. 
# ?rec icon:recognizedIntrinsicMeaning ?intrinsic. ?intrinsic ?rel ?lev3. 
}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["Level 3 subjects", int(row[0])])
# Out:
# (rdflib.term.Literal('422', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# ### Number of people

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT (count(distinct ?people) as ?tot) WHERE {

# ?people a crm:E21_Person. 

}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["People", int(row[0])])
# Out:
# (rdflib.term.Literal('214', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %%
if (URIRef("http://icondataset.org/people/cesare-vecellio"), None, None) in newg:
    print("this works")
else: 
    print("not working")
# Out:
# not working

# %% [markdown]
# ### Number of books

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT (count(distinct ?book) as ?tot) WHERE {

{?book crm:P2_has_type ?type. 
# ?type crm:P2_has_type <http://vocab.getty.edu/page/aat/300028051>. } 
UNION 
{?book crm:P2_has_type <http://vocab.getty.edu/page/aat/300028051>}

}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["Books", int(row[0])])
# Out:
# (rdflib.term.Literal('147', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# ### Number of Places

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT (count(distinct ?place) as ?tot) WHERE {
#?art crm:P53_has_former_or_current_location ?place.
# ?place crm:P89_falls_within ?place2. 
# ?place a crm:E53_Place.

}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["Places", int(row[0])])
# Out:
# (rdflib.term.Literal('221', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# ### number of artworks types

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT (count(distinct ?type) as ?tot) WHERE {
# ?obj crm:P65_shows_visual_item ?art; 
    crm:P2_has_type ?type. 


}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["Cultural Object types", int(row[0])])
# Out:
# (rdflib.term.Literal('56', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# ### Number of styles

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT (count(distinct ?style) as ?tot) WHERE {

# ?style crm:P2_has_type <http://vocab.getty.edu/aat/300015646>.



}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["Styles", int(row[0])])
# Out:
# (rdflib.term.Literal('32', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# ### Number of periods

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT (count(distinct ?period) as ?tot) WHERE {

# ?period a crm:E4_Period.



}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["Periods", int(row[0])])
# Out:
# (rdflib.term.Literal('12', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# ### Number of sources cited as evidence

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT (count(distinct ?evidence) as ?tot) WHERE {

# ?entity cito:citesAsEvidence ?evidence. 



}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["cited Evidences", int(row[0])])
# Out:
# (rdflib.term.Literal('186', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# ### Number of resources aligned

# %%
cq = '''
PREFIX d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX owl: <http://www.w3.org/2002/07/owl#> 


SELECT (count(distinct ?entity) as ?tot) WHERE {

# ?entity owl:sameAs ?evidence. 



}
'''

cqres = newg.query(cq)

for row in cqres:
    print(row)
    counting_overview.append(["resources aligned", int(row[0])])
# Out:
# (rdflib.term.Literal('195', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %%
# we don't consider triples, as the visualization is not interesting with a such high number 
counting_overview.remove(["Level 1 subjects", 888])
counting_overview
# Out:
# [['Artworks', 423],
#  ['Level 1 Recognitions', 3517],
#  ['Level 2 Recognitions', 1035],
#  ['Level 3 Recognitions', 877],
#  ['Level 2 subjects', 555],
#  ['Level 3 subjects', 422],
#  ['People', 214],
#  ['Books', 147],
#  ['Places', 221],
#  ['Cultural Object types', 56],
#  ['Styles', 32],
#  ['Periods', 12],
#  ['cited Evidences', 186],
#  ['resources aligned', 195],
#  ['Level 1 subjects', 923]]

# %%
# barchart of the countings, excluding the number of triples ? 

# List of lists where each list is [object, frequency] 

df = pd.DataFrame(np.array(counting_overview),
                   columns=['Object', 'Frequency'])
df['Frequency'] = df['Frequency'].astype(int)
result = df.dtypes

print("Output:")
print(result)
# Out:
# Output:
# Object       object
# Frequency     int32
# dtype: object

# %%
dfcount = df.sort_values(by=['Frequency'], ascending=False)
dfcount
# Out:
#                    Object  Frequency
# 1    Level 1 Recognitions       3517
# 2    Level 2 Recognitions       1035
# 14       Level 1 subjects        923
# 3    Level 3 Recognitions        877
# 4        Level 2 subjects        555
# 0                Artworks        423
# 5        Level 3 subjects        422
# 8                  Places        221
# 6                  People        214
# 13      resources aligned        195
# 12        cited Evidences        186
# 7                   Books        147
# 9   Cultural Object types         56
# 10                 Styles         32
# 11                Periods         12

# %%
import seaborn as seaborn 
chartCount = seaborn.barplot(data=dfcount, x = 'Frequency', y='Object')

# %% [markdown]
# # 2. Overwiew of Cultural Phenomena<a class="anchor" id="second-bullet"></a>

# %% [markdown]
# section with:
# * [2-1 Overview of the major categories counting](#2.1-Overview-of-the-major-categories-counting)
# * 2.2 [Barcharts showing the frequency of the top subjects per cultural phenomenon](#2.2-Frequency-of-the-top-K-subjects-per-Cultural-Phenomenon-(barcharts))
# * [2.3 General histogram of frequency of subjects per Cultural Phenomenon](#2.3-Frequency-of-the-top-K-subjects-per-Cultural-Phenomenon-(overall-visualization))
# * [2.4 Co-occurrencies of subjects and Cultural Phenomena](#2.4-Co-occurrencies-of-subjects-and-Cultural-Phenomena)
#
# <br>
#
# [Back to top](#Dataset-overview)

# %% [markdown]
# ## 2.1 Overview of the major categories counting
# count how many artworks have a certain phenomenon category and visualize it. NB: one cultural phenomenon may have more than one category

# %%
cf_category_frequency = []
cq1 = '''
prefix data: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?CFBroaderLabel (count(distinct ?artwork) as ?tot) WHERE {
  # ?iconol icon:aboutWorkOfArt ?artwork;
  icon:recognizedIntrinsicMeaning ?intrinsic.
  # ?intrinsic icon:recognizedCulturalPhenomenon ?meaning.
  # ?meaning a icon:CulturalPhenomenon; crm:P2_has_type ?CFBroader. 
  # ?CFBroader rdfs:label ?CFBroaderLabel .
}
GROUP BY ?CFBroaderLabel 
ORDER BY DESC(?tot)
'''

cq1res = newg.query(cq1)
for row in cq1res: 
    if str(row[0]) != "?": 
        cf_category_frequency.append([str(row[0]), int(row[1])])

# %%
df2 = pd.DataFrame(np.array(cf_category_frequency),
                   columns=['Cultural Phenomenon', 'Frequency'])
df2['Frequency'] = df2['Frequency'].astype(int)
result = df2.dtypes

print("Output:")
print(result)
# Out:
# Output:
# Cultural Phenomenon    object
# Frequency               int32
# dtype: object

# %%
# df3 = df2.sort_values(by=['Frequency'], ascending=False)
df3 = df2.sort_index(ascending=False)
df3
# Out:
#                  Cultural Phenomenon  Frequency
# 20           Cultural interpretation          2
# 19                     Moral meaning          2
# 18       Iconographic interpretation          3
# 17                             Taste          3
# 16                            Humour          3
# 15                 Cultural movement          4
# 14                    Cultural value          7
# 13               Societal phenomenon         10
# 12                Cultural influence         14
# 11                          Attitude         15
# 10          Iconographical influence         15
# 9                Artist's expression         15
# 8          Cultural reinterpretation         17
# 7      Formal or stylistic influence         24
# 6                             Belief         30
# 5                           Tendency         39
# 4      Iconographical interpretation         51
# 3     Formal or stylistic phenomenon         61
# 2      Formal or stylistic evolution         89
# 1           Iconographical evolution        115
# 0   Reception of Classical antiquity        203

# %%
import seaborn as seaborn 
chart = seaborn.barplot(data=df3, x = 'Frequency', y='Cultural Phenomenon')

# %% [markdown]
# [Back to top](#Dataset-overview) <br>
# [Back to section 2](#2.-Overwiew-of-Cultural-Phenomena)

# %% [markdown]
# ## 2.2 Frequency of the top K subjects per Cultural Phenomenon (barcharts)

# %%
# test
cq2 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?CFbroader ?artwork WHERE {
  VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
  # ?CFbroader ^crm:P2_has_type ?meaning.
  # ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?iconol icon:aboutWorkOfArt ?artwork .


} 
""" 

cq2res = newg.query(cq2)
for row in cq2res:
  print(row[0], '-',row[1])

# %%
# no modify
cq2 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?CFbroader ?CFbroaderLabel ?artwork ?subj2  WHERE {
  VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
  # ?CFbroader ^crm:P2_has_type ?meaning.
  # ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?iconol icon:aboutWorkOfArt ?artwork .
  # ?icrec icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition;
          icon:recognizedImage ?image.
 
  # ?CFbroader rdfs:label ?CFbroaderLabel. 
  # ?image ?rel ?subj2. 

  #OPTIONAL {
  #  ?icrec icon:aboutWorkOfArt ?artwork;
  #  a icon:IconographicalRecognition; icon:recognizedInvenzione ?subj2.
  #}

} 
""" 

cq2res = newg.query(cq2)
for row in cq2res:
  print(row[0], '-',row[3], " -- cf: ", row[1])
# Out:
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/hercules  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/orpheus  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/orpheus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/societal-phenomenon - http://icondataset.org/the-young-mago-caspar  -- cf:  Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/member-of-the-procession  -- cf:  Societal phenomenon
# http://icondataset.org/iconographical-evolution - http://icondataset.org/christ  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/christ  -- cf:  Reception of Classical antiquity
# http://icondataset.org/tendency - http://icondataset.org/christ  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/cerberus  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cerberus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/pluto  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pluto  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/proserpina  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/proserpina  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/cerberus  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cerberus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/pluto  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pluto  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/proserpina  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/proserpina  -- cf:  Reception of Classical antiquity
# http://icondataset.org/belief - http://icondataset.org/archangel-gabriel  -- cf:  Belief
# http://icondataset.org/belief - http://icondataset.org/mary  -- cf:  Belief
# http://icondataset.org/belief - http://icondataset.org/god  -- cf:  Belief
# http://icondataset.org/belief - http://icondataset.org/archangel-gabriel  -- cf:  Belief
# http://icondataset.org/belief - http://icondataset.org/mary  -- cf:  Belief
# http://icondataset.org/belief - http://icondataset.org/salamander  -- cf:  Belief
# http://icondataset.org/belief - http://icondataset.org/crocodile  -- cf:  Belief
# http://icondataset.org/societal-phenomenon - http://icondataset.org/christ  -- cf:  Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/satan  -- cf:  Societal phenomenon
# http://icondataset.org/iconographical-evolution - http://icondataset.org/perseus  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/perseus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/argus  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/argus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/argus  -- cf:  Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-influence - http://icondataset.org/planetary-deities  -- cf:  Iconographical influence
# http://icondataset.org/iconographical-influence - http://icondataset.org/planetary-deities  -- cf:  Iconographical influence
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/jupiter  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-evolution - http://icondataset.org/jupiter  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/venus  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/mercury  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/saturn  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- cf:  Reception of Classical antiquity
# http://icondataset.org/attitude - http://icondataset.org/planetary-deities  -- cf:  Attitude
# http://icondataset.org/belief - http://icondataset.org/planetary-deities  -- cf:  Belief
# http://icondataset.org/attitude - http://icondataset.org/the-children-of-each-planet  -- cf:  Attitude
# http://icondataset.org/belief - http://icondataset.org/the-children-of-each-planet  -- cf:  Belief
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-children-of-saturn  -- cf:  Iconographical evolution
# http://icondataset.org/belief - http://icondataset.org/the-children-of-saturn  -- cf:  Belief
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury  -- cf:  Iconographical evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-children-of-mercury  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-children-of-mercury  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-children-of-mercury  -- cf:  Iconographical evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-influence - http://icondataset.org/mercury  -- cf:  Iconographical influence
# http://icondataset.org/belief - http://icondataset.org/mercury  -- cf:  Belief
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-children-of-mercury  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-influence - http://icondataset.org/the-children-of-mercury  -- cf:  Iconographical influence
# http://icondataset.org/belief - http://icondataset.org/the-children-of-mercury  -- cf:  Belief
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-children-of-mercury  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/mars  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mars  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mars  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pluto  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/pluto  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/pluto  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/mercury  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bacchus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/bacchus  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/bacchus  -- cf:  Iconographical interpretation
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/laocoon  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/laocoon  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/laocoon  -- cf:  Iconographical interpretation
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/thymbraeus-son-of-laoocoon  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/thymbraeus-son-of-laoocoon  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/thymbraeus-son-of-laoocoon  -- cf:  Iconographical interpretation
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/antiphas-son-of-laoocoon  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/antiphas-son-of-laoocoon  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/antiphas-son-of-laoocoon  -- cf:  Iconographical interpretation
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/marine-snakes  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/marine-snakes  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/marine-snakes  -- cf:  Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-movement - http://icondataset.org/saturn  -- cf:  Cultural movement
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/saturn  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/jupiter  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-movement - http://icondataset.org/jupiter  -- cf:  Cultural movement
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/jupiter  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/jupiter  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/apollo  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-movement - http://icondataset.org/apollo  -- cf:  Cultural movement
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/apollo  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/apollo  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/the-three-graces  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-three-graces  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-movement - http://icondataset.org/the-three-graces  -- cf:  Cultural movement
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-three-graces  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-three-graces  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/venus  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-influence - http://icondataset.org/venus  -- cf:  Iconographical influence
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-three-graces  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-three-graces  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-three-graces  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-influence - http://icondataset.org/the-three-graces  -- cf:  Iconographical influence
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury  -- cf:  Iconographical evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/argus  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/argus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/argus  -- cf:  Iconographical evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-influence - http://icondataset.org/hecuba  -- cf:  Cultural influence
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/hecuba  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/hecuba  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/hecuba  -- cf:  Cultural reinterpretation
# http://icondataset.org/cultural-influence - http://icondataset.org/troilus  -- cf:  Cultural influence
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/troilus  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/troilus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/troilus  -- cf:  Cultural reinterpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/polyxena  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/polyxena  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/polyxena  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/polyxena  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/archangel-gabriel  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mary  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/thisbe  -- cf:  Reception of Classical antiquity
# http://icondataset.org/tendency - http://icondataset.org/thisbe  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/thisbe  -- cf:  Formal or stylistic evolution
# http://icondataset.org/attitude - http://icondataset.org/thisbe  -- cf:  Attitude
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-three-graces  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-three-graces  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/europas-companions  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/europas-companions  -- cf:  Formal or stylistic evolution
# http://icondataset.org/attitude - http://icondataset.org/europas-companions  -- cf:  Attitude
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/eve  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/people/saint-luke  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saint-mark  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/saint-mark  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/saint-peter  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saint-peter  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/saint-peter  -- cf:  Formal or stylistic evolution
# http://icondataset.org/tendency - http://icondataset.org/saint-peter  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-resurrected  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-resurrected  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-resurrected  -- cf:  Formal or stylistic evolution
# http://icondataset.org/tendency - http://icondataset.org/the-resurrected  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/mary  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mary  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mary  -- cf:  Formal or stylistic evolution
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/mary  -- cf:  Cultural reinterpretation
# http://icondataset.org/tendency - http://icondataset.org/mary  -- cf:  Tendency
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/simeon  -- cf:  Reception of Classical antiquity
# http://icondataset.org/tendency - http://icondataset.org/simeon  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/simeon  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/god  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/prometheus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/pygmalion  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pygmalion  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-interpretation - http://icondataset.org/venus  -- cf:  Cultural interpretation
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-interpretation - http://icondataset.org/cupid  -- cf:  Cultural interpretation
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-interpretation - http://icondataset.org/venus  -- cf:  Cultural interpretation
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-interpretation - http://icondataset.org/cupid  -- cf:  Cultural interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/sisyphus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/sisyphus  -- cf:  Iconographical interpretation
# http://icondataset.org/moral-meaning - http://icondataset.org/sisyphus  -- cf:  Moral meaning
# http://icondataset.org/tendency - http://icondataset.org/sisyphus  -- cf:  Tendency
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/tantalus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/tantalus  -- cf:  Iconographical interpretation
# http://icondataset.org/moral-meaning - http://icondataset.org/tantalus  -- cf:  Moral meaning
# http://icondataset.org/tendency - http://icondataset.org/tantalus  -- cf:  Tendency
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/ixion  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/ixion  -- cf:  Iconographical interpretation
# http://icondataset.org/moral-meaning - http://icondataset.org/ixion  -- cf:  Moral meaning
# http://icondataset.org/tendency - http://icondataset.org/ixion  -- cf:  Tendency
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/hercules  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/hercules  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/satyr  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/satyr  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/cupid  -- cf:  Cultural reinterpretation
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/cupid  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/cupid  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/cupid  -- cf:  Cultural reinterpretation
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/cupid  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/cupid  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/mithras  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mithras  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mithras  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/mithras  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mithras  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mithras  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/people/virgil  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/people/virgil  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/people/virgil  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/people/virgil  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/people/virgil  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/people/virgil  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/people/virgil  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/people/virgil  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/people/virgil  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/people/virgil  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/people/virgil  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- cf:  Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/saint-john-the-evangelist  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/saint-john-the-evangelist  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saint-john-the-evangelist  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/joachim  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/mary  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/saint-anne  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/apostles  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/iconographical-evolution - http://icondataset.org/apostles  -- cf:  Iconographical evolution
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/christ  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/iconographical-evolution - http://icondataset.org/christ  -- cf:  Iconographical evolution
# http://icondataset.org/formal-or-stylistic-influence - http://icondataset.org/mary  -- cf:  Formal or stylistic influence
# http://icondataset.org/tendency - http://icondataset.org/mary  -- cf:  Tendency
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mary  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-influence - http://icondataset.org/christ  -- cf:  Formal or stylistic influence
# http://icondataset.org/tendency - http://icondataset.org/christ  -- cf:  Tendency
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/christ  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/david  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/david  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/roman-emperors  -- cf:  Reception of Classical antiquity
# http://icondataset.org/attitude - http://icondataset.org/roman-emperors  -- cf:  Attitude
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/paris  -- cf:  Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/paris  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/paris  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/helen  -- cf:  Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/helen  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/helen  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/hylas  -- cf:  Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/vulcan  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/hylas  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/vulcan  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/hylas  -- cf:  Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/vulcan  -- cf:  Formal or stylistic evolution
# http://icondataset.org/tendency - http://icondataset.org/hylas  -- cf:  Tendency
# http://icondataset.org/tendency - http://icondataset.org/vulcan  -- cf:  Tendency
# http://icondataset.org/artists-expression - http://icondataset.org/hylas  -- cf:  Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/vulcan  -- cf:  Artist's expression
# http://icondataset.org/belief - http://icondataset.org/hylas  -- cf:  Belief
# http://icondataset.org/belief - http://icondataset.org/vulcan  -- cf:  Belief
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/nymphs  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/nymphs  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/nymphs  -- cf:  Formal or stylistic evolution
# http://icondataset.org/tendency - http://icondataset.org/nymphs  -- cf:  Tendency
# http://icondataset.org/artists-expression - http://icondataset.org/nymphs  -- cf:  Artist's expression
# http://icondataset.org/belief - http://icondataset.org/nymphs  -- cf:  Belief
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/aeolus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/humour - http://icondataset.org/aeolus  -- cf:  Humour
# http://icondataset.org/artists-expression - http://icondataset.org/aeolus  -- cf:  Artist's expression
# http://icondataset.org/belief - http://icondataset.org/aeolus  -- cf:  Belief
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/aeolus  -- cf:  Formal or stylistic evolution
# http://icondataset.org/societal-phenomenon - http://icondataset.org/aeolus  -- cf:  Societal phenomenon
# http://icondataset.org/tendency - http://icondataset.org/aeolus  -- cf:  Tendency
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/aeolus  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/vulcan  -- cf:  Reception of Classical antiquity
# http://icondataset.org/humour - http://icondataset.org/vulcan  -- cf:  Humour
# http://icondataset.org/artists-expression - http://icondataset.org/vulcan  -- cf:  Artist's expression
# http://icondataset.org/belief - http://icondataset.org/vulcan  -- cf:  Belief
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/vulcan  -- cf:  Formal or stylistic evolution
# http://icondataset.org/societal-phenomenon - http://icondataset.org/vulcan  -- cf:  Societal phenomenon
# http://icondataset.org/tendency - http://icondataset.org/vulcan  -- cf:  Tendency
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/vulcan  -- cf:  Iconographical interpretation
# http://icondataset.org/humour - http://icondataset.org/silenus  -- cf:  Humour
# http://icondataset.org/belief - http://icondataset.org/silenus  -- cf:  Belief
# http://icondataset.org/tendency - http://icondataset.org/silenus  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/silenus  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/silenus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/silenus  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/silenus  -- cf:  Iconographical interpretation
# http://icondataset.org/artists-expression - http://icondataset.org/silenus  -- cf:  Artist's expression
# http://icondataset.org/humour - http://icondataset.org/satyr  -- cf:  Humour
# http://icondataset.org/belief - http://icondataset.org/satyr  -- cf:  Belief
# http://icondataset.org/tendency - http://icondataset.org/satyr  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/satyr  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/satyr  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/satyr  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/satyr  -- cf:  Iconographical interpretation
# http://icondataset.org/artists-expression - http://icondataset.org/satyr  -- cf:  Artist's expression
# http://icondataset.org/humour - http://icondataset.org/bacchus  -- cf:  Humour
# http://icondataset.org/belief - http://icondataset.org/bacchus  -- cf:  Belief
# http://icondataset.org/tendency - http://icondataset.org/bacchus  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/bacchus  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bacchus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/bacchus  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/bacchus  -- cf:  Iconographical interpretation
# http://icondataset.org/artists-expression - http://icondataset.org/bacchus  -- cf:  Artist's expression
# http://icondataset.org/humour - http://icondataset.org/ariadne  -- cf:  Humour
# http://icondataset.org/belief - http://icondataset.org/ariadne  -- cf:  Belief
# http://icondataset.org/tendency - http://icondataset.org/ariadne  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/ariadne  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/ariadne  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/ariadne  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/ariadne  -- cf:  Iconographical interpretation
# http://icondataset.org/artists-expression - http://icondataset.org/ariadne  -- cf:  Artist's expression
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/fedro  -- cf:  Iconographical interpretation
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/cupid  -- cf:  Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/minerva  -- cf:  Iconographical interpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/minerva  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/venus  -- cf:  Iconographical interpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/venus  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/hercules  -- cf:  Iconographical interpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/hercules  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/apollo  -- cf:  Iconographical interpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/apollo  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/cupid  -- cf:  Iconographical interpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/cupid  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/vulcan  -- cf:  Iconographical interpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/vulcan  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/jupiter  -- cf:  Iconographical interpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/jupiter  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/diana  -- cf:  Iconographical interpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/diana  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/mercury  -- cf:  Iconographical interpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/mercury  -- cf:  Cultural reinterpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn  -- cf:  Iconographical interpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/saturn  -- cf:  Cultural reinterpretation
# http://icondataset.org/belief - http://icondataset.org/venus-pudica  -- cf:  Belief
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus-pudica  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus-pudica  -- cf:  Reception of Classical antiquity
# http://icondataset.org/belief - http://icondataset.org/venus-coelestis  -- cf:  Belief
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus-coelestis  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus-coelestis  -- cf:  Reception of Classical antiquity
# http://icondataset.org/belief - http://icondataset.org/cupid  -- cf:  Belief
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- cf:  Reception of Classical antiquity
# http://icondataset.org/belief - http://icondataset.org/the-three-graces  -- cf:  Belief
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-three-graces  -- cf:  Reception of Classical antiquity
# http://icondataset.org/belief - http://icondataset.org/mercury  -- cf:  Belief
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- cf:  Reception of Classical antiquity
# http://icondataset.org/belief - http://icondataset.org/natural-venus  -- cf:  Belief
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/natural-venus  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/erato  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/erato  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/apollo  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/muses  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/muses  -- cf:  Reception of Classical antiquity
# http://icondataset.org/taste - http://icondataset.org/saturn  -- cf:  Taste
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- cf:  Reception of Classical antiquity
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/saturn  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- cf:  Iconographical evolution
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/christ-as-a-child  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/christ  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/son-of-the-widow-of-nain  -- cf:  Formal or stylistic phenomenon
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saint-john-the-evangelist  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saint-john-the-evangelist  -- cf:  Reception of Classical antiquity
# http://icondataset.org/tendency - http://icondataset.org/saint-john-the-evangelist  -- cf:  Tendency
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/aeneas  -- cf:  Reception of Classical antiquity
# http://icondataset.org/tendency - http://icondataset.org/aeneas  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/aeneas  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/dido  -- cf:  Reception of Classical antiquity
# http://icondataset.org/tendency - http://icondataset.org/dido  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/dido  -- cf:  Formal or stylistic evolution
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/satyr  -- cf:  Iconographical interpretation
# http://icondataset.org/artists-expression - http://icondataset.org/satyr  -- cf:  Artist's expression
# http://icondataset.org/belief - http://icondataset.org/satyr  -- cf:  Belief
# http://icondataset.org/tendency - http://icondataset.org/satyr  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/satyr  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/satyr  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/centaur  -- cf:  Iconographical interpretation
# http://icondataset.org/artists-expression - http://icondataset.org/centaur  -- cf:  Artist's expression
# http://icondataset.org/belief - http://icondataset.org/centaur  -- cf:  Belief
# http://icondataset.org/tendency - http://icondataset.org/centaur  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/centaur  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/centaur  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/satyr  -- cf:  Iconographical interpretation
# http://icondataset.org/artists-expression - http://icondataset.org/satyr  -- cf:  Artist's expression
# http://icondataset.org/belief - http://icondataset.org/satyr  -- cf:  Belief
# http://icondataset.org/tendency - http://icondataset.org/satyr  -- cf:  Tendency
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/satyr  -- cf:  Formal or stylistic evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/satyr  -- cf:  Reception of Classical antiquity
# ...
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love  -- cf:  Reception of Classical antiquity
# http://icondataset.org/artists-expression - http://icondataset.org/phaeton-the-presumptuous  -- cf:  Artist's expression
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/phaeton-the-presumptuous  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/phaeton-the-presumptuous  -- cf:  Reception of Classical antiquity
# http://icondataset.org/artists-expression - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- cf:  Artist's expression
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- cf:  Reception of Classical antiquity
# http://icondataset.org/artists-expression - http://icondataset.org/phaeton-the-presumptuous  -- cf:  Artist's expression
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/phaeton-the-presumptuous  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/phaeton-the-presumptuous  -- cf:  Reception of Classical antiquity
# http://icondataset.org/artists-expression - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- cf:  Artist's expression
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- cf:  Reception of Classical antiquity
# http://icondataset.org/artists-expression - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- cf:  Artist's expression
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- cf:  Reception of Classical antiquity
# http://icondataset.org/humour - http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life  -- cf:  Humour
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life  -- cf:  Iconographical interpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life  -- cf:  Reception of Classical antiquity
# http://icondataset.org/belief - http://icondataset.org/sleeping-cupid-natural-desire-has-nothing-to-do-with-love  -- cf:  Belief
# http://icondataset.org/belief - http://icondataset.org/archers-without-arrows-tools-of-a-force-beyond-their-will-and-consciousness  -- cf:  Belief
# http://icondataset.org/belief - http://icondataset.org/masks-fallacy-deceit  -- cf:  Belief
# http://icondataset.org/belief - http://icondataset.org/man-reclining-on-terrestrial-world-human-mind-placed-between-the-fallacious-and-unreal-life-on-earth-and-the-celestial-realm  -- cf:  Belief
# http://icondataset.org/iconographical-evolution - http://icondataset.org/face-of-an-old-man-the-past  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/face-of-an-old-man-the-past  -- cf:  Reception of Classical antiquity
# http://icondataset.org/artists-expression - http://icondataset.org/face-of-an-old-man-the-past  -- cf:  Artist's expression
# http://icondataset.org/iconographical-evolution - http://icondataset.org/face-of-an-adult-man-the-present  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/face-of-an-adult-man-the-present  -- cf:  Reception of Classical antiquity
# http://icondataset.org/artists-expression - http://icondataset.org/face-of-an-adult-man-the-present  -- cf:  Artist's expression
# http://icondataset.org/iconographical-evolution - http://icondataset.org/face-of-a-young-man-the-future  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/face-of-a-young-man-the-future  -- cf:  Reception of Classical antiquity
# http://icondataset.org/artists-expression - http://icondataset.org/face-of-a-young-man-the-future  -- cf:  Artist's expression
# http://icondataset.org/iconographical-evolution - http://icondataset.org/three-headed-companion-of-serapis-prudence  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/three-headed-companion-of-serapis-prudence  -- cf:  Reception of Classical antiquity
# http://icondataset.org/artists-expression - http://icondataset.org/three-headed-companion-of-serapis-prudence  -- cf:  Artist's expression
# http://icondataset.org/iconographical-evolution - http://icondataset.org/face-of-an-old-man-the-past  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/face-of-an-old-man-the-past  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/face-of-an-adult-man-the-present  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/face-of-an-adult-man-the-present  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/face-of-a-young-man-the-future  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/face-of-a-young-man-the-future  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/three-books-three-forms-of-time-past-present-future  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/three-books-three-forms-of-time-past-present-future  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/face-of-an-old-woman-the-past  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/face-of-an-old-woman-the-past  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/face-of-an-adult-woman-the-present  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/face-of-an-adult-woman-the-present  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/face-of-a-young-woman-the-future  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/face-of-a-young-woman-the-future  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/serpent-attribute-of-wisdom  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/serpent-attribute-of-wisdom  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/head-of-a-dog-the-future  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/head-of-a-wolf-the-past  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/head-of-a-lion-the-present  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future  -- cf:  Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/book-attribute-of-wisdom  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/book-attribute-of-wisdom  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/owl-attribute-of-wisdom  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/owl-attribute-of-wisdom  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/bear-anger  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bear-anger  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/dolphin-haste  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/dolphin-haste  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/three-headed-companion-of-serapis-prudence  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/three-headed-companion-of-serapis-prudence  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/book-attribute-of-wisdom  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/book-attribute-of-wisdom  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/owl-attribute-of-wisdom  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/owl-attribute-of-wisdom  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/bowl-on-a-book-wisdom  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bowl-on-a-book-wisdom  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/bear-anger  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bear-anger  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/dolphin-haste  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/dolphin-haste  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/three-headed-companion-of-serapis-prudence  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/three-headed-companion-of-serapis-prudence  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-influence - http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone  -- cf:  Iconographical influence
# http://icondataset.org/cultural-influence - http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone  -- cf:  Cultural influence
# http://icondataset.org/iconographical-evolution - http://icondataset.org/fly-decade  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/fly-decade  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mouse-all-devouring-time  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mouse-all-devouring-time  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/skull-death-personified  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/skull-death-personified  -- cf:  Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/shepherdess-amorous-implications-of-the-arcadian-milieu  -- cf:  Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/shepherdess-amorous-implications-of-the-arcadian-milieu  -- cf:  Iconographical evolution
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo-idolatry  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/apollo-idolatry  -- cf:  Cultural reinterpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mars-discord  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/mars-discord  -- cf:  Cultural reinterpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pluto-avarice  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/pluto-avarice  -- cf:  Cultural reinterpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter-pride  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/jupiter-pride  -- cf:  Cultural reinterpretation
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bacchus-folly  -- cf:  Reception of Classical antiquity
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/bacchus-folly  -- cf:  Cultural reinterpretation

# %%
from collections import defaultdict , Counter

meanings_subjects = defaultdict(list)
# ?meaning ?artwork ?subj2
for row in cq2res:
  meanings_subjects[str(row['CFbroader'])].append(str(row['subj2']))


meanings_subjects_with_counts = {}
for k,v in meanings_subjects.items():
#  for m,c in well_represented_phenomena_and_counts:
 #   if k == m:
    meanings_subjects_with_counts[k] = dict(Counter(v).most_common())

# add count

#meanings_subjects_with_counts
# Out:
# {'http://icondataset.org/reception-of-classical-antiquity': {'http://icondataset.org/saturn': 16,
#   'http://icondataset.org/cupid': 14,
#   'http://icondataset.org/mercury': 11,
#   'http://icondataset.org/venus': 8,
#   'http://icondataset.org/jupiter': 8,
#   'http://icondataset.org/apollo': 8,
#   'http://icondataset.org/companion-of-serapis': 7,
#   'http://icondataset.org/the-constellation-hercules': 6,
#   'http://icondataset.org/blindfold-cupid': 5,
#   'http://icondataset.org/saturn-devouring-a-living-child': 5,
#   'http://icondataset.org/caduceus': 5,
#   'http://icondataset.org/pluto': 4,
#   'http://icondataset.org/bacchus': 4,
#   'http://icondataset.org/the-three-graces': 4,
#   'http://icondataset.org/mary': 4,
#   'http://icondataset.org/satyr': 4,
#   'http://icondataset.org/people/virgil': 4,
#   'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/death': 4,
#   'http://icondataset.org/hercules': 3,
#   'http://icondataset.org/christ': 3,
#   'http://icondataset.org/mars': 3,
#   'http://icondataset.org/vulcan': 3,
#   'http://icondataset.org/silenus': 3,
#   'http://icondataset.org/centaur': 3,
#   'http://icondataset.org/phaeton': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/the-constellation-perseus': 3,
#   'http://icondataset.org/truth': 3,
#   'http://icondataset.org/time-the-destroyer': 3,
#   'http://icondataset.org/dragon-biting-its-tail-time': 3,
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': 3,
#   'http://icondataset.org/three-headed-companion-of-serapis-prudence': 3,
#   'http://icondataset.org/cerberus': 2,
#   'http://icondataset.org/proserpina': 2,
#   'http://icondataset.org/argus': 2,
#   'http://icondataset.org/the-children-of-mercury': 2,
#   'http://icondataset.org/polyxena': 2,
#   'http://icondataset.org/europas-companions': 2,
#   'http://icondataset.org/prometheus': 2,
#   'http://icondataset.org/mithras': 2,
#   'http://icondataset.org/saint-john-the-evangelist': 2,
#   'http://icondataset.org/ariadne': 2,
#   'http://icondataset.org/anteros': 2,
#   'http://icondataset.org/rape': 2,
#   'http://icondataset.org/crucifixion': 2,
#   'http://icondataset.org/the-abduction-of-europa': 2,
#   'http://icondataset.org/blood-sacrifice-of-animals': 2,
#   'http://icondataset.org/death-steals-the-weapons-from-cupid-while-he-sleeps': 2,
#   'http://icondataset.org/algol-head-of-demon': 2,
#   'http://icondataset.org/mercurys-winged-sandals': 2,
#   'http://icondataset.org/sun': 2,
#   'http://icondataset.org/moon': 2,
#   'http://icondataset.org/flora': 2,
#   'http://icondataset.org/time-ripa': 2,
#   'http://icondataset.org/time-the-revealer': 2,
#   'http://icondataset.org/time-as-a-cosmic-power': 2,
#   'http://icondataset.org/cupid-amor-carnalis': 2,
#   'http://icondataset.org/phaeton-the-presumptuous': 2,
#   'http://icondataset.org/face-of-an-old-man-the-past': 2,
#   'http://icondataset.org/face-of-an-adult-man-the-present': 2,
#   'http://icondataset.org/face-of-a-young-man-the-future': 2,
#   'http://icondataset.org/book-attribute-of-wisdom': 2,
#   'http://icondataset.org/owl-attribute-of-wisdom': 2,
#   'http://icondataset.org/bear-anger': 2,
#   'http://icondataset.org/dolphin-haste': 2,
#   'http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart': 2,
#   'http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future': 2,
#   'http://icondataset.org/orpheus': 1,
#   'http://icondataset.org/perseus': 1,
#   'http://icondataset.org/laocoon': 1,
#   'http://icondataset.org/thymbraeus-son-of-laoocoon': 1,
#   'http://icondataset.org/antiphas-son-of-laoocoon': 1,
#   'http://icondataset.org/marine-snakes': 1,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/archangel-gabriel': 1,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/eve': 1,
#   'http://icondataset.org/people/saint-luke': 1,
#   'http://icondataset.org/saint-mark': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/the-resurrected': 1,
#   'http://icondataset.org/simeon': 1,
#   'http://icondataset.org/god': 1,
#   'http://icondataset.org/pygmalion': 1,
#   'http://icondataset.org/sisyphus': 1,
#   'http://icondataset.org/tantalus': 1,
#   'http://icondataset.org/ixion': 1,
#   'http://icondataset.org/david': 1,
#   'http://icondataset.org/roman-emperors': 1,
#   'http://icondataset.org/paris': 1,
#   'http://icondataset.org/helen': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/venus-pudica': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/natural-venus': 1,
#   'http://icondataset.org/erato': 1,
#   'http://icondataset.org/muses': 1,
#   'http://icondataset.org/aeneas': 1,
#   'http://icondataset.org/dido': 1,
#   'http://icondataset.org/lapiths': 1,
#   'http://icondataset.org/aion/phanes': 1,
#   'http://icondataset.org/rhea': 1,
#   'http://icondataset.org/the-children-of-saturn': 1,
#   'http://icondataset.org/dieu-amour': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/tityus': 1,
#   'http://icondataset.org/female-pan': 1,
#   'http://icondataset.org/serapis': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/apollo-medicus-or-aesculapius': 1,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/rachel': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/leach': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/sybil': 1,
#   'http://icondataset.org/prophet': 1,
#   'http://icondataset.org/christ-as-a-child': 1,
#   'http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion': 1,
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/simeon-witnesses-the-presentation-of-christ': 1,
#   'http://icondataset.org/god-creating-the-universe': 1,
#   'http://icondataset.org/prometheus-animates-man': 1,
#   'http://icondataset.org/pygmalion-dressing-his-statue': 1,
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill': 1,
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water': 1,
#   'http://icondataset.org/ixion-on-his-wheel': 1,
#   'http://icondataset.org/joseph-cast-into-the-pit': 1,
#   'http://icondataset.org/mithras-twisting-the-horns-of-a-bull': 1,
#   'http://icondataset.org/mithras-killing-the-bull': 1,
#   'http://icondataset.org/sacrifice-of-a-bull': 1,
#   'http://icondataset.org/lamentation-of-christ': 1,
#   'http://icondataset.org/amorini-pointing-out-to-death-her-first-victims': 1,
#   'http://icondataset.org/three-corpses-warn-three-gentlemen-against-their-thoughtless-enjoyment-of-life': 1,
#   'http://icondataset.org/paris-rapes-helen': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/battle-of-lapiths-and-centaurs': 1,
#   'http://icondataset.org/prometheus-is-punished': 1,
#   'http://icondataset.org/era-sub-prometheo': 1,
#   'http://icondataset.org/time-devouring-the-past': 1,
#   'http://icondataset.org/innocence-threatened-by-the-powers-of-evil': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/sun-moves-his-chariot-through-the-zodiac': 1,
#   'http://icondataset.org/love-shooting-the-foolish': 1,
#   'http://icondataset.org/love-shooting-the-wise-man': 1,
#   'http://icondataset.org/triumph-of-love': 1,
#   'http://icondataset.org/resurrection-of-christ': 1,
#   'http://icondataset.org/medusas-head': 1,
#   'http://icondataset.org/the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/apollonian-swan': 1,
#   'http://icondataset.org/torch-of-prometheus': 1,
#   'http://icondataset.org/mercury-planet': 1,
#   'http://icondataset.org/saturn-planet': 1,
#   'http://icondataset.org/jupiter-planet': 1,
#   'http://icondataset.org/mars-planet': 1,
#   'http://icondataset.org/venus-planet': 1,
#   'http://icondataset.org/moon-planet': 1,
#   'http://icondataset.org/torso-del-belvedere': 1,
#   'http://icondataset.org/tower-of-chastity': 1,
#   'http://icondataset.org/hearts-of-cupids-victims': 1,
#   'http://icondataset.org/lion-zodiacal-sign': 1,
#   'http://icondataset.org/planimetrical-scheme-of-the-celestial-spheres': 1,
#   'http://icondataset.org/north-pole-sky': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/the-constellation-eridanus': 1,
#   'http://icondataset.org/the-virgin-constellation': 1,
#   'http://icondataset.org/oceanus': 1,
#   'http://icondataset.org/tellus': 1,
#   'http://icondataset.org/the-twins-constellation': 1,
#   'http://icondataset.org/atlas': 1,
#   'http://icondataset.org/sleep': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/spring': 1,
#   'http://icondataset.org/zephir': 1,
#   'http://icondataset.org/kairos': 1,
#   'http://icondataset.org/aion/phanes-as-personification-of-eternal-time': 1,
#   'http://icondataset.org/time-as-universal-cosmic-principle': 1,
#   'http://icondataset.org/innocence': 1,
#   'http://icondataset.org/justice': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/poverty': 1,
#   'http://icondataset.org/labour': 1,
#   'http://icondataset.org/wealth': 1,
#   'http://icondataset.org/luxury': 1,
#   'http://icondataset.org/sun-on-his-chariot': 1,
#   'http://icondataset.org/amor-carnalis': 1,
#   'http://icondataset.org/amor': 1,
#   'http://icondataset.org/ardor': 1,
#   'http://icondataset.org/penitentia': 1,
#   'http://icondataset.org/amor-divino': 1,
#   'http://icondataset.org/fortune': 1,
#   'http://icondataset.org/faith': 1,
#   'http://icondataset.org/hope': 1,
#   'http://icondataset.org/love': 1,
#   'http://icondataset.org/three-stages-of-human-life': 1,
#   'http://icondataset.org/good-counsel': 1,
#   'http://icondataset.org/river-alpheus': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/deer-souls': 1,
#   'http://icondataset.org/carrying-on-shoulders-saving-souls': 1,
#   'http://icondataset.org/stepping-on-defeating-devil': 1,
#   'http://icondataset.org/dragoon-devil': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/europa-human-soul': 1,
#   'http://icondataset.org/bull-christ': 1,
#   'http://icondataset.org/urns-pagan-custom-of-cremation': 1,
#   'http://icondataset.org/tombs-christian-rite-of-burial': 1,
#   'http://icondataset.org/sisyphus-pride': 1,
#   'http://icondataset.org/tantalus-avarice': 1,
#   'http://icondataset.org/ixion-lewdness': 1,
#   'http://icondataset.org/hercules-egypt': 1,
#   'http://icondataset.org/satyr-egyptian-desert-wilderness': 1,
#   'http://icondataset.org/torch-unholy-ardor': 1,
#   'http://icondataset.org/ibis-homo-carnalis': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/venus-coelestis-amor-divinus': 1,
#   'http://icondataset.org/natural-venus-amor-humanus': 1,
#   'http://icondataset.org/mercury-turning-his-back-to-the-realm-of-the-natural-venus-the-discursive-reason-is-not-involved-in-the-activities-of-the-natural-venus': 1,
#   'http://icondataset.org/mercury-discursive-reason': 1,
#   'http://icondataset.org/mercury-discursive-reason:-limitations-and-possibilities-of-what-human-reason-can-do': 1,
#   'http://icondataset.org/lyre-fashioned-from-a-stags-head-low-class-and-uncouth-music': 1,
#   'http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind': 1,
#   'http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening': 1,
#   'http://icondataset.org/monk-vita-contemplativa': 1,
#   'http://icondataset.org/fire-fire-to-burn-the-time': 1,
#   'http://icondataset.org/four-wings-four-seasons': 1,
#   'http://icondataset.org/desolate-scenery-destructive-power-of-time': 1,
#   'http://icondataset.org/dog-envy': 1,
#   'http://icondataset.org/lion-fury': 1,
#   'http://icondataset.org/wolf-greed': 1,
#   'http://icondataset.org/serpent-perfidy': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/hourglass-transience': 1,
#   'http://icondataset.org/soap-bubbles-futility': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-affection-changes-with-luck': 1,
#   'http://icondataset.org/bundle-of-sticks-unity': 1,
#   'http://icondataset.org/myrtle-everlasting-love': 1,
#   'http://icondataset.org/roses-pleasures-of-permanent-congeniality': 1,
#   'http://icondataset.org/glass-sphere-harmony-that-can-be-easily-broken': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/liver-seat-of-physical-passions': 1,
#   'http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love': 1,
#   'http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life': 1,
#   'http://icondataset.org/three-books-three-forms-of-time-past-present-future': 1,
#   'http://icondataset.org/face-of-an-old-woman-the-past': 1,
#   'http://icondataset.org/face-of-an-adult-woman-the-present': 1,
#   'http://icondataset.org/face-of-a-young-woman-the-future': 1,
#   'http://icondataset.org/serpent-attribute-of-wisdom': 1,
#   'http://icondataset.org/bowl-on-a-book-wisdom': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1,
#   'http://icondataset.org/fly-decade': 1,
#   'http://icondataset.org/mouse-all-devouring-time': 1,
#   'http://icondataset.org/skull-death-personified': 1,
#   'http://icondataset.org/shepherdess-amorous-implications-of-the-arcadian-milieu': 1,
#   'http://icondataset.org/apollo-idolatry': 1,
#   'http://icondataset.org/mars-discord': 1,
#   'http://icondataset.org/pluto-avarice': 1,
#   'http://icondataset.org/jupiter-pride': 1,
#   'http://icondataset.org/bacchus-folly': 1},
#  'http://icondataset.org/iconographical-evolution': {'http://icondataset.org/saturn': 16,
#   'http://icondataset.org/cupid': 14,
#   'http://icondataset.org/companion-of-serapis': 8,
#   'http://icondataset.org/venus': 6,
#   'http://icondataset.org/apollo': 6,
#   'http://icondataset.org/blindfold-cupid': 6,
#   'http://icondataset.org/mercury': 5,
#   'http://icondataset.org/saturn-devouring-a-living-child': 5,
#   'http://icondataset.org/truth': 5,
#   'http://icondataset.org/death': 5,
#   'http://icondataset.org/christ': 4,
#   'http://icondataset.org/people/virgil': 4,
#   'http://icondataset.org/time-the-destroyer': 4,
#   'http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future': 4,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/eros-as-the-great-force-ruling-over-the-instincts-of-gods-man-and-animals': 3,
#   'http://icondataset.org/dragon-biting-its-tail-time': 3,
#   'http://icondataset.org/three-headed-companion-of-serapis-prudence': 3,
#   'http://icondataset.org/argus': 2,
#   'http://icondataset.org/the-children-of-saturn': 2,
#   'http://icondataset.org/bacchus': 2,
#   'http://icondataset.org/the-three-graces': 2,
#   'http://icondataset.org/mithras': 2,
#   'http://icondataset.org/saint-theodora-of-alexandria': 2,
#   'http://icondataset.org/olympian-gods': 2,
#   'http://icondataset.org/zeus': 2,
#   'http://icondataset.org/mercury-hermes': 2,
#   'http://icondataset.org/aglauros': 2,
#   'http://icondataset.org/anteros': 2,
#   'http://icondataset.org/blood-sacrifice-of-animals': 2,
#   'http://icondataset.org/death-steals-the-weapons-from-cupid-while-he-sleeps': 2,
#   'http://icondataset.org/medusas-head': 2,
#   'http://icondataset.org/mercurys-winged-sandals': 2,
#   'http://icondataset.org/caduceus': 2,
#   'http://icondataset.org/the-constellation-perseus': 2,
#   'http://icondataset.org/amor-carnalis': 2,
#   'http://icondataset.org/time-ripa': 2,
#   'http://icondataset.org/time-the-revealer': 2,
#   'http://icondataset.org/time-as-a-cosmic-power': 2,
#   'http://icondataset.org/poverty': 2,
#   'http://icondataset.org/fortune': 2,
#   'http://icondataset.org/face-of-an-old-man-the-past': 2,
#   'http://icondataset.org/face-of-an-adult-man-the-present': 2,
#   'http://icondataset.org/face-of-a-young-man-the-future': 2,
#   'http://icondataset.org/book-attribute-of-wisdom': 2,
#   'http://icondataset.org/owl-attribute-of-wisdom': 2,
#   'http://icondataset.org/bear-anger': 2,
#   'http://icondataset.org/dolphin-haste': 2,
#   'http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart': 2,
#   'http://icondataset.org/orpheus': 1,
#   'http://icondataset.org/perseus': 1,
#   'http://icondataset.org/the-children-of-mercury': 1,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/pluto': 1,
#   'http://icondataset.org/apostles': 1,
#   'http://icondataset.org/silenus': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/venus-pudica': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/saint-john-the-evangelist': 1,
#   'http://icondataset.org/aion/phanes': 1,
#   'http://icondataset.org/rhea': 1,
#   'http://icondataset.org/jest': 1,
#   'http://icondataset.org/dieu-amour': 1,
#   'http://icondataset.org/athene': 1,
#   'http://icondataset.org/herse': 1,
#   'http://icondataset.org/devil': 1,
#   'http://icondataset.org/gods-hand': 1,
#   'http://icondataset.org/serapis': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/europas-companions': 1,
#   'http://icondataset.org/apollo-medicus-or-aesculapius': 1,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/crucifixion': 1,
#   'http://icondataset.org/mithras-twisting-the-horns-of-a-bull': 1,
#   'http://icondataset.org/mithras-killing-the-bull': 1,
#   'http://icondataset.org/sacrifice-of-a-bull': 1,
#   'http://icondataset.org/amorini-pointing-out-to-death-her-first-victims': 1,
#   'http://icondataset.org/three-corpses-warn-three-gentlemen-against-their-thoughtless-enjoyment-of-life': 1,
#   'http://icondataset.org/era-sub-vulcano': 1,
#   'http://icondataset.org/cupid-unblinding-himself': 1,
#   'http://icondataset.org/time-devouring-the-past': 1,
#   'http://icondataset.org/innocence-threatened-by-the-powers-of-evil': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/sun-moves-his-chariot-through-the-zodiac': 1,
#   'http://icondataset.org/death-disembowelling-her-victim': 1,
#   'http://icondataset.org/love-shooting-the-foolish': 1,
#   'http://icondataset.org/love-shooting-the-wise-man': 1,
#   'http://icondataset.org/triumph-of-love': 1,
#   'http://icondataset.org/resurrection-of-christ': 1,
#   'http://icondataset.org/the-abduction-of-europa': 1,
#   'http://icondataset.org/celestial-map': 1,
#   'http://icondataset.org/mercury-planet': 1,
#   'http://icondataset.org/saturn-planet': 1,
#   'http://icondataset.org/jupiter-planet': 1,
#   'http://icondataset.org/mars-planet': 1,
#   'http://icondataset.org/venus-planet': 1,
#   'http://icondataset.org/moon-planet': 1,
#   'http://icondataset.org/torso-del-belvedere': 1,
#   'http://icondataset.org/tower-of-chastity': 1,
#   'http://icondataset.org/hearts-of-cupids-victims': 1,
#   'http://icondataset.org/love-stricken-soul': 1,
#   'http://icondataset.org/lion-zodiacal-sign': 1,
#   'http://icondataset.org/implements-of-the-holy-mass': 1,
#   'http://icondataset.org/planimetrical-scheme-of-the-celestial-spheres': 1,
#   'http://icondataset.org/north-pole-sky': 1,
#   'http://icondataset.org/the-constellation-orion': 1,
#   'http://icondataset.org/the-constellation-hercules-engonasin': 1,
#   'http://icondataset.org/the-constellation-eridanus': 1,
#   'http://icondataset.org/the-constellation-hercules': 1,
#   'http://icondataset.org/the-virgin-constellation': 1,
#   'http://icondataset.org/oceanus': 1,
#   'http://icondataset.org/tellus': 1,
#   'http://icondataset.org/sun': 1,
#   'http://icondataset.org/moon': 1,
#   'http://icondataset.org/nude-prudence': 1,
#   'http://icondataset.org/platonic-love': 1,
#   'http://icondataset.org/flora': 1,
#   'http://icondataset.org/kairos': 1,
#   'http://icondataset.org/aion/phanes-as-personification-of-eternal-time': 1,
#   'http://icondataset.org/synagogue': 1,
#   'http://icondataset.org/life': 1,
#   'http://icondataset.org/church': 1,
#   'http://icondataset.org/time-as-universal-cosmic-principle': 1,
#   'http://icondataset.org/innocence': 1,
#   'http://icondataset.org/justice': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/labour': 1,
#   'http://icondataset.org/wealth': 1,
#   'http://icondataset.org/luxury': 1,
#   'http://icondataset.org/sun-on-his-chariot': 1,
#   'http://icondataset.org/blind-night': 1,
#   'http://icondataset.org/blind-death': 1,
#   'http://icondataset.org/amor': 1,
#   'http://icondataset.org/ardor': 1,
#   'http://icondataset.org/penitentia': 1,
#   'http://icondataset.org/amor-divino': 1,
#   'http://icondataset.org/mockery': 1,
#   'http://icondataset.org/mourning': 1,
#   'http://icondataset.org/evil-effects-of-love': 1,
#   'http://icondataset.org/earth': 1,
#   'http://icondataset.org/chastity': 1,
#   'http://icondataset.org/three-stages-of-human-life': 1,
#   'http://icondataset.org/good-counsel': 1,
#   'http://icondataset.org/river-alpheus': 1,
#   'http://icondataset.org/deer-souls': 1,
#   'http://icondataset.org/carrying-on-shoulders-saving-souls': 1,
#   'http://icondataset.org/stepping-on-defeating-devil': 1,
#   'http://icondataset.org/dragoon-devil': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/cupid-unblindfolding-himself-cupid-transforming-himself-from-a-personification-of-blind-ignoble-love-to-an-exponent-of-seeing-platonic-love': 1,
#   'http://icondataset.org/venus-coelestis-amor-divinus': 1,
#   'http://icondataset.org/monk-vita-contemplativa': 1,
#   'http://icondataset.org/fire-fire-to-burn-the-time': 1,
#   'http://icondataset.org/four-wings-four-seasons': 1,
#   'http://icondataset.org/desolate-scenery-destructive-power-of-time': 1,
#   'http://icondataset.org/dog-envy': 1,
#   'http://icondataset.org/lion-fury': 1,
#   'http://icondataset.org/wolf-greed': 1,
#   'http://icondataset.org/serpent-perfidy': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/hourglass-transience': 1,
#   'http://icondataset.org/soap-bubbles-futility': 1,
#   'http://icondataset.org/branches-of-a-tree-antidotes-against-sexual-passion-marriage-prayer-business-abstinence': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-affection-changes-with-luck': 1,
#   'http://icondataset.org/three-books-three-forms-of-time-past-present-future': 1,
#   'http://icondataset.org/face-of-an-old-woman-the-past': 1,
#   'http://icondataset.org/face-of-an-adult-woman-the-present': 1,
#   'http://icondataset.org/face-of-a-young-woman-the-future': 1,
#   'http://icondataset.org/serpent-attribute-of-wisdom': 1,
#   'http://icondataset.org/head-of-a-dog-the-future': 1,
#   'http://icondataset.org/head-of-a-wolf-the-past': 1,
#   'http://icondataset.org/head-of-a-lion-the-present': 1,
#   'http://icondataset.org/bowl-on-a-book-wisdom': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1,
#   'http://icondataset.org/fly-decade': 1,
#   'http://icondataset.org/mouse-all-devouring-time': 1,
#   'http://icondataset.org/skull-death-personified': 1,
#   'http://icondataset.org/shepherdess-amorous-implications-of-the-arcadian-milieu': 1},
#  'http://icondataset.org/societal-phenomenon': {'http://icondataset.org/companion-of-serapis': 3,
#   'http://icondataset.org/apollo': 3,
#   'http://icondataset.org/the-young-mago-caspar': 1,
#   'http://icondataset.org/member-of-the-procession': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/satan': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/vulcan': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/anteros': 1,
#   'http://icondataset.org/faith-has-the-world-under-her-feet': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/era-sub-vulcano': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/eros-and-anteros-fishing-for-hearts': 1,
#   'http://icondataset.org/missal': 1,
#   'http://icondataset.org/original-sin': 1,
#   'http://icondataset.org/altar': 1,
#   'http://icondataset.org/bible': 1,
#   'http://icondataset.org/glass-sphere-as-a-popular-decorative-curiosity': 1,
#   'http://icondataset.org/private-chapel-installed-within-a-large-house': 1,
#   'http://icondataset.org/divine-justice': 1,
#   'http://icondataset.org/catholic-faith': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/weighing-with-balance-weighing-of-souls': 1,
#   'http://icondataset.org/weighing-with-balance-allusion-to-last-judgement': 1,
#   'http://icondataset.org/jewelry-earthly-goods': 1,
#   'http://icondataset.org/mirror-introspection': 1,
#   'http://icondataset.org/young-mago-future-time': 1,
#   'http://icondataset.org/glass-sphere-heaven': 1,
#   'http://icondataset.org/glass-sphere-god': 1,
#   'http://icondataset.org/white-purity': 1,
#   'http://icondataset.org/blue-hue-of-heaven': 1,
#   'http://icondataset.org/heart-source-of-living-faith': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1},
#  'http://icondataset.org/tendency': {'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/mary': 3,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/centaur': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/christ': 2,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/silenus': 2,
#   'http://icondataset.org/bacchus': 2,
#   'http://icondataset.org/ariadne': 2,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/the-resurrected': 1,
#   'http://icondataset.org/simeon': 1,
#   'http://icondataset.org/sisyphus': 1,
#   'http://icondataset.org/tantalus': 1,
#   'http://icondataset.org/ixion': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/saint-john-the-evangelist': 1,
#   'http://icondataset.org/aeneas': 1,
#   'http://icondataset.org/dido': 1,
#   'http://icondataset.org/lapiths': 1,
#   'http://icondataset.org/prometheus': 1,
#   'http://icondataset.org/people/lorenzo-de-medici': 1,
#   'http://icondataset.org/votary-of-saturn': 1,
#   'http://icondataset.org/giuliano-de-medici': 1,
#   'http://icondataset.org/votary-of-jupiter': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/europas-companions': 1,
#   'http://icondataset.org/apollo': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/rachel': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/leach': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/sybil': 1,
#   'http://icondataset.org/prophet': 1,
#   'http://icondataset.org/christ-as-a-child': 1,
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/simeon-witnesses-the-presentation-of-christ': 1,
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill': 1,
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water': 1,
#   'http://icondataset.org/ixion-on-his-wheel': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/battle-of-lapiths-and-centaurs': 1,
#   'http://icondataset.org/prometheus-is-punished': 1,
#   'http://icondataset.org/era-sub-prometheo': 1,
#   'http://icondataset.org/gesture-of-saturnian-silence': 1,
#   'http://icondataset.org/the-abduction-of-europa': 1,
#   'http://icondataset.org/the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/torch-of-prometheus': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/nude-prudence': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/deer-souls': 1,
#   'http://icondataset.org/carrying-on-shoulders-saving-souls': 1,
#   'http://icondataset.org/stepping-on-defeating-devil': 1,
#   'http://icondataset.org/dragoon-devil': 1,
#   'http://icondataset.org/urns-pagan-custom-of-cremation': 1,
#   'http://icondataset.org/tombs-christian-rite-of-burial': 1,
#   'http://icondataset.org/sisyphus-pride': 1,
#   'http://icondataset.org/tantalus-avarice': 1,
#   'http://icondataset.org/ixion-lewdness': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind': 1,
#   'http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening': 1,
#   'http://icondataset.org/closed-cash-box-saturninian-parsimony': 1,
#   'http://icondataset.org/bat-melancholy': 1,
#   'http://icondataset.org/princely-sceptre-jovial-magnanimity': 1},
#  'http://icondataset.org/formal-or-stylistic-evolution': {'http://icondataset.org/mercury': 8,
#   'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/saturn': 3,
#   'http://icondataset.org/apollo': 3,
#   'http://icondataset.org/the-three-graces': 3,
#   'http://icondataset.org/cupid': 3,
#   'http://icondataset.org/people/virgil': 3,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/centaur': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/caduceus': 3,
#   'http://icondataset.org/cerberus': 2,
#   'http://icondataset.org/pluto': 2,
#   'http://icondataset.org/proserpina': 2,
#   'http://icondataset.org/argus': 2,
#   'http://icondataset.org/the-children-of-mercury': 2,
#   'http://icondataset.org/polyxena': 2,
#   'http://icondataset.org/europas-companions': 2,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/silenus': 2,
#   'http://icondataset.org/bacchus': 2,
#   'http://icondataset.org/ariadne': 2,
#   'http://icondataset.org/rape': 2,
#   'http://icondataset.org/the-abduction-of-europa': 2,
#   'http://icondataset.org/cupid-amor-carnalis': 2,
#   'http://icondataset.org/laocoon': 1,
#   'http://icondataset.org/thymbraeus-son-of-laoocoon': 1,
#   'http://icondataset.org/antiphas-son-of-laoocoon': 1,
#   'http://icondataset.org/marine-snakes': 1,
#   'http://icondataset.org/jupiter': 1,
#   'http://icondataset.org/venus': 1,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/the-resurrected': 1,
#   'http://icondataset.org/mary': 1,
#   'http://icondataset.org/pygmalion': 1,
#   'http://icondataset.org/saint-john-the-evangelist': 1,
#   'http://icondataset.org/david': 1,
#   'http://icondataset.org/paris': 1,
#   'http://icondataset.org/helen': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/aeneas': 1,
#   'http://icondataset.org/dido': 1,
#   'http://icondataset.org/lapiths': 1,
#   'http://icondataset.org/prometheus': 1,
#   'http://icondataset.org/bishop-simone-saltarelli': 1,
#   'http://icondataset.org/presbyter-bruno': 1,
#   'http://icondataset.org/companion-of-serapis': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/crucifixion': 1,
#   'http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion': 1,
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/pygmalion-dressing-his-statue': 1,
#   'http://icondataset.org/lamentation-of-christ': 1,
#   'http://icondataset.org/paris-rapes-helen': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/battle-of-lapiths-and-centaurs': 1,
#   'http://icondataset.org/prometheus-is-punished': 1,
#   'http://icondataset.org/era-sub-prometheo': 1,
#   'http://icondataset.org/presbyter-bruno-mourned-by-beggars-whom-he-had-supported-during-his-life': 1,
#   'http://icondataset.org/the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/torch-of-prometheus': 1,
#   'http://icondataset.org/implements-of-the-holy-mass': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/temple-of-solomon': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/the-constellation-hercules': 1,
#   'http://icondataset.org/the-virgin-constellation': 1,
#   'http://icondataset.org/sun': 1,
#   'http://icondataset.org/moon': 1,
#   'http://icondataset.org/death': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/truth': 1,
#   'http://icondataset.org/dragon-biting-its-tail-time': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/europa-human-soul': 1,
#   'http://icondataset.org/bull-christ': 1,
#   'http://icondataset.org/urns-pagan-custom-of-cremation': 1,
#   'http://icondataset.org/tombs-christian-rite-of-burial': 1,
#   'http://icondataset.org/torch-unholy-ardor': 1,
#   'http://icondataset.org/ibis-homo-carnalis': 1,
#   'http://icondataset.org/temple-of-solomon-ornate-as-a-church-correlation-between-the-old-testament-and-the-new': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind': 1,
#   'http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening': 1},
#  'http://icondataset.org/belief': {'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/era-sub-vulcano': 3,
#   'http://icondataset.org/erection-of-primitive-buildings': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/archangel-gabriel': 2,
#   'http://icondataset.org/mary': 2,
#   'http://icondataset.org/the-children-of-saturn': 2,
#   'http://icondataset.org/mercury': 2,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/cupid': 2,
#   'http://icondataset.org/centaur': 2,
#   'http://icondataset.org/archangel-gabriel-pronounces-the-ave-maria': 2,
#   'http://icondataset.org/mary-welcomes-the-holy-spirit': 2,
#   'http://icondataset.org/flora': 2,
#   'http://icondataset.org/two-out-of-the-four-times-of-day': 2,
#   'http://icondataset.org/two-out-of-the-four-rivers-of-hades': 2,
#   'http://icondataset.org/empty-throne-invisible-presence-of-an-immortal': 2,
#   'http://icondataset.org/highest-zone-of-the-tomb-supercelestial-sphere': 2,
#   'http://icondataset.org/lowest-zone-of-the-tomb-realm-of-sheer-matter': 2,
#   'http://icondataset.org/central-zone-of-the-tomb-realm-of-nature-the-only-sphere-subject-to-time': 2,
#   'http://icondataset.org/four-times-of-day-four-humours': 2,
#   'http://icondataset.org/four-times-of-day-fourfold-aspect-of-life-on-earth-as-a-state-of-actual-suffering': 2,
#   'http://icondataset.org/four-times-of-day-realm-of-nature': 2,
#   'http://icondataset.org/four-rivers-of-hades-four-elements-air-fire-earth-water': 2,
#   'http://icondataset.org/four-rivers-of-hades-fourfold-aspect-of-matter-as-a-source-of-potential-evil': 2,
#   'http://icondataset.org/god': 1,
#   'http://icondataset.org/salamander': 1,
#   'http://icondataset.org/crocodile': 1,
#   'http://icondataset.org/planetary-deities': 1,
#   'http://icondataset.org/the-children-of-each-planet': 1,
#   'http://icondataset.org/the-children-of-mercury': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/silenus': 1,
#   'http://icondataset.org/bacchus': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/venus-pudica': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/the-three-graces': 1,
#   'http://icondataset.org/natural-venus': 1,
#   'http://icondataset.org/saturn': 1,
#   'http://icondataset.org/angels': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/saint-paul': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/people/lorenzo-de-medici': 1,
#   'http://icondataset.org/giuliano-de-medici': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/unconsciuous-creatures': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/caduceus': 1,
#   'http://icondataset.org/sella-gestatoria': 1,
#   'http://icondataset.org/dream-vision': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/the-right': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/spring': 1,
#   'http://icondataset.org/zephir': 1,
#   'http://icondataset.org/victories': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/crepuscolo': 1,
#   'http://icondataset.org/aurora': 1,
#   'http://icondataset.org/day': 1,
#   'http://icondataset.org/night': 1,
#   'http://icondataset.org/personification-of-the-natural-forces-stimulating-the-action-of-the-unconscious-creatures': 1,
#   'http://icondataset.org/seven-capital-sins': 1,
#   'http://icondataset.org/human-mind': 1,
#   'http://icondataset.org/virtue': 1,
#   'http://icondataset.org/blowing-in-a-tube-fertilising': 1,
#   'http://icondataset.org/beams-of-light---gods-word': 1,
#   'http://icondataset.org/white-lilium-virginity': 1,
#   'http://icondataset.org/flying-towards-marys-head-to-fertilise': 1,
#   'http://icondataset.org/dove-holy-spirit': 1,
#   'http://icondataset.org/right-man-salamander': 1,
#   'http://icondataset.org/fire-luxury': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/venus-coelestis-amor-divinus': 1,
#   'http://icondataset.org/natural-venus-amor-humanus': 1,
#   'http://icondataset.org/mercury-turning-his-back-to-the-realm-of-the-natural-venus-the-discursive-reason-is-not-involved-in-the-activities-of-the-natural-venus': 1,
#   'http://icondataset.org/mercury-discursive-reason': 1,
#   'http://icondataset.org/mercury-discursive-reason:-limitations-and-possibilities-of-what-human-reason-can-do': 1,
#   'http://icondataset.org/monk-vita-contemplativa': 1,
#   'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom': 1,
#   'http://icondataset.org/moses-mens': 1,
#   'http://icondataset.org/saint-paul-mens': 1,
#   'http://icondataset.org/angel-smiling-while-carrying-the-coffin-of-the-pope-angel-glad-that-the-soul-of-the-pope-had-been-received-among-the-blessed-spirits': 1,
#   'http://icondataset.org/angel-wepting-while-carrying-the-coffin-of-the-pope-angel-grieved-that-the-world-had-been-deprived-of-such-a-man': 1,
#   'http://icondataset.org/victory-human-soul-in-state-of-freedom': 1,
#   'http://icondataset.org/children-crouching-down-unborn-souls-doomed-to-descend-to-the-lower-spheres': 1,
#   'http://icondataset.org/trophies-ultimate-triumph-over-the-lower-forms-of-existence': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/sleeping-cupid-natural-desire-has-nothing-to-do-with-love': 1,
#   'http://icondataset.org/archers-without-arrows-tools-of-a-force-beyond-their-will-and-consciousness': 1,
#   'http://icondataset.org/masks-fallacy-deceit': 1,
#   'http://icondataset.org/man-reclining-on-terrestrial-world-human-mind-placed-between-the-fallacious-and-unreal-life-on-earth-and-the-celestial-realm': 1},
#  'http://icondataset.org/iconographical-influence': {'http://icondataset.org/planetary-deities': 2,
#   'http://icondataset.org/lion-zodiacal-sign': 2,
#   'http://icondataset.org/the-constellation-hercules': 2,
#   'http://icondataset.org/mercury': 1,
#   'http://icondataset.org/the-children-of-mercury': 1,
#   'http://icondataset.org/venus': 1,
#   'http://icondataset.org/the-three-graces': 1,
#   'http://icondataset.org/serapis': 1,
#   'http://icondataset.org/companion-of-serapis': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/apollo-medicus-or-aesculapius': 1,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/death-disembowelling-her-victim': 1,
#   'http://icondataset.org/algol-head-of-demon': 1,
#   'http://icondataset.org/imperial-orb': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/the-constellation-perseus': 1,
#   'http://icondataset.org/the-twins-constellation': 1,
#   'http://icondataset.org/blind-synagogue': 1,
#   'http://icondataset.org/blind-death': 1,
#   'http://icondataset.org/sun': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1},
#  'http://icondataset.org/cultural-reinterpretation': {'http://icondataset.org/cupid': 4,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/the-constellation-hercules': 3,
#   'http://icondataset.org/venus': 2,
#   'http://icondataset.org/mercury': 2,
#   'http://icondataset.org/saturn': 2,
#   'http://icondataset.org/apollo': 2,
#   'http://icondataset.org/algol-head-of-demon': 2,
#   'http://icondataset.org/the-constellation-perseus': 2,
#   'http://icondataset.org/cupid-amor-carnalis': 2,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/mary': 1,
#   'http://icondataset.org/minerva': 1,
#   'http://icondataset.org/hercules': 1,
#   'http://icondataset.org/vulcan': 1,
#   'http://icondataset.org/diana': 1,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/pluto': 1,
#   'http://icondataset.org/bacchus': 1,
#   'http://icondataset.org/flame-of-divine-wisdom': 1,
#   'http://icondataset.org/sleep': 1,
#   'http://icondataset.org/death': 1,
#   'http://icondataset.org/contemplative-mind': 1,
#   'http://icondataset.org/torch-unholy-ardor': 1,
#   'http://icondataset.org/ibis-homo-carnalis': 1,
#   'http://icondataset.org/jupiter-minerva-mercury-saturn-as-superior-divinities-reason': 1,
#   'http://icondataset.org/jupiter-diana-mercury-saturn-as-superior-divinities-reason': 1,
#   'http://icondataset.org/venus-cupid-vulcan-lower-soul': 1,
#   'http://icondataset.org/apollo-idolatry': 1,
#   'http://icondataset.org/mars-discord': 1,
#   'http://icondataset.org/pluto-avarice': 1,
#   'http://icondataset.org/jupiter-pride': 1,
#   'http://icondataset.org/bacchus-folly': 1},
#  'http://icondataset.org/attitude': {'http://icondataset.org/europas-companions': 2,
#   'http://icondataset.org/the-abduction-of-europa': 2,
#   'http://icondataset.org/planetary-deities': 1,
#   'http://icondataset.org/the-children-of-each-planet': 1,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/roman-emperors': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/apollo': 1,
#   'http://icondataset.org/cupid': 1,
# ...
#   'http://icondataset.org/sisyphus': 1,
#   'http://icondataset.org/tantalus': 1,
#   'http://icondataset.org/ixion': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/fedro': 1,
#   'http://icondataset.org/minerva': 1,
#   'http://icondataset.org/diana': 1,
#   'http://icondataset.org/erato': 1,
#   'http://icondataset.org/muses': 1,
#   'http://icondataset.org/devil': 1,
#   'http://icondataset.org/anteros': 1,
#   'http://icondataset.org/geminae-veneres': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/venus-vulgaris': 1,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/venus-verticordia': 1,
#   'http://icondataset.org/angels': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/saint-paul': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/tityus': 1,
#   'http://icondataset.org/female-pan': 1,
#   'http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion': 1,
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill': 1,
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water': 1,
#   'http://icondataset.org/ixion-on-his-wheel': 1,
#   'http://icondataset.org/joseph-cast-into-the-pit': 1,
#   'http://icondataset.org/mithras-twisting-the-horns-of-a-bull': 1,
#   'http://icondataset.org/mithras-killing-the-bull': 1,
#   'http://icondataset.org/sacrifice-of-a-bull': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/cupid-unblinding-himself': 1,
#   'http://icondataset.org/time-devouring-the-past': 1,
#   'http://icondataset.org/innocence-threatened-by-the-powers-of-evil': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/caduceus': 1,
#   'http://icondataset.org/mercurys-winged-sandals': 1,
#   'http://icondataset.org/flame-of-divine-wisdom': 1,
#   'http://icondataset.org/apollonian-swan': 1,
#   'http://icondataset.org/torso-del-belvedere': 1,
#   'http://icondataset.org/love-stricken-soul': 1,
#   'http://icondataset.org/sella-gestatoria': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/paysage-moralise': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/platonic-love': 1,
#   'http://icondataset.org/amor-carnalis': 1,
#   'http://icondataset.org/contemplative-mind': 1,
#   'http://icondataset.org/innocence': 1,
#   'http://icondataset.org/justice': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/amor-divino': 1,
#   'http://icondataset.org/mockery': 1,
#   'http://icondataset.org/poverty': 1,
#   'http://icondataset.org/mourning': 1,
#   'http://icondataset.org/evil-effects-of-love': 1,
#   'http://icondataset.org/fortune': 1,
#   'http://icondataset.org/faith': 1,
#   'http://icondataset.org/hope': 1,
#   'http://icondataset.org/love': 1,
#   'http://icondataset.org/marital-affection': 1,
#   'http://icondataset.org/chastity': 1,
#   'http://icondataset.org/voluptas': 1,
#   'http://icondataset.org/beauty': 1,
#   'http://icondataset.org/three-graces-three-aspects-of-venus': 1,
#   'http://icondataset.org/grace-pulchritudo': 1,
#   'http://icondataset.org/victories': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/sisyphus-pride': 1,
#   'http://icondataset.org/tantalus-avarice': 1,
#   'http://icondataset.org/ixion-lewdness': 1,
#   'http://icondataset.org/hercules-egypt': 1,
#   'http://icondataset.org/satyr-egyptian-desert-wilderness': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/cameo-with-a-pair-of-winged-horses-and-a-charioteer-platos-immortal-comparison-of-the-human-soul': 1,
#   'http://icondataset.org/cupid-unblindfolding-himself-cupid-transforming-himself-from-a-personification-of-blind-ignoble-love-to-an-exponent-of-seeing-platonic-love': 1,
#   'http://icondataset.org/jupiter-minerva-mercury-saturn-as-superior-divinities-reason': 1,
#   'http://icondataset.org/jupiter-diana-mercury-saturn-as-superior-divinities-reason': 1,
#   'http://icondataset.org/venus-cupid-vulcan-lower-soul': 1,
#   'http://icondataset.org/lyre-fashioned-from-a-stags-head-low-class-and-uncouth-music': 1,
#   'http://icondataset.org/four-wings-four-seasons': 1,
#   'http://icondataset.org/desolate-scenery-destructive-power-of-time': 1,
#   'http://icondataset.org/dog-envy': 1,
#   'http://icondataset.org/lion-fury': 1,
#   'http://icondataset.org/wolf-greed': 1,
#   'http://icondataset.org/serpent-perfidy': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/branches-of-a-tree-antidotes-against-sexual-passion-marriage-prayer-business-abstinence': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-affection-changes-with-luck': 1,
#   'http://icondataset.org/hares-animal-love-fertility': 1,
#   'http://icondataset.org/venus-coelestis-principle-of-universal-and-eternal-but-purely-intelligible-beauty': 1,
#   'http://icondataset.org/venus-vulgaris-generative-force-that-creates-the-perishable-but-visible-and-tangible-images-of-beauty-of-earth': 1,
#   'http://icondataset.org/cupid-between-venus-coelestis-and-venus-vulgaris-love-acts-as-an-intermediary-between-heaven-and-earth': 1,
#   'http://icondataset.org/sarcophagus-converted-in-a-spring-of-life-vis-generandi': 1,
#   'http://icondataset.org/bundle-of-sticks-unity': 1,
#   'http://icondataset.org/myrtle-everlasting-love': 1,
#   'http://icondataset.org/roses-pleasures-of-permanent-congeniality': 1,
#   'http://icondataset.org/glass-sphere-harmony-that-can-be-easily-broken': 1,
#   'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom': 1,
#   'http://icondataset.org/moses-mens': 1,
#   'http://icondataset.org/saint-paul-mens': 1,
#   'http://icondataset.org/angel-smiling-while-carrying-the-coffin-of-the-pope-angel-glad-that-the-soul-of-the-pope-had-been-received-among-the-blessed-spirits': 1,
#   'http://icondataset.org/angel-wepting-while-carrying-the-coffin-of-the-pope-angel-grieved-that-the-world-had-been-deprived-of-such-a-man': 1,
#   'http://icondataset.org/victory-human-soul-in-state-of-freedom': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/liver-seat-of-physical-passions': 1,
#   'http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love': 1,
#   'http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life': 1},
#  'http://icondataset.org/cultural-movement': {'http://icondataset.org/apollo': 2,
#   'http://icondataset.org/saturn': 1,
#   'http://icondataset.org/jupiter': 1,
#   'http://icondataset.org/the-three-graces': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/europas-companions': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/the-abduction-of-europa': 1,
#   'http://icondataset.org/dragon-biting-its-tail-time': 1},
#  'http://icondataset.org/cultural-influence': {'http://icondataset.org/the-constellation-hercules': 2,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/venus': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/mary': 1,
#   'http://icondataset.org/saints': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/angels': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/resurrection-of-christ': 1,
#   'http://icondataset.org/algol-head-of-demon': 1,
#   'http://icondataset.org/lion-zodiacal-sign': 1,
#   'http://icondataset.org/planimetrical-scheme-of-the-celestial-spheres': 1,
#   'http://icondataset.org/north-pole-sky': 1,
#   'http://icondataset.org/the-constellation-perseus': 1,
#   'http://icondataset.org/the-twins-constellation': 1,
#   'http://icondataset.org/time-the-revealer': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/truth': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/victories': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1},
#  'http://icondataset.org/cultural-interpretation': {'http://icondataset.org/venus': 2,
#   'http://icondataset.org/cupid': 2},
#  'http://icondataset.org/moral-meaning': {'http://icondataset.org/sisyphus': 1,
#   'http://icondataset.org/tantalus': 1,
#   'http://icondataset.org/ixion': 1,
#   'http://icondataset.org/tityus': 1,
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill': 1,
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water': 1,
#   'http://icondataset.org/ixion-on-his-wheel': 1,
#   'http://icondataset.org/sisyphus-pride': 1,
#   'http://icondataset.org/tantalus-avarice': 1,
#   'http://icondataset.org/ixion-lewdness': 1,
#   'http://icondataset.org/liver-seat-of-physical-passions': 1,
#   'http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love': 1},
#  'http://icondataset.org/formal-or-stylistic-influence': {'http://icondataset.org/mary': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/archangel-gabriel': 1,
#   'http://icondataset.org/atlas': 1},
#  'http://icondataset.org/artists-expression': {'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/phaeton': 3,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/era-sub-vulcano': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': 3,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/centaur': 2,
#   'http://icondataset.org/phaeton-the-presumptuous': 2,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/silenus': 1,
#   'http://icondataset.org/bacchus': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/tityus': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/victory': 1,
#   'http://icondataset.org/three-stages-of-human-life': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/liver-seat-of-physical-passions': 1,
#   'http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love': 1,
#   'http://icondataset.org/face-of-an-old-man-the-past': 1,
#   'http://icondataset.org/face-of-an-adult-man-the-present': 1,
#   'http://icondataset.org/face-of-a-young-man-the-future': 1,
#   'http://icondataset.org/three-headed-companion-of-serapis-prudence': 1},
#  'http://icondataset.org/humour': {'http://icondataset.org/silenus': 2,
#   'http://icondataset.org/era-sub-vulcano': 2,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/vulcan': 1,
#   'http://icondataset.org/satyr': 1,
#   'http://icondataset.org/bacchus': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/female-pan': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life': 1},
#  'http://icondataset.org/taste': {'http://icondataset.org/saturn': 1},
#  'http://icondataset.org/cultural-value': {'http://icondataset.org/centaur': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/olympian-gods': 1,
#   'http://icondataset.org/zeus': 1,
#   'http://icondataset.org/mercury-hermes': 1,
#   'http://icondataset.org/aglauros': 1,
#   'http://icondataset.org/saint-theodora-of-alexandria': 1,
#   'http://icondataset.org/satyr': 1,
#   'http://icondataset.org/the-age-of-stone': 1,
#   'http://icondataset.org/era-ante-vulcanum': 1,
#   'http://icondataset.org/blind-night': 1,
#   'http://icondataset.org/eros-as-the-great-force-ruling-over-the-instincts-of-gods-man-and-animals': 1},
#  'http://icondataset.org/iconographic-interpretation': {'http://icondataset.org/companion-of-serapis': 3,
#   'http://icondataset.org/apollo': 3}}

# %%
# tpo 5 most frequent subjects per cf
# maybe repeat the analysis with subject 2 broader categories? 
top_5_subj_per_cf = {}
for item in meanings_subjects_with_counts.items():
    if item[0] not in top_5_subj_per_cf:
        top_5_subj_per_cf[item[0]] = {}
        for pair in item[1].items(): 
            if len(top_5_subj_per_cf[item[0]]) < 5:
                top_5_subj_per_cf[item[0]][pair[0]] = pair[1]
               
#top_5_subj_per_cf
# Out:
# {'http://icondataset.org/reception-of-classical-antiquity': {'http://icondataset.org/saturn': 16,
#   'http://icondataset.org/cupid': 14,
#   'http://icondataset.org/mercury': 11,
#   'http://icondataset.org/venus': 8,
#   'http://icondataset.org/jupiter': 8},
#  'http://icondataset.org/iconographical-evolution': {'http://icondataset.org/saturn': 16,
#   'http://icondataset.org/cupid': 14,
#   'http://icondataset.org/companion-of-serapis': 8,
#   'http://icondataset.org/venus': 6,
#   'http://icondataset.org/apollo': 6},
#  'http://icondataset.org/societal-phenomenon': {'http://icondataset.org/companion-of-serapis': 3,
#   'http://icondataset.org/apollo': 3,
#   'http://icondataset.org/the-young-mago-caspar': 1,
#   'http://icondataset.org/member-of-the-procession': 1,
#   'http://icondataset.org/christ': 1},
#  'http://icondataset.org/tendency': {'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/mary': 3,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/centaur': 3,
#   'http://icondataset.org/the-age-of-stone': 3},
#  'http://icondataset.org/formal-or-stylistic-evolution': {'http://icondataset.org/mercury': 8,
#   'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/saturn': 3,
#   'http://icondataset.org/apollo': 3,
#   'http://icondataset.org/the-three-graces': 3},
#  'http://icondataset.org/belief': {'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/era-sub-vulcano': 3,
#   'http://icondataset.org/erection-of-primitive-buildings': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3},
#  'http://icondataset.org/iconographical-influence': {'http://icondataset.org/planetary-deities': 2,
#   'http://icondataset.org/lion-zodiacal-sign': 2,
#   'http://icondataset.org/the-constellation-hercules': 2,
#   'http://icondataset.org/mercury': 1,
#   'http://icondataset.org/the-children-of-mercury': 1},
#  'http://icondataset.org/cultural-reinterpretation': {'http://icondataset.org/cupid': 4,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/the-constellation-hercules': 3,
#   'http://icondataset.org/venus': 2,
#   'http://icondataset.org/mercury': 2},
#  'http://icondataset.org/attitude': {'http://icondataset.org/europas-companions': 2,
#   'http://icondataset.org/the-abduction-of-europa': 2,
#   'http://icondataset.org/planetary-deities': 1,
#   'http://icondataset.org/the-children-of-each-planet': 1,
#   'http://icondataset.org/thisbe': 1},
#  'http://icondataset.org/formal-or-stylistic-phenomenon': {'http://icondataset.org/mary': 2,
#   'http://icondataset.org/christ': 2,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/saint-mark': 1,
#   'http://icondataset.org/saint-peter': 1},
#  'http://icondataset.org/iconographical-interpretation': {'http://icondataset.org/cupid': 10,
#   'http://icondataset.org/saturn': 7,
#   'http://icondataset.org/jupiter': 6,
#   'http://icondataset.org/saturn-devouring-a-living-child': 5,
#   'http://icondataset.org/satyr': 4},
#  'http://icondataset.org/cultural-movement': {'http://icondataset.org/apollo': 2,
#   'http://icondataset.org/saturn': 1,
#   'http://icondataset.org/jupiter': 1,
#   'http://icondataset.org/the-three-graces': 1,
#   'http://icondataset.org/europa': 1},
#  'http://icondataset.org/cultural-influence': {'http://icondataset.org/the-constellation-hercules': 2,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/venus': 1,
#   'http://icondataset.org/cupid': 1},
#  'http://icondataset.org/cultural-interpretation': {'http://icondataset.org/venus': 2,
#   'http://icondataset.org/cupid': 2},
#  'http://icondataset.org/moral-meaning': {'http://icondataset.org/sisyphus': 1,
#   'http://icondataset.org/tantalus': 1,
#   'http://icondataset.org/ixion': 1,
#   'http://icondataset.org/tityus': 1,
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill': 1},
#  'http://icondataset.org/formal-or-stylistic-influence': {'http://icondataset.org/mary': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/archangel-gabriel': 1,
#   'http://icondataset.org/atlas': 1},
#  'http://icondataset.org/artists-expression': {'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/phaeton': 3,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/era-sub-vulcano': 3,
#   'http://icondataset.org/the-age-of-stone': 3},
#  'http://icondataset.org/humour': {'http://icondataset.org/silenus': 2,
#   'http://icondataset.org/era-sub-vulcano': 2,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/vulcan': 1,
#   'http://icondataset.org/satyr': 1},
#  'http://icondataset.org/taste': {'http://icondataset.org/saturn': 1},
#  'http://icondataset.org/cultural-value': {'http://icondataset.org/centaur': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/olympian-gods': 1,
#   'http://icondataset.org/zeus': 1,
#   'http://icondataset.org/mercury-hermes': 1},
#  'http://icondataset.org/iconographic-interpretation': {'http://icondataset.org/companion-of-serapis': 3,
#   'http://icondataset.org/apollo': 3}}

# %%
# labels 
labels = {}

candidate = []
for key, value in top_5_subj_per_cf.items(): 
    candidate.append("<"+key+">")
    for subj in value: 
        if subj not in candidate: 
            candidate.append("<"+subj+">") 
            
labels = {}
# no modify
cqLabel = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?item ?label  WHERE {
    VALUES ?item { """+ ' '.join(candidate) +"""}
    # ?item rdfs:label ?label. 

} 
""" 

cqLabelres = newg.query(cqLabel)

for row in cqLabelres:
 # print(row[0], row[1])
  if str(row[0]) not in labels: 
    labels[str(row[0])] = str(row[1])
print(labels)
# Out:
# ['<http://icondataset.org/reception-of-classical-antiquity>',
#  '<http://icondataset.org/saturn>',
#  '<http://icondataset.org/cupid>',
#  '<http://icondataset.org/mercury>',
#  '<http://icondataset.org/venus>',
#  '<http://icondataset.org/jupiter>',
#  '<http://icondataset.org/iconographical-evolution>',
#  '<http://icondataset.org/saturn>',
#  '<http://icondataset.org/cupid>',
#  '<http://icondataset.org/companion-of-serapis>',
#  '<http://icondataset.org/venus>',
#  '<http://icondataset.org/apollo>',
#  '<http://icondataset.org/societal-phenomenon>',
#  '<http://icondataset.org/companion-of-serapis>',
#  '<http://icondataset.org/apollo>',
#  '<http://icondataset.org/the-young-mago-caspar>',
#  '<http://icondataset.org/member-of-the-procession>',
#  '<http://icondataset.org/christ>',
#  '<http://icondataset.org/tendency>',
#  '<http://icondataset.org/era-sub-vulcano>',
#  '<http://icondataset.org/mary>',
#  '<http://icondataset.org/satyr>',
#  '<http://icondataset.org/centaur>',
#  '<http://icondataset.org/the-age-of-stone>',
#  '<http://icondataset.org/formal-or-stylistic-evolution>',
#  '<http://icondataset.org/mercury>',
#  '<http://icondataset.org/era-sub-vulcano>',
#  '<http://icondataset.org/saturn>',
#  '<http://icondataset.org/apollo>',
#  '<http://icondataset.org/the-three-graces>',
#  '<http://icondataset.org/belief>',
#  '<http://icondataset.org/satyr>',
#  '<http://icondataset.org/era-sub-vulcano>',
#  '<http://icondataset.org/erection-of-primitive-buildings>',
#  '<http://icondataset.org/the-age-of-stone>',
#  '<http://icondataset.org/era-ante-vulcanum>',
#  '<http://icondataset.org/iconographical-influence>',
#  '<http://icondataset.org/planetary-deities>',
#  '<http://icondataset.org/lion-zodiacal-sign>',
#  '<http://icondataset.org/the-constellation-hercules>',
#  '<http://icondataset.org/mercury>',
#  '<http://icondataset.org/the-children-of-mercury>',
#  '<http://icondataset.org/cultural-reinterpretation>',
#  '<http://icondataset.org/cupid>',
#  '<http://icondataset.org/jupiter>',
#  '<http://icondataset.org/the-constellation-hercules>',
#  '<http://icondataset.org/venus>',
#  '<http://icondataset.org/mercury>',
#  '<http://icondataset.org/attitude>',
#  '<http://icondataset.org/europas-companions>',
#  '<http://icondataset.org/the-abduction-of-europa>',
#  '<http://icondataset.org/planetary-deities>',
#  '<http://icondataset.org/the-children-of-each-planet>',
#  '<http://icondataset.org/thisbe>',
#  '<http://icondataset.org/formal-or-stylistic-phenomenon>',
#  '<http://icondataset.org/mary>',
#  '<http://icondataset.org/christ>',
#  '<http://icondataset.org/mars>',
#  '<http://icondataset.org/saint-mark>',
#  '<http://icondataset.org/saint-peter>',
#  '<http://icondataset.org/iconographical-interpretation>',
#  '<http://icondataset.org/cupid>',
#  '<http://icondataset.org/saturn>',
#  '<http://icondataset.org/jupiter>',
#  '<http://icondataset.org/saturn-devouring-a-living-child>',
#  '<http://icondataset.org/satyr>',
#  '<http://icondataset.org/cultural-movement>',
#  '<http://icondataset.org/apollo>',
#  '<http://icondataset.org/saturn>',
#  '<http://icondataset.org/jupiter>',
#  '<http://icondataset.org/the-three-graces>',
#  '<http://icondataset.org/europa>',
#  '<http://icondataset.org/cultural-influence>',
#  '<http://icondataset.org/the-constellation-hercules>',
#  '<http://icondataset.org/hecuba>',
#  '<http://icondataset.org/troilus>',
#  '<http://icondataset.org/venus>',
#  '<http://icondataset.org/cupid>',
#  '<http://icondataset.org/cultural-interpretation>',
#  '<http://icondataset.org/venus>',
#  '<http://icondataset.org/cupid>',
#  '<http://icondataset.org/moral-meaning>',
#  '<http://icondataset.org/sisyphus>',
#  '<http://icondataset.org/tantalus>',
#  '<http://icondataset.org/ixion>',
#  '<http://icondataset.org/tityus>',
#  '<http://icondataset.org/sisyphus-carrying-the-stone-uphill>',
#  '<http://icondataset.org/formal-or-stylistic-influence>',
#  '<http://icondataset.org/mary>',
#  '<http://icondataset.org/christ>',
#  '<http://icondataset.org/archangel-gabriel>',
#  '<http://icondataset.org/atlas>',
#  '<http://icondataset.org/artists-expression>',
#  '<http://icondataset.org/satyr>',
#  '<http://icondataset.org/phaeton>',
#  '<http://icondataset.org/jupiter>',
#  '<http://icondataset.org/era-sub-vulcano>',
#  '<http://icondataset.org/the-age-of-stone>',
#  '<http://icondataset.org/humour>',
#  '<http://icondataset.org/silenus>',
#  '<http://icondataset.org/era-sub-vulcano>',
#  '<http://icondataset.org/aeolus>',
#  '<http://icondataset.org/vulcan>',
#  '<http://icondataset.org/satyr>',
#  '<http://icondataset.org/taste>',
#  '<http://icondataset.org/saturn>',
#  '<http://icondataset.org/cultural-value>',
#  '<http://icondataset.org/centaur>',
#  '<http://icondataset.org/cupid>',
#  '<http://icondataset.org/olympian-gods>',
#  '<http://icondataset.org/zeus>',
#  '<http://icondataset.org/mercury-hermes>',
#  '<http://icondataset.org/iconographic-interpretation>',
#  '<http://icondataset.org/companion-of-serapis>',
#  '<http://icondataset.org/apollo>']

# %%
# extract list of lists for each cf with the corresponding labels
subj2_counting_cf = []

for key, value in top_5_subj_per_cf.items(): 
    cf = labels[key] 
    for v in value.items():
        subj2 = labels[v[0]]
        freq = v[1]
        subj2_counting_cf.append([cf, subj2, freq])

#subj2_counting_cf
# Out:
# [['Reception of Classical antiquity', 'Saturn', 16],
#  ['Reception of Classical antiquity', 'Cupid', 14],
#  ['Reception of Classical antiquity', 'Mercury', 11],
#  ['Reception of Classical antiquity', 'Venus', 8],
#  ['Reception of Classical antiquity', 'Jupiter', 8],
#  ['Iconographical evolution', 'Saturn', 16],
#  ['Iconographical evolution', 'Cupid', 14],
#  ['Iconographical evolution', 'Companion of Serapis', 8],
#  ['Iconographical evolution', 'Venus', 6],
#  ['Iconographical evolution', 'APOLLO', 6],
#  ['Societal phenomenon', 'Companion of Serapis', 3],
#  ['Societal phenomenon', 'APOLLO', 3],
#  ['Societal phenomenon', 'The young Mago Caspar', 1],
#  ['Societal phenomenon', 'Member of the procession', 1],
#  ['Societal phenomenon', 'Christ', 1],
#  ['Tendency', 'Era Sub Vulcano', 4],
#  ['Tendency', 'Mary', 3],
#  ['Tendency', 'Satyr', 3],
#  ['Tendency', 'Centaur', 3],
#  ['Tendency', 'The Age of Stone', 3],
#  ['Formal or stylistic evolution', 'Mercury', 8],
#  ['Formal or stylistic evolution', 'Era Sub Vulcano', 4],
#  ['Formal or stylistic evolution', 'Saturn', 3],
#  ['Formal or stylistic evolution', 'APOLLO', 3],
#  ['Formal or stylistic evolution', 'The three Graces', 3],
#  ['Belief', 'Satyr', 3],
#  ['Belief', 'Era Sub Vulcano', 3],
#  ['Belief', 'Erection of primitive buildings', 3],
#  ['Belief', 'The Age of Stone', 3],
#  ['Belief', 'Era ante Vulcanum', 3],
#  ['Iconographical influence', 'Planetary deities', 2],
#  ['Iconographical influence', 'lion-zodiacal-sign', 2],
#  ['Iconographical influence', 'The Constellation Hercules', 2],
#  ['Iconographical influence', 'Mercury', 1],
#  ['Iconographical influence', 'The Children of Mercury', 1],
#  ['Cultural reinterpretation', 'Cupid', 4],
#  ['Cultural reinterpretation', 'Jupiter', 3],
#  ['Cultural reinterpretation', 'The Constellation Hercules', 3],
#  ['Cultural reinterpretation', 'Venus', 2],
#  ['Cultural reinterpretation', 'Mercury', 2],
#  ['Attitude', "Europa's Companions", 2],
#  ['Attitude', 'The abduction of Europa', 2],
#  ['Attitude', 'Planetary deities', 1],
#  ['Attitude', 'The Children of each Planet', 1],
#  ['Attitude', 'Thisbe', 1],
#  ['Formal or stylistic phenomenon', 'Mary', 2],
#  ['Formal or stylistic phenomenon', 'Christ', 2],
#  ['Formal or stylistic phenomenon', 'Mars', 1],
#  ['Formal or stylistic phenomenon', 'Saint Mark', 1],
#  ['Formal or stylistic phenomenon', 'Saint Peter', 1],
#  ['Iconographical interpretation', 'Cupid', 10],
#  ['Iconographical interpretation', 'Saturn', 7],
#  ['Iconographical interpretation', 'Jupiter', 6],
#  ['Iconographical interpretation', 'Saturn devouring a living child', 5],
#  ['Iconographical interpretation', 'Satyr', 4],
#  ['Cultural movement', 'APOLLO', 2],
#  ['Cultural movement', 'Saturn', 1],
#  ['Cultural movement', 'Jupiter', 1],
#  ['Cultural movement', 'The three Graces', 1],
#  ['Cultural movement', 'Europa', 1],
#  ['Cultural influence', 'The Constellation Hercules', 2],
#  ['Cultural influence', 'Hecuba', 1],
#  ['Cultural influence', 'Troilus', 1],
#  ['Cultural influence', 'Venus', 1],
#  ['Cultural influence', 'Cupid', 1],
#  ['Cultural interpretation', 'Venus', 2],
#  ['Cultural interpretation', 'Cupid', 2],
#  ['Moral meaning', 'Sisyphus', 1],
#  ['Moral meaning', 'Tantalus', 1],
#  ['Moral meaning', 'Ixion', 1],
#  ['Moral meaning', 'Tityus', 1],
#  ['Moral meaning', 'Sisyphus carrying the stone uphill', 1],
#  ['Formal or stylistic influence', 'Mary', 1],
#  ['Formal or stylistic influence', 'Christ', 1],
#  ['Formal or stylistic influence', 'Archangel Gabriel', 1],
#  ['Formal or stylistic influence', 'Atlas', 1],
#  ["Artist's expression", 'Satyr', 3],
#  ["Artist's expression", 'Phaeton', 3],
#  ["Artist's expression", 'Jupiter', 3],
#  ["Artist's expression", 'Era Sub Vulcano', 3],
#  ["Artist's expression", 'The Age of Stone', 3],
#  ['Humour', 'Silenus', 2],
#  ['Humour', 'Era Sub Vulcano', 2],
#  ['Humour', 'Aeolus', 1],
#  ['Humour', 'Vulcan', 1],
#  ['Humour', 'Satyr', 1],
#  ['Taste', 'Saturn', 1],
#  ['Cultural value', 'Centaur', 1],
#  ['Cultural value', 'Cupid', 1],
#  ['Cultural value', 'Olympian Gods', 1],
#  ['Cultural value', 'Zeus', 1],
#  ['Cultural value', 'Mercury (Hermes)', 1],
#  ['Iconographic interpretation', 'Companion of Serapis', 3],
#  ['Iconographic interpretation', 'APOLLO', 3]]

# %%
line = ["Cultural Phenomenon", "Level 2 subject", "Frequency"] # labels only
save = store_csv("subj2_per_cf_top_5.csv", line, subj2_counting_cf)

# %%
dfSubjCf = pd.DataFrame(np.array(subj2_counting_cf),
                   columns=['Cultural Phenomenon', 'Level 2 Subject', 'Frequency'])
dfSubjCf['Frequency'] = dfSubjCf['Frequency'].astype(int)
# Out:
# Output:
# Cultural Phenomenon    object
# Level 2 Subject        object
# Frequency               int32
# dtype: object

# %%
dfSubjCf
# Out:
#                  Cultural Phenomenon       Level 2 Subject  Frequency
# 0   Reception of Classical antiquity                Saturn         16
# 1   Reception of Classical antiquity                 Cupid         14
# 2   Reception of Classical antiquity               Mercury         11
# 3   Reception of Classical antiquity                 Venus          8
# 4   Reception of Classical antiquity               Jupiter          8
# ..                               ...                   ...        ...
# 89                    Cultural value         Olympian Gods          1
# 90                    Cultural value                  Zeus          1
# 91                    Cultural value      Mercury (Hermes)          1
# 92       Iconographic interpretation  Companion of Serapis          3
# 93       Iconographic interpretation                APOLLO          3
#
# [94 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# https://seaborn.pydata.org/generated/seaborn.FacetGrid.html

gr = sns.FacetGrid(dfSubjCf, col="Cultural Phenomenon", col_wrap=4, sharex=False)
gr.map_dataframe(sns.barplot, x="Level 2 Subject", y="Frequency")
gr.set_titles(col_template="{col_name}")
#plt.tight_layout()

for axes in gr.axes.flat: # we modify the x labels
    wrap_labels(axes, 15) # wrap the labels longer than 15 characters
    axes.set_xticklabels(axes.get_xticklabels(), rotation=90) # rotate the labels

# gr.fig.tight_layout()
plt.subplots_adjust(hspace=1.5) # height space between graphs

# %% [markdown]
# [Back to top](#Dataset-overview) <br>
# [Back to section 2](#2.-Overwiew-of-Cultural-Phenomena)

# %% [markdown]
# ## 2.3 Frequency of the top K subjects per Cultural Phenomenon (overall visualization)

# %%
dfSubjCf = pd.read_csv("subj2_per_cf_top_5.csv")
dfSubjCf['Frequency'] = dfSubjCf['Frequency'].astype(int)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")


# Draw a nested barplot. Color represents each cultural phenomenon
g= sns.histplot(data=dfSubjCf, x="Level 2 subject", y="Frequency", hue="Cultural Phenomenon", palette="pastel")
# g = sns.histplot(data=df6, x="Subject", y="Frequency", hue="Cultural Phenomenon", palette="pastel")
# g.despine(left=True)
# g.set_axis_labels("", "Frequency")
# g.legend.set_title("")
plt.xticks(rotation=90)
#plt.tight_layout()
sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")


# Draw a nested barplot. Color represents each cultural phenomenon
g= sns.catplot(data=dfSubjCf,kind="bar", x="Frequency", y="Level 2 subject", hue="Cultural Phenomenon", palette="dark", height=6)
# g = sns.histplot(data=df6, x="Subject", y="Frequency", hue="Cultural Phenomenon", palette="pastel")
# g.despine(left=True)
# g.set_axis_labels("", "Frequency")
# g.legend.set_title("")
plt.xticks(rotation=90)
plt.tight_layout()
sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")


# Draw a nested barplot by species and sex
g = sns.catplot(
    data=dfSubjCf, kind="bar", x="Frequency", y="Level 2 subject", hue="Cultural Phenomenon",
     palette="dark", alpha=.6, height=20
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")

# %%
#dfMeanings = meanings_subjects
meanings_subjects_without_count = []
for cf, value in meanings_subjects.items(): 
    name = cf[0]
    for s in value: 
       meanings_subjects_without_count.append([cf, s]) 
meanings_subjects_without_count
# Out:
# [['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/jupiter'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/hercules'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/orpheus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/christ'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cerberus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/pluto'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/proserpina'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cerberus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/pluto'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/proserpina'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/perseus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/argus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/jupiter'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-children-of-mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-children-of-mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mars'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/pluto'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/bacchus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/laocoon'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/thymbraeus-son-of-laoocoon'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/antiphas-son-of-laoocoon'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/marine-snakes'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/jupiter'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/apollo'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-three-graces'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-three-graces'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/argus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/hecuba'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/troilus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/polyxena'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/polyxena'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/archangel-gabriel'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mary'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/thisbe'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-three-graces'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/europas-companions'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/eve'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/people/saint-luke'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saint-mark'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saint-peter'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-resurrected'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mary'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/simeon'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/god'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/prometheus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/pygmalion'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sisyphus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/tantalus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/ixion'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/hercules'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/satyr'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mithras'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mithras'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/people/virgil'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/people/virgil'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/people/virgil'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/people/virgil'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saint-john-the-evangelist'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mary'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/christ'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/david'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/roman-emperors'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/paris'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/helen'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/hylas'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/vulcan'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/nymphs'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/aeolus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/vulcan'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/silenus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/satyr'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/bacchus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/ariadne'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus-pudica'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus-coelestis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-three-graces'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/natural-venus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/erato'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/apollo'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/muses'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saint-john-the-evangelist'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/aeneas'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/dido'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/satyr'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/centaur'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/satyr'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/centaur'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/centaur'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/bacchus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/ariadne'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/silenus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/lapiths'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/prometheus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/aion/phanes'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/rhea'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/jupiter'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-children-of-saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/dieu-amour'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/blindfold-cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/blindfold-cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/blindfold-cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/anteros'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/anteros'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/blindfold-cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/blindfold-cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mars'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/jupiter-as-an-eagle'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/ganymede'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/tityus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/phaeton'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/jupiter'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/phaeton'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/jupiter'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/phaeton'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/jupiter'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/female-pan'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/silenus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/companion-of-serapis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/companion-of-serapis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/companion-of-serapis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/apollo'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/companion-of-serapis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/apollo'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/companion-of-serapis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/apollo'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/serapis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/companion-of-serapis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/apollo'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/companion-of-serapis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/hercules'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/christ'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sol-iustitiae'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/europa'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/europas-companions'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/apollo'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/apollo-medicus-or-aesculapius'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/apollo-god-of-sun'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mars'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/pluto'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/jupiter'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/bacchus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/apollo'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/vulcan'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/rachel'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/pope-julius-ii'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/leach'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/moses'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sybil'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/prophet'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mary'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/christ-as-a-child'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/rape'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/rape'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/crucifixion'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/crucifixion'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-abduction-of-europa'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/simeon-witnesses-the-presentation-of-christ'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/god-creating-the-universe'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/prometheus-animates-man'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/pygmalion-dressing-his-statue'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/ixion-on-his-wheel'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/joseph-cast-into-the-pit'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/blood-sacrifice-of-animals'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mithras-twisting-the-horns-of-a-bull'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mithras-killing-the-bull'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sacrifice-of-a-bull'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/blood-sacrifice-of-animals'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/lamentation-of-christ'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/amorini-pointing-out-to-death-her-first-victims'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/three-corpses-warn-three-gentlemen-against-their-thoughtless-enjoyment-of-life'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/paris-rapes-helen'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/era-sub-vulcano'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/era-sub-vulcano'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-age-of-metal'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/era-sub-vulcano'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-age-of-stone'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/era-ante-vulcanum'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-age-of-stone'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/era-ante-vulcanum'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-age-of-stone'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/era-ante-vulcanum'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/battle-of-lapiths-and-centaurs'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/era-sub-vulcano'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/prometheus-is-punished'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/era-sub-prometheo'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn-devouring-a-living-child'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn-devouring-a-living-child'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn-devouring-a-living-child'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-devouring-the-past'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/innocence-threatened-by-the-powers-of-evil'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-reveals-the-truth'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sun-moves-his-chariot-through-the-zodiac'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/love-shooting-the-foolish'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/love-shooting-the-wise-man'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/triumph-of-love'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/death-steals-the-weapons-from-cupid-while-he-sleeps'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/death-steals-the-weapons-from-cupid-while-he-sleeps'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/resurrection-of-christ'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-abduction-of-europa'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn-devouring-a-living-child'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn-devouring-a-living-child'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/algol-head-of-demon'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/medusas-head'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercurys-winged-sandals'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/caduceus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/algol-head-of-demon'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/caduceus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercurys-winged-sandals'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-tomb-of-king-ninus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/caduceus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/apollonian-swan'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/torch-of-prometheus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury-planet'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/saturn-planet'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/jupiter-planet'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mars-planet'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus-planet'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/moon-planet'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/torso-del-belvedere'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/tower-of-chastity'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/hearts-of-cupids-victims'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/caduceus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/caduceus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/lion-zodiacal-sign'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/planimetrical-scheme-of-the-celestial-spheres'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/north-pole-sky'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/heaven'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/island-of-lemnos'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-constellation-eridanus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-constellation-hercules'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-constellation-hercules'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-constellation-hercules'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-constellation-hercules'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-constellation-perseus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-constellation-hercules'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-constellation-perseus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-constellation-hercules'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-constellation-perseus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-virgin-constellation'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/oceanus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/tellus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sun'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/moon'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sun'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/moon'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-twins-constellation'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/atlas'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sleep'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/death'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/ignis-elementatus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/flora'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/spring'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/flora'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/zephir'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/truth'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/kairos'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/aion/phanes-as-personification-of-eternal-time'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-as-universal-cosmic-principle'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-the-destroyer'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-the-destroyer'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-ripa'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-the-destroyer'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-ripa'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/innocence'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/justice'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-the-revealer'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/truth'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-the-revealer'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/futile-and-treacherous-pleasure'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/fraude'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/truth'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/jealousy'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/pleasure'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-as-a-cosmic-power'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/poverty'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/labour'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/wealth'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/luxury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/time-as-a-cosmic-power'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sun-on-his-chariot'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/amor-carnalis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/amor'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/ardor'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/death'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/penitentia'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/amor-divino'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/death'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/death'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/fortune'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/faith'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/hope'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/love'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/three-stages-of-human-life'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/good-counsel'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/river-alpheus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/vita-contemplativa'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/vita-activa'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/deer-souls'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/carrying-on-shoulders-saving-souls'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/stepping-on-defeating-devil'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/dragoon-devil'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/dragon-biting-its-tail-time'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/europa-human-soul'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/bull-christ'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/urns-pagan-custom-of-cremation'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/tombs-christian-rite-of-burial'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sisyphus-pride'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/tantalus-avarice'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/ixion-lewdness'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/hercules-egypt'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/satyr-egyptian-desert-wilderness'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid-amor-carnalis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/torch-unholy-ardor'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/ibis-homo-carnalis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/cupid-amor-carnalis'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/venus-coelestis-amor-divinus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/natural-venus-amor-humanus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury-turning-his-back-to-the-realm-of-the-natural-venus-the-discursive-reason-is-not-involved-in-the-activities-of-the-natural-venus'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury-discursive-reason'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/mercury-discursive-reason:-limitations-and-possibilities-of-what-human-reason-can-do'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/lyre-fashioned-from-a-stags-head-low-class-and-uncouth-music'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/dragon-biting-its-tail-time'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/monk-vita-contemplativa'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/fire-fire-to-burn-the-time'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/four-wings-four-seasons'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/dragon-biting-its-tail-time'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/desolate-scenery-destructive-power-of-time'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/dog-envy'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/lion-fury'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/wolf-greed'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/serpent-perfidy'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/pillow-idleness-and-lechery'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/two-billing-doves-amorous-caresses'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/myrtle-love'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/hourglass-transience'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/soap-bubbles-futility'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-affection-changes-with-luck'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/bundle-of-sticks-unity'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/myrtle-everlasting-love'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/roses-pleasures-of-permanent-congeniality'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/glass-sphere-harmony-that-can-be-easily-broken'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/liver-seat-of-physical-passions'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/phaeton-the-presumptuous'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/phaeton-the-presumptuous'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/face-of-an-old-man-the-past'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/face-of-an-adult-man-the-present'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/face-of-a-young-man-the-future'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/three-headed-companion-of-serapis-prudence'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/face-of-an-old-man-the-past'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/face-of-an-adult-man-the-present'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/face-of-a-young-man-the-future'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/three-books-three-forms-of-time-past-present-future'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/face-of-an-old-woman-the-past'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/face-of-an-adult-woman-the-present'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/face-of-a-young-woman-the-future'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/serpent-attribute-of-wisdom'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/book-attribute-of-wisdom'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/owl-attribute-of-wisdom'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/bear-anger'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/dolphin-haste'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/three-headed-companion-of-serapis-prudence'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/book-attribute-of-wisdom'],
#  ['http://icondataset.org/reception-of-classical-antiquity',
#   'http://icondataset.org/owl-attribute-of-wisdom'],
# ...
#  ['http://icondataset.org/tendency', 'http://icondataset.org/centaur'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/bacchus'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/ariadne'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/silenus'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/lapiths'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/prometheus'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/people/lorenzo-de-medici'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/votary-of-saturn'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/giuliano-de-medici'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/votary-of-jupiter'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/europa'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/europas-companions'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/apollo'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/cupid'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/rachel'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/pope-julius-ii'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/leach'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/moses'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/sybil'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/prophet'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/mary'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/christ-as-a-child'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/simeon-witnesses-the-presentation-of-christ'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/ixion-on-his-wheel'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/era-sub-vulcano'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/era-sub-vulcano'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/the-age-of-metal'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/era-sub-vulcano'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/the-age-of-stone'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/era-ante-vulcanum'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/the-age-of-stone'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/era-ante-vulcanum'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/the-age-of-stone'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/era-ante-vulcanum'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/battle-of-lapiths-and-centaurs'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/era-sub-vulcano'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/prometheus-is-punished'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/era-sub-prometheo'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/gesture-of-saturnian-silence'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/the-abduction-of-europa'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/the-tomb-of-king-ninus'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/torch-of-prometheus'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/island-of-lemnos'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/nude-prudence'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/ignis-elementatus'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/vita-contemplativa'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/vita-activa'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/deer-souls'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/carrying-on-shoulders-saving-souls'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/stepping-on-defeating-devil'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/dragoon-devil'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/urns-pagan-custom-of-cremation'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/tombs-christian-rite-of-burial'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/sisyphus-pride'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/tantalus-avarice'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/ixion-lewdness'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/closed-cash-box-saturninian-parsimony'],
#  ['http://icondataset.org/tendency', 'http://icondataset.org/bat-melancholy'],
#  ['http://icondataset.org/tendency',
#   'http://icondataset.org/princely-sceptre-jovial-magnanimity'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/cerberus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/pluto'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/proserpina'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/cerberus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/pluto'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/proserpina'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/argus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/the-children-of-mercury'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/the-children-of-mercury'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/laocoon'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/thymbraeus-son-of-laoocoon'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/antiphas-son-of-laoocoon'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/marine-snakes'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/jupiter'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/apollo'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/the-three-graces'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/venus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/the-three-graces'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/argus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/hecuba'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/troilus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/polyxena'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/polyxena'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/thisbe'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/the-three-graces'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/europas-companions'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/saint-peter'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/the-resurrected'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/mary'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/pygmalion'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/people/virgil'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/people/virgil'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/people/virgil'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/saint-john-the-evangelist'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/david'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/paris'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/helen'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/hylas'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/vulcan'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/nymphs'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/aeolus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/vulcan'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/silenus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/satyr'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/bacchus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/ariadne'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/aeneas'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/dido'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/satyr'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/centaur'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/satyr'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/centaur'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/centaur'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/bacchus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/ariadne'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/silenus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/lapiths'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/prometheus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/saturn'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/bishop-simone-saltarelli'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/presbyter-bruno'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/apollo'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/companion-of-serapis'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/mercury'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/europa'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/europas-companions'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/apollo'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/cupid'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/rape'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/rape'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/crucifixion'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/the-abduction-of-europa'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/pygmalion-dressing-his-statue'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/lamentation-of-christ'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/paris-rapes-helen'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/era-sub-vulcano'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/era-sub-vulcano'],
#  ['http://icondataset.org/formal-or-stylistic-evolution',
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows'],
#  ...]

# %% [markdown]
# [Back to top](#Dataset-overview) <br>
# [Back to section 2](#2.-Overwiew-of-Cultural-Phenomena)

# %% [markdown]
# ## 2.4 Co-occurrencies of subjects and Cultural Phenomena

# %% [markdown]
# [Back to top](#Dataset-overview) <br>
# [Back to section 2](#2.-Overwiew-of-Cultural-Phenomena)

# %% [markdown]
# # 3. Overview of subjects relations<a class="anchor" id="third-bullet"></a>
# Visualization of level 1, 2, 3 subjects relations
# <br>
# [Back to top](#Dataset-overview)

# %%
# https://plotly.com/python/sankey-diagram/
# useful tutorial: https://www.youtube.com/watch?v=yyVwvBUFRwY 
#import plotly.graph_objects as go

fig = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 15,
      thickness = 20,
      line = dict(color = "black", width = 0.5),
      label = ["A1", "A2", "B1", "B2", "C1", "C2"],
      color = "blue"
    ),
    link = dict(
      source = [0, 1, 0, 2, 3, 3], # indices corresponding to labels, eg A1, A2, A1, B1, ...
      target = [2, 3, 3, 4, 4, 5],
      value = [8, 4, 2, 8, 4, 2]
  ))])

fig.update_layout(title_text="Basic Sankey Diagram", font_size=10)
fig.show()
# Out:
# <div>                            <div id="bc43c7c8-d9fc-4421-8b2c-f19decf9d68e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc43c7c8-d9fc-4421-8b2c-f19decf9d68e")) {                    Plotly.newPlot(                        "bc43c7c8-d9fc-4421-8b2c-f19decf9d68e",                        [{"link":{"source":[0,1,0,2,3,3],"target":[2,3,3,4,4,5],"value":[8,4,2,8,4,2]},"node":{"color":"blue","label":["A1","A2","B1","B2","C1","C2"],"line":{"color":"black","width":0.5},"pad":15,"thickness":20},"type":"sankey"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"typ ...
#
# var gd = document.getElementById('bc43c7c8-d9fc-4421-8b2c-f19decf9d68e');
# var x = new MutationObserver(function (mutations, observer) {{

# %%
# extract data 

# no modify
cq2 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?artwork ?subj1 ?subj1Label ?type1Label ?subj2 ?subj2Label ?type2Label ?subj3 ?subj3Label ?type3Label  WHERE {
  VALUES ?rel1 {icon:hasExpressionalMeaning icon:hasFactualMeaning crm:P138_depicts}
  VALUES ?rel2 {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
  
  # ?subj3 ^icon:recognizedCulturalPhenomenon | ^icon:recognizedConceptualObject / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?subj3 rdfs:label ?subj3Label; a ?type3Label. 
  # ?iconol icon:aboutWorkOfArt ?artwork .
  # ?icrec icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition;
          icon:recognizedImage ?image; 
  # ?image ?rel2 ?subj2. 
  # ?preicrec icon:aboutWorkOfArt ?artwork; 
      a icon:PreiconographicalRecognition; 
      icon:recognizedArtisticMotif ?am. ?am ?rel1 ?subj1. 
  # ?subj1 rdfs:label ?subj1Label; 
      a ?type1.
  # ?type1 rdfs:label ?type1Label. 
{?lev1 icon:hasPart ?am. ?am ?rel1 ?subj1} UNION {?lev1 ?rel1 ?subj1}
# ?subj1 rdfs:label ?subj1Label. 

  #OPTIONAL {
  #  ?icrec icon:aboutWorkOfArt ?artwork;
  #  a icon:IconographicalRecognition; icon:recognizedInvenzione ?subj2.
  #}

} 
""" 

cq2res = newg.query(cq2)
for row in cq2res:
  print(row[0], '-',row[3], " -- cf: ", row[1])

# %%
# extract data 
test_1 = []
# no modify
cq2 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?type1 (count(distinct ?am) as ?tot1) ?type2 (count(distinct ?image) as ?tot2)  WHERE {
  VALUES ?rel1 {icon:hasExpressionalMeaning icon:hasFactualMeaning crm:P138_depicts}
  VALUES ?rel2 {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
  

  # ?icrec icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition;
          icon:recognizedImage ?image. 
  # ?image ?rel2 ?subj2.  
  # ?subj2 a ?type2. 
 # ?type2 rdfs:label ?type2Label. 
  {?icrec icon:refersToArtisticMotif ?lev1. 
  # ?lev1 icon:hasPart ?am. ?am ?rel1 ?subj1} 
  UNION 
  {?icrec icon:refersToArtisticMotif ?am. ?am ?rel1 ?subj1}
  # ?subj1 a ?type1. 
 # ?type1 rdfs:label ?type1Label.


} 
""" 

cq2res = newg.query(cq2)
for row in cq2res:
    test_1.append([str(row[0]), int(row[1]), str(row[2]), int(row[3])])
    print(str(row[0]), int(row[1]), str(row[2]), int(row[3]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\SOFIAB~1\AppData\Local\Temp/ipykernel_1292/1684548393.py in <module>
#      32
#      33 cq2res = newg.query(cq2)
# ---> 34 for row in cq2res:
#      35     test_1.append([str(row[0]), int(row[1]), str(row[2]), int(row[3])])
#      36     print(str(row[0]), int(row[1]), str(row[2]), int(row[3]))
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\query.py in __iter__(self)
#     290
#     291             if self._genbindings:
# --> 292                 for b in self._genbindings:
#     293                     if b:  # don't add a result row in case of empty binding {}
#     294                         self._bindings.append(b)
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalDistinct(ctx, part)
#     499
#     500     done = set()
# --> 501     for x in res:
#     502         if x not in done:
#     503             yield x
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in <genexpr>(.0)
#     508     res = evalPart(ctx, project.p)
#     509
# --> 510     return (row.project(project.PV) for row in res)
#     511
#     512
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalExtend(ctx, extend)
#      91     # TODO: Deal with dict returned from evalPart from GROUP BY
#      92
# ---> 93     for c in evalPart(ctx, extend.p):
#      94         try:
#      95             e = _eval(extend.expr, c.forget(ctx, _except=extend._vars))
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalExtend(ctx, extend)
#      91     # TODO: Deal with dict returned from evalPart from GROUP BY
#      92
# ---> 93     for c in evalPart(ctx, extend.p):
#      94         try:
#      95             e = _eval(extend.expr, c.forget(ctx, _except=extend._vars))
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalExtend(ctx, extend)
#      91     # TODO: Deal with dict returned from evalPart from GROUP BY
#      92
# ---> 93     for c in evalPart(ctx, extend.p):
#      94         try:
#      95             e = _eval(extend.expr, c.forget(ctx, _except=extend._vars))
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalExtend(ctx, extend)
#      91     # TODO: Deal with dict returned from evalPart from GROUP BY
#      92
# ---> 93     for c in evalPart(ctx, extend.p):
#      94         try:
#      95             e = _eval(extend.expr, c.forget(ctx, _except=extend._vars))
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalAggregateJoin(ctx, agg)
#     416         # get 1 aggregator for counting
#     417         aggregator = res[True]
# --> 418         for row in p:
#     419             aggregator.update(row)
#     420     else:
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evalutils.py in _join(a, b)
#      25
#      26 def _join(a, b):
# ---> 27     for x in a:
#      28         for y in b:
#      29             if x.compatible(y):
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evalutils.py in _join(a, b)
#      27     for x in a:
#      28         for y in b:
# ---> 29             if x.compatible(y):
#      30                 yield x.merge(y)
#      31
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\sparql.py in compatible(self, other)
#     137         for k in self:
#     138             try:
# --> 139                 if self[k] != other[k]:
#     140                     return False
#     141             except KeyError:
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\sparql.py in __getitem__(self, key)
#     163     def __getitem__(self, key):
#     164
# --> 165         if not isinstance(key, Node):
#     166             key = Variable(key)
#     167
#
# KeyboardInterrupt:

# %% [markdown]
# [Back to top](#Dataset-overview) <br>
# [Back to section 3](#3.-Overview-of-subjects-relations)
