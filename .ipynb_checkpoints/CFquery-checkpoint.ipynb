# %%
#pip install rdflib
import rdflib
from rdflib import Namespace , Literal , URIRef
from rdflib.namespace import RDF , RDFS
import pandas as pd
import numpy as np
import seaborn as seaborn 
from collections import defaultdict , Counter

# %%
# create an empty Graph
g = rdflib.Graph()

# parse a local RDF file by specifying the format
result = g.parse("26102022output.ttl")

# %%
# useful functions
import json
def store_in_json(file_name, dictName): 
  with open(file_name, mode='w', encoding="utf-8") as jsonfile:
    json.dump(dictName, jsonfile)
    
import csv 
def store_csv(file_name, first_line, list_of_lists): 
    with open(file_name, mode='w', newline='', encoding='UTF-8') as my_file:
        file = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
        file.writerow(first_line) 
        for l in list_of_lists: 
            file.writerow(l) 
    return(file_name)

# %%
# Cultural phenomena in the dataset

# %%
# count how many artworks have a certain phenomenon category and visualize it

# %%
cf_category_frequency = []
cq1 = '''
prefix data: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?CFBroaderLabel (count(distinct ?artwork) as ?tot) WHERE {
  # ?iconol icon:aboutWorkOfArt ?artwork;
  icon:recognizedIntrinsicMeaning ?intrinsic.
  # ?intrinsic icon:recognizedCulturalPhenomenon ?meaning.
  # ?meaning a icon:CulturalPhenomenon; crm:P2_has_type ?CFBroader. 
  # ?CFBroader rdfs:label ?CFBroaderLabel .
}
GROUP BY ?CFBroaderLabel 
ORDER BY DESC(?tot)
'''

cq1res = g.query(cq1)
for row in cq1res: 
    if str(row[0]) != "?": 
        cf_category_frequency.append([str(row[0]), int(row[1])])

# %%
df2 = pd.DataFrame(np.array(cf_category_frequency),
                   columns=['Cultural Phenomenon', 'Frequency'])
df2['Frequency'] = df2['Frequency'].astype(int)
result = df2.dtypes

print("Output:")
print(result)
# Out:
# Output:
# Cultural Phenomenon    object
# Frequency               int32
# dtype: object

# %%
# df3 = df2.sort_values(by=['Frequency'], ascending=False)
df3 = df2.sort_index(ascending=False)
df3
# Out:
#                  Cultural Phenomenon  Frequency
# 20           Cultural interpretation          2
# 19                     Moral meaning          2
# 18       Iconographic interpretation          3
# 17                             Taste          3
# 16                            Humour          3
# 15                 Cultural movement          4
# 14                    Cultural value          7
# 13               Societal phenomenon         10
# 12                Cultural influence         14
# 11                          Attitude         15
# 10          Iconographical influence         15
# 9                Artist's expression         15
# 8          Cultural reinterpretation         17
# 7      Formal or stylistic influence         24
# 6                             Belief         30
# 5                           Tendency         39
# 4      Iconographical interpretation         51
# 3     Formal or stylistic phenomenon         61
# 2      Formal or stylistic evolution         89
# 1           Iconographical evolution        115
# 0   Reception of Classical antiquity        203

# %%
import seaborn as seaborn 
chart = seaborn.barplot(data=df3, x = 'Frequency', y='Cultural Phenomenon')

# %% [markdown]
# # Distribution of cultural phenomena

# %%
cq1 = '''
prefix data: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?meaning ?meaningLabel (count(distinct ?artwork) as ?tot) ?time WHERE {
  # ?iconol icon:aboutWorkOfArt ?artwork;
  icon:recognizedIntrinsicMeaning ?intrinsic.
  # ?intrinsic (icon:recognizedConceptualObject | icon:recognizedCulturalPhenomenon) ?meaning.
  # ?meaning a icon:CulturalPhenomenon; rdfs:label ?meaningLabel .
  OPTIONAL {?cultObj crm:P65_shows_visual_item ?artwork.
          # ?production crm:P108_has_produced ?cultObj;
          crm:P4_has_time_span ?time}
}
GROUP BY ?meaning 
ORDER BY DESC(?tot)
'''

cq1res = g.query(cq1)

# create a list with phenomena that appear in at least 5 artworks
well_represented_phenomena = []
well_represented_phenomena_and_counts = []
for row in cq1res:
  if int(row[2]) >= 9:
    well_represented_phenomena.append("<"+str(row[0])+">")
    well_represented_phenomena_and_counts.append((str(row[0]), row[2]))
    print(row[2], '-',row[1])
# Out:
# 26 - Representation of classical content with contemporary formal motifs
# 23 - Renascences of classical antiquity in Western Art before the Renaissance
# 13 - Reintegration of classical style and content in the Italian Renaissance
# 12 - Iconographic evolution of classical subjects
# 12 - Iconographic evolution of the representation of the three-headed companion of Serapis
# 11 - Classical motifs recovery
# 10 - Classical subject matter represented in classical form
# 10 - The phenomenon called Principle of disjunction: whenever in the high and later Middle Ages a work of art borrows its form from a classical model, this form is almost invariably invested with a non-classical, normally Christian, significance; whenever in the high and later Middle Ages a work of art borrows its theme from classical poetry, legend, history or mythology, this theme is quite invariably presented in a non-classical, normally contemporary, form.
# 9 - Intrinsic classicism was created by the meeting of Gothic and Proto-Renaissance tendencies
# 9 - Piero di Cosimo's representation of the primitive world is an "extreme and unique manifestation of the general tendency to retrieve the sacrosancta vetustas"

# %% [markdown]
# Notes: they are a lot, which is ok. I'm wondering if some can be generalized, e.g. an artwork that exemplifies "Iconographic evolution of nudity" can also exemplify "Iconographic evolution of classical subjects". If so, can the artwork be associated to both phenomena?

# %%
# same query with general categories

cq1 = '''
prefix data: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?CFbroader ?CFbroaderLabel (count(distinct ?artwork) as ?tot) ?time WHERE {
  # ?iconol icon:aboutWorkOfArt ?artwork;
  icon:recognizedIntrinsicMeaning ?intrinsic.
  # ?intrinsic icon:recognizedCulturalPhenomenon ?meaning.
  # ?meaning a icon:CulturalPhenomenon; crm:P2_has_type ?CFbroader. 
# ?CFbroader rdfs:label ?CFbroaderLabel.
  OPTIONAL {?cultObj crm:P65_shows_visual_item ?artwork.
          # ?production crm:P108_has_produced ?cultObj;
          crm:P4_has_time_span ?time}
}
GROUP BY ?CFbroader 
ORDER BY DESC(?tot)
'''

cq1res = g.query(cq1)

# create a list with phenomena that appear in at least 5 artworks
well_represented_phenomena = []
well_represented_phenomena_and_counts = []
for row in cq1res:
  if int(row[2]) >= 9:
    well_represented_phenomena.append("<"+str(row[0])+">")
    well_represented_phenomena_and_counts.append((str(row[0]), row[2]))
    print(row[2], '-',row[1])
# Out:
# 203 - Reception of Classical antiquity
# 115 - Iconographical evolution
# 89 - Formal or stylistic evolution
# 61 - Formal or stylistic phenomenon
# 51 - Iconographical interpretation
# 39 - Tendency
# 30 - Belief
# 24 - Formal or stylistic influence
# 17 - Cultural reinterpretation
# 15 - Artist's expression
# 15 - Iconographical influence
# 15 - Attitude
# 14 - Cultural influence
# 10 - Societal phenomenon

# %%
well_represented_phenomena = ['<http://icondataset.org/reception-of-classical-antiquity>',
'<http://icondataset.org/iconographical-evolution>',
 '<http://icondataset.org/formal-or-stylistic-evolution>',
 '<http://icondataset.org/formal-or-stylistic-phenomenon>',
 '<http://icondataset.org/iconographical-interpretation>',
 '<http://icondataset.org/tendency>',
 '<http://icondataset.org/belief>',
 '<http://icondataset.org/formal-or-stylistic-influence>',
 '<http://icondataset.org/cultural-reinterpretation>',
 '<http://icondataset.org/artists-expression>',
 '<http://icondataset.org/iconographical-influence>',
 '<http://icondataset.org/attitude>',
 '<http://icondataset.org/cultural-influence>',
 '<http://icondataset.org/societal-phenomenon>']
# Out:
# ['<http://icondataset.org/reception-of-classical-antiquity>',
#  '<http://icondataset.org/iconographical-evolution>',
#  '<http://icondataset.org/formal-or-stylistic-evolution>',
#  '<http://icondataset.org/formal-or-stylistic-phenomenon>',
#  '<http://icondataset.org/iconographical-interpretation>',
#  '<http://icondataset.org/tendency>',
#  '<http://icondataset.org/belief>',
#  '<http://icondataset.org/formal-or-stylistic-influence>',
#  '<http://icondataset.org/cultural-reinterpretation>',
#  '<http://icondataset.org/artists-expression>',
#  '<http://icondataset.org/iconographical-influence>',
#  '<http://icondataset.org/attitude>',
#  '<http://icondataset.org/cultural-influence>',
#  '<http://icondataset.org/societal-phenomenon>']

# %% [markdown]
# # Subjects of well represented phenomena
#
# Level 2 subjects associated to the most well represented cultural phenomena

# %%
cq2 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?meaning ?artwork ?subj2  WHERE {
  VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
  VALUES ?meaning { """+ ' '.join(well_represented_phenomena) +"""}
  # ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?iconol icon:aboutWorkOfArt ?artwork .
  # ?icrec icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition;
          icon:recognizedImage ?image.
  
  # ?image ?rel ?subj2. 

  #OPTIONAL {
  #  ?icrec icon:aboutWorkOfArt ?artwork;
  #  a icon:IconographicalRecognition; icon:recognizedInvenzione ?subj2.
  #}

} 
""" 

cq2res = g.query(cq2)
#for row in cq2res:
#  print(row[0], '-',row[2], " -- meaning:", row[1])

# %%
# same, takng cultural phenomena typologies

# %%
cq2 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?CFbroader ?CFbroaderLabel ?artwork ?subj2  WHERE {
  VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
  VALUES ?CFbroader { """+ ' '.join(well_represented_phenomena) +"""}
  # ?CFbroader ^crm:P2_has_type ?meaning.
  # ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?iconol icon:aboutWorkOfArt ?artwork .
  # ?icrec icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition;
          icon:recognizedImage ?image.
 
  # ?CFbroader rdfs:label ?CFbroaderLabel. 
  # ?image ?rel ?subj2. 

  #OPTIONAL {
  #  ?icrec icon:aboutWorkOfArt ?artwork;
  #  a icon:IconographicalRecognition; icon:recognizedInvenzione ?subj2.
  #}

} 
""" 

cq2res = g.query(cq2)
for row in cq2res:
  print(row[0], '-',row[3], " -- meaning:", row[1])
# Out:
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/argus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/vulcan  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-three-graces  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/silenus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pygmalion  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/archangel-gabriel  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/thisbe  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/ganymede  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/vulcan  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/marine-snakes  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/troilus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/blindfold-cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/companion-of-serapis  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pluto  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/sisyphus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mary  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/blindfold-cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/muses  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/natural-venus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/paris  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-resurrected  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/centaur  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bacchus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/satyr  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/europa  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cerberus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saint-john-the-evangelist  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/thymbraeus-son-of-laoocoon  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/nymphs  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/phaeton  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-children-of-saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saint-mark  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/vulcan  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/aeneas  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/europas-companions  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/companion-of-serapis  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/people/virgil  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-three-graces  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/prometheus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/hercules  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/erato  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/people/virgil  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/blindfold-cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pluto  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cerberus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mars  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/dido  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/perseus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/sol-iustitiae  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/anteros  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/christ  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/hylas  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mary  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mars  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus-coelestis  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/satyr  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/satyr  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mithras  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/ariadne  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mary  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/polyxena  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/blindfold-cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/centaur  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/antiphas-son-of-laoocoon  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/europas-companions  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/polyxena  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mary  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/prometheus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/argus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/blindfold-cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter-as-an-eagle  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/orpheus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/prophet  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/hecuba  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/rachel  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/david  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/simeon  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo-medicus-or-aesculapius  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/companion-of-serapis  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/moses  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/serapis  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo-god-of-sun  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bacchus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pluto  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/helen  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saint-peter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/tityus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/laocoon  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/people/virgil  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/aeolus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/companion-of-serapis  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/companion-of-serapis  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/lapiths  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/silenus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/satyr  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/hercules  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pope-julius-ii  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/people/virgil  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bacchus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/rhea  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/eve  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus-pudica  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/tantalus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-children-of-mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-three-graces  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pluto  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/apollo  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/silenus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/leach  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/christ-as-a-child  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-three-graces  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/roman-emperors  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/people/saint-luke  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/companion-of-serapis  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bacchus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/phaeton  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/phaeton  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-children-of-mercury  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/god  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/female-pan  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/christ  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/ixion  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/ariadne  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mithras  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/aion/phanes  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/venus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/proserpina  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/christ  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/hercules  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/proserpina  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/cupid  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/dieu-amour  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/companion-of-serapis  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saint-john-the-evangelist  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/anteros  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/sybil  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/centaur  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/mars  -- meaning: Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/apostles  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/satyr  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-children-of-saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury-hermes  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/companion-of-serapis  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/apollo-god-of-sun  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mithras  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/companion-of-serapis  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/blindfold-cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/companion-of-serapis  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/anteros  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/dieu-amour  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/companion-of-serapis  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/olympian-gods  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/companion-of-serapis  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/argus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/apollo  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/people/virgil  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/blindfold-cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/ariadne  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/apollo  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/blindfold-cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/apollo-medicus-or-aesculapius  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/blindfold-cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/bacchus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/sol-iustitiae  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/companion-of-serapis  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/jupiter  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/apollo  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/pluto  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/argus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/satyr  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/blindfold-cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/blindfold-cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/aglauros  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-children-of-saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/anteros  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mars  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/europa  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-three-graces  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/devil  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury-hermes  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/athene  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/serapis  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/christ  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/companion-of-serapis  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/perseus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/christ  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/aglauros  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus-coelestis  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/apollo  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/olympian-gods  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mithras  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/companion-of-serapis  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/people/virgil  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/aion/phanes  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/jest  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saint-theodora-of-alexandria  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/people/virgil  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/orpheus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-children-of-mercury  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/christ  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/mercury  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/jupiter  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/silenus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/gods-hand  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/apollo  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/satyr  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/herse  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-three-graces  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/zeus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/rhea  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/christ  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/cupid  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/jupiter  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/venus-pudica  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saint-john-the-evangelist  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saint-theodora-of-alexandria  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/zeus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/apollo  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/europas-companions  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/bacchus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/people/virgil  -- meaning: Iconographical evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/satyr  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/saturn  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/apollo  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/argus  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/saint-john-the-evangelist  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-three-graces  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-three-graces  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/centaur  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/centaur  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/prometheus  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/vulcan  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/polyxena  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/jupiter  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/david  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/bishop-simone-saltarelli  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/saturn  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/ariadne  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/apollo  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/pluto  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-children-of-mercury  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/laocoon  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/pygmalion  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/silenus  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/thisbe  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/vulcan  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-resurrected  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/saturn  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/cerberus  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/satyr  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/thymbraeus-son-of-laoocoon  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/nymphs  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/cupid  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mercury  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/aeneas  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/europa  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/mary  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/people/virgil  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/cerberus  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/dido  -- meaning: Formal or stylistic evolution
# ...
# http://icondataset.org/tendency - http://icondataset.org/ixion-lewdness  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/tantalus-avarice  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/deer-souls  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/tombs-christian-rite-of-burial  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/family-simple-happiness-of-primitive-civilization  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/sisyphus-pride  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/urns-pagan-custom-of-cremation  -- meaning: Tendency
# http://icondataset.org/belief - http://icondataset.org/masks-fallacy-deceit  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/natural-venus-amor-humanus  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/blowing-in-a-tube-fertilising  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/four-rivers-of-hades-four-elements-air-fire-earth-water  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/central-zone-of-the-tomb-realm-of-nature-the-only-sphere-subject-to-time  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/family-simple-happiness-of-primitive-civilization  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/fire-luxury  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/archers-without-arrows-tools-of-a-force-beyond-their-will-and-consciousness  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/monk-vita-contemplativa  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/four-times-of-day-fourfold-aspect-of-life-on-earth-as-a-state-of-actual-suffering  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/mercury-discursive-reason  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/empty-throne-invisible-presence-of-an-immortal  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/trophies-ultimate-triumph-over-the-lower-forms-of-existence  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/four-times-of-day-realm-of-nature  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/empty-throne-invisible-presence-of-an-immortal  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/lowest-zone-of-the-tomb-realm-of-sheer-matter  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/four-rivers-of-hades-fourfold-aspect-of-matter-as-a-source-of-potential-evil  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/four-times-of-day-realm-of-nature  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/four-rivers-of-hades-fourfold-aspect-of-matter-as-a-source-of-potential-evil  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/angel-wepting-while-carrying-the-coffin-of-the-pope-angel-grieved-that-the-world-had-been-deprived-of-such-a-man  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/children-crouching-down-unborn-souls-doomed-to-descend-to-the-lower-spheres  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/flying-towards-marys-head-to-fertilise  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/sleeping-cupid-natural-desire-has-nothing-to-do-with-love  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/mercury-turning-his-back-to-the-realm-of-the-natural-venus-the-discursive-reason-is-not-involved-in-the-activities-of-the-natural-venus  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/highest-zone-of-the-tomb-supercelestial-sphere  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/four-times-of-day-four-humours  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/white-lilium-virginity  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/four-times-of-day-four-humours  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/four-rivers-of-hades-four-elements-air-fire-earth-water  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/lowest-zone-of-the-tomb-realm-of-sheer-matter  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/four-times-of-day-fourfold-aspect-of-life-on-earth-as-a-state-of-actual-suffering  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/mercury-discursive-reason:-limitations-and-possibilities-of-what-human-reason-can-do  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/highest-zone-of-the-tomb-supercelestial-sphere  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/central-zone-of-the-tomb-realm-of-nature-the-only-sphere-subject-to-time  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/right-man-salamander  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/angel-smiling-while-carrying-the-coffin-of-the-pope-angel-glad-that-the-soul-of-the-pope-had-been-received-among-the-blessed-spirits  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/venus-coelestis-amor-divinus  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/saint-paul-mens  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/victory-human-soul-in-state-of-freedom  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/beams-of-light---gods-word  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/moses-mens  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/man-reclining-on-terrestrial-world-human-mind-placed-between-the-fallacious-and-unreal-life-on-earth-and-the-celestial-realm  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/dove-holy-spirit  -- meaning: Belief
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/ibis-homo-carnalis  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/apollo-idolatry  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/mars-discord  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/cupid-amor-carnalis  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/jupiter-diana-mercury-saturn-as-superior-divinities-reason  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/venus-cupid-vulcan-lower-soul  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/pluto-avarice  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/torch-unholy-ardor  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/bacchus-folly  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/jupiter-pride  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/cupid-amor-carnalis  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/jupiter-minerva-mercury-saturn-as-superior-divinities-reason  -- meaning: Cultural reinterpretation
# http://icondataset.org/artists-expression - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/phaeton-the-presumptuous  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/face-of-a-young-man-the-future  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/phaeton-the-presumptuous  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/family-simple-happiness-of-primitive-civilization  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/face-of-an-old-man-the-past  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/face-of-an-adult-man-the-present  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/three-headed-companion-of-serapis-prudence  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/liver-seat-of-physical-passions  -- meaning: Artist's expression
# http://icondataset.org/iconographical-influence - http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone  -- meaning: Iconographical influence
# http://icondataset.org/iconographical-influence - http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold  -- meaning: Iconographical influence
# http://icondataset.org/iconographical-influence - http://icondataset.org/the-grace-turning-his-back-favor-conferred  -- meaning: Iconographical influence
# http://icondataset.org/attitude - http://icondataset.org/bull-christ  -- meaning: Attitude
# http://icondataset.org/attitude - http://icondataset.org/europa-human-soul  -- meaning: Attitude
# http://icondataset.org/cultural-influence - http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone  -- meaning: Cultural influence
# http://icondataset.org/cultural-influence - http://icondataset.org/pillow-idleness-and-lechery  -- meaning: Cultural influence
# http://icondataset.org/cultural-influence - http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood  -- meaning: Cultural influence
# http://icondataset.org/cultural-influence - http://icondataset.org/myrtle-love  -- meaning: Cultural influence
# http://icondataset.org/cultural-influence - http://icondataset.org/two-billing-doves-amorous-caresses  -- meaning: Cultural influence
# http://icondataset.org/societal-phenomenon - http://icondataset.org/mirror-introspection  -- meaning: societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/white-purity  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/glass-sphere-god  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/glass-sphere-heaven  -- meaning: societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/family-simple-happiness-of-primitive-civilization  -- meaning: societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/weighing-with-balance-allusion-to-last-judgement  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/young-mago-future-time  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/weighing-with-balance-weighing-of-souls  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/jewelry-earthly-goods  -- meaning: societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/heart-source-of-living-faith  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/blue-hue-of-heaven  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization  -- meaning: societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/blue-hue-of-heaven  -- meaning: societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/glass-sphere-heaven  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/family-simple-happiness-of-primitive-civilization  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/weighing-with-balance-allusion-to-last-judgement  -- meaning: societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/young-mago-future-time  -- meaning: societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/weighing-with-balance-weighing-of-souls  -- meaning: societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/jewelry-earthly-goods  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/heart-source-of-living-faith  -- meaning: societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/mirror-introspection  -- meaning: Societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/white-purity  -- meaning: societal phenomenon
# http://icondataset.org/societal-phenomenon - http://icondataset.org/glass-sphere-god  -- meaning: societal phenomenon

# %%
from collections import defaultdict , Counter

meanings_subjects = defaultdict(list)
# ?meaning ?artwork ?subj2
for row in cq2res:
  meanings_subjects[str(row['CFbroader'])].append(str(row['subj2']))

meanings_subjects_with_counts = {}
for k,v in meanings_subjects.items():
  for m,c in well_represented_phenomena_and_counts:
    if k == m:
      meanings_subjects_with_counts[k+" ("+c+")"] = dict(Counter(v).most_common())

# add count

meanings_subjects_with_counts
# Out:
# {'http://icondataset.org/reception-of-classical-antiquity (203)': {'http://icondataset.org/saturn': 16,
#   'http://icondataset.org/cupid': 14,
#   'http://icondataset.org/mercury': 11,
#   'http://icondataset.org/venus': 8,
#   'http://icondataset.org/apollo': 8,
#   'http://icondataset.org/jupiter': 8,
#   'http://icondataset.org/companion-of-serapis': 7,
#   'http://icondataset.org/the-constellation-hercules': 6,
#   'http://icondataset.org/blindfold-cupid': 5,
#   'http://icondataset.org/saturn-devouring-a-living-child': 5,
#   'http://icondataset.org/caduceus': 5,
#   'http://icondataset.org/the-three-graces': 4,
#   'http://icondataset.org/pluto': 4,
#   'http://icondataset.org/mary': 4,
#   'http://icondataset.org/bacchus': 4,
#   'http://icondataset.org/satyr': 4,
#   'http://icondataset.org/people/virgil': 4,
#   'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/death': 4,
#   'http://icondataset.org/vulcan': 3,
#   'http://icondataset.org/silenus': 3,
#   'http://icondataset.org/centaur': 3,
#   'http://icondataset.org/phaeton': 3,
#   'http://icondataset.org/hercules': 3,
#   'http://icondataset.org/mars': 3,
#   'http://icondataset.org/christ': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/the-constellation-perseus': 3,
#   'http://icondataset.org/truth': 3,
#   'http://icondataset.org/time-the-destroyer': 3,
#   'http://icondataset.org/dragon-biting-its-tail-time': 3,
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': 3,
#   'http://icondataset.org/three-headed-companion-of-serapis-prudence': 3,
#   'http://icondataset.org/argus': 2,
#   'http://icondataset.org/cerberus': 2,
#   'http://icondataset.org/saint-john-the-evangelist': 2,
#   'http://icondataset.org/europas-companions': 2,
#   'http://icondataset.org/prometheus': 2,
#   'http://icondataset.org/anteros': 2,
#   'http://icondataset.org/mithras': 2,
#   'http://icondataset.org/ariadne': 2,
#   'http://icondataset.org/polyxena': 2,
#   'http://icondataset.org/the-children-of-mercury': 2,
#   'http://icondataset.org/proserpina': 2,
#   'http://icondataset.org/the-abduction-of-europa': 2,
#   'http://icondataset.org/blood-sacrifice-of-animals': 2,
#   'http://icondataset.org/crucifixion': 2,
#   'http://icondataset.org/rape': 2,
#   'http://icondataset.org/death-steals-the-weapons-from-cupid-while-he-sleeps': 2,
#   'http://icondataset.org/algol-head-of-demon': 2,
#   'http://icondataset.org/mercurys-winged-sandals': 2,
#   'http://icondataset.org/time-the-revealer': 2,
#   'http://icondataset.org/time-ripa': 2,
#   'http://icondataset.org/sun': 2,
#   'http://icondataset.org/time-as-a-cosmic-power': 2,
#   'http://icondataset.org/moon': 2,
#   'http://icondataset.org/flora': 2,
#   'http://icondataset.org/bear-anger': 2,
#   'http://icondataset.org/dolphin-haste': 2,
#   'http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart': 2,
#   'http://icondataset.org/face-of-a-young-man-the-future': 2,
#   'http://icondataset.org/face-of-an-adult-man-the-present': 2,
#   'http://icondataset.org/face-of-an-old-man-the-past': 2,
#   'http://icondataset.org/cupid-amor-carnalis': 2,
#   'http://icondataset.org/owl-attribute-of-wisdom': 2,
#   'http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future': 2,
#   'http://icondataset.org/book-attribute-of-wisdom': 2,
#   'http://icondataset.org/phaeton-the-presumptuous': 2,
#   'http://icondataset.org/pygmalion': 1,
#   'http://icondataset.org/archangel-gabriel': 1,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/marine-snakes': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/sisyphus': 1,
#   'http://icondataset.org/muses': 1,
#   'http://icondataset.org/natural-venus': 1,
#   'http://icondataset.org/paris': 1,
#   'http://icondataset.org/the-resurrected': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/thymbraeus-son-of-laoocoon': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/the-children-of-saturn': 1,
#   'http://icondataset.org/saint-mark': 1,
#   'http://icondataset.org/aeneas': 1,
#   'http://icondataset.org/erato': 1,
#   'http://icondataset.org/dido': 1,
#   'http://icondataset.org/perseus': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/antiphas-son-of-laoocoon': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/orpheus': 1,
#   'http://icondataset.org/prophet': 1,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/rachel': 1,
#   'http://icondataset.org/david': 1,
#   'http://icondataset.org/simeon': 1,
#   'http://icondataset.org/apollo-medicus-or-aesculapius': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/serapis': 1,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/helen': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/tityus': 1,
#   'http://icondataset.org/laocoon': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/lapiths': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/rhea': 1,
#   'http://icondataset.org/eve': 1,
#   'http://icondataset.org/venus-pudica': 1,
#   'http://icondataset.org/tantalus': 1,
#   'http://icondataset.org/leach': 1,
#   'http://icondataset.org/christ-as-a-child': 1,
#   'http://icondataset.org/roman-emperors': 1,
#   'http://icondataset.org/people/saint-luke': 1,
#   'http://icondataset.org/god': 1,
#   'http://icondataset.org/female-pan': 1,
#   'http://icondataset.org/ixion': 1,
#   'http://icondataset.org/aion/phanes': 1,
#   'http://icondataset.org/dieu-amour': 1,
#   'http://icondataset.org/sybil': 1,
#   'http://icondataset.org/amorini-pointing-out-to-death-her-first-victims': 1,
#   'http://icondataset.org/sun-moves-his-chariot-through-the-zodiac': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/ixion-on-his-wheel': 1,
#   'http://icondataset.org/mithras-killing-the-bull': 1,
#   'http://icondataset.org/pygmalion-dressing-his-statue': 1,
#   'http://icondataset.org/era-sub-prometheo': 1,
#   'http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion': 1,
#   'http://icondataset.org/sacrifice-of-a-bull': 1,
#   'http://icondataset.org/innocence-threatened-by-the-powers-of-evil': 1,
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/joseph-cast-into-the-pit': 1,
#   'http://icondataset.org/paris-rapes-helen': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/love-shooting-the-foolish': 1,
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/simeon-witnesses-the-presentation-of-christ': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/lamentation-of-christ': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water': 1,
#   'http://icondataset.org/time-devouring-the-past': 1,
#   'http://icondataset.org/battle-of-lapiths-and-centaurs': 1,
#   'http://icondataset.org/prometheus-animates-man': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/love-shooting-the-wise-man': 1,
#   'http://icondataset.org/god-creating-the-universe': 1,
#   'http://icondataset.org/prometheus-is-punished': 1,
#   'http://icondataset.org/three-corpses-warn-three-gentlemen-against-their-thoughtless-enjoyment-of-life': 1,
#   'http://icondataset.org/resurrection-of-christ': 1,
#   'http://icondataset.org/triumph-of-love': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/mithras-twisting-the-horns-of-a-bull': 1,
#   'http://icondataset.org/tower-of-chastity': 1,
#   'http://icondataset.org/jupiter-planet': 1,
#   'http://icondataset.org/torso-del-belvedere': 1,
#   'http://icondataset.org/the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/hearts-of-cupids-victims': 1,
#   'http://icondataset.org/mercury-planet': 1,
#   'http://icondataset.org/saturn-planet': 1,
#   'http://icondataset.org/lion-zodiacal-sign': 1,
#   'http://icondataset.org/apollonian-swan': 1,
#   'http://icondataset.org/mars-planet': 1,
#   'http://icondataset.org/medusas-head': 1,
#   'http://icondataset.org/venus-planet': 1,
#   'http://icondataset.org/moon-planet': 1,
#   'http://icondataset.org/torch-of-prometheus': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/planimetrical-scheme-of-the-celestial-spheres': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/north-pole-sky': 1,
#   'http://icondataset.org/aion/phanes-as-personification-of-eternal-time': 1,
#   'http://icondataset.org/justice': 1,
#   'http://icondataset.org/oceanus': 1,
#   'http://icondataset.org/sleep': 1,
#   'http://icondataset.org/three-stages-of-human-life': 1,
#   'http://icondataset.org/fortune': 1,
#   'http://icondataset.org/zephir': 1,
#   'http://icondataset.org/kairos': 1,
#   'http://icondataset.org/amor-carnalis': 1,
#   'http://icondataset.org/amor-divino': 1,
#   'http://icondataset.org/time-as-universal-cosmic-principle': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/tellus': 1,
#   'http://icondataset.org/labour': 1,
#   'http://icondataset.org/hope': 1,
#   'http://icondataset.org/the-twins-constellation': 1,
#   'http://icondataset.org/love': 1,
#   'http://icondataset.org/the-virgin-constellation': 1,
#   'http://icondataset.org/river-alpheus': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/innocence': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/luxury': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/faith': 1,
#   'http://icondataset.org/penitentia': 1,
#   'http://icondataset.org/ardor': 1,
#   'http://icondataset.org/the-constellation-eridanus': 1,
#   'http://icondataset.org/amor': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/wealth': 1,
#   'http://icondataset.org/atlas': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/sun-on-his-chariot': 1,
#   'http://icondataset.org/poverty': 1,
#   'http://icondataset.org/good-counsel': 1,
#   'http://icondataset.org/spring': 1,
#   'http://icondataset.org/monk-vita-contemplativa': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/desolate-scenery-destructive-power-of-time': 1,
#   'http://icondataset.org/bundle-of-sticks-unity': 1,
#   'http://icondataset.org/fire-fire-to-burn-the-time': 1,
#   'http://icondataset.org/deer-souls': 1,
#   'http://icondataset.org/soap-bubbles-futility': 1,
#   'http://icondataset.org/hourglass-transience': 1,
#   'http://icondataset.org/natural-venus-amor-humanus': 1,
#   'http://icondataset.org/tombs-christian-rite-of-burial': 1,
#   'http://icondataset.org/wolf-greed': 1,
#   'http://icondataset.org/apollo-idolatry': 1,
#   'http://icondataset.org/venus-coelestis-amor-divinus': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1,
#   'http://icondataset.org/mars-discord': 1,
#   'http://icondataset.org/dragoon-devil': 1,
#   'http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1,
#   'http://icondataset.org/carrying-on-shoulders-saving-souls': 1,
#   'http://icondataset.org/torch-unholy-ardor': 1,
#   'http://icondataset.org/stepping-on-defeating-devil': 1,
#   'http://icondataset.org/roses-pleasures-of-permanent-congeniality': 1,
#   'http://icondataset.org/ibis-homo-carnalis': 1,
#   'http://icondataset.org/mouse-all-devouring-time': 1,
#   'http://icondataset.org/europa-human-soul': 1,
#   'http://icondataset.org/urns-pagan-custom-of-cremation': 1,
#   'http://icondataset.org/fly-decade': 1,
#   'http://icondataset.org/three-books-three-forms-of-time-past-present-future': 1,
#   'http://icondataset.org/mercury-discursive-reason:-limitations-and-possibilities-of-what-human-reason-can-do': 1,
#   'http://icondataset.org/skull-death-personified': 1,
#   'http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening': 1,
#   'http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love': 1,
#   'http://icondataset.org/bull-christ': 1,
#   'http://icondataset.org/lyre-fashioned-from-a-stags-head-low-class-and-uncouth-music': 1,
#   'http://icondataset.org/shepherdess-amorous-implications-of-the-arcadian-milieu': 1,
#   'http://icondataset.org/four-wings-four-seasons': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/serpent-perfidy': 1,
#   'http://icondataset.org/bowl-on-a-book-wisdom': 1,
#   'http://icondataset.org/tantalus-avarice': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life': 1,
#   'http://icondataset.org/ixion-lewdness': 1,
#   'http://icondataset.org/satyr-egyptian-desert-wilderness': 1,
#   'http://icondataset.org/liver-seat-of-physical-passions': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-affection-changes-with-luck': 1,
#   'http://icondataset.org/hercules-egypt': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/jupiter-pride': 1,
#   'http://icondataset.org/bacchus-folly': 1,
#   'http://icondataset.org/pluto-avarice': 1,
#   'http://icondataset.org/mercury-discursive-reason': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1,
#   'http://icondataset.org/dog-envy': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/lion-fury': 1,
#   'http://icondataset.org/mercury-turning-his-back-to-the-realm-of-the-natural-venus-the-discursive-reason-is-not-involved-in-the-activities-of-the-natural-venus': 1,
#   'http://icondataset.org/face-of-an-old-woman-the-past': 1,
#   'http://icondataset.org/myrtle-everlasting-love': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/glass-sphere-harmony-that-can-be-easily-broken': 1,
#   'http://icondataset.org/sisyphus-pride': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/serpent-attribute-of-wisdom': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/face-of-an-adult-woman-the-present': 1,
#   'http://icondataset.org/face-of-a-young-woman-the-future': 1},
#  'http://icondataset.org/iconographical-evolution (115)': {'http://icondataset.org/saturn': 16,
#   'http://icondataset.org/cupid': 14,
#   'http://icondataset.org/companion-of-serapis': 8,
#   'http://icondataset.org/blindfold-cupid': 6,
#   'http://icondataset.org/apollo': 6,
#   'http://icondataset.org/venus': 6,
#   'http://icondataset.org/mercury': 5,
#   'http://icondataset.org/saturn-devouring-a-living-child': 5,
#   'http://icondataset.org/death': 5,
#   'http://icondataset.org/truth': 5,
#   'http://icondataset.org/people/virgil': 4,
#   'http://icondataset.org/christ': 4,
#   'http://icondataset.org/time-the-destroyer': 4,
#   'http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future': 4,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/eros-as-the-great-force-ruling-over-the-instincts-of-gods-man-and-animals': 3,
#   'http://icondataset.org/three-headed-companion-of-serapis-prudence': 3,
#   'http://icondataset.org/dragon-biting-its-tail-time': 3,
#   'http://icondataset.org/the-children-of-saturn': 2,
#   'http://icondataset.org/mercury-hermes': 2,
#   'http://icondataset.org/mithras': 2,
#   'http://icondataset.org/anteros': 2,
#   'http://icondataset.org/olympian-gods': 2,
#   'http://icondataset.org/argus': 2,
#   'http://icondataset.org/bacchus': 2,
#   'http://icondataset.org/aglauros': 2,
#   'http://icondataset.org/the-three-graces': 2,
#   'http://icondataset.org/saint-theodora-of-alexandria': 2,
#   'http://icondataset.org/zeus': 2,
#   'http://icondataset.org/death-steals-the-weapons-from-cupid-while-he-sleeps': 2,
#   'http://icondataset.org/blood-sacrifice-of-animals': 2,
#   'http://icondataset.org/mercurys-winged-sandals': 2,
#   'http://icondataset.org/caduceus': 2,
#   'http://icondataset.org/medusas-head': 2,
#   'http://icondataset.org/poverty': 2,
#   'http://icondataset.org/time-as-a-cosmic-power': 2,
#   'http://icondataset.org/time-ripa': 2,
#   'http://icondataset.org/fortune': 2,
#   'http://icondataset.org/the-constellation-perseus': 2,
#   'http://icondataset.org/time-the-revealer': 2,
#   'http://icondataset.org/amor-carnalis': 2,
#   'http://icondataset.org/bear-anger': 2,
#   'http://icondataset.org/owl-attribute-of-wisdom': 2,
#   'http://icondataset.org/book-attribute-of-wisdom': 2,
#   'http://icondataset.org/face-of-an-old-man-the-past': 2,
#   'http://icondataset.org/face-of-an-adult-man-the-present': 2,
#   'http://icondataset.org/dolphin-haste': 2,
#   'http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart': 2,
#   'http://icondataset.org/face-of-a-young-man-the-future': 2,
#   'http://icondataset.org/apostles': 1,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/dieu-amour': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/apollo-medicus-or-aesculapius': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/pluto': 1,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/devil': 1,
#   'http://icondataset.org/athene': 1,
#   'http://icondataset.org/serapis': 1,
#   'http://icondataset.org/perseus': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/aion/phanes': 1,
#   'http://icondataset.org/jest': 1,
#   'http://icondataset.org/orpheus': 1,
#   'http://icondataset.org/the-children-of-mercury': 1,
#   'http://icondataset.org/silenus': 1,
#   'http://icondataset.org/gods-hand': 1,
#   'http://icondataset.org/herse': 1,
#   'http://icondataset.org/rhea': 1,
#   'http://icondataset.org/venus-pudica': 1,
#   'http://icondataset.org/saint-john-the-evangelist': 1,
#   'http://icondataset.org/europas-companions': 1,
#   'http://icondataset.org/love-shooting-the-foolish': 1,
#   'http://icondataset.org/cupid-unblinding-himself': 1,
#   'http://icondataset.org/amorini-pointing-out-to-death-her-first-victims': 1,
#   'http://icondataset.org/innocence-threatened-by-the-powers-of-evil': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/sun-moves-his-chariot-through-the-zodiac': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/sacrifice-of-a-bull': 1,
#   'http://icondataset.org/three-corpses-warn-three-gentlemen-against-their-thoughtless-enjoyment-of-life': 1,
#   'http://icondataset.org/death-disembowelling-her-victim': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/triumph-of-love': 1,
#   'http://icondataset.org/mithras-twisting-the-horns-of-a-bull': 1,
#   'http://icondataset.org/crucifixion': 1,
#   'http://icondataset.org/resurrection-of-christ': 1,
#   'http://icondataset.org/mithras-killing-the-bull': 1,
#   'http://icondataset.org/era-sub-vulcano': 1,
#   'http://icondataset.org/the-abduction-of-europa': 1,
#   'http://icondataset.org/time-devouring-the-past': 1,
#   'http://icondataset.org/love-shooting-the-wise-man': 1,
#   'http://icondataset.org/mercury-planet': 1,
#   'http://icondataset.org/lion-zodiacal-sign': 1,
#   'http://icondataset.org/saturn-planet': 1,
#   'http://icondataset.org/tower-of-chastity': 1,
#   'http://icondataset.org/jupiter-planet': 1,
#   'http://icondataset.org/implements-of-the-holy-mass': 1,
#   'http://icondataset.org/hearts-of-cupids-victims': 1,
#   'http://icondataset.org/torso-del-belvedere': 1,
#   'http://icondataset.org/love-stricken-soul': 1,
#   'http://icondataset.org/celestial-map': 1,
#   'http://icondataset.org/venus-planet': 1,
#   'http://icondataset.org/moon-planet': 1,
#   'http://icondataset.org/mars-planet': 1,
#   'http://icondataset.org/planimetrical-scheme-of-the-celestial-spheres': 1,
#   'http://icondataset.org/north-pole-sky': 1,
#   'http://icondataset.org/sun': 1,
#   'http://icondataset.org/amor-divino': 1,
#   'http://icondataset.org/moon': 1,
#   'http://icondataset.org/time-as-universal-cosmic-principle': 1,
#   'http://icondataset.org/three-stages-of-human-life': 1,
#   'http://icondataset.org/labour': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/ardor': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/river-alpheus': 1,
#   'http://icondataset.org/life': 1,
#   'http://icondataset.org/blind-death': 1,
#   'http://icondataset.org/justice': 1,
#   'http://icondataset.org/penitentia': 1,
#   'http://icondataset.org/aion/phanes-as-personification-of-eternal-time': 1,
#   'http://icondataset.org/good-counsel': 1,
#   'http://icondataset.org/church': 1,
#   'http://icondataset.org/the-constellation-eridanus': 1,
#   'http://icondataset.org/blind-night': 1,
#   'http://icondataset.org/evil-effects-of-love': 1,
#   'http://icondataset.org/mockery': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/oceanus': 1,
#   'http://icondataset.org/mourning': 1,
#   'http://icondataset.org/kairos': 1,
#   'http://icondataset.org/wealth': 1,
#   'http://icondataset.org/sun-on-his-chariot': 1,
#   'http://icondataset.org/innocence': 1,
#   'http://icondataset.org/platonic-love': 1,
#   'http://icondataset.org/the-constellation-hercules': 1,
#   'http://icondataset.org/the-virgin-constellation': 1,
#   'http://icondataset.org/the-constellation-orion': 1,
#   'http://icondataset.org/synagogue': 1,
#   'http://icondataset.org/earth': 1,
#   'http://icondataset.org/chastity': 1,
#   'http://icondataset.org/the-constellation-hercules-engonasin': 1,
#   'http://icondataset.org/tellus': 1,
#   'http://icondataset.org/luxury': 1,
#   'http://icondataset.org/amor': 1,
#   'http://icondataset.org/flora': 1,
#   'http://icondataset.org/nude-prudence': 1,
#   'http://icondataset.org/cupid-unblindfolding-himself-cupid-transforming-himself-from-a-personification-of-blind-ignoble-love-to-an-exponent-of-seeing-platonic-love': 1,
#   'http://icondataset.org/branches-of-a-tree-antidotes-against-sexual-passion-marriage-prayer-business-abstinence': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1,
#   'http://icondataset.org/skull-death-personified': 1,
#   'http://icondataset.org/carrying-on-shoulders-saving-souls': 1,
#   'http://icondataset.org/head-of-a-dog-the-future': 1,
#   'http://icondataset.org/three-books-three-forms-of-time-past-present-future': 1,
#   'http://icondataset.org/mouse-all-devouring-time': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/fly-decade': 1,
#   'http://icondataset.org/desolate-scenery-destructive-power-of-time': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/monk-vita-contemplativa': 1,
#   'http://icondataset.org/bowl-on-a-book-wisdom': 1,
#   'http://icondataset.org/fire-fire-to-burn-the-time': 1,
#   'http://icondataset.org/soap-bubbles-futility': 1,
#   'http://icondataset.org/head-of-a-lion-the-present': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1,
#   'http://icondataset.org/hourglass-transience': 1,
#   'http://icondataset.org/head-of-a-wolf-the-past': 1,
#   'http://icondataset.org/wolf-greed': 1,
#   'http://icondataset.org/dragoon-devil': 1,
#   'http://icondataset.org/venus-coelestis-amor-divinus': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/stepping-on-defeating-devil': 1,
#   'http://icondataset.org/face-of-an-old-woman-the-past': 1,
#   'http://icondataset.org/face-of-a-young-woman-the-future': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/lion-fury': 1,
#   'http://icondataset.org/face-of-an-adult-woman-the-present': 1,
#   'http://icondataset.org/serpent-attribute-of-wisdom': 1,
#   'http://icondataset.org/deer-souls': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/four-wings-four-seasons': 1,
#   'http://icondataset.org/serpent-perfidy': 1,
#   'http://icondataset.org/shepherdess-amorous-implications-of-the-arcadian-milieu': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-affection-changes-with-luck': 1,
#   'http://icondataset.org/dog-envy': 1},
#  'http://icondataset.org/formal-or-stylistic-evolution (87)': {'http://icondataset.org/mercury': 8,
#   'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/saturn': 3,
#   'http://icondataset.org/apollo': 3,
#   'http://icondataset.org/the-three-graces': 3,
#   'http://icondataset.org/centaur': 3,
#   'http://icondataset.org/people/virgil': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/caduceus': 3,
#   'http://icondataset.org/argus': 2,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/polyxena': 2,
#   'http://icondataset.org/ariadne': 2,
#   'http://icondataset.org/pluto': 2,
#   'http://icondataset.org/the-children-of-mercury': 2,
#   'http://icondataset.org/silenus': 2,
#   'http://icondataset.org/cerberus': 2,
#   'http://icondataset.org/proserpina': 2,
#   'http://icondataset.org/europas-companions': 2,
#   'http://icondataset.org/bacchus': 2,
#   'http://icondataset.org/rape': 2,
#   'http://icondataset.org/the-abduction-of-europa': 2,
#   'http://icondataset.org/saint-john-the-evangelist': 1,
#   'http://icondataset.org/prometheus': 1,
#   'http://icondataset.org/jupiter': 1,
#   'http://icondataset.org/david': 1,
#   'http://icondataset.org/bishop-simone-saltarelli': 1,
#   'http://icondataset.org/laocoon': 1,
#   'http://icondataset.org/pygmalion': 1,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/the-resurrected': 1,
#   'http://icondataset.org/thymbraeus-son-of-laoocoon': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/aeneas': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/mary': 1,
#   'http://icondataset.org/dido': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/venus': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/antiphas-son-of-laoocoon': 1,
#   'http://icondataset.org/paris': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/lapiths': 1,
#   'http://icondataset.org/helen': 1,
#   'http://icondataset.org/marine-snakes': 1,
#   'http://icondataset.org/companion-of-serapis': 1,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/presbyter-bruno': 1,
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/lamentation-of-christ': 1,
#   'http://icondataset.org/era-sub-prometheo': 1,
#   'http://icondataset.org/prometheus-is-punished': 1,
#   'http://icondataset.org/battle-of-lapiths-and-centaurs': 1,
#   'http://icondataset.org/paris-rapes-helen': 1,
#   'http://icondataset.org/pygmalion-dressing-his-statue': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/crucifixion': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/presbyter-bruno-mourned-by-beggars-whom-he-had-supported-during-his-life': 1,
#   'http://icondataset.org/the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/torch-of-prometheus': 1,
#   'http://icondataset.org/implements-of-the-holy-mass': 1,
#   'http://icondataset.org/temple-of-solomon': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/truth': 1,
#   'http://icondataset.org/the-constellation-hercules': 1,
#   'http://icondataset.org/sun': 1,
#   'http://icondataset.org/the-virgin-constellation': 1,
#   'http://icondataset.org/moon': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1,
#   'http://icondataset.org/urns-pagan-custom-of-cremation': 1,
#   'http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/tombs-christian-rite-of-burial': 1,
#   'http://icondataset.org/temple-of-solomon-ornate-as-a-church-correlation-between-the-old-testament-and-the-new': 1,
#   'http://icondataset.org/dragon-biting-its-tail-time': 1,
#   'http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/bull-christ': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/europa-human-soul': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1},
#  'http://icondataset.org/formal-or-stylistic-phenomenon (59)': {'http://icondataset.org/mary': 2,
#   'http://icondataset.org/christ': 2,
#   'http://icondataset.org/archangel-gabriel': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/europas-companions': 1,
#   'http://icondataset.org/apostles': 1,
#   'http://icondataset.org/apollo-medicus-or-aesculapius': 1,
#   'http://icondataset.org/apollo': 1,
#   'http://icondataset.org/paris': 1,
#   'http://icondataset.org/hespontine-sibyl': 1,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/helen': 1,
#   'http://icondataset.org/simeon': 1,
#   'http://icondataset.org/saint-john-the-evangelist': 1,
#   'http://icondataset.org/the-resurrected': 1,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/saint-mark': 1,
#   'http://icondataset.org/christ-as-a-child': 1,
#   'http://icondataset.org/son-of-the-widow-of-nain': 1,
#   'http://icondataset.org/saint-anne': 1,
#   'http://icondataset.org/joachim': 1,
#   'http://icondataset.org/paris-rapes-helen': 1,
#   'http://icondataset.org/the-abduction-of-europa': 1,
#   'http://icondataset.org/christ-resurrects-the-son-of-nain': 1,
#   'http://icondataset.org/lamentation-of-christ': 1,
#   'http://icondataset.org/simeon-witnesses-the-presentation-of-christ': 1,
#   'http://icondataset.org/apparition-of-christ': 1,
#   'http://icondataset.org/temple-of-solomon': 1,
#   'http://icondataset.org/city-of-nain': 1,
#   'http://icondataset.org/the-twins-constellation': 1,
#   'http://icondataset.org/atlas': 1,
#   'http://icondataset.org/temple-of-solomon-ornate-as-a-church-correlation-between-the-old-testament-and-the-new': 1,
#   'http://icondataset.org/urns-pagan-custom-of-cremation': 1,
#   'http://icondataset.org/tombs-christian-rite-of-burial': 1},
#  'http://icondataset.org/iconographical-interpretation (51)': {'http://icondataset.org/cupid': 10,
#   'http://icondataset.org/saturn': 7,
#   'http://icondataset.org/jupiter': 6,
#   'http://icondataset.org/saturn-devouring-a-living-child': 5,
#   'http://icondataset.org/satyr': 4,
#   'http://icondataset.org/vulcan': 4,
#   'http://icondataset.org/blindfold-cupid': 4,
#   'http://icondataset.org/venus': 4,
#   'http://icondataset.org/phaeton': 3,
#   'http://icondataset.org/apollo': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/era-sub-vulcano': 3,
#   'http://icondataset.org/time-the-destroyer': 3,
#   'http://icondataset.org/truth': 3,
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': 3,
#   'http://icondataset.org/dragon-biting-its-tail-time': 3,
#   'http://icondataset.org/bacchus': 2,
#   'http://icondataset.org/hercules': 2,
#   'http://icondataset.org/centaur': 2,
#   'http://icondataset.org/mercury': 2,
#   'http://icondataset.org/silenus': 2,
#   'http://icondataset.org/mithras': 2,
#   'http://icondataset.org/death-steals-the-weapons-from-cupid-while-he-sleeps': 2,
#   'http://icondataset.org/blood-sacrifice-of-animals': 2,
#   'http://icondataset.org/time-the-revealer': 2,
#   'http://icondataset.org/time-ripa': 2,
#   'http://icondataset.org/death': 2,
#   'http://icondataset.org/phaeton-the-presumptuous': 2,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/tantalus': 1,
#   'http://icondataset.org/minerva': 1,
#   'http://icondataset.org/thymbraeus-son-of-laoocoon': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/female-pan': 1,
#   'http://icondataset.org/angels': 1,
#   'http://icondataset.org/geminae-veneres': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/venus-verticordia': 1,
#   'http://icondataset.org/laocoon': 1,
#   'http://icondataset.org/saint-paul': 1,
#   'http://icondataset.org/ixion': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/venus-vulgaris': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/marine-snakes': 1,
#   'http://icondataset.org/pluto': 1,
#   'http://icondataset.org/muses': 1,
#   'http://icondataset.org/sisyphus': 1,
#   'http://icondataset.org/devil': 1,
#   'http://icondataset.org/erato': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/diana': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/anteros': 1,
#   'http://icondataset.org/fedro': 1,
#   'http://icondataset.org/antiphas-son-of-laoocoon': 1,
#   'http://icondataset.org/the-three-graces': 1,
#   'http://icondataset.org/tityus': 1,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/innocence-threatened-by-the-powers-of-evil': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/mithras-twisting-the-horns-of-a-bull': 1,
#   'http://icondataset.org/time-devouring-the-past': 1,
#   'http://icondataset.org/cupid-unblinding-himself': 1,
#   'http://icondataset.org/mithras-killing-the-bull': 1,
#   'http://icondataset.org/ixion-on-his-wheel': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/joseph-cast-into-the-pit': 1,
#   'http://icondataset.org/sacrifice-of-a-bull': 1,
#   'http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion': 1,
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill': 1,
#   'http://icondataset.org/apollonian-swan': 1,
#   'http://icondataset.org/sella-gestatoria': 1,
#   'http://icondataset.org/caduceus': 1,
#   'http://icondataset.org/love-stricken-soul': 1,
#   'http://icondataset.org/flame-of-divine-wisdom': 1,
#   'http://icondataset.org/torso-del-belvedere': 1,
#   'http://icondataset.org/mercurys-winged-sandals': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/paysage-moralise': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/voluptas': 1,
#   'http://icondataset.org/contemplative-mind': 1,
#   'http://icondataset.org/amor-divino': 1,
#   'http://icondataset.org/platonic-love': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/innocence': 1,
#   'http://icondataset.org/grace-pulchritudo': 1,
#   'http://icondataset.org/victories': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/mockery': 1,
#   'http://icondataset.org/evil-effects-of-love': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/chastity': 1,
#   'http://icondataset.org/justice': 1,
#   'http://icondataset.org/faith': 1,
#   'http://icondataset.org/three-graces-three-aspects-of-venus': 1,
#   'http://icondataset.org/hope': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/beauty': 1,
#   'http://icondataset.org/marital-affection': 1,
#   'http://icondataset.org/love': 1,
#   'http://icondataset.org/mourning': 1,
#   'http://icondataset.org/fortune': 1,
#   'http://icondataset.org/amor-carnalis': 1,
#   'http://icondataset.org/poverty': 1,
#   'http://icondataset.org/tantalus-avarice': 1,
#   'http://icondataset.org/branches-of-a-tree-antidotes-against-sexual-passion-marriage-prayer-business-abstinence': 1,
#   'http://icondataset.org/wolf-greed': 1,
#   'http://icondataset.org/glass-sphere-harmony-that-can-be-easily-broken': 1,
#   'http://icondataset.org/angel-wepting-while-carrying-the-coffin-of-the-pope-angel-grieved-that-the-world-had-been-deprived-of-such-a-man': 1,
#   'http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life': 1,
#   'http://icondataset.org/ixion-lewdness': 1,
#   'http://icondataset.org/saint-paul-mens': 1,
#   'http://icondataset.org/myrtle-everlasting-love': 1,
#   'http://icondataset.org/hercules-egypt': 1,
#   'http://icondataset.org/jupiter-minerva-mercury-saturn-as-superior-divinities-reason': 1,
#   'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom': 1,
#   'http://icondataset.org/hares-animal-love-fertility': 1,
#   'http://icondataset.org/lion-fury': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/cameo-with-a-pair-of-winged-horses-and-a-charioteer-platos-immortal-comparison-of-the-human-soul': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-affection-changes-with-luck': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/liver-seat-of-physical-passions': 1,
#   'http://icondataset.org/victory-human-soul-in-state-of-freedom': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/venus-coelestis-principle-of-universal-and-eternal-but-purely-intelligible-beauty': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/angel-smiling-while-carrying-the-coffin-of-the-pope-angel-glad-that-the-soul-of-the-pope-had-been-received-among-the-blessed-spirits': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1,
#   'http://icondataset.org/dog-envy': 1,
#   'http://icondataset.org/four-wings-four-seasons': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/venus-cupid-vulcan-lower-soul': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/serpent-perfidy': 1,
#   'http://icondataset.org/sisyphus-pride': 1,
#   'http://icondataset.org/moses-mens': 1,
#   'http://icondataset.org/cupid-unblindfolding-himself-cupid-transforming-himself-from-a-personification-of-blind-ignoble-love-to-an-exponent-of-seeing-platonic-love': 1,
#   'http://icondataset.org/jupiter-diana-mercury-saturn-as-superior-divinities-reason': 1,
#   'http://icondataset.org/cupid-between-venus-coelestis-and-venus-vulgaris-love-acts-as-an-intermediary-between-heaven-and-earth': 1,
#   'http://icondataset.org/bundle-of-sticks-unity': 1,
#   'http://icondataset.org/roses-pleasures-of-permanent-congeniality': 1,
#   'http://icondataset.org/desolate-scenery-destructive-power-of-time': 1,
#   'http://icondataset.org/lyre-fashioned-from-a-stags-head-low-class-and-uncouth-music': 1,
#   'http://icondataset.org/sarcophagus-converted-in-a-spring-of-life-vis-generandi': 1,
#   'http://icondataset.org/satyr-egyptian-desert-wilderness': 1,
#   'http://icondataset.org/venus-vulgaris-generative-force-that-creates-the-perishable-but-visible-and-tangible-images-of-beauty-of-earth': 1,
#   'http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love': 1},
#  'http://icondataset.org/tendency (39)': {'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/mary': 3,
#   'http://icondataset.org/centaur': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/ariadne': 2,
#   'http://icondataset.org/christ': 2,
#   'http://icondataset.org/bacchus': 2,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/silenus': 2,
#   'http://icondataset.org/prophet': 1,
#   'http://icondataset.org/sisyphus': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/prometheus': 1,
#   'http://icondataset.org/giuliano-de-medici': 1,
#   'http://icondataset.org/europas-companions': 1,
#   'http://icondataset.org/rachel': 1,
#   'http://icondataset.org/apollo': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/votary-of-saturn': 1,
#   'http://icondataset.org/aeneas': 1,
#   'http://icondataset.org/simeon': 1,
#   'http://icondataset.org/people/lorenzo-de-medici': 1,
#   'http://icondataset.org/dido': 1,
#   'http://icondataset.org/lapiths': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/tantalus': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/the-resurrected': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/saint-john-the-evangelist': 1,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/votary-of-jupiter': 1,
#   'http://icondataset.org/sybil': 1,
#   'http://icondataset.org/ixion': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/christ-as-a-child': 1,
#   'http://icondataset.org/leach': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/the-abduction-of-europa': 1,
#   'http://icondataset.org/ixion-on-his-wheel': 1,
#   'http://icondataset.org/battle-of-lapiths-and-centaurs': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/era-sub-prometheo': 1,
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill': 1,
#   'http://icondataset.org/simeon-witnesses-the-presentation-of-christ': 1,
#   'http://icondataset.org/gesture-of-saturnian-silence': 1,
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/prometheus-is-punished': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/torch-of-prometheus': 1,
#   'http://icondataset.org/the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/nude-prudence': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening': 1,
#   'http://icondataset.org/princely-sceptre-jovial-magnanimity': 1,
#   'http://icondataset.org/carrying-on-shoulders-saving-souls': 1,
#   'http://icondataset.org/stepping-on-defeating-devil': 1,
#   'http://icondataset.org/dragoon-devil': 1,
#   'http://icondataset.org/closed-cash-box-saturninian-parsimony': 1,
#   'http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind': 1,
#   'http://icondataset.org/bat-melancholy': 1,
#   'http://icondataset.org/ixion-lewdness': 1,
#   'http://icondataset.org/tantalus-avarice': 1,
#   'http://icondataset.org/deer-souls': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/tombs-christian-rite-of-burial': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/sisyphus-pride': 1,
#   'http://icondataset.org/urns-pagan-custom-of-cremation': 1},
#  'http://icondataset.org/belief (30)': {'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/erection-of-primitive-buildings': 3,
#   'http://icondataset.org/era-sub-vulcano': 3,
#   'http://icondataset.org/mercury': 2,
#   'http://icondataset.org/centaur': 2,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/cupid': 2,
#   'http://icondataset.org/mary': 2,
#   'http://icondataset.org/the-children-of-saturn': 2,
#   'http://icondataset.org/archangel-gabriel': 2,
#   'http://icondataset.org/archangel-gabriel-pronounces-the-ave-maria': 2,
#   'http://icondataset.org/mary-welcomes-the-holy-spirit': 2,
#   'http://icondataset.org/two-out-of-the-four-times-of-day': 2,
#   'http://icondataset.org/flora': 2,
#   'http://icondataset.org/two-out-of-the-four-rivers-of-hades': 2,
# ...
#   'http://icondataset.org/four-times-of-day-realm-of-nature': 2,
#   'http://icondataset.org/lowest-zone-of-the-tomb-realm-of-sheer-matter': 2,
#   'http://icondataset.org/four-rivers-of-hades-fourfold-aspect-of-matter-as-a-source-of-potential-evil': 2,
#   'http://icondataset.org/highest-zone-of-the-tomb-supercelestial-sphere': 2,
#   'http://icondataset.org/four-times-of-day-four-humours': 2,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/angels': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/the-three-graces': 1,
#   'http://icondataset.org/natural-venus': 1,
#   'http://icondataset.org/the-children-of-mercury': 1,
#   'http://icondataset.org/venus-pudica': 1,
#   'http://icondataset.org/unconsciuous-creatures': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/people/lorenzo-de-medici': 1,
#   'http://icondataset.org/planetary-deities': 1,
#   'http://icondataset.org/crocodile': 1,
#   'http://icondataset.org/silenus': 1,
#   'http://icondataset.org/salamander': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/bacchus': 1,
#   'http://icondataset.org/giuliano-de-medici': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/saturn': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/saint-paul': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/god': 1,
#   'http://icondataset.org/the-children-of-each-planet': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/dream-vision': 1,
#   'http://icondataset.org/caduceus': 1,
#   'http://icondataset.org/sella-gestatoria': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/aurora': 1,
#   'http://icondataset.org/crepuscolo': 1,
#   'http://icondataset.org/zephir': 1,
#   'http://icondataset.org/personification-of-the-natural-forces-stimulating-the-action-of-the-unconscious-creatures': 1,
#   'http://icondataset.org/day': 1,
#   'http://icondataset.org/human-mind': 1,
#   'http://icondataset.org/night': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/spring': 1,
#   'http://icondataset.org/seven-capital-sins': 1,
#   'http://icondataset.org/the-right': 1,
#   'http://icondataset.org/victories': 1,
#   'http://icondataset.org/virtue': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/masks-fallacy-deceit': 1,
#   'http://icondataset.org/natural-venus-amor-humanus': 1,
#   'http://icondataset.org/blowing-in-a-tube-fertilising': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/fire-luxury': 1,
#   'http://icondataset.org/archers-without-arrows-tools-of-a-force-beyond-their-will-and-consciousness': 1,
#   'http://icondataset.org/monk-vita-contemplativa': 1,
#   'http://icondataset.org/mercury-discursive-reason': 1,
#   'http://icondataset.org/trophies-ultimate-triumph-over-the-lower-forms-of-existence': 1,
#   'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom': 1,
#   'http://icondataset.org/angel-wepting-while-carrying-the-coffin-of-the-pope-angel-grieved-that-the-world-had-been-deprived-of-such-a-man': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/children-crouching-down-unborn-souls-doomed-to-descend-to-the-lower-spheres': 1,
#   'http://icondataset.org/flying-towards-marys-head-to-fertilise': 1,
#   'http://icondataset.org/sleeping-cupid-natural-desire-has-nothing-to-do-with-love': 1,
#   'http://icondataset.org/mercury-turning-his-back-to-the-realm-of-the-natural-venus-the-discursive-reason-is-not-involved-in-the-activities-of-the-natural-venus': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/white-lilium-virginity': 1,
#   'http://icondataset.org/mercury-discursive-reason:-limitations-and-possibilities-of-what-human-reason-can-do': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/right-man-salamander': 1,
#   'http://icondataset.org/angel-smiling-while-carrying-the-coffin-of-the-pope-angel-glad-that-the-soul-of-the-pope-had-been-received-among-the-blessed-spirits': 1,
#   'http://icondataset.org/venus-coelestis-amor-divinus': 1,
#   'http://icondataset.org/saint-paul-mens': 1,
#   'http://icondataset.org/victory-human-soul-in-state-of-freedom': 1,
#   'http://icondataset.org/beams-of-light---gods-word': 1,
#   'http://icondataset.org/moses-mens': 1,
#   'http://icondataset.org/man-reclining-on-terrestrial-world-human-mind-placed-between-the-fallacious-and-unreal-life-on-earth-and-the-celestial-realm': 1,
#   'http://icondataset.org/dove-holy-spirit': 1},
#  'http://icondataset.org/formal-or-stylistic-influence (24)': {'http://icondataset.org/mary': 1,
#   'http://icondataset.org/archangel-gabriel': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/atlas': 1},
#  'http://icondataset.org/cultural-reinterpretation (17)': {'http://icondataset.org/cupid': 4,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/the-constellation-hercules': 3,
#   'http://icondataset.org/saturn': 2,
#   'http://icondataset.org/mercury': 2,
#   'http://icondataset.org/venus': 2,
#   'http://icondataset.org/apollo': 2,
#   'http://icondataset.org/algol-head-of-demon': 2,
#   'http://icondataset.org/the-constellation-perseus': 2,
#   'http://icondataset.org/cupid-amor-carnalis': 2,
#   'http://icondataset.org/mary': 1,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/diana': 1,
#   'http://icondataset.org/bacchus': 1,
#   'http://icondataset.org/pluto': 1,
#   'http://icondataset.org/vulcan': 1,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/minerva': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/hercules': 1,
#   'http://icondataset.org/flame-of-divine-wisdom': 1,
#   'http://icondataset.org/death': 1,
#   'http://icondataset.org/sleep': 1,
#   'http://icondataset.org/contemplative-mind': 1,
#   'http://icondataset.org/ibis-homo-carnalis': 1,
#   'http://icondataset.org/apollo-idolatry': 1,
#   'http://icondataset.org/mars-discord': 1,
#   'http://icondataset.org/jupiter-diana-mercury-saturn-as-superior-divinities-reason': 1,
#   'http://icondataset.org/venus-cupid-vulcan-lower-soul': 1,
#   'http://icondataset.org/pluto-avarice': 1,
#   'http://icondataset.org/torch-unholy-ardor': 1,
#   'http://icondataset.org/bacchus-folly': 1,
#   'http://icondataset.org/jupiter-pride': 1,
#   'http://icondataset.org/jupiter-minerva-mercury-saturn-as-superior-divinities-reason': 1},
#  'http://icondataset.org/artists-expression (15)': {'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/phaeton': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-sub-vulcano': 3,
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': 3,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/centaur': 2,
#   'http://icondataset.org/phaeton-the-presumptuous': 2,
#   'http://icondataset.org/silenus': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/tityus': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/bacchus': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/victory': 1,
#   'http://icondataset.org/three-stages-of-human-life': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/face-of-a-young-man-the-future': 1,
#   'http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/face-of-an-old-man-the-past': 1,
#   'http://icondataset.org/face-of-an-adult-man-the-present': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/three-headed-companion-of-serapis-prudence': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/liver-seat-of-physical-passions': 1},
#  'http://icondataset.org/iconographical-influence (15)': {'http://icondataset.org/planetary-deities': 2,
#   'http://icondataset.org/lion-zodiacal-sign': 2,
#   'http://icondataset.org/the-constellation-hercules': 2,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/the-children-of-mercury': 1,
#   'http://icondataset.org/the-three-graces': 1,
#   'http://icondataset.org/serapis': 1,
#   'http://icondataset.org/companion-of-serapis': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/mercury': 1,
#   'http://icondataset.org/apollo-medicus-or-aesculapius': 1,
#   'http://icondataset.org/venus': 1,
#   'http://icondataset.org/death-disembowelling-her-victim': 1,
#   'http://icondataset.org/imperial-orb': 1,
#   'http://icondataset.org/algol-head-of-demon': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/the-twins-constellation': 1,
#   'http://icondataset.org/blind-death': 1,
#   'http://icondataset.org/blind-synagogue': 1,
#   'http://icondataset.org/sun': 1,
#   'http://icondataset.org/the-constellation-perseus': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1},
#  'http://icondataset.org/attitude (15)': {'http://icondataset.org/europas-companions': 2,
#   'http://icondataset.org/the-abduction-of-europa': 2,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/the-children-of-each-planet': 1,
#   'http://icondataset.org/apollo': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/roman-emperors': 1,
#   'http://icondataset.org/planetary-deities': 1,
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/chastity': 1,
#   'http://icondataset.org/the-constellation-hercules': 1,
#   'http://icondataset.org/bull-christ': 1,
#   'http://icondataset.org/europa-human-soul': 1},
#  'http://icondataset.org/cultural-influence (14)': {'http://icondataset.org/the-constellation-hercules': 2,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/mary': 1,
#   'http://icondataset.org/saints': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/venus': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/angels': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/resurrection-of-christ': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/lion-zodiacal-sign': 1,
#   'http://icondataset.org/algol-head-of-demon': 1,
#   'http://icondataset.org/planimetrical-scheme-of-the-celestial-spheres': 1,
#   'http://icondataset.org/north-pole-sky': 1,
#   'http://icondataset.org/time-the-revealer': 1,
#   'http://icondataset.org/victories': 1,
#   'http://icondataset.org/the-twins-constellation': 1,
#   'http://icondataset.org/the-constellation-perseus': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/truth': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1},
#  'http://icondataset.org/societal-phenomenon (10)': {'http://icondataset.org/apollo': 6,
#   'http://icondataset.org/companion-of-serapis': 6,
#   'http://icondataset.org/christ': 2,
#   'http://icondataset.org/anteros': 2,
#   'http://icondataset.org/member-of-the-procession': 2,
#   'http://icondataset.org/aeolus': 2,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/satan': 2,
#   'http://icondataset.org/the-young-mago-caspar': 2,
#   'http://icondataset.org/cupid': 2,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 2,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 2,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 2,
#   'http://icondataset.org/eros-and-anteros-fishing-for-hearts': 2,
#   'http://icondataset.org/the-age-of-metal': 2,
#   'http://icondataset.org/era-sub-vulcano': 2,
#   'http://icondataset.org/faith-has-the-world-under-her-feet': 2,
#   'http://icondataset.org/altar': 2,
#   'http://icondataset.org/original-sin': 2,
#   'http://icondataset.org/bible': 2,
#   'http://icondataset.org/glass-sphere-as-a-popular-decorative-curiosity': 2,
#   'http://icondataset.org/missal': 2,
#   'http://icondataset.org/private-chapel-installed-within-a-large-house': 2,
#   'http://icondataset.org/ignis-elementatus': 2,
#   'http://icondataset.org/divine-justice': 2,
#   'http://icondataset.org/catholic-faith': 2,
#   'http://icondataset.org/mirror-introspection': 2,
#   'http://icondataset.org/white-purity': 2,
#   'http://icondataset.org/glass-sphere-god': 2,
#   'http://icondataset.org/glass-sphere-heaven': 2,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 2,
#   'http://icondataset.org/weighing-with-balance-allusion-to-last-judgement': 2,
#   'http://icondataset.org/young-mago-future-time': 2,
#   'http://icondataset.org/weighing-with-balance-weighing-of-souls': 2,
#   'http://icondataset.org/jewelry-earthly-goods': 2,
#   'http://icondataset.org/heart-source-of-living-faith': 2,
#   'http://icondataset.org/blue-hue-of-heaven': 2,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 2}}

# %%
frequent_subj_per_cf = {}
for item in meanings_subjects_with_counts.items():
    for pair in item[1].items(): 
        if int(pair[1]) >= 10:
            print(item[0], pair)
           # if item[0] not in frequent_subj_per_cf:
            #    frequent_subj_per_cf[item[0]] = {pair}
           # else:
# Out:
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/saturn', 16)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/cupid', 14)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/mercury', 11)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/saturn', 16)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/cupid', 14)
# http://icondataset.org/iconographical-interpretation (51) ('http://icondataset.org/cupid', 10)

# %% [markdown]
# Result analysis. They are all classical deities. In fact, nearly half on the phenomena are about the reception of classical antiquity. Maybe we can see how classical subjects evolve over time.
#
# |CF | CF frequency | lev 2 | lev 2 frequency |percentage of lev 2 in cf|
# |---|--------------|-------|------------------|----|
# |reception of classical antiquity |203 | cupid | 14| 7% |
# |reception of classical antiquity |203 | mercury | 11| 5% |
# |iconographical evolution |115| saturn | 16| 14% |
# |iconographical evolution |115| cupid | 14| 12% |
# |iconographical interpretation |51| cupid| 10| 20% |
#
#
# Spontaneous question: which are the main "areas" (e.g. classical antiquity, christianity) in the dataset? how much are they represented?

# %%
frequent_subj_per_cf = {}
for item in meanings_subjects_with_counts.items():
    for pair in item[1].items(): 
        if int(pair[1]) >= 5:
            print(item[0], pair)
           # if item[0] not in frequent_subj_per_cf:
            #    frequent_subj_per_cf[item[0]] = {pair}
           # else:
# Out:
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/saturn', 16)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/cupid', 14)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/mercury', 11)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/venus', 8)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/apollo', 8)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/jupiter', 8)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/companion-of-serapis', 7)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/the-constellation-hercules', 6)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/blindfold-cupid', 5)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/saturn-devouring-a-living-child', 5)
# http://icondataset.org/reception-of-classical-antiquity (203) ('http://icondataset.org/caduceus', 5)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/saturn', 16)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/cupid', 14)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/companion-of-serapis', 8)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/blindfold-cupid', 6)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/apollo', 6)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/venus', 6)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/mercury', 5)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/saturn-devouring-a-living-child', 5)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/death', 5)
# http://icondataset.org/iconographical-evolution (115) ('http://icondataset.org/truth', 5)
# http://icondataset.org/formal-or-stylistic-evolution (87) ('http://icondataset.org/mercury', 8)
# http://icondataset.org/iconographical-interpretation (51) ('http://icondataset.org/cupid', 10)
# http://icondataset.org/iconographical-interpretation (51) ('http://icondataset.org/saturn', 7)
# http://icondataset.org/iconographical-interpretation (51) ('http://icondataset.org/jupiter', 6)
# http://icondataset.org/iconographical-interpretation (51) ('http://icondataset.org/saturn-devouring-a-living-child', 5)
# http://icondataset.org/societal-phenomenon (10) ('http://icondataset.org/apollo', 6)
# http://icondataset.org/societal-phenomenon (10) ('http://icondataset.org/companion-of-serapis', 6)

# %%
meanings_subjects_with_counts
# Out:
# {'http://icondataset.org/reception-of-classical-antiquity (203)': {'http://icondataset.org/saturn': 16,
#   'http://icondataset.org/cupid': 14,
#   'http://icondataset.org/mercury': 11,
#   'http://icondataset.org/venus': 8,
#   'http://icondataset.org/apollo': 8,
#   'http://icondataset.org/jupiter': 8,
#   'http://icondataset.org/companion-of-serapis': 7,
#   'http://icondataset.org/the-constellation-hercules': 6,
#   'http://icondataset.org/blindfold-cupid': 5,
#   'http://icondataset.org/saturn-devouring-a-living-child': 5,
#   'http://icondataset.org/caduceus': 5,
#   'http://icondataset.org/the-three-graces': 4,
#   'http://icondataset.org/pluto': 4,
#   'http://icondataset.org/mary': 4,
#   'http://icondataset.org/bacchus': 4,
#   'http://icondataset.org/satyr': 4,
#   'http://icondataset.org/people/virgil': 4,
#   'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/death': 4,
#   'http://icondataset.org/vulcan': 3,
#   'http://icondataset.org/silenus': 3,
#   'http://icondataset.org/centaur': 3,
#   'http://icondataset.org/phaeton': 3,
#   'http://icondataset.org/hercules': 3,
#   'http://icondataset.org/mars': 3,
#   'http://icondataset.org/christ': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/the-constellation-perseus': 3,
#   'http://icondataset.org/truth': 3,
#   'http://icondataset.org/time-the-destroyer': 3,
#   'http://icondataset.org/dragon-biting-its-tail-time': 3,
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': 3,
#   'http://icondataset.org/three-headed-companion-of-serapis-prudence': 3,
#   'http://icondataset.org/argus': 2,
#   'http://icondataset.org/cerberus': 2,
#   'http://icondataset.org/saint-john-the-evangelist': 2,
#   'http://icondataset.org/europas-companions': 2,
#   'http://icondataset.org/prometheus': 2,
#   'http://icondataset.org/anteros': 2,
#   'http://icondataset.org/mithras': 2,
#   'http://icondataset.org/ariadne': 2,
#   'http://icondataset.org/polyxena': 2,
#   'http://icondataset.org/the-children-of-mercury': 2,
#   'http://icondataset.org/proserpina': 2,
#   'http://icondataset.org/the-abduction-of-europa': 2,
#   'http://icondataset.org/blood-sacrifice-of-animals': 2,
#   'http://icondataset.org/crucifixion': 2,
#   'http://icondataset.org/rape': 2,
#   'http://icondataset.org/death-steals-the-weapons-from-cupid-while-he-sleeps': 2,
#   'http://icondataset.org/algol-head-of-demon': 2,
#   'http://icondataset.org/mercurys-winged-sandals': 2,
#   'http://icondataset.org/time-the-revealer': 2,
#   'http://icondataset.org/time-ripa': 2,
#   'http://icondataset.org/sun': 2,
#   'http://icondataset.org/time-as-a-cosmic-power': 2,
#   'http://icondataset.org/moon': 2,
#   'http://icondataset.org/flora': 2,
#   'http://icondataset.org/bear-anger': 2,
#   'http://icondataset.org/dolphin-haste': 2,
#   'http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart': 2,
#   'http://icondataset.org/face-of-a-young-man-the-future': 2,
#   'http://icondataset.org/face-of-an-adult-man-the-present': 2,
#   'http://icondataset.org/face-of-an-old-man-the-past': 2,
#   'http://icondataset.org/cupid-amor-carnalis': 2,
#   'http://icondataset.org/owl-attribute-of-wisdom': 2,
#   'http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future': 2,
#   'http://icondataset.org/book-attribute-of-wisdom': 2,
#   'http://icondataset.org/phaeton-the-presumptuous': 2,
#   'http://icondataset.org/pygmalion': 1,
#   'http://icondataset.org/archangel-gabriel': 1,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/marine-snakes': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/sisyphus': 1,
#   'http://icondataset.org/muses': 1,
#   'http://icondataset.org/natural-venus': 1,
#   'http://icondataset.org/paris': 1,
#   'http://icondataset.org/the-resurrected': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/thymbraeus-son-of-laoocoon': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/the-children-of-saturn': 1,
#   'http://icondataset.org/saint-mark': 1,
#   'http://icondataset.org/aeneas': 1,
#   'http://icondataset.org/erato': 1,
#   'http://icondataset.org/dido': 1,
#   'http://icondataset.org/perseus': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/antiphas-son-of-laoocoon': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/orpheus': 1,
#   'http://icondataset.org/prophet': 1,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/rachel': 1,
#   'http://icondataset.org/david': 1,
#   'http://icondataset.org/simeon': 1,
#   'http://icondataset.org/apollo-medicus-or-aesculapius': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/serapis': 1,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/helen': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/tityus': 1,
#   'http://icondataset.org/laocoon': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/lapiths': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/rhea': 1,
#   'http://icondataset.org/eve': 1,
#   'http://icondataset.org/venus-pudica': 1,
#   'http://icondataset.org/tantalus': 1,
#   'http://icondataset.org/leach': 1,
#   'http://icondataset.org/christ-as-a-child': 1,
#   'http://icondataset.org/roman-emperors': 1,
#   'http://icondataset.org/people/saint-luke': 1,
#   'http://icondataset.org/god': 1,
#   'http://icondataset.org/female-pan': 1,
#   'http://icondataset.org/ixion': 1,
#   'http://icondataset.org/aion/phanes': 1,
#   'http://icondataset.org/dieu-amour': 1,
#   'http://icondataset.org/sybil': 1,
#   'http://icondataset.org/amorini-pointing-out-to-death-her-first-victims': 1,
#   'http://icondataset.org/sun-moves-his-chariot-through-the-zodiac': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/ixion-on-his-wheel': 1,
#   'http://icondataset.org/mithras-killing-the-bull': 1,
#   'http://icondataset.org/pygmalion-dressing-his-statue': 1,
#   'http://icondataset.org/era-sub-prometheo': 1,
#   'http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion': 1,
#   'http://icondataset.org/sacrifice-of-a-bull': 1,
#   'http://icondataset.org/innocence-threatened-by-the-powers-of-evil': 1,
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/joseph-cast-into-the-pit': 1,
#   'http://icondataset.org/paris-rapes-helen': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/love-shooting-the-foolish': 1,
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/simeon-witnesses-the-presentation-of-christ': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/lamentation-of-christ': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water': 1,
#   'http://icondataset.org/time-devouring-the-past': 1,
#   'http://icondataset.org/battle-of-lapiths-and-centaurs': 1,
#   'http://icondataset.org/prometheus-animates-man': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/love-shooting-the-wise-man': 1,
#   'http://icondataset.org/god-creating-the-universe': 1,
#   'http://icondataset.org/prometheus-is-punished': 1,
#   'http://icondataset.org/three-corpses-warn-three-gentlemen-against-their-thoughtless-enjoyment-of-life': 1,
#   'http://icondataset.org/resurrection-of-christ': 1,
#   'http://icondataset.org/triumph-of-love': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/mithras-twisting-the-horns-of-a-bull': 1,
#   'http://icondataset.org/tower-of-chastity': 1,
#   'http://icondataset.org/jupiter-planet': 1,
#   'http://icondataset.org/torso-del-belvedere': 1,
#   'http://icondataset.org/the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/hearts-of-cupids-victims': 1,
#   'http://icondataset.org/mercury-planet': 1,
#   'http://icondataset.org/saturn-planet': 1,
#   'http://icondataset.org/lion-zodiacal-sign': 1,
#   'http://icondataset.org/apollonian-swan': 1,
#   'http://icondataset.org/mars-planet': 1,
#   'http://icondataset.org/medusas-head': 1,
#   'http://icondataset.org/venus-planet': 1,
#   'http://icondataset.org/moon-planet': 1,
#   'http://icondataset.org/torch-of-prometheus': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/planimetrical-scheme-of-the-celestial-spheres': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/north-pole-sky': 1,
#   'http://icondataset.org/aion/phanes-as-personification-of-eternal-time': 1,
#   'http://icondataset.org/justice': 1,
#   'http://icondataset.org/oceanus': 1,
#   'http://icondataset.org/sleep': 1,
#   'http://icondataset.org/three-stages-of-human-life': 1,
#   'http://icondataset.org/fortune': 1,
#   'http://icondataset.org/zephir': 1,
#   'http://icondataset.org/kairos': 1,
#   'http://icondataset.org/amor-carnalis': 1,
#   'http://icondataset.org/amor-divino': 1,
#   'http://icondataset.org/time-as-universal-cosmic-principle': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/tellus': 1,
#   'http://icondataset.org/labour': 1,
#   'http://icondataset.org/hope': 1,
#   'http://icondataset.org/the-twins-constellation': 1,
#   'http://icondataset.org/love': 1,
#   'http://icondataset.org/the-virgin-constellation': 1,
#   'http://icondataset.org/river-alpheus': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/innocence': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/luxury': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/faith': 1,
#   'http://icondataset.org/penitentia': 1,
#   'http://icondataset.org/ardor': 1,
#   'http://icondataset.org/the-constellation-eridanus': 1,
#   'http://icondataset.org/amor': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/wealth': 1,
#   'http://icondataset.org/atlas': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/sun-on-his-chariot': 1,
#   'http://icondataset.org/poverty': 1,
#   'http://icondataset.org/good-counsel': 1,
#   'http://icondataset.org/spring': 1,
#   'http://icondataset.org/monk-vita-contemplativa': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/desolate-scenery-destructive-power-of-time': 1,
#   'http://icondataset.org/bundle-of-sticks-unity': 1,
#   'http://icondataset.org/fire-fire-to-burn-the-time': 1,
#   'http://icondataset.org/deer-souls': 1,
#   'http://icondataset.org/soap-bubbles-futility': 1,
#   'http://icondataset.org/hourglass-transience': 1,
#   'http://icondataset.org/natural-venus-amor-humanus': 1,
#   'http://icondataset.org/tombs-christian-rite-of-burial': 1,
#   'http://icondataset.org/wolf-greed': 1,
#   'http://icondataset.org/apollo-idolatry': 1,
#   'http://icondataset.org/venus-coelestis-amor-divinus': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1,
#   'http://icondataset.org/mars-discord': 1,
#   'http://icondataset.org/dragoon-devil': 1,
#   'http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1,
#   'http://icondataset.org/carrying-on-shoulders-saving-souls': 1,
#   'http://icondataset.org/torch-unholy-ardor': 1,
#   'http://icondataset.org/stepping-on-defeating-devil': 1,
#   'http://icondataset.org/roses-pleasures-of-permanent-congeniality': 1,
#   'http://icondataset.org/ibis-homo-carnalis': 1,
#   'http://icondataset.org/mouse-all-devouring-time': 1,
#   'http://icondataset.org/europa-human-soul': 1,
#   'http://icondataset.org/urns-pagan-custom-of-cremation': 1,
#   'http://icondataset.org/fly-decade': 1,
#   'http://icondataset.org/three-books-three-forms-of-time-past-present-future': 1,
#   'http://icondataset.org/mercury-discursive-reason:-limitations-and-possibilities-of-what-human-reason-can-do': 1,
#   'http://icondataset.org/skull-death-personified': 1,
#   'http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening': 1,
#   'http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love': 1,
#   'http://icondataset.org/bull-christ': 1,
#   'http://icondataset.org/lyre-fashioned-from-a-stags-head-low-class-and-uncouth-music': 1,
#   'http://icondataset.org/shepherdess-amorous-implications-of-the-arcadian-milieu': 1,
#   'http://icondataset.org/four-wings-four-seasons': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/serpent-perfidy': 1,
#   'http://icondataset.org/bowl-on-a-book-wisdom': 1,
#   'http://icondataset.org/tantalus-avarice': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life': 1,
#   'http://icondataset.org/ixion-lewdness': 1,
#   'http://icondataset.org/satyr-egyptian-desert-wilderness': 1,
#   'http://icondataset.org/liver-seat-of-physical-passions': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-affection-changes-with-luck': 1,
#   'http://icondataset.org/hercules-egypt': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/jupiter-pride': 1,
#   'http://icondataset.org/bacchus-folly': 1,
#   'http://icondataset.org/pluto-avarice': 1,
#   'http://icondataset.org/mercury-discursive-reason': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1,
#   'http://icondataset.org/dog-envy': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/lion-fury': 1,
#   'http://icondataset.org/mercury-turning-his-back-to-the-realm-of-the-natural-venus-the-discursive-reason-is-not-involved-in-the-activities-of-the-natural-venus': 1,
#   'http://icondataset.org/face-of-an-old-woman-the-past': 1,
#   'http://icondataset.org/myrtle-everlasting-love': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/glass-sphere-harmony-that-can-be-easily-broken': 1,
#   'http://icondataset.org/sisyphus-pride': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/serpent-attribute-of-wisdom': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/face-of-an-adult-woman-the-present': 1,
#   'http://icondataset.org/face-of-a-young-woman-the-future': 1},
#  'http://icondataset.org/iconographical-evolution (115)': {'http://icondataset.org/saturn': 16,
#   'http://icondataset.org/cupid': 14,
#   'http://icondataset.org/companion-of-serapis': 8,
#   'http://icondataset.org/blindfold-cupid': 6,
#   'http://icondataset.org/apollo': 6,
#   'http://icondataset.org/venus': 6,
#   'http://icondataset.org/mercury': 5,
#   'http://icondataset.org/saturn-devouring-a-living-child': 5,
#   'http://icondataset.org/death': 5,
#   'http://icondataset.org/truth': 5,
#   'http://icondataset.org/people/virgil': 4,
#   'http://icondataset.org/christ': 4,
#   'http://icondataset.org/time-the-destroyer': 4,
#   'http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future': 4,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/eros-as-the-great-force-ruling-over-the-instincts-of-gods-man-and-animals': 3,
#   'http://icondataset.org/three-headed-companion-of-serapis-prudence': 3,
#   'http://icondataset.org/dragon-biting-its-tail-time': 3,
#   'http://icondataset.org/the-children-of-saturn': 2,
#   'http://icondataset.org/mercury-hermes': 2,
#   'http://icondataset.org/mithras': 2,
#   'http://icondataset.org/anteros': 2,
#   'http://icondataset.org/olympian-gods': 2,
#   'http://icondataset.org/argus': 2,
#   'http://icondataset.org/bacchus': 2,
#   'http://icondataset.org/aglauros': 2,
#   'http://icondataset.org/the-three-graces': 2,
#   'http://icondataset.org/saint-theodora-of-alexandria': 2,
#   'http://icondataset.org/zeus': 2,
#   'http://icondataset.org/death-steals-the-weapons-from-cupid-while-he-sleeps': 2,
#   'http://icondataset.org/blood-sacrifice-of-animals': 2,
#   'http://icondataset.org/mercurys-winged-sandals': 2,
#   'http://icondataset.org/caduceus': 2,
#   'http://icondataset.org/medusas-head': 2,
#   'http://icondataset.org/poverty': 2,
#   'http://icondataset.org/time-as-a-cosmic-power': 2,
#   'http://icondataset.org/time-ripa': 2,
#   'http://icondataset.org/fortune': 2,
#   'http://icondataset.org/the-constellation-perseus': 2,
#   'http://icondataset.org/time-the-revealer': 2,
#   'http://icondataset.org/amor-carnalis': 2,
#   'http://icondataset.org/bear-anger': 2,
#   'http://icondataset.org/owl-attribute-of-wisdom': 2,
#   'http://icondataset.org/book-attribute-of-wisdom': 2,
#   'http://icondataset.org/face-of-an-old-man-the-past': 2,
#   'http://icondataset.org/face-of-an-adult-man-the-present': 2,
#   'http://icondataset.org/dolphin-haste': 2,
#   'http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart': 2,
#   'http://icondataset.org/face-of-a-young-man-the-future': 2,
#   'http://icondataset.org/apostles': 1,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/dieu-amour': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/apollo-medicus-or-aesculapius': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/pluto': 1,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/devil': 1,
#   'http://icondataset.org/athene': 1,
#   'http://icondataset.org/serapis': 1,
#   'http://icondataset.org/perseus': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/aion/phanes': 1,
#   'http://icondataset.org/jest': 1,
#   'http://icondataset.org/orpheus': 1,
#   'http://icondataset.org/the-children-of-mercury': 1,
#   'http://icondataset.org/silenus': 1,
#   'http://icondataset.org/gods-hand': 1,
#   'http://icondataset.org/herse': 1,
#   'http://icondataset.org/rhea': 1,
#   'http://icondataset.org/venus-pudica': 1,
#   'http://icondataset.org/saint-john-the-evangelist': 1,
#   'http://icondataset.org/europas-companions': 1,
#   'http://icondataset.org/love-shooting-the-foolish': 1,
#   'http://icondataset.org/cupid-unblinding-himself': 1,
#   'http://icondataset.org/amorini-pointing-out-to-death-her-first-victims': 1,
#   'http://icondataset.org/innocence-threatened-by-the-powers-of-evil': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/sun-moves-his-chariot-through-the-zodiac': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/sacrifice-of-a-bull': 1,
#   'http://icondataset.org/three-corpses-warn-three-gentlemen-against-their-thoughtless-enjoyment-of-life': 1,
#   'http://icondataset.org/death-disembowelling-her-victim': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/triumph-of-love': 1,
#   'http://icondataset.org/mithras-twisting-the-horns-of-a-bull': 1,
#   'http://icondataset.org/crucifixion': 1,
#   'http://icondataset.org/resurrection-of-christ': 1,
#   'http://icondataset.org/mithras-killing-the-bull': 1,
#   'http://icondataset.org/era-sub-vulcano': 1,
#   'http://icondataset.org/the-abduction-of-europa': 1,
#   'http://icondataset.org/time-devouring-the-past': 1,
#   'http://icondataset.org/love-shooting-the-wise-man': 1,
#   'http://icondataset.org/mercury-planet': 1,
#   'http://icondataset.org/lion-zodiacal-sign': 1,
#   'http://icondataset.org/saturn-planet': 1,
#   'http://icondataset.org/tower-of-chastity': 1,
#   'http://icondataset.org/jupiter-planet': 1,
#   'http://icondataset.org/implements-of-the-holy-mass': 1,
#   'http://icondataset.org/hearts-of-cupids-victims': 1,
#   'http://icondataset.org/torso-del-belvedere': 1,
#   'http://icondataset.org/love-stricken-soul': 1,
#   'http://icondataset.org/celestial-map': 1,
#   'http://icondataset.org/venus-planet': 1,
#   'http://icondataset.org/moon-planet': 1,
#   'http://icondataset.org/mars-planet': 1,
#   'http://icondataset.org/planimetrical-scheme-of-the-celestial-spheres': 1,
#   'http://icondataset.org/north-pole-sky': 1,
#   'http://icondataset.org/sun': 1,
#   'http://icondataset.org/amor-divino': 1,
#   'http://icondataset.org/moon': 1,
#   'http://icondataset.org/time-as-universal-cosmic-principle': 1,
#   'http://icondataset.org/three-stages-of-human-life': 1,
#   'http://icondataset.org/labour': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/ardor': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/river-alpheus': 1,
#   'http://icondataset.org/life': 1,
#   'http://icondataset.org/blind-death': 1,
#   'http://icondataset.org/justice': 1,
#   'http://icondataset.org/penitentia': 1,
#   'http://icondataset.org/aion/phanes-as-personification-of-eternal-time': 1,
#   'http://icondataset.org/good-counsel': 1,
#   'http://icondataset.org/church': 1,
#   'http://icondataset.org/the-constellation-eridanus': 1,
#   'http://icondataset.org/blind-night': 1,
#   'http://icondataset.org/evil-effects-of-love': 1,
#   'http://icondataset.org/mockery': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/oceanus': 1,
#   'http://icondataset.org/mourning': 1,
#   'http://icondataset.org/kairos': 1,
#   'http://icondataset.org/wealth': 1,
#   'http://icondataset.org/sun-on-his-chariot': 1,
#   'http://icondataset.org/innocence': 1,
#   'http://icondataset.org/platonic-love': 1,
#   'http://icondataset.org/the-constellation-hercules': 1,
#   'http://icondataset.org/the-virgin-constellation': 1,
#   'http://icondataset.org/the-constellation-orion': 1,
#   'http://icondataset.org/synagogue': 1,
#   'http://icondataset.org/earth': 1,
#   'http://icondataset.org/chastity': 1,
#   'http://icondataset.org/the-constellation-hercules-engonasin': 1,
#   'http://icondataset.org/tellus': 1,
#   'http://icondataset.org/luxury': 1,
#   'http://icondataset.org/amor': 1,
#   'http://icondataset.org/flora': 1,
#   'http://icondataset.org/nude-prudence': 1,
#   'http://icondataset.org/cupid-unblindfolding-himself-cupid-transforming-himself-from-a-personification-of-blind-ignoble-love-to-an-exponent-of-seeing-platonic-love': 1,
#   'http://icondataset.org/branches-of-a-tree-antidotes-against-sexual-passion-marriage-prayer-business-abstinence': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1,
#   'http://icondataset.org/skull-death-personified': 1,
#   'http://icondataset.org/carrying-on-shoulders-saving-souls': 1,
#   'http://icondataset.org/head-of-a-dog-the-future': 1,
#   'http://icondataset.org/three-books-three-forms-of-time-past-present-future': 1,
#   'http://icondataset.org/mouse-all-devouring-time': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/fly-decade': 1,
#   'http://icondataset.org/desolate-scenery-destructive-power-of-time': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/monk-vita-contemplativa': 1,
#   'http://icondataset.org/bowl-on-a-book-wisdom': 1,
#   'http://icondataset.org/fire-fire-to-burn-the-time': 1,
#   'http://icondataset.org/soap-bubbles-futility': 1,
#   'http://icondataset.org/head-of-a-lion-the-present': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1,
#   'http://icondataset.org/hourglass-transience': 1,
#   'http://icondataset.org/head-of-a-wolf-the-past': 1,
#   'http://icondataset.org/wolf-greed': 1,
#   'http://icondataset.org/dragoon-devil': 1,
#   'http://icondataset.org/venus-coelestis-amor-divinus': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/stepping-on-defeating-devil': 1,
#   'http://icondataset.org/face-of-an-old-woman-the-past': 1,
#   'http://icondataset.org/face-of-a-young-woman-the-future': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/lion-fury': 1,
#   'http://icondataset.org/face-of-an-adult-woman-the-present': 1,
#   'http://icondataset.org/serpent-attribute-of-wisdom': 1,
#   'http://icondataset.org/deer-souls': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/four-wings-four-seasons': 1,
#   'http://icondataset.org/serpent-perfidy': 1,
#   'http://icondataset.org/shepherdess-amorous-implications-of-the-arcadian-milieu': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-affection-changes-with-luck': 1,
#   'http://icondataset.org/dog-envy': 1},
#  'http://icondataset.org/formal-or-stylistic-evolution (87)': {'http://icondataset.org/mercury': 8,
#   'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/saturn': 3,
#   'http://icondataset.org/apollo': 3,
#   'http://icondataset.org/the-three-graces': 3,
#   'http://icondataset.org/centaur': 3,
#   'http://icondataset.org/people/virgil': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/caduceus': 3,
#   'http://icondataset.org/argus': 2,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/polyxena': 2,
#   'http://icondataset.org/ariadne': 2,
#   'http://icondataset.org/pluto': 2,
#   'http://icondataset.org/the-children-of-mercury': 2,
#   'http://icondataset.org/silenus': 2,
#   'http://icondataset.org/cerberus': 2,
#   'http://icondataset.org/proserpina': 2,
#   'http://icondataset.org/europas-companions': 2,
#   'http://icondataset.org/bacchus': 2,
#   'http://icondataset.org/rape': 2,
#   'http://icondataset.org/the-abduction-of-europa': 2,
#   'http://icondataset.org/saint-john-the-evangelist': 1,
#   'http://icondataset.org/prometheus': 1,
#   'http://icondataset.org/jupiter': 1,
#   'http://icondataset.org/david': 1,
#   'http://icondataset.org/bishop-simone-saltarelli': 1,
#   'http://icondataset.org/laocoon': 1,
#   'http://icondataset.org/pygmalion': 1,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/the-resurrected': 1,
#   'http://icondataset.org/thymbraeus-son-of-laoocoon': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/aeneas': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/mary': 1,
#   'http://icondataset.org/dido': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/venus': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/antiphas-son-of-laoocoon': 1,
#   'http://icondataset.org/paris': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/lapiths': 1,
#   'http://icondataset.org/helen': 1,
#   'http://icondataset.org/marine-snakes': 1,
#   'http://icondataset.org/companion-of-serapis': 1,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/presbyter-bruno': 1,
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/lamentation-of-christ': 1,
#   'http://icondataset.org/era-sub-prometheo': 1,
#   'http://icondataset.org/prometheus-is-punished': 1,
#   'http://icondataset.org/battle-of-lapiths-and-centaurs': 1,
#   'http://icondataset.org/paris-rapes-helen': 1,
#   'http://icondataset.org/pygmalion-dressing-his-statue': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/crucifixion': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/presbyter-bruno-mourned-by-beggars-whom-he-had-supported-during-his-life': 1,
#   'http://icondataset.org/the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/torch-of-prometheus': 1,
#   'http://icondataset.org/implements-of-the-holy-mass': 1,
#   'http://icondataset.org/temple-of-solomon': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/truth': 1,
#   'http://icondataset.org/the-constellation-hercules': 1,
#   'http://icondataset.org/sun': 1,
#   'http://icondataset.org/the-virgin-constellation': 1,
#   'http://icondataset.org/moon': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1,
#   'http://icondataset.org/urns-pagan-custom-of-cremation': 1,
#   'http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/tombs-christian-rite-of-burial': 1,
#   'http://icondataset.org/temple-of-solomon-ornate-as-a-church-correlation-between-the-old-testament-and-the-new': 1,
#   'http://icondataset.org/dragon-biting-its-tail-time': 1,
#   'http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/bull-christ': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/europa-human-soul': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1},
#  'http://icondataset.org/formal-or-stylistic-phenomenon (59)': {'http://icondataset.org/mary': 2,
#   'http://icondataset.org/christ': 2,
#   'http://icondataset.org/archangel-gabriel': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/europas-companions': 1,
#   'http://icondataset.org/apostles': 1,
#   'http://icondataset.org/apollo-medicus-or-aesculapius': 1,
#   'http://icondataset.org/apollo': 1,
#   'http://icondataset.org/paris': 1,
#   'http://icondataset.org/hespontine-sibyl': 1,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/helen': 1,
#   'http://icondataset.org/simeon': 1,
#   'http://icondataset.org/saint-john-the-evangelist': 1,
#   'http://icondataset.org/the-resurrected': 1,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/saint-mark': 1,
#   'http://icondataset.org/christ-as-a-child': 1,
#   'http://icondataset.org/son-of-the-widow-of-nain': 1,
#   'http://icondataset.org/saint-anne': 1,
#   'http://icondataset.org/joachim': 1,
#   'http://icondataset.org/paris-rapes-helen': 1,
#   'http://icondataset.org/the-abduction-of-europa': 1,
#   'http://icondataset.org/christ-resurrects-the-son-of-nain': 1,
#   'http://icondataset.org/lamentation-of-christ': 1,
#   'http://icondataset.org/simeon-witnesses-the-presentation-of-christ': 1,
#   'http://icondataset.org/apparition-of-christ': 1,
#   'http://icondataset.org/temple-of-solomon': 1,
#   'http://icondataset.org/city-of-nain': 1,
#   'http://icondataset.org/the-twins-constellation': 1,
#   'http://icondataset.org/atlas': 1,
#   'http://icondataset.org/temple-of-solomon-ornate-as-a-church-correlation-between-the-old-testament-and-the-new': 1,
#   'http://icondataset.org/urns-pagan-custom-of-cremation': 1,
#   'http://icondataset.org/tombs-christian-rite-of-burial': 1},
#  'http://icondataset.org/iconographical-interpretation (51)': {'http://icondataset.org/cupid': 10,
#   'http://icondataset.org/saturn': 7,
#   'http://icondataset.org/jupiter': 6,
#   'http://icondataset.org/saturn-devouring-a-living-child': 5,
#   'http://icondataset.org/satyr': 4,
#   'http://icondataset.org/vulcan': 4,
#   'http://icondataset.org/blindfold-cupid': 4,
#   'http://icondataset.org/venus': 4,
#   'http://icondataset.org/phaeton': 3,
#   'http://icondataset.org/apollo': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/era-sub-vulcano': 3,
#   'http://icondataset.org/time-the-destroyer': 3,
#   'http://icondataset.org/truth': 3,
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': 3,
#   'http://icondataset.org/dragon-biting-its-tail-time': 3,
#   'http://icondataset.org/bacchus': 2,
#   'http://icondataset.org/hercules': 2,
#   'http://icondataset.org/centaur': 2,
#   'http://icondataset.org/mercury': 2,
#   'http://icondataset.org/silenus': 2,
#   'http://icondataset.org/mithras': 2,
#   'http://icondataset.org/death-steals-the-weapons-from-cupid-while-he-sleeps': 2,
#   'http://icondataset.org/blood-sacrifice-of-animals': 2,
#   'http://icondataset.org/time-the-revealer': 2,
#   'http://icondataset.org/time-ripa': 2,
#   'http://icondataset.org/death': 2,
#   'http://icondataset.org/phaeton-the-presumptuous': 2,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/tantalus': 1,
#   'http://icondataset.org/minerva': 1,
#   'http://icondataset.org/thymbraeus-son-of-laoocoon': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/female-pan': 1,
#   'http://icondataset.org/angels': 1,
#   'http://icondataset.org/geminae-veneres': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/venus-verticordia': 1,
#   'http://icondataset.org/laocoon': 1,
#   'http://icondataset.org/saint-paul': 1,
#   'http://icondataset.org/ixion': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/venus-vulgaris': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/marine-snakes': 1,
#   'http://icondataset.org/pluto': 1,
#   'http://icondataset.org/muses': 1,
#   'http://icondataset.org/sisyphus': 1,
#   'http://icondataset.org/devil': 1,
#   'http://icondataset.org/erato': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/diana': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/anteros': 1,
#   'http://icondataset.org/fedro': 1,
#   'http://icondataset.org/antiphas-son-of-laoocoon': 1,
#   'http://icondataset.org/the-three-graces': 1,
#   'http://icondataset.org/tityus': 1,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/innocence-threatened-by-the-powers-of-evil': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/mithras-twisting-the-horns-of-a-bull': 1,
#   'http://icondataset.org/time-devouring-the-past': 1,
#   'http://icondataset.org/cupid-unblinding-himself': 1,
#   'http://icondataset.org/mithras-killing-the-bull': 1,
#   'http://icondataset.org/ixion-on-his-wheel': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/joseph-cast-into-the-pit': 1,
#   'http://icondataset.org/sacrifice-of-a-bull': 1,
#   'http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion': 1,
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill': 1,
#   'http://icondataset.org/apollonian-swan': 1,
#   'http://icondataset.org/sella-gestatoria': 1,
#   'http://icondataset.org/caduceus': 1,
#   'http://icondataset.org/love-stricken-soul': 1,
#   'http://icondataset.org/flame-of-divine-wisdom': 1,
#   'http://icondataset.org/torso-del-belvedere': 1,
#   'http://icondataset.org/mercurys-winged-sandals': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/paysage-moralise': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/voluptas': 1,
#   'http://icondataset.org/contemplative-mind': 1,
#   'http://icondataset.org/amor-divino': 1,
#   'http://icondataset.org/platonic-love': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/innocence': 1,
#   'http://icondataset.org/grace-pulchritudo': 1,
#   'http://icondataset.org/victories': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/mockery': 1,
#   'http://icondataset.org/evil-effects-of-love': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/chastity': 1,
#   'http://icondataset.org/justice': 1,
#   'http://icondataset.org/faith': 1,
#   'http://icondataset.org/three-graces-three-aspects-of-venus': 1,
#   'http://icondataset.org/hope': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/beauty': 1,
#   'http://icondataset.org/marital-affection': 1,
#   'http://icondataset.org/love': 1,
#   'http://icondataset.org/mourning': 1,
#   'http://icondataset.org/fortune': 1,
#   'http://icondataset.org/amor-carnalis': 1,
#   'http://icondataset.org/poverty': 1,
#   'http://icondataset.org/tantalus-avarice': 1,
#   'http://icondataset.org/branches-of-a-tree-antidotes-against-sexual-passion-marriage-prayer-business-abstinence': 1,
#   'http://icondataset.org/wolf-greed': 1,
#   'http://icondataset.org/glass-sphere-harmony-that-can-be-easily-broken': 1,
#   'http://icondataset.org/angel-wepting-while-carrying-the-coffin-of-the-pope-angel-grieved-that-the-world-had-been-deprived-of-such-a-man': 1,
#   'http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life': 1,
#   'http://icondataset.org/ixion-lewdness': 1,
#   'http://icondataset.org/saint-paul-mens': 1,
#   'http://icondataset.org/myrtle-everlasting-love': 1,
#   'http://icondataset.org/hercules-egypt': 1,
#   'http://icondataset.org/jupiter-minerva-mercury-saturn-as-superior-divinities-reason': 1,
#   'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom': 1,
#   'http://icondataset.org/hares-animal-love-fertility': 1,
#   'http://icondataset.org/lion-fury': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/cameo-with-a-pair-of-winged-horses-and-a-charioteer-platos-immortal-comparison-of-the-human-soul': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-affection-changes-with-luck': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/liver-seat-of-physical-passions': 1,
#   'http://icondataset.org/victory-human-soul-in-state-of-freedom': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/venus-coelestis-principle-of-universal-and-eternal-but-purely-intelligible-beauty': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/angel-smiling-while-carrying-the-coffin-of-the-pope-angel-glad-that-the-soul-of-the-pope-had-been-received-among-the-blessed-spirits': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1,
#   'http://icondataset.org/dog-envy': 1,
#   'http://icondataset.org/four-wings-four-seasons': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/venus-cupid-vulcan-lower-soul': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/serpent-perfidy': 1,
#   'http://icondataset.org/sisyphus-pride': 1,
#   'http://icondataset.org/moses-mens': 1,
#   'http://icondataset.org/cupid-unblindfolding-himself-cupid-transforming-himself-from-a-personification-of-blind-ignoble-love-to-an-exponent-of-seeing-platonic-love': 1,
#   'http://icondataset.org/jupiter-diana-mercury-saturn-as-superior-divinities-reason': 1,
#   'http://icondataset.org/cupid-between-venus-coelestis-and-venus-vulgaris-love-acts-as-an-intermediary-between-heaven-and-earth': 1,
#   'http://icondataset.org/bundle-of-sticks-unity': 1,
#   'http://icondataset.org/roses-pleasures-of-permanent-congeniality': 1,
#   'http://icondataset.org/desolate-scenery-destructive-power-of-time': 1,
#   'http://icondataset.org/lyre-fashioned-from-a-stags-head-low-class-and-uncouth-music': 1,
#   'http://icondataset.org/sarcophagus-converted-in-a-spring-of-life-vis-generandi': 1,
#   'http://icondataset.org/satyr-egyptian-desert-wilderness': 1,
#   'http://icondataset.org/venus-vulgaris-generative-force-that-creates-the-perishable-but-visible-and-tangible-images-of-beauty-of-earth': 1,
#   'http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love': 1},
#  'http://icondataset.org/tendency (39)': {'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/mary': 3,
#   'http://icondataset.org/centaur': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/ariadne': 2,
#   'http://icondataset.org/christ': 2,
#   'http://icondataset.org/bacchus': 2,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/silenus': 2,
#   'http://icondataset.org/prophet': 1,
#   'http://icondataset.org/sisyphus': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/prometheus': 1,
#   'http://icondataset.org/giuliano-de-medici': 1,
#   'http://icondataset.org/europas-companions': 1,
#   'http://icondataset.org/rachel': 1,
#   'http://icondataset.org/apollo': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/votary-of-saturn': 1,
#   'http://icondataset.org/aeneas': 1,
#   'http://icondataset.org/simeon': 1,
#   'http://icondataset.org/people/lorenzo-de-medici': 1,
#   'http://icondataset.org/dido': 1,
#   'http://icondataset.org/lapiths': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/tantalus': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/the-resurrected': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/saint-john-the-evangelist': 1,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/votary-of-jupiter': 1,
#   'http://icondataset.org/sybil': 1,
#   'http://icondataset.org/ixion': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/christ-as-a-child': 1,
#   'http://icondataset.org/leach': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/the-abduction-of-europa': 1,
#   'http://icondataset.org/ixion-on-his-wheel': 1,
#   'http://icondataset.org/battle-of-lapiths-and-centaurs': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/era-sub-prometheo': 1,
#   'http://icondataset.org/sisyphus-carrying-the-stone-uphill': 1,
#   'http://icondataset.org/simeon-witnesses-the-presentation-of-christ': 1,
#   'http://icondataset.org/gesture-of-saturnian-silence': 1,
#   'http://icondataset.org/tantalus-vainly-reaching-for-the-water': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/prometheus-is-punished': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/torch-of-prometheus': 1,
#   'http://icondataset.org/the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/nude-prudence': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening': 1,
#   'http://icondataset.org/princely-sceptre-jovial-magnanimity': 1,
#   'http://icondataset.org/carrying-on-shoulders-saving-souls': 1,
#   'http://icondataset.org/stepping-on-defeating-devil': 1,
#   'http://icondataset.org/dragoon-devil': 1,
#   'http://icondataset.org/closed-cash-box-saturninian-parsimony': 1,
#   'http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind': 1,
#   'http://icondataset.org/bat-melancholy': 1,
#   'http://icondataset.org/ixion-lewdness': 1,
#   'http://icondataset.org/tantalus-avarice': 1,
#   'http://icondataset.org/deer-souls': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/tombs-christian-rite-of-burial': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/sisyphus-pride': 1,
#   'http://icondataset.org/urns-pagan-custom-of-cremation': 1},
#  'http://icondataset.org/belief (30)': {'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/erection-of-primitive-buildings': 3,
#   'http://icondataset.org/era-sub-vulcano': 3,
#   'http://icondataset.org/mercury': 2,
#   'http://icondataset.org/centaur': 2,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/cupid': 2,
#   'http://icondataset.org/mary': 2,
#   'http://icondataset.org/the-children-of-saturn': 2,
#   'http://icondataset.org/archangel-gabriel': 2,
#   'http://icondataset.org/archangel-gabriel-pronounces-the-ave-maria': 2,
#   'http://icondataset.org/mary-welcomes-the-holy-spirit': 2,
#   'http://icondataset.org/two-out-of-the-four-times-of-day': 2,
#   'http://icondataset.org/flora': 2,
#   'http://icondataset.org/two-out-of-the-four-rivers-of-hades': 2,
# ...
#   'http://icondataset.org/four-times-of-day-realm-of-nature': 2,
#   'http://icondataset.org/lowest-zone-of-the-tomb-realm-of-sheer-matter': 2,
#   'http://icondataset.org/four-rivers-of-hades-fourfold-aspect-of-matter-as-a-source-of-potential-evil': 2,
#   'http://icondataset.org/highest-zone-of-the-tomb-supercelestial-sphere': 2,
#   'http://icondataset.org/four-times-of-day-four-humours': 2,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/angels': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/the-three-graces': 1,
#   'http://icondataset.org/natural-venus': 1,
#   'http://icondataset.org/the-children-of-mercury': 1,
#   'http://icondataset.org/venus-pudica': 1,
#   'http://icondataset.org/unconsciuous-creatures': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/people/lorenzo-de-medici': 1,
#   'http://icondataset.org/planetary-deities': 1,
#   'http://icondataset.org/crocodile': 1,
#   'http://icondataset.org/silenus': 1,
#   'http://icondataset.org/salamander': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/bacchus': 1,
#   'http://icondataset.org/giuliano-de-medici': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/saturn': 1,
#   'http://icondataset.org/venus-coelestis': 1,
#   'http://icondataset.org/saint-paul': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/god': 1,
#   'http://icondataset.org/the-children-of-each-planet': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/dream-vision': 1,
#   'http://icondataset.org/caduceus': 1,
#   'http://icondataset.org/sella-gestatoria': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/aurora': 1,
#   'http://icondataset.org/crepuscolo': 1,
#   'http://icondataset.org/zephir': 1,
#   'http://icondataset.org/personification-of-the-natural-forces-stimulating-the-action-of-the-unconscious-creatures': 1,
#   'http://icondataset.org/day': 1,
#   'http://icondataset.org/human-mind': 1,
#   'http://icondataset.org/night': 1,
#   'http://icondataset.org/vita-contemplativa': 1,
#   'http://icondataset.org/spring': 1,
#   'http://icondataset.org/seven-capital-sins': 1,
#   'http://icondataset.org/the-right': 1,
#   'http://icondataset.org/victories': 1,
#   'http://icondataset.org/virtue': 1,
#   'http://icondataset.org/vita-activa': 1,
#   'http://icondataset.org/masks-fallacy-deceit': 1,
#   'http://icondataset.org/natural-venus-amor-humanus': 1,
#   'http://icondataset.org/blowing-in-a-tube-fertilising': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/fire-luxury': 1,
#   'http://icondataset.org/archers-without-arrows-tools-of-a-force-beyond-their-will-and-consciousness': 1,
#   'http://icondataset.org/monk-vita-contemplativa': 1,
#   'http://icondataset.org/mercury-discursive-reason': 1,
#   'http://icondataset.org/trophies-ultimate-triumph-over-the-lower-forms-of-existence': 1,
#   'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom': 1,
#   'http://icondataset.org/angel-wepting-while-carrying-the-coffin-of-the-pope-angel-grieved-that-the-world-had-been-deprived-of-such-a-man': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/children-crouching-down-unborn-souls-doomed-to-descend-to-the-lower-spheres': 1,
#   'http://icondataset.org/flying-towards-marys-head-to-fertilise': 1,
#   'http://icondataset.org/sleeping-cupid-natural-desire-has-nothing-to-do-with-love': 1,
#   'http://icondataset.org/mercury-turning-his-back-to-the-realm-of-the-natural-venus-the-discursive-reason-is-not-involved-in-the-activities-of-the-natural-venus': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/white-lilium-virginity': 1,
#   'http://icondataset.org/mercury-discursive-reason:-limitations-and-possibilities-of-what-human-reason-can-do': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/right-man-salamander': 1,
#   'http://icondataset.org/angel-smiling-while-carrying-the-coffin-of-the-pope-angel-glad-that-the-soul-of-the-pope-had-been-received-among-the-blessed-spirits': 1,
#   'http://icondataset.org/venus-coelestis-amor-divinus': 1,
#   'http://icondataset.org/saint-paul-mens': 1,
#   'http://icondataset.org/victory-human-soul-in-state-of-freedom': 1,
#   'http://icondataset.org/beams-of-light---gods-word': 1,
#   'http://icondataset.org/moses-mens': 1,
#   'http://icondataset.org/man-reclining-on-terrestrial-world-human-mind-placed-between-the-fallacious-and-unreal-life-on-earth-and-the-celestial-realm': 1,
#   'http://icondataset.org/dove-holy-spirit': 1},
#  'http://icondataset.org/formal-or-stylistic-influence (24)': {'http://icondataset.org/mary': 1,
#   'http://icondataset.org/archangel-gabriel': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/atlas': 1},
#  'http://icondataset.org/cultural-reinterpretation (17)': {'http://icondataset.org/cupid': 4,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/the-constellation-hercules': 3,
#   'http://icondataset.org/saturn': 2,
#   'http://icondataset.org/mercury': 2,
#   'http://icondataset.org/venus': 2,
#   'http://icondataset.org/apollo': 2,
#   'http://icondataset.org/algol-head-of-demon': 2,
#   'http://icondataset.org/the-constellation-perseus': 2,
#   'http://icondataset.org/cupid-amor-carnalis': 2,
#   'http://icondataset.org/mary': 1,
#   'http://icondataset.org/mars': 1,
#   'http://icondataset.org/diana': 1,
#   'http://icondataset.org/bacchus': 1,
#   'http://icondataset.org/pluto': 1,
#   'http://icondataset.org/vulcan': 1,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/minerva': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/hercules': 1,
#   'http://icondataset.org/flame-of-divine-wisdom': 1,
#   'http://icondataset.org/death': 1,
#   'http://icondataset.org/sleep': 1,
#   'http://icondataset.org/contemplative-mind': 1,
#   'http://icondataset.org/ibis-homo-carnalis': 1,
#   'http://icondataset.org/apollo-idolatry': 1,
#   'http://icondataset.org/mars-discord': 1,
#   'http://icondataset.org/jupiter-diana-mercury-saturn-as-superior-divinities-reason': 1,
#   'http://icondataset.org/venus-cupid-vulcan-lower-soul': 1,
#   'http://icondataset.org/pluto-avarice': 1,
#   'http://icondataset.org/torch-unholy-ardor': 1,
#   'http://icondataset.org/bacchus-folly': 1,
#   'http://icondataset.org/jupiter-pride': 1,
#   'http://icondataset.org/jupiter-minerva-mercury-saturn-as-superior-divinities-reason': 1},
#  'http://icondataset.org/artists-expression (15)': {'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/phaeton': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/era-sub-vulcano': 3,
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': 3,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/centaur': 2,
#   'http://icondataset.org/phaeton-the-presumptuous': 2,
#   'http://icondataset.org/silenus': 1,
#   'http://icondataset.org/ariadne': 1,
#   'http://icondataset.org/tityus': 1,
#   'http://icondataset.org/hylas': 1,
#   'http://icondataset.org/ganymede': 1,
#   'http://icondataset.org/nymphs': 1,
#   'http://icondataset.org/bacchus': 1,
#   'http://icondataset.org/aeolus': 1,
#   'http://icondataset.org/jupiter-as-an-eagle': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/the-age-of-metal': 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 1,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 1,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 1,
#   'http://icondataset.org/island-of-lemnos': 1,
#   'http://icondataset.org/ignis-elementatus': 1,
#   'http://icondataset.org/victory': 1,
#   'http://icondataset.org/three-stages-of-human-life': 1,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/face-of-a-young-man-the-future': 1,
#   'http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love': 1,
#   'http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness': 1,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 1,
#   'http://icondataset.org/face-of-an-old-man-the-past': 1,
#   'http://icondataset.org/face-of-an-adult-man-the-present': 1,
#   'http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization': 1,
#   'http://icondataset.org/three-headed-companion-of-serapis-prudence': 1,
#   'http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love': 1,
#   'http://icondataset.org/liver-seat-of-physical-passions': 1},
#  'http://icondataset.org/iconographical-influence (15)': {'http://icondataset.org/planetary-deities': 2,
#   'http://icondataset.org/lion-zodiacal-sign': 2,
#   'http://icondataset.org/the-constellation-hercules': 2,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/the-children-of-mercury': 1,
#   'http://icondataset.org/the-three-graces': 1,
#   'http://icondataset.org/serapis': 1,
#   'http://icondataset.org/companion-of-serapis': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/mercury': 1,
#   'http://icondataset.org/apollo-medicus-or-aesculapius': 1,
#   'http://icondataset.org/venus': 1,
#   'http://icondataset.org/death-disembowelling-her-victim': 1,
#   'http://icondataset.org/imperial-orb': 1,
#   'http://icondataset.org/algol-head-of-demon': 1,
#   'http://icondataset.org/heaven': 1,
#   'http://icondataset.org/the-twins-constellation': 1,
#   'http://icondataset.org/blind-death': 1,
#   'http://icondataset.org/blind-synagogue': 1,
#   'http://icondataset.org/sun': 1,
#   'http://icondataset.org/the-constellation-perseus': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1,
#   'http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold': 1,
#   'http://icondataset.org/the-grace-turning-his-back-favor-conferred': 1},
#  'http://icondataset.org/attitude (15)': {'http://icondataset.org/europas-companions': 2,
#   'http://icondataset.org/the-abduction-of-europa': 2,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/the-children-of-each-planet': 1,
#   'http://icondataset.org/apollo': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/europa': 1,
#   'http://icondataset.org/roman-emperors': 1,
#   'http://icondataset.org/planetary-deities': 1,
#   'http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/the-tomb-of-king-ninus': 1,
#   'http://icondataset.org/chastity': 1,
#   'http://icondataset.org/the-constellation-hercules': 1,
#   'http://icondataset.org/bull-christ': 1,
#   'http://icondataset.org/europa-human-soul': 1},
#  'http://icondataset.org/cultural-influence (14)': {'http://icondataset.org/the-constellation-hercules': 2,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/mary': 1,
#   'http://icondataset.org/saints': 1,
#   'http://icondataset.org/moses': 1,
#   'http://icondataset.org/venus': 1,
#   'http://icondataset.org/pope-julius-ii': 1,
#   'http://icondataset.org/angels': 1,
#   'http://icondataset.org/sol-iustitiae': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good': 1,
#   'http://icondataset.org/time-reveals-the-truth': 1,
#   'http://icondataset.org/resurrection-of-christ': 1,
#   'http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one': 1,
#   'http://icondataset.org/lion-zodiacal-sign': 1,
#   'http://icondataset.org/algol-head-of-demon': 1,
#   'http://icondataset.org/planimetrical-scheme-of-the-celestial-spheres': 1,
#   'http://icondataset.org/north-pole-sky': 1,
#   'http://icondataset.org/time-the-revealer': 1,
#   'http://icondataset.org/victories': 1,
#   'http://icondataset.org/the-twins-constellation': 1,
#   'http://icondataset.org/the-constellation-perseus': 1,
#   'http://icondataset.org/fraude': 1,
#   'http://icondataset.org/pleasure': 1,
#   'http://icondataset.org/futile-and-treacherous-pleasure': 1,
#   'http://icondataset.org/jealousy': 1,
#   'http://icondataset.org/truth': 1,
#   'http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone': 1,
#   'http://icondataset.org/pillow-idleness-and-lechery': 1,
#   'http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood': 1,
#   'http://icondataset.org/myrtle-love': 1,
#   'http://icondataset.org/two-billing-doves-amorous-caresses': 1},
#  'http://icondataset.org/societal-phenomenon (10)': {'http://icondataset.org/apollo': 6,
#   'http://icondataset.org/companion-of-serapis': 6,
#   'http://icondataset.org/christ': 2,
#   'http://icondataset.org/anteros': 2,
#   'http://icondataset.org/member-of-the-procession': 2,
#   'http://icondataset.org/aeolus': 2,
#   'http://icondataset.org/vulcan': 2,
#   'http://icondataset.org/satan': 2,
#   'http://icondataset.org/the-young-mago-caspar': 2,
#   'http://icondataset.org/cupid': 2,
#   'http://icondataset.org/aeolus-working-two-blacksmiths-bellows': 2,
#   'http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins': 2,
#   'http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep': 2,
#   'http://icondataset.org/eros-and-anteros-fishing-for-hearts': 2,
#   'http://icondataset.org/the-age-of-metal': 2,
#   'http://icondataset.org/era-sub-vulcano': 2,
#   'http://icondataset.org/faith-has-the-world-under-her-feet': 2,
#   'http://icondataset.org/altar': 2,
#   'http://icondataset.org/original-sin': 2,
#   'http://icondataset.org/bible': 2,
#   'http://icondataset.org/glass-sphere-as-a-popular-decorative-curiosity': 2,
#   'http://icondataset.org/missal': 2,
#   'http://icondataset.org/private-chapel-installed-within-a-large-house': 2,
#   'http://icondataset.org/ignis-elementatus': 2,
#   'http://icondataset.org/divine-justice': 2,
#   'http://icondataset.org/catholic-faith': 2,
#   'http://icondataset.org/mirror-introspection': 2,
#   'http://icondataset.org/white-purity': 2,
#   'http://icondataset.org/glass-sphere-god': 2,
#   'http://icondataset.org/glass-sphere-heaven': 2,
#   'http://icondataset.org/family-simple-happiness-of-primitive-civilization': 2,
#   'http://icondataset.org/weighing-with-balance-allusion-to-last-judgement': 2,
#   'http://icondataset.org/young-mago-future-time': 2,
#   'http://icondataset.org/weighing-with-balance-weighing-of-souls': 2,
#   'http://icondataset.org/jewelry-earthly-goods': 2,
#   'http://icondataset.org/heart-source-of-living-faith': 2,
#   'http://icondataset.org/blue-hue-of-heaven': 2,
#   'http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization': 2}}

# %%
# tpo 10 most frequent subjects per cf
top_5_subj_per_cf = {}
for item in meanings_subjects_with_counts.items():
    if item[0] not in top_5_subj_per_cf:
        top_5_subj_per_cf[item[0]] = {}
        for pair in item[1].items(): 
            if len(top_5_subj_per_cf[item[0]]) < 5:
                top_5_subj_per_cf[item[0]][pair[0]] = pair[1]
               
top_5_subj_per_cf
# Out:
# {'http://icondataset.org/reception-of-classical-antiquity (203)': {'http://icondataset.org/saturn': 16,
#   'http://icondataset.org/cupid': 14,
#   'http://icondataset.org/mercury': 11,
#   'http://icondataset.org/venus': 8,
#   'http://icondataset.org/apollo': 8},
#  'http://icondataset.org/iconographical-evolution (115)': {'http://icondataset.org/saturn': 16,
#   'http://icondataset.org/cupid': 14,
#   'http://icondataset.org/companion-of-serapis': 8,
#   'http://icondataset.org/blindfold-cupid': 6,
#   'http://icondataset.org/apollo': 6},
#  'http://icondataset.org/formal-or-stylistic-evolution (87)': {'http://icondataset.org/mercury': 8,
#   'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/saturn': 3,
#   'http://icondataset.org/apollo': 3},
#  'http://icondataset.org/formal-or-stylistic-phenomenon (59)': {'http://icondataset.org/mary': 2,
#   'http://icondataset.org/christ': 2,
#   'http://icondataset.org/archangel-gabriel': 1,
#   'http://icondataset.org/saint-peter': 1,
#   'http://icondataset.org/europas-companions': 1},
#  'http://icondataset.org/iconographical-interpretation (51)': {'http://icondataset.org/cupid': 10,
#   'http://icondataset.org/saturn': 7,
#   'http://icondataset.org/jupiter': 6,
#   'http://icondataset.org/saturn-devouring-a-living-child': 5,
#   'http://icondataset.org/satyr': 4},
#  'http://icondataset.org/tendency (39)': {'http://icondataset.org/era-sub-vulcano': 4,
#   'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/mary': 3,
#   'http://icondataset.org/centaur': 3,
#   'http://icondataset.org/the-age-of-stone': 3},
#  'http://icondataset.org/belief (30)': {'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/the-age-of-stone': 3,
#   'http://icondataset.org/erection-of-primitive-buildings': 3,
#   'http://icondataset.org/era-sub-vulcano': 3},
#  'http://icondataset.org/formal-or-stylistic-influence (24)': {'http://icondataset.org/mary': 1,
#   'http://icondataset.org/archangel-gabriel': 1,
#   'http://icondataset.org/christ': 1,
#   'http://icondataset.org/atlas': 1},
#  'http://icondataset.org/cultural-reinterpretation (17)': {'http://icondataset.org/cupid': 4,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/the-constellation-hercules': 3,
#   'http://icondataset.org/saturn': 2,
#   'http://icondataset.org/mercury': 2},
#  'http://icondataset.org/artists-expression (15)': {'http://icondataset.org/satyr': 3,
#   'http://icondataset.org/jupiter': 3,
#   'http://icondataset.org/phaeton': 3,
#   'http://icondataset.org/era-ante-vulcanum': 3,
#   'http://icondataset.org/the-age-of-stone': 3},
#  'http://icondataset.org/iconographical-influence (15)': {'http://icondataset.org/planetary-deities': 2,
#   'http://icondataset.org/lion-zodiacal-sign': 2,
#   'http://icondataset.org/the-constellation-hercules': 2,
#   'http://icondataset.org/apollo-god-of-sun': 1,
#   'http://icondataset.org/the-children-of-mercury': 1},
#  'http://icondataset.org/attitude (15)': {'http://icondataset.org/europas-companions': 2,
#   'http://icondataset.org/the-abduction-of-europa': 2,
#   'http://icondataset.org/thisbe': 1,
#   'http://icondataset.org/the-children-of-each-planet': 1,
#   'http://icondataset.org/apollo': 1},
#  'http://icondataset.org/cultural-influence (14)': {'http://icondataset.org/the-constellation-hercules': 2,
#   'http://icondataset.org/hecuba': 1,
#   'http://icondataset.org/cupid': 1,
#   'http://icondataset.org/troilus': 1,
#   'http://icondataset.org/mary': 1},
#  'http://icondataset.org/societal-phenomenon (10)': {'http://icondataset.org/apollo': 6,
#   'http://icondataset.org/companion-of-serapis': 6,
#   'http://icondataset.org/christ': 2,
#   'http://icondataset.org/anteros': 2,
#   'http://icondataset.org/member-of-the-procession': 2}}

# %%
# experiment 1. correlation of cf-level2 subj . lists too long, memory error
final_lists = []
for k,v in meanings_subjects.items(): 
        l = v
        final_lists.append(l)

# %%
print(final_lists)
# Out:
# [['http://icondataset.org/argus', 'http://icondataset.org/vulcan', 'http://icondataset.org/the-three-graces', 'http://icondataset.org/silenus', 'http://icondataset.org/pygmalion', 'http://icondataset.org/archangel-gabriel', 'http://icondataset.org/venus', 'http://icondataset.org/thisbe', 'http://icondataset.org/cupid', 'http://icondataset.org/ganymede', 'http://icondataset.org/saturn', 'http://icondataset.org/vulcan', 'http://icondataset.org/cupid', 'http://icondataset.org/marine-snakes', 'http://icondataset.org/mercury', 'http://icondataset.org/mercury', 'http://icondataset.org/troilus', 'http://icondataset.org/blindfold-cupid', 'http://icondataset.org/companion-of-serapis', 'http://icondataset.org/pluto', 'http://icondataset.org/sisyphus', 'http://icondataset.org/apollo', 'http://icondataset.org/mary', 'http://icondataset.org/blindfold-cupid', 'http://icondataset.org/muses', 'http://icondataset.org/natural-venus', 'http://icondataset.org/paris', 'http://icondataset.org/saturn', 'http://icondataset.org/cupid', 'http://icondataset.org/saturn', 'http://icondataset.org/the-resurrected', 'http://icondataset.org/mercury', 'http://icondataset.org/mercury', 'http://icondataset.org/cupid', 'http://icondataset.org/jupiter', 'http://icondataset.org/saturn', 'http://icondataset.org/centaur', 'http://icondataset.org/bacchus', 'http://icondataset.org/satyr', 'http://icondataset.org/europa', 'http://icondataset.org/cerberus', 'http://icondataset.org/jupiter', 'http://icondataset.org/saint-john-the-evangelist', 'http://icondataset.org/thymbraeus-son-of-laoocoon', 'http://icondataset.org/nymphs', 'http://icondataset.org/phaeton', 'http://icondataset.org/mercury', 'http://icondataset.org/the-children-of-saturn', 'http://icondataset.org/saturn', 'http://icondataset.org/saint-mark', 'http://icondataset.org/venus', 'http://icondataset.org/vulcan', 'http://icondataset.org/aeneas', 'http://icondataset.org/europas-companions', 'http://icondataset.org/mercury', 'http://icondataset.org/companion-of-serapis', 'http://icondataset.org/people/virgil', 'http://icondataset.org/the-three-graces', 'http://icondataset.org/prometheus', 'http://icondataset.org/hercules', 'http://icondataset.org/saturn', 'http://icondataset.org/erato', 'http://icondataset.org/people/virgil', 'http://icondataset.org/blindfold-cupid', 'http://icondataset.org/pluto', 'http://icondataset.org/cerberus', 'http://icondataset.org/mars', 'http://icondataset.org/mercury', 'http://icondataset.org/saturn', 'http://icondataset.org/dido', 'http://icondataset.org/perseus', 'http://icondataset.org/saturn', 'http://icondataset.org/cupid', 'http://icondataset.org/sol-iustitiae', 'http://icondataset.org/anteros', 'http://icondataset.org/jupiter', 'http://icondataset.org/christ', 'http://icondataset.org/hylas', 'http://icondataset.org/cupid', 'http://icondataset.org/mary', 'http://icondataset.org/mars', 'http://icondataset.org/jupiter', 'http://icondataset.org/venus-coelestis', 'http://icondataset.org/mercury', 'http://icondataset.org/apollo', 'http://icondataset.org/satyr', 'http://icondataset.org/satyr', 'http://icondataset.org/mithras', 'http://icondataset.org/ariadne', 'http://icondataset.org/mercury', 'http://icondataset.org/cupid', 'http://icondataset.org/saturn', 'http://icondataset.org/mary', 'http://icondataset.org/mercury', 'http://icondataset.org/polyxena', 'http://icondataset.org/saturn', 'http://icondataset.org/blindfold-cupid', 'http://icondataset.org/centaur', 'http://icondataset.org/antiphas-son-of-laoocoon', 'http://icondataset.org/europas-companions', 'http://icondataset.org/polyxena', 'http://icondataset.org/mary', 'http://icondataset.org/prometheus', 'http://icondataset.org/argus', 'http://icondataset.org/blindfold-cupid', 'http://icondataset.org/jupiter-as-an-eagle', 'http://icondataset.org/orpheus', 'http://icondataset.org/prophet', 'http://icondataset.org/hecuba', 'http://icondataset.org/saturn', 'http://icondataset.org/saturn', 'http://icondataset.org/rachel', 'http://iconda ...

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
import pandas as pd


dataset = final_lists

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df, min_support=0.15, use_colnames=True)
frequent_itemsets
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# C:\Users\SOFIAB~1\AppData\Local\Temp/ipykernel_15068/1669039847.py in <module>
#      10 df = pd.DataFrame(te_ary, columns=te.columns_)
#      11
# ---> 12 frequent_itemsets = apriori(df, min_support=0.15, use_colnames=True)
#      13 frequent_itemsets
#
# ~\AppData\Roaming\Python\Python39\site-packages\mlxtend\frequent_patterns\apriori.py in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     285         else:
#     286             combin = generate_new_combinations(itemset_dict[max_itemset])
# --> 287             combin = np.fromiter(combin, dtype=int)
#     288             combin = combin.reshape(-1, next_max_itemset)
#     289
#
# MemoryError: cannot allocate array memory

# %%
# same, with categories of subjects


cq2 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>
prefix skos: <http://www.w3.org/2004/02/skos/core#>

SELECT DISTINCT ?CFbroader ?CFbroaderLabel ?artwork ?subj2 ?subj2Broader WHERE {
  VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
  VALUES ?CFbroader { """+ ' '.join(well_represented_phenomena) +"""}
  # ?CFbroader ^crm:P2_has_type ?meaning.
  # ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?iconol icon:aboutWorkOfArt ?artwork .
  # ?icrec icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition; 
          icon:recognizedImage ?image. 
  # ?CFbroader rdfs:label ?CFbroaderLabel. 
  # ?image ?rel ?subj2. 

  OPTIONAL {?subj2 skos:broader ?subj2Broader }
  OPTIONAL {?invenzione skos:broader ?invenzioneBroader }

} 
""" 

cq2res = g.query(cq2)
for row in cq2res:
  print(row[0], '-',row[3], "has broader subject: ", row[4], " -- meaning:", row[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SOFIAB~1\AppData\Local\Temp/ipykernel_15068/1769211588.py in <module>
#      12 SELECT DISTINCT ?CFbroader ?CFbroaderLabel ?artwork ?subj2 ?subj2Broader WHERE {
#      13   VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
# ---> 14   VALUES ?CFbroader { """+ ' '.join(well_represented_phenomena) +"""}
#      15   ?CFbroader ^crm:P2_has_type ?meaning.
#      16   ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
#
# NameError: name 'well_represented_phenomena' is not defined

# %% [markdown]
# Notes: there are too many subjects to see a pattern, I'd try to group them by type, manually, in a second iteration? e.g. greek gods, places, mythological figures, landscape, and so on.
#
# Question: is it possible that you have many artworks without subjects of level 2? Look for instance at http://icondataset.org/CF1327, which is associated to 10 artworks, but all subjects appear in one artwork only. Answer: they appear in all the artworks only once.
#
# You can use the same method to query subjects of level 1.

# %% [markdown]
# # cultural phenomena correlation with stories and allegories

# %%
# same, with categories of subjects


cq2 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>
prefix skos: <http://www.w3.org/2004/02/skos/core#>

SELECT DISTINCT ?CFbroader ?CFbroaderLabel ?artwork ?invenzione ?invenzioneBroader ?type WHERE {
  VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
  VALUES ?CFbroader { """+ ' '.join(well_represented_phenomena) +"""}
  # ?CFbroader ^crm:P2_has_type ?meaning; rdfs:label ?CFbroaderLabel. 
  # ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?iconol icon:aboutWorkOfArt ?artwork .
  # ?icrec icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition; 
          icon:recognizedInvenzione ?invenzione. 
  # ?invenzione rdfs:label ?invenzioneLabel; a ?type. 

  OPTIONAL {?invenzione skos:broader ?invenzioneBroader }
  OPTIONAL {?invenzione skos:broader ?invenzioneBroader. ?invenzioneBroader  rdfs:label ?invenzioneBroaderLabel }

} 
""" 

cq2res = g.query(cq2)
for row in cq2res:
  #print(row)  
    print(row[0], '-',row[3],"has type: ", row[5], "has broader: ", row[4], " -- meaning:", row[1])
    if row[4] != "None": 
        inv = row[4]
    else: 
        inv = row[3]
# Out:
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/perseus-and-medusa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/perseus-and-medusa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-perseus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/hercules-fighting-the-lion has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/hercules-fighting-the-lion has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-hercules  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Story has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-rape-of-proserpina has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-rape-of-proserpina has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-pluto  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-advent-of-the-celestial-venus has type:  https://w3id.org/icon/ontology/Invenzione has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pygmalion-falls-in-love-with-the-statue-he-is-carving has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/pygmalion-falls-in-love-with-the-statue-he-is-carving has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-pygmalion  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/luxury has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-bacchus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/happy-union-of-a-betrothed-or-married-couple has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Event has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/allegory-of-salvation has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/luxury has type:  https://w3id.org/icon/ontology/Personification has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-story-of-laocoon-and-his-sons has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-annunciation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-visitation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-visitation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/the-annunciation  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-forces-forming-the-cycle-of-mans-social-destiny-dance-to-the-lyre-of-time has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-calumny-of-apelles has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/legend-of-the-three-quick-and-the-three-dead has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/legend  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/birth-of-venus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/birth-of-venus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-venus  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-presentation-of-christ has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-presentation-of-christ has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/birth-and-youth-of-christ  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-realm-of-the-natural-venus has type:  https://w3id.org/icon/ontology/Invenzione has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-to-symbolize-that-affection-changes-with-luck has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-rape-of-proserpina has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/the-rape-of-proserpina has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-pluto  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/story-of-tityus-whose-liver-is-devoured-by-a-vulture has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/abduction-of-helen has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-the-stone has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/saturn-devouring-the-stone has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter-rapes-ganymede-and-takes-him-to-the-olympus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/jupiter-rapes-ganymede-and-takes-him-to-the-olympus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/allegory-of-good-counsel has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/reception-of-classical-antiquity - http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Reception of Classical antiquity
# http://icondataset.org/iconographical-evolution - http://icondataset.org/allegory-of-good-counsel has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/luxury has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-the-stone has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-the-stone has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-bacchus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/luxury has type:  https://w3id.org/icon/ontology/Personification has broader:  None  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-to-symbolize-that-affection-changes-with-luck has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/crucifixion has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/crucifixion has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/passion-of-christ  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-calumny-of-apelles has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/legend-of-the-three-quick-and-the-three-dead has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/legend  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/allegory-of-salvation has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/crucifixion has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/bible  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/crucifixion has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/passion-of-christ  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/hermes-aglauros-and-herse has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/birth-of-venus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/birth-of-venus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-venus  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/hermes-aglauros-and-herse has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-forces-forming-the-cycle-of-mans-social-destiny-dance-to-the-lyre-of-time has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/the-advent-of-the-celestial-venus has type:  https://w3id.org/icon/ontology/Invenzione has broader:  None  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/perseus-and-medusa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical evolution
# http://icondataset.org/iconographical-evolution - http://icondataset.org/perseus-and-medusa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-perseus  -- meaning: Iconographical evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Story has broader:  None  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-rape-of-proserpina has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-rape-of-proserpina has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-pluto  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-bacchus  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/pygmalion-falls-in-love-with-the-statue-he-is-carving has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/pygmalion-falls-in-love-with-the-statue-he-is-carving has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-pygmalion  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Event has broader:  None  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-calumny-of-apelles has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-visitation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-visitation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/the-annunciation  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-rape-of-proserpina has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-rape-of-proserpina has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-pluto  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/the-story-of-laocoon-and-his-sons has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/abduction-of-helen has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-evolution - http://icondataset.org/life-of-the-bishop-simone-saltarelli has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story  -- meaning: Formal or stylistic evolution
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-resurrection-of-the-youth-of-nain has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-resurrection-of-the-youth-of-nain has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/public-life-of-christ  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-visitation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-visitation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/the-annunciation  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-presentation-of-christ has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-presentation-of-christ has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/birth-and-youth-of-christ  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-annunciation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/abduction-of-helen has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-vision-of-the-magi has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/formal-or-stylistic-phenomenon - http://icondataset.org/the-vision-of-the-magi has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/the-story-of-the-magi  -- meaning: Formal or stylistic phenomenon
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Story has broader:  None  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-to-symbolize-that-affection-changes-with-luck has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Event has broader:  None  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/conflict-between-lust-and-reason has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-bacchus  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/the-choice-of-beauty-between-blind-cupid-and-clearsighted-love has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/human-life-on-earth-with-its-defeats-and-victories has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/luxury has type:  https://w3id.org/icon/ontology/Personification has broader:  None  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/luxury has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/saturn-devouring-his-children has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-saturn  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/the-calumny-of-apelles has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/jupiter-rapes-ganymede-and-takes-him-to-the-olympus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/jupiter-rapes-ganymede-and-takes-him-to-the-olympus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/the-story-of-laocoon-and-his-sons has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/happy-union-of-a-betrothed-or-married-couple has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical interpretation
# http://icondataset.org/iconographical-interpretation - http://icondataset.org/story-of-tityus-whose-liver-is-devoured-by-a-vulture has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Iconographical interpretation
# http://icondataset.org/tendency - http://icondataset.org/the-presentation-of-christ has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/the-presentation-of-christ has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/birth-and-youth-of-christ  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-bacchus  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/the-visitation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/the-visitation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/the-annunciation  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Story has broader:  None  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/allegory-of-salvation has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Tendency
# http://icondataset.org/tendency - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Event has broader:  None  -- meaning: Tendency
# http://icondataset.org/belief - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Story has broader:  None  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Event has broader:  None  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/the-annunciation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/the-realm-of-the-natural-venus has type:  https://w3id.org/icon/ontology/Invenzione has broader:  None  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/immaculate-conception has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-bacchus  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/human-life-on-earth-with-its-defeats-and-victories has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/effects-of-natural-forces-on-creatures-not-endowed-with-consciousness has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/immaculate-conception has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/jupiter-rapes-ganymede-and-takes-him-to-the-olympus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/jupiter-rapes-ganymede-and-takes-him-to-the-olympus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/the-right-man-doesnt-burn-in-the-flames-of-luxury-and-seduction has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/the-advent-of-the-celestial-venus has type:  https://w3id.org/icon/ontology/Invenzione has broader:  None  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/birth-of-venus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/birth-of-venus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-venus  -- meaning: Belief
# http://icondataset.org/belief - http://icondataset.org/the-annunciation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Belief
# http://icondataset.org/formal-or-stylistic-influence - http://icondataset.org/the-annunciation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Formal or stylistic influence
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/conflict-between-lust-and-reason has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/the-visitation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/bible  -- meaning: Cultural reinterpretation
# http://icondataset.org/cultural-reinterpretation - http://icondataset.org/the-visitation has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/the-annunciation  -- meaning: Cultural reinterpretation
# http://icondataset.org/artists-expression - http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/bacchus-discovers-the-honey has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/story-of-bacchus  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/jupiter-rapes-ganymede-and-takes-him-to-the-olympus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/jupiter-rapes-ganymede-and-takes-him-to-the-olympus has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Story has broader:  None  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos has type:  https://w3id.org/icon/ontology/Event has broader:  None  -- meaning: Artist's expression
# http://icondataset.org/artists-expression - http://icondataset.org/story-of-tityus-whose-liver-is-devoured-by-a-vulture has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Artist's expression
# http://icondataset.org/iconographical-influence - http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical influence
# http://icondataset.org/iconographical-influence - http://icondataset.org/allegory-of-sun has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Iconographical influence
# http://icondataset.org/attitude - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Attitude
# http://icondataset.org/attitude - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Attitude
# http://icondataset.org/attitude - http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Attitude
# http://icondataset.org/attitude - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Attitude
# http://icondataset.org/attitude - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Attitude
# http://icondataset.org/attitude - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Attitude
# http://icondataset.org/attitude - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Event has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Attitude
# http://icondataset.org/attitude - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/classical-mythology-and-ancient-history  -- meaning: Attitude
# http://icondataset.org/attitude - http://icondataset.org/the-abduction-of-europa has type:  https://w3id.org/icon/ontology/Story has broader:  http://icondataset.org/love-affairs-of-jupiter  -- meaning: Attitude
# http://icondataset.org/cultural-influence - http://icondataset.org/luxury has type:  https://w3id.org/icon/ontology/Personification has broader:  None  -- meaning: Cultural influence
# http://icondataset.org/cultural-influence - http://icondataset.org/luxury has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Cultural influence
# http://icondataset.org/societal-phenomenon - http://icondataset.org/allegory-of-divine-justice has type:  https://w3id.org/icon/ontology/Allegory has broader:  None  -- meaning: Societal phenomenon

# %%
from collections import defaultdict , Counter

meanings_inv = defaultdict(list)
# ?meaning ?artwork ?subj2
for row in cq2res:
    if row[4] == None: 
        inv = str(row[3])
    else: 
        inv = (row[4])
    meanings_inv[str(row['CFbroader'])].append(inv)

meanings_inv_with_counts = {}
for k,v in meanings_inv.items():
  for m,c in well_represented_phenomena_and_counts:
    if k == m:
      meanings_inv_with_counts[k+" ("+c+")"] = dict(Counter(v).most_common())

# add count

meanings_inv_with_counts
# Out:
# {'http://icondataset.org/reception-of-classical-antiquity (203)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 22,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 6,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 5,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 3,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-pluto'): 2,
#   'http://icondataset.org/luxury': 2,
#   rdflib.term.URIRef('http://icondataset.org/story-of-perseus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-hercules'): 1,
#   'http://icondataset.org/the-advent-of-the-celestial-venus': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-pygmalion'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   'http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul': 1,
#   'http://icondataset.org/happy-union-of-a-betrothed-or-married-couple': 1,
#   'http://icondataset.org/allegory-of-salvation': 1,
#   'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1,
#   'http://icondataset.org/the-forces-forming-the-cycle-of-mans-social-destiny-dance-to-the-lyre-of-time': 1,
#   rdflib.term.URIRef('http://icondataset.org/legend'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-venus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/birth-and-youth-of-christ'): 1,
#   'http://icondataset.org/the-realm-of-the-natural-venus': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-to-symbolize-that-affection-changes-with-luck': 1,
#   'http://icondataset.org/allegory-of-good-counsel': 1,
#   'http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love': 1},
#  'http://icondataset.org/iconographical-evolution (115)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 14,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 6,
#   'http://icondataset.org/luxury': 2,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 2,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 2,
#   rdflib.term.URIRef('http://icondataset.org/passion-of-christ'): 2,
#   'http://icondataset.org/allegory-of-good-counsel': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-to-symbolize-that-affection-changes-with-luck': 1,
#   rdflib.term.URIRef('http://icondataset.org/legend'): 1,
#   'http://icondataset.org/allegory-of-salvation': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-venus'): 1,
#   'http://icondataset.org/the-forces-forming-the-cycle-of-mans-social-destiny-dance-to-the-lyre-of-time': 1,
#   'http://icondataset.org/the-advent-of-the-celestial-venus': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-perseus'): 1},
#  'http://icondataset.org/formal-or-stylistic-evolution (89)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 11,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 4,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-pluto'): 2,
#   'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-pygmalion'): 1,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1,
#   'http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul': 1,
#   rdflib.term.URIRef('http://icondataset.org/story'): 1},
#  'http://icondataset.org/formal-or-stylistic-phenomenon (61)': {rdflib.term.URIRef('http://icondataset.org/bible'): 5,
#   rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 2,
#   rdflib.term.URIRef('http://icondataset.org/public-life-of-christ'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1,
#   rdflib.term.URIRef('http://icondataset.org/birth-and-youth-of-christ'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-story-of-the-magi'): 1},
#  'http://icondataset.org/iconographical-interpretation (51)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 10,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 5,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2,
#   'http://icondataset.org/luxury': 2,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-to-symbolize-that-affection-changes-with-luck': 1,
#   'http://icondataset.org/conflict-between-lust-and-reason': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   'http://icondataset.org/the-choice-of-beauty-between-blind-cupid-and-clearsighted-love': 1,
#   'http://icondataset.org/human-life-on-earth-with-its-defeats-and-victories': 1,
#   'http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love': 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1,
#   'http://icondataset.org/happy-union-of-a-betrothed-or-married-couple': 1},
#  'http://icondataset.org/tendency (39)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 2,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 2,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2,
#   rdflib.term.URIRef('http://icondataset.org/birth-and-youth-of-christ'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1,
#   'http://icondataset.org/allegory-of-salvation': 1},
#  'http://icondataset.org/belief (30)': {rdflib.term.URIRef('http://icondataset.org/bible'): 4,
#   rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2,
#   'http://icondataset.org/the-realm-of-the-natural-venus': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   'http://icondataset.org/human-life-on-earth-with-its-defeats-and-victories': 1,
#   'http://icondataset.org/effects-of-natural-forces-on-creatures-not-endowed-with-consciousness': 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1,
#   'http://icondataset.org/the-right-man-doesnt-burn-in-the-flames-of-luxury-and-seduction': 1,
#   'http://icondataset.org/the-advent-of-the-celestial-venus': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-venus'): 1},
#  'http://icondataset.org/formal-or-stylistic-influence (24)': {rdflib.term.URIRef('http://icondataset.org/bible'): 1},
#  'http://icondataset.org/cultural-reinterpretation (17)': {'http://icondataset.org/conflict-between-lust-and-reason': 1,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1},
#  'http://icondataset.org/artists-expression (15)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2,
#   'http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1},
#  'http://icondataset.org/iconographical-influence (15)': {'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   'http://icondataset.org/allegory-of-sun': 1},
#  'http://icondataset.org/attitude (15)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 4,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 4,
#   'http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul': 1},
#  'http://icondataset.org/cultural-influence (14)': {'http://icondataset.org/luxury': 2},
#  'http://icondataset.org/societal-phenomenon (10)': {'http://icondataset.org/allegory-of-divine-justice': 1}}

# %%
# tpo 5 most frequent subjects per cf
top_5_inv_per_cf = {}
for item in meanings_inv_with_counts.items():
    if item[0] not in top_5_inv_per_cf:
        top_5_inv_per_cf[item[0]] = {}
        for pair in item[1].items(): 
            if len(top_5_inv_per_cf[item[0]]) < 5:
                top_5_inv_per_cf[item[0]][pair[0]] = pair[1]
               
top_5_inv_per_cf
# Out:
# {'http://icondataset.org/reception-of-classical-antiquity (203)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 22,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 6,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 5,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 3,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2},
#  'http://icondataset.org/iconographical-evolution (115)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 14,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 6,
#   'http://icondataset.org/luxury': 2,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 2,
#   rdflib.term.URIRef('http://icondataset.org/passion-of-christ'): 2},
#  'http://icondataset.org/formal-or-stylistic-evolution (87)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 11,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 4,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-pluto'): 2,
#   'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1},
#  'http://icondataset.org/formal-or-stylistic-phenomenon (59)': {rdflib.term.URIRef('http://icondataset.org/bible'): 5,
#   rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 2,
#   rdflib.term.URIRef('http://icondataset.org/public-life-of-christ'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1},
#  'http://icondataset.org/iconographical-interpretation (51)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 10,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 5,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2,
#   'http://icondataset.org/luxury': 2,
#   'http://icondataset.org/human-life-on-earth-with-its-defeats-and-victories': 1},
#  'http://icondataset.org/tendency (39)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 2,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 2,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1},
#  'http://icondataset.org/belief (30)': {rdflib.term.URIRef('http://icondataset.org/bible'): 4,
#   rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2,
#   'http://icondataset.org/the-advent-of-the-celestial-venus': 1,
#   'http://icondataset.org/the-right-man-doesnt-burn-in-the-flames-of-luxury-and-seduction': 1},
#  'http://icondataset.org/formal-or-stylistic-influence (24)': {rdflib.term.URIRef('http://icondataset.org/bible'): 1},
#  'http://icondataset.org/cultural-reinterpretation (17)': {'http://icondataset.org/conflict-between-lust-and-reason': 1,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1},
#  'http://icondataset.org/artists-expression (15)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 2,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   'http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love': 1},
#  'http://icondataset.org/iconographical-influence (15)': {'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   'http://icondataset.org/allegory-of-sun': 1},
#  'http://icondataset.org/attitude (15)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 4,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 4,
#   'http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul': 1},
#  'http://icondataset.org/cultural-influence (14)': {'http://icondataset.org/luxury': 2},
#  'http://icondataset.org/societal-phenomenon (10)': {'http://icondataset.org/allegory-of-divine-justice': 2}}

# %%
# repeat dividing for stories and allegories

# %%
# same, dividing allegories and stories
# from collections import defaultdict , Counter

meanings_inv_story = defaultdict(list)
meanings_inv_allegory = defaultdict(list)
# ?meaning ?artwork ?subj2
for row in cq2res:
    if row[4] == None: 
        inv = str(row[3])
    else: 
        inv = (row[4])
    if str(row[5]) == 'https://w3id.org/icon/ontology/Allegory': 
        meanings_inv_allegory[str(row['CFbroader'])].append(inv)
    elif str(row[5]) == 'https://w3id.org/icon/ontology/Story': 
        meanings_inv_story[str(row['CFbroader'])].append(inv)

meanings_story_with_counts = {}
for k,v in meanings_inv_story.items():
  for m,c in well_represented_phenomena_and_counts:
    if k == m:
      meanings_story_with_counts[k+" ("+c+")"] = dict(Counter(v).most_common())

meanings_allegory_with_counts = {}
for k,v in meanings_inv_allegory.items():
  for m,c in well_represented_phenomena_and_counts:
    if k == m:
      meanings_allegory_with_counts[k+" ("+c+")"] = dict(Counter(v).most_common())
# add count

meanings_story_with_counts
#meanings_allegory_with_counts
# Out:
# {'http://icondataset.org/reception-of-classical-antiquity (203)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 20,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 6,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 3,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 3,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-pluto'): 2,
#   rdflib.term.URIRef('http://icondataset.org/story-of-perseus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-hercules'): 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-pygmalion'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1,
#   rdflib.term.URIRef('http://icondataset.org/legend'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-venus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/birth-and-youth-of-christ'): 1},
#  'http://icondataset.org/iconographical-evolution (115)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 13,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 6,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 1,
#   rdflib.term.URIRef('http://icondataset.org/passion-of-christ'): 1,
#   rdflib.term.URIRef('http://icondataset.org/legend'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-venus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-perseus'): 1},
#  'http://icondataset.org/formal-or-stylistic-evolution (89)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 9,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 2,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-pluto'): 2,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-pygmalion'): 1,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story'): 1},
#  'http://icondataset.org/formal-or-stylistic-phenomenon (61)': {rdflib.term.URIRef('http://icondataset.org/bible'): 5,
#   rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 2,
#   rdflib.term.URIRef('http://icondataset.org/public-life-of-christ'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1,
#   rdflib.term.URIRef('http://icondataset.org/birth-and-youth-of-christ'): 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-story-of-the-magi'): 1},
#  'http://icondataset.org/iconographical-interpretation (51)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 10,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 5,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1},
#  'http://icondataset.org/tendency (39)': {rdflib.term.URIRef('http://icondataset.org/bible'): 2,
#   rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 2,
#   rdflib.term.URIRef('http://icondataset.org/birth-and-youth-of-christ'): 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1},
#  'http://icondataset.org/belief (30)': {rdflib.term.URIRef('http://icondataset.org/bible'): 4,
#   rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-venus'): 1},
#  'http://icondataset.org/formal-or-stylistic-influence (24)': {rdflib.term.URIRef('http://icondataset.org/bible'): 1},
#  'http://icondataset.org/cultural-reinterpretation (17)': {rdflib.term.URIRef('http://icondataset.org/bible'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1},
#  'http://icondataset.org/artists-expression (15)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1},
#  'http://icondataset.org/attitude (15)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 2,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 2}}

# %%
meanings_allegory_with_counts
# Out:
# {'http://icondataset.org/reception-of-classical-antiquity (203)': {'http://icondataset.org/luxury': 1,
#   'http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul': 1,
#   'http://icondataset.org/happy-union-of-a-betrothed-or-married-couple': 1,
#   'http://icondataset.org/allegory-of-salvation': 1,
#   'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   'http://icondataset.org/the-forces-forming-the-cycle-of-mans-social-destiny-dance-to-the-lyre-of-time': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-to-symbolize-that-affection-changes-with-luck': 1,
#   'http://icondataset.org/allegory-of-good-counsel': 1,
#   'http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love': 1},
#  'http://icondataset.org/iconographical-evolution (115)': {'http://icondataset.org/allegory-of-good-counsel': 1,
#   'http://icondataset.org/luxury': 1,
#   'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-to-symbolize-that-affection-changes-with-luck': 1,
#   'http://icondataset.org/allegory-of-salvation': 1,
#   'http://icondataset.org/the-forces-forming-the-cycle-of-mans-social-destiny-dance-to-the-lyre-of-time': 1},
#  'http://icondataset.org/formal-or-stylistic-evolution (89)': {'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   'http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul': 1},
#  'http://icondataset.org/iconographical-interpretation (51)': {'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-to-symbolize-that-affection-changes-with-luck': 1,
#   'http://icondataset.org/conflict-between-lust-and-reason': 1,
#   'http://icondataset.org/the-choice-of-beauty-between-blind-cupid-and-clearsighted-love': 1,
#   'http://icondataset.org/human-life-on-earth-with-its-defeats-and-victories': 1,
#   'http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love': 1,
#   'http://icondataset.org/luxury': 1,
#   'http://icondataset.org/happy-union-of-a-betrothed-or-married-couple': 1},
#  'http://icondataset.org/tendency (39)': {'http://icondataset.org/allegory-of-salvation': 1},
#  'http://icondataset.org/belief (30)': {'http://icondataset.org/human-life-on-earth-with-its-defeats-and-victories': 1,
#   'http://icondataset.org/effects-of-natural-forces-on-creatures-not-endowed-with-consciousness': 1,
#   'http://icondataset.org/the-right-man-doesnt-burn-in-the-flames-of-luxury-and-seduction': 1},
#  'http://icondataset.org/cultural-reinterpretation (17)': {'http://icondataset.org/conflict-between-lust-and-reason': 1},
#  'http://icondataset.org/artists-expression (15)': {'http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love': 1},
#  'http://icondataset.org/iconographical-influence (15)': {'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   'http://icondataset.org/allegory-of-sun': 1},
#  'http://icondataset.org/attitude (15)': {'http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul': 1},
#  'http://icondataset.org/cultural-influence (14)': {'http://icondataset.org/luxury': 1},
#  'http://icondataset.org/societal-phenomenon (10)': {'http://icondataset.org/allegory-of-divine-justice': 1}}

# %%
# tpo 5 most frequent subjects per cf
top_5_story_per_cf = {}
for item in meanings_story_with_counts.items():
    if item[0] not in top_5_story_per_cf:
        top_5_story_per_cf[item[0]] = {}
        for pair in item[1].items(): 
            if len(top_5_story_per_cf[item[0]]) < 5:
                top_5_story_per_cf[item[0]][pair[0]] = pair[1]
               
top_5_story_per_cf
# Out:
# {'http://icondataset.org/reception-of-classical-antiquity (203)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 20,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 6,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 3,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 3,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-pluto'): 2},
#  'http://icondataset.org/iconographical-evolution (115)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 13,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 6,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/bible'): 1},
#  'http://icondataset.org/formal-or-stylistic-evolution (89)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 9,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 2,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-pluto'): 2,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1},
#  'http://icondataset.org/formal-or-stylistic-phenomenon (61)': {rdflib.term.URIRef('http://icondataset.org/bible'): 5,
#   rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 2,
#   rdflib.term.URIRef('http://icondataset.org/public-life-of-christ'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1,
#   rdflib.term.URIRef('http://icondataset.org/birth-and-youth-of-christ'): 1},
#  'http://icondataset.org/iconographical-interpretation (51)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 10,
#   rdflib.term.URIRef('http://icondataset.org/story-of-saturn'): 5,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1},
#  'http://icondataset.org/tendency (39)': {rdflib.term.URIRef('http://icondataset.org/bible'): 2,
#   rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 2,
#   rdflib.term.URIRef('http://icondataset.org/birth-and-youth-of-christ'): 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1},
#  'http://icondataset.org/belief (30)': {rdflib.term.URIRef('http://icondataset.org/bible'): 4,
#   rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1},
#  'http://icondataset.org/formal-or-stylistic-influence (24)': {rdflib.term.URIRef('http://icondataset.org/bible'): 1},
#  'http://icondataset.org/cultural-reinterpretation (17)': {rdflib.term.URIRef('http://icondataset.org/bible'): 1,
#   rdflib.term.URIRef('http://icondataset.org/the-annunciation'): 1},
#  'http://icondataset.org/artists-expression (15)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 3,
#   rdflib.term.URIRef('http://icondataset.org/story-of-bacchus'): 1,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 1,
#   'http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos': 1},
#  'http://icondataset.org/attitude (15)': {rdflib.term.URIRef('http://icondataset.org/classical-mythology-and-ancient-history'): 2,
#   rdflib.term.URIRef('http://icondataset.org/love-affairs-of-jupiter'): 2}}

# %%
# tpo 5 most frequent subjects per cf
top_5_allegory_per_cf = {}
for item in meanings_allegory_with_counts.items():
    if item[0] not in top_5_allegory_per_cf:
        top_5_allegory_per_cf[item[0]] = {}
        for pair in item[1].items(): 
            if len(top_5_allegory_per_cf[item[0]]) < 5:
                top_5_allegory_per_cf[item[0]][pair[0]] = pair[1]
               
top_5_allegory_per_cf
# Out:
# {'http://icondataset.org/reception-of-classical-antiquity (203)': {'http://icondataset.org/luxury': 1,
#   'http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul': 1,
#   'http://icondataset.org/happy-union-of-a-betrothed-or-married-couple': 1,
#   'http://icondataset.org/allegory-of-salvation': 1,
#   'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1},
#  'http://icondataset.org/iconographical-evolution (115)': {'http://icondataset.org/allegory-of-good-counsel': 1,
#   'http://icondataset.org/luxury': 1,
#   'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-to-symbolize-that-affection-changes-with-luck': 1,
#   'http://icondataset.org/allegory-of-salvation': 1},
#  'http://icondataset.org/formal-or-stylistic-evolution (89)': {'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   'http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul': 1},
#  'http://icondataset.org/iconographical-interpretation (51)': {'http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-to-symbolize-that-affection-changes-with-luck': 1,
#   'http://icondataset.org/conflict-between-lust-and-reason': 1,
#   'http://icondataset.org/the-choice-of-beauty-between-blind-cupid-and-clearsighted-love': 1,
#   'http://icondataset.org/human-life-on-earth-with-its-defeats-and-victories': 1,
#   'http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love': 1},
#  'http://icondataset.org/tendency (39)': {'http://icondataset.org/allegory-of-salvation': 1},
#  'http://icondataset.org/belief (30)': {'http://icondataset.org/human-life-on-earth-with-its-defeats-and-victories': 1,
#   'http://icondataset.org/effects-of-natural-forces-on-creatures-not-endowed-with-consciousness': 1,
#   'http://icondataset.org/the-right-man-doesnt-burn-in-the-flames-of-luxury-and-seduction': 1},
#  'http://icondataset.org/cultural-reinterpretation (17)': {'http://icondataset.org/conflict-between-lust-and-reason': 1},
#  'http://icondataset.org/artists-expression (15)': {'http://icondataset.org/allegory-of-the-tortures-caused-by-immoderate-love': 1},
#  'http://icondataset.org/iconographical-influence (15)': {'http://icondataset.org/allegorical-explanation-of-the-the-three-graces-position': 1,
#   'http://icondataset.org/allegory-of-sun': 1},
#  'http://icondataset.org/attitude (15)': {'http://icondataset.org/the-abduction-of-europa-as-allegory-of-christ-saving-the-human-soul': 1},
#  'http://icondataset.org/cultural-influence (14)': {'http://icondataset.org/luxury': 1},
#  'http://icondataset.org/societal-phenomenon (10)': {'http://icondataset.org/allegory-of-divine-justice': 1}}

# %%
# See if there are artworks with stories and allegories not having a cf 


cq4 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>
prefix skos: <http://www.w3.org/2004/02/skos/core#>

SELECT DISTINCT ?invenzione ?invenzioneLabel ?artwork WHERE {
  VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
 # VALUES ?CFbroader { """+ ' '.join(well_represented_phenomena) +"""}
  # ?icrec icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition; 
          icon:recognizedInvenzione ?invenzione. 
  # ?invenzione rdfs:label ?invenzioneLabel; a ?type. 
MINUS { ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?iconol icon:aboutWorkOfArt ?artwork .}

} 
""" 

cq4res = g.query(cq4)
for row in cq4res:
  #print(row)  
    print(row[0], row[1], row[2])
# Out:
# http://icondataset.org/hercules-and-the-erymanthian-boar Hercules and the Erymanthian Boar http://icondataset.org/ART1003
# http://icondataset.org/the-story-of-laocoon-and-his-sons The story of Laocoon and his sons http://icondataset.org/ART1006test
# http://icondataset.org/story-of-quos-ego Story of Quos Ego http://icondataset.org/ART1011test
# http://icondataset.org/the-rape-of-cybele The rape of Cybele http://icondataset.org/ART1015test
# http://icondataset.org/time-carrying-off-the-truth Time carrying off the Truth http://icondataset.org/ART1015test
# http://icondataset.org/judith-and-holofernes Judith and Holofernes http://icondataset.org/ART1234
# http://icondataset.org/eros-and-anteros-struggling-for-the-palm-branch Eros and Anteros struggling for the palm branch http://icondataset.org/ART1308
# http://icondataset.org/the-descent-into-limbo The descent into Limbo http://icondataset.org/ART1537

# %%
# level 2 representation of the invenzioni not having a cf

# See if there are artworks with stories and allegories not having a cf 

inv_without_cf = set()
cq4 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>
prefix skos: <http://www.w3.org/2004/02/skos/core#>

SELECT DISTINCT ?invenzione ?invenzioneLabel ?lev2 ?artwork WHERE {
  VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
 # VALUES ?CFbroader { """+ ' '.join(well_represented_phenomena) +"""}
  # ?icrec icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition; 
          icon:recognizedInvenzione ?invenzione. 
  # ?invenzione rdfs:label ?invenzioneLabel; a ?type; icon:composedOf ?lev2. 
  
MINUS { ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?iconol icon:aboutWorkOfArt ?artwork .}

} 
""" 

cq4res = g.query(cq4)
for row in cq4res:
    inv = "<"+str(row[0])+">"
    inv_without_cf.add(inv)
  #print(row)  
   # print(row[0], row[1], row[2])
inv_without_cf
# Out:
# {'<http://icondataset.org/hercules-and-the-erymanthian-boar>',
#  '<http://icondataset.org/judith-and-holofernes>',
#  '<http://icondataset.org/story-of-quos-ego>',
#  '<http://icondataset.org/the-descent-into-limbo>',
#  '<http://icondataset.org/the-rape-of-cybele>',
#  '<http://icondataset.org/the-story-of-laocoon-and-his-sons>',
#  '<http://icondataset.org/time-carrying-off-the-truth>'}

# %%
' '.join(inv_without_cf)
# Out:
# '<http://icondataset.org/the-story-of-laocoon-and-his-sons> <http://icondataset.org/time-carrying-off-the-truth> <http://icondataset.org/judith-and-holofernes> <http://icondataset.org/the-rape-of-cybele> <http://icondataset.org/hercules-and-the-erymanthian-boar> <http://icondataset.org/story-of-quos-ego> <http://icondataset.org/the-descent-into-limbo>'

# %%
# level 2 representation of the invenzioni having a cf. Not enough results to do a comparison between subjects having and not having a cf

# See if there are artworks with stories and allegories not having a cf 


cq5 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>
prefix skos: <http://www.w3.org/2004/02/skos/core#>

SELECT DISTINCT ?invenzione ?invenzioneLabel ?lev2 ?artwork WHERE {
 # VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
  VALUES ?invenzione { """+ ' '.join(inv_without_cf) +"""}
  # ?icrec icon:recognizedInvenzione ?invenzione; 
          icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition. 
  # ?invenzione rdfs:label ?invenzioneLabel; icon:composedOf ?lev2. 
# ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?iconol icon:aboutWorkOfArt ?artwork .

} 
""" 

cq5res = g.query(cq5)
for row in cq5res:
  #print(row)  
    print(row[0], row[1], row[2], row[3])
# Out:
# http://icondataset.org/the-story-of-laocoon-and-his-sons The story of Laocoon and his sons http://icondataset.org/antiphas-son-of-laoocoon http://icondataset.org/ART1042
# http://icondataset.org/the-story-of-laocoon-and-his-sons The story of Laocoon and his sons http://icondataset.org/laocoon http://icondataset.org/ART1042
# http://icondataset.org/the-story-of-laocoon-and-his-sons The story of Laocoon and his sons http://icondataset.org/marine-snakes http://icondataset.org/ART1042
# http://icondataset.org/the-story-of-laocoon-and-his-sons The story of Laocoon and his sons http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion http://icondataset.org/ART1042
# http://icondataset.org/the-story-of-laocoon-and-his-sons The story of Laocoon and his sons http://icondataset.org/thymbraeus-son-of-laoocoon http://icondataset.org/ART1042
# http://icondataset.org/the-story-of-laocoon-and-his-sons The story of Laocoon and his sons http://icondataset.org/two-marine-snakes-strangle-laocoon-and-his-sons http://icondataset.org/ART1042

# %%
#level 2 subj represented in an artwork not having a cf

art_subj2_without_cf = set()
lev2_without_cf = set()
cq6 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>
prefix skos: <http://www.w3.org/2004/02/skos/core#>

SELECT DISTINCT ?lev2 ?lev2Label ?artwork WHERE {
  VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
 # VALUES ?CFbroader { """+ ' '.join(well_represented_phenomena) +"""}
  # ?icrec icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition; 
          icon:recognizedImage ?img. 
          # ?img ?rel ?lev2.
          # ?lev2 rdfs:label ?lev2Label. 
  
MINUS { ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?iconol icon:aboutWorkOfArt ?artwork .}

} 
""" 

cq6res = g.query(cq6)
for row in cq6res:
    inv = "<"+str(row[0])+">"
    lev2_without_cf.add(inv)
    art = "<"+str(row[2])+">"
    art_subj2_without_cf.add(art)
  #print(row)  
   # print(row[0], row[1], row[2])
lev2_without_cf
# Out:
# {'<http://icondataset.org/adam>',
#  '<http://icondataset.org/angel>',
#  '<http://icondataset.org/anteros>',
#  '<http://icondataset.org/antiphas-son-of-laoocoon>',
#  '<http://icondataset.org/antoninus-pius>',
#  '<http://icondataset.org/ape-everything-subhuman-in-man-lust-greed-gluttony-shamelessness>',
#  '<http://icondataset.org/ape-lower-soul>',
#  '<http://icondataset.org/avarice>',
#  '<http://icondataset.org/bacchant>',
#  '<http://icondataset.org/blind-night>',
#  '<http://icondataset.org/blindfold-cupid>',
#  '<http://icondataset.org/blowing-in-a-cone-shell-generating-panic-terror>',
#  '<http://icondataset.org/cacus>',
#  '<http://icondataset.org/centaurs>',
#  '<http://icondataset.org/charity>',
#  '<http://icondataset.org/chastity>',
#  '<http://icondataset.org/christ-as-a-child>',
#  '<http://icondataset.org/christ-rescuing-souls-from-hell>',
#  '<http://icondataset.org/christ>',
#  '<http://icondataset.org/christian-virtues>',
#  '<http://icondataset.org/companion-of-serapis>',
#  '<http://icondataset.org/concord>',
#  '<http://icondataset.org/cone-shell-fertility>',
#  '<http://icondataset.org/cone-shell-panic>',
#  '<http://icondataset.org/cupid>',
#  '<http://icondataset.org/cybele>',
#  '<http://icondataset.org/david>',
#  '<http://icondataset.org/day>',
#  '<http://icondataset.org/decoration-for-wedding-occasions>',
#  '<http://icondataset.org/devil>',
#  '<http://icondataset.org/dieu-amour>',
#  '<http://icondataset.org/dionysus-is-supported-by-a-satyr>',
#  '<http://icondataset.org/dionysus>',
#  '<http://icondataset.org/discord>',
#  '<http://icondataset.org/dolphin-persuasion>',
#  '<http://icondataset.org/draped-ganymede-raped-by-the-eagle-so-that-he-is-not-hurt-by-the-eagles-talons-perfect-harmony-of-soul-and-body>',
#  '<http://icondataset.org/dressed-girl-heavenly-life>',
#  '<http://icondataset.org/era-sub-prometheo>',
#  '<http://icondataset.org/erymanthian-boar>',
#  '<http://icondataset.org/eve>',
#  '<http://icondataset.org/faith>',
#  '<http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius>',
#  '<http://icondataset.org/fame>',
#  '<http://icondataset.org/feathers-months>',
#  '<http://icondataset.org/fettered-ape-blind-and-unhappy-human-soul>',
#  '<http://icondataset.org/fettered-ape-subjugation-of-base-emotions>',
#  '<http://icondataset.org/fettered-slave-unregenerated-human-soul-held-in-bondage-by-its-natural-desires>',
#  '<http://icondataset.org/flower-of-venus>',
#  '<http://icondataset.org/folly>',
#  '<http://icondataset.org/fountain-of-life>',
#  '<http://icondataset.org/four-seasons>',
#  '<http://icondataset.org/four-wings-four-seasons>',
#  '<http://icondataset.org/furor-poeticus>',
#  '<http://icondataset.org/ganymede-mind>',
#  '<http://icondataset.org/ganymede>',
#  '<http://icondataset.org/grace>',
#  '<http://icondataset.org/head-of-holofernes>',
#  '<http://icondataset.org/head-of-saint-john-the-baptist>',
#  '<http://icondataset.org/hercules-carrying-the-spheres-of-heavens>',
#  '<http://icondataset.org/hercules>',
#  '<http://icondataset.org/humility>',
#  '<http://icondataset.org/idolatry>',
#  '<http://icondataset.org/incense-burner-bridal-chamber-decoration>',
#  '<http://icondataset.org/integrity>',
#  '<http://icondataset.org/ivy-eternal-love>',
#  '<http://icondataset.org/judith>',
#  '<http://icondataset.org/king-eurystheus>',
#  '<http://icondataset.org/knotted-ribbon-bracelets-love>',
#  '<http://icondataset.org/laocoon>',
#  '<http://icondataset.org/lapiths>',
#  '<http://icondataset.org/lilium-purity>',
#  '<http://icondataset.org/lost-occasio>',
#  '<http://icondataset.org/luxury>',
#  '<http://icondataset.org/marine-snakes>',
#  '<http://icondataset.org/mars>',
#  '<http://icondataset.org/mary>',
#  '<http://icondataset.org/medusas-head>',
#  '<http://icondataset.org/member-of-medici-family>',
#  '<http://icondataset.org/member-of-the-crowd-of-faithful-in-prayer>',
#  '<http://icondataset.org/mercurys-winged-sandals>',
#  '<http://icondataset.org/mermaid-persuasion>',
#  '<http://icondataset.org/mida>',
#  '<http://icondataset.org/mountain-ash-the-tree-of-life>',
#  '<http://icondataset.org/myrtle-wreath-conjugal-love>',
#  '<http://icondataset.org/nature>',
#  '<http://icondataset.org/neptune-calms-the-riots>',
#  '<http://icondataset.org/neptune>',
#  '<http://icondataset.org/noah>',
#  '<http://icondataset.org/nude-girl-worldly-happiness>',
#  '<http://icondataset.org/occasio>',
#  '<http://icondataset.org/ox-carrying-off-his-master-luke-the-evangelist-obeys-the-dictates-of-the-holy-spirit>',
#  '<http://icondataset.org/ox-christ>',
#  '<http://icondataset.org/pan-god-of-panic>',
#  '<http://icondataset.org/pan>',
#  '<http://icondataset.org/peaceful-landscape-on-the-left-reprehensible-pleasure>',
#  '<http://icondataset.org/perseus>',
#  '<http://icondataset.org/personification-of-time-as-an-abstract-principle-temps>',
#  '<http://icondataset.org/personification-of-time-lapse-of-time>',
#  '<http://icondataset.org/phaeton-the-presumptuous>',
#  '<http://icondataset.org/phaeton>',
#  '<http://icondataset.org/platonic-love>',
#  '<http://icondataset.org/playful-attitude-joy-love>',
#  '<http://icondataset.org/pluto-abducting-proserpina>',
#  '<http://icondataset.org/pluto>',
#  '<http://icondataset.org/pride>',
#  '<http://icondataset.org/prince-bestowing-favours-upon-his-subjects>',
#  '<http://icondataset.org/proserpina>',
#  '<http://icondataset.org/prudence>',
#  '<http://icondataset.org/puer-mingens-fertility>',
#  '<http://icondataset.org/puer-mingens>',
#  '<http://icondataset.org/putti-with-dolphins-love>',
#  '<http://icondataset.org/raising-an-arm-calming-the-riots>',
#  '<http://icondataset.org/reason>',
#  '<http://icondataset.org/red-cloth-bridal-chamber-decoration>',
#  '<http://icondataset.org/regret>',
#  '<http://icondataset.org/river-gods>',
#  '<http://icondataset.org/river-pactolus>',
#  '<http://icondataset.org/rod-venus-punished-cupid>',
#  '<http://icondataset.org/rose-virginity>',
#  '<http://icondataset.org/saint-basilius>',
#  '<http://icondataset.org/saint-cosmas>',
#  '<http://icondataset.org/saint-damian>',
#  '<http://icondataset.org/saturn>',
#  '<http://icondataset.org/satyr-egyptian-desert-wilderness>',
#  '<http://icondataset.org/satyr>',
#  '<http://icondataset.org/serapis>',
#  '<http://icondataset.org/serpent-pitfalls-of-love>',
#  '<http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom>',
#  '<http://icondataset.org/snake-subterranean-world>',
#  '<http://icondataset.org/sol-invictus>',
#  '<http://icondataset.org/storm-caused-by-eolus>',
#  '<http://icondataset.org/the-adult-mago-balthasar>',
#  '<http://icondataset.org/the-children-of-jupiter>',
#  '<http://icondataset.org/the-constellation-perseus>',
#  '<http://icondataset.org/the-devil-conjures-up-the-tempting-vision-of-a-venus-carnalis>',
#  '<http://icondataset.org/the-elder-mago-balthasar>',
#  '<http://icondataset.org/the-ilde>',
#  '<http://icondataset.org/threatening-and-wild-landscape-on-the-right-praiseworthy-virtues>',
#  '<http://icondataset.org/three-heads-three-forms-of-time-past-present-future>',
#  '<http://icondataset.org/thymbraeus-son-of-laoocoon>',
#  '<http://icondataset.org/time>',
#  '<http://icondataset.org/tityus>',
#  '<http://icondataset.org/truth>',
#  '<http://icondataset.org/two-marine-snakes-strangle-laocoon-and-his-sons>',
#  '<http://icondataset.org/two-rats-one-black-one-white-destruction-of-life-by-each-day-and-night>',
#  '<http://icondataset.org/urinating-wish-of-fertility>',
#  '<http://icondataset.org/venetian-bridal-clothes>',
#  '<http://icondataset.org/venus-belt-seduction>',
#  '<http://icondataset.org/venus-belt>',
#  '<http://icondataset.org/venus-carnalis>',
#  '<http://icondataset.org/venus>',
#  '<http://icondataset.org/winds>'}

# %%
#level 2 subj represented in an artwork having a cf


lev2_with_cf = set()
cq7 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>
prefix skos: <http://www.w3.org/2004/02/skos/core#>

SELECT DISTINCT ?lev2 ?lev2Label ?artwork WHERE {
  VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
 # VALUES ?CFbroader { """+ ' '.join(well_represented_phenomena) +"""}
  # ?icrec icon:aboutWorkOfArt ?artwork; 
          a icon:IconographicalRecognition; 
          icon:recognizedImage ?img. 
          # ?img ?rel ?lev2.
          # ?lev2 rdfs:label ?lev2Label. 
# ?meaning ^icon:recognizedCulturalPhenomenon / ^icon:recognizedIntrinsicMeaning ?iconol .
  # ?iconol icon:aboutWorkOfArt ?artwork .

} 
""" 

cq7res = g.query(cq7)
for row in cq7res:
    inv = "<"+str(row[0])+">"
    lev2_with_cf.add(inv)
    
  #print(row)  
   # print(row[0], row[1], row[2])
lev2_with_cf
# Out:
# {'<http://icondataset.org/a-pair-of-masks-one-of-a-young-woman-the-other-of-a-old-malevolent-man-worldliness-insincerity-falsehood>',
#  '<http://icondataset.org/aeneas>',
#  '<http://icondataset.org/aeolus-seals-the-naughty-winds-into-the-wine-skins>',
#  '<http://icondataset.org/aeolus-working-two-blacksmiths-bellows>',
#  '<http://icondataset.org/aeolus>',
#  '<http://icondataset.org/aglauros>',
#  '<http://icondataset.org/aion/phanes-as-personification-of-eternal-time>',
#  '<http://icondataset.org/aion/phanes>',
#  '<http://icondataset.org/algol-head-of-demon>',
#  '<http://icondataset.org/altar>',
#  '<http://icondataset.org/amor-carnalis>',
#  '<http://icondataset.org/amor-divino>',
#  '<http://icondataset.org/amor>',
#  '<http://icondataset.org/amorini-pointing-out-to-death-her-first-victims>',
#  '<http://icondataset.org/angel-smiling-while-carrying-the-coffin-of-the-pope-angel-glad-that-the-soul-of-the-pope-had-been-received-among-the-blessed-spirits>',
#  '<http://icondataset.org/angel-wepting-while-carrying-the-coffin-of-the-pope-angel-grieved-that-the-world-had-been-deprived-of-such-a-man>',
#  '<http://icondataset.org/angels>',
#  '<http://icondataset.org/anteros>',
#  '<http://icondataset.org/antiphas-son-of-laoocoon>',
#  '<http://icondataset.org/apollo-god-of-sun>',
#  '<http://icondataset.org/apollo-idolatry>',
#  '<http://icondataset.org/apollo-medicus-or-aesculapius>',
#  '<http://icondataset.org/apollo>',
#  '<http://icondataset.org/apollonian-swan>',
#  '<http://icondataset.org/apostles>',
#  '<http://icondataset.org/apparition-of-christ>',
#  '<http://icondataset.org/archangel-gabriel-pronounces-the-ave-maria>',
#  '<http://icondataset.org/archangel-gabriel>',
#  '<http://icondataset.org/archers-without-arrows-tools-of-a-force-beyond-their-will-and-consciousness>',
#  '<http://icondataset.org/ardor>',
#  '<http://icondataset.org/argus>',
#  '<http://icondataset.org/ariadne>',
#  '<http://icondataset.org/athene>',
#  '<http://icondataset.org/atlas>',
#  '<http://icondataset.org/aurora>',
#  '<http://icondataset.org/bacchus-folly>',
#  '<http://icondataset.org/bacchus>',
#  '<http://icondataset.org/bat-melancholy>',
#  '<http://icondataset.org/battle-of-lapiths-and-centaurs>',
#  '<http://icondataset.org/beams-of-light---gods-word>',
#  '<http://icondataset.org/bear-anger>',
#  '<http://icondataset.org/beauty>',
#  '<http://icondataset.org/bible>',
#  '<http://icondataset.org/bishop-simone-saltarelli>',
#  '<http://icondataset.org/blind-death>',
#  '<http://icondataset.org/blind-fortune-blindfolding-cupid-and-putting-him-on-a-sphere-affection-changes-with-luck>',
#  '<http://icondataset.org/blind-night>',
#  '<http://icondataset.org/blind-synagogue>',
#  '<http://icondataset.org/blindfold-cupid>',
#  '<http://icondataset.org/blood-sacrifice-of-animals>',
#  '<http://icondataset.org/blowing-in-a-tube-fertilising>',
#  '<http://icondataset.org/blue-hue-of-heaven>',
#  '<http://icondataset.org/book-attribute-of-wisdom>',
#  '<http://icondataset.org/bowl-on-a-book-wisdom>',
#  '<http://icondataset.org/branches-of-a-tree-antidotes-against-sexual-passion-marriage-prayer-business-abstinence>',
#  '<http://icondataset.org/bull-christ>',
#  '<http://icondataset.org/bull-zodiacal-sign-of-april>',
#  '<http://icondataset.org/bundle-of-sticks-unity>',
#  '<http://icondataset.org/caduceus>',
#  '<http://icondataset.org/cameo-with-a-pair-of-winged-horses-and-a-charioteer-platos-immortal-comparison-of-the-human-soul>',
#  '<http://icondataset.org/carrying-on-shoulders-saving-souls>',
#  '<http://icondataset.org/catholic-faith>',
#  '<http://icondataset.org/celestial-fire-carried-by-the-torch-of-prometheus-clarity-of-knowledge-infused-into-the-heart-of-the-ignorant-that-can-be-attained-at-the-expense-of-happiness-and-peace-of-mind>',
#  '<http://icondataset.org/celestial-map>',
#  '<http://icondataset.org/centaur>',
#  '<http://icondataset.org/central-zone-of-the-tomb-realm-of-nature-the-only-sphere-subject-to-time>',
#  '<http://icondataset.org/cerberus>',
#  '<http://icondataset.org/chain-with-a-heart-good-counsel-coming-from-heart>',
#  '<http://icondataset.org/chastity>',
#  '<http://icondataset.org/children-crouching-down-unborn-souls-doomed-to-descend-to-the-lower-spheres>',
#  '<http://icondataset.org/christ-as-a-child>',
#  '<http://icondataset.org/christ-resurrects-the-son-of-nain>',
#  '<http://icondataset.org/christ>',
#  '<http://icondataset.org/church>',
#  '<http://icondataset.org/closed-cash-box-saturninian-parsimony>',
#  '<http://icondataset.org/companion-of-serapis>',
#  '<http://icondataset.org/contemplative-mind>',
#  '<http://icondataset.org/crepuscolo>',
#  '<http://icondataset.org/crocodile>',
#  '<http://icondataset.org/crucifixion>',
#  '<http://icondataset.org/cupid-amor-carnalis>',
#  '<http://icondataset.org/cupid-between-venus-coelestis-and-venus-vulgaris-love-acts-as-an-intermediary-between-heaven-and-earth>',
#  '<http://icondataset.org/cupid-unblindfolding-himself-cupid-transforming-himself-from-a-personification-of-blind-ignoble-love-to-an-exponent-of-seeing-platonic-love>',
#  '<http://icondataset.org/cupid-unblinding-himself>',
#  '<http://icondataset.org/cupid>',
#  '<http://icondataset.org/david>',
#  '<http://icondataset.org/day>',
#  '<http://icondataset.org/death-disembowelling-her-victim>',
#  '<http://icondataset.org/death-steals-the-weapons-from-cupid-while-he-sleeps>',
#  '<http://icondataset.org/death>',
#  '<http://icondataset.org/deer-souls>',
#  '<http://icondataset.org/desolate-scenery-destructive-power-of-time>',
#  '<http://icondataset.org/devil>',
#  '<http://icondataset.org/diana>',
#  '<http://icondataset.org/dido>',
#  '<http://icondataset.org/dieu-amour>',
#  '<http://icondataset.org/divine-justice>',
#  '<http://icondataset.org/dog-envy>',
#  '<http://icondataset.org/dolphin-haste>',
#  '<http://icondataset.org/dove-holy-spirit>',
#  '<http://icondataset.org/dragon-biting-its-tail-time>',
#  '<http://icondataset.org/dragoon-devil>',
#  '<http://icondataset.org/dream-vision>',
#  '<http://icondataset.org/earth>',
#  '<http://icondataset.org/empty-throne-invisible-presence-of-an-immortal>',
#  '<http://icondataset.org/era-ante-vulcanum>',
#  '<http://icondataset.org/era-sub-prometheo>',
#  '<http://icondataset.org/era-sub-vulcano>',
#  '<http://icondataset.org/erato>',
#  '<http://icondataset.org/erection-of-primitive-buildings>',
#  '<http://icondataset.org/eros-and-anteros-fishing-for-hearts>',
#  '<http://icondataset.org/eros-as-the-great-force-ruling-over-the-instincts-of-gods-man-and-animals>',
#  '<http://icondataset.org/europa-human-soul>',
#  '<http://icondataset.org/europa>',
#  '<http://icondataset.org/europas-companions>',
#  '<http://icondataset.org/eve>',
#  '<http://icondataset.org/evil-effects-of-love>',
#  '<http://icondataset.org/face-of-a-young-man-the-future>',
#  '<http://icondataset.org/face-of-a-young-woman-the-future>',
#  '<http://icondataset.org/face-of-an-adult-man-the-present>',
#  '<http://icondataset.org/face-of-an-adult-woman-the-present>',
#  '<http://icondataset.org/face-of-an-old-man-the-past>',
#  '<http://icondataset.org/face-of-an-old-woman-the-past>',
#  '<http://icondataset.org/faith-has-the-world-under-her-feet>',
#  '<http://icondataset.org/faith>',
#  '<http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius>',
#  '<http://icondataset.org/family-simple-happiness-of-primitive-civilization>',
#  '<http://icondataset.org/fedro>',
#  '<http://icondataset.org/female-pan>',
#  '<http://icondataset.org/fire-fire-to-burn-the-time>',
#  '<http://icondataset.org/fire-luxury>',
#  '<http://icondataset.org/flame-of-divine-wisdom>',
#  '<http://icondataset.org/flora>',
#  '<http://icondataset.org/fly-decade>',
#  '<http://icondataset.org/flying-towards-marys-head-to-fertilise>',
#  '<http://icondataset.org/fortune>',
#  '<http://icondataset.org/four-rivers-of-hades-four-elements-air-fire-earth-water>',
#  '<http://icondataset.org/four-rivers-of-hades-fourfold-aspect-of-matter-as-a-source-of-potential-evil>',
#  '<http://icondataset.org/four-times-of-day-four-humours>',
#  '<http://icondataset.org/four-times-of-day-fourfold-aspect-of-life-on-earth-as-a-state-of-actual-suffering>',
#  '<http://icondataset.org/four-times-of-day-realm-of-nature>',
#  '<http://icondataset.org/four-wings-four-seasons>',
#  '<http://icondataset.org/fraud-hides-poison-in-what-seems-to-be-her-evli-hand-but-is-really-her-good>',
#  '<http://icondataset.org/fraud-offers-sweetness-with-what-seems-to-be-the-good-hand-but-is-really-the-evil-one>',
#  '<http://icondataset.org/fraude>',
#  '<http://icondataset.org/futile-and-treacherous-pleasure>',
#  '<http://icondataset.org/ganymede-ascending-to-heaven-on-the-wings-of-an-eagle-ecstasy-of-platonic-love>',
#  '<http://icondataset.org/ganymede>',
#  '<http://icondataset.org/geminae-veneres>',
#  '<http://icondataset.org/gesture-of-saturnian-silence>',
#  '<http://icondataset.org/giuliano-de-medici>',
#  '<http://icondataset.org/glass-sphere-as-a-popular-decorative-curiosity>',
#  '<http://icondataset.org/glass-sphere-god>',
#  '<http://icondataset.org/glass-sphere-harmony-that-can-be-easily-broken>',
#  '<http://icondataset.org/glass-sphere-heaven>',
#  '<http://icondataset.org/god-creating-the-universe>',
#  '<http://icondataset.org/god>',
#  '<http://icondataset.org/gods-hand>',
#  '<http://icondataset.org/good-counsel>',
#  '<http://icondataset.org/grace-pulchritudo>',
#  '<http://icondataset.org/hares-animal-love-fertility>',
#  '<http://icondataset.org/head-of-a-dog-the-future>',
#  '<http://icondataset.org/head-of-a-lion-the-present>',
#  '<http://icondataset.org/head-of-a-wolf-the-past>',
#  '<http://icondataset.org/heart-source-of-living-faith>',
#  '<http://icondataset.org/hearts-of-cupids-victims>',
#  '<http://icondataset.org/heaven>',
#  '<http://icondataset.org/hecuba>',
#  '<http://icondataset.org/helen>',
#  '<http://icondataset.org/hercules-egypt>',
#  '<http://icondataset.org/hercules>',
#  '<http://icondataset.org/herse>',
#  '<http://icondataset.org/hespontine-sibyl>',
#  '<http://icondataset.org/highest-zone-of-the-tomb-supercelestial-sphere>',
#  '<http://icondataset.org/hope>',
#  '<http://icondataset.org/hourglass-transience>',
#  '<http://icondataset.org/human-mind>',
#  '<http://icondataset.org/hylas>',
#  '<http://icondataset.org/ibis-homo-carnalis>',
#  '<http://icondataset.org/ignis-elementatus>',
#  '<http://icondataset.org/imperial-orb>',
#  '<http://icondataset.org/implements-of-the-holy-mass>',
#  '<http://icondataset.org/innocence-threatened-by-the-powers-of-evil>',
#  '<http://icondataset.org/innocence>',
#  '<http://icondataset.org/ixion-lewdness>',
#  '<http://icondataset.org/ixion-on-his-wheel>',
#  '<http://icondataset.org/ixion>',
#  '<http://icondataset.org/jealousy>',
#  '<http://icondataset.org/jest>',
#  '<http://icondataset.org/jewelry-earthly-goods>',
#  '<http://icondataset.org/joachim>',
#  '<http://icondataset.org/joseph-cast-into-the-pit>',
#  '<http://icondataset.org/jupiter-as-an-eagle>',
#  '<http://icondataset.org/jupiter-diana-mercury-saturn-as-superior-divinities-reason>',
#  '<http://icondataset.org/jupiter-minerva-mercury-saturn-as-superior-divinities-reason>',
#  '<http://icondataset.org/jupiter-planet>',
#  '<http://icondataset.org/jupiter-pride>',
#  '<http://icondataset.org/jupiter>',
#  '<http://icondataset.org/justice>',
#  '<http://icondataset.org/kairos>',
#  '<http://icondataset.org/labour>',
#  '<http://icondataset.org/lamentation-of-christ>',
#  '<http://icondataset.org/laocoon>',
#  '<http://icondataset.org/lapiths>',
#  '<http://icondataset.org/leach>',
#  '<http://icondataset.org/life>',
#  '<http://icondataset.org/lion-fury>',
#  '<http://icondataset.org/lion-zodiacal-sign>',
#  '<http://icondataset.org/liver-seat-of-physical-passions>',
#  '<http://icondataset.org/love-shooting-the-foolish>',
#  '<http://icondataset.org/love-shooting-the-wise-man>',
#  '<http://icondataset.org/love-stricken-soul>',
#  '<http://icondataset.org/love>',
#  '<http://icondataset.org/lowest-zone-of-the-tomb-realm-of-sheer-matter>',
#  '<http://icondataset.org/luxury>',
#  '<http://icondataset.org/lyre-fashioned-from-a-stags-head-low-class-and-uncouth-music>',
#  '<http://icondataset.org/man-reclining-on-terrestrial-world-human-mind-placed-between-the-fallacious-and-unreal-life-on-earth-and-the-celestial-realm>',
#  '<http://icondataset.org/marine-snakes>',
#  '<http://icondataset.org/marital-affection>',
#  '<http://icondataset.org/mars-discord>',
#  '<http://icondataset.org/mars-planet>',
#  '<http://icondataset.org/mars>',
#  '<http://icondataset.org/mary-welcomes-the-holy-spirit>',
#  '<http://icondataset.org/mary>',
#  '<http://icondataset.org/masks-fallacy-deceit>',
#  '<http://icondataset.org/medusas-head>',
#  '<http://icondataset.org/member-of-the-procession>',
#  '<http://icondataset.org/mercury-discursive-reason:-limitations-and-possibilities-of-what-human-reason-can-do>',
#  '<http://icondataset.org/mercury-discursive-reason>',
#  '<http://icondataset.org/mercury-hermes>',
#  '<http://icondataset.org/mercury-planet>',
#  '<http://icondataset.org/mercury-turning-his-back-to-the-realm-of-the-natural-venus-the-discursive-reason-is-not-involved-in-the-activities-of-the-natural-venus>',
#  '<http://icondataset.org/mercury>',
#  '<http://icondataset.org/mercurys-winged-sandals>',
#  '<http://icondataset.org/minerva>',
#  '<http://icondataset.org/mirror-introspection>',
#  '<http://icondataset.org/missal>',
#  '<http://icondataset.org/mithras-killing-the-bull>',
#  '<http://icondataset.org/mithras-twisting-the-horns-of-a-bull>',
#  '<http://icondataset.org/mithras>',
#  '<http://icondataset.org/mockery>',
#  '<http://icondataset.org/monk-vita-contemplativa>',
#  '<http://icondataset.org/moon-planet>',
#  '<http://icondataset.org/moon>',
#  '<http://icondataset.org/moses-mens>',
#  '<http://icondataset.org/moses>',
#  '<http://icondataset.org/most-primitive-natural-functions-sphere-of-a-purely-vegetative-life>',
#  '<http://icondataset.org/mourning>',
#  '<http://icondataset.org/mouse-all-devouring-time>',
#  '<http://icondataset.org/muses>',
#  '<http://icondataset.org/myrtle-everlasting-love>',
#  '<http://icondataset.org/myrtle-love>',
#  '<http://icondataset.org/natural-venus-amor-humanus>',
#  '<http://icondataset.org/natural-venus>',
#  '<http://icondataset.org/night>',
#  '<http://icondataset.org/nude-prudence>',
#  '<http://icondataset.org/nymphs>',
#  '<http://icondataset.org/oceanus>',
#  '<http://icondataset.org/olympian-gods>',
#  '<http://icondataset.org/original-sin>',
#  '<http://icondataset.org/orpheus>',
#  '<http://icondataset.org/owl-attribute-of-wisdom>',
#  '<http://icondataset.org/paris-rapes-helen>',
#  '<http://icondataset.org/paris>',
#  '<http://icondataset.org/peaceful-landscape-on-the-left-innocent-happiness-of-a-pastoral-civilization>',
#  '<http://icondataset.org/penitentia>',
#  '<http://icondataset.org/perseus>',
#  '<http://icondataset.org/personification-of-the-natural-forces-stimulating-the-action-of-the-unconscious-creatures>',
#  '<http://icondataset.org/phaeton-the-presumptuous>',
#  '<http://icondataset.org/phaeton>',
#  '<http://icondataset.org/pillow-idleness-and-lechery>',
#  '<http://icondataset.org/planetary-deities>',
#  '<http://icondataset.org/platonic-love>',
#  '<http://icondataset.org/pleasure>',
#  '<http://icondataset.org/pluto-avarice>',
#  '<http://icondataset.org/pluto>',
#  '<http://icondataset.org/polyxena>',
#  '<http://icondataset.org/pope-julius-ii>',
#  '<http://icondataset.org/poverty>',
#  '<http://icondataset.org/presbyter-bruno-mourned-by-beggars-whom-he-had-supported-during-his-life>',
#  '<http://icondataset.org/presbyter-bruno>',
#  '<http://icondataset.org/princely-sceptre-jovial-magnanimity>',
#  '<http://icondataset.org/prometheus-animates-man>',
#  '<http://icondataset.org/prometheus-is-punished>',
#  '<http://icondataset.org/prometheus>',
#  '<http://icondataset.org/prophet>',
#  '<http://icondataset.org/proserpina>',
#  '<http://icondataset.org/punishment-of-prometheus-the-price-which-mankind-has-to-pay-for-its-intellectual-awakening>',
#  '<http://icondataset.org/punishment-of-tityus-liver-devoured-by-a-vulture-tortures-caused-by-immoderate-love>',
#  '<http://icondataset.org/pygmalion-dressing-his-statue>',
#  '<http://icondataset.org/pygmalion>',
#  '<http://icondataset.org/rachel>',
#  '<http://icondataset.org/ram-zodiacal-sign-of-march>',
#  '<http://icondataset.org/rape>',
#  '<http://icondataset.org/resurrection-of-christ>',
#  '<http://icondataset.org/rhea>',
#  '<http://icondataset.org/right-man-salamander>',
#  '<http://icondataset.org/river-alpheus>',
#  '<http://icondataset.org/roman-emperors>',
#  '<http://icondataset.org/roses-pleasures-of-permanent-congeniality>',
#  '<http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion>',
#  '<http://icondataset.org/sacrifice-of-a-bull>',
#  '<http://icondataset.org/saint-anne>',
#  '<http://icondataset.org/saint-john-the-evangelist>',
#  '<http://icondataset.org/saint-mark>',
#  '<http://icondataset.org/saint-paul-mens>',
#  '<http://icondataset.org/saint-paul>',
#  '<http://icondataset.org/saint-peter>',
#  '<http://icondataset.org/saint-theodora-of-alexandria>',
#  '<http://icondataset.org/saints>',
#  '<http://icondataset.org/salamander>',
#  '<http://icondataset.org/sarcophagus-converted-in-a-spring-of-life-vis-generandi>',
#  '<http://icondataset.org/satan>',
#  '<http://icondataset.org/saturn-devouring-a-living-child>',
#  '<http://icondataset.org/saturn-planet>',
#  '<http://icondataset.org/saturn>',
#  '<http://icondataset.org/satyr-egyptian-desert-wilderness>',
#  '<http://icondataset.org/satyr>',
#  '<http://icondataset.org/sella-gestatoria>',
#  '<http://icondataset.org/serapis>',
#  '<http://icondataset.org/serpent-attribute-of-wisdom>',
#  '<http://icondataset.org/serpent-perfidy>',
#  '<http://icondataset.org/seven-capital-sins>',
#  '<http://icondataset.org/shepherdess-amorous-implications-of-the-arcadian-milieu>',
#  '<http://icondataset.org/silenus>',
#  '<http://icondataset.org/simeon-witnesses-the-presentation-of-christ>',
#  '<http://icondataset.org/simeon>',
#  '<http://icondataset.org/sisyphus-carrying-the-stone-uphill>',
#  '<http://icondataset.org/sisyphus-pride>',
#  '<http://icondataset.org/sisyphus>',
#  '<http://icondataset.org/sitting-down-on-a-lion-quando-est-in-leone>',
#  '<http://icondataset.org/skull-death-personified>',
#  '<http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom>',
#  '<http://icondataset.org/sleep>',
#  '<http://icondataset.org/sleeping-cupid-natural-desire-has-nothing-to-do-with-love>',
#  '<http://icondataset.org/sleeping-youth-simple-happiness-of-primitive-civilization>',
#  '<http://icondataset.org/soap-bubbles-futility>',
#  '<http://icondataset.org/sol-iustitiae>',
#  '<http://icondataset.org/son-of-the-widow-of-nain>',
#  '<http://icondataset.org/spring>',
#  '<http://icondataset.org/stepping-on-defeating-devil>',
#  '<http://icondataset.org/sun-moves-his-chariot-through-the-zodiac>',
#  '<http://icondataset.org/sun-on-his-chariot>',
#  '<http://icondataset.org/sun>',
#  '<http://icondataset.org/sybil>',
#  '<http://icondataset.org/synagogue>',
#  '<http://icondataset.org/tantalus-avarice>',
#  '<http://icondataset.org/tantalus-vainly-reaching-for-the-water>',
#  '<http://icondataset.org/tantalus>',
#  '<http://icondataset.org/tellus>',
#  '<http://icondataset.org/temple-of-solomon-ornate-as-a-church-correlation-between-the-old-testament-and-the-new>',
#  '<http://icondataset.org/the-abduction-of-europa>',
#  '<http://icondataset.org/the-age-of-metal>',
#  '<http://icondataset.org/the-age-of-stone>',
#  '<http://icondataset.org/the-children-of-each-planet>',
#  '<http://icondataset.org/the-children-of-mercury>',
#  '<http://icondataset.org/the-children-of-saturn>',
#  '<http://icondataset.org/the-constellation-eridanus>',
#  '<http://icondataset.org/the-constellation-hercules-engonasin>',
#  '<http://icondataset.org/the-constellation-hercules>',
#  '<http://icondataset.org/the-constellation-orion>',
#  '<http://icondataset.org/the-constellation-perseus>',
#  '<http://icondataset.org/the-grace-turning-his-back-favor-conferred>',
#  '<http://icondataset.org/the-nymphs-help-vulcan-precipitated-from-mount-olympus-onto-the-island-of-lemnos>',
#  '<http://icondataset.org/the-resurrected>',
#  '<http://icondataset.org/the-right>',
#  '<http://icondataset.org/the-three-graces>',
#  '<http://icondataset.org/the-tomb-of-king-ninus>',
#  '<http://icondataset.org/the-twins-constellation>',
#  '<http://icondataset.org/the-virgin-constellation>',
#  '<http://icondataset.org/the-young-mago-caspar>',
#  '<http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus>',
#  '<http://icondataset.org/thisbe>',
#  '<http://icondataset.org/threatening-and-wild-landscape-on-the-right-merciless-hardships-of-unmitigated-wildness>',
#  '<http://icondataset.org/three-books-three-forms-of-time-past-present-future>',
#  '<http://icondataset.org/three-corpses-warn-three-gentlemen-against-their-thoughtless-enjoyment-of-life>',
#  '<http://icondataset.org/three-graces-three-aspects-of-venus>',
#  '<http://icondataset.org/three-headed-companion-of-serapis-prudence>',
#  '<http://icondataset.org/three-headed-companion-of-serapis-three-forms-of-time-past-present-future>',
#  '<http://icondataset.org/three-stages-of-human-life>',
#  '<http://icondataset.org/thymbraeus-son-of-laoocoon>',
#  '<http://icondataset.org/time-as-a-cosmic-power>',
#  '<http://icondataset.org/time-as-universal-cosmic-principle>',
#  '<http://icondataset.org/time-devouring-the-past>',
#  '<http://icondataset.org/time-reveals-the-truth>',
#  '<http://icondataset.org/time-ripa>',
#  '<http://icondataset.org/time-the-destroyer>',
#  '<http://icondataset.org/time-the-revealer>',
#  '<http://icondataset.org/tityus>',
#  '<http://icondataset.org/tombs-christian-rite-of-burial>',
#  '<http://icondataset.org/torch-of-prometheus>',
#  '<http://icondataset.org/torch-unholy-ardor>',
#  '<http://icondataset.org/torso-del-belvedere>',
#  '<http://icondataset.org/tower-of-chastity>',
#  '<http://icondataset.org/triumph-of-love>',
#  '<http://icondataset.org/troilus>',
#  '<http://icondataset.org/trophies-ultimate-triumph-over-the-lower-forms-of-existence>',
#  '<http://icondataset.org/truth>',
#  '<http://icondataset.org/twins-zodiacal-sign-of-may>',
#  '<http://icondataset.org/two-billing-doves-amorous-caresses>',
#  '<http://icondataset.org/two-graces-facing-the-observer-favor-returned-twofold>',
#  '<http://icondataset.org/two-out-of-the-four-rivers-of-hades>',
#  '<http://icondataset.org/two-out-of-the-four-times-of-day>',
#  '<http://icondataset.org/unconsciuous-creatures>',
#  '<http://icondataset.org/urns-pagan-custom-of-cremation>',
#  '<http://icondataset.org/venus-coelestis-amor-divinus>',
#  '<http://icondataset.org/venus-coelestis-principle-of-universal-and-eternal-but-purely-intelligible-beauty>',
#  '<http://icondataset.org/venus-coelestis>',
#  '<http://icondataset.org/venus-cupid-vulcan-lower-soul>',
#  '<http://icondataset.org/venus-planet>',
#  '<http://icondataset.org/venus-pudica>',
#  '<http://icondataset.org/venus-verticordia>',
#  '<http://icondataset.org/venus-vulgaris-generative-force-that-creates-the-perishable-but-visible-and-tangible-images-of-beauty-of-earth>',
#  '<http://icondataset.org/venus-vulgaris>',
#  '<http://icondataset.org/venus>',
#  '<http://icondataset.org/victories>',
#  '<http://icondataset.org/victory-human-soul-in-state-of-freedom>',
#  '<http://icondataset.org/victory>',
#  '<http://icondataset.org/virtue>',
#  '<http://icondataset.org/vita-activa>',
#  '<http://icondataset.org/vita-contemplativa>',
#  '<http://icondataset.org/voluptas>',
#  '<http://icondataset.org/votary-of-jupiter>',
#  '<http://icondataset.org/votary-of-saturn>',
#  '<http://icondataset.org/vulcan-with-his-helpers-are-already-at-work-in-mid-career-of-night-when-ordinary-people-are-still-asleep>',
#  '<http://icondataset.org/vulcan>',
#  '<http://icondataset.org/wealth>',
#  '<http://icondataset.org/weighing-with-balance-allusion-to-last-judgement>',
#  '<http://icondataset.org/weighing-with-balance-weighing-of-souls>',
#  '<http://icondataset.org/white-lilium-virginity>',
#  '<http://icondataset.org/white-purity>',
#  '<http://icondataset.org/wolf-greed>',
#  '<http://icondataset.org/young-mago-future-time>',
#  '<http://icondataset.org/zephir>',
#  '<http://icondataset.org/zeus>',
#  '<http://icondataset.org/zodiacal-signs>'}

# %%
art_subj2_cf = set()
for row in cq7res:
    art = "<"+str(row[2])+">"
    art_subj2_cf.add(art)
art_subj2_cf
# Out:
# {'<http://icondataset.org/ART1000>',
#  '<http://icondataset.org/ART1001>',
#  '<http://icondataset.org/ART1001test>',
#  '<http://icondataset.org/ART1002>',
#  '<http://icondataset.org/ART1003test>',
#  '<http://icondataset.org/ART1004>',
#  '<http://icondataset.org/ART1004test>',
#  '<http://icondataset.org/ART1005>',
#  '<http://icondataset.org/ART1005test>',
#  '<http://icondataset.org/ART1008test>',
#  '<http://icondataset.org/ART1009test>',
#  '<http://icondataset.org/ART1010>',
#  '<http://icondataset.org/ART1011>',
#  '<http://icondataset.org/ART1013test>',
#  '<http://icondataset.org/ART1014>',
#  '<http://icondataset.org/ART1014test>',
#  '<http://icondataset.org/ART1015>',
#  '<http://icondataset.org/ART1016>',
#  '<http://icondataset.org/ART1017>',
#  '<http://icondataset.org/ART1017test>',
#  '<http://icondataset.org/ART1018>',
#  '<http://icondataset.org/ART1019>',
#  '<http://icondataset.org/ART1020>',
#  '<http://icondataset.org/ART1021>',
#  '<http://icondataset.org/ART1024>',
#  '<http://icondataset.org/ART1028>',
#  '<http://icondataset.org/ART1029>',
#  '<http://icondataset.org/ART1030>',
#  '<http://icondataset.org/ART1031>',
#  '<http://icondataset.org/ART1032>',
#  '<http://icondataset.org/ART1033>',
#  '<http://icondataset.org/ART1034>',
#  '<http://icondataset.org/ART1036>',
#  '<http://icondataset.org/ART1039>',
#  '<http://icondataset.org/ART1040>',
#  '<http://icondataset.org/ART1041>',
#  '<http://icondataset.org/ART1042>',
#  '<http://icondataset.org/ART1043>',
#  '<http://icondataset.org/ART1044>',
#  '<http://icondataset.org/ART1046>',
#  '<http://icondataset.org/ART1051>',
#  '<http://icondataset.org/ART1054>',
#  '<http://icondataset.org/ART1055>',
#  '<http://icondataset.org/ART1056>',
#  '<http://icondataset.org/ART1061>',
#  '<http://icondataset.org/ART1064>',
#  '<http://icondataset.org/ART1065>',
#  '<http://icondataset.org/ART1066>',
#  '<http://icondataset.org/ART1068>',
#  '<http://icondataset.org/ART1078>',
#  '<http://icondataset.org/ART1079>',
#  '<http://icondataset.org/ART1083>',
#  '<http://icondataset.org/ART1102>',
#  '<http://icondataset.org/ART1104>',
#  '<http://icondataset.org/ART1107>',
#  '<http://icondataset.org/ART1113>',
#  '<http://icondataset.org/ART1115>',
#  '<http://icondataset.org/ART1120>',
#  '<http://icondataset.org/ART1121>',
#  '<http://icondataset.org/ART1122>',
#  '<http://icondataset.org/ART1123>',
#  '<http://icondataset.org/ART1124>',
#  '<http://icondataset.org/ART1126>',
#  '<http://icondataset.org/ART1127>',
#  '<http://icondataset.org/ART1129>',
#  '<http://icondataset.org/ART1130>',
#  '<http://icondataset.org/ART1131>',
#  '<http://icondataset.org/ART1132>',
#  '<http://icondataset.org/ART1135>',
#  '<http://icondataset.org/ART1137>',
#  '<http://icondataset.org/ART1138>',
#  '<http://icondataset.org/ART1139>',
#  '<http://icondataset.org/ART1140>',
#  '<http://icondataset.org/ART1145>',
#  '<http://icondataset.org/ART1147>',
#  '<http://icondataset.org/ART1150>',
#  '<http://icondataset.org/ART1158>',
#  '<http://icondataset.org/ART1160>',
#  '<http://icondataset.org/ART1162>',
#  '<http://icondataset.org/ART1166>',
#  '<http://icondataset.org/ART1168>',
#  '<http://icondataset.org/ART1187>',
#  '<http://icondataset.org/ART1191>',
#  '<http://icondataset.org/ART1192>',
#  '<http://icondataset.org/ART1193>',
#  '<http://icondataset.org/ART1195>',
#  '<http://icondataset.org/ART1196>',
#  '<http://icondataset.org/ART1197>',
#  '<http://icondataset.org/ART1198>',
#  '<http://icondataset.org/ART1200>',
#  '<http://icondataset.org/ART1201>',
#  '<http://icondataset.org/ART1202>',
#  '<http://icondataset.org/ART1203>',
#  '<http://icondataset.org/ART1204>',
#  '<http://icondataset.org/ART1205>',
#  '<http://icondataset.org/ART1207>',
#  '<http://icondataset.org/ART1212>',
#  '<http://icondataset.org/ART1232>',
#  '<http://icondataset.org/ART1233>',
#  '<http://icondataset.org/ART1236>',
#  '<http://icondataset.org/ART1240>',
#  '<http://icondataset.org/ART1243>',
#  '<http://icondataset.org/ART1244>',
#  '<http://icondataset.org/ART1245>',
#  '<http://icondataset.org/ART1249>',
#  '<http://icondataset.org/ART1250>',
#  '<http://icondataset.org/ART1251>',
#  '<http://icondataset.org/ART1252>',
#  '<http://icondataset.org/ART1253>',
#  '<http://icondataset.org/ART1254>',
#  '<http://icondataset.org/ART1256>',
#  '<http://icondataset.org/ART1257>',
#  '<http://icondataset.org/ART1259>',
#  '<http://icondataset.org/ART1260>',
#  '<http://icondataset.org/ART1261>',
#  '<http://icondataset.org/ART1263>',
#  '<http://icondataset.org/ART1264>',
#  '<http://icondataset.org/ART1265>',
#  '<http://icondataset.org/ART1266>',
#  '<http://icondataset.org/ART1267>',
#  '<http://icondataset.org/ART1268>',
#  '<http://icondataset.org/ART1269>',
#  '<http://icondataset.org/ART1270>',
#  '<http://icondataset.org/ART1272>',
#  '<http://icondataset.org/ART1273>',
#  '<http://icondataset.org/ART1274>',
#  '<http://icondataset.org/ART1279>',
#  '<http://icondataset.org/ART1282>',
#  '<http://icondataset.org/ART1283>',
#  '<http://icondataset.org/ART1284>',
#  '<http://icondataset.org/ART1288>',
#  '<http://icondataset.org/ART1289>',
#  '<http://icondataset.org/ART1290>',
#  '<http://icondataset.org/ART1291>',
#  '<http://icondataset.org/ART1292>',
#  '<http://icondataset.org/ART1294>',
#  '<http://icondataset.org/ART1297>',
#  '<http://icondataset.org/ART1298>',
#  '<http://icondataset.org/ART1301>',
#  '<http://icondataset.org/ART1303>',
#  '<http://icondataset.org/ART1306>',
#  '<http://icondataset.org/ART1307>',
#  '<http://icondataset.org/ART1310>',
#  '<http://icondataset.org/ART1311>',
#  '<http://icondataset.org/ART1312>',
#  '<http://icondataset.org/ART1314>',
#  '<http://icondataset.org/ART1315>',
#  '<http://icondataset.org/ART1316>',
#  '<http://icondataset.org/ART1317>',
#  '<http://icondataset.org/ART1318>',
#  '<http://icondataset.org/ART1319>',
#  '<http://icondataset.org/ART1321>',
#  '<http://icondataset.org/ART1323>',
#  '<http://icondataset.org/ART1324>',
#  '<http://icondataset.org/ART1325>',
#  '<http://icondataset.org/ART1326>',
#  '<http://icondataset.org/ART1329>',
#  '<http://icondataset.org/ART1333>',
#  '<http://icondataset.org/ART1334>',
#  '<http://icondataset.org/ART1335>',
#  '<http://icondataset.org/ART1338>',
#  '<http://icondataset.org/ART1339>',
#  '<http://icondataset.org/ART1352>',
#  '<http://icondataset.org/ART1353>',
#  '<http://icondataset.org/ART1354>',
#  '<http://icondataset.org/ART1355>',
#  '<http://icondataset.org/ART1364>',
#  '<http://icondataset.org/ART1365>',
#  '<http://icondataset.org/ART1374>',
#  '<http://icondataset.org/ART1375>',
#  '<http://icondataset.org/ART1378>',
#  '<http://icondataset.org/ART1379>',
#  '<http://icondataset.org/ART1382>',
#  '<http://icondataset.org/ART1383>',
#  '<http://icondataset.org/ART1384>',
#  '<http://icondataset.org/ART1385>',
#  '<http://icondataset.org/ART1386>',
#  '<http://icondataset.org/ART1387>',
#  '<http://icondataset.org/ART1393>',
#  '<http://icondataset.org/ART1409>',
#  '<http://icondataset.org/ART1410>',
#  '<http://icondataset.org/ART1411>',
#  '<http://icondataset.org/ART1412>',
#  '<http://icondataset.org/ART1413>',
#  '<http://icondataset.org/ART1414>',
#  '<http://icondataset.org/ART1416>',
#  '<http://icondataset.org/ART1417>',
#  '<http://icondataset.org/ART1418>',
#  '<http://icondataset.org/ART1419>',
#  '<http://icondataset.org/ART1420>',
#  '<http://icondataset.org/ART1421>',
#  '<http://icondataset.org/ART1422>',
#  '<http://icondataset.org/ART1423>',
#  '<http://icondataset.org/ART1424>',
#  '<http://icondataset.org/ART1431>',
#  '<http://icondataset.org/ART1446>',
#  '<http://icondataset.org/ART1452>',
#  '<http://icondataset.org/ART1454>',
#  '<http://icondataset.org/ART1458>',
#  '<http://icondataset.org/ART1459>',
#  '<http://icondataset.org/ART1460>',
#  '<http://icondataset.org/ART1467>',
#  '<http://icondataset.org/ART1468>',
#  '<http://icondataset.org/ART1512>',
#  '<http://icondataset.org/ART1516>',
#  '<http://icondataset.org/ART1517>',
#  '<http://icondataset.org/ART1525>',
#  '<http://icondataset.org/ART1526>',
#  '<http://icondataset.org/ART1527>',
#  '<http://icondataset.org/ART1531>',
#  '<http://icondataset.org/ART1534>',
#  '<http://icondataset.org/ART1535>',
#  '<http://icondataset.org/ART1536>',
#  '<http://icondataset.org/ART1538>',
#  '<http://icondataset.org/ART1539>'}

# %%
# see the level 2 subjects that appear in artworks with a cf or without a cf
subj2_with_without_cf = lev2_without_cf.intersection(lev2_with_cf)

# %%
art_subj2_cf.intersection(art_subj2_without_cf)
# Out:
# set()

# %%
#level 1 representation of subj2 in artworks having a cf
# dict. structure: {subj 2 uri : set of lev 1 subj with which it's represented }
subj2_with_cf = {}

cq8 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>
prefix skos: <http://www.w3.org/2004/02/skos/core#>

SELECT DISTINCT ?subj1 ?subj2 ?artwork WHERE {
    VALUES ?rel1 {icon:hasFactualMeaning icon:hasExpressionalMeaning crm:P138_represents}
    VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
 VALUES ?subj2{ """+ ' '.join(subj2_with_without_cf) +"""}
 VALUES ?artwork { """+ ' '.join(art_subj2_cf) +"""}
  # ?img ?rel ?subj2; 
        ^icon:recognizedImage ?icrec.
  # ?icrec icon:aboutWorkOfArt ?artwork; 
        #  a icon:IconographicalRecognition;  
          icon:refersToArtisticMotif ?lev1.
{?lev1 icon:hasPart ?am. ?am ?rel1 ?subj1} UNION {?lev1 ?rel1 ?subj1}
# ?subj1 rdfs:label ?subj1Label. 

} 
""" 

cq8res = g.query(cq8)
for row in cq8res:
    print(row)
    subj2 = str(row[1])
    subj1 = str(row[0])
    if subj2 not in subj2_with_cf: 
        subj2_with_cf[subj2] = set()
    subj2_with_cf[subj2].add(subj1)
   # lev2_with_cf.add(inv)
    
subj2_with_cf
# Out:
# (rdflib.term.URIRef('http://icondataset.org/human'), rdflib.term.URIRef('http://icondataset.org/devil'), rdflib.term.URIRef('http://icondataset.org/ART1317'))
# (rdflib.term.URIRef('http://icondataset.org/holding-with-a-hand'), rdflib.term.URIRef('http://icondataset.org/devil'), rdflib.term.URIRef('http://icondataset.org/ART1317'))
# (rdflib.term.URIRef('http://icondataset.org/figure'), rdflib.term.URIRef('http://icondataset.org/devil'), rdflib.term.URIRef('http://icondataset.org/ART1317'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/tityus'), rdflib.term.URIRef('http://icondataset.org/ART1379'))
# (rdflib.term.URIRef('http://icondataset.org/touching-breast'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1338'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1338'))
# (rdflib.term.URIRef('http://icondataset.org/armor'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1338'))
# (rdflib.term.URIRef('http://icondataset.org/gentleman'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1338'))
# (rdflib.term.URIRef('http://icondataset.org/shield'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1036'))
# (rdflib.term.URIRef('http://icondataset.org/cloak'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1036'))
# (rdflib.term.URIRef('http://icondataset.org/hat'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1036'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1036'))
# (rdflib.term.URIRef('http://icondataset.org/backward-turning-movement'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1036'))
# (rdflib.term.URIRef('http://icondataset.org/spear'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1036'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1525'))
# (rdflib.term.URIRef('http://icondataset.org/shield'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1525'))
# (rdflib.term.URIRef('http://icondataset.org/spear'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1525'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-dog'), rdflib.term.URIRef('http://icondataset.org/serapis'), rdflib.term.URIRef('http://icondataset.org/ART1421'))
# (rdflib.term.URIRef('http://icondataset.org/three-headed-serpent'), rdflib.term.URIRef('http://icondataset.org/serapis'), rdflib.term.URIRef('http://icondataset.org/ART1421'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-wolf'), rdflib.term.URIRef('http://icondataset.org/serapis'), rdflib.term.URIRef('http://icondataset.org/ART1421'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-lion'), rdflib.term.URIRef('http://icondataset.org/serapis'), rdflib.term.URIRef('http://icondataset.org/ART1421'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1297'))
# (rdflib.term.URIRef('http://icondataset.org/tree'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1297'))
# (rdflib.term.URIRef('http://icondataset.org/arrow'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1297'))
# (rdflib.term.URIRef('http://icondataset.org/torch'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1297'))
# (rdflib.term.URIRef('http://icondataset.org/sitting-on'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1297'))
# (rdflib.term.URIRef('http://icondataset.org/clothes'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1297'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1297'))
# (rdflib.term.URIRef('http://icondataset.org/crown'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1297'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1446'))
# (rdflib.term.URIRef('http://icondataset.org/bow'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1446'))
# (rdflib.term.URIRef('http://icondataset.org/drawing-the-bow'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1446'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1001'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1201'))
# (rdflib.term.URIRef('http://icondataset.org/club'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1201'))
# (rdflib.term.URIRef('http://icondataset.org/standing-on-the-ground'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1233'))
# (rdflib.term.URIRef('http://icondataset.org/ground'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1233'))
# (rdflib.term.URIRef('http://icondataset.org/lifting-one-hand'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1458'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1458'))
# (rdflib.term.URIRef('http://icondataset.org/sceptre'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1458'))
# (rdflib.term.URIRef('http://icondataset.org/holding-with-the-right-hand'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1458'))
# (rdflib.term.URIRef('http://icondataset.org/halo-of-rays'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1458'))
# (rdflib.term.URIRef('http://icondataset.org/cornerstone-of-a-church'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1017test'))
# (rdflib.term.URIRef('http://icondataset.org/cloth'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1004'))
# (rdflib.term.URIRef('http://icondataset.org/carrying-on-shoulders'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1004'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1004'))
# (rdflib.term.URIRef('http://icondataset.org/crown'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1264'))
# (rdflib.term.URIRef('http://icondataset.org/cross'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1264'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1264'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1538'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1187'))
# (rdflib.term.URIRef('http://icondataset.org/halo'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1187'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1162'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1324'))
# (rdflib.term.URIRef('http://icondataset.org/fishing'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1324'))
# (rdflib.term.URIRef('http://icondataset.org/halo'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1324'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1324'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1319'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1319'))
# (rdflib.term.URIRef('http://icondataset.org/fishing'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1318'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1318'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1318'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1321'))
# (rdflib.term.URIRef('http://icondataset.org/tying'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1321'))
# (rdflib.term.URIRef('http://icondataset.org/tree'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1321'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/ganymede'), rdflib.term.URIRef('http://icondataset.org/ART1378'))
# (rdflib.term.URIRef('http://icondataset.org/clothes'), rdflib.term.URIRef('http://icondataset.org/laocoon'), rdflib.term.URIRef('http://icondataset.org/ART1042'))
# (rdflib.term.URIRef('http://icondataset.org/bear'), rdflib.term.URIRef('http://icondataset.org/laocoon'), rdflib.term.URIRef('http://icondataset.org/ART1042'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/laocoon'), rdflib.term.URIRef('http://icondataset.org/ART1042'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/christ-as-a-child'), rdflib.term.URIRef('http://icondataset.org/ART1539'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/christ-as-a-child'), rdflib.term.URIRef('http://icondataset.org/ART1232'))
# (rdflib.term.URIRef('http://icondataset.org/water'), rdflib.term.URIRef('http://icondataset.org/marine-snakes'), rdflib.term.URIRef('http://icondataset.org/ART1042'))
# (rdflib.term.URIRef('http://icondataset.org/serpent'), rdflib.term.URIRef('http://icondataset.org/marine-snakes'), rdflib.term.URIRef('http://icondataset.org/ART1042'))
# (rdflib.term.URIRef('http://icondataset.org/wings-at-the-heels'), rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.URIRef('http://icondataset.org/ART1019'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.URIRef('http://icondataset.org/ART1019'))
# (rdflib.term.URIRef('http://icondataset.org/sword'), rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.URIRef('http://icondataset.org/ART1019'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/antiphas-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1042'))
# (rdflib.term.URIRef('http://icondataset.org/clothes'), rdflib.term.URIRef('http://icondataset.org/antiphas-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1042'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1160'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1539'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1061'))
# (rdflib.term.URIRef('http://icondataset.org/statue-of-a-woman'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1355'))
# (rdflib.term.URIRef('http://icondataset.org/girl'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1008test'))
# (rdflib.term.URIRef('http://icondataset.org/holding-a-book'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1008test'))
# (rdflib.term.URIRef('http://icondataset.org/book'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1008test'))
# (rdflib.term.URIRef('http://icondataset.org/clothes'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1107'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1107'))
# (rdflib.term.URIRef('http://icondataset.org/face'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1107'))
# (rdflib.term.URIRef('http://icondataset.org/clothes'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1009test'))
# (rdflib.term.URIRef('http://icondataset.org/girl'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1009test'))
# (rdflib.term.URIRef('http://icondataset.org/halo'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1187'))
# (rdflib.term.URIRef('http://icondataset.org/mantle'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1187'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1187'))
# (rdflib.term.URIRef('http://icondataset.org/crown'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1339'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1339'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1338'))
# (rdflib.term.URIRef('http://icondataset.org/glass-sphere'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1338'))
# (rdflib.term.URIRef('http://icondataset.org/holding-on-her-lap'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1338'))
# (rdflib.term.URIRef('http://icondataset.org/clothes'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1030'))
# (rdflib.term.URIRef('http://icondataset.org/lady'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1030'))
# (rdflib.term.URIRef('http://icondataset.org/rose'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1030'))
# (rdflib.term.URIRef('http://icondataset.org/holding-a-rose-to-her-face'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1030'))
# (rdflib.term.URIRef('http://icondataset.org/holding-with-a-hand'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1121'))
# (rdflib.term.URIRef('http://icondataset.org/sea-goose'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1121'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1121'))
# (rdflib.term.URIRef('http://icondataset.org/emerging-from-the-water'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1121'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1288'))
# (rdflib.term.URIRef('http://icondataset.org/crown'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1044'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1044'))
# (rdflib.term.URIRef('http://icondataset.org/dove'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1000'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1000'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1122'))
# (rdflib.term.URIRef('http://icondataset.org/holding-with-a-hand'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1122'))
# (rdflib.term.URIRef('http://icondataset.org/sea-goose-with-a-fish-tail'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1122'))
# (rdflib.term.URIRef('http://icondataset.org/emerging-from-the-water'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1122'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1201'))
# (rdflib.term.URIRef('http://icondataset.org/arrow'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1201'))
# (rdflib.term.URIRef('http://icondataset.org/dove'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1123'))
# (rdflib.term.URIRef('http://icondataset.org/slate'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1123'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1123'))
# (rdflib.term.URIRef('http://icondataset.org/holding-with-a-hand'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1123'))
# (rdflib.term.URIRef('http://icondataset.org/rose'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1123'))
# (rdflib.term.URIRef('http://icondataset.org/emerging-from-the-water'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1123'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/david'), rdflib.term.URIRef('http://icondataset.org/ART1191'))
# (rdflib.term.URIRef('http://icondataset.org/drapery'), rdflib.term.URIRef('http://icondataset.org/david'), rdflib.term.URIRef('http://icondataset.org/ART1191'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/thymbraeus-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1042'))
# (rdflib.term.URIRef('http://icondataset.org/clothes'), rdflib.term.URIRef('http://icondataset.org/thymbraeus-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1042'))
# (rdflib.term.URIRef('http://icondataset.org/armor'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/cart'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/lending-both-hands-to-a-woman'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/knight'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1041'))
# (rdflib.term.URIRef('http://icondataset.org/jar'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1041'))
# (rdflib.term.URIRef('http://icondataset.org/grabbing-and-lifting-a-woman'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1005test'))
# (rdflib.term.URIRef('http://icondataset.org/crown'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1005test'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1005test'))
# (rdflib.term.URIRef('http://icondataset.org/sceptre'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1525'))
# (rdflib.term.URIRef('http://icondataset.org/holding-with-the-right-hand'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1525'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1525'))
# (rdflib.term.URIRef('http://icondataset.org/holding-with-the-left-hand'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1525'))
# (rdflib.term.URIRef('http://icondataset.org/flowers'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/lending-one-hand-to-a-man'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/sitting-down'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/gathering-flowers'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/court-dress'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1005test'))
# (rdflib.term.URIRef('http://icondataset.org/raising-arms-upwards'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1005test'))
# (rdflib.term.URIRef('http://icondataset.org/human-figure-with-animal-legs'), rdflib.term.URIRef('http://icondataset.org/satyr'), rdflib.term.URIRef('http://icondataset.org/ART1197'))
# (rdflib.term.URIRef('http://icondataset.org/woman-with-goat-legs'), rdflib.term.URIRef('http://icondataset.org/satyr'), rdflib.term.URIRef('http://icondataset.org/ART1197'))
# (rdflib.term.URIRef('http://icondataset.org/human-baby-with-animal-legs'), rdflib.term.URIRef('http://icondataset.org/satyr'), rdflib.term.URIRef('http://icondataset.org/ART1197'))
# (rdflib.term.URIRef('http://icondataset.org/human-figure-with-animal-legs'), rdflib.term.URIRef('http://icondataset.org/satyr'), rdflib.term.URIRef('http://icondataset.org/ART1315'))
# (rdflib.term.URIRef('http://icondataset.org/human-figure-with-animal-legs'), rdflib.term.URIRef('http://icondataset.org/satyr'), rdflib.term.URIRef('http://icondataset.org/ART1250'))
# (rdflib.term.URIRef('http://icondataset.org/human-figure-with-animal-legs'), rdflib.term.URIRef('http://icondataset.org/satyr'), rdflib.term.URIRef('http://icondataset.org/ART1316'))
# (rdflib.term.URIRef('http://icondataset.org/human-figure-with-animal-legs'), rdflib.term.URIRef('http://icondataset.org/satyr'), rdflib.term.URIRef('http://icondataset.org/ART1249'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/eve'), rdflib.term.URIRef('http://icondataset.org/ART1068'))
# (rdflib.term.URIRef('http://icondataset.org/clothes'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1270'))
# (rdflib.term.URIRef('http://icondataset.org/wooden-leg'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1270'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1270'))
# (rdflib.term.URIRef('http://icondataset.org/crutch'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1270'))
# (rdflib.term.URIRef('http://icondataset.org/king'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1265'))
# (rdflib.term.URIRef('http://icondataset.org/sitting-on'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1265'))
# (rdflib.term.URIRef('http://icondataset.org/throne'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1265'))
# (rdflib.term.URIRef('http://icondataset.org/spade'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1265'))
# (rdflib.term.URIRef('http://icondataset.org/crown'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1265'))
# (rdflib.term.URIRef('http://icondataset.org/bear'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1268'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1268'))
# (rdflib.term.URIRef('http://icondataset.org/scythe'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1268'))
# (rdflib.term.URIRef('http://icondataset.org/soldier'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1030'))
# (rdflib.term.URIRef('http://icondataset.org/helmet'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1030'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1212'))
# (rdflib.term.URIRef('http://icondataset.org/cloth'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1212'))
# (rdflib.term.URIRef('http://icondataset.org/sickle'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1212'))
# (rdflib.term.URIRef('http://icondataset.org/support-oneself-with'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1269'))
# (rdflib.term.URIRef('http://icondataset.org/crutch'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1269'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1269'))
# (rdflib.term.URIRef('http://icondataset.org/sickle'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1269'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1261'))
# (rdflib.term.URIRef('http://icondataset.org/cloth'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1261'))
# (rdflib.term.URIRef('http://icondataset.org/scythe'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1261'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1289'))
# (rdflib.term.URIRef('http://icondataset.org/bear'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1289'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1289'))
# (rdflib.term.URIRef('http://icondataset.org/king'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1266'))
# (rdflib.term.URIRef('http://icondataset.org/dragon-biting-its-tail'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1266'))
# (rdflib.term.URIRef('http://icondataset.org/scythe'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1266'))
# (rdflib.term.URIRef('http://icondataset.org/throne'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1266'))
# (rdflib.term.URIRef('http://icondataset.org/sitting-on'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1266'))
# (rdflib.term.URIRef('http://icondataset.org/crown'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1266'))
# (rdflib.term.URIRef('http://icondataset.org/sickle'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1043'))
# (rdflib.term.URIRef('http://icondataset.org/veil'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1043'))
# (rdflib.term.URIRef('http://icondataset.org/scythe'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1043'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1043'))
# (rdflib.term.URIRef('http://icondataset.org/dragon-biting-its-tail'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1043'))
# (rdflib.term.URIRef('http://icondataset.org/scythe'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1534'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1534'))
# (rdflib.term.URIRef('http://icondataset.org/bear'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1534'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1267'))
# (rdflib.term.URIRef('http://icondataset.org/scythe'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1267'))
# (rdflib.term.URIRef('http://icondataset.org/bear'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1267'))
# (rdflib.term.URIRef('http://icondataset.org/sickle'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1260'))
# (rdflib.term.URIRef('http://icondataset.org/veil'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1260'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1260'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1201'))
# (rdflib.term.URIRef('http://icondataset.org/scythe'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1201'))
# (rdflib.term.URIRef('http://icondataset.org/sickle'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1259'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1259'))
# (rdflib.term.URIRef('http://icondataset.org/veil'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1259'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1535'))
# (rdflib.term.URIRef('http://icondataset.org/bear'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1535'))
# (rdflib.term.URIRef('http://icondataset.org/stick'), rdflib.term.URIRef('http://icondataset.org/lapiths'), rdflib.term.URIRef('http://icondataset.org/ART1253'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/lapiths'), rdflib.term.URIRef('http://icondataset.org/ART1253'))
# (rdflib.term.URIRef('http://icondataset.org/three-headed-serpent'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1418'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-lion'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1419'))
# (rdflib.term.URIRef('http://icondataset.org/three-headed-serpent'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1419'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-dog'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1419'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-wolf'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1419'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-wolf'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1416'))
# (rdflib.term.URIRef('http://icondataset.org/three-headed-serpent'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1416'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-dog'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1416'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-lion'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1416'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-lion'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1417'))
# (rdflib.term.URIRef('http://icondataset.org/three-headed-serpent'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1417'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-wolf'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1417'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-dog'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1417'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-dog'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1423'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-lion'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1423'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-wolf'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1423'))
# (rdflib.term.URIRef('http://icondataset.org/three-headed-figure'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1423'))
# (rdflib.term.URIRef('http://icondataset.org/sceptre'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1421'))
# (rdflib.term.URIRef('http://icondataset.org/modius'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1421'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1421'))
# (rdflib.term.URIRef('http://icondataset.org/serpent'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1413'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-dog'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1413'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-wolf'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1413'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-lion'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1413'))
# (rdflib.term.URIRef('http://icondataset.org/three-headed-figure'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1413'))
# (rdflib.term.URIRef('http://icondataset.org/twisting-around'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1413'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-dog'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1414'))
# (rdflib.term.URIRef('http://icondataset.org/three-headed-figure'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1414'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-lion'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1414'))
# (rdflib.term.URIRef('http://icondataset.org/serpent'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1414'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-wolf'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1414'))
# (rdflib.term.URIRef('http://icondataset.org/twisting-around'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1414'))
# (rdflib.term.URIRef('http://icondataset.org/bow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1314'))
# (rdflib.term.URIRef('http://icondataset.org/talon'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1314'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1314'))
# (rdflib.term.URIRef('http://icondataset.org/arrow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1314'))
# (rdflib.term.URIRef('http://icondataset.org/bandage'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1314'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1314'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1339'))
# (rdflib.term.URIRef('http://icondataset.org/snuggling-in-her-lap'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1339'))
# (rdflib.term.URIRef('http://icondataset.org/putto'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1339'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1317'))
# (rdflib.term.URIRef('http://icondataset.org/bow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1317'))
# (rdflib.term.URIRef('http://icondataset.org/bandage'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1317'))
# (rdflib.term.URIRef('http://icondataset.org/arrow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1317'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1317'))
# (rdflib.term.URIRef('http://icondataset.org/sphere'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1326'))
# (rdflib.term.URIRef('http://icondataset.org/standing-on'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1326'))
# (rdflib.term.URIRef('http://icondataset.org/bandage'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1326'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1326'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1326'))
# (rdflib.term.URIRef('http://icondataset.org/arrow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1326'))
# (rdflib.term.URIRef('http://icondataset.org/bow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1323'))
# (rdflib.term.URIRef('http://icondataset.org/arrow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1323'))
# (rdflib.term.URIRef('http://icondataset.org/natural-landscape'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1323'))
# (rdflib.term.URIRef('http://icondataset.org/sleeping'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1323'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1323'))
# (rdflib.term.URIRef('http://icondataset.org/bandage'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1323'))
# (rdflib.term.URIRef('http://icondataset.org/throne'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1311'))
# (rdflib.term.URIRef('http://icondataset.org/string-of-hearts'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1311'))
# (rdflib.term.URIRef('http://icondataset.org/griffon-claws'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1311'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1311'))
# (rdflib.term.URIRef('http://icondataset.org/arrow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1311'))
# (rdflib.term.URIRef('http://icondataset.org/bandage'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1311'))
# (rdflib.term.URIRef('http://icondataset.org/bow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1311'))
# (rdflib.term.URIRef('http://icondataset.org/crown-of-roses'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1311'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1311'))
# (rdflib.term.URIRef('http://icondataset.org/hearts'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1310'))
# (rdflib.term.URIRef('http://icondataset.org/bow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1310'))
# (rdflib.term.URIRef('http://icondataset.org/arrow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1310'))
# (rdflib.term.URIRef('http://icondataset.org/bandage'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1310'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1310'))
# (rdflib.term.URIRef('http://icondataset.org/griffon-claws'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1310'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1310'))
# ...
# (rdflib.term.URIRef('http://icondataset.org/courteous-attitude'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/force'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1005test'))
# (rdflib.term.URIRef('http://icondataset.org/backward-gaze'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1005test'))
# (rdflib.term.URIRef('http://icondataset.org/crying'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1005test'))
# (rdflib.term.URIRef('http://icondataset.org/gloomy'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1265'))
# (rdflib.term.URIRef('http://icondataset.org/gloomy'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1266'))
# (rdflib.term.URIRef('http://icondataset.org/gloomy'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1260'))
# (rdflib.term.URIRef('http://icondataset.org/gloomy'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1259'))
# (rdflib.term.URIRef('http://icondataset.org/despair'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1535'))
# (rdflib.term.URIRef('http://icondataset.org/intense-devotion'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1338'))
# (rdflib.term.URIRef('http://icondataset.org/terrifying-expression'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1018'))
# (rdflib.term.URIRef('http://icondataset.org/terrifying-expression'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1024'))
# (rdflib.term.URIRef('http://icondataset.org/joyful-excitement'), rdflib.term.URIRef('http://icondataset.org/faith'), rdflib.term.URIRef('http://icondataset.org/ART1338'))
# (rdflib.term.URIRef('http://icondataset.org/disgust'), rdflib.term.URIRef('http://icondataset.org/truth'), rdflib.term.URIRef('http://icondataset.org/ART1288'))
# (rdflib.term.URIRef('http://icondataset.org/mors-aeterna'), rdflib.term.URIRef('http://icondataset.org/devil'), rdflib.term.URIRef('http://icondataset.org/ART1317'))
# (rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/triple-throated-cerberus'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1525'))
# (rdflib.term.URIRef('http://icondataset.org/preserpine'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1004test'))
# (rdflib.term.URIRef('http://icondataset.org/caput-meduse'), rdflib.term.URIRef('http://icondataset.org/medusas-head'), rdflib.term.URIRef('http://icondataset.org/ART1019'))
# (rdflib.term.URIRef('http://icondataset.org/caput-algol'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1018'))
# (rdflib.term.URIRef('http://icondataset.org/caput-meduse'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1019'))
# {'http://icondataset.org/devil': {'http://icondataset.org/figure',
#   'http://icondataset.org/holding-with-a-hand',
#   'http://icondataset.org/human',
#   'http://icondataset.org/mors-aeterna'},
#  'http://icondataset.org/tityus': {'http://icondataset.org/man'},
#  'http://icondataset.org/mars': {'http://icondataset.org/armor',
#   'http://icondataset.org/backward-turning-movement',
#   'http://icondataset.org/cloak',
#   'http://icondataset.org/gentleman',
#   'http://icondataset.org/hat',
#   'http://icondataset.org/man',
#   'http://icondataset.org/shield',
#   'http://icondataset.org/spear',
#   'http://icondataset.org/touching-breast',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/serapis': {'http://icondataset.org/head-of-a-dog',
#   'http://icondataset.org/head-of-a-lion',
#   'http://icondataset.org/head-of-a-wolf',
#   'http://icondataset.org/three-headed-serpent'},
#  'http://icondataset.org/dieu-amour': {'http://icondataset.org/arrow',
#   'http://icondataset.org/boy',
#   'http://icondataset.org/clothes',
#   'http://icondataset.org/crown',
#   'http://icondataset.org/sitting-on',
#   'http://icondataset.org/torch',
#   'http://icondataset.org/tree',
#   'http://icondataset.org/wings'},
#  'http://icondataset.org/hercules': {'http://icondataset.org/bow',
#   'http://icondataset.org/club',
#   'http://icondataset.org/drawing-the-bow',
#   'http://icondataset.org/energy',
#   'http://icondataset.org/forceful',
#   'http://icondataset.org/man',
#   'http://icondataset.org/powerful-sturdiness'},
#  'http://icondataset.org/christ': {'http://icondataset.org/carrying-on-shoulders',
#   'http://icondataset.org/child',
#   'http://icondataset.org/cloth',
#   'http://icondataset.org/condemning-gesture',
#   'http://icondataset.org/cornerstone-of-a-church',
#   'http://icondataset.org/cross',
#   'http://icondataset.org/crown',
#   'http://icondataset.org/ground',
#   'http://icondataset.org/halo',
#   'http://icondataset.org/halo-of-rays',
#   'http://icondataset.org/holding-with-the-right-hand',
#   'http://icondataset.org/lifting-one-hand',
#   'http://icondataset.org/man',
#   'http://icondataset.org/sceptre',
#   'http://icondataset.org/standing-on-the-ground'},
#  'http://icondataset.org/anteros': {'http://icondataset.org/boy',
#   'http://icondataset.org/child',
#   'http://icondataset.org/fishing',
#   'http://icondataset.org/halo',
#   'http://icondataset.org/tree',
#   'http://icondataset.org/tying',
#   'http://icondataset.org/wings'},
#  'http://icondataset.org/ganymede': {'http://icondataset.org/immobility',
#   'http://icondataset.org/man',
#   'http://icondataset.org/state-of-trance'},
#  'http://icondataset.org/laocoon': {'http://icondataset.org/bear',
#   'http://icondataset.org/clothes',
#   'http://icondataset.org/man'},
#  'http://icondataset.org/christ-as-a-child': {'http://icondataset.org/child'},
#  'http://icondataset.org/marine-snakes': {'http://icondataset.org/serpent',
#   'http://icondataset.org/water'},
#  'http://icondataset.org/perseus': {'http://icondataset.org/man',
#   'http://icondataset.org/sword',
#   'http://icondataset.org/wings-at-the-heels'},
#  'http://icondataset.org/antiphas-son-of-laoocoon': {'http://icondataset.org/boy',
#   'http://icondataset.org/clothes'},
#  'http://icondataset.org/mary': {'http://icondataset.org/book',
#   'http://icondataset.org/clothes',
#   'http://icondataset.org/face',
#   'http://icondataset.org/girl',
#   'http://icondataset.org/halo',
#   'http://icondataset.org/holding-a-book',
#   'http://icondataset.org/mantle',
#   'http://icondataset.org/smiling',
#   'http://icondataset.org/statue-of-a-woman',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/venus': {'http://icondataset.org/arrow',
#   'http://icondataset.org/clothes',
#   'http://icondataset.org/crown',
#   'http://icondataset.org/dove',
#   'http://icondataset.org/emerging-from-the-water',
#   'http://icondataset.org/glass-sphere',
#   'http://icondataset.org/holding-a-rose-to-her-face',
#   'http://icondataset.org/holding-on-her-lap',
#   'http://icondataset.org/holding-with-a-hand',
#   'http://icondataset.org/lady',
#   'http://icondataset.org/pensively',
#   'http://icondataset.org/rose',
#   'http://icondataset.org/sea-goose',
#   'http://icondataset.org/sea-goose-with-a-fish-tail',
#   'http://icondataset.org/slate',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/david': {'http://icondataset.org/agitated-movement',
#   'http://icondataset.org/boy',
#   'http://icondataset.org/drapery',
#   'http://icondataset.org/pathos',
#   'http://icondataset.org/victorious'},
#  'http://icondataset.org/thymbraeus-son-of-laoocoon': {'http://icondataset.org/boy',
#   'http://icondataset.org/clothes'},
#  'http://icondataset.org/pluto': {'http://icondataset.org/armor',
#   'http://icondataset.org/cart',
#   'http://icondataset.org/courteous-attitude',
#   'http://icondataset.org/crown',
#   'http://icondataset.org/force',
#   'http://icondataset.org/grabbing-and-lifting-a-woman',
#   'http://icondataset.org/holding-with-the-left-hand',
#   'http://icondataset.org/holding-with-the-right-hand',
#   'http://icondataset.org/jar',
#   'http://icondataset.org/knight',
#   'http://icondataset.org/lending-both-hands-to-a-woman',
#   'http://icondataset.org/man',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/sceptre',
#   'http://icondataset.org/triple-throated-cerberus'},
#  'http://icondataset.org/proserpina': {'http://icondataset.org/backward-gaze',
#   'http://icondataset.org/court-dress',
#   'http://icondataset.org/crying',
#   'http://icondataset.org/flowers',
#   'http://icondataset.org/gathering-flowers',
#   'http://icondataset.org/lending-one-hand-to-a-man',
#   'http://icondataset.org/preserpine',
#   'http://icondataset.org/raising-arms-upwards',
#   'http://icondataset.org/sitting-down',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/satyr': {'http://icondataset.org/human-baby-with-animal-legs',
#   'http://icondataset.org/human-figure-with-animal-legs',
#   'http://icondataset.org/woman-with-goat-legs'},
#  'http://icondataset.org/eve': {'http://icondataset.org/woman'},
#  'http://icondataset.org/saturn': {'http://icondataset.org/bear',
#   'http://icondataset.org/cloth',
#   'http://icondataset.org/clothes',
#   'http://icondataset.org/crown',
#   'http://icondataset.org/crutch',
#   'http://icondataset.org/despair',
#   'http://icondataset.org/dragon-biting-its-tail',
#   'http://icondataset.org/gloomy',
#   'http://icondataset.org/helmet',
#   'http://icondataset.org/king',
#   'http://icondataset.org/man',
#   'http://icondataset.org/scythe',
#   'http://icondataset.org/sickle',
#   'http://icondataset.org/sitting-on',
#   'http://icondataset.org/soldier',
#   'http://icondataset.org/spade',
#   'http://icondataset.org/support-oneself-with',
#   'http://icondataset.org/throne',
#   'http://icondataset.org/veil',
#   'http://icondataset.org/wings',
#   'http://icondataset.org/wooden-leg'},
#  'http://icondataset.org/lapiths': {'http://icondataset.org/man',
#   'http://icondataset.org/stick'},
#  'http://icondataset.org/companion-of-serapis': {'http://icondataset.org/head-of-a-dog',
#   'http://icondataset.org/head-of-a-lion',
#   'http://icondataset.org/head-of-a-wolf',
#   'http://icondataset.org/man',
#   'http://icondataset.org/modius',
#   'http://icondataset.org/sceptre',
#   'http://icondataset.org/serpent',
#   'http://icondataset.org/three-headed-figure',
#   'http://icondataset.org/three-headed-serpent',
#   'http://icondataset.org/twisting-around'},
#  'http://icondataset.org/blindfold-cupid': {'http://icondataset.org/arrow',
#   'http://icondataset.org/bandage',
#   'http://icondataset.org/bow',
#   'http://icondataset.org/boy',
#   'http://icondataset.org/child',
#   'http://icondataset.org/crown-of-roses',
#   'http://icondataset.org/griffon-claws',
#   'http://icondataset.org/hearts',
#   'http://icondataset.org/natural-landscape',
#   'http://icondataset.org/putto',
#   'http://icondataset.org/sleeping',
#   'http://icondataset.org/snuggling-in-her-lap',
#   'http://icondataset.org/sphere',
#   'http://icondataset.org/standing-on',
#   'http://icondataset.org/string-of-hearts',
#   'http://icondataset.org/talon',
#   'http://icondataset.org/throne',
#   'http://icondataset.org/wings'},
#  'http://icondataset.org/phaeton': {'http://icondataset.org/falling-off',
#   'http://icondataset.org/man'},
#  'http://icondataset.org/cupid': {'http://icondataset.org/arrow',
#   'http://icondataset.org/bandage',
#   'http://icondataset.org/boots',
#   'http://icondataset.org/bow',
#   'http://icondataset.org/boy',
#   'http://icondataset.org/child',
#   'http://icondataset.org/court-dress',
#   'http://icondataset.org/crown',
#   'http://icondataset.org/fire',
#   'http://icondataset.org/fishing',
#   'http://icondataset.org/flying',
#   'http://icondataset.org/girl',
#   'http://icondataset.org/grabbing-with-one-hand',
#   'http://icondataset.org/griffon-claws',
#   'http://icondataset.org/holding-with-a-hand',
#   'http://icondataset.org/horse',
#   'http://icondataset.org/intense-devotion',
#   'http://icondataset.org/lappets',
#   'http://icondataset.org/leaning-on-her-shoulder',
#   'http://icondataset.org/leaning-upon',
#   'http://icondataset.org/man',
#   'http://icondataset.org/mantle',
#   'http://icondataset.org/myrtle-wreath',
#   'http://icondataset.org/putto',
#   'http://icondataset.org/removing',
#   'http://icondataset.org/ribbon',
#   'http://icondataset.org/rose',
#   'http://icondataset.org/shooting-an-arrow',
#   'http://icondataset.org/sleeping',
#   'http://icondataset.org/standing-on-a-horse',
#   'http://icondataset.org/stirring-water',
#   'http://icondataset.org/string-of-hearts',
#   'http://icondataset.org/taking-aim',
#   'http://icondataset.org/torch',
#   'http://icondataset.org/wings',
#   'http://icondataset.org/woman',
#   'http://icondataset.org/wreath',
#   'http://icondataset.org/young'},
#  'http://icondataset.org/mercurys-winged-sandals': {'http://icondataset.org/bird',
#   'http://icondataset.org/wings-at-the-heels'},
#  'http://icondataset.org/medusas-head': {'http://icondataset.org/caput-meduse',
#   'http://icondataset.org/cutten-head',
#   'http://icondataset.org/serpent-locks'},
#  'http://icondataset.org/luxury': {'http://icondataset.org/woman'},
#  'http://icondataset.org/the-constellation-perseus': {'http://icondataset.org/beard',
#   'http://icondataset.org/caput-algol',
#   'http://icondataset.org/caput-meduse',
#   'http://icondataset.org/constellation',
#   'http://icondataset.org/cutten-head',
#   'http://icondataset.org/gown',
#   'http://icondataset.org/grabbing-with-one-hand',
#   'http://icondataset.org/lifting-one-hand',
#   'http://icondataset.org/lifting-with-one-hand',
#   'http://icondataset.org/man',
#   'http://icondataset.org/serpent-locks',
#   'http://icondataset.org/sword',
#   'http://icondataset.org/terrifying-expression'},
#  'http://icondataset.org/faith': {'http://icondataset.org/basket-with-roses',
#   'http://icondataset.org/figure',
#   'http://icondataset.org/glancing-heavenward',
#   'http://icondataset.org/joyful-excitement',
#   'http://icondataset.org/raising'},
#  'http://icondataset.org/blind-night': {'http://icondataset.org/bandage',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/platonic-love': {'http://icondataset.org/arrow',
#   'http://icondataset.org/child',
#   'http://icondataset.org/wings'},
#  'http://icondataset.org/day': {'http://icondataset.org/man'},
#  'http://icondataset.org/truth': {'http://icondataset.org/child',
#   'http://icondataset.org/curtain',
#   'http://icondataset.org/disgust',
#   'http://icondataset.org/girl',
#   'http://icondataset.org/removing',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/chastity': {'http://icondataset.org/arrow',
#   'http://icondataset.org/covering-herself',
#   'http://icondataset.org/maiden',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/phaeton-the-presumptuous': {'http://icondataset.org/falling-off',
#   'http://icondataset.org/man'},
#  'http://icondataset.org/four-wings-four-seasons': {'http://icondataset.org/wings'},
#  'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': {'http://icondataset.org/chariot',
#   'http://icondataset.org/eagle',
#   'http://icondataset.org/falling-off',
#   'http://icondataset.org/group-of-figures',
#   'http://icondataset.org/horse',
#   'http://icondataset.org/hurling',
#   'http://icondataset.org/man',
#   'http://icondataset.org/thunderbolt'},
#  'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom': {'http://icondataset.org/statue-of-a-slave'}}

# %%
#level 1 representation of subj2 in artworks not having a cf
# dict. structure: {subj 2 uri : set of lev 1 subj with which it's represented }
subj2_without_cf = {}

cq9 = """
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>
prefix skos: <http://www.w3.org/2004/02/skos/core#>

SELECT DISTINCT ?subj1 ?subj2 ?artwork WHERE {
    VALUES ?rel1 {icon:hasFactualMeaning icon:hasExpressionalMeaning crm:P138_represents}
    VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
 VALUES ?subj2{ """+ ' '.join(subj2_with_without_cf) +"""}
 VALUES ?artwork { """+ ' '.join(art_subj2_without_cf) +"""}
  # ?img ?rel ?subj2; 
        ^icon:recognizedImage ?icrec.
  # ?icrec icon:aboutWorkOfArt ?artwork; 
        #  a icon:IconographicalRecognition;  
          icon:refersToArtisticMotif ?lev1.
{?lev1 icon:hasPart ?am. ?am ?rel1 ?subj1} UNION {?lev1 ?rel1 ?subj1}
# ?subj1 rdfs:label ?subj1Label. 

} 
""" 

cq9res = g.query(cq9)
for row in cq9res:
    print(row)
    subj2 = str(row[1])
    subj1 = str(row[0])
    if subj2 not in subj2_without_cf: 
        subj2_without_cf[subj2] = set()
    subj2_without_cf[subj2].add(subj1)
   # lev2_with_cf.add(inv)
    
subj2_without_cf
# Out:
# (rdflib.term.URIRef('http://icondataset.org/winged-creature'), rdflib.term.URIRef('http://icondataset.org/devil'), rdflib.term.URIRef('http://icondataset.org/ART1388'))
# (rdflib.term.URIRef('http://icondataset.org/fettered-man'), rdflib.term.URIRef('http://icondataset.org/tityus'), rdflib.term.URIRef('http://icondataset.org/ART1380'))
# (rdflib.term.URIRef('http://icondataset.org/spear'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1037'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1037'))
# (rdflib.term.URIRef('http://icondataset.org/cloak'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1037'))
# (rdflib.term.URIRef('http://icondataset.org/helmet'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1037'))
# (rdflib.term.URIRef('http://icondataset.org/shield'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1037'))
# (rdflib.term.URIRef('http://icondataset.org/backward-turning-movement'), rdflib.term.URIRef('http://icondataset.org/mars'), rdflib.term.URIRef('http://icondataset.org/ART1037'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/serapis'), rdflib.term.URIRef('http://icondataset.org/ART1415'))
# (rdflib.term.URIRef('http://icondataset.org/throne'), rdflib.term.URIRef('http://icondataset.org/serapis'), rdflib.term.URIRef('http://icondataset.org/ART1415'))
# (rdflib.term.URIRef('http://icondataset.org/sceptre'), rdflib.term.URIRef('http://icondataset.org/serapis'), rdflib.term.URIRef('http://icondataset.org/ART1415'))
# (rdflib.term.URIRef('http://icondataset.org/modius'), rdflib.term.URIRef('http://icondataset.org/serapis'), rdflib.term.URIRef('http://icondataset.org/ART1415'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1296'))
# (rdflib.term.URIRef('http://icondataset.org/clothes'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1296'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1296'))
# (rdflib.term.URIRef('http://icondataset.org/crown'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1296'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1295'))
# (rdflib.term.URIRef('http://icondataset.org/arrow'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1295'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1295'))
# (rdflib.term.URIRef('http://icondataset.org/clothes'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1295'))
# (rdflib.term.URIRef('http://icondataset.org/bow'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1295'))
# (rdflib.term.URIRef('http://icondataset.org/crown'), rdflib.term.URIRef('http://icondataset.org/dieu-amour'), rdflib.term.URIRef('http://icondataset.org/ART1295'))
# (rdflib.term.URIRef('http://icondataset.org/drawing-the-bow'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1447'))
# (rdflib.term.URIRef('http://icondataset.org/bow'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1447'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1447'))
# (rdflib.term.URIRef('http://icondataset.org/supporting'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1237'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1237'))
# (rdflib.term.URIRef('http://icondataset.org/sphere'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1237'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1003'))
# (rdflib.term.URIRef('http://icondataset.org/lion-skin'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1003'))
# (rdflib.term.URIRef('http://icondataset.org/carrying-on-shoulders'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1003'))
# (rdflib.term.URIRef('http://icondataset.org/figure'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1392'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1537'))
# (rdflib.term.URIRef('http://icondataset.org/dead-body-of-a-man'), rdflib.term.URIRef('http://icondataset.org/christ'), rdflib.term.URIRef('http://icondataset.org/ART1543'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1308'))
# (rdflib.term.URIRef('http://icondataset.org/putto'), rdflib.term.URIRef('http://icondataset.org/anteros'), rdflib.term.URIRef('http://icondataset.org/ART1308'))
# (rdflib.term.URIRef('http://icondataset.org/cloth'), rdflib.term.URIRef('http://icondataset.org/ganymede'), rdflib.term.URIRef('http://icondataset.org/ART1389'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/ganymede'), rdflib.term.URIRef('http://icondataset.org/ART1389'))
# (rdflib.term.URIRef('http://icondataset.org/wiggling-out-of-serpents'), rdflib.term.URIRef('http://icondataset.org/laocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/bear'), rdflib.term.URIRef('http://icondataset.org/laocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/laocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/christ-as-a-child'), rdflib.term.URIRef('http://icondataset.org/ART1373'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/christ-as-a-child'), rdflib.term.URIRef('http://icondataset.org/ART1372'))
# (rdflib.term.URIRef('http://icondataset.org/grabbing'), rdflib.term.URIRef('http://icondataset.org/marine-snakes'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/serpent'), rdflib.term.URIRef('http://icondataset.org/marine-snakes'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/lifting-with-one-hand'), rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/sword'), rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/cloth'), rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/cutten-head'), rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/wings-at-the-heels'), rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/running'), rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/wiggling-out-of-serpents'), rdflib.term.URIRef('http://icondataset.org/antiphas-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/antiphas-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/cloth'), rdflib.term.URIRef('http://icondataset.org/antiphas-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1373'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1372'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1363'))
# (rdflib.term.URIRef('http://icondataset.org/dais'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1199'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1199'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1332'))
# (rdflib.term.URIRef('http://icondataset.org/sketch-of-a-human-figure'), rdflib.term.URIRef('http://icondataset.org/mary'), rdflib.term.URIRef('http://icondataset.org/ART1370'))
# (rdflib.term.URIRef('http://icondataset.org/earring'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/knotted-ribbon-bracelet'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/tiara'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/rose'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/veil'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/rose-petal'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/touching-breast'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/holding-a-wreath'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/belt'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/holding-with-a-hand'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1210'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1210'))
# (rdflib.term.URIRef('http://icondataset.org/seashell'), rdflib.term.URIRef('http://icondataset.org/venus'), rdflib.term.URIRef('http://icondataset.org/ART1210'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/david'), rdflib.term.URIRef('http://icondataset.org/ART1373'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/thymbraeus-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/cloth'), rdflib.term.URIRef('http://icondataset.org/thymbraeus-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/wiggling-out-of-serpents'), rdflib.term.URIRef('http://icondataset.org/thymbraeus-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/figure'), rdflib.term.URIRef('http://icondataset.org/pluto'), rdflib.term.URIRef('http://icondataset.org/ART1286'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/proserpina'), rdflib.term.URIRef('http://icondataset.org/ART1286'))
# (rdflib.term.URIRef('http://icondataset.org/human-figure-with-animal-legs'), rdflib.term.URIRef('http://icondataset.org/satyr'), rdflib.term.URIRef('http://icondataset.org/ART1478'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/eve'), rdflib.term.URIRef('http://icondataset.org/ART1457'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/eve'), rdflib.term.URIRef('http://icondataset.org/ART1332'))
# (rdflib.term.URIRef('http://icondataset.org/bear'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1015test'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1015test'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/saturn'), rdflib.term.URIRef('http://icondataset.org/ART1015test'))
# (rdflib.term.URIRef('http://icondataset.org/people'), rdflib.term.URIRef('http://icondataset.org/lapiths'), rdflib.term.URIRef('http://icondataset.org/ART1533'))
# (rdflib.term.URIRef('http://icondataset.org/twisting-around'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1415'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-lion'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1415'))
# (rdflib.term.URIRef('http://icondataset.org/three-headed-figure'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1415'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-dog'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1415'))
# (rdflib.term.URIRef('http://icondataset.org/head-of-a-wolf'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1415'))
# (rdflib.term.URIRef('http://icondataset.org/serpent'), rdflib.term.URIRef('http://icondataset.org/companion-of-serapis'), rdflib.term.URIRef('http://icondataset.org/ART1415'))
# (rdflib.term.URIRef('http://icondataset.org/standing-on-a-horse'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1313'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1313'))
# (rdflib.term.URIRef('http://icondataset.org/arrow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1313'))
# (rdflib.term.URIRef('http://icondataset.org/spear'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1313'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1313'))
# (rdflib.term.URIRef('http://icondataset.org/bow'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1313'))
# (rdflib.term.URIRef('http://icondataset.org/griffon-claws'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1313'))
# (rdflib.term.URIRef('http://icondataset.org/horse'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1313'))
# (rdflib.term.URIRef('http://icondataset.org/band'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1313'))
# (rdflib.term.URIRef('http://icondataset.org/bandage'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1322'))
# (rdflib.term.URIRef('http://icondataset.org/child'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1322'))
# (rdflib.term.URIRef('http://icondataset.org/running'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1322'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/blindfold-cupid'), rdflib.term.URIRef('http://icondataset.org/ART1322'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/phaeton'), rdflib.term.URIRef('http://icondataset.org/ART1390'))
# (rdflib.term.URIRef('http://icondataset.org/falling-off'), rdflib.term.URIRef('http://icondataset.org/phaeton'), rdflib.term.URIRef('http://icondataset.org/ART1390'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1308'))
# (rdflib.term.URIRef('http://icondataset.org/putto'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1308'))
# (rdflib.term.URIRef('http://icondataset.org/bow'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/holding-a-wreath'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/putto'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/torch'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1293'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1293'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1293'))
# (rdflib.term.URIRef('http://icondataset.org/arrow'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1293'))
# (rdflib.term.URIRef('http://icondataset.org/mantle'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1293'))
# (rdflib.term.URIRef('http://icondataset.org/wings-at-the-heels'), rdflib.term.URIRef('http://icondataset.org/mercurys-winged-sandals'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/cutten-head'), rdflib.term.URIRef('http://icondataset.org/medusas-head'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/serpent-locks'), rdflib.term.URIRef('http://icondataset.org/medusas-head'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/drops-of-blood'), rdflib.term.URIRef('http://icondataset.org/medusas-head'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/embracing'), rdflib.term.URIRef('http://icondataset.org/luxury'), rdflib.term.URIRef('http://icondataset.org/ART1134'))
# (rdflib.term.URIRef('http://icondataset.org/lover'), rdflib.term.URIRef('http://icondataset.org/luxury'), rdflib.term.URIRef('http://icondataset.org/ART1134'))
# (rdflib.term.URIRef('http://icondataset.org/drops-of-blood'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/grabbing-with-one-hand'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/wings-at-the-heels'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/running'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/lifting-with-one-hand'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/sword'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/serpent-locks'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/cloth'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/cutten-head'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/faith'), rdflib.term.URIRef('http://icondataset.org/ART1134'))
# (rdflib.term.URIRef('http://icondataset.org/veil'), rdflib.term.URIRef('http://icondataset.org/blind-night'), rdflib.term.URIRef('http://icondataset.org/ART1302'))
# (rdflib.term.URIRef('http://icondataset.org/figure'), rdflib.term.URIRef('http://icondataset.org/blind-night'), rdflib.term.URIRef('http://icondataset.org/ART1302'))
# (rdflib.term.URIRef('http://icondataset.org/veil'), rdflib.term.URIRef('http://icondataset.org/blind-night'), rdflib.term.URIRef('http://icondataset.org/ART1299'))
# (rdflib.term.URIRef('http://icondataset.org/covering-her-eyes'), rdflib.term.URIRef('http://icondataset.org/blind-night'), rdflib.term.URIRef('http://icondataset.org/ART1299'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/blind-night'), rdflib.term.URIRef('http://icondataset.org/ART1299'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/platonic-love'), rdflib.term.URIRef('http://icondataset.org/ART1322'))
# (rdflib.term.URIRef('http://icondataset.org/boy'), rdflib.term.URIRef('http://icondataset.org/platonic-love'), rdflib.term.URIRef('http://icondataset.org/ART1322'))
# (rdflib.term.URIRef('http://icondataset.org/torch'), rdflib.term.URIRef('http://icondataset.org/platonic-love'), rdflib.term.URIRef('http://icondataset.org/ART1322'))
# (rdflib.term.URIRef('http://icondataset.org/figure'), rdflib.term.URIRef('http://icondataset.org/day'), rdflib.term.URIRef('http://icondataset.org/ART1302'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/truth'), rdflib.term.URIRef('http://icondataset.org/ART1015test'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/chastity'), rdflib.term.URIRef('http://icondataset.org/ART1134'))
# (rdflib.term.URIRef('http://icondataset.org/lilium'), rdflib.term.URIRef('http://icondataset.org/chastity'), rdflib.term.URIRef('http://icondataset.org/ART1509'))
# (rdflib.term.URIRef('http://icondataset.org/woman'), rdflib.term.URIRef('http://icondataset.org/chastity'), rdflib.term.URIRef('http://icondataset.org/ART1509'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/phaeton-the-presumptuous'), rdflib.term.URIRef('http://icondataset.org/ART1390'))
# (rdflib.term.URIRef('http://icondataset.org/falling-off'), rdflib.term.URIRef('http://icondataset.org/phaeton-the-presumptuous'), rdflib.term.URIRef('http://icondataset.org/ART1390'))
# (rdflib.term.URIRef('http://icondataset.org/wings'), rdflib.term.URIRef('http://icondataset.org/four-wings-four-seasons'), rdflib.term.URIRef('http://icondataset.org/ART1271'))
# (rdflib.term.URIRef('http://icondataset.org/cloud'), rdflib.term.URIRef('http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius'), rdflib.term.URIRef('http://icondataset.org/ART1390'))
# (rdflib.term.URIRef('http://icondataset.org/falling-off'), rdflib.term.URIRef('http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius'), rdflib.term.URIRef('http://icondataset.org/ART1390'))
# (rdflib.term.URIRef('http://icondataset.org/horse'), rdflib.term.URIRef('http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius'), rdflib.term.URIRef('http://icondataset.org/ART1390'))
# (rdflib.term.URIRef('http://icondataset.org/man'), rdflib.term.URIRef('http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius'), rdflib.term.URIRef('http://icondataset.org/ART1390'))
# (rdflib.term.URIRef('http://icondataset.org/sun'), rdflib.term.URIRef('http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius'), rdflib.term.URIRef('http://icondataset.org/ART1390'))
# (rdflib.term.URIRef('http://icondataset.org/slave'), rdflib.term.URIRef('http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom'), rdflib.term.URIRef('http://icondataset.org/ART1360'))
# (rdflib.term.URIRef('http://icondataset.org/effort'), rdflib.term.URIRef('http://icondataset.org/hercules'), rdflib.term.URIRef('http://icondataset.org/ART1237'))
# (rdflib.term.URIRef('http://icondataset.org/pathos'), rdflib.term.URIRef('http://icondataset.org/laocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/despair'), rdflib.term.URIRef('http://icondataset.org/laocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/grace'), rdflib.term.URIRef('http://icondataset.org/perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/despair'), rdflib.term.URIRef('http://icondataset.org/antiphas-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/despair'), rdflib.term.URIRef('http://icondataset.org/thymbraeus-son-of-laoocoon'), rdflib.term.URIRef('http://icondataset.org/ART1006test'))
# (rdflib.term.URIRef('http://icondataset.org/playful-attitude'), rdflib.term.URIRef('http://icondataset.org/cupid'), rdflib.term.URIRef('http://icondataset.org/ART1002test'))
# (rdflib.term.URIRef('http://icondataset.org/grace'), rdflib.term.URIRef('http://icondataset.org/the-constellation-perseus'), rdflib.term.URIRef('http://icondataset.org/ART1023'))
# (rdflib.term.URIRef('http://icondataset.org/despair'), rdflib.term.URIRef('http://icondataset.org/truth'), rdflib.term.URIRef('http://icondataset.org/ART1015test'))
# {'http://icondataset.org/devil': {'http://icondataset.org/winged-creature'},
#  'http://icondataset.org/tityus': {'http://icondataset.org/fettered-man'},
#  'http://icondataset.org/mars': {'http://icondataset.org/backward-turning-movement',
#   'http://icondataset.org/cloak',
#   'http://icondataset.org/helmet',
#   'http://icondataset.org/man',
#   'http://icondataset.org/shield',
#   'http://icondataset.org/spear'},
#  'http://icondataset.org/serapis': {'http://icondataset.org/modius',
#   'http://icondataset.org/sceptre',
#   'http://icondataset.org/throne',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/dieu-amour': {'http://icondataset.org/arrow',
#   'http://icondataset.org/bow',
#   'http://icondataset.org/boy',
#   'http://icondataset.org/clothes',
#   'http://icondataset.org/crown',
#   'http://icondataset.org/wings'},
#  'http://icondataset.org/hercules': {'http://icondataset.org/bow',
#   'http://icondataset.org/carrying-on-shoulders',
#   'http://icondataset.org/drawing-the-bow',
#   'http://icondataset.org/effort',
#   'http://icondataset.org/figure',
#   'http://icondataset.org/lion-skin',
#   'http://icondataset.org/man',
#   'http://icondataset.org/sphere',
#   'http://icondataset.org/supporting'},
#  'http://icondataset.org/christ': {'http://icondataset.org/dead-body-of-a-man',
#   'http://icondataset.org/man'},
#  'http://icondataset.org/anteros': {'http://icondataset.org/putto',
#   'http://icondataset.org/wings'},
#  'http://icondataset.org/ganymede': {'http://icondataset.org/cloth',
#   'http://icondataset.org/man'},
#  'http://icondataset.org/laocoon': {'http://icondataset.org/bear',
#   'http://icondataset.org/despair',
#   'http://icondataset.org/man',
#   'http://icondataset.org/pathos',
#   'http://icondataset.org/wiggling-out-of-serpents'},
#  'http://icondataset.org/christ-as-a-child': {'http://icondataset.org/child'},
#  'http://icondataset.org/marine-snakes': {'http://icondataset.org/grabbing',
#   'http://icondataset.org/serpent'},
#  'http://icondataset.org/perseus': {'http://icondataset.org/cloth',
#   'http://icondataset.org/cutten-head',
#   'http://icondataset.org/grace',
#   'http://icondataset.org/lifting-with-one-hand',
#   'http://icondataset.org/man',
#   'http://icondataset.org/running',
#   'http://icondataset.org/sword',
#   'http://icondataset.org/wings-at-the-heels'},
#  'http://icondataset.org/antiphas-son-of-laoocoon': {'http://icondataset.org/boy',
#   'http://icondataset.org/cloth',
#   'http://icondataset.org/despair',
#   'http://icondataset.org/wiggling-out-of-serpents'},
#  'http://icondataset.org/mary': {'http://icondataset.org/dais',
#   'http://icondataset.org/sketch-of-a-human-figure',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/venus': {'http://icondataset.org/belt',
#   'http://icondataset.org/earring',
#   'http://icondataset.org/holding-a-wreath',
#   'http://icondataset.org/holding-with-a-hand',
#   'http://icondataset.org/knotted-ribbon-bracelet',
#   'http://icondataset.org/rose',
#   'http://icondataset.org/rose-petal',
#   'http://icondataset.org/seashell',
#   'http://icondataset.org/tiara',
#   'http://icondataset.org/touching-breast',
#   'http://icondataset.org/veil',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/david': {'http://icondataset.org/man'},
#  'http://icondataset.org/thymbraeus-son-of-laoocoon': {'http://icondataset.org/boy',
#   'http://icondataset.org/cloth',
#   'http://icondataset.org/despair',
#   'http://icondataset.org/wiggling-out-of-serpents'},
#  'http://icondataset.org/pluto': {'http://icondataset.org/figure'},
#  'http://icondataset.org/proserpina': {'http://icondataset.org/woman'},
#  'http://icondataset.org/satyr': {'http://icondataset.org/human-figure-with-animal-legs'},
#  'http://icondataset.org/eve': {'http://icondataset.org/woman'},
#  'http://icondataset.org/saturn': {'http://icondataset.org/bear',
#   'http://icondataset.org/man',
#   'http://icondataset.org/wings'},
#  'http://icondataset.org/lapiths': {'http://icondataset.org/people'},
#  'http://icondataset.org/companion-of-serapis': {'http://icondataset.org/head-of-a-dog',
#   'http://icondataset.org/head-of-a-lion',
#   'http://icondataset.org/head-of-a-wolf',
#   'http://icondataset.org/serpent',
#   'http://icondataset.org/three-headed-figure',
#   'http://icondataset.org/twisting-around'},
#  'http://icondataset.org/blindfold-cupid': {'http://icondataset.org/arrow',
#   'http://icondataset.org/band',
#   'http://icondataset.org/bandage',
#   'http://icondataset.org/bow',
#   'http://icondataset.org/boy',
#   'http://icondataset.org/child',
#   'http://icondataset.org/griffon-claws',
#   'http://icondataset.org/horse',
#   'http://icondataset.org/running',
#   'http://icondataset.org/spear',
#   'http://icondataset.org/standing-on-a-horse',
#   'http://icondataset.org/wings'},
#  'http://icondataset.org/phaeton': {'http://icondataset.org/falling-off',
#   'http://icondataset.org/man'},
#  'http://icondataset.org/cupid': {'http://icondataset.org/arrow',
#   'http://icondataset.org/bow',
#   'http://icondataset.org/boy',
#   'http://icondataset.org/holding-a-wreath',
#   'http://icondataset.org/mantle',
#   'http://icondataset.org/playful-attitude',
#   'http://icondataset.org/putto',
#   'http://icondataset.org/torch',
#   'http://icondataset.org/wings'},
#  'http://icondataset.org/mercurys-winged-sandals': {'http://icondataset.org/wings-at-the-heels'},
#  'http://icondataset.org/medusas-head': {'http://icondataset.org/cutten-head',
#   'http://icondataset.org/drops-of-blood',
#   'http://icondataset.org/serpent-locks'},
#  'http://icondataset.org/luxury': {'http://icondataset.org/embracing',
#   'http://icondataset.org/lover'},
#  'http://icondataset.org/the-constellation-perseus': {'http://icondataset.org/cloth',
#   'http://icondataset.org/cutten-head',
#   'http://icondataset.org/drops-of-blood',
#   'http://icondataset.org/grabbing-with-one-hand',
#   'http://icondataset.org/grace',
#   'http://icondataset.org/lifting-with-one-hand',
#   'http://icondataset.org/man',
#   'http://icondataset.org/running',
#   'http://icondataset.org/serpent-locks',
#   'http://icondataset.org/sword',
#   'http://icondataset.org/wings-at-the-heels'},
#  'http://icondataset.org/faith': {'http://icondataset.org/woman'},
#  'http://icondataset.org/blind-night': {'http://icondataset.org/covering-her-eyes',
#   'http://icondataset.org/figure',
#   'http://icondataset.org/veil',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/platonic-love': {'http://icondataset.org/boy',
#   'http://icondataset.org/torch',
#   'http://icondataset.org/wings'},
#  'http://icondataset.org/day': {'http://icondataset.org/figure'},
#  'http://icondataset.org/truth': {'http://icondataset.org/despair',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/chastity': {'http://icondataset.org/lilium',
#   'http://icondataset.org/woman'},
#  'http://icondataset.org/phaeton-the-presumptuous': {'http://icondataset.org/falling-off',
#   'http://icondataset.org/man'},
#  'http://icondataset.org/four-wings-four-seasons': {'http://icondataset.org/wings'},
#  'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': {'http://icondataset.org/cloud',
#   'http://icondataset.org/falling-off',
#   'http://icondataset.org/horse',
#   'http://icondataset.org/man',
#   'http://icondataset.org/sun'},
#  'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom': {'http://icondataset.org/slave'}}

# %%
# extract the differences of subj2 represented in artworks having and not having a cf
cfr_subj2_dict = {}
for subj2 in subj2_without_cf.items(): 
    for subj2cf in subj2_with_cf.items(): 
        if subj2[0] == subj2cf[0]: 
            if subj2[0] not in cfr_subj2_dict: 
                cfr_subj2_dict[subj2[0]] = {}
            only_not_cf = subj2[1] - subj2cf[1] # items only in the not cf set
            only_cf = subj2cf[1] - subj2[1] # items only in the cf set
            same = subj2[1].intersection(subj2cf[1]) # items in both 
            cfr_subj2_dict[subj2[0]]["only not cf"] = only_not_cf
            cfr_subj2_dict[subj2[0]]["only cf"] = only_cf
            cfr_subj2_dict[subj2[0]]["in both"] = same
cfr_subj2_dict
# Out:
# {'http://icondataset.org/devil': {'only not cf': {'http://icondataset.org/winged-creature'},
#   'only cf': {'http://icondataset.org/figure',
#    'http://icondataset.org/holding-with-a-hand',
#    'http://icondataset.org/human',
#    'http://icondataset.org/mors-aeterna'},
#   'in both': set()},
#  'http://icondataset.org/tityus': {'only not cf': {'http://icondataset.org/fettered-man'},
#   'only cf': {'http://icondataset.org/man'},
#   'in both': set()},
#  'http://icondataset.org/mars': {'only not cf': {'http://icondataset.org/helmet'},
#   'only cf': {'http://icondataset.org/armor',
#    'http://icondataset.org/gentleman',
#    'http://icondataset.org/hat',
#    'http://icondataset.org/touching-breast',
#    'http://icondataset.org/woman'},
#   'in both': {'http://icondataset.org/backward-turning-movement',
#    'http://icondataset.org/cloak',
#    'http://icondataset.org/man',
#    'http://icondataset.org/shield',
#    'http://icondataset.org/spear'}},
#  'http://icondataset.org/serapis': {'only not cf': {'http://icondataset.org/modius',
#    'http://icondataset.org/sceptre',
#    'http://icondataset.org/throne',
#    'http://icondataset.org/woman'},
#   'only cf': {'http://icondataset.org/head-of-a-dog',
#    'http://icondataset.org/head-of-a-lion',
#    'http://icondataset.org/head-of-a-wolf',
#    'http://icondataset.org/three-headed-serpent'},
#   'in both': set()},
#  'http://icondataset.org/dieu-amour': {'only not cf': {'http://icondataset.org/bow'},
#   'only cf': {'http://icondataset.org/sitting-on',
#    'http://icondataset.org/torch',
#    'http://icondataset.org/tree'},
#   'in both': {'http://icondataset.org/arrow',
#    'http://icondataset.org/boy',
#    'http://icondataset.org/clothes',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/wings'}},
#  'http://icondataset.org/hercules': {'only not cf': {'http://icondataset.org/carrying-on-shoulders',
#    'http://icondataset.org/effort',
#    'http://icondataset.org/figure',
#    'http://icondataset.org/lion-skin',
#    'http://icondataset.org/sphere',
#    'http://icondataset.org/supporting'},
#   'only cf': {'http://icondataset.org/club',
#    'http://icondataset.org/energy',
#    'http://icondataset.org/forceful',
#    'http://icondataset.org/powerful-sturdiness'},
#   'in both': {'http://icondataset.org/bow',
#    'http://icondataset.org/drawing-the-bow',
#    'http://icondataset.org/man'}},
#  'http://icondataset.org/christ': {'only not cf': {'http://icondataset.org/dead-body-of-a-man'},
#   'only cf': {'http://icondataset.org/carrying-on-shoulders',
#    'http://icondataset.org/child',
#    'http://icondataset.org/cloth',
#    'http://icondataset.org/condemning-gesture',
#    'http://icondataset.org/cornerstone-of-a-church',
#    'http://icondataset.org/cross',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/ground',
#    'http://icondataset.org/halo',
#    'http://icondataset.org/halo-of-rays',
#    'http://icondataset.org/holding-with-the-right-hand',
#    'http://icondataset.org/lifting-one-hand',
#    'http://icondataset.org/sceptre',
#    'http://icondataset.org/standing-on-the-ground'},
#   'in both': {'http://icondataset.org/man'}},
#  'http://icondataset.org/anteros': {'only not cf': {'http://icondataset.org/putto'},
#   'only cf': {'http://icondataset.org/boy',
#    'http://icondataset.org/child',
#    'http://icondataset.org/fishing',
#    'http://icondataset.org/halo',
#    'http://icondataset.org/tree',
#    'http://icondataset.org/tying'},
#   'in both': {'http://icondataset.org/wings'}},
#  'http://icondataset.org/ganymede': {'only not cf': {'http://icondataset.org/cloth'},
#   'only cf': {'http://icondataset.org/immobility',
#    'http://icondataset.org/state-of-trance'},
#   'in both': {'http://icondataset.org/man'}},
#  'http://icondataset.org/laocoon': {'only not cf': {'http://icondataset.org/despair',
#    'http://icondataset.org/pathos',
#    'http://icondataset.org/wiggling-out-of-serpents'},
#   'only cf': {'http://icondataset.org/clothes'},
#   'in both': {'http://icondataset.org/bear', 'http://icondataset.org/man'}},
#  'http://icondataset.org/christ-as-a-child': {'only not cf': set(),
#   'only cf': set(),
#   'in both': {'http://icondataset.org/child'}},
#  'http://icondataset.org/marine-snakes': {'only not cf': {'http://icondataset.org/grabbing'},
#   'only cf': {'http://icondataset.org/water'},
#   'in both': {'http://icondataset.org/serpent'}},
#  'http://icondataset.org/perseus': {'only not cf': {'http://icondataset.org/cloth',
#    'http://icondataset.org/cutten-head',
#    'http://icondataset.org/grace',
#    'http://icondataset.org/lifting-with-one-hand',
#    'http://icondataset.org/running'},
#   'only cf': set(),
#   'in both': {'http://icondataset.org/man',
#    'http://icondataset.org/sword',
#    'http://icondataset.org/wings-at-the-heels'}},
#  'http://icondataset.org/antiphas-son-of-laoocoon': {'only not cf': {'http://icondataset.org/cloth',
#    'http://icondataset.org/despair',
#    'http://icondataset.org/wiggling-out-of-serpents'},
#   'only cf': {'http://icondataset.org/clothes'},
#   'in both': {'http://icondataset.org/boy'}},
#  'http://icondataset.org/mary': {'only not cf': {'http://icondataset.org/dais',
#    'http://icondataset.org/sketch-of-a-human-figure'},
#   'only cf': {'http://icondataset.org/book',
#    'http://icondataset.org/clothes',
#    'http://icondataset.org/face',
#    'http://icondataset.org/girl',
#    'http://icondataset.org/halo',
#    'http://icondataset.org/holding-a-book',
#    'http://icondataset.org/mantle',
#    'http://icondataset.org/smiling',
#    'http://icondataset.org/statue-of-a-woman'},
#   'in both': {'http://icondataset.org/woman'}},
#  'http://icondataset.org/venus': {'only not cf': {'http://icondataset.org/belt',
#    'http://icondataset.org/earring',
#    'http://icondataset.org/holding-a-wreath',
#    'http://icondataset.org/knotted-ribbon-bracelet',
#    'http://icondataset.org/rose-petal',
#    'http://icondataset.org/seashell',
#    'http://icondataset.org/tiara',
#    'http://icondataset.org/touching-breast',
#    'http://icondataset.org/veil'},
#   'only cf': {'http://icondataset.org/arrow',
#    'http://icondataset.org/clothes',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/dove',
#    'http://icondataset.org/emerging-from-the-water',
#    'http://icondataset.org/glass-sphere',
#    'http://icondataset.org/holding-a-rose-to-her-face',
#    'http://icondataset.org/holding-on-her-lap',
#    'http://icondataset.org/lady',
#    'http://icondataset.org/pensively',
#    'http://icondataset.org/sea-goose',
#    'http://icondataset.org/sea-goose-with-a-fish-tail',
#    'http://icondataset.org/slate'},
#   'in both': {'http://icondataset.org/holding-with-a-hand',
#    'http://icondataset.org/rose',
#    'http://icondataset.org/woman'}},
#  'http://icondataset.org/david': {'only not cf': {'http://icondataset.org/man'},
#   'only cf': {'http://icondataset.org/agitated-movement',
#    'http://icondataset.org/boy',
#    'http://icondataset.org/drapery',
#    'http://icondataset.org/pathos',
#    'http://icondataset.org/victorious'},
#   'in both': set()},
#  'http://icondataset.org/thymbraeus-son-of-laoocoon': {'only not cf': {'http://icondataset.org/cloth',
#    'http://icondataset.org/despair',
#    'http://icondataset.org/wiggling-out-of-serpents'},
#   'only cf': {'http://icondataset.org/clothes'},
#   'in both': {'http://icondataset.org/boy'}},
#  'http://icondataset.org/pluto': {'only not cf': {'http://icondataset.org/figure'},
#   'only cf': {'http://icondataset.org/armor',
#    'http://icondataset.org/cart',
#    'http://icondataset.org/courteous-attitude',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/force',
#    'http://icondataset.org/grabbing-and-lifting-a-woman',
#    'http://icondataset.org/holding-with-the-left-hand',
#    'http://icondataset.org/holding-with-the-right-hand',
#    'http://icondataset.org/jar',
#    'http://icondataset.org/knight',
#    'http://icondataset.org/lending-both-hands-to-a-woman',
#    'http://icondataset.org/man',
#    'http://icondataset.org/pluto',
#    'http://icondataset.org/sceptre',
#    'http://icondataset.org/triple-throated-cerberus'},
#   'in both': set()},
#  'http://icondataset.org/proserpina': {'only not cf': set(),
#   'only cf': {'http://icondataset.org/backward-gaze',
#    'http://icondataset.org/court-dress',
#    'http://icondataset.org/crying',
#    'http://icondataset.org/flowers',
#    'http://icondataset.org/gathering-flowers',
#    'http://icondataset.org/lending-one-hand-to-a-man',
#    'http://icondataset.org/preserpine',
#    'http://icondataset.org/raising-arms-upwards',
#    'http://icondataset.org/sitting-down'},
#   'in both': {'http://icondataset.org/woman'}},
#  'http://icondataset.org/satyr': {'only not cf': set(),
#   'only cf': {'http://icondataset.org/human-baby-with-animal-legs',
#    'http://icondataset.org/woman-with-goat-legs'},
#   'in both': {'http://icondataset.org/human-figure-with-animal-legs'}},
#  'http://icondataset.org/eve': {'only not cf': set(),
#   'only cf': set(),
#   'in both': {'http://icondataset.org/woman'}},
#  'http://icondataset.org/saturn': {'only not cf': set(),
#   'only cf': {'http://icondataset.org/cloth',
#    'http://icondataset.org/clothes',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/crutch',
#    'http://icondataset.org/despair',
#    'http://icondataset.org/dragon-biting-its-tail',
#    'http://icondataset.org/gloomy',
#    'http://icondataset.org/helmet',
#    'http://icondataset.org/king',
#    'http://icondataset.org/scythe',
#    'http://icondataset.org/sickle',
#    'http://icondataset.org/sitting-on',
#    'http://icondataset.org/soldier',
#    'http://icondataset.org/spade',
#    'http://icondataset.org/support-oneself-with',
#    'http://icondataset.org/throne',
#    'http://icondataset.org/veil',
#    'http://icondataset.org/wooden-leg'},
#   'in both': {'http://icondataset.org/bear',
#    'http://icondataset.org/man',
#    'http://icondataset.org/wings'}},
#  'http://icondataset.org/lapiths': {'only not cf': {'http://icondataset.org/people'},
#   'only cf': {'http://icondataset.org/man', 'http://icondataset.org/stick'},
#   'in both': set()},
#  'http://icondataset.org/companion-of-serapis': {'only not cf': set(),
#   'only cf': {'http://icondataset.org/man',
#    'http://icondataset.org/modius',
#    'http://icondataset.org/sceptre',
#    'http://icondataset.org/three-headed-serpent'},
#   'in both': {'http://icondataset.org/head-of-a-dog',
#    'http://icondataset.org/head-of-a-lion',
#    'http://icondataset.org/head-of-a-wolf',
#    'http://icondataset.org/serpent',
#    'http://icondataset.org/three-headed-figure',
#    'http://icondataset.org/twisting-around'}},
#  'http://icondataset.org/blindfold-cupid': {'only not cf': {'http://icondataset.org/band',
#    'http://icondataset.org/horse',
#    'http://icondataset.org/running',
#    'http://icondataset.org/spear',
#    'http://icondataset.org/standing-on-a-horse'},
#   'only cf': {'http://icondataset.org/crown-of-roses',
#    'http://icondataset.org/hearts',
#    'http://icondataset.org/natural-landscape',
#    'http://icondataset.org/putto',
#    'http://icondataset.org/sleeping',
#    'http://icondataset.org/snuggling-in-her-lap',
#    'http://icondataset.org/sphere',
#    'http://icondataset.org/standing-on',
#    'http://icondataset.org/string-of-hearts',
#    'http://icondataset.org/talon',
#    'http://icondataset.org/throne'},
#   'in both': {'http://icondataset.org/arrow',
#    'http://icondataset.org/bandage',
#    'http://icondataset.org/bow',
#    'http://icondataset.org/boy',
#    'http://icondataset.org/child',
#    'http://icondataset.org/griffon-claws',
#    'http://icondataset.org/wings'}},
#  'http://icondataset.org/phaeton': {'only not cf': set(),
#   'only cf': set(),
#   'in both': {'http://icondataset.org/falling-off',
#    'http://icondataset.org/man'}},
#  'http://icondataset.org/cupid': {'only not cf': {'http://icondataset.org/holding-a-wreath',
#    'http://icondataset.org/playful-attitude'},
#   'only cf': {'http://icondataset.org/bandage',
#    'http://icondataset.org/boots',
#    'http://icondataset.org/child',
#    'http://icondataset.org/court-dress',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/fire',
#    'http://icondataset.org/fishing',
#    'http://icondataset.org/flying',
#    'http://icondataset.org/girl',
#    'http://icondataset.org/grabbing-with-one-hand',
#    'http://icondataset.org/griffon-claws',
#    'http://icondataset.org/holding-with-a-hand',
#    'http://icondataset.org/horse',
#    'http://icondataset.org/intense-devotion',
#    'http://icondataset.org/lappets',
#    'http://icondataset.org/leaning-on-her-shoulder',
#    'http://icondataset.org/leaning-upon',
#    'http://icondataset.org/man',
#    'http://icondataset.org/myrtle-wreath',
#    'http://icondataset.org/removing',
#    'http://icondataset.org/ribbon',
#    'http://icondataset.org/rose',
#    'http://icondataset.org/shooting-an-arrow',
#    'http://icondataset.org/sleeping',
#    'http://icondataset.org/standing-on-a-horse',
#    'http://icondataset.org/stirring-water',
#    'http://icondataset.org/string-of-hearts',
#    'http://icondataset.org/taking-aim',
#    'http://icondataset.org/woman',
#    'http://icondataset.org/wreath',
#    'http://icondataset.org/young'},
#   'in both': {'http://icondataset.org/arrow',
#    'http://icondataset.org/bow',
#    'http://icondataset.org/boy',
#    'http://icondataset.org/mantle',
#    'http://icondataset.org/putto',
#    'http://icondataset.org/torch',
#    'http://icondataset.org/wings'}},
#  'http://icondataset.org/mercurys-winged-sandals': {'only not cf': set(),
#   'only cf': {'http://icondataset.org/bird'},
#   'in both': {'http://icondataset.org/wings-at-the-heels'}},
#  'http://icondataset.org/medusas-head': {'only not cf': {'http://icondataset.org/drops-of-blood'},
#   'only cf': {'http://icondataset.org/caput-meduse'},
#   'in both': {'http://icondataset.org/cutten-head',
#    'http://icondataset.org/serpent-locks'}},
#  'http://icondataset.org/luxury': {'only not cf': {'http://icondataset.org/embracing',
#    'http://icondataset.org/lover'},
#   'only cf': {'http://icondataset.org/woman'},
#   'in both': set()},
#  'http://icondataset.org/the-constellation-perseus': {'only not cf': {'http://icondataset.org/cloth',
#    'http://icondataset.org/drops-of-blood',
#    'http://icondataset.org/grace',
#    'http://icondataset.org/running',
#    'http://icondataset.org/wings-at-the-heels'},
#   'only cf': {'http://icondataset.org/beard',
#    'http://icondataset.org/caput-algol',
#    'http://icondataset.org/caput-meduse',
#    'http://icondataset.org/constellation',
#    'http://icondataset.org/gown',
#    'http://icondataset.org/lifting-one-hand',
#    'http://icondataset.org/terrifying-expression'},
#   'in both': {'http://icondataset.org/cutten-head',
#    'http://icondataset.org/grabbing-with-one-hand',
#    'http://icondataset.org/lifting-with-one-hand',
#    'http://icondataset.org/man',
#    'http://icondataset.org/serpent-locks',
#    'http://icondataset.org/sword'}},
#  'http://icondataset.org/faith': {'only not cf': {'http://icondataset.org/woman'},
#   'only cf': {'http://icondataset.org/basket-with-roses',
#    'http://icondataset.org/figure',
#    'http://icondataset.org/glancing-heavenward',
#    'http://icondataset.org/joyful-excitement',
#    'http://icondataset.org/raising'},
#   'in both': set()},
#  'http://icondataset.org/blind-night': {'only not cf': {'http://icondataset.org/covering-her-eyes',
#    'http://icondataset.org/figure',
#    'http://icondataset.org/veil'},
#   'only cf': {'http://icondataset.org/bandage'},
#   'in both': {'http://icondataset.org/woman'}},
#  'http://icondataset.org/platonic-love': {'only not cf': {'http://icondataset.org/boy',
#    'http://icondataset.org/torch'},
#   'only cf': {'http://icondataset.org/arrow', 'http://icondataset.org/child'},
#   'in both': {'http://icondataset.org/wings'}},
#  'http://icondataset.org/day': {'only not cf': {'http://icondataset.org/figure'},
#   'only cf': {'http://icondataset.org/man'},
#   'in both': set()},
#  'http://icondataset.org/truth': {'only not cf': {'http://icondataset.org/despair'},
#   'only cf': {'http://icondataset.org/child',
#    'http://icondataset.org/curtain',
#    'http://icondataset.org/disgust',
#    'http://icondataset.org/girl',
#    'http://icondataset.org/removing'},
#   'in both': {'http://icondataset.org/woman'}},
#  'http://icondataset.org/chastity': {'only not cf': {'http://icondataset.org/lilium'},
#   'only cf': {'http://icondataset.org/arrow',
#    'http://icondataset.org/covering-herself',
#    'http://icondataset.org/maiden'},
#   'in both': {'http://icondataset.org/woman'}},
#  'http://icondataset.org/phaeton-the-presumptuous': {'only not cf': set(),
#   'only cf': set(),
#   'in both': {'http://icondataset.org/falling-off',
#    'http://icondataset.org/man'}},
#  'http://icondataset.org/four-wings-four-seasons': {'only not cf': set(),
#   'only cf': set(),
#   'in both': {'http://icondataset.org/wings'}},
#  'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': {'only not cf': {'http://icondataset.org/cloud',
#    'http://icondataset.org/sun'},
#   'only cf': {'http://icondataset.org/chariot',
#    'http://icondataset.org/eagle',
#    'http://icondataset.org/group-of-figures',
#    'http://icondataset.org/hurling',
#    'http://icondataset.org/thunderbolt'},
#   'in both': {'http://icondataset.org/falling-off',
#    'http://icondataset.org/horse',
#    'http://icondataset.org/man'}},
#  'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom': {'only not cf': {'http://icondataset.org/slave'},
#   'only cf': {'http://icondataset.org/statue-of-a-slave'},
#   'in both': set()}}

# %%
cfr_subj2_dict2 = cfr_subj2_dict
copy = cfr_subj2_dict.copy()
#print(copy)
for item in copy.items(): 
    for i in item[1].items(): 
        new = list(i[1])
        print(new)
        cfr_subj2_dict2[item[0]][i[0]] = new
   # for values in item.items():
      #  new = list(values[1])
cfr_subj2_dict2
# Out:
# ['http://icondataset.org/winged-creature']
# ['http://icondataset.org/figure', 'http://icondataset.org/mors-aeterna', 'http://icondataset.org/holding-with-a-hand', 'http://icondataset.org/human']
# []
# ['http://icondataset.org/fettered-man']
# ['http://icondataset.org/man']
# []
# ['http://icondataset.org/helmet']
# ['http://icondataset.org/woman', 'http://icondataset.org/hat', 'http://icondataset.org/touching-breast', 'http://icondataset.org/gentleman', 'http://icondataset.org/armor']
# ['http://icondataset.org/backward-turning-movement', 'http://icondataset.org/man', 'http://icondataset.org/cloak', 'http://icondataset.org/shield', 'http://icondataset.org/spear']
# ['http://icondataset.org/woman', 'http://icondataset.org/throne', 'http://icondataset.org/modius', 'http://icondataset.org/sceptre']
# ['http://icondataset.org/head-of-a-lion', 'http://icondataset.org/head-of-a-wolf', 'http://icondataset.org/three-headed-serpent', 'http://icondataset.org/head-of-a-dog']
# []
# ['http://icondataset.org/bow']
# ['http://icondataset.org/torch', 'http://icondataset.org/tree', 'http://icondataset.org/sitting-on']
# ['http://icondataset.org/clothes', 'http://icondataset.org/wings', 'http://icondataset.org/crown', 'http://icondataset.org/arrow', 'http://icondataset.org/boy']
# ['http://icondataset.org/effort', 'http://icondataset.org/sphere', 'http://icondataset.org/lion-skin', 'http://icondataset.org/supporting', 'http://icondataset.org/figure', 'http://icondataset.org/carrying-on-shoulders']
# ['http://icondataset.org/powerful-sturdiness', 'http://icondataset.org/club', 'http://icondataset.org/energy', 'http://icondataset.org/forceful']
# ['http://icondataset.org/man', 'http://icondataset.org/bow', 'http://icondataset.org/drawing-the-bow']
# ['http://icondataset.org/dead-body-of-a-man']
# ['http://icondataset.org/halo-of-rays', 'http://icondataset.org/child', 'http://icondataset.org/lifting-one-hand', 'http://icondataset.org/cornerstone-of-a-church', 'http://icondataset.org/crown', 'http://icondataset.org/halo', 'http://icondataset.org/sceptre', 'http://icondataset.org/ground', 'http://icondataset.org/cloth', 'http://icondataset.org/condemning-gesture', 'http://icondataset.org/standing-on-the-ground', 'http://icondataset.org/cross', 'http://icondataset.org/holding-with-the-right-hand', 'http://icondataset.org/carrying-on-shoulders']
# ['http://icondataset.org/man']
# ['http://icondataset.org/putto']
# ['http://icondataset.org/child', 'http://icondataset.org/halo', 'http://icondataset.org/tree', 'http://icondataset.org/boy', 'http://icondataset.org/fishing', 'http://icondataset.org/tying']
# ['http://icondataset.org/wings']
# ['http://icondataset.org/cloth']
# ['http://icondataset.org/state-of-trance', 'http://icondataset.org/immobility']
# ['http://icondataset.org/man']
# ['http://icondataset.org/despair', 'http://icondataset.org/pathos', 'http://icondataset.org/wiggling-out-of-serpents']
# ['http://icondataset.org/clothes']
# ['http://icondataset.org/man', 'http://icondataset.org/bear']
# []
# []
# ['http://icondataset.org/child']
# ['http://icondataset.org/grabbing']
# ['http://icondataset.org/water']
# ['http://icondataset.org/serpent']
# ['http://icondataset.org/running', 'http://icondataset.org/lifting-with-one-hand', 'http://icondataset.org/cloth', 'http://icondataset.org/grace', 'http://icondataset.org/cutten-head']
# []
# ['http://icondataset.org/man', 'http://icondataset.org/sword', 'http://icondataset.org/wings-at-the-heels']
# ['http://icondataset.org/despair', 'http://icondataset.org/cloth', 'http://icondataset.org/wiggling-out-of-serpents']
# ['http://icondataset.org/clothes']
# ['http://icondataset.org/boy']
# ['http://icondataset.org/dais', 'http://icondataset.org/sketch-of-a-human-figure']
# ['http://icondataset.org/clothes', 'http://icondataset.org/mantle', 'http://icondataset.org/statue-of-a-woman', 'http://icondataset.org/book', 'http://icondataset.org/halo', 'http://icondataset.org/girl', 'http://icondataset.org/face', 'http://icondataset.org/smiling', 'http://icondataset.org/holding-a-book']
# ['http://icondataset.org/woman']
# ['http://icondataset.org/touching-breast', 'http://icondataset.org/veil', 'http://icondataset.org/seashell', 'http://icondataset.org/holding-a-wreath', 'http://icondataset.org/earring', 'http://icondataset.org/tiara', 'http://icondataset.org/knotted-ribbon-bracelet', 'http://icondataset.org/rose-petal', 'http://icondataset.org/belt']
# ['http://icondataset.org/pensively', 'http://icondataset.org/clothes', 'http://icondataset.org/holding-a-rose-to-her-face', 'http://icondataset.org/sea-goose', 'http://icondataset.org/crown', 'http://icondataset.org/arrow', 'http://icondataset.org/slate', 'http://icondataset.org/lady', 'http://icondataset.org/dove', 'http://icondataset.org/sea-goose-with-a-fish-tail', 'http://icondataset.org/holding-on-her-lap', 'http://icondataset.org/emerging-from-the-water', 'http://icondataset.org/glass-sphere']
# ['http://icondataset.org/woman', 'http://icondataset.org/holding-with-a-hand', 'http://icondataset.org/rose']
# ['http://icondataset.org/man']
# ['http://icondataset.org/victorious', 'http://icondataset.org/drapery', 'http://icondataset.org/boy', 'http://icondataset.org/pathos', 'http://icondataset.org/agitated-movement']
# []
# ['http://icondataset.org/despair', 'http://icondataset.org/cloth', 'http://icondataset.org/wiggling-out-of-serpents']
# ['http://icondataset.org/clothes']
# ['http://icondataset.org/boy']
# ['http://icondataset.org/figure']
# ['http://icondataset.org/lending-both-hands-to-a-woman', 'http://icondataset.org/man', 'http://icondataset.org/jar', 'http://icondataset.org/courteous-attitude', 'http://icondataset.org/crown', 'http://icondataset.org/pluto', 'http://icondataset.org/sceptre', 'http://icondataset.org/holding-with-the-left-hand', 'http://icondataset.org/cart', 'http://icondataset.org/triple-throated-cerberus', 'http://icondataset.org/holding-with-the-right-hand', 'http://icondataset.org/knight', 'http://icondataset.org/grabbing-and-lifting-a-woman', 'http://icondataset.org/armor', 'http://icondataset.org/force']
# []
# []
# ['http://icondataset.org/preserpine', 'http://icondataset.org/sitting-down', 'http://icondataset.org/lending-one-hand-to-a-man', 'http://icondataset.org/backward-gaze', 'http://icondataset.org/gathering-flowers', 'http://icondataset.org/crying', 'http://icondataset.org/flowers', 'http://icondataset.org/court-dress', 'http://icondataset.org/raising-arms-upwards']
# ['http://icondataset.org/woman']
# []
# ['http://icondataset.org/woman-with-goat-legs', 'http://icondataset.org/human-baby-with-animal-legs']
# ['http://icondataset.org/human-figure-with-animal-legs']
# []
# []
# ['http://icondataset.org/woman']
# []
# ['http://icondataset.org/despair', 'http://icondataset.org/clothes', 'http://icondataset.org/helmet', 'http://icondataset.org/sitting-on', 'http://icondataset.org/soldier', 'http://icondataset.org/throne', 'http://icondataset.org/crown', 'http://icondataset.org/veil', 'http://icondataset.org/gloomy', 'http://icondataset.org/spade', 'http://icondataset.org/cloth', 'http://icondataset.org/scythe', 'http://icondataset.org/support-oneself-with', 'http://icondataset.org/crutch', 'http://icondataset.org/sickle', 'http://icondataset.org/king', 'http://icondataset.org/wooden-leg', 'http://icondataset.org/dragon-biting-its-tail']
# ['http://icondataset.org/man', 'http://icondataset.org/wings', 'http://icondataset.org/bear']
# ['http://icondataset.org/people']
# ['http://icondataset.org/stick', 'http://icondataset.org/man']
# []
# []
# ['http://icondataset.org/three-headed-serpent', 'http://icondataset.org/man', 'http://icondataset.org/modius', 'http://icondataset.org/sceptre']
# ['http://icondataset.org/head-of-a-lion', 'http://icondataset.org/three-headed-figure', 'http://icondataset.org/serpent', 'http://icondataset.org/head-of-a-dog', 'http://icondataset.org/twisting-around', 'http://icondataset.org/head-of-a-wolf']
# ['http://icondataset.org/band', 'http://icondataset.org/running', 'http://icondataset.org/spear', 'http://icondataset.org/horse', 'http://icondataset.org/standing-on-a-horse']
# ['http://icondataset.org/talon', 'http://icondataset.org/sphere', 'http://icondataset.org/putto', 'http://icondataset.org/throne', 'http://icondataset.org/string-of-hearts', 'http://icondataset.org/sleeping', 'http://icondataset.org/crown-of-roses', 'http://icondataset.org/standing-on', 'http://icondataset.org/hearts', 'http://icondataset.org/natural-landscape', 'http://icondataset.org/snuggling-in-her-lap']
# ['http://icondataset.org/griffon-claws', 'http://icondataset.org/wings', 'http://icondataset.org/child', 'http://icondataset.org/arrow', 'http://icondataset.org/boy', 'http://icondataset.org/bandage', 'http://icondataset.org/bow']
# []
# []
# ['http://icondataset.org/man', 'http://icondataset.org/falling-off']
# ['http://icondataset.org/playful-attitude', 'http://icondataset.org/holding-a-wreath']
# ['http://icondataset.org/young', 'http://icondataset.org/man', 'http://icondataset.org/flying', 'http://icondataset.org/wreath', 'http://icondataset.org/sleeping', 'http://icondataset.org/taking-aim', 'http://icondataset.org/intense-devotion', 'http://icondataset.org/leaning-upon', 'http://icondataset.org/griffon-claws', 'http://icondataset.org/stirring-water', 'http://icondataset.org/rose', 'http://icondataset.org/fire', 'http://icondataset.org/string-of-hearts', 'http://icondataset.org/bandage', 'http://icondataset.org/lappets', 'http://icondataset.org/boots', 'http://icondataset.org/court-dress', 'http://icondataset.org/ribbon', 'http://icondataset.org/grabbing-with-one-hand', 'http://icondataset.org/holding-with-a-hand', 'http://icondataset.org/woman', 'http://icondataset.org/crown', 'http://icondataset.org/horse', 'http://icondataset.org/child', 'http://icondataset.org/shooting-an-arrow', 'http://icondataset.org/removing', 'http://icondataset.org/girl', 'http://icondataset.org/fishing', 'http://icondataset.org/leaning-on-her-shoulder', 'http://icondataset.org/myrtle-wreath', 'http://icondataset.org/standing-on-a-horse']
# ['http://icondataset.org/wings', 'http://icondataset.org/mantle', 'http://icondataset.org/putto', 'http://icondataset.org/arrow', 'http://icondataset.org/boy', 'http://icondataset.org/torch', 'http://icondataset.org/bow']
# []
# ['http://icondataset.org/bird']
# ['http://icondataset.org/wings-at-the-heels']
# ['http://icondataset.org/drops-of-blood']
# ['http://icondataset.org/caput-meduse']
# ['http://icondataset.org/serpent-locks', 'http://icondataset.org/cutten-head']
# ['http://icondataset.org/embracing', 'http://icondataset.org/lover']
# ['http://icondataset.org/woman']
# []
# ['http://icondataset.org/wings-at-the-heels', 'http://icondataset.org/running', 'http://icondataset.org/cloth', 'http://icondataset.org/grace', 'http://icondataset.org/drops-of-blood']
# ['http://icondataset.org/terrifying-expression', 'http://icondataset.org/beard', 'http://icondataset.org/gown', 'http://icondataset.org/caput-algol', 'http://icondataset.org/lifting-one-hand', 'http://icondataset.org/caput-meduse', 'http://icondataset.org/constellation']
# ['http://icondataset.org/man', 'http://icondataset.org/grabbing-with-one-hand', 'http://icondataset.org/sword', 'http://icondataset.org/serpent-locks', 'http://icondataset.org/lifting-with-one-hand', 'http://icondataset.org/cutten-head']
# ['http://icondataset.org/woman']
# ['http://icondataset.org/joyful-excitement', 'http://icondataset.org/basket-with-roses', 'http://icondataset.org/raising', 'http://icondataset.org/glancing-heavenward', 'http://icondataset.org/figure']
# []
# ['http://icondataset.org/figure', 'http://icondataset.org/veil', 'http://icondataset.org/covering-her-eyes']
# ['http://icondataset.org/bandage']
# ['http://icondataset.org/woman']
# ['http://icondataset.org/torch', 'http://icondataset.org/boy']
# ['http://icondataset.org/arrow', 'http://icondataset.org/child']
# ['http://icondataset.org/wings']
# ['http://icondataset.org/figure']
# ['http://icondataset.org/man']
# []
# ['http://icondataset.org/despair']
# ['http://icondataset.org/child', 'http://icondataset.org/removing', 'http://icondataset.org/girl', 'http://icondataset.org/disgust', 'http://icondataset.org/curtain']
# ['http://icondataset.org/woman']
# ['http://icondataset.org/lilium']
# ['http://icondataset.org/maiden', 'http://icondataset.org/arrow', 'http://icondataset.org/covering-herself']
# ['http://icondataset.org/woman']
# []
# []
# ['http://icondataset.org/man', 'http://icondataset.org/falling-off']
# []
# []
# ['http://icondataset.org/wings']
# ['http://icondataset.org/sun', 'http://icondataset.org/cloud']
# ['http://icondataset.org/hurling', 'http://icondataset.org/group-of-figures', 'http://icondataset.org/chariot', 'http://icondataset.org/thunderbolt', 'http://icondataset.org/eagle']
# ['http://icondataset.org/man', 'http://icondataset.org/falling-off', 'http://icondataset.org/horse']
# ['http://icondataset.org/slave']
# ['http://icondataset.org/statue-of-a-slave']
# []
# {'http://icondataset.org/devil': {'only not cf': ['http://icondataset.org/winged-creature'],
#   'only cf': ['http://icondataset.org/figure',
#    'http://icondataset.org/mors-aeterna',
#    'http://icondataset.org/holding-with-a-hand',
#    'http://icondataset.org/human'],
#   'in both': []},
#  'http://icondataset.org/tityus': {'only not cf': ['http://icondataset.org/fettered-man'],
#   'only cf': ['http://icondataset.org/man'],
#   'in both': []},
#  'http://icondataset.org/mars': {'only not cf': ['http://icondataset.org/helmet'],
#   'only cf': ['http://icondataset.org/woman',
#    'http://icondataset.org/hat',
#    'http://icondataset.org/touching-breast',
#    'http://icondataset.org/gentleman',
#    'http://icondataset.org/armor'],
#   'in both': ['http://icondataset.org/backward-turning-movement',
#    'http://icondataset.org/man',
#    'http://icondataset.org/cloak',
#    'http://icondataset.org/shield',
#    'http://icondataset.org/spear']},
#  'http://icondataset.org/serapis': {'only not cf': ['http://icondataset.org/woman',
#    'http://icondataset.org/throne',
#    'http://icondataset.org/modius',
#    'http://icondataset.org/sceptre'],
#   'only cf': ['http://icondataset.org/head-of-a-lion',
#    'http://icondataset.org/head-of-a-wolf',
#    'http://icondataset.org/three-headed-serpent',
#    'http://icondataset.org/head-of-a-dog'],
#   'in both': []},
#  'http://icondataset.org/dieu-amour': {'only not cf': ['http://icondataset.org/bow'],
#   'only cf': ['http://icondataset.org/torch',
#    'http://icondataset.org/tree',
#    'http://icondataset.org/sitting-on'],
#   'in both': ['http://icondataset.org/clothes',
#    'http://icondataset.org/wings',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/arrow',
#    'http://icondataset.org/boy']},
#  'http://icondataset.org/hercules': {'only not cf': ['http://icondataset.org/effort',
#    'http://icondataset.org/sphere',
#    'http://icondataset.org/lion-skin',
#    'http://icondataset.org/supporting',
#    'http://icondataset.org/figure',
#    'http://icondataset.org/carrying-on-shoulders'],
#   'only cf': ['http://icondataset.org/powerful-sturdiness',
#    'http://icondataset.org/club',
#    'http://icondataset.org/energy',
#    'http://icondataset.org/forceful'],
#   'in both': ['http://icondataset.org/man',
#    'http://icondataset.org/bow',
#    'http://icondataset.org/drawing-the-bow']},
#  'http://icondataset.org/christ': {'only not cf': ['http://icondataset.org/dead-body-of-a-man'],
#   'only cf': ['http://icondataset.org/halo-of-rays',
#    'http://icondataset.org/child',
#    'http://icondataset.org/lifting-one-hand',
#    'http://icondataset.org/cornerstone-of-a-church',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/halo',
#    'http://icondataset.org/sceptre',
#    'http://icondataset.org/ground',
#    'http://icondataset.org/cloth',
#    'http://icondataset.org/condemning-gesture',
#    'http://icondataset.org/standing-on-the-ground',
#    'http://icondataset.org/cross',
#    'http://icondataset.org/holding-with-the-right-hand',
#    'http://icondataset.org/carrying-on-shoulders'],
#   'in both': ['http://icondataset.org/man']},
#  'http://icondataset.org/anteros': {'only not cf': ['http://icondataset.org/putto'],
#   'only cf': ['http://icondataset.org/child',
#    'http://icondataset.org/halo',
#    'http://icondataset.org/tree',
#    'http://icondataset.org/boy',
#    'http://icondataset.org/fishing',
#    'http://icondataset.org/tying'],
#   'in both': ['http://icondataset.org/wings']},
#  'http://icondataset.org/ganymede': {'only not cf': ['http://icondataset.org/cloth'],
#   'only cf': ['http://icondataset.org/state-of-trance',
#    'http://icondataset.org/immobility'],
#   'in both': ['http://icondataset.org/man']},
#  'http://icondataset.org/laocoon': {'only not cf': ['http://icondataset.org/despair',
#    'http://icondataset.org/pathos',
#    'http://icondataset.org/wiggling-out-of-serpents'],
#   'only cf': ['http://icondataset.org/clothes'],
#   'in both': ['http://icondataset.org/man', 'http://icondataset.org/bear']},
#  'http://icondataset.org/christ-as-a-child': {'only not cf': [],
#   'only cf': [],
#   'in both': ['http://icondataset.org/child']},
#  'http://icondataset.org/marine-snakes': {'only not cf': ['http://icondataset.org/grabbing'],
#   'only cf': ['http://icondataset.org/water'],
#   'in both': ['http://icondataset.org/serpent']},
#  'http://icondataset.org/perseus': {'only not cf': ['http://icondataset.org/running',
#    'http://icondataset.org/lifting-with-one-hand',
#    'http://icondataset.org/cloth',
#    'http://icondataset.org/grace',
#    'http://icondataset.org/cutten-head'],
#   'only cf': [],
#   'in both': ['http://icondataset.org/man',
#    'http://icondataset.org/sword',
#    'http://icondataset.org/wings-at-the-heels']},
#  'http://icondataset.org/antiphas-son-of-laoocoon': {'only not cf': ['http://icondataset.org/despair',
#    'http://icondataset.org/cloth',
#    'http://icondataset.org/wiggling-out-of-serpents'],
#   'only cf': ['http://icondataset.org/clothes'],
#   'in both': ['http://icondataset.org/boy']},
#  'http://icondataset.org/mary': {'only not cf': ['http://icondataset.org/dais',
#    'http://icondataset.org/sketch-of-a-human-figure'],
#   'only cf': ['http://icondataset.org/clothes',
#    'http://icondataset.org/mantle',
#    'http://icondataset.org/statue-of-a-woman',
#    'http://icondataset.org/book',
#    'http://icondataset.org/halo',
#    'http://icondataset.org/girl',
#    'http://icondataset.org/face',
#    'http://icondataset.org/smiling',
#    'http://icondataset.org/holding-a-book'],
#   'in both': ['http://icondataset.org/woman']},
#  'http://icondataset.org/venus': {'only not cf': ['http://icondataset.org/touching-breast',
#    'http://icondataset.org/veil',
#    'http://icondataset.org/seashell',
#    'http://icondataset.org/holding-a-wreath',
#    'http://icondataset.org/earring',
#    'http://icondataset.org/tiara',
#    'http://icondataset.org/knotted-ribbon-bracelet',
#    'http://icondataset.org/rose-petal',
#    'http://icondataset.org/belt'],
#   'only cf': ['http://icondataset.org/pensively',
#    'http://icondataset.org/clothes',
#    'http://icondataset.org/holding-a-rose-to-her-face',
#    'http://icondataset.org/sea-goose',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/arrow',
#    'http://icondataset.org/slate',
#    'http://icondataset.org/lady',
#    'http://icondataset.org/dove',
#    'http://icondataset.org/sea-goose-with-a-fish-tail',
#    'http://icondataset.org/holding-on-her-lap',
#    'http://icondataset.org/emerging-from-the-water',
#    'http://icondataset.org/glass-sphere'],
#   'in both': ['http://icondataset.org/woman',
#    'http://icondataset.org/holding-with-a-hand',
#    'http://icondataset.org/rose']},
#  'http://icondataset.org/david': {'only not cf': ['http://icondataset.org/man'],
#   'only cf': ['http://icondataset.org/victorious',
#    'http://icondataset.org/drapery',
#    'http://icondataset.org/boy',
#    'http://icondataset.org/pathos',
#    'http://icondataset.org/agitated-movement'],
#   'in both': []},
#  'http://icondataset.org/thymbraeus-son-of-laoocoon': {'only not cf': ['http://icondataset.org/despair',
#    'http://icondataset.org/cloth',
#    'http://icondataset.org/wiggling-out-of-serpents'],
#   'only cf': ['http://icondataset.org/clothes'],
#   'in both': ['http://icondataset.org/boy']},
#  'http://icondataset.org/pluto': {'only not cf': ['http://icondataset.org/figure'],
#   'only cf': ['http://icondataset.org/lending-both-hands-to-a-woman',
#    'http://icondataset.org/man',
#    'http://icondataset.org/jar',
#    'http://icondataset.org/courteous-attitude',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/pluto',
#    'http://icondataset.org/sceptre',
#    'http://icondataset.org/holding-with-the-left-hand',
#    'http://icondataset.org/cart',
#    'http://icondataset.org/triple-throated-cerberus',
#    'http://icondataset.org/holding-with-the-right-hand',
#    'http://icondataset.org/knight',
#    'http://icondataset.org/grabbing-and-lifting-a-woman',
#    'http://icondataset.org/armor',
#    'http://icondataset.org/force'],
#   'in both': []},
#  'http://icondataset.org/proserpina': {'only not cf': [],
#   'only cf': ['http://icondataset.org/preserpine',
#    'http://icondataset.org/sitting-down',
#    'http://icondataset.org/lending-one-hand-to-a-man',
#    'http://icondataset.org/backward-gaze',
#    'http://icondataset.org/gathering-flowers',
#    'http://icondataset.org/crying',
#    'http://icondataset.org/flowers',
#    'http://icondataset.org/court-dress',
#    'http://icondataset.org/raising-arms-upwards'],
#   'in both': ['http://icondataset.org/woman']},
#  'http://icondataset.org/satyr': {'only not cf': [],
#   'only cf': ['http://icondataset.org/woman-with-goat-legs',
#    'http://icondataset.org/human-baby-with-animal-legs'],
#   'in both': ['http://icondataset.org/human-figure-with-animal-legs']},
#  'http://icondataset.org/eve': {'only not cf': [],
#   'only cf': [],
#   'in both': ['http://icondataset.org/woman']},
#  'http://icondataset.org/saturn': {'only not cf': [],
#   'only cf': ['http://icondataset.org/despair',
#    'http://icondataset.org/clothes',
#    'http://icondataset.org/helmet',
#    'http://icondataset.org/sitting-on',
#    'http://icondataset.org/soldier',
#    'http://icondataset.org/throne',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/veil',
#    'http://icondataset.org/gloomy',
#    'http://icondataset.org/spade',
#    'http://icondataset.org/cloth',
#    'http://icondataset.org/scythe',
#    'http://icondataset.org/support-oneself-with',
#    'http://icondataset.org/crutch',
#    'http://icondataset.org/sickle',
#    'http://icondataset.org/king',
#    'http://icondataset.org/wooden-leg',
#    'http://icondataset.org/dragon-biting-its-tail'],
#   'in both': ['http://icondataset.org/man',
#    'http://icondataset.org/wings',
#    'http://icondataset.org/bear']},
#  'http://icondataset.org/lapiths': {'only not cf': ['http://icondataset.org/people'],
#   'only cf': ['http://icondataset.org/stick', 'http://icondataset.org/man'],
#   'in both': []},
#  'http://icondataset.org/companion-of-serapis': {'only not cf': [],
#   'only cf': ['http://icondataset.org/three-headed-serpent',
#    'http://icondataset.org/man',
#    'http://icondataset.org/modius',
#    'http://icondataset.org/sceptre'],
#   'in both': ['http://icondataset.org/head-of-a-lion',
#    'http://icondataset.org/three-headed-figure',
#    'http://icondataset.org/serpent',
#    'http://icondataset.org/head-of-a-dog',
#    'http://icondataset.org/twisting-around',
#    'http://icondataset.org/head-of-a-wolf']},
#  'http://icondataset.org/blindfold-cupid': {'only not cf': ['http://icondataset.org/band',
#    'http://icondataset.org/running',
#    'http://icondataset.org/spear',
#    'http://icondataset.org/horse',
#    'http://icondataset.org/standing-on-a-horse'],
#   'only cf': ['http://icondataset.org/talon',
#    'http://icondataset.org/sphere',
#    'http://icondataset.org/putto',
#    'http://icondataset.org/throne',
#    'http://icondataset.org/string-of-hearts',
#    'http://icondataset.org/sleeping',
#    'http://icondataset.org/crown-of-roses',
#    'http://icondataset.org/standing-on',
#    'http://icondataset.org/hearts',
#    'http://icondataset.org/natural-landscape',
#    'http://icondataset.org/snuggling-in-her-lap'],
#   'in both': ['http://icondataset.org/griffon-claws',
#    'http://icondataset.org/wings',
#    'http://icondataset.org/child',
#    'http://icondataset.org/arrow',
#    'http://icondataset.org/boy',
#    'http://icondataset.org/bandage',
#    'http://icondataset.org/bow']},
#  'http://icondataset.org/phaeton': {'only not cf': [],
#   'only cf': [],
#   'in both': ['http://icondataset.org/man',
#    'http://icondataset.org/falling-off']},
#  'http://icondataset.org/cupid': {'only not cf': ['http://icondataset.org/playful-attitude',
#    'http://icondataset.org/holding-a-wreath'],
#   'only cf': ['http://icondataset.org/young',
#    'http://icondataset.org/man',
#    'http://icondataset.org/flying',
#    'http://icondataset.org/wreath',
#    'http://icondataset.org/sleeping',
#    'http://icondataset.org/taking-aim',
#    'http://icondataset.org/intense-devotion',
#    'http://icondataset.org/leaning-upon',
#    'http://icondataset.org/griffon-claws',
#    'http://icondataset.org/stirring-water',
#    'http://icondataset.org/rose',
#    'http://icondataset.org/fire',
#    'http://icondataset.org/string-of-hearts',
#    'http://icondataset.org/bandage',
#    'http://icondataset.org/lappets',
#    'http://icondataset.org/boots',
#    'http://icondataset.org/court-dress',
#    'http://icondataset.org/ribbon',
#    'http://icondataset.org/grabbing-with-one-hand',
#    'http://icondataset.org/holding-with-a-hand',
#    'http://icondataset.org/woman',
#    'http://icondataset.org/crown',
#    'http://icondataset.org/horse',
#    'http://icondataset.org/child',
#    'http://icondataset.org/shooting-an-arrow',
#    'http://icondataset.org/removing',
#    'http://icondataset.org/girl',
#    'http://icondataset.org/fishing',
#    'http://icondataset.org/leaning-on-her-shoulder',
#    'http://icondataset.org/myrtle-wreath',
#    'http://icondataset.org/standing-on-a-horse'],
#   'in both': ['http://icondataset.org/wings',
#    'http://icondataset.org/mantle',
#    'http://icondataset.org/putto',
#    'http://icondataset.org/arrow',
#    'http://icondataset.org/boy',
#    'http://icondataset.org/torch',
#    'http://icondataset.org/bow']},
#  'http://icondataset.org/mercurys-winged-sandals': {'only not cf': [],
#   'only cf': ['http://icondataset.org/bird'],
#   'in both': ['http://icondataset.org/wings-at-the-heels']},
#  'http://icondataset.org/medusas-head': {'only not cf': ['http://icondataset.org/drops-of-blood'],
#   'only cf': ['http://icondataset.org/caput-meduse'],
#   'in both': ['http://icondataset.org/serpent-locks',
#    'http://icondataset.org/cutten-head']},
#  'http://icondataset.org/luxury': {'only not cf': ['http://icondataset.org/embracing',
#    'http://icondataset.org/lover'],
#   'only cf': ['http://icondataset.org/woman'],
#   'in both': []},
#  'http://icondataset.org/the-constellation-perseus': {'only not cf': ['http://icondataset.org/wings-at-the-heels',
#    'http://icondataset.org/running',
#    'http://icondataset.org/cloth',
#    'http://icondataset.org/grace',
#    'http://icondataset.org/drops-of-blood'],
#   'only cf': ['http://icondataset.org/terrifying-expression',
#    'http://icondataset.org/beard',
#    'http://icondataset.org/gown',
#    'http://icondataset.org/caput-algol',
#    'http://icondataset.org/lifting-one-hand',
#    'http://icondataset.org/caput-meduse',
#    'http://icondataset.org/constellation'],
#   'in both': ['http://icondataset.org/man',
#    'http://icondataset.org/grabbing-with-one-hand',
#    'http://icondataset.org/sword',
#    'http://icondataset.org/serpent-locks',
#    'http://icondataset.org/lifting-with-one-hand',
#    'http://icondataset.org/cutten-head']},
#  'http://icondataset.org/faith': {'only not cf': ['http://icondataset.org/woman'],
#   'only cf': ['http://icondataset.org/joyful-excitement',
#    'http://icondataset.org/basket-with-roses',
#    'http://icondataset.org/raising',
#    'http://icondataset.org/glancing-heavenward',
#    'http://icondataset.org/figure'],
#   'in both': []},
#  'http://icondataset.org/blind-night': {'only not cf': ['http://icondataset.org/figure',
#    'http://icondataset.org/veil',
#    'http://icondataset.org/covering-her-eyes'],
#   'only cf': ['http://icondataset.org/bandage'],
#   'in both': ['http://icondataset.org/woman']},
#  'http://icondataset.org/platonic-love': {'only not cf': ['http://icondataset.org/torch',
#    'http://icondataset.org/boy'],
#   'only cf': ['http://icondataset.org/arrow', 'http://icondataset.org/child'],
#   'in both': ['http://icondataset.org/wings']},
#  'http://icondataset.org/day': {'only not cf': ['http://icondataset.org/figure'],
#   'only cf': ['http://icondataset.org/man'],
#   'in both': []},
#  'http://icondataset.org/truth': {'only not cf': ['http://icondataset.org/despair'],
#   'only cf': ['http://icondataset.org/child',
#    'http://icondataset.org/removing',
#    'http://icondataset.org/girl',
#    'http://icondataset.org/disgust',
#    'http://icondataset.org/curtain'],
#   'in both': ['http://icondataset.org/woman']},
#  'http://icondataset.org/chastity': {'only not cf': ['http://icondataset.org/lilium'],
#   'only cf': ['http://icondataset.org/maiden',
#    'http://icondataset.org/arrow',
#    'http://icondataset.org/covering-herself'],
#   'in both': ['http://icondataset.org/woman']},
#  'http://icondataset.org/phaeton-the-presumptuous': {'only not cf': [],
#   'only cf': [],
#   'in both': ['http://icondataset.org/man',
#    'http://icondataset.org/falling-off']},
#  'http://icondataset.org/four-wings-four-seasons': {'only not cf': [],
#   'only cf': [],
#   'in both': ['http://icondataset.org/wings']},
#  'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius': {'only not cf': ['http://icondataset.org/sun',
#    'http://icondataset.org/cloud'],
#   'only cf': ['http://icondataset.org/hurling',
#    'http://icondataset.org/group-of-figures',
#    'http://icondataset.org/chariot',
#    'http://icondataset.org/thunderbolt',
#    'http://icondataset.org/eagle'],
#   'in both': ['http://icondataset.org/man',
#    'http://icondataset.org/falling-off',
#    'http://icondataset.org/horse']},
#  'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom': {'only not cf': ['http://icondataset.org/slave'],
#   'only cf': ['http://icondataset.org/statue-of-a-slave'],
#   'in both': []}}

# %%
store = store_in_json("cf_subj2_difference.json", cfr_subj2_dict2)

# %%
len(cfr_subj2_dict)
# Out:
# 42

# %%
store_subj2_no_cf = []
for row in cq9res:
   # print(row)
    subj2 = str(row[1])
    subj1 = str(row[0])
    art = str(row[2])
    if art not in 
    store_subj2_no_cf.append([art, subj2, subj1])
store_subj2_no_cf
# Out:
# [['http://icondataset.org/ART1388',
#   'http://icondataset.org/devil',
#   'http://icondataset.org/winged-creature'],
#  ['http://icondataset.org/ART1380',
#   'http://icondataset.org/tityus',
#   'http://icondataset.org/fettered-man'],
#  ['http://icondataset.org/ART1037',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/spear'],
#  ['http://icondataset.org/ART1037',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1037',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/cloak'],
#  ['http://icondataset.org/ART1037',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/helmet'],
#  ['http://icondataset.org/ART1037',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/shield'],
#  ['http://icondataset.org/ART1037',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/backward-turning-movement'],
#  ['http://icondataset.org/ART1415',
#   'http://icondataset.org/serapis',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1415',
#   'http://icondataset.org/serapis',
#   'http://icondataset.org/throne'],
#  ['http://icondataset.org/ART1415',
#   'http://icondataset.org/serapis',
#   'http://icondataset.org/sceptre'],
#  ['http://icondataset.org/ART1415',
#   'http://icondataset.org/serapis',
#   'http://icondataset.org/modius'],
#  ['http://icondataset.org/ART1296',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1296',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/clothes'],
#  ['http://icondataset.org/ART1296',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1296',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/crown'],
#  ['http://icondataset.org/ART1295',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1295',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1295',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1295',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/clothes'],
#  ['http://icondataset.org/ART1295',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1295',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/crown'],
#  ['http://icondataset.org/ART1447',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/drawing-the-bow'],
#  ['http://icondataset.org/ART1447',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1447',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1237',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/supporting'],
#  ['http://icondataset.org/ART1237',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1237',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/sphere'],
#  ['http://icondataset.org/ART1003',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1003',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/lion-skin'],
#  ['http://icondataset.org/ART1003',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/carrying-on-shoulders'],
#  ['http://icondataset.org/ART1392',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/figure'],
#  ['http://icondataset.org/ART1537',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1543',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/dead-body-of-a-man'],
#  ['http://icondataset.org/ART1308',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1308',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1389',
#   'http://icondataset.org/ganymede',
#   'http://icondataset.org/cloth'],
#  ['http://icondataset.org/ART1389',
#   'http://icondataset.org/ganymede',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/laocoon',
#   'http://icondataset.org/wiggling-out-of-serpents'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/laocoon',
#   'http://icondataset.org/bear'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/laocoon',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1373',
#   'http://icondataset.org/christ-as-a-child',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1372',
#   'http://icondataset.org/christ-as-a-child',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/marine-snakes',
#   'http://icondataset.org/grabbing'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/marine-snakes',
#   'http://icondataset.org/serpent'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/perseus',
#   'http://icondataset.org/lifting-with-one-hand'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/perseus',
#   'http://icondataset.org/sword'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/perseus',
#   'http://icondataset.org/cloth'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/perseus',
#   'http://icondataset.org/cutten-head'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/perseus',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/perseus',
#   'http://icondataset.org/wings-at-the-heels'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/perseus',
#   'http://icondataset.org/running'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/antiphas-son-of-laoocoon',
#   'http://icondataset.org/wiggling-out-of-serpents'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/antiphas-son-of-laoocoon',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/antiphas-son-of-laoocoon',
#   'http://icondataset.org/cloth'],
#  ['http://icondataset.org/ART1373',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1372',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1363',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1199',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/dais'],
#  ['http://icondataset.org/ART1199',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1332',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1370',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/sketch-of-a-human-figure'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/earring'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/knotted-ribbon-bracelet'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/tiara'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/rose'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/veil'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/rose-petal'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/touching-breast'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/holding-a-wreath'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/belt'],
#  ['http://icondataset.org/ART1210',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/holding-with-a-hand'],
#  ['http://icondataset.org/ART1210',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1210',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/seashell'],
#  ['http://icondataset.org/ART1373',
#   'http://icondataset.org/david',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/thymbraeus-son-of-laoocoon',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/thymbraeus-son-of-laoocoon',
#   'http://icondataset.org/cloth'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/thymbraeus-son-of-laoocoon',
#   'http://icondataset.org/wiggling-out-of-serpents'],
#  ['http://icondataset.org/ART1286',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/figure'],
#  ['http://icondataset.org/ART1286',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1478',
#   'http://icondataset.org/satyr',
#   'http://icondataset.org/human-figure-with-animal-legs'],
#  ['http://icondataset.org/ART1457',
#   'http://icondataset.org/eve',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1332',
#   'http://icondataset.org/eve',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1015test',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/bear'],
#  ['http://icondataset.org/ART1015test',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1015test',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1533',
#   'http://icondataset.org/lapiths',
#   'http://icondataset.org/people'],
#  ['http://icondataset.org/ART1415',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/twisting-around'],
#  ['http://icondataset.org/ART1415',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-lion'],
#  ['http://icondataset.org/ART1415',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/three-headed-figure'],
#  ['http://icondataset.org/ART1415',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-dog'],
#  ['http://icondataset.org/ART1415',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-wolf'],
#  ['http://icondataset.org/ART1415',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/serpent'],
#  ['http://icondataset.org/ART1313',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/standing-on-a-horse'],
#  ['http://icondataset.org/ART1313',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1313',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1313',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/spear'],
#  ['http://icondataset.org/ART1313',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1313',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1313',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/griffon-claws'],
#  ['http://icondataset.org/ART1313',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/horse'],
#  ['http://icondataset.org/ART1313',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/band'],
#  ['http://icondataset.org/ART1322',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1322',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1322',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/running'],
#  ['http://icondataset.org/ART1322',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1390',
#   'http://icondataset.org/phaeton',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1390',
#   'http://icondataset.org/phaeton',
#   'http://icondataset.org/falling-off'],
#  ['http://icondataset.org/ART1308',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1308',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/holding-a-wreath'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1293',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/torch'],
#  ['http://icondataset.org/ART1293',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1293',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1293',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1293',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/mantle'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/mercurys-winged-sandals',
#   'http://icondataset.org/wings-at-the-heels'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/medusas-head',
#   'http://icondataset.org/cutten-head'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/medusas-head',
#   'http://icondataset.org/serpent-locks'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/medusas-head',
#   'http://icondataset.org/drops-of-blood'],
#  ['http://icondataset.org/ART1134',
#   'http://icondataset.org/luxury',
#   'http://icondataset.org/embracing'],
#  ['http://icondataset.org/ART1134',
#   'http://icondataset.org/luxury',
#   'http://icondataset.org/lover'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/drops-of-blood'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/grabbing-with-one-hand'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/wings-at-the-heels'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/running'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/lifting-with-one-hand'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/sword'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/serpent-locks'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/cloth'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/cutten-head'],
#  ['http://icondataset.org/ART1134',
#   'http://icondataset.org/faith',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1302',
#   'http://icondataset.org/blind-night',
#   'http://icondataset.org/veil'],
#  ['http://icondataset.org/ART1302',
#   'http://icondataset.org/blind-night',
#   'http://icondataset.org/figure'],
#  ['http://icondataset.org/ART1299',
#   'http://icondataset.org/blind-night',
#   'http://icondataset.org/veil'],
#  ['http://icondataset.org/ART1299',
#   'http://icondataset.org/blind-night',
#   'http://icondataset.org/covering-her-eyes'],
#  ['http://icondataset.org/ART1299',
#   'http://icondataset.org/blind-night',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1322',
#   'http://icondataset.org/platonic-love',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1322',
#   'http://icondataset.org/platonic-love',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1322',
#   'http://icondataset.org/platonic-love',
#   'http://icondataset.org/torch'],
#  ['http://icondataset.org/ART1302',
#   'http://icondataset.org/day',
#   'http://icondataset.org/figure'],
#  ['http://icondataset.org/ART1015test',
#   'http://icondataset.org/truth',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1134',
#   'http://icondataset.org/chastity',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1509',
#   'http://icondataset.org/chastity',
#   'http://icondataset.org/lilium'],
#  ['http://icondataset.org/ART1509',
#   'http://icondataset.org/chastity',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1390',
#   'http://icondataset.org/phaeton-the-presumptuous',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1390',
#   'http://icondataset.org/phaeton-the-presumptuous',
#   'http://icondataset.org/falling-off'],
#  ['http://icondataset.org/ART1271',
#   'http://icondataset.org/four-wings-four-seasons',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1390',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/cloud'],
#  ['http://icondataset.org/ART1390',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/falling-off'],
#  ['http://icondataset.org/ART1390',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/horse'],
#  ['http://icondataset.org/ART1390',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1390',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/sun'],
#  ['http://icondataset.org/ART1360',
#   'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom',
#   'http://icondataset.org/slave'],
#  ['http://icondataset.org/ART1237',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/effort'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/laocoon',
#   'http://icondataset.org/pathos'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/laocoon',
#   'http://icondataset.org/despair'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/perseus',
#   'http://icondataset.org/grace'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/antiphas-son-of-laoocoon',
#   'http://icondataset.org/despair'],
#  ['http://icondataset.org/ART1006test',
#   'http://icondataset.org/thymbraeus-son-of-laoocoon',
#   'http://icondataset.org/despair'],
#  ['http://icondataset.org/ART1002test',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/playful-attitude'],
#  ['http://icondataset.org/ART1023',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/grace'],
#  ['http://icondataset.org/ART1015test',
#   'http://icondataset.org/truth',
#   'http://icondataset.org/despair']]

# %%
store_subj2_cf = []
for row in cq8res:
   # print(row)
    subj2 = str(row[1])
    subj1 = str(row[0])
    art = str(row[2])
    store_subj2_cf.append([art, subj2, subj1])
store_subj2_cf
# Out:
# [['http://icondataset.org/ART1317',
#   'http://icondataset.org/devil',
#   'http://icondataset.org/human'],
#  ['http://icondataset.org/ART1317',
#   'http://icondataset.org/devil',
#   'http://icondataset.org/holding-with-a-hand'],
#  ['http://icondataset.org/ART1317',
#   'http://icondataset.org/devil',
#   'http://icondataset.org/figure'],
#  ['http://icondataset.org/ART1379',
#   'http://icondataset.org/tityus',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/touching-breast'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/armor'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/gentleman'],
#  ['http://icondataset.org/ART1036',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/shield'],
#  ['http://icondataset.org/ART1036',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/cloak'],
#  ['http://icondataset.org/ART1036',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/hat'],
#  ['http://icondataset.org/ART1036',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1036',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/backward-turning-movement'],
#  ['http://icondataset.org/ART1036',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/spear'],
#  ['http://icondataset.org/ART1525',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1525',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/shield'],
#  ['http://icondataset.org/ART1525',
#   'http://icondataset.org/mars',
#   'http://icondataset.org/spear'],
#  ['http://icondataset.org/ART1421',
#   'http://icondataset.org/serapis',
#   'http://icondataset.org/head-of-a-dog'],
#  ['http://icondataset.org/ART1421',
#   'http://icondataset.org/serapis',
#   'http://icondataset.org/three-headed-serpent'],
#  ['http://icondataset.org/ART1421',
#   'http://icondataset.org/serapis',
#   'http://icondataset.org/head-of-a-wolf'],
#  ['http://icondataset.org/ART1421',
#   'http://icondataset.org/serapis',
#   'http://icondataset.org/head-of-a-lion'],
#  ['http://icondataset.org/ART1297',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1297',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/tree'],
#  ['http://icondataset.org/ART1297',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1297',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/torch'],
#  ['http://icondataset.org/ART1297',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/sitting-on'],
#  ['http://icondataset.org/ART1297',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/clothes'],
#  ['http://icondataset.org/ART1297',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1297',
#   'http://icondataset.org/dieu-amour',
#   'http://icondataset.org/crown'],
#  ['http://icondataset.org/ART1446',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1446',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1446',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/drawing-the-bow'],
#  ['http://icondataset.org/ART1001',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1201',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1201',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/club'],
#  ['http://icondataset.org/ART1233',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/standing-on-the-ground'],
#  ['http://icondataset.org/ART1233',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/ground'],
#  ['http://icondataset.org/ART1458',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/lifting-one-hand'],
#  ['http://icondataset.org/ART1458',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1458',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/sceptre'],
#  ['http://icondataset.org/ART1458',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/holding-with-the-right-hand'],
#  ['http://icondataset.org/ART1458',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/halo-of-rays'],
#  ['http://icondataset.org/ART1017test',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/cornerstone-of-a-church'],
#  ['http://icondataset.org/ART1004',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/cloth'],
#  ['http://icondataset.org/ART1004',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/carrying-on-shoulders'],
#  ['http://icondataset.org/ART1004',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1264',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/crown'],
#  ['http://icondataset.org/ART1264',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/cross'],
#  ['http://icondataset.org/ART1264',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1538',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1187',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1187',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/halo'],
#  ['http://icondataset.org/ART1162',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1324',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1324',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/fishing'],
#  ['http://icondataset.org/ART1324',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/halo'],
#  ['http://icondataset.org/ART1324',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1319',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1319',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1318',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/fishing'],
#  ['http://icondataset.org/ART1318',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1318',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1321',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1321',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/tying'],
#  ['http://icondataset.org/ART1321',
#   'http://icondataset.org/anteros',
#   'http://icondataset.org/tree'],
#  ['http://icondataset.org/ART1378',
#   'http://icondataset.org/ganymede',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1042',
#   'http://icondataset.org/laocoon',
#   'http://icondataset.org/clothes'],
#  ['http://icondataset.org/ART1042',
#   'http://icondataset.org/laocoon',
#   'http://icondataset.org/bear'],
#  ['http://icondataset.org/ART1042',
#   'http://icondataset.org/laocoon',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1539',
#   'http://icondataset.org/christ-as-a-child',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1232',
#   'http://icondataset.org/christ-as-a-child',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1042',
#   'http://icondataset.org/marine-snakes',
#   'http://icondataset.org/water'],
#  ['http://icondataset.org/ART1042',
#   'http://icondataset.org/marine-snakes',
#   'http://icondataset.org/serpent'],
#  ['http://icondataset.org/ART1019',
#   'http://icondataset.org/perseus',
#   'http://icondataset.org/wings-at-the-heels'],
#  ['http://icondataset.org/ART1019',
#   'http://icondataset.org/perseus',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1019',
#   'http://icondataset.org/perseus',
#   'http://icondataset.org/sword'],
#  ['http://icondataset.org/ART1042',
#   'http://icondataset.org/antiphas-son-of-laoocoon',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1042',
#   'http://icondataset.org/antiphas-son-of-laoocoon',
#   'http://icondataset.org/clothes'],
#  ['http://icondataset.org/ART1160',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1539',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1061',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1355',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/statue-of-a-woman'],
#  ['http://icondataset.org/ART1008test',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/girl'],
#  ['http://icondataset.org/ART1008test',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/holding-a-book'],
#  ['http://icondataset.org/ART1008test',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/book'],
#  ['http://icondataset.org/ART1107',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/clothes'],
#  ['http://icondataset.org/ART1107',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1107',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/face'],
#  ['http://icondataset.org/ART1009test',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/clothes'],
#  ['http://icondataset.org/ART1009test',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/girl'],
#  ['http://icondataset.org/ART1187',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/halo'],
#  ['http://icondataset.org/ART1187',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/mantle'],
#  ['http://icondataset.org/ART1187',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1339',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/crown'],
#  ['http://icondataset.org/ART1339',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/glass-sphere'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/holding-on-her-lap'],
#  ['http://icondataset.org/ART1030',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/clothes'],
#  ['http://icondataset.org/ART1030',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/lady'],
#  ['http://icondataset.org/ART1030',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/rose'],
#  ['http://icondataset.org/ART1030',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/holding-a-rose-to-her-face'],
#  ['http://icondataset.org/ART1121',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/holding-with-a-hand'],
#  ['http://icondataset.org/ART1121',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/sea-goose'],
#  ['http://icondataset.org/ART1121',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1121',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/emerging-from-the-water'],
#  ['http://icondataset.org/ART1288',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1044',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/crown'],
#  ['http://icondataset.org/ART1044',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1000',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/dove'],
#  ['http://icondataset.org/ART1000',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1122',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1122',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/holding-with-a-hand'],
#  ['http://icondataset.org/ART1122',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/sea-goose-with-a-fish-tail'],
#  ['http://icondataset.org/ART1122',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/emerging-from-the-water'],
#  ['http://icondataset.org/ART1201',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1201',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/dove'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/slate'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/holding-with-a-hand'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/rose'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/emerging-from-the-water'],
#  ['http://icondataset.org/ART1191',
#   'http://icondataset.org/david',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1191',
#   'http://icondataset.org/david',
#   'http://icondataset.org/drapery'],
#  ['http://icondataset.org/ART1042',
#   'http://icondataset.org/thymbraeus-son-of-laoocoon',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1042',
#   'http://icondataset.org/thymbraeus-son-of-laoocoon',
#   'http://icondataset.org/clothes'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/armor'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/cart'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/lending-both-hands-to-a-woman'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/knight'],
#  ['http://icondataset.org/ART1041',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1041',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/jar'],
#  ['http://icondataset.org/ART1005test',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/grabbing-and-lifting-a-woman'],
#  ['http://icondataset.org/ART1005test',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/crown'],
#  ['http://icondataset.org/ART1005test',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1525',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/sceptre'],
#  ['http://icondataset.org/ART1525',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/holding-with-the-right-hand'],
#  ['http://icondataset.org/ART1525',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1525',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/holding-with-the-left-hand'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/flowers'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/lending-one-hand-to-a-man'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/sitting-down'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/gathering-flowers'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/court-dress'],
#  ['http://icondataset.org/ART1005test',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1005test',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/raising-arms-upwards'],
#  ['http://icondataset.org/ART1197',
#   'http://icondataset.org/satyr',
#   'http://icondataset.org/human-figure-with-animal-legs'],
#  ['http://icondataset.org/ART1197',
#   'http://icondataset.org/satyr',
#   'http://icondataset.org/woman-with-goat-legs'],
#  ['http://icondataset.org/ART1197',
#   'http://icondataset.org/satyr',
#   'http://icondataset.org/human-baby-with-animal-legs'],
#  ['http://icondataset.org/ART1315',
#   'http://icondataset.org/satyr',
#   'http://icondataset.org/human-figure-with-animal-legs'],
#  ['http://icondataset.org/ART1250',
#   'http://icondataset.org/satyr',
#   'http://icondataset.org/human-figure-with-animal-legs'],
#  ['http://icondataset.org/ART1316',
#   'http://icondataset.org/satyr',
#   'http://icondataset.org/human-figure-with-animal-legs'],
#  ['http://icondataset.org/ART1249',
#   'http://icondataset.org/satyr',
#   'http://icondataset.org/human-figure-with-animal-legs'],
#  ['http://icondataset.org/ART1068',
#   'http://icondataset.org/eve',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1270',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/clothes'],
#  ['http://icondataset.org/ART1270',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/wooden-leg'],
#  ['http://icondataset.org/ART1270',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1270',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/crutch'],
#  ['http://icondataset.org/ART1265',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/king'],
#  ['http://icondataset.org/ART1265',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/sitting-on'],
#  ['http://icondataset.org/ART1265',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/throne'],
#  ['http://icondataset.org/ART1265',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/spade'],
#  ['http://icondataset.org/ART1265',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/crown'],
#  ['http://icondataset.org/ART1268',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/bear'],
#  ['http://icondataset.org/ART1268',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1268',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/scythe'],
#  ['http://icondataset.org/ART1030',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/soldier'],
#  ['http://icondataset.org/ART1030',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/helmet'],
#  ['http://icondataset.org/ART1212',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1212',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/cloth'],
#  ['http://icondataset.org/ART1212',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/sickle'],
#  ['http://icondataset.org/ART1269',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/support-oneself-with'],
#  ['http://icondataset.org/ART1269',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/crutch'],
#  ['http://icondataset.org/ART1269',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1269',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/sickle'],
#  ['http://icondataset.org/ART1261',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1261',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/cloth'],
#  ['http://icondataset.org/ART1261',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/scythe'],
#  ['http://icondataset.org/ART1289',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1289',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/bear'],
#  ['http://icondataset.org/ART1289',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1266',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/king'],
#  ['http://icondataset.org/ART1266',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/dragon-biting-its-tail'],
#  ['http://icondataset.org/ART1266',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/scythe'],
#  ['http://icondataset.org/ART1266',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/throne'],
#  ['http://icondataset.org/ART1266',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/sitting-on'],
#  ['http://icondataset.org/ART1266',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/crown'],
#  ['http://icondataset.org/ART1043',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/sickle'],
#  ['http://icondataset.org/ART1043',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/veil'],
#  ['http://icondataset.org/ART1043',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/scythe'],
#  ['http://icondataset.org/ART1043',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1043',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/dragon-biting-its-tail'],
#  ['http://icondataset.org/ART1534',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/scythe'],
#  ['http://icondataset.org/ART1534',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1534',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/bear'],
#  ['http://icondataset.org/ART1267',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1267',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/scythe'],
#  ['http://icondataset.org/ART1267',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/bear'],
#  ['http://icondataset.org/ART1260',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/sickle'],
#  ['http://icondataset.org/ART1260',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/veil'],
#  ['http://icondataset.org/ART1260',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1201',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1201',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/scythe'],
#  ['http://icondataset.org/ART1259',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/sickle'],
#  ['http://icondataset.org/ART1259',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1259',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/veil'],
#  ['http://icondataset.org/ART1535',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1535',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/bear'],
#  ['http://icondataset.org/ART1253',
#   'http://icondataset.org/lapiths',
#   'http://icondataset.org/stick'],
#  ['http://icondataset.org/ART1253',
#   'http://icondataset.org/lapiths',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1418',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/three-headed-serpent'],
#  ['http://icondataset.org/ART1419',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-lion'],
#  ['http://icondataset.org/ART1419',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/three-headed-serpent'],
#  ['http://icondataset.org/ART1419',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-dog'],
#  ['http://icondataset.org/ART1419',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-wolf'],
#  ['http://icondataset.org/ART1416',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-wolf'],
#  ['http://icondataset.org/ART1416',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/three-headed-serpent'],
#  ['http://icondataset.org/ART1416',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-dog'],
#  ['http://icondataset.org/ART1416',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-lion'],
#  ['http://icondataset.org/ART1417',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-lion'],
#  ['http://icondataset.org/ART1417',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/three-headed-serpent'],
#  ['http://icondataset.org/ART1417',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-wolf'],
#  ['http://icondataset.org/ART1417',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-dog'],
#  ['http://icondataset.org/ART1423',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-dog'],
#  ['http://icondataset.org/ART1423',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-lion'],
#  ['http://icondataset.org/ART1423',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-wolf'],
#  ['http://icondataset.org/ART1423',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/three-headed-figure'],
#  ['http://icondataset.org/ART1421',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/sceptre'],
#  ['http://icondataset.org/ART1421',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/modius'],
#  ['http://icondataset.org/ART1421',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1413',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/serpent'],
#  ['http://icondataset.org/ART1413',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-dog'],
#  ['http://icondataset.org/ART1413',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-wolf'],
#  ['http://icondataset.org/ART1413',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-lion'],
#  ['http://icondataset.org/ART1413',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/three-headed-figure'],
#  ['http://icondataset.org/ART1413',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/twisting-around'],
#  ['http://icondataset.org/ART1414',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-dog'],
#  ['http://icondataset.org/ART1414',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/three-headed-figure'],
#  ['http://icondataset.org/ART1414',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-lion'],
#  ['http://icondataset.org/ART1414',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/serpent'],
#  ['http://icondataset.org/ART1414',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/head-of-a-wolf'],
#  ['http://icondataset.org/ART1414',
#   'http://icondataset.org/companion-of-serapis',
#   'http://icondataset.org/twisting-around'],
#  ['http://icondataset.org/ART1314',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1314',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/talon'],
#  ['http://icondataset.org/ART1314',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1314',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1314',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1314',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1339',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1339',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/snuggling-in-her-lap'],
#  ['http://icondataset.org/ART1339',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1317',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1317',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1317',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1317',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1317',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1326',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/sphere'],
#  ['http://icondataset.org/ART1326',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/standing-on'],
#  ['http://icondataset.org/ART1326',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1326',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1326',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1326',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1323',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1323',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1323',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/natural-landscape'],
#  ['http://icondataset.org/ART1323',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/sleeping'],
#  ['http://icondataset.org/ART1323',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1323',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1311',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/throne'],
#  ['http://icondataset.org/ART1311',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/string-of-hearts'],
#  ['http://icondataset.org/ART1311',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/griffon-claws'],
#  ['http://icondataset.org/ART1311',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1311',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1311',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1311',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1311',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/crown-of-roses'],
#  ['http://icondataset.org/ART1311',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1310',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/hearts'],
#  ['http://icondataset.org/ART1310',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1310',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1310',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1310',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1310',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/griffon-claws'],
#  ['http://icondataset.org/ART1310',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1310',
#   'http://icondataset.org/blindfold-cupid',
#   'http://icondataset.org/crown-of-roses'],
#  ['http://icondataset.org/ART1384',
#   'http://icondataset.org/phaeton',
#   'http://icondataset.org/falling-off'],
#  ['http://icondataset.org/ART1384',
#   'http://icondataset.org/phaeton',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/phaeton',
#   'http://icondataset.org/falling-off'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/phaeton',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/phaeton',
#   'http://icondataset.org/falling-off'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/phaeton',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1131',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1131',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wreath'],
#  ['http://icondataset.org/ART1131',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/grabbing-with-one-hand'],
#  ['http://icondataset.org/ART1512',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/boots'],
#  ['http://icondataset.org/ART1512',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/ribbon'],
#  ['http://icondataset.org/ART1512',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/lappets'],
#  ['http://icondataset.org/ART1512',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1339',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/leaning-on-her-shoulder'],
#  ['http://icondataset.org/ART1339',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1339',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1339',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1292',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1292',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/mantle'],
#  ['http://icondataset.org/ART1292',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1292',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/shooting-an-arrow'],
#  ['http://icondataset.org/ART1292',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1292',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1200',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1200',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1200',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1129',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/sleeping'],
#  ['http://icondataset.org/ART1129',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/torch'],
#  ['http://icondataset.org/ART1129',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1129',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/leaning-upon'],
#  ['http://icondataset.org/ART1129',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1132',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wreath'],
#  ['http://icondataset.org/ART1132',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/grabbing-with-one-hand'],
#  ['http://icondataset.org/ART1132',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/myrtle-wreath'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/girl'],
#  ['http://icondataset.org/ART1203',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1203',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/fire'],
#  ['http://icondataset.org/ART1203',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/taking-aim'],
#  ['http://icondataset.org/ART1203',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1203',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1203',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1324',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1324',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1324',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1324',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/fishing'],
#  ['http://icondataset.org/ART1130',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/flying'],
#  ['http://icondataset.org/ART1130',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/holding-with-a-hand'],
#  ['http://icondataset.org/ART1130',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1130',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/torch'],
#  ['http://icondataset.org/ART1130',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1386',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/sleeping'],
#  ['http://icondataset.org/ART1386',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1386',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1386',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1325',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1315',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/shooting-an-arrow'],
#  ['http://icondataset.org/ART1315',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/mantle'],
#  ['http://icondataset.org/ART1315',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1315',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1315',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1315',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1329',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1329',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/stirring-water'],
#  ['http://icondataset.org/ART1329',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1312',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1312',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/rose'],
#  ['http://icondataset.org/ART1312',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/horse'],
#  ['http://icondataset.org/ART1312',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1312',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/string-of-hearts'],
#  ['http://icondataset.org/ART1312',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/standing-on-a-horse'],
#  ['http://icondataset.org/ART1312',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1312',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/griffon-claws'],
#  ['http://icondataset.org/ART1312',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1319',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1319',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1288',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/removing'],
#  ['http://icondataset.org/ART1294',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1294',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1294',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1294',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/flying'],
#  ['http://icondataset.org/ART1316',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1316',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/shooting-an-arrow'],
#  ['http://icondataset.org/ART1316',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1316',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1316',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1316',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1122',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/crown'],
#  ['http://icondataset.org/ART1122',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1122',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1122',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/court-dress'],
#  ['http://icondataset.org/ART1122',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1122',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1122',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1201',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1201',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1201',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1201',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/shooting-an-arrow'],
#  ['http://icondataset.org/ART1201',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/young'],
#  ['http://icondataset.org/ART1318',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1318',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/fishing'],
#  ['http://icondataset.org/ART1318',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1321',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1321',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1321',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1321',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/boy'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/court-dress'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/bow'],
#  ['http://icondataset.org/ART1123',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1291',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1291',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/putto'],
#  ['http://icondataset.org/ART1041',
#   'http://icondataset.org/mercurys-winged-sandals',
#   'http://icondataset.org/bird'],
#  ['http://icondataset.org/ART1019',
#   'http://icondataset.org/mercurys-winged-sandals',
#   'http://icondataset.org/wings-at-the-heels'],
#  ['http://icondataset.org/ART1005',
#   'http://icondataset.org/medusas-head',
#   'http://icondataset.org/cutten-head'],
#  ['http://icondataset.org/ART1019',
#   'http://icondataset.org/medusas-head',
#   'http://icondataset.org/serpent-locks'],
#  ['http://icondataset.org/ART1019',
#   'http://icondataset.org/medusas-head',
#   'http://icondataset.org/cutten-head'],
#  ['http://icondataset.org/ART1290',
#   'http://icondataset.org/luxury',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1005',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1005',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/sword'],
#  ['http://icondataset.org/ART1005',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/cutten-head'],
#  ['http://icondataset.org/ART1018',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/beard'],
#  ['http://icondataset.org/ART1018',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/cutten-head'],
#  ['http://icondataset.org/ART1018',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/grabbing-with-one-hand'],
#  ['http://icondataset.org/ART1018',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/lifting-one-hand'],
#  ['http://icondataset.org/ART1018',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/constellation'],
#  ['http://icondataset.org/ART1018',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1019',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/serpent-locks'],
#  ['http://icondataset.org/ART1019',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/cutten-head'],
#  ['http://icondataset.org/ART1024',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/constellation'],
#  ['http://icondataset.org/ART1024',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/cutten-head'],
#  ['http://icondataset.org/ART1024',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/grabbing-with-one-hand'],
#  ['http://icondataset.org/ART1024',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/gown'],
#  ['http://icondataset.org/ART1024',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/sword'],
#  ['http://icondataset.org/ART1024',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/lifting-with-one-hand'],
#  ['http://icondataset.org/ART1024',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/beard'],
#  ['http://icondataset.org/ART1024',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/faith',
#   'http://icondataset.org/figure'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/faith',
#   'http://icondataset.org/glancing-heavenward'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/faith',
#   'http://icondataset.org/basket-with-roses'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/faith',
#   'http://icondataset.org/raising'],
#  ['http://icondataset.org/ART1298',
#   'http://icondataset.org/blind-night',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1298',
#   'http://icondataset.org/blind-night',
#   'http://icondataset.org/bandage'],
#  ['http://icondataset.org/ART1200',
#   'http://icondataset.org/platonic-love',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1200',
#   'http://icondataset.org/platonic-love',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1200',
#   'http://icondataset.org/platonic-love',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1365',
#   'http://icondataset.org/day',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1283',
#   'http://icondataset.org/truth',
#   'http://icondataset.org/girl'],
#  ['http://icondataset.org/ART1333',
#   'http://icondataset.org/truth',
#   'http://icondataset.org/child'],
#  ['http://icondataset.org/ART1333',
#   'http://icondataset.org/truth',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1335',
#   'http://icondataset.org/truth',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1204',
#   'http://icondataset.org/truth',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1288',
#   'http://icondataset.org/truth',
#   'http://icondataset.org/removing'],
#  ['http://icondataset.org/ART1288',
#   'http://icondataset.org/truth',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1288',
#   'http://icondataset.org/truth',
#   'http://icondataset.org/curtain'],
#  ['http://icondataset.org/ART1339',
#   'http://icondataset.org/chastity',
#   'http://icondataset.org/arrow'],
#  ['http://icondataset.org/ART1339',
#   'http://icondataset.org/chastity',
#   'http://icondataset.org/maiden'],
#  ['http://icondataset.org/ART1334',
#   'http://icondataset.org/chastity',
#   'http://icondataset.org/covering-herself'],
#  ['http://icondataset.org/ART1334',
#   'http://icondataset.org/chastity',
#   'http://icondataset.org/woman'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/phaeton-the-presumptuous',
#   'http://icondataset.org/falling-off'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/phaeton-the-presumptuous',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/phaeton-the-presumptuous',
#   'http://icondataset.org/falling-off'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/phaeton-the-presumptuous',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1273',
#   'http://icondataset.org/four-wings-four-seasons',
#   'http://icondataset.org/wings'],
#  ['http://icondataset.org/ART1384',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/falling-off'],
#  ['http://icondataset.org/ART1384',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/eagle'],
#  ['http://icondataset.org/ART1384',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1384',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/thunderbolt'],
#  ['http://icondataset.org/ART1384',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/horse'],
#  ['http://icondataset.org/ART1384',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/chariot'],
#  ['http://icondataset.org/ART1384',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/hurling'],
#  ['http://icondataset.org/ART1384',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/group-of-figures'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/chariot'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/falling-off'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/horse'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/thunderbolt'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/eagle'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/hurling'],
#  ['http://icondataset.org/ART1383',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/group-of-figures'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/chariot'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/group-of-figures'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/man'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/eagle'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/thunderbolt'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/hurling'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/falling-off'],
#  ['http://icondataset.org/ART1382',
#   'http://icondataset.org/fall-of-phaeton-fate-of-every-temerarius',
#   'http://icondataset.org/horse'],
#  ['http://icondataset.org/ART1352',
#   'http://icondataset.org/slave-human-soul-in-so-far-as-it-is-devoid-of-freedom',
#   'http://icondataset.org/statue-of-a-slave'],
#  ['http://icondataset.org/ART1446',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/energy'],
#  ['http://icondataset.org/ART1446',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/forceful'],
#  ['http://icondataset.org/ART1446',
#   'http://icondataset.org/hercules',
#   'http://icondataset.org/powerful-sturdiness'],
#  ['http://icondataset.org/ART1538',
#   'http://icondataset.org/christ',
#   'http://icondataset.org/condemning-gesture'],
#  ['http://icondataset.org/ART1378',
#   'http://icondataset.org/ganymede',
#   'http://icondataset.org/immobility'],
#  ['http://icondataset.org/ART1378',
#   'http://icondataset.org/ganymede',
#   'http://icondataset.org/state-of-trance'],
#  ['http://icondataset.org/ART1008test',
#   'http://icondataset.org/mary',
#   'http://icondataset.org/smiling'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/venus',
#   'http://icondataset.org/pensively'],
#  ['http://icondataset.org/ART1191',
#   'http://icondataset.org/david',
#   'http://icondataset.org/victorious'],
#  ['http://icondataset.org/ART1191',
#   'http://icondataset.org/david',
#   'http://icondataset.org/pathos'],
#  ['http://icondataset.org/ART1191',
#   'http://icondataset.org/david',
#   'http://icondataset.org/agitated-movement'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/courteous-attitude'],
#  ['http://icondataset.org/ART1005test',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/force'],
#  ['http://icondataset.org/ART1005test',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/backward-gaze'],
#  ['http://icondataset.org/ART1005test',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/crying'],
#  ['http://icondataset.org/ART1265',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/gloomy'],
#  ['http://icondataset.org/ART1266',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/gloomy'],
#  ['http://icondataset.org/ART1260',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/gloomy'],
#  ['http://icondataset.org/ART1259',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/gloomy'],
#  ['http://icondataset.org/ART1535',
#   'http://icondataset.org/saturn',
#   'http://icondataset.org/despair'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/cupid',
#   'http://icondataset.org/intense-devotion'],
#  ['http://icondataset.org/ART1018',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/terrifying-expression'],
#  ['http://icondataset.org/ART1024',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/terrifying-expression'],
#  ['http://icondataset.org/ART1338',
#   'http://icondataset.org/faith',
#   'http://icondataset.org/joyful-excitement'],
#  ['http://icondataset.org/ART1288',
#   'http://icondataset.org/truth',
#   'http://icondataset.org/disgust'],
#  ['http://icondataset.org/ART1317',
#   'http://icondataset.org/devil',
#   'http://icondataset.org/mors-aeterna'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/pluto'],
#  ['http://icondataset.org/ART1525',
#   'http://icondataset.org/pluto',
#   'http://icondataset.org/triple-throated-cerberus'],
#  ['http://icondataset.org/ART1004test',
#   'http://icondataset.org/proserpina',
#   'http://icondataset.org/preserpine'],
#  ['http://icondataset.org/ART1019',
#   'http://icondataset.org/medusas-head',
#   'http://icondataset.org/caput-meduse'],
#  ['http://icondataset.org/ART1018',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/caput-algol'],
#  ['http://icondataset.org/ART1019',
#   'http://icondataset.org/the-constellation-perseus',
#   'http://icondataset.org/caput-meduse']]

# %%
first_line = ["artwork", "subject2", "subject1"]
store = store_csv("subj2_subj1_no_cf.csv", first_line, store_subj2_no_cf)
store2 =  store_csv("subj2_subj1_cf.csv", first_line, store_subj2_cf)
