# %% [markdown]
# ## To Do
# Dictionaries that need multiple reconciliation:
# 1. people (done)
#
# 2. places:
# - cities
# - countries
# - institutions
#
# 3. Level1:
# - named obj
# - quality
# - expressional
# - actions
#
# 4. Level2:
# - characters (done)
# - named obj
# - places
# - events
# - personifications
# - allegories
# - invenzioni
#
# 5. Level3
# - concepts
#
# 6. Simulation

# %% [markdown]
# ## Imports

# %%
# !pip install requests
import requests

#!pip install SPARQLWrapper

from SPARQLWrapper import SPARQLWrapper, JSON
import ssl

#!pip install fuzzywuzzy
import difflib
# !pip install python-Levenshtein
# !pip install thefuzz
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# from thefuzz import fuzz
# from thefuzz import process
import json
import csv
import time #
# Out:
# C:\Users\Sofia Baroncini\AppData\Roaming\Python\Python39\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#!pip install rdflib
from rdflib import URIRef, BNode, Literal, Graph
from rdflib.namespace import CSVW, DC, DCAT, DCTERMS, DOAP, FOAF, ODRL2, ORG, OWL, \
                           PROF, PROV, RDF, RDFS, SDO, SH, SKOS, SOSA, SSN, TIME, \
                           VOID, XMLNS, XSD
from rdflib import Namespace, Literal, XSD

# %%
# endpoints

sparql_getty = "http://vocab.getty.edu/sparql"
wikidata_endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"
iconclass_api = ""

# %% [markdown]
# ## Ancillary functions

# %%
# ancillary functions


def sparql_query_setting(query, endpoint):# set the endpoint 
  sparql = SPARQLWrapper(endpoint)
  # set the query
  sparql.setQuery(query)
  # set the returned format
  sparql.setReturnFormat(JSON)
  # get the results
  results = sparql.query().convert()
  return results



def wikidata_reconciliation(r, endpoint, q_class=None): # specify the class of which the individual should be instance of
# r = json results of the get request 
  # double check if the entity belongs to the right class
  if 'search' in r and len(r['search']) >= 1:
      if q_class: # if a class is given, it checkes if the wikidata entity belongs to the correct class. 
        query_string = """ASK {<"""+r['search'][0]['concepturi']+"""> wdt:P31 wd:"""+q_class+""". }"""
        res = sparql_query_setting(query_string, endpoint)
        # print("\nRES", query, query_string, res)
        if res["boolean"] == True: # add a timeout

          return [ r['search'][0]['concepturi'] , 'class_match']
        else:
          return [ r['search'][0]['concepturi'] , 'no_class_match']
      else:
        return [ r['search'][0]['concepturi'] , 'no_class_given']
  else:
      return 'not matched'

# having a dictionary containing q terms, query wd for asking its related terms in external vocabulary, as specified by the query.
def alignments_through_wd(dictionary, query, variable_list, endpoint, url_string): 
  all_items = dictionary.items() # ordered dict of tuples
  for item in all_items: # tuple with key-value pairs
    if type(item[1]) == list: 
      for el in item[1]: # item[1]
        if el.startswith("http://www.wikidata.org/entity/"): # in this way, we also filter automatically also the " rec" keys
          print(el, item[0])
          cleaned_el = el.replace("\"","")
          final_query = query.replace("toBeReplaced", cleaned_el)
          res = sparql_query_setting(final_query, endpoint)
          for result in res["results"]["bindings"]:
            for var in variable_list: 
              aligned = url_string+result[var]["value"]
              print(aligned)
              if aligned not in dictionary[item[0]]: 
                dictionary[item[0]].append(aligned)
  return(dictionary)
    
# function already present in the main script - remove/add terms from a dictionary
def remove_add_terms(dictionary, pair_list, instruction_string): # dictionary to be updated, list containing tuples with key-link to be removed
  for pair in pair_list: # pair[0] = name, pair[1] = value
   # print(pair)
    if instruction_string == "remove": 
      if pair[1] in dictionary[pair[0]]:
        dictionary[pair[0]].remove(pair[1])
    elif instruction_string == "add": 
      # if dictionary[pair[0]][0].startswith("http://icondataset.org/") and len(dictionary[pair[0]]) == 1: # we double check that the term is really without an alignment
      if len(dictionary[pair[0]]) <=1:
        dictionary[pair[0]] = [pair[1]]
  return dictionary

# mean of the fuzzywuzzy parameters for word similarity
def fuzz_ratio_mean(name, term):
  ratio1 = fuzz.ratio(name, term)
  ratio2 = fuzz.partial_ratio(name, term)
  ratio3 = fuzz.token_sort_ratio(name, term)
  ratio4 = fuzz.WRatio(name, term)
  mean = (ratio1+ratio2+ratio3+ratio4)/4
  return mean

# open dictionaries stored in json
def open_json(json_file): 
  with open(json_file, mode='r', encoding="utf-8") as jsonfile:
    dictName = json.load(jsonfile)
    return dictName

# save a dictionary in json
def store_in_json(file_name, dictName): 
  with open(file_name, mode='w', encoding="utf-8") as jsonfile:
    json.dump(dictName, jsonfile)


# stop words and others removal. After this passage: ready to reconcile

def rumor_removal(dictionary):
  for item in dictionary.items(): 
    if type(item[1]) == list: 
      for i in range(len(item[1])- 1, -1, -1): # len - 1 = last postition; start -1 = 0; move of -1
        if item[1][i].startswith("http") is False:
          del item[1][i]
  return(dictionary)

# store in csv

def store_csv(file_name, first_line, list_of_lists): 
    with open(file_name, mode='w', newline='', encoding='UTF-8') as my_file:
        file = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
        file.writerow(first_line) 
        for l in list_of_lists: 
            file.writerow(l) 
    return(file_name)

# store in csv
# input: list of tuples, where tup[0] is the name and tup[1] is the reconciled link
# store in a json where the first column is the name and the second column is a concat of all the values having that key, with " @ " as separator
def from_tup_to_csv(list_of_tup, file_name, first_line): 
    list_of_lists = []
    tot_dict = {}
    for tup in list_of_tup: 
        if tup[0] not in tot_dict: 
            tot_dict[tup[0]] = []
        tot_dict[tup[0]].append(tup[1])

    for item in tot_dict.items(): 
        list_of_lists.append([item[0], ' @ '.join(item[1])])
        
    with open(file_name, mode='w', newline='') as my_file:
        file = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
        file.writerow(first_line) 
        for l in list_of_lists: 
            file.writerow(l) 
    return(file_name) 

import csv

# from dict to csv: 
def store_dict_in_csv(file_name, first_line, dictionary):
    list_of_lists = []
    for tup in dictionary.items(): 
        if tup[0].endswith(" rec"): 
            col1 = tup[0].replace(" rec", "")
            if type(tup[1])== list:
                col2 = ' @ '.join(tup[1])
            else: 
                col2 = tup[1]
            list_of_lists.append([col1, col2])
    final = store_csv(file_name, first_line, list_of_lists)
    return final

# %% [markdown]
# # Word filtering
# * detetection of plurals: words of the same tipology with a high rank of similarity will be standardized in the format word(plural end of word)
# * detection of synonyms through wordnet
#
# dictionaries will be updated with the new form, the correspondence will be stored in a list of tuples.

# %% [markdown]
# ## Detection of plurals
#
# **Method**: <br>
# 1. For each interested vocabulary, create 2 lists containing all the keys. With a for loop check all the words similarities through the fuzzywuzzy means algorithm
# 2. identify the difference between similar forms. if the difference is equal to "s", "es", "ies", the words are considered singular/plural. Print the others: if there are plurals, add them manually to the list of tuples afer passage 3.
# 3. store the result in a list of tuples (at the beginning inserted as sets to avoid repetitions) where tup[0] = singular, tup[1] = plural, tup[2] = neutral form in "name(s)" type
# 4. substitute the forms with singular/plural in the dictionary with the new neutral form, adding, if present, the values of the previous keys

# %%
# dictionary opening
naturalElementDict = open_json("baseDictionaries/naturalElementDict.json")
characterDict = open_json("Final/characterAlignedFinal.json")

# %%
# function that detects plurals, 1) store them in a list of tuples in the format tup[0] = singular, tup [1] = plural, tup[2] = neutral form with (s)
# and 2) update the given dictionary, appending the previous values to the new key in the form "name(s)" and deleting the plural/singular forms
# suggestion: since the dictionary is directly modified, make a copy of it before running
# last point to be solved: shall we modify the link corresponding to the new form? eg. take only the singular, appending it only the first time? in any case the singular form is the first appended value
def detect_plurals(dictionary, plurals_list):
    keys = list(dictionary.keys())
    keys2 = []
    keys3 = []
    doubles = []
    final_dict = {}
    rec_words = list(filter(lambda x: 'rec' in x, keys)) # we select the keys for the recociled terms, to filter them out
    for term in keys: 
        if term not in rec_words:
            keys2.append(term) 
            keys3.append(term) # we create a duplicate list to copare terms to find similarities

    for key in keys3: 
        for key2 in keys2: 
            if key !=key2:
                if fuzz_ratio_mean(key, key2) > 85: # the plural "es" is 87
                    if set((key,key2)) not in doubles:
                        doubles.append(set((key,key2)))
    for s in doubles: 
        couple = tuple(s)
        if len(couple[0])> len(couple[1]): # as it is more frequent, we decide that the longer term is the plural form
            base_term = couple[1]
            plural_term = couple[0]
        elif len(couple[0])< len(couple[1]): 
            base_term = couple[0]
            plural_term = couple[1]
        difference = plural_term.replace(base_term, "")
        pl_addition = "("+str(difference)+")"
       # final_form = str(base_term)+pl_addition
        if difference == "s" or difference =="e" or difference =="es": # exeptions: woman(en), man(en), latin plurals (sacophagus. -i)
            plurals_list.append((base_term, plural_term))
        else: 
            print("not included in plurals: ", final_form)
                            
    for tup in plurals_list: 
        for term in dictionary.copy(): 
            if term == tup[0] or term == tup[1]: 
                if tup[2] not in dictionary: 
                    dictionary[tup[2]] = [dictionary[term]] # we assign the original value to the new key
                    dictionary[tup[2]+ " rec"] = dictionary[term+" rec"]
                else: 
                    if dictionary[term] not in dictionary[tup[2]]:
                        print(term, tup[2], dictionary[tup[2]])
                        dictionary[tup[2]].append(dictionary[term]) # in this case, the base dictionary have a str as value
                    for r in dictionary[term+ " rec"]: 
                        if r not in dictionary[tup[2]+ " rec"]: # the reconciliation may find the same term
                            dictionary[tup[2]+ " rec"].append(r)
                del dictionary[term]
                del dictionary[term+ " rec"]
                #if tup[2] not in final_dict: 
                 #   final_dict[tup[2]] = [dictionary[term]] # the base dictionary shoud already have list as a value
                #    final_dict[tup[2]+ " rec"] = dictionary[term+" rec"]
                #else: 
                #    if dictionary[term] not in final_dict[tup[2]]:
                 #       final_dict[tup[2]].append(dictionary[term]) # in this case, the base dictionary have a str as value
                 #   for r in dictionary[term+ " rec"]: 
                 #       if r not in final_dict[tup[2]+ " rec"]: # the reconciliation may find the same term
                 #           final_dict[tup[2]+ " rec"].append(r)
                 # we replace the singular/plural form with the new one to be reconciled
          #  else: 
           #     if not term == tup[0]+" rec" or term == tup[1]+" rec":
             #       final_dict[term] = dictionary[term] # we copy the items that have no plural
  #  print(plurals_list)
    print(dictionary)
    return dictionary

# test
d = {"cicci": "link", "cicci rec":["extLink"], "ciccis": "links", "ciccis rec": ["extLiks"]}
plu = []

dictionary = detect_plurals(d, plu)
# Out:
# ciccis cicci(s) ['link']
# {'cicci(s)': ['link', 'links'], 'cicci(s) rec': ['extLink', 'extLiks']}

# %%
not_fitted_plurals = []
not_fitted_plurals.append(("sarcophagus", "sarcophagi", "sarcophagus(i)"))
not_fitted_plurals.append(("woman", "women", "woman(women)"))
not_fitted_plurals.append(("man", "men", "man(men)"))
not_fitted_plurals.append(("ox", "oxen", "ox(oxen)"))
not_fitted_plurals.append(("wood", "woods", "wood(s)"))
not_fitted_plurals.append(("kid", "kids", "kid(s)"))
not_fitted_plurals.append(("child", "childdren", "child(dren)"))
not_fitted_plurals.append(("savage", "savages", "savage(s)"))

final = detect_plurals(naturalElementDict2, not_fitted_plurals)
# Out:
# not included in plurals:  acantus plant(acanthus plant)
# not included in plurals:  lance(ba)
# not included in plurals:  bear(d)
# not included in plurals:  ox(b)
# not included in plurals:  cart(chart)
# not included in plurals:  chariot(eer)
# not included in plurals:  child(ren)
# not included in plurals:  child(ren)
# not included in plurals:  cock(clock)
# not included in plurals:  convex lines(concave lines)
# not included in plurals:  lowest zone of the tomb(highest zone of the tomb)
# not included in plurals:  man face(wo)
# not included in plurals:  sarcophagi(sarcophagus)
# not included in plurals:  sea(t)
# not included in plurals:  shadowed face(shadowened face)
# not included in plurals:  statue of a man(statue of a woman)
# not included in plurals:  human figure with animal legs(human figures with animal legs)
# sarcophagus sarcophagus(i) ['http://icondataset.org/sarcophagi']
# women woman(women) ['http://icondataset.org/woman']
# men man(men) ['http://icondataset.org/man']
# oxen ox(oxen) ['http://icondataset.org/ox']
# {'abaci': 'http://icondataset.org/abaci', 'abaci rec': [], 'acanthus plant': 'http://icondataset.org/acanthus-plant', 'acanthus plant rec': [], 'altar': 'http://icondataset.org/altar', 'altar rec': [], 'altarpiece': 'http://icondataset.org/altarpiece', 'altarpiece rec': [], 'amoretti': 'http://icondataset.org/amoretti', 'amoretti rec': [], 'amphitheater': 'http://icondataset.org/amphitheater', 'amphitheater rec': [], 'amphora': 'http://icondataset.org/amphora', 'amphora rec': [], 'animals': 'http://icondataset.org/animals', 'animals rec': [], 'anklet with bells': 'http://icondataset.org/anklet-with-bells', 'anklet with bells rec': [], 'anteroom': 'http://icondataset.org/anteroom', 'anteroom rec': [], 'apple': 'http://icondataset.org/apple', 'apple rec': [], 'apse': 'http://icondataset.org/apse', 'apse rec': [], 'arch': 'http://icondataset.org/arch', 'arch rec': [], 'architecture': 'http://icondataset.org/architecture', 'architecture rec': [], 'aries': 'http://icondataset.org/aries', 'aries rec': [], 'armor': 'http://icondataset.org/armor', 'armor rec': [], 'arms lifted': 'http://icondataset.org/arms-lifted', 'arms lifted rec': [], 'arms lowered': 'http://icondataset.org/arms-lowered', 'arms lowered rec': [], 'baby': 'http://icondataset.org/baby', 'baby rec': [], 'bag': 'http://icondataset.org/bag', 'bag rec': [], 'balance': 'http://icondataset.org/balance', 'balance rec': [], 'balance of the arms': 'http://icondataset.org/balance-of-the-arms', 'balance of the arms rec': [], 'bald-headed': 'http://icondataset.org/bald-headed', 'bald-headed rec': [], 'band': 'http://icondataset.org/band', 'band rec': [], 'bandage': 'http://icondataset.org/bandage', 'bandage rec': [], 'barrel': 'http://icondataset.org/barrel', 'barrel rec': [], 'base with strigilated motif': 'http://icondataset.org/base-with-strigilated-motif', 'base with strigilated motif rec': [], 'basket with roses': 'http://icondataset.org/basket-with-roses', 'basket with roses rec': [], 'bat wings': 'http://icondataset.org/bat-wings', 'bat wings rec': [], 'bathing trunks': 'http://icondataset.org/bathing-trunks', 'bathing trunks rec': [], 'battle': 'http://icondataset.org/battle', 'battle rec': [], 'battling monsters': 'http://icondataset.org/battling-monsters', 'battling monsters rec': [], 'beams of light': 'http://icondataset.org/beams-of-light', 'beams of light rec': [], 'bear': 'http://icondataset.org/bear', 'bear rec': [], 'beard': 'http://icondataset.org/beard', 'beard rec': [], 'bed': 'http://icondataset.org/bed', 'bed rec': [], 'beggars': 'http://icondataset.org/beggars', 'beggars rec': [], 'belt': 'http://icondataset.org/belt', 'belt rec': [], 'belt of flowers': 'http://icondataset.org/belt-of-flowers', 'belt of flowers rec': [], 'biga': 'http://icondataset.org/biga', 'biga rec': [], 'bird': 'http://icondataset.org/bird', 'bird rec': [], 'birth chamber': 'http://icondataset.org/birth-chamber', 'birth chamber rec': [], 'bishop': 'http://icondataset.org/bishop', 'bishop rec': [], 'bitten apple': 'http://icondataset.org/bitten-apple', 'bitten apple rec': [], 'blacksmith': 'http://icondataset.org/blacksmith', 'blacksmith rec': [], 'block': 'http://icondataset.org/block', 'block rec': [], 'boar': 'http://icondataset.org/boar', 'boar rec': [], 'boats': 'http://icondataset.org/boats', 'boats rec': [], 'body covered with feathers': 'http://icondataset.org/body-covered-with-feathers', 'body covered with feathers rec': [], 'bones': 'http://icondataset.org/bones', 'bones rec': [], 'boots': 'http://icondataset.org/boots', 'boots rec': [], 'bow': 'http://icondataset.org/bow', 'bow rec': [], 'bowl of grapes': 'http://icondataset.org/bowl-of-grapes', 'bowl of grapes rec': [], 'bowls': 'http://icondataset.org/bowls', 'bowls rec': [], 'box': 'http://icondataset.org/box', 'box rec': [], 'boy': 'http://icondataset.org/boy', 'boy rec': [], 'branches': 'http://icondataset.org/branches', 'branches rec': [], 'broken string': 'http://icondataset.org/broken-string', 'broken string rec': [], ...

# %%
print(naturalElementDict2["man(men)"])
# Out:
# ['http://icondataset.org/man', 'http://icondataset.org/men']

# %%
print(fuzz_ratio_mean("child(dren)", "child")) # fuzz ratio should be >75
# Out:
# 79.75

# %%
# plurals of natural elements
#plurals_list = []
# print(characterDict3)
#characterDict4 = detect_plurals(characterDict3, plurals_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\SOFIAB~1\AppData\Local\Temp/ipykernel_6084/4263483868.py in <module>
#       3 # print(characterDict3)
#       4 #characterDict4 = detect_plurals(characterDict3, plurals_list)
# ----> 5 print(characterDict4["Angels rec"])
#
# KeyError: 'Angels rec'

# %% [markdown]
# ## Detection of synonyms through wordnet
# * there's a pyhon library for it: https://github.com/goodmami/wn usage documentation for another library: https://www.nltk.org/howto/wordnet.html
# * api documentation: https://wordnet.princeton.edu/related-projects
# * **a tutorial for ntlk wordnet usage**: https://pythonprogramming.net/wordnet-nltk-tutorial/
# * may be useful for alignment approaches: https://aclanthology.org/2020.lrec-1.597.pdf
#
# * Synset: a set of synonyms that share a common meaning.
# * conversion of wordnet to LOD: https://www.w3.org/community/bpmlod/wiki/Converting_WordNets_to_Linked_Data
# * other wordnet (3.0)search, with RDF format for each lemma: http://wordnet-rdf.princeton.edu/
# * **wordnet rdf official**: http://wordnet-rdf.princeton.edu/about
# * ontology: http://wordnet-rdf.princeton.edu/ontology.html
# * what is offset/8 digit: https://wordnet.princeton.edu/documentation/wndb5wn#:~:text=semantic%20concordance%20texts.-,synset_offset,syntactic%20category%2C%20a%20data%20structure%20containing%20the%20parsed%20synset%20is%20returned.,-Data%20File%20Format
# * how to extract RDF links: http://wordnet-rdf.princeton.edu/about#:~:text=the%20licensing%20information-,WordNet%20Identifiers,-Words%20are%20identified
#
# * NB: the offset numbers that we have with ntlk library are the ones of version 3.0 (not the last one), that are not in rdf but also in json. In the json there is the correspondance between the old key and the new one. If the number has 7 digits, you have to add a 0 at the beginning. problem: no full json file for all the terms

# %% [markdown]
# ### To do:
#
# 1. verify if the wordnet term is pertinent
# 2. verify if there are synonims used in the dataset
# 3. only for them, extract (with the method here) the numbers of the version 3.0, and then use it as a link (our word in the dataset skos:broader link wordnet 3.0). link example: http://wordnet-rdf.princeton.edu/pwn30/00001740-a

# %%
from nltk.corpus import wordnet as wn

# %%
syns = wn.synsets('dog') # result: list with synset(name)
# result: 'dog.n.01'
#print(syns)
#print(syns[0])
name = syns[0].name() # we obtain the name (ID) of the resource. 
print(name)
#print(wn.synset('dog.n.01').definition()) # ask for definition
dog = wn.synset('dog.n.01') # ask for hyperonyms
# s = syns[0]
#for l in syns[0].lemmas(): 
 #   print(s.name(),"-definition:", s.definition(),"-synonyms:", l.name()) # s, s.definition(),
# Out:
# dog.n.01

# %%
syns = wn.synsets('abacus')
offsets_list = [(s.offset(), s) for s in syns]
offsets_dict = dict(offsets_list)
print(offsets_dict)
# Out:
# {2666347: Synset('abacus.n.01'), 2666196: Synset('abacus.n.02')}

# %%
synset_offset
syns = wn.synsets('abacus')
offsets_list = [(s.synset_offset(), s) for s in syns]
print(offsets_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SOFIAB~1\AppData\Local\Temp/ipykernel_6084/3781727197.py in <module>
# ----> 1 synset_offset
#       2 syns = wn.synsets('abacus')
#       3 offsets_list = [(s.synset_offset(), s) for s in syns]
#       4 print(offsets_list)
#
# NameError: name 'synset_offset' is not defined

# %%
# code adapted from: https://www.holisticseo.digital/python-seo/nltk/wordnet
syn_dict = {}
def synonym_antonym_extractor(dictionary, syn_dict):
    syn_names = {}
    names_list = list(dictionary.keys())
    for name in names_list.copy(): 
        if name.endswith("rec"):
            names_list.remove(name)
    for n in names_list: 
    # from nltk.corpus import wordnet
        synonyms = []
        syn = wn.synsets(n) # it does already a world lookup, synonyms included
        if syn != []: 
            for l in syn[0].lemmas():
                synonyms.append(l.name())
               # print(syn[0].name(),"-definition:", syn[0].definition(),"-synonyms:", l.name())
            syn_dict[n] = synonyms 
            wname = syn[0].name().split(".")[0]
            if fuzz_ratio_mean(n, wname) <80 and n in synonyms: 
                syn_names[n] = syn[0].name() # wname
        
            print(n, syn[0].name(),"-definition:", syn[0].definition(),"-synonyms:", synonyms)
    # print(set(antonyms))
    return syn_names
natSynNames = synonym_antonym_extractor(naturalElementDict2, syn_dict)
# Out:
# abaci abacus.n.01 -definition: a tablet placed horizontally on top of the capital of a column as an aid in supporting the architrave -synonyms: ['abacus']
# altar altar.n.01 -definition: the table in Christian churches where communion is given -synonyms: ['altar', 'communion_table', "Lord's_table"]
# altarpiece altarpiece.n.01 -definition: a painted or carved screen placed above and behind an altar or communion table -synonyms: ['altarpiece', 'reredos']
# amphitheater amphitheater.n.01 -definition: a sloping gallery with seats for spectators (as in an operating room or theater) -synonyms: ['amphitheater', 'amphitheatre']
# amphora amphora.n.01 -definition: an ancient jar with two handles and a narrow neck; used to hold oil or wine -synonyms: ['amphora']
# animals animal.n.01 -definition: a living organism characterized by voluntary movement -synonyms: ['animal', 'animate_being', 'beast', 'brute', 'creature', 'fauna']
# anteroom anteroom.n.01 -definition: a large entrance or reception room or area -synonyms: ['anteroom', 'antechamber', 'entrance_hall', 'hall', 'foyer', 'lobby', 'vestibule']
# apple apple.n.01 -definition: fruit with red or yellow or green skin and sweet to tart crisp whitish flesh -synonyms: ['apple']
# apse apse.n.01 -definition: a domed or vaulted recess or projection on a building especially the east end of a church; usually contains the altar -synonyms: ['apse', 'apsis']
# arch arch.n.01 -definition: a curved shape in the vertical plane that spans an opening -synonyms: ['arch']
# architecture architecture.n.01 -definition: an architectural product or work -synonyms: ['architecture']
# aries aries.n.01 -definition: (astrology) a person who is born while the sun is in Aries -synonyms: ['Aries', 'Ram']
# armor armor.n.01 -definition: protective covering made of metal and used in combat -synonyms: ['armor', 'armour']
# baby baby.n.01 -definition: a very young child (birth to 1 year) who has not yet begun to walk or talk -synonyms: ['baby', 'babe', 'infant']
# bag bag.n.01 -definition: a flexible container with a single opening -synonyms: ['bag']
# balance balance.n.01 -definition: a state of equilibrium -synonyms: ['balance']
# bald-headed bald.s.02 -definition: lacking hair on all or most of the scalp -synonyms: ['bald', 'bald-headed', 'bald-pated']
# band set.n.05 -definition: an unofficial association of people or groups -synonyms: ['set', 'circle', 'band', 'lot']
# bandage bandage.n.01 -definition: a piece of soft material that covers and protects an injured part of the body -synonyms: ['bandage', 'patch']
# barrel barrel.n.01 -definition: a tube through which a bullet travels when a gun is fired -synonyms: ['barrel', 'gun_barrel']
# battle battle.n.01 -definition: a hostile meeting of opposing military forces in the course of a war -synonyms: ['battle', 'conflict', 'fight', 'engagement']
# bear bear.n.01 -definition: massive plantigrade carnivorous or omnivorous mammals with long shaggy coats and strong claws -synonyms: ['bear']
# beard beard.n.01 -definition: the hair growing on the lower part of a man's face -synonyms: ['beard', 'face_fungus', 'whiskers']
# bed bed.n.01 -definition: a piece of furniture that provides a place to sleep -synonyms: ['bed']
# beggars beggar.n.01 -definition: a pauper who lives by begging -synonyms: ['beggar', 'mendicant']
# belt belt.n.01 -definition: endless loop of flexible material between two rotating shafts or pulleys -synonyms: ['belt']
# bird bird.n.01 -definition: warm-blooded egg-laying vertebrates characterized by feathers and forelimbs modified as wings -synonyms: ['bird']
# bishop bishop.n.01 -definition: a senior member of the Christian clergy having spiritual and administrative authority; appointed in Christian churches to oversee priests or ministers; considered in some churches to be successors of the twelve Apostles of Christ -synonyms: ['bishop']
# blacksmith blacksmith.n.01 -definition: a smith who forges and shapes iron with a hammer and anvil -synonyms: ['blacksmith']
# block block.n.01 -definition: a solid piece of something (usually having flat rectangular sides) -synonyms: ['block']
# boar wild_boar.n.01 -definition: Old World wild swine having a narrow body and prominent tusks from which most domestic swine come; introduced in United States -synonyms: ['wild_boar', 'boar', 'Sus_scrofa']
# boats boat.n.01 -definition: a small vessel for travel on water -synonyms: ['boat']
# bones bones.n.01 -definition: a percussion instrument consisting of a pair of hollow pieces of wood or bone (usually held between the thumb and fingers) that are made to click together (as by Spanish dancers) in rhythm with the dance -synonyms: ['bones', 'castanets', 'clappers', 'finger_cymbals']
# boots boot.n.01 -definition: footwear that covers the whole foot and lower leg -synonyms: ['boot']
# bow bow.n.01 -definition: a knot with two loops and loose ends; used to tie shoelaces -synonyms: ['bow', 'bowknot']
# bowls lawn_bowling.n.01 -definition: a bowling game played on a level lawn with biased wooden balls that are rolled at a jack -synonyms: ['lawn_bowling', 'bowls']
# box box.n.01 -definition: a (usually rectangular) container; may have a lid -synonyms: ['box']
# boy male_child.n.01 -definition: a youthful male person -synonyms: ['male_child', 'boy']
# branches branch.n.01 -definition: a division of some larger or more complex organization -synonyms: ['branch', 'subdivision', 'arm']
# bull bull.n.01 -definition: uncastrated adult male of domestic cattle -synonyms: ['bull']
# camel camel.n.01 -definition: cud-chewing mammal used as a draft or saddle animal in desert regions -synonyms: ['camel']
# cameo cameo.n.01 -definition: engraving or carving in low relief on a stone (as in a brooch or ring) -synonyms: ['cameo']
# capitals capital.n.01 -definition: assets available for use in the production of further assets -synonyms: ['capital', 'working_capital']
# carcass carcase.n.01 -definition: the dead body of an animal especially one slaughtered and dressed for food -synonyms: ['carcase', 'carcass']
# cart cart.n.01 -definition: a heavy open wagon usually having two wheels and drawn by an animal -synonyms: ['cart']
# catafalque catafalque.n.01 -definition: a decorated bier on which a coffin rests in state during a funeral -synonyms: ['catafalque']
# ceiling ceiling.n.01 -definition: the overhead upper surface of a covered space -synonyms: ['ceiling']
# chains irons.n.01 -definition: metal shackles; for hands or legs -synonyms: ['irons', 'chains']
# chalice chalice.n.01 -definition: a bowl-shaped drinking vessel; especially the Eucharistic cup -synonyms: ['chalice', 'goblet']
# charger charger.n.01 -definition: formerly a strong swift horse ridden into battle -synonyms: ['charger', 'courser']
# chariot chariot.n.01 -definition: a light four-wheel horse-drawn ceremonial carriage -synonyms: ['chariot']
# charioteer charioteer.n.01 -definition: the driver of a chariot -synonyms: ['charioteer']
# chart chart.n.01 -definition: a visual display of information -synonyms: ['chart']
# chest thorax.n.02 -definition: the part of the human torso between the neck and the diaphragm or the corresponding part in other vertebrates -synonyms: ['thorax', 'chest', 'pectus']
# children child.n.01 -definition: a young person of either sex -synonyms: ['child', 'kid', 'youngster', 'minor', 'shaver', 'nipper', 'small_fry', 'tiddler', 'tike', 'tyke', 'fry', 'nestling']
# chlamys perianth.n.01 -definition: collective term for the outer parts of a flower consisting of the calyx and corolla and enclosing the stamens and pistils -synonyms: ['perianth', 'chlamys', 'floral_envelope', 'perigone', 'perigonium']
# choir choir.n.01 -definition: a chorus that sings as part of a religious ceremony -synonyms: ['choir']
# church church.n.01 -definition: one of the groups of Christians who have their own beliefs and forms of worship -synonyms: ['church', 'Christian_church']
# circle circle.n.01 -definition: ellipse in which the two axes are of equal length; a plane curve generated by one point moving at a constant distance from a fixed point -synonyms: ['circle']
# city city.n.01 -definition: a large and densely populated urban area; may include several independent administrative districts -synonyms: ['city', 'metropolis', 'urban_center']
# cleric cleric.n.01 -definition: a clergyman or other person in religious orders -synonyms: ['cleric', 'churchman', 'divine', 'ecclesiastic']
# cloak cloak.n.01 -definition: anything that covers or conceals -synonyms: ['cloak']
# clock clock.n.01 -definition: a timepiece that shows the time of day -synonyms: ['clock']
# clouds cloud.n.01 -definition: any collection of particles (e.g., smoke or dust) or gases that is visible -synonyms: ['cloud']
# coat coat.n.01 -definition: an outer garment that has sleeves and covers the body from shoulder down; worn outdoors -synonyms: ['coat']
# cock cock.n.01 -definition: obscene terms for penis -synonyms: ['cock', 'prick', 'dick', 'shaft', 'pecker', 'peter', 'tool', 'putz']
# coins coin.n.01 -definition: a flat metal piece (usually a disc) used as money -synonyms: ['coin']
# cornice cornice.n.01 -definition: a decorative framework to conceal curtain fixtures at the top of a window casing -synonyms: ['cornice', 'valance', 'valance_board', 'pelmet']
# cornucopia horn_of_plenty.n.01 -definition: a goat's horn filled with grain and flowers and fruit symbolizing prosperity -synonyms: ['horn_of_plenty', 'cornucopia']
# criminals criminal.n.01 -definition: someone who has committed a crime or has been legally convicted of a crime -synonyms: ['criminal', 'felon', 'crook', 'outlaw', 'malefactor']
# cripples cripple.n.01 -definition: someone who is unable to walk normally because of an injury or disability to the legs or back -synonyms: ['cripple']
# crosier crosier.n.01 -definition: a staff surmounted by a crook or cross carried by bishops as a symbol of pastoral office -synonyms: ['crosier', 'crozier']
# cross cross.n.01 -definition: a wooden structure consisting of an upright post with a transverse piece -synonyms: ['cross']
# crown crown.n.01 -definition: the Crown (or the reigning monarch) as the symbol of the power and authority of a monarchy -synonyms: ['Crown']
# crucifix crucifix.n.01 -definition: representation of the cross on which Jesus died -synonyms: ['crucifix', 'rood', 'rood-tree']
# crunch crunch.n.01 -definition: the sound of something crunching -synonyms: ['crunch']
# cudgels cudgel.n.01 -definition: a club that is used as a weapon -synonyms: ['cudgel']
# cup cup.n.01 -definition: a small open container usually used for drinking; usually has a handle -synonyms: ['cup']
# cupboard cupboard.n.01 -definition: a small room (or recess) or cabinet used for storage space -synonyms: ['cupboard', 'closet']
# curls coil.n.02 -definition: a round shape formed by a series of concentric circles (as formed by leaves or flower petals) -synonyms: ['coil', 'whorl', 'roll', 'curl', 'curlicue', 'ringlet', 'gyre', 'scroll']
# curtain curtain.n.01 -definition: hanging cloth used as a blind (especially for a window) -synonyms: ['curtain', 'drape', 'drapery', 'mantle', 'pall']
# cymbals cymbal.n.01 -definition: a percussion instrument consisting of a concave brass disk; makes a loud crashing sound when hit with a drumstick or when two are struck together -synonyms: ['cymbal']
# dais dais.n.01 -definition: a platform raised above the surrounding level to give prominence to the person on it -synonyms: ['dais', 'podium', 'pulpit', 'rostrum', 'ambo', 'stump', 'soapbox']
# deer deer.n.01 -definition: distinguished from Bovidae by the male's having solid deciduous antlers -synonyms: ['deer', 'cervid']
# demon devil.n.02 -definition: an evil supernatural being -synonyms: ['devil', 'fiend', 'demon', 'daemon', 'daimon']
# desk desk.n.01 -definition: a piece of furniture with a writing surface and usually drawers or other compartments -synonyms: ['desk']
# donkey donkey.n.01 -definition: the symbol of the Democratic Party; introduced in cartoons by Thomas Nast in 1874 -synonyms: ['donkey']
# dragoon dragoon.n.01 -definition: a member of a European military unit formerly composed of heavily armed cavalrymen -synonyms: ['dragoon']
# drapery curtain.n.01 -definition: hanging cloth used as a blind (especially for a window) -synonyms: ['curtain', 'drape', 'drapery', 'mantle', 'pall']
# eagle eagle.n.01 -definition: any of various large keen-sighted diurnal birds of prey noted for their broad wings and strong soaring flight -synonyms: ['eagle', 'bird_of_Jove']
# earrings earring.n.01 -definition: jewelry to ornament the ear; usually clipped to the earlobe or fastened through a hole in the lobe -synonyms: ['earring']
# earth earth.n.01 -definition: the 3rd planet from the sun; the planet we live on -synonyms: ['Earth', 'earth', 'world', 'globe']
# entablature entablature.n.01 -definition: (architecture) the structure consisting of the part of a classical temple above the columns between a capital and the roof -synonyms: ['entablature']
# equator equator.n.01 -definition: an imaginary line around the Earth forming the great circle that is equidistant from the north and south poles -synonyms: ['equator']
# eyes eyes.n.01 -definition: opinion or judgment -synonyms: ['eyes']
# face face.n.01 -definition: the front of the human head from the forehead to the chin and ear to ear -synonyms: ['face', 'human_face']
# family family.n.01 -definition: a social unit living together -synonyms: ['family', 'household', 'house', 'home', 'menage']
# feathers feather.n.01 -definition: the light horny waterproof structure forming the external covering of birds -synonyms: ['feather', 'plume', 'plumage']
# feet foot.n.01 -definition: the part of the leg of a human being below the ankle joint -synonyms: ['foot', 'human_foot', 'pes']
# fire fire.n.01 -definition: the event of something burning (often destructive) -synonyms: ['fire']
# flag flag.n.01 -definition: emblem usually consisting of a rectangular piece of cloth of distinctive design -synonyms: ['flag']
# flames fire.n.03 -definition: the process of combustion of inflammable materials producing heat and light and (often) smoke -synonyms: ['fire', 'flame', 'flaming']
# flies flies.n.01 -definition: (theater) the space over the stage (out of view of the audience) used to store scenery (drop curtains) -synonyms: ['flies']
# floor floor.n.01 -definition: the inside lower horizontal surface (as of a room, hallway, tent, or other structure) -synonyms: ['floor', 'flooring']
# flowers flower.n.01 -definition: a plant cultivated for its blooms or blossoms -synonyms: ['flower']
# flute flute.n.01 -definition: a high-pitched woodwind instrument; a slender tube closed at one end with finger holes on one end and an opening near the closed end across which the breath is blown -synonyms: ['flute', 'transverse_flute']
# fly fly.n.01 -definition: two-winged insects characterized by active flight -synonyms: ['fly']
# forelock forelock.n.01 -definition: a lock of hair growing (or falling) over the forehead -synonyms: ['forelock']
# forest forest.n.01 -definition: the trees and other plants in a large densely wooded area -synonyms: ['forest', 'wood', 'woods']
# fountain fountain.n.01 -definition: a structure from which an artificially produced jet of water arises -synonyms: ['fountain']
# gale gale.n.01 -definition: a strong wind moving 45-90 knots; force 7 to 10 on Beaufort scale -synonyms: ['gale']
# garlands garland.n.01 -definition: United States singer and film actress (1922-1969) -synonyms: ['Garland', 'Judy_Garland']
# gentleman gentleman.n.01 -definition: a man of refinement -synonyms: ['gentleman']
# giraffe giraffe.n.01 -definition: tallest living quadruped; having a spotted coat and small horns and very long neck and legs; of savannahs of tropical Africa -synonyms: ['giraffe', 'camelopard', 'Giraffa_camelopardalis']
# glasses spectacles.n.01 -definition: optical instrument consisting of a frame that holds a pair of lenses for correcting defective vision -synonyms: ['spectacles', 'specs', 'eyeglasses', 'glasses']
# globe earth.n.01 -definition: the 3rd planet from the sun; the planet we live on -synonyms: ['Earth', 'earth', 'world', 'globe']
# gloves baseball_glove.n.01 -definition: the handwear used by fielders in playing baseball -synonyms: ['baseball_glove', 'glove', 'baseball_mitt', 'mitt']
# goat goat.n.01 -definition: any of numerous agile ruminants related to sheep but having a beard and straight horns -synonyms: ['goat', 'caprine_animal']
# goblet goblet.n.01 -definition: a drinking glass with a base and stem -synonyms: ['goblet']
# goddess goddess.n.01 -definition: a female deity -synonyms: ['goddess']
# gown gown.n.01 -definition: a woman's dress, usually with a close-fitting bodice and a long flared skirt, often worn on formal occasions -synonyms: ['gown']
# grape grape.n.01 -definition: any of various juicy fruit of the genus Vitis with green or purple skins; grow in clusters -synonyms: ['grape']
# graters grater.n.01 -definition: utensil with sharp perforations for shredding foods (as vegetables or cheese) -synonyms: ['grater']
# ground land.n.04 -definition: the solid part of the earth's surface -synonyms: ['land', 'dry_land', 'earth', 'ground', 'solid_ground', 'terra_firma']
# hair hair.n.01 -definition: a covering for the body (or parts of it) consisting of a dense growth of threadlike structures (as on the human head); helps to prevent heat loss -synonyms: ['hair']
# halo aura.n.02 -definition: an indication of radiant light drawn around the head of a saint -synonyms: ['aura', 'aureole', 'halo', 'nimbus', 'glory', 'gloriole']
# hand hand.n.01 -definition: the (prehensile) extremity of the superior limb -synonyms: ['hand', 'manus', 'mitt', 'paw']
# hanging hanging.n.01 -definition: decoration that is hung (as a tapestry) on a wall or over a window -synonyms: ['hanging', 'wall_hanging']
# hares hare.n.01 -definition: swift timid long-eared mammal larger than a rabbit having a divided upper lip and long hind legs; young born furred and with open eyes -synonyms: ['hare']
# hat hat.n.01 -definition: headdress that protects the head from bad weather; has shaped crown and usually a brim -synonyms: ['hat', 'chapeau', 'lid']
# headdress headdress.n.01 -definition: clothing for the head -synonyms: ['headdress', 'headgear']
# hearts hearts.n.01 -definition: a form of whist in which players avoid winning tricks containing hearts or the queen of spades -synonyms: ['hearts', 'Black_Maria']
# helmet helmet.n.01 -definition: armor plate that protects the head -synonyms: ['helmet']
# hides hide.n.01 -definition: the dressed skin of an animal (especially a large animal) -synonyms: ['hide', 'fell']
# hills hill.n.01 -definition: a local and well-defined elevation of the land -synonyms: ['hill']
# honeycomb honeycomb.n.01 -definition: a structure of small hexagonal cells constructed from beeswax by bees and used to store honey and larvae -synonyms: ['honeycomb']
# horseman horseman.n.01 -definition: a man skilled in equitation -synonyms: ['horseman', 'equestrian', 'horseback_rider']
# horseshoe horseshoe.n.01 -definition: game equipment consisting of an open ring of iron used in playing horseshoes -synonyms: ['horseshoe']
# hourglass hourglass.n.01 -definition: a sandglass that runs for sixty minutes -synonyms: ['hourglass']
# human homo.n.02 -definition: any living or extinct member of the family Hominidae characterized by superior intelligence, articulate speech, and erect carriage -synonyms: ['homo', 'man', 'human_being', 'human']
# hut hut.n.01 -definition: temporary military shelter -synonyms: ['hut', 'army_hut', 'field_hut']
# ibis ibis.n.01 -definition: wading birds of warm regions having long slender down-curved bills -synonyms: ['ibis']
# idol idol.n.01 -definition: a material effigy that is worshipped -synonyms: ['idol', 'graven_image', 'god']
# inscription inscription.n.01 -definition: letters inscribed (especially words engraved or carved) on something -synonyms: ['inscription', 'lettering']
# ivy ivy.n.01 -definition: Old World vine with lobed evergreen leaves and black berrylike fruits -synonyms: ['ivy', 'common_ivy', 'English_ivy', 'Hedera_helix']
# jar jar.n.01 -definition: a vessel (usually cylindrical) with a wide mouth and without handles -synonyms: ['jar']
# journeyman craftsman.n.03 -definition: a skilled worker who practices some trade or handicraft -synonyms: ['craftsman', 'artisan', 'journeyman', 'artificer']
# kettle kettle.n.01 -definition: a metal pot for stewing or boiling; usually has a lid -synonyms: ['kettle', 'boiler']
# king king.n.01 -definition: a male sovereign; ruler of a kingdom -synonyms: ['king', 'male_monarch', 'Rex']
# kitchen kitchen.n.01 -definition: a room equipped for preparing meals -synonyms: ['kitchen']
# knapsack backpack.n.01 -definition: a bag carried by a strap on your back or shoulder -synonyms: ['backpack', 'back_pack', 'knapsack', 'packsack', 'rucksack', 'haversack']
# ladles ladle.n.01 -definition: a spoon-shaped vessel with a long handle; frequently used to transfer liquids from one container to another -synonyms: ['ladle']
# lady lady.n.01 -definition: a polite name for any woman -synonyms: ['lady']
# lance spear.n.01 -definition: a long pointed rod used as a tool or weapon -synonyms: ['spear', 'lance', 'shaft']
# lantern lantern.n.01 -definition: light in a transparent protective case -synonyms: ['lantern']
# lappets wattle.n.01 -definition: a fleshy wrinkled and often brightly colored fold of skin hanging from the neck or throat of certain birds (chickens and turkeys) or lizards -synonyms: ['wattle', 'lappet']
# lawns lawn.n.01 -definition: a field of cultivated and mowed grass -synonyms: ['lawn']
# leash leash.n.01 -definition: restraint consisting of a rope (or light chain) used to restrain an animal -synonyms: ['leash', 'tether', 'lead']
# lilies lily.n.01 -definition: any liliaceous plant of the genus Lilium having showy pendulous flowers -synonyms: ['lily']
# lilium lilium.n.01 -definition: type genus of Liliaceae -synonyms: ['Lilium', 'genus_Lilium']
# liver liver.n.01 -definition: large and complicated reddish-brown glandular organ located in the upper right portion of the abdominal cavity; secretes bile and functions in metabolism of protein and carbohydrate and fat; synthesizes substances involved in the clotting of the blood; synthesizes vitamin A; detoxifies poisonous substances and breaks down worn-out erythrocytes -synonyms: ['liver']
# logs log.n.01 -definition: a segment of the trunk of a tree when stripped of branches -synonyms: ['log']
# lovers lover.n.01 -definition: a person who loves someone or is loved by someone -synonyms: ['lover']
# lunette lunette.n.01 -definition: temporary fortification like a detached bastion -synonyms: ['lunette']
# lyre lyre.n.01 -definition: a harp used by ancient Greeks for accompaniment -synonyms: ['lyre']
# mahlstick maulstick.n.01 -definition: a long stick that a painter uses to support the hand holding the brush -synonyms: ['maulstick', 'mahlstick']
# maiden maid.n.02 -definition: an unmarried girl (especially a virgin) -synonyms: ['maid', 'maiden']
# mantle mantle.n.01 -definition: the cloak as a symbol of authority -synonyms: ['mantle']
# masks mask.n.01 -definition: a covering to disguise or conceal the face -synonyms: ['mask']
# medallions medallion.n.01 -definition: any of various large ancient Greek coins -synonyms: ['medallion']
# merchant merchant.n.01 -definition: a businessperson engaged in retail trade -synonyms: ['merchant', 'merchandiser']
# mermaids mermaid.n.01 -definition: half woman and half fish; lives in the sea -synonyms: ['mermaid']
# mirror mirror.n.01 -definition: polished surface that forms images by reflecting light -synonyms: ['mirror']
# mist mist.n.01 -definition: a thin fog with condensation near the ground -synonyms: ['mist']
# monk monk.n.01 -definition: a male religious living in a cloister and devoting himself to contemplation and prayer and work -synonyms: ['monk', 'monastic']
# monument memorial.n.03 -definition: a structure erected to commemorate persons or events -synonyms: ['memorial', 'monument']
# mourners mourner.n.01 -definition: a person who is feeling grief (as grieving over someone who has died) -synonyms: ['mourner', 'griever', 'sorrower', 'lamenter']
# mouse mouse.n.01 -definition: any of numerous small rodents typically resembling diminutive rats having pointed snouts and small ears on elongated bodies with slender usually hairless tails -synonyms: ['mouse']
# mud mud.n.01 -definition: water soaked soil; soft wet earth -synonyms: ['mud', 'clay']
# mule mule.n.01 -definition: hybrid offspring of a male donkey and a female horse; usually sterile -synonyms: ['mule']
# muscles muscle.n.01 -definition: one of the contractile organs of the body -synonyms: ['muscle', 'musculus']
# myrtle myrtle.n.01 -definition: widely cultivated as a groundcover for its dark green shiny leaves and usually blue-violet flowers -synonyms: ['myrtle', 'Vinca_minor']
# nails nail.n.01 -definition: horny plate covering and protecting part of the dorsal surface of the digits -synonyms: ['nail']
# network network.n.01 -definition: an interconnected system of things or people -synonyms: ['network', 'web']
# nosegay bouquet.n.01 -definition: an arrangement of flowers that is usually given as a present -synonyms: ['bouquet', 'corsage', 'posy', 'nosegay']
# obelisk obelisk.n.01 -definition: a stone pillar having a rectangular cross section tapering towards a pyramidal top -synonyms: ['obelisk']
# onions onion.n.01 -definition: the bulb of an onion plant -synonyms: ['onion']
# outdoors outdoors.n.01 -definition: where the air is unconfined -synonyms: ['outdoors', 'out-of-doors', 'open_air', 'open']
# owl owl.n.01 -definition: nocturnal bird of prey with hawk-like beak and claws and large head with front-facing eyes -synonyms: ['owl', 'bird_of_Minerva', 'bird_of_night', 'hooter']
# painter painter.n.01 -definition: an artist who paints -synonyms: ['painter']
# painting painting.n.01 -definition: graphic art consisting of an artistic composition made by applying paints to a surface -synonyms: ['painting', 'picture']
# palette palette.n.01 -definition: the range of colour characteristic of a particular artist or painting or school of art -synonyms: ['palette', 'pallet']
# pans pan.n.01 -definition: cooking utensil consisting of a wide metal vessel -synonyms: ['pan', 'cooking_pan']
# parapet parapet.n.01 -definition: a low wall along the edge of a roof or balcony -synonyms: ['parapet']
# pavement pavement.n.01 -definition: the paved surface of a thoroughfare -synonyms: ['pavement', 'paving']
# peacock peacock.n.01 -definition: European butterfly having reddish-brown wings each marked with a purple eyespot -synonyms: ['peacock', 'peacock_butterfly', 'Inachis_io']
# peasants peasant.n.01 -definition: a country person -synonyms: ['peasant', 'provincial', 'bucolic']
# pedestals base.n.08 -definition: a support or foundation -synonyms: ['base', 'pedestal', 'stand']
# pediment pediment.n.01 -definition: a triangular gable between a horizontal entablature and a sloping roof -synonyms: ['pediment']
# people people.n.01 -definition: (plural) any group of human beings (men or women or children) collectively -synonyms: ['people']
# person person.n.01 -definition: a human being -synonyms: ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul']
# philosophers philosopher.n.01 -definition: a specialist in philosophy -synonyms: ['philosopher']
# pig hog.n.03 -definition: domestic swine -synonyms: ['hog', 'pig', 'grunter', 'squealer', 'Sus_scrofa']
# pilasters pilaster.n.01 -definition: a rectangular column that usually projects about a third of its width from the wall to which it is attached -synonyms: ['pilaster']
# pillow pillow.n.01 -definition: a cushion to support the head of a sleeping person -synonyms: ['pillow']
# pinnacles pinnacle.n.01 -definition: (architecture) a slender upright spire at the top of a buttress of tower -synonyms: ['pinnacle']
# platter platter.n.01 -definition: a large shallow dish used for serving food -synonyms: ['platter']
# portal portal.n.01 -definition: a grand and imposing entrance (often extended metaphorically) -synonyms: ['portal']
# portrait portrayal.n.01 -definition: a word picture of a person's appearance and character -synonyms: ['portrayal', 'portraiture', 'portrait']
# pots pot.n.01 -definition: metal or earthenware cooking vessel that is usually round and deep; often has a handle and lid -synonyms: ['pot']
# prince prince.n.01 -definition: a male member of a royal family other than the sovereign (especially the son of a sovereign) -synonyms: ['prince']
# prisms prism.n.01 -definition: a polyhedron with two congruent and parallel faces (the bases) and whose lateral faces are parallelograms -synonyms: ['prism']
# prisoners prisoner.n.01 -definition: a person who is confined; especially a prisoner of war -synonyms: ['prisoner', 'captive']
# procession emanation.n.03 -definition: (theology) the origination of the Holy Spirit at Pentecost -synonyms: ['emanation', 'rise', 'procession']
# pupil student.n.01 -definition: a learner who is enrolled in an educational institution -synonyms: ['student', 'pupil', 'educatee']
# purse bag.n.04 -definition: a container used for carrying money and small personal items or accessories (especially by women) -synonyms: ['bag', 'handbag', 'pocketbook', 'purse']
# rafts tons.n.01 -definition: a large number or amount -synonyms: ['tons', 'dozens', 'heaps', 'lots', 'piles', 'scores', 'stacks', 'loads', 'rafts', 'slews', 'wads', 'oodles', 'gobs', 'scads', 'lashings']
# rainbow rainbow.n.01 -definition: an arc of colored light in the sky caused by refraction of the sun's rays by rain -synonyms: ['rainbow']
# ram random-access_memory.n.01 -definition: the most common computer memory which can be used by programs to perform necessary tasks while the computer is on; an integrated circuit memory chip allows information to be stored or accessed in any order and all storage locations are equally accessible -synonyms: ['random-access_memory', 'random_access_memory', 'random_memory', 'RAM', 'read/write_memory']
# rat rat.n.01 -definition: any of various long-tailed rodents similar to but larger than a mouse -synonyms: ['rat']
# ribbon ribbon.n.01 -definition: any long object resembling a thin line -synonyms: ['ribbon', 'thread']
# river river.n.01 -definition: a large natural stream of water (larger than a creek) -synonyms: ['river']
# rock rock.n.01 -definition: a lump or mass of hard consolidated mineral matter -synonyms: ['rock', 'stone']
# rod rod.n.01 -definition: a long thin implement made of metal or wood -synonyms: ['rod']
# roundel roundel.n.01 -definition: English form of rondeau having three triplets with a refrain after the first and third -synonyms: ['roundel']
# ruins ruin.n.01 -definition: an irrecoverable state of devastation and destruction -synonyms: ['ruin', 'ruination']
# sceptre scepter.n.01 -definition: the imperial authority symbolized by a scepter -synonyms: ['scepter', 'sceptre']
# scimitar scimitar.n.01 -definition: a curved oriental saber; the edge is on the convex side of the blade -synonyms: ['scimitar']
# scourge scourge.n.01 -definition: a whip used to inflict punishment (often used for pedantic humor) -synonyms: ['scourge', 'flagellum']
# scroll coil.n.02 -definition: a round shape formed by a series of concentric circles (as formed by leaves or flower petals) -synonyms: ['coil', 'whorl', 'roll', 'curl', 'curlicue', 'ringlet', 'gyre', 'scroll']
# scythe scythe.n.01 -definition: an edge tool for cutting grass; has a long handle that must be held with both hands and a curved blade that moves parallel to the ground -synonyms: ['scythe']
# sea sea.n.01 -definition: a division of an ocean or a large body of salt water partially enclosed by land -synonyms: ['sea']
# seashell seashell.n.01 -definition: the shell of a marine organism -synonyms: ['seashell']
# seat seat.n.01 -definition: a space reserved for sitting (as in a theater or on a train or airplane) -synonyms: ['seat', 'place']
# servants servant.n.01 -definition: a person working in the service of another (especially in the household) -synonyms: ['servant', 'retainer']
# sheep sheep.n.01 -definition: woolly usually horned ruminant mammal related to the goat -synonyms: ['sheep']
# shepherdess shepherdess.n.01 -definition: a woman shepherd -synonyms: ['shepherdess']
# shield shield.n.01 -definition: a protective covering or structure -synonyms: ['shield']
# shipwreck shipwreck.n.01 -definition: a wrecked ship (or a part of one) -synonyms: ['shipwreck']
# shovels shovel.n.01 -definition: a hand tool for lifting loose material; consists of a curved container or scoop and a handle -synonyms: ['shovel']
# sickle sickle.n.01 -definition: an edge tool for cutting grass or crops; has a curved blade and a short handle -synonyms: ['sickle', 'reaping_hook', 'reap_hook']
# skeleton skeleton.n.01 -definition: something reduced to its minimal form -synonyms: ['skeleton']
# skins skin.n.01 -definition: a natural protective body covering and site of the sense of touch -synonyms: ['skin', 'tegument', 'cutis']
# skullcap skullcap.n.01 -definition: rounded brimless cap fitting the crown of the head -synonyms: ['skullcap']
# sky sky.n.01 -definition: the atmosphere and outer space as viewed from the earth -synonyms: ['sky']
# slate slate.n.01 -definition: (formerly) a writing tablet made of slate -synonyms: ['slate']
# slave slave.n.01 -definition: a person who is owned by someone -synonyms: ['slave']
# snake snake.n.01 -definition: limbless scaly elongate reptile; some are venomous -synonyms: ['snake', 'serpent', 'ophidian']
# space space.n.01 -definition: the unlimited expanse in which everything is located -synonyms: ['space', 'infinite']
# spade spade.n.01 -definition: a playing card in the major suit that has one or more black figures on it -synonyms: ['spade']
# spear spear.n.01 -definition: a long pointed rod used as a tool or weapon -synonyms: ['spear', 'lance', 'shaft']
# sphinx sphinx.n.01 -definition: an inscrutable person who keeps his thoughts and intentions secret -synonyms: ['sphinx']
# spiral spiral.n.01 -definition: a plane curve traced by a point circling about the center but at increasing distances from the center -synonyms: ['spiral']
# staff staff.n.01 -definition: personnel who assist their superior in carrying out an assigned task -synonyms: ['staff']
# stake interest.n.05 -definition: (law) a right or legal share of something; a financial involvement with something -synonyms: ['interest', 'stake']
# statuette figurine.n.01 -definition: a small carved or molded figure -synonyms: ['figurine', 'statuette']
# stick stick.n.01 -definition: an implement consisting of a length of wood -synonyms: ['stick']
# stone rock.n.01 -definition: a lump or mass of hard consolidated mineral matter -synonyms: ['rock', 'stone']
# storm storm.n.01 -definition: a violent weather condition with winds 64-72 knots (11 on the Beaufort scale) and precipitation and thunder and lightning -synonyms: ['storm', 'violent_storm']
# stove stove.n.01 -definition: a kitchen appliance used for cooking food -synonyms: ['stove', 'kitchen_stove', 'range', 'kitchen_range', 'cooking_stove']
# sun sun.n.01 -definition: the star that is the source of light and heat for the planets in the solar system -synonyms: ['sun', 'Sun']
# swan swan.n.01 -definition: stately heavy-bodied aquatic bird with very long neck and usually white plumage as adult -synonyms: ['swan']
# sword sword.n.01 -definition: a cutting or thrusting weapon that has a long metal blade and a hilt with a hand guard -synonyms: ['sword', 'blade', 'brand', 'steel']
# syrinx panpipe.n.01 -definition: a primitive wind instrument consisting of several parallel pipes bound together -synonyms: ['panpipe', 'pandean_pipe', 'syrinx']
# tabernacle tabernacle.n.01 -definition: the Mormon temple -synonyms: ['Tabernacle', 'Mormon_Tabernacle']
# table table.n.01 -definition: a set of data arranged in rows and columns -synonyms: ['table', 'tabular_array']
# talons talon.n.01 -definition: a sharp hooked claw especially on a bird of prey -synonyms: ['talon']
# target target.n.01 -definition: a reference point to shoot at -synonyms: ['target', 'mark']
# teacher teacher.n.01 -definition: a person whose occupation is teaching -synonyms: ['teacher', 'instructor']
# temple temple.n.01 -definition: place of worship consisting of an edifice for the worship of a deity -synonyms: ['temple']
# throne throne.n.01 -definition: the chair of state for a monarch, bishop, etc. -synonyms: ['throne']
# thunderbolts thunderbolt.n.01 -definition: a discharge of lightning accompanied by thunder -synonyms: ['thunderbolt', 'bolt', 'bolt_of_lightning']
# tiara tiara.n.01 -definition: a jeweled headdress worn by women on formal occasions -synonyms: ['tiara']
# toga toga.n.01 -definition: a one-piece cloak worn by men in ancient Rome -synonyms: ['toga']
# tombs grave.n.02 -definition: a place for the burial of a corpse (especially beneath the ground and marked by a tombstone) -synonyms: ['grave', 'tomb']
# tombstone gravestone.n.01 -definition: a stone that is used to mark a grave -synonyms: ['gravestone', 'headstone', 'tombstone']
# tongs tongs.n.01 -definition: any of various devices for taking hold of objects; usually have two hinged legs with handles above and pointed hooks below -synonyms: ['tongs', 'pair_of_tongs']
# tower tower.n.01 -definition: a structure taller than its diameter; can stand alone or be attached to a larger building -synonyms: ['tower']
# tracery tracery.n.01 -definition: decoration consisting of an open pattern of interlacing ribs -synonyms: ['tracery']
# trident trident.n.01 -definition: a spear with three prongs -synonyms: ['trident']
# trophies trophy.n.01 -definition: an award for success in war or hunting -synonyms: ['trophy']
# trumpet cornet.n.01 -definition: a brass musical instrument with a brilliant tone; has a narrow tube and a flared bell and is played by means of valves -synonyms: ['cornet', 'horn', 'trumpet', 'trump']
# trunk trunk.n.01 -definition: the main stem of a tree; usually covered with bark; the bole is usually the part that is commercially useful for lumber -synonyms: ['trunk', 'tree_trunk', 'bole']
# tube tube.n.01 -definition: conduit consisting of a long hollow object (usually cylindrical) used to hold and conduct objects or liquids or gases -synonyms: ['tube', 'tubing']
# turban turban.n.01 -definition: a traditional Muslim headdress consisting of a long scarf wrapped around the head -synonyms: ['turban']
# turrets turret.n.01 -definition: a small tower extending above a building -synonyms: ['turret']
# twins twins.n.01 -definition: (mineralogy) two interwoven crystals that are mirror images on each other -synonyms: ['twins']
# unicorn unicorn.n.01 -definition: an imaginary creature represented as a white horse with a long horn growing from its forehead -synonyms: ['unicorn']
# universe universe.n.01 -definition: everything that exists anywhere -synonyms: ['universe', 'existence', 'creation', 'world', 'cosmos', 'macrocosm']
# urns urn.n.01 -definition: a large vase that usually has a pedestal or feet -synonyms: ['urn']
# veil head_covering.n.01 -definition: a garment that covers the head and face -synonyms: ['head_covering', 'veil']
# vulture vulture.n.01 -definition: any of various large diurnal birds of prey having naked heads and weak claws and feeding chiefly on carrion -synonyms: ['vulture']
# wasps wasp.n.01 -definition: a white person of Anglo-Saxon ancestry who belongs to a Protestant denomination -synonyms: ['WASP', 'white_Anglo-Saxon_Protestant']
# water water.n.01 -definition: binary compound that occurs at room temperature as a clear colorless odorless tasteless liquid; freezes into ice below 0 degrees centigrade and boils above 100 degrees centigrade; widely used as a solvent -synonyms: ['water', 'H2O']
# weapons weapon.n.01 -definition: any instrument or instrumentality used in fighting or hunting -synonyms: ['weapon', 'arm', 'weapon_system']
# wheel wheel.n.01 -definition: a simple machine consisting of a circular frame with spokes (or a solid disc) that can rotate on a shaft or axle (as in vehicles or other machines) -synonyms: ['wheel']
# wings wings.n.01 -definition: a means of flight or ascent -synonyms: ['wings']
# wolf wolf.n.01 -definition: any of various predatory carnivorous canine mammals of North America and Eurasia that usually hunt in packs -synonyms: ['wolf']
# wreath wreath.n.01 -definition: flower arrangement consisting of a circular band of foliage or flowers for ornamental purposes -synonyms: ['wreath', 'garland', 'coronal', 'chaplet', 'lei']
# writings hagiographa.n.01 -definition: the third of three divisions of the Hebrew Scriptures -synonyms: ['Hagiographa', 'Ketubim', 'Writings']
# young young.n.01 -definition: any immature animal -synonyms: ['young', 'offspring']
# zodiac zodiac.n.01 -definition: a belt-shaped region in the heavens on either side to the ecliptic; divided into 12 constellations or signs for astrological purposes -synonyms: ['zodiac']

# %%
print(natSynNames)
save = store_in_json("synonyms_dict.json", natSynNames)
# Out:
# {'bald-headed': 'bald', 'band': 'set', 'boar': 'wild_boar', 'bowls': 'lawn_bowling', 'boy': 'male_child', 'chains': 'irons', 'chest': 'thorax', 'chlamys': 'perianth', 'cornucopia': 'horn_of_plenty', 'demon': 'devil', 'drapery': 'curtain', 'glasses': 'spectacles', 'globe': 'earth', 'ground': 'land', 'halo': 'aura', 'human': 'homo', 'journeyman': 'craftsman', 'knapsack': 'backpack', 'lance': 'spear', 'monument': 'memorial', 'nosegay': 'bouquet', 'pig': 'hog', 'portrait': 'portrayal', 'procession': 'emanation', 'pupil': 'student', 'purse': 'bag', 'rafts': 'tons', 'scroll': 'coil', 'stake': 'interest', 'statuette': 'figurine', 'stone': 'rock', 'syrinx': 'panpipe', 'tombstone': 'gravestone', 'trumpet': 'cornet', 'veil': 'head_covering'}

# %%
print(syn_dict) # here, the value is the name of the wordnet synset. we can substitute the used word with this to avoid duplicates
# Out:
# {'bald-headed': 'bald', 'band': 'set', 'boar': 'wild_boar', 'bowls': 'lawn_bowling', 'boy': 'male_child', 'chains': 'irons', 'chest': 'thorax', 'chlamys': 'perianth', 'cornucopia': 'horn_of_plenty', 'demon': 'devil', 'drapery': 'curtain', 'glasses': 'spectacles', 'globe': 'earth', 'ground': 'land', 'halo': 'aura', 'human': 'homo', 'journeyman': 'craftsman', 'knapsack': 'backpack', 'lance': 'spear', 'monument': 'memorial', 'nosegay': 'bouquet', 'pig': 'hog', 'portrait': 'portrayal', 'procession': 'emanation', 'pupil': 'student', 'purse': 'bag', 'rafts': 'tons', 'scroll': 'coil', 'stake': 'interest', 'statuette': 'figurine', 'stone': 'rock', 'syrinx': 'panpipe', 'tombstone': 'gravestone', 'trumpet': 'cornet', 'veil': 'head_covering'}

# %%
# characterDict
characterSynDict = {}
synonym_antonym_extractor(characterDict, characterSynDict)
print(characterSynDict)
# Out:
# Adam adam.n.01 -definition: (Old Testament) in Judeo-Christian mythology; the first man and the husband of Eve and the progenitor of the human race -synonyms: ['Adam']
# Aeneas aeneas.n.01 -definition: a mythical Greek warrior who was a leader on the Trojan side of the Trojan War; hero of the Aeneid -synonyms: ['Aeneas']
# Aeolus aeolus.n.01 -definition: god of the winds in ancient mythology -synonyms: ['Aeolus']
# Apollo apollo.n.01 -definition: (Greek mythology) Greek god of light; god of prophecy and poetry and music and healing; son of Zeus and Leto; twin brother of Artemis -synonyms: ['Apollo', 'Phoebus', 'Phoebus_Apollo']
# Apostles apostle.n.01 -definition: an ardent early supporter of a cause or reform -synonyms: ['apostle']
# Argus argus.n.01 -definition: (Greek mythology) a giant with 100 eyes; was guardian of the heifer Io and was slain by Hermes -synonyms: ['Argus']
# Ariadne ariadne.n.01 -definition: beautiful daughter of Minos and Pasiphae; she fell in love with Theseus and gave him the thread with which he found his way out of the Minotaur's labyrinth -synonyms: ['Ariadne']
# Athene athena.n.01 -definition: (Greek mythology) goddess of wisdom and useful arts and prudent warfare; guardian of Athens; identified with Roman Minerva -synonyms: ['Athena', 'Athene', 'Pallas', 'Pallas_Athena', 'Pallas_Athene']
# bacchant drunken_reveler.n.01 -definition: someone who engages in drinking bouts -synonyms: ['drunken_reveler', 'drunken_reveller', 'bacchanal', 'bacchant']
# Bacchus bacchus.n.01 -definition: (classical mythology) god of wine; equivalent of Dionysus -synonyms: ['Bacchus']
# Cerberus cerberus.n.01 -definition: (Greek mythology) the three-headed dog guarding the entrance to Hades; son of Typhon -synonyms: ['Cerberus', 'hellhound']
# Christ jesus.n.01 -definition: a teacher and prophet born in Bethlehem and active in Nazareth; his life and sermons form the basis for Christianity (circa 4 BC - AD 29) -synonyms: ['Jesus', 'Jesus_of_Nazareth', 'the_Nazarene', 'Jesus_Christ', 'Christ', 'Savior', 'Saviour', 'Good_Shepherd', 'Redeemer', 'Deliverer']
# crocodile crocodile.n.01 -definition: large voracious aquatic reptile having a long snout with massive jaws and sharp teeth and a body covered with bony plates; of sluggish tropical waters -synonyms: ['crocodile']
# Cybele cybele.n.01 -definition: great nature goddess of ancient Phrygia in Asia Minor; counterpart of Greek Rhea and Roman Ops -synonyms: ['Cybele', 'Dindymene', 'Great_Mother', 'Magna_Mater', 'Mater_Turrita']
# David david.n.01 -definition: patron saint of Wales (circa 520-600) -synonyms: ['David', 'Saint_David', 'St._David']
# Devil satan.n.01 -definition: (Judeo-Christian and Islamic religions) chief spirit of evil and adversary of God; tempter of mankind; master of Hell -synonyms: ['Satan', 'Old_Nick', 'Devil', 'Lucifer', 'Beelzebub', 'the_Tempter', 'Prince_of_Darkness']
# Diana diana.n.01 -definition: English aristocrat who was the first wife of Prince Charles; her death in an automobile accident in Paris produced intense national mourning (1961-1997) -synonyms: ['Diana', 'Princess_Diana', 'Princess_of_Wales', 'Lady_Diana_Frances_Spencer']
# Dido dido.n.01 -definition: (Roman mythology) a princess of Tyre who was the founder and queen of Carthage; Virgil tells of her suicide when she was abandoned by Aeneas -synonyms: ['Dido']
# Dionysus dionysus.n.01 -definition: (Greek mythology) god of wine and fertility and drama; the Greek name of Bacchus -synonyms: ['Dionysus']
# Erato erato.n.01 -definition: (Greek mythology) the Muse of lyric and love poetry -synonyms: ['Erato']
# Europa europa.n.01 -definition: the 4th largest of Jupiter's satellites; covered with a smooth shell of frozen water -synonyms: ['Europa']
# Eve eve.n.01 -definition: (Old Testament) Adam's wife in Judeo-Christian mythology: the first woman and mother of the human race; God created Eve from Adam's rib and placed Adam and Eve in the Garden of Eden -synonyms: ['Eve']
# Flora vegetation.n.01 -definition: all the plant life in a particular region or period -synonyms: ['vegetation', 'flora', 'botany']
# Ganymede ganymede.n.01 -definition: (Greek mythology) a Trojan boy who was so beautiful that Zeus carried him away to serve as cupbearer to the gods -synonyms: ['Ganymede']
# God god.n.01 -definition: the supernatural being conceived as the perfect and omnipotent and omniscient originator and ruler of the universe; the object of worship in monotheistic religions -synonyms: ['God', 'Supreme_Being']
# Helen helen.n.01 -definition: (Greek mythology) the beautiful daughter of Zeus and Leda who was abducted by Paris; the Greek army sailed to Troy to get her back which resulted in the Trojan War -synonyms: ['Helen', 'Helen_of_Troy']
# Hercules hercules.n.01 -definition: (classical mythology) a hero noted for his strength; performed 12 immense labors to gain immortality -synonyms: ['Hercules', 'Heracles', 'Herakles', 'Alcides']
# Hylas hyla.n.01 -definition: the type genus of the Hylidae; tree toads -synonyms: ['Hyla', 'genus_Hyla']
# Jest joke.n.01 -definition: a humorous anecdote or remark intended to provoke laughter -synonyms: ['joke', 'gag', 'laugh', 'jest', 'jape']
# Joachim joachim.n.01 -definition: Hungarian violinist and composer (1831-1907) -synonyms: ['Joachim', 'Joseph_Joachim']
# Judith judith.n.01 -definition: Jewish heroine in one of the books of the Apocrypha; she saved her people by decapitating the Assyrian general Holofernes -synonyms: ['Judith']
# Jupiter jupiter.n.01 -definition: the largest planet and the 5th from the sun; has many satellites and is one of the brightest objects in the night sky -synonyms: ['Jupiter']
# Laocoon laocoon.n.01 -definition: (Greek mythology) the priest of Apollo who warned the Trojans to beware of Greeks bearing gifts when they wanted to accept the Trojan Horse; a god who favored the Greeks (Poseidon or Athena) sent snakes who coiled around Laocoon and his two twin sons killing them -synonyms: ['Laocoon']
# Leach leach.n.01 -definition: the process of leaching -synonyms: ['leach', 'leaching']
# Mars mars.n.01 -definition: a small reddish planet that is the 4th from the sun and is periodically visible to the naked eye; minerals rich in iron cover its surface and are responsible for its characteristic color -synonyms: ['Mars', 'Red_Planet']
# Mary mary.n.01 -definition: the mother of Jesus; Christians refer to her as the Virgin Mary; she is especially honored by Roman Catholics -synonyms: ['Mary', 'Virgin_Mary', 'The_Virgin', 'Blessed_Virgin', 'Madonna']
# Mercury mercury.n.01 -definition: a heavy silvery toxic univalent and bivalent metallic element; the only metal that is liquid at ordinary temperatures -synonyms: ['mercury', 'quicksilver', 'hydrargyrum', 'Hg', 'atomic_number_80']
# Minerva minerva.n.01 -definition: (Roman mythology) goddess of wisdom; counterpart of Greek Athena -synonyms: ['Minerva']
# Moses moses.n.01 -definition: (Old Testament) the Hebrew prophet who led the Israelites from Egypt across the Red sea on a journey known as the Exodus; Moses received the Ten Commandments from God on Mount Sinai -synonyms: ['Moses']
# Muses muse.n.01 -definition: in ancient Greek mythology any of 9 daughters of Zeus and Mnemosyne; protector of an art or science -synonyms: ['Muse']
# Mithras mithras.n.01 -definition: ancient Persian god of light and truth; sun god -synonyms: ['Mithras', 'Mithra']
# Neptune neptune.n.01 -definition: (Roman mythology) god of the sea; counterpart of Greek Poseidon -synonyms: ['Neptune']
# Noah noah.n.01 -definition: the Hebrew patriarch who saved himself and his family and the animals by building an ark in which they survived 40 days and 40 nights of rain; the story of Noah and the flood is told in the Book of Genesis -synonyms: ['Noah']
# Nymphs nymph.n.01 -definition: (classical mythology) a minor nature goddess usually depicted as a beautiful maiden -synonyms: ['nymph']
# Orpheus orpheus.n.01 -definition: (Greek mythology) a great musician; when his wife Eurydice died he went to Hades to get her back but failed -synonyms: ['Orpheus']
# Pan pan.n.01 -definition: cooking utensil consisting of a wide metal vessel -synonyms: ['pan', 'cooking_pan']
# Paris paris.n.01 -definition: the capital and largest city of France; and international center of culture and commerce -synonyms: ['Paris', 'City_of_Light', 'French_capital', 'capital_of_France']
# Perseus perseus.n.01 -definition: (Greek mythology) the son of Zeus who slew Medusa (with the help of Athena and Hermes) and rescued Andromeda from a sea monster -synonyms: ['Perseus']
# Phaeton touring_car.n.01 -definition: large open car seating four with folding top -synonyms: ['touring_car', 'phaeton', 'tourer']
# Pluto pluto.n.01 -definition: a cartoon character created by Walt Disney -synonyms: ['Pluto']
# Prometheus prometheus.n.01 -definition: (Greek mythology) the Titan who stole fire from Olympus and gave it to mankind; Zeus punished him by chaining him to a rock where an eagle gnawed at his liver until Hercules rescued him -synonyms: ['Prometheus']
# Prophet prophet.n.01 -definition: an authoritative person who divines the future -synonyms: ['prophet', 'prophesier', 'oracle', 'seer', 'vaticinator']
# Proserpina proserpina.n.01 -definition: goddess of the underworld; counterpart of Greek Persephone -synonyms: ['Proserpina', 'Proserpine']
# Pygmalion pygmalion.n.01 -definition: (Greek mythology) a king who created a statue of a woman and fell in love with it; Aphrodite brought the sculpture to life as Galatea -synonyms: ['Pygmalion']
# Rachel rachel.n.01 -definition: (Old Testament) the second wife of Jacob and mother of Joseph and Benjamin -synonyms: ['Rachel']
# Rhea rhea.n.01 -definition: fertility goddess in ancient Greek mythology; wife of Cronus and mother of Zeus; identified with Roman Ops and Cybele of ancient Asia Minor -synonyms: ['Rhea']
# Salamander salamander.n.01 -definition: any of various typically terrestrial amphibians that resemble lizards and that return to water only to breed -synonyms: ['salamander']
# Satan satan.n.01 -definition: (Judeo-Christian and Islamic religions) chief spirit of evil and adversary of God; tempter of mankind; master of Hell -synonyms: ['Satan', 'Old_Nick', 'Devil', 'Lucifer', 'Beelzebub', 'the_Tempter', 'Prince_of_Darkness']
# Saturn saturn.n.01 -definition: a giant planet that is surrounded by three planar concentric rings of ice particles; the 6th planet from the sun -synonyms: ['Saturn']
# Satyr satyr.n.01 -definition: man with strong sexual desires -synonyms: ['satyr', 'lecher', 'lech', 'letch']
# Silenus silenus.n.01 -definition: any of the minor woodland deities who were companions of Dionysus (similar to the satyrs) -synonyms: ['silenus']
# Simeon simeon.n.01 -definition: (Old Testament) the 2nd son of Jacob and one of the 12 patriarchs of Israel -synonyms: ['Simeon']
# Sisyphus sisyphus.n.01 -definition: (Greek legend) a king in ancient Greece who offended Zeus and whose punishment was to roll a huge boulder to the top of a steep hill; each time the boulder neared the top it rolled back down and Sisyphus was forced to start again -synonyms: ['Sisyphus']
# Tantalus tantalus.n.01 -definition: (Greek mythology) a wicked king and son of Zeus; condemned in Hades to stand in water that receded when he tried to drink and beneath fruit that receded when he reached for it -synonyms: ['Tantalus']
# Virgil virgil.n.01 -definition: a Roman poet; author of the epic poem `Aeneid' (70-19 BC) -synonyms: ['Virgil', 'Vergil', 'Publius_Vergilius_Maro']
# Vulcan vulcan.n.01 -definition: (Roman mythology) god of fire and metal working; counterpart of Greek Hephaestus -synonyms: ['Vulcan']
# Zeus zeus.n.01 -definition: (Greek mythology) the supreme god of ancient Greek mythology; son of Rhea and Cronus whom he dethroned; husband and brother of Hera; brother of Poseidon and Hades; father of many gods; counterpart of Roman Jupiter -synonyms: ['Zeus']
# Venus venus.n.01 -definition: the second nearest planet to the sun; it is peculiar in that its rotation is slow and retrograde (in the opposite sense of the Earth and all other planets except Uranus); it is visible from Earth as an early `morning star' or an `evening star' -synonyms: ['Venus']
# Cupid cupid.n.01 -definition: (Roman mythology) god of love; counterpart of Greek Eros -synonyms: ['Cupid', 'Amor']
# {'Athene': 'athena', 'bacchant': 'drunken_reveler', 'Christ': 'jesus', 'Devil': 'satan'}

# %%
# print(syn_dict) NB: it works with the old version of the dictionary
keys = list(syn_dict.keys())
#rint(keys)
values = list(syn_dict.values())
#print(values)
items = list(syn_dict.items())
#rint(items)
for item in items: 
    key = item[0]
    v = item[1]
   #print(key, values)
    if v != []:
        for value in v: 
            if value != key: 
                if value in keys: 
                   print(key, value)
# Out:
# band circle
# chalice goblet
# curls scroll
# curtain drapery
# curtain mantle
# drapery curtain
# drapery mantle
# earth globe
# flames fire
# globe earth
# ground earth
# lance spear
# purse bag
# rock stone
# spear lance
# stone rock

# %%
#note for the valuable synonyms: 
woods forest
spear lance
stone rock
purse bag
men gentleman
men human
kid child
lance spear
ground earth
globe earth
chalice goblet
garlands wreath

# plurals to be updated: 
"woman", "women", "woman(women)"
"man", "men", "man(men)"
"ox", "oxen", "ox(oxen)"
"wood", "woods", "wood(s)"
"kid", "kids", "kid(s)"
"child", "childdren", "child(dren)"
"savage", "savages", "savage(s)"
"savage", "savages", "savage(s)"

# %% [markdown]
# ## Main reconciliation function

# %%
# function to test and improve

def reconciliation_function(dictionary, query, endpoint=None, variables_list=None, q_class=None): # ancillary function: we are already in a for loop with "name"
  all_items = dictionary.items()
  for item in all_items: 
    if item[0].endswith(" rec"): #and item[1] == []:  
      name_rec = item[0] 
      name = item[0].replace(" rec", "")
     # print(name, item[1])
      stop_words = list(filter(lambda x: 'stop' in x, item[1])) # checks if the word "stop" is in the list. returns a list of words containing "stop"
     # if item[1] == []: # we take only the ones without a manual alignment or comment to avoid mistakes/repetitions
      
      # wikidata api request
      if type(query) == dict and endpoint == wikidata_endpoint:
        if "stop wd" not in stop_words: # if there is, it means that the iteration has already been done
          final_query = query 
          final_query['search'] = name
          API_WD = "https://www.wikidata.org/w/api.php"
          r =    requests.get(API_WD, params = final_query).json() # json with all the classes to be filtered
          res = wikidata_reconciliation(r, endpoint, q_class)
          time.sleep(5)
          item[1].append("stop wd")
          if res[1] == 'class_match' or res[1] == 'no_class_given':
            if res[0] not in dictionary[name+" rec"]:
              print(name, "resulting q class is", res[0])
              dictionary[name+" rec"].append(res[0])
       # elif if type(query) == dict and endpoint == iconclass_endpoint: # to be developed
       
      elif type(query) == str: 
        final_query = query.replace("toBeReplaced", name)
          # iconclass api request
        if query.startswith("https://iconclass"):
          if "stop ic" not in stop_words:
          #print(query)
            candidate_list = []
            response = requests.get(final_query)
            final = response.json()
            for el in final["result"]: 
              candidate_list.append(el)
            dictionary[name+" rec"].append("stop ic") # in this way, we search the term only once
            #print(candidate_list)
            for code in candidate_list: 
              # querying directly the code gives the response with keywords: 
              query_code= "https://iconclass.org/"+code+".json"  
              response_code = requests.get(query_code)
              final_code = response_code.json()
              if "txt" in final_code: 
                if "en" in final_code["txt"]: 
                  desc = final_code["txt"]["en"]
                  if "kw" in final_code:
                      if "en" in final_code["kw"]:
                          to_be_checked = final_code["kw"]["en"]
                          if len(to_be_checked) ==1:
                            for candidate in to_be_checked: 
                              if fuzz_ratio_mean(name, candidate) >= 95: 
                                print(name, candidate, code, desc)
                                if "https://iconclass.org/"+code not in dictionary[name+" rec"]: 
                                  dictionary[name+" rec"].append("https://iconclass.org/"+code)
        else:
          res = sparql_query_setting(final_query, endpoint)

          for result in res["results"]["bindings"]:
            if "@en" in str(result[variables_list[0]]["value"]): # case found in getty vocabs
              term = str(result[variables_list[0]]["value"]).replace("@en", "")
            else: 
              term = str(result[variables_list[0]]["value"])
            if fuzz_ratio_mean(name, term) >= 95: 
              print(name, term)
              if result[variables_list[1]]["value"] not in dictionary[name+" rec"]: 
                dictionary[name+" rec"] = [result[variables_list[1]]["value"]]


    # result["Descr"]["value"], result["ScopeNote"]["value"], result["Type"]["value"]

       # print(result["Subject"]["value"], result["Term"]["value"], result["Parents"]["value"])

# %% [markdown]
# ## Iconclass reconciliation

# %%
characterDict = open_json("character_Iconclass_first_match.json")

# %%
done_char = """Adam
Aeneas
Aeolus
Aglauros
Aion/Phanes
Anteros
Antiphas, son of Laoocoon
Antoninus Pius
Apollo
Apollo god of Sun
Apollo Medicus or Aesculapius
Apostles
Archangel Gabriel
Argus
Ariadne
Athene
bacchant
Bacchus
Bishop Simone Saltarelli
Blindfold Cupid
Cacus
Cerberus
Christ
Christ as a child
Companion of Serapis
crocodile
Cybele
David
Devil
Diana
Dido
Dieu Amour
Dionysus
Erato
Erymanthian Boar
Europa
Europa's Companions
Eve
Fedro
Female Pan
Flora
Four Saints
Ganymede
Geminae Veneres
Giuliano de' Medici
God
God's hand
Hecuba
Helen
Hercules
Hermes Sphenopogon
Herse
Hespontine Sibyl
Hylas
Ixion
Jest
Joachim
Judith
Jupiter
Jupiter as an eagle
King Eurystheus
Laocoon
Leach
Lorenzo de' Medici
Marine snakes
Mars
Mary
Member of Medici family
Member of the crowd of faithful in prayer
Member of the procession
Mercury
Mercury (Hermes)
Mida
Minerva
Moses
Muses
Mithras
natural Venus
Neptune
Noah
Nymphs
Olympian Gods
Orpheus
Pan
Pan, God of Panic
Paris
Perseus
Phaeton
Planetary deities
Pluto
Polyxena
Pope Julius II
Presbyter Bruno
Prometheus
Prophet
Proserpina
puer mingens
Pygmalion
Rachel
Rhea
Roman emperors
Saint Anne
Saint Basilius
Saint Cosmas
Saint Damian
Saint John the Evangelist
Saint Luke
Saint Mark
Saint Paul
Saint Peter
Saint Theodora of Alexandria
Salamander
Satan
Saturn
Satyr
Serapis
Silenus
Simeon
Sol Invictus
Sol Iustitiae
Son of the widow of Nain
Sybil
Sisyphus""" 

new = done_char.replace("\n"," @ ")
final = new.split(" @ ")
print(final)
# Out:
# ['Adam', 'Aeneas', 'Aeolus', 'Aglauros', 'Aion/Phanes', 'Anteros', 'Antiphas, son of Laoocoon', 'Antoninus Pius', 'Apollo', 'Apollo god of Sun', 'Apollo Medicus or Aesculapius', 'Apostles', 'Archangel Gabriel', 'Argus', 'Ariadne', 'Athene', 'bacchant', 'Bacchus', 'Bishop Simone Saltarelli', 'Blindfold Cupid', 'Cacus', 'Cerberus', 'Christ', 'Christ as a child', 'Companion of Serapis', 'crocodile', 'Cybele', 'David', 'Devil', 'Diana', 'Dido', 'Dieu Amour', 'Dionysus', 'Erato', 'Erymanthian Boar', 'Europa', "Europa's Companions", 'Eve', 'Fedro', 'Female Pan', 'Flora', 'Four Saints', 'Ganymede', 'Geminae Veneres', "Giuliano de' Medici", 'God', "God's hand", 'Hecuba', 'Helen', 'Hercules', 'Hermes Sphenopogon', 'Herse', 'Hespontine Sibyl', 'Hylas', 'Ixion', 'Jest', 'Joachim', 'Judith', 'Jupiter', 'Jupiter as an eagle', 'King Eurystheus', 'Laocoon', 'Leach', "Lorenzo de' Medici", 'Marine snakes', 'Mars', 'Mary', 'Member of Medici family', 'Member of the crowd of faithful in prayer', 'Member of the procession', 'Mercury', 'Mercury (Hermes)', 'Mida', 'Minerva', 'Moses', 'Muses', 'Mithras', 'natural Venus', 'Neptune', 'Noah', 'Nymphs', 'Olympian Gods', 'Orpheus', 'Pan', 'Pan, God of Panic', 'Paris', 'Perseus', 'Phaeton', 'Planetary deities', 'Pluto', 'Polyxena', 'Pope Julius II', 'Presbyter Bruno', 'Prometheus', 'Prophet', 'Proserpina', 'puer mingens', 'Pygmalion', 'Rachel', 'Rhea', 'Roman emperors', 'Saint Anne', 'Saint Basilius', 'Saint Cosmas', 'Saint Damian', 'Saint John the Evangelist', 'Saint Luke', 'Saint Mark', 'Saint Paul', 'Saint Peter', 'Saint Theodora of Alexandria', 'Salamander', 'Satan', 'Saturn', 'Satyr', 'Serapis', 'Silenus', 'Simeon', 'Sol Invictus', 'Sol Iustitiae', 'Son of the widow of Nain', 'Sybil', 'Sisyphus']

# %%
for name in final: 
  name_rec = name+" rec"
  characterDict[name_rec].append("stop ic")
  print(characterDict[name_rec])
# Out:
# ['https://iconclass.org/11I62(ADAM)', 'stop ic']
# ['https://iconclass.org/96C(AENEAS)', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['http://www.iconclass.org/rkd/91A14%28AION%29/', 'stop ic']
# ['http://www.iconclass.org/rkd/92D1911/', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/92B3', 'https://iconclass.org/95B(MARPESSA)222', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/95B(ARIADNE)', 'https://iconclass.org/94M21', 'https://iconclass.org/92L121', 'https://iconclass.org/92L1781', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/92L1912', 'stop ic']
# ['https://iconclass.org/92L1', 'https://iconclass.org/95A(LYCURGUS)41', 'stop ic']
# ['stop ic']
# ['http://www.iconclass.org/rkd/92D18%28BLINDFOLD%29/', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/25F43', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/71H', 'https://iconclass.org/46A1262', 'https://iconclass.org/73E113', 'https://iconclass.org/73EE113', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/92C3', 'https://iconclass.org/94Q511', 'https://iconclass.org/92B32421', 'stop ic']
# ['https://iconclass.org/96D(DIDO)', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['http://www.iconclass.org/rkd/92D426/', 'https://iconclass.org/92D426', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/11I63(EVE)', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/92D8', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/11C', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/95B(HECUBA)', 'stop ic']
# ['https://iconclass.org/95B(HELEN)', 'https://iconclass.org/95A(MENELAUS)21', 'https://iconclass.org/94R41', 'https://iconclass.org/94F321', 'stop ic']
# ['https://iconclass.org/94L', 'https://iconclass.org/98B(COMMODUS)91', 'https://iconclass.org/94A333', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/92B522', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/71U', 'stop ic']
# ['https://iconclass.org/24C12', 'https://iconclass.org/92B1', 'https://iconclass.org/24C212', 'https://iconclass.org/92B21211', 'https://iconclass.org/94F743', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['http://vocab.getty.edu/ulan/500114960', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/24C13', 'https://iconclass.org/92B4', 'https://iconclass.org/24C213', 'https://iconclass.org/92C45211', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/24C14', 'https://iconclass.org/92B5', 'https://iconclass.org/97D121', 'https://iconclass.org/24C216', 'stop ic']
# ['http://www.iconclass.org/rkd/92B5/', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/92C2', 'https://iconclass.org/94S311', 'stop ic']
# ['stop ic']
# ['http://www.iconclass.org/rkd/92D4/', 'https://iconclass.org/48C71101', 'https://iconclass.org/48C72101', 'https://iconclass.org/48B101', 'https://iconclass.org/48C9101', 'https://iconclass.org/48BB101', 'https://iconclass.org/48C51101', 'https://iconclass.org/48CC71101', 'stop ic']
# ['https://iconclass.org/96A34', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/92H1', 'https://iconclass.org/24C15', 'https://iconclass.org/94F744', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/94O', 'https://iconclass.org/11D3284', 'https://iconclass.org/11DD3284', 'https://iconclass.org/12E84(ORPHEUS)', 'stop ic']
# ['https://iconclass.org/92L5', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/95A(PARIS)', 'stop ic']
# ['https://iconclass.org/94P', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/24C16', 'https://iconclass.org/92N1', 'https://iconclass.org/73D6721', 'stop ic']
# ['https://iconclass.org/95B(POLYXENA)', 'https://iconclass.org/95A(ACHILLES)22', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/91E4', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/92M2', 'https://iconclass.org/92N123', 'https://iconclass.org/92C4912', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/95A(PYGMALION)', 'stop ic']
# ['https://iconclass.org/11I63(RACHEL)', 'stop ic']
# ['https://iconclass.org/91B121', 'https://iconclass.org/91B11122', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['https://iconclass.org/11K(SATAN)', 'https://iconclass.org/73D2421', 'stop ic']
# ['https://iconclass.org/24C17', 'https://iconclass.org/24C211', 'stop ic']
# ['stop ic']
# ['https://iconclass.org/96A32', 'stop ic']
# ['https://iconclass.org/92L421', 'stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']
# ['stop ic']

# %%
# 1st part of iteration
iconclass_query = "https://iconclass.org/api/search?q=toBeReplaced&lang=en&size=999&page=1&sort=rank&keys=0"
character_iconclass = reconciliation_function(characterDict, iconclass_query)
# Out:
# Adam Adam 11I62(ADAM) Adam (not in biblical context)
# Aeneas Aeneas 96C(AENEAS) (story of) Aeneas
# Apollo Apollo 92B3 (story of) Apollo (Phoebus)
# Apollo Apollo 95B(MARPESSA)222 Apollo tries to take Marpessa away from Idas
# Ariadne Ariadne 95B(ARIADNE) (story of) Ariadne
# Ariadne Ariadne 94M21 Theseus in love with Ariadne, Minos' daughter
# Ariadne Ariadne 92L121 (story of) Ariadne and Bacchus
# Ariadne Ariadne 92L1781 triumph of Bacchus and Ariadne
# bacchant bacchant 92L1912 male bacchant(es)
# Bacchus Bacchus 92L1 (story of) Bacchus (Dionysus), Liber
# Bacchus Bacchus 95A(LYCURGUS)41 Lycurgus, king of the Thracian Edones, opposes Bacchus and his train
# crocodile crocodile 25F43 crocodiles
# David David 71H story of David
# David David 46A1262 David (one of the nine worthies)
# David David 73E113 David near the tomb of Christ
# David David 73EE113 David near the tomb of Christ - EE - the tomb closed (with unbroken seals)
# Diana Diana 92C3 (story of) Diana (Artemis)
# Diana Diana 94Q511 Orion and Diana hunting
# Diana Diana 92B32421 Diana shoots Coronis
# Dido Dido 96D(DIDO) (story of) Dido
# Erato Erato 92D426 Erato (one of the Muses); 'Erato' (Ripa)
# Eve Eve 11I63(EVE) Eve (not in biblical context)
# Ganymede Ganymede 92D8 (story of) Ganymede
# God God 11C God the Father
# Hecuba Hecuba 95B(HECUBA) (story of) Hecuba
# Helen Helen 95B(HELEN) (story of) Helen
# Helen Helen 95A(MENELAUS)21 Menelaus and Helen
# Helen Helen 94R41 the Dioscuri in Attica: they fetch Helen, whom Theseus had carried off
# Helen Helen 94F321 Venus fetches Helen and brings her to Paris
# Hercules Hercules 94L (story of) Hercules (Heracles)
# Hercules Hercules 98B(COMMODUS)91 emperor Commodus as Hercules
# Hercules Hercules 94A333 the Argonauts sailing away leaving Hercules behind
# Herse Herse 92B522 Mercury and Herse, daughter of Cecrops
# Judith Judith 71U the book of Judith
# Jupiter Jupiter 24C12 Jupiter (planet)
# Jupiter Jupiter 92B1 (story of) Jupiter (Zeus)
# Jupiter Jupiter 24C212 Jupiter and his children ('Planetenkinder')
# Jupiter Jupiter 92B21211 Vulcan is cast out of Olympus by Jupiter
# Jupiter Jupiter 94F743 Jupiter is lured away by Juno wearing Venus' girdle
# Mars Mars 24C13 Mars (planet)
# Mars Mars 92B4 (story of) Mars (Ares)
# Mars Mars 24C213 Mars and his children ('Planetenkinder')
# Mars Mars 92C45211 bath of Venus and Mars
# Mercury Mercury 24C14 Mercury (planet)
# Mercury Mercury 92B5 (story of) Mercury (Hermes)
# Mercury Mercury 97D121 Mercury bringing Argus' eyes to Juno; Juno sets Argus' eyes in the tail of her peacock
# Mercury Mercury 24C216 Mercury and his children ('Planetenkinder')
# Minerva Minerva 92C2 (story of) Minerva (Pallas, Athena)
# Minerva Minerva 94S311 Bellerophon bridles Pegasus, assisted by Minerva
# Muses Muses 48C71101 the composer and his muse
# Muses Muses 48C72101 the musician and his muse
# Muses Muses 48B101 the artist and his muse (in general)
# Muses Muses 48C9101 the poet and his muse
# Muses Muses 48BB101 the artist and his muse (in general) - BB - out of doors
# Muses Muses 48C51101 the painter and his muse
# Muses Muses 48CC71101 the composer and his muse - CC - out of doors
# Mithras Mithras 96A34 (story of) Mithra(s)
# Neptune Neptune 92H1 (story of) Neptune (Poseidon)
# Neptune Neptune 24C15 Neptune (planet)
# Neptune Neptune 94F744 during Jupiter's absence Neptune turns the battle in favour of the Greeks
# Orpheus Orpheus 94O (story of) Orpheus
# Orpheus Orpheus 11D3284 Christ ~ Orpheus
# Orpheus Orpheus 11DD3284 Christ ~ Orpheus - DD - Christ beardless
# Orpheus Orpheus 12E84(ORPHEUS) Orphic mysteries
# Pan Pan 92L5 (story of) Pan
# Paris Paris 95A(PARIS) (story of) Paris (Alexander)
# Perseus Perseus 94P (story of) Perseus
# Pluto Pluto 24C16 Pluto (planet)
# Pluto Pluto 92N1 (story of) Pluto (Hades), Dis Pater, Orcus
# Pluto Pluto 73D6721 other 'uncommon' persons or objects at the foot of the cross of Christ, e.g.: Hades (Pluto)
# Polyxena Polyxena 95B(POLYXENA) Polyxena
# Polyxena Polyxena 95A(ACHILLES)22 Polyxena beloved by Achilles
# Prometheus Prometheus 91E4 (story of) Prometheus
# Proserpina Proserpina 92M2 (story of) Proserpina (Persephone, Core), Libera
# Proserpina Proserpina 92N123 Pluto in love with Proserpina
# Proserpina Proserpina 92C4912 Venus entrusts Adonis to Proserpina
# Pygmalion Pygmalion 95A(PYGMALION) (story of) Pygmalion
# Rachel Rachel 11I63(RACHEL) Rachel (not in biblical context)
# Rhea Rhea 91B121 Rhea
# Rhea Rhea 91B11122 Rhea and Saturn
# Satan Satan 11K(SATAN) devil(s) and demons: Satan
# Satan Satan 73D2421 Satan enters Judas ~ Last Supper
# Saturn Saturn 24C17 Saturn (planet)
# Saturn Saturn 24C211 Saturn and his children ('Planetenkinder')
# Serapis Serapis 96A32 Serapis
# Silenus Silenus 92L421 (story of) Silenus
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-c2597524f567> in <module>
#       1 iconclass_query = "https://iconclass.org/api/search?q=toBeReplaced&lang=en&size=999&page=1&sort=rank&keys=0"
# ----> 2 character_iconclass = reconciliation_function(characterDict, iconclass_query)
#
# <ipython-input-48-0648509adedc> in reconciliation_function(dictionary, query, endpoint, variables_list, q_class)
#      44             response_code = requests.get(query_code)
#      45             final_code = response_code.json()
# ---> 46             desc = final_code["txt"]["en"]
#      47             if "kw" in final_code:
#      48                 if "en" in final_code["kw"]:
#
# KeyError: 'txt'

# %%
# 2nd part of iteration
iconclass_query = "https://iconclass.org/api/search?q=toBeReplaced&lang=en&size=999&page=1&sort=rank&keys=0"
character_iconclass = reconciliation_function(characterDict, iconclass_query)
# Out:
# Tantalus Tantalus 95A(TANTALUS) (story of) Tantalus
# Troilus Troilus 95A(TROILUS) (story of) Troilus
# Virgil Virgil 82A(VIRGIL) Virgil
# Virgil Virgil 13B2(VIRGIL) sorcerer, magician, wizard, warlock: Virgil
# Venus Venus 24C19 Venus (planet)
# Venus Venus 92C4 (story of) Venus (Aphrodite)
# Venus Venus 92B222 Vulcan and Venus
# Venus Venus 24C215 Venus and her children ('Planetenkinder')
# Venus Venus 92D15211 Cupid shooting a dart at Venus' order
# Venus Venus 92D192163 Psyche with Venus
# Cupid Cupid 92C454 Venus and Cupid (Cupid not being mere attribute)

# %%
characterDict2 = rumor_removal(characterDict)
print(characterDict2)
# Out:
# {'Adam': 'http://icondataset.org/adam', 'Adam rec': ['https://iconclass.org/11I62(ADAM)'], 'Aeneas': 'http://icondataset.org/aeneas', 'Aeneas rec': ['https://iconclass.org/96C(AENEAS)'], 'Aeolus': 'http://icondataset.org/aeolus', 'Aeolus rec': [], 'Aglauros': 'http://icondataset.org/aglauros', 'Aglauros rec': [], 'Aion/Phanes': 'http://icondataset.org/aion/phanes', 'Aion/Phanes rec': ['http://www.iconclass.org/rkd/91A14%28AION%29/'], 'Anteros': 'http://icondataset.org/anteros', 'Anteros rec': ['http://www.iconclass.org/rkd/92D1911/'], 'Antiphas, son of Laoocoon': 'http://icondataset.org/antiphas-son-of-laoocoon', 'Antiphas, son of Laoocoon rec': [], 'Antoninus Pius': 'http://icondataset.org/antoninus-pius', 'Antoninus Pius rec': [], 'Apollo': 'http://icondataset.org/apollo', 'Apollo rec': ['https://iconclass.org/92B3'], 'Apollo god of Sun': 'http://icondataset.org/apollo-god-of-sun', 'Apollo god of Sun rec': [], 'Apollo Medicus or Aesculapius': 'http://icondataset.org/apollo-medicus-or-aesculapius', 'Apollo Medicus or Aesculapius rec': [], 'Apostles': 'http://icondataset.org/apostles', 'Apostles rec': [], 'Archangel Gabriel': 'http://icondataset.org/archangel-gabriel', 'Archangel Gabriel rec': [], 'Argus': 'http://icondataset.org/argus', 'Argus rec': [], 'Ariadne': 'http://icondataset.org/ariadne', 'Ariadne rec': ['https://iconclass.org/95B(ARIADNE)'], 'Athene': 'http://icondataset.org/athene', 'Athene rec': [], 'bacchant': 'http://icondataset.org/bacchant', 'bacchant rec': ['https://iconclass.org/92L1912'], 'Bacchus': 'http://icondataset.org/bacchus', 'Bacchus rec': ['https://iconclass.org/92L1'], 'Bishop Simone Saltarelli': 'http://icondataset.org/bishop-simone-saltarelli', 'Bishop Simone Saltarelli rec': [], 'Blindfold Cupid': 'http://icondataset.org/blindfold-cupid', 'Blindfold Cupid rec': ['http://www.iconclass.org/rkd/92D18%28BLINDFOLD%29/'], 'Cacus': 'http://icondataset.org/cacus', 'Cacus rec': [], 'Cerberus': 'http://icondataset.org/cerberus', 'Cerberus rec': [], 'Christ': 'http://icondataset.org/christ', 'Christ rec': [], 'Christ as a child': 'http://icondataset.org/christ-as-a-child', 'Christ as a child rec': [], 'Companion of Serapis': 'http://icondataset.org/companion-of-serapis', 'Companion of Serapis rec': [], 'crocodile': 'http://icondataset.org/crocodile', 'crocodile rec': ['https://iconclass.org/25F43'], 'Cybele': 'http://icondataset.org/cybele', 'Cybele rec': [], 'David': 'http://icondataset.org/david', 'David rec': ['https://iconclass.org/71H'], 'Devil': 'http://icondataset.org/devil', 'Devil rec': [], 'Diana': 'http://icondataset.org/diana', 'Diana rec': ['https://iconclass.org/92C3'], 'Dido': 'http://icondataset.org/dido', 'Dido rec': ['https://iconclass.org/96D(DIDO)'], 'Dieu Amour': 'http://icondataset.org/dieu-amour', 'Dieu Amour rec': [], 'Dionysus': 'http://icondataset.org/dionysus', 'Dionysus rec': [], 'Erato': 'http://icondataset.org/erato', 'Erato rec': ['http://www.iconclass.org/rkd/92D426/', 'https://iconclass.org/92D426'], 'Erymanthian Boar': 'http://icondataset.org/erymanthian-boar', 'Erymanthian Boar rec': [], 'Europa': 'http://icondataset.org/europa', 'Europa rec': [], "Europa's Companions": 'http://icondataset.org/europas-companions', "Europa's Companions rec": [], 'Eve': 'http://icondataset.org/eve', 'Eve rec': ['https://iconclass.org/11I63(EVE)'], 'Fedro': 'http://icondataset.org/fedro', 'Fedro rec': [], 'Female Pan': 'http://icondataset.org/female-pan', 'Female Pan rec': [], 'Flora': 'http://icondataset.org/flora', 'Flora rec': [], 'Four Saints': 'http://icondataset.org/four-saints', 'Four Saints rec': [], 'Ganymede': 'http://icondataset.org/ganymede', 'Ganymede rec': ['https://iconclass.org/92D8'], 'Geminae Veneres': 'http://icondataset.org/geminae-veneres', 'Geminae Veneres rec': [], "Giuliano de' Medici": 'http://icondataset.org/giuliano-de-medici', "Giuliano de' Medici rec": [], 'God': 'http://icondataset.org/god', 'God rec': ['https://iconclass.org/11C'], "God's hand": 'http://iconda ...

# %%
to_be_removed = []
ic = "https://iconclass.org/"
to_be_removed.append(("Apollo rec", ic+"95B(MARPESSA)222"))
to_be_removed.append(("Ariadne rec", ic+"94M21"))
to_be_removed.append(("Ariadne rec", ic+"92L121"))
to_be_removed.append(("Ariadne rec", ic+"92L1781")) 

to_be_removed.append(("Bacchus rec", ic+"95A(LYCURGUS)41"))
to_be_removed.append(("David rec", ic+"46A1262"))
to_be_removed.append(("David rec", ic+"73E113"))
to_be_removed.append(("David rec", ic+"73EE113"))
to_be_removed.append(("Diana rec", ic+"94Q511"))
to_be_removed.append(("Diana rec", ic+"92B32421"))
to_be_removed.append(("Helen rec", ic+"95A(MENELAUS)21"))
to_be_removed.append(("Helen rec", ic+"94R41"))
to_be_removed.append(("Helen rec", ic+"94F321"))
to_be_removed.append(("Hercules rec", ic+"98B(COMMODUS)91"))
to_be_removed.append(("Hercules rec", ic+"94A333"))
to_be_removed.append(("Herse rec", ic+"92B522"))
to_be_removed.append(("Judith rec", ic+"71U"))
to_be_removed.append(("Jupiter rec", ic+"24C12"))
to_be_removed.append(("Jupiter rec", ic+"92B21211"))
to_be_removed.append(("Jupiter rec", ic+"94F743"))
to_be_removed.append(("Mars rec", ic+"24C13"))
to_be_removed.append(("Mars rec", ic+"24C213"))
to_be_removed.append(("Mars rec", ic+"92C45211"))
to_be_removed.append(("Mercury rec", ic+"97D121"))

to_be_removed.append(("Mercury rec", ic+"24C14"))
to_be_removed.append(("Mercury rec", ic+"24C216"))
to_be_removed.append(("Minerva rec", ic+"94S311"))
to_be_removed.append(("Muses rec", ic+"48C71101"))
to_be_removed.append(("Muses rec", ic+"48C72101"))
to_be_removed.append(("Muses rec", ic+"48B101"))
to_be_removed.append(("Muses rec", ic+"48C9101"))
to_be_removed.append(("Muses rec", ic+"48BB101"))
to_be_removed.append(("Muses rec", ic+"48C51101"))
to_be_removed.append(("Muses rec", ic+"48CC71101"))
to_be_removed.append(("Neptune rec", ic+"24C15"))
to_be_removed.append(("Neptune rec", ic+"94F744"))
to_be_removed.append(("Orpheus rec", ic+"11D3284"))
to_be_removed.append(("Orpheus rec", ic+"11DD3284"))
to_be_removed.append(("Orpheus rec", ic+"12E84(ORPHEUS)"))
to_be_removed.append(("Pluto rec", ic+"24C16"))
to_be_removed.append(("Pluto rec", ic+"73D6721"))
to_be_removed.append(("Polyxena rec", ic+"95A(ACHILLES)22"))
to_be_removed.append(("Proserpina rec", ic+"92N123"))
to_be_removed.append(("Proserpina rec", ic+"92C4912"))
to_be_removed.append(("Rhea rec", ic+"91B11122"))
to_be_removed.append(("Satan rec", ic+"73D2421"))
to_be_removed.append(("Saturn rec", ic+"24C17"))
to_be_removed.append(("Virgil rec", ic+"13B2(VIRGIL)"))
to_be_removed.append(("Venus rec", ic+"24C19"))
to_be_removed.append(("Venus rec", ic+"92B222"))
to_be_removed.append(("Venus rec", ic+"24C215"))
to_be_removed.append(("Venus rec", ic+"92D15211"))
to_be_removed.append(("Venus rec", ic+"92D192163"))
to_be_removed.append(("Cupid rec", ic+"92C454"))


characterDict3 = remove_add_terms(characterDict2, to_be_removed, "remove")

to_be_added = []
to_be_added.append(("Muses rec", "https://iconclass.org/92D4"))
to_be_added.append(("The Children of Saturn rec", "http://www.iconclass.org/24C211"))
to_be_added.append(("Cupid rec", "https://iconclass.org/92D1"))
characterDict4 = remove_add_terms(characterDict3, to_be_added, "add")
# Out:
# ('Apollo rec', 'https://iconclass.org/95B(MARPESSA)222')
# ('Ariadne rec', 'https://iconclass.org/94M21')
# ('Ariadne rec', 'https://iconclass.org/92L121')
# ('Ariadne rec', 'https://iconclass.org/92L1781')
# ('Bacchus rec', 'https://iconclass.org/95A(LYCURGUS)41')
# ('David rec', 'https://iconclass.org/46A1262')
# ('David rec', 'https://iconclass.org/73E113')
# ('David rec', 'https://iconclass.org/73EE113')
# ('Diana rec', 'https://iconclass.org/94Q511')
# ('Diana rec', 'https://iconclass.org/92B32421')
# ('Helen rec', 'https://iconclass.org/95A(MENELAUS)21')
# ('Helen rec', 'https://iconclass.org/94R41')
# ('Helen rec', 'https://iconclass.org/94F321')
# ('Hercules rec', 'https://iconclass.org/98B(COMMODUS)91')
# ('Hercules rec', 'https://iconclass.org/94A333')
# ('Herse rec', 'https://iconclass.org/92B522')
# ('Judith rec', 'https://iconclass.org/71U')
# ('Jupiter rec', 'https://iconclass.org/24C12')
# ('Jupiter rec', 'https://iconclass.org/92B21211')
# ('Jupiter rec', 'https://iconclass.org/94F743')
# ('Mars rec', 'https://iconclass.org/24C13')
# ('Mars rec', 'https://iconclass.org/24C213')
# ('Mars rec', 'https://iconclass.org/92C45211')
# ('Mercury rec', 'https://iconclass.org/97D121')
# ('Mercury rec', 'https://iconclass.org/24C14')
# ('Mercury rec', 'https://iconclass.org/24C216')
# ('Minerva rec', 'https://iconclass.org/94S311')
# ('Muses rec', 'https://iconclass.org/48C71101')
# ('Muses rec', 'https://iconclass.org/48C72101')
# ('Muses rec', 'https://iconclass.org/48B101')
# ('Muses rec', 'https://iconclass.org/48C9101')
# ('Muses rec', 'https://iconclass.org/48BB101')
# ('Muses rec', 'https://iconclass.org/48C51101')
# ('Muses rec', 'https://iconclass.org/48CC71101')
# ('Neptune rec', 'https://iconclass.org/24C15')
# ('Neptune rec', 'https://iconclass.org/94F744')
# ('Orpheus rec', 'https://iconclass.org/11D3284')
# ('Orpheus rec', 'https://iconclass.org/11DD3284')
# ('Orpheus rec', 'https://iconclass.org/12E84(ORPHEUS)')
# ('Pluto rec', 'https://iconclass.org/24C16')
# ('Pluto rec', 'https://iconclass.org/73D6721')
# ('Polyxena rec', 'https://iconclass.org/95A(ACHILLES)22')
# ('Proserpina rec', 'https://iconclass.org/92N123')
# ('Proserpina rec', 'https://iconclass.org/92C4912')
# ('Rhea rec', 'https://iconclass.org/91B11122')
# ('Satan rec', 'https://iconclass.org/73D2421')
# ('Saturn rec', 'https://iconclass.org/24C17')
# ('Virgil rec', 'https://iconclass.org/13B2(VIRGIL)')
# ('Venus rec', 'https://iconclass.org/24C19')
# ('Venus rec', 'https://iconclass.org/92B222')
# ('Venus rec', 'https://iconclass.org/24C215')
# ('Venus rec', 'https://iconclass.org/92D15211')
# ('Venus rec', 'https://iconclass.org/92D192163')
# ('Cupid rec', 'https://iconclass.org/92C454')
# ('Muses rec', 'https://iconclass.org/92D4')
# ('The Children of Saturn rec', 'http://www.iconclass.org/24C211')
# ('Cupid rec', 'https://iconclass.org/92D1')

# %%
storage = store_in_json("character_Iconclass_aligned.json", characterDict4)

# %% [markdown]
# ## Places

# %%
# find the corresponding country of a given city 

getty_endpoint = "http://vocab.getty.edu/sparql"

city_country = []
for city in citiesDict: 
    getty_cities_countries_query = """

        select ?City ?Label ?Country ?CountryLabel{

          # ?City luc:term "toBeReplaced";
                 gvp:placeType [rdfs:label "cities"@en];
                gvp:broaderPreferred* ?Country.
          # ?Country gvp:placeType [rdfs:label "republics"@en] .
          optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
          optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
        }
      """
    if city.endswith(" rec"): 
        name = city.replace(" rec", "")
        final_query = getty_cities_countries_query.replace("toBeReplaced", name) 
        print(final_query)
        res = sparql_query_setting(final_query, getty_endpoint)
        
       # for result in res["results"]["bindings"]: 
        #    print()
        for result in res["results"]["bindings"]:
            if "Label" in result:
                if "@en" in str(result["Label"]["value"]): # case found in getty vocabs
                    cityLabel = str(result["Label"]["value"]).replace("@en", "")
                else: 
                    cityLabel = str(result["Label"]["value"])
                if "CountryLabel" in result:
                    if "@en" in str(result["CountryLabel"]["value"]): # case found in getty vocabs
                        countryLabel = str(result["CountryLabel"]["value"]).replace("@en", "")
                    else: 
                        countryLabel = str(result["CountryLabel"]["value"])
                
                if fuzz_ratio_mean(name, cityLabel) >= 95: 
                    print(name, cityLabel)
                    line = [cityLabel, result["City"]["value"], countryLabel, result["Country"]["value"]]
                    print(line)
                    city_country.append(line)
# Out:
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "St. Gilles";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Siena";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Siena Siena
# ['Siena', 'http://vocab.getty.edu/tgn/7011179', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Vienna";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Vienna Vienna
# ['Vienna', 'http://vocab.getty.edu/tgn/7003321', 'Austria', 'http://vocab.getty.edu/tgn/1000062']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Munich";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Munich Munich
# ['Munich', 'http://vocab.getty.edu/tgn/7004333', 'Bavaria', 'http://vocab.getty.edu/tgn/7003669']
# Munich Munich
# ['Munich', 'http://vocab.getty.edu/tgn/7004333', 'Germany', 'http://vocab.getty.edu/tgn/7000084']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Berlin";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Berlin Berlin
# ['Berlin', 'http://vocab.getty.edu/tgn/7003712', 'Germany', 'http://vocab.getty.edu/tgn/7000084']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Anagni";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Padua";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Padua Padua
# ['Padua', 'http://vocab.getty.edu/tgn/7003085', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Oxford";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Auxerre";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Baltimore";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Bamberg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Bamberg Bamberg
# ['Bamberg', 'http://vocab.getty.edu/tgn/7004325', 'Bavaria', 'http://vocab.getty.edu/tgn/7003669']
# Bamberg Bamberg
# ['Bamberg', 'http://vocab.getty.edu/tgn/7004325', 'Germany', 'http://vocab.getty.edu/tgn/7000084']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Florence";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Florence Florence
# ['Florence', 'http://vocab.getty.edu/tgn/7000457', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Pisa";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Pisa Pisa
# ['Pisa', 'http://vocab.getty.edu/tgn/7006082', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Bari";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Bari Bari
# ['Bari', 'http://vocab.getty.edu/tgn/7004101', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Vatican City";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Rome";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Rome Rome
# ['Rome', 'http://vocab.getty.edu/tgn/7000874', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Naples";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Naples Naples
# ['Naples', 'http://vocab.getty.edu/tgn/7004474', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Paris";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Paris Paris
# ['Paris', 'http://vocab.getty.edu/tgn/7008038', 'France', 'http://vocab.getty.edu/tgn/1000070']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Lyons";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Lyons Lyons
# ['Lyons', 'http://vocab.getty.edu/tgn/7008772', 'France', 'http://vocab.getty.edu/tgn/1000070']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Verdun";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Autun";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Dijon";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Geneva";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Geneva Geneva
# ['Geneva', 'http://vocab.getty.edu/tgn/7007279', 'Geneva', 'http://vocab.getty.edu/tgn/7003746']
# Geneva Geneva
# ['Geneva', 'http://vocab.getty.edu/tgn/7007279', 'Switzerland', 'http://vocab.getty.edu/tgn/7011731']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Brussels";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "London";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Mantua";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Mantua Mantua
# ['Mantua', 'http://vocab.getty.edu/tgn/7005879', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Parma";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Avio";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Chartres";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Chrartres";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Schongrabern";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Reading";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Copenhagen";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Chatsworth";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Cambridge";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Frankfort on Main";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Haarlem";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Dresda";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Nuremberg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Nuremberg Nuremberg
# ['Nuremberg', 'http://vocab.getty.edu/tgn/7004334', 'Bavaria', 'http://vocab.getty.edu/tgn/7003669']
# Nuremberg Nuremberg
# ['Nuremberg', 'http://vocab.getty.edu/tgn/7004334', 'Germany', 'http://vocab.getty.edu/tgn/7000084']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Hildesheim";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Freiburg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Dresden";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Darmstadt";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Darmstadt Darmstadt
# ['Darmstadt', 'http://vocab.getty.edu/tgn/7004428', 'Germany', 'http://vocab.getty.edu/tgn/7000084']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Montecassino";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Lisieux";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Augsburg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "New York";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Milan";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
# Milan Milan
# ['Milan', 'http://vocab.getty.edu/tgn/7005903', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Modena";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Mount Athos";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Monreale";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Bayonne";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Chantilly";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Bourdeaux";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Reims";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Toulouse";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Toulouse Toulouse
# ['Toulouse', 'http://vocab.getty.edu/tgn/7008441', 'France', 'http://vocab.getty.edu/tgn/1000070']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "St.-Germain-en-Laye";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Bologna";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Bologna Bologna
# ['Bologna', 'http://vocab.getty.edu/tgn/7004847', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Hamburg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "The Hague";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Strasbourg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Strasbourg Strasbourg
# ['Strasbourg', 'http://vocab.getty.edu/tgn/7012346', 'France', 'http://vocab.getty.edu/tgn/1000070']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Turin";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Turin Turin
# ['Turin', 'http://vocab.getty.edu/tgn/7005688', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Naumburg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Hannover";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Salzburg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
# Salzburg Salzburg
# ['Salzburg', 'http://vocab.getty.edu/tgn/7003256', 'Austria', 'http://vocab.getty.edu/tgn/1000062']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Fiesole";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Ottawa";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Ferrara";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Ferrara Ferrara
# ['Ferrara', 'http://vocab.getty.edu/tgn/7004264', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Amsterdam";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Philadelphia";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Faenza";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Madrid";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Zurich";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Zurich Zurich
# ['Zurich', 'http://vocab.getty.edu/tgn/7007302', 'Switzerland', 'http://vocab.getty.edu/tgn/7011731']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Windsor";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Arezzo";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Assisi";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Charlieu";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Venice";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Venice Venice
# ['Venice', 'http://vocab.getty.edu/tgn/7018159', 'Venice', 'http://vocab.getty.edu/tgn/7018159']
# Venice Venice
# ['Venice', 'http://vocab.getty.edu/tgn/7018159', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Arles";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Leipzig";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Vézelay";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Cleveland";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Boston";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Osnabruck";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Leyden";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Princeton";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Leiden";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Utrecht";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Hartford";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Cologne";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Cologne Cologne
# ['Cologne', 'http://vocab.getty.edu/tgn/7004446', 'Germany', 'http://vocab.getty.edu/tgn/7000084']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Washington";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Wolfegg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Worcester";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Stuttgart";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Würzburg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Würzburg Würzburg
# ['Würzburg', 'http://vocab.getty.edu/tgn/7004335', 'Bavaria', 'http://vocab.getty.edu/tgn/7003669']
# Würzburg Würzburg
# ['Würzburg', 'http://vocab.getty.edu/tgn/7004335', 'Germany', 'http://vocab.getty.edu/tgn/7000084']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "New Haven";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Amiens";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Lorsh";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Mainz";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
# Mainz Mainz
# ['Mainz', 'http://vocab.getty.edu/tgn/7004449', 'Germany', 'http://vocab.getty.edu/tgn/7000084']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Panticapaeum";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Pompei";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Saint Petersburg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Saint Petersburg Saint Petersburg
# ['Saint Petersburg', 'http://vocab.getty.edu/tgn/7010273', 'Russia', 'http://vocab.getty.edu/tgn/7002435']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Trèves";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Vicenza";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Vicenza Vicenza
# ['Vicenza', 'http://vocab.getty.edu/tgn/7003204', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Wien";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Lubeck";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Lubeck Lubeck
# ['Lubeck', 'http://vocab.getty.edu/tgn/7012327', 'Germany', 'http://vocab.getty.edu/tgn/7000084']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Como";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Como Como
# ['Como', 'http://vocab.getty.edu/tgn/7005851', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Nurnberg";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Trieste";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Trieste Trieste
# ['Trieste', 'http://vocab.getty.edu/tgn/7005539', 'Italy', 'http://vocab.getty.edu/tgn/1000080']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Basel";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
# Basel Basel
# ['Basel', 'http://vocab.getty.edu/tgn/7007269', 'Switzerland', 'http://vocab.getty.edu/tgn/7011731']
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Antwerp";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Ingolstadt";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Mayence";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }
#
#
#
#         select ?City ?Label ?Country ?CountryLabel{
#
#           ?City luc:term "Sicily";
#                  gvp:placeType [rdfs:label "cities"@en];
#                 gvp:broaderPreferred* ?Country.
#           ?Country gvp:placeType [rdfs:label "republics"@en] .
#           optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
#           optional {?Country xl:prefLabel [xl:literalForm ?CountryLabel; dct:language gvp_lang:en]}
#         }

# %%
        for result in res["results"]["bindings"]:
            if "@en" in str(result["Label"]["value"]): # case found in getty vocabs
                cityLabel = str(result["Label"]["value"]).replace("@en", "")
            else: 
                cityLabel = str(result["Label"]["value"])
            if "@en" in str(result["CountryLabel"]["value"]): # case found in getty vocabs
                countryLabel = str(result["CountryLabel"]["value"]).replace("@en", "")
            else: 
                countryLabel = str(result["Label"]["value"])
                
            if fuzz_ratio_mean(name, cityLabel) >= 95: 
              print(name, cityLabel)
            line = [cityLabel, result["City"]["value"], countryLabel, result["Country"]["value"]]
            print(line)
            city_country.append(line)

# %%
print(city_country)
headings = ["City", "CityLink", "Country", "CountryLink"]
store = store_csv("city_country_tgn.csv", headings, city_country)
# Out:
# [['Siena', 'http://vocab.getty.edu/tgn/7011179', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Vienna', 'http://vocab.getty.edu/tgn/7003321', 'Austria', 'http://vocab.getty.edu/tgn/1000062'], ['Munich', 'http://vocab.getty.edu/tgn/7004333', 'Bavaria', 'http://vocab.getty.edu/tgn/7003669'], ['Munich', 'http://vocab.getty.edu/tgn/7004333', 'Germany', 'http://vocab.getty.edu/tgn/7000084'], ['Berlin', 'http://vocab.getty.edu/tgn/7003712', 'Germany', 'http://vocab.getty.edu/tgn/7000084'], ['Padua', 'http://vocab.getty.edu/tgn/7003085', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Bamberg', 'http://vocab.getty.edu/tgn/7004325', 'Bavaria', 'http://vocab.getty.edu/tgn/7003669'], ['Bamberg', 'http://vocab.getty.edu/tgn/7004325', 'Germany', 'http://vocab.getty.edu/tgn/7000084'], ['Florence', 'http://vocab.getty.edu/tgn/7000457', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Pisa', 'http://vocab.getty.edu/tgn/7006082', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Bari', 'http://vocab.getty.edu/tgn/7004101', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Rome', 'http://vocab.getty.edu/tgn/7000874', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Naples', 'http://vocab.getty.edu/tgn/7004474', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Paris', 'http://vocab.getty.edu/tgn/7008038', 'France', 'http://vocab.getty.edu/tgn/1000070'], ['Lyons', 'http://vocab.getty.edu/tgn/7008772', 'France', 'http://vocab.getty.edu/tgn/1000070'], ['Geneva', 'http://vocab.getty.edu/tgn/7007279', 'Geneva', 'http://vocab.getty.edu/tgn/7003746'], ['Geneva', 'http://vocab.getty.edu/tgn/7007279', 'Switzerland', 'http://vocab.getty.edu/tgn/7011731'], ['Mantua', 'http://vocab.getty.edu/tgn/7005879', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Nuremberg', 'http://vocab.getty.edu/tgn/7004334', 'Bavaria', 'http://vocab.getty.edu/tgn/7003669'], ['Nuremberg', 'http://vocab.getty.edu/tgn/7004334', 'Germany', 'http://vocab.getty.edu/tgn/7000084'], ['Darmstadt', 'http://vocab.getty.edu/tgn/7004428', 'Germany', 'http://vocab.getty.edu/tgn/7000084'], ['Milan', 'http://vocab.getty.edu/tgn/7005903', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Toulouse', 'http://vocab.getty.edu/tgn/7008441', 'France', 'http://vocab.getty.edu/tgn/1000070'], ['Bologna', 'http://vocab.getty.edu/tgn/7004847', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Strasbourg', 'http://vocab.getty.edu/tgn/7012346', 'France', 'http://vocab.getty.edu/tgn/1000070'], ['Turin', 'http://vocab.getty.edu/tgn/7005688', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Salzburg', 'http://vocab.getty.edu/tgn/7003256', 'Austria', 'http://vocab.getty.edu/tgn/1000062'], ['Ferrara', 'http://vocab.getty.edu/tgn/7004264', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Zurich', 'http://vocab.getty.edu/tgn/7007302', 'Switzerland', 'http://vocab.getty.edu/tgn/7011731'], ['Venice', 'http://vocab.getty.edu/tgn/7018159', 'Venice', 'http://vocab.getty.edu/tgn/7018159'], ['Venice', 'http://vocab.getty.edu/tgn/7018159', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Cologne', 'http://vocab.getty.edu/tgn/7004446', 'Germany', 'http://vocab.getty.edu/tgn/7000084'], ['Würzburg', 'http://vocab.getty.edu/tgn/7004335', 'Bavaria', 'http://vocab.getty.edu/tgn/7003669'], ['Würzburg', 'http://vocab.getty.edu/tgn/7004335', 'Germany', 'http://vocab.getty.edu/tgn/7000084'], ['Mainz', 'http://vocab.getty.edu/tgn/7004449', 'Germany', 'http://vocab.getty.edu/tgn/7000084'], ['Saint Petersburg', 'http://vocab.getty.edu/tgn/7010273', 'Russia', 'http://vocab.getty.edu/tgn/7002435'], ['Vicenza', 'http://vocab.getty.edu/tgn/7003204', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Lubeck', 'http://vocab.getty.edu/tgn/7012327', 'Germany', 'http://vocab.getty.edu/tgn/7000084'], ['Como', 'http://vocab.getty.edu/tgn/7005851', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Trieste', 'http://vocab.getty.edu/tgn/7005539', 'Italy', 'http://vocab.getty.edu/tgn/1000080'], ['Basel', 'http://vocab.getty.edu/tgn/7007269 ...

# %%
citiesDict = open_json("baseDictionaries/cityDict.json")
countriesDict = open_json("baseDictionaries/countryDict.json")

# %%
print(citiesDict)
# Out:
# {'St. Gilles': 'http://icondataset.org/places/st-gilles', 'St. Gilles rec': ['http://vocab.getty.edu/tgn/1026710'], 'Siena': 'http://icondataset.org/places/siena', 'Siena rec': [], 'Vienna': 'http://icondataset.org/places/vienna', 'Vienna rec': [], 'Munich': 'http://icondataset.org/places/munich', 'Munich rec': [], 'Berlin': 'http://icondataset.org/places/berlin', 'Berlin rec': [], 'Anagni': 'http://icondataset.org/places/anagni', 'Anagni rec': [], 'Padua': 'http://icondataset.org/places/padua', 'Padua rec': [], 'Oxford': 'http://icondataset.org/places/oxford', 'Oxford rec': [], 'Auxerre': 'http://icondataset.org/places/auxerre', 'Auxerre rec': [], 'Baltimore': 'http://icondataset.org/places/baltimore', 'Baltimore rec': [], 'Bamberg': 'http://icondataset.org/places/bamberg', 'Bamberg rec': [], 'Florence': 'http://icondataset.org/places/florence', 'Florence rec': [], 'Pisa': 'http://icondataset.org/places/pisa', 'Pisa rec': [], 'Bari': 'http://icondataset.org/places/bari', 'Bari rec': [], 'Vatican City': 'http://icondataset.org/places/vatican-city', 'Vatican City rec': [], 'Rome': 'http://icondataset.org/places/rome', 'Rome rec': [], 'Naples': 'http://icondataset.org/places/naples', 'Naples rec': [], 'Paris': 'http://icondataset.org/places/paris', 'Paris rec': [], 'Lyons': 'http://icondataset.org/places/lyons', 'Lyons rec': [], 'Verdun': 'http://icondataset.org/places/verdun', 'Verdun rec': [], 'Autun': 'http://icondataset.org/places/autun', 'Autun rec': [], 'Dijon': 'http://icondataset.org/places/dijon', 'Dijon rec': [], 'Geneva': 'http://icondataset.org/places/geneva', 'Geneva rec': [], 'Brussels': 'http://icondataset.org/places/brussels', 'Brussels rec': [], 'London': 'http://icondataset.org/places/london', 'London rec': [], 'Mantua': 'http://icondataset.org/places/mantua', 'Mantua rec': [], 'Parma': 'http://icondataset.org/places/parma', 'Parma rec': [], 'Avio': 'http://icondataset.org/places/avio', 'Avio rec': [], 'Chartres': 'http://icondataset.org/places/chartres', 'Chartres rec': [], 'Chrartres': 'http://icondataset.org/places/chrartres', 'Chrartres rec': [], 'Schongrabern': 'http://icondataset.org/places/schongrabern', 'Schongrabern rec': [], 'Reading': 'http://icondataset.org/places/reading', 'Reading rec': [], 'Copenhagen': 'http://icondataset.org/places/copenhagen', 'Copenhagen rec': [], 'Chatsworth': 'http://icondataset.org/places/chatsworth', 'Chatsworth rec': [], 'Cambridge': 'http://icondataset.org/places/cambridge', 'Cambridge rec': [], 'Frankfort on Main': 'http://icondataset.org/places/frankfort-on-main', 'Frankfort on Main rec': [], 'Haarlem': 'http://icondataset.org/places/haarlem', 'Haarlem rec': [], 'Dresda': 'http://icondataset.org/places/dresda', 'Dresda rec': [], 'Nuremberg': 'http://icondataset.org/places/nuremberg', 'Nuremberg rec': [], 'Hildesheim': 'http://icondataset.org/places/hildesheim', 'Hildesheim rec': [], 'Freiburg': 'http://icondataset.org/places/freiburg', 'Freiburg rec': [], 'Dresden': 'http://icondataset.org/places/dresden', 'Dresden rec': [], 'Darmstadt': 'http://icondataset.org/places/darmstadt', 'Darmstadt rec': [], 'Montecassino': 'http://icondataset.org/places/montecassino', 'Montecassino rec': [], 'Lisieux': 'http://icondataset.org/places/lisieux', 'Lisieux rec': [], 'Augsburg': 'http://icondataset.org/places/augsburg', 'Augsburg rec': [], 'New York': 'http://icondataset.org/places/new-york', 'New York rec': [], 'Milan': 'http://icondataset.org/places/milan', 'Milan rec': [], 'Modena': 'http://icondataset.org/places/modena', 'Modena rec': [], 'Mount Athos': 'http://icondataset.org/places/mount-athos', 'Mount Athos rec': [], 'Monreale': 'http://icondataset.org/places/monreale', 'Monreale rec': [], 'Bayonne': 'http://icondataset.org/places/bayonne', 'Bayonne rec': [], 'Chantilly': 'http://icondataset.org/places/chantilly', 'Chantilly rec': [], 'Bourdeaux': 'http://icondataset.org/places/bourdeaux', 'Bourdeaux rec': [], 'Reims': 'http://icondataset.org/places/reims', 'Reims rec': [], ...

# %%
# getty countries 

getty_countries_variables = ["Label", "Country"]
getty_countries_query = """

select ?Country ?Label {
  
  # ?Country luc:term "toBeReplaced";
         gvp:placeType [rdfs:label "republics"@en]
  optional {?Country xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
}
      """
getty_endpoint = "http://vocab.getty.edu/sparql"
countries = reconciliation_function(countriesDict, getty_countries_query, getty_endpoint, getty_countries_variables)


wd_query = { # nb:applying only to wikidata. Every API has its own parameters. 
        "action": "wbsearchentities",
        "format": "json",
        "language": "en",
        "search": "toBeReplaced"
    }

#countries2 = reconciliation_function(countriesDict, wd_query, wikidata_endpoint, q_class="Q6256")
# print(countriesDict)
# Out:
# Germany Germany
# Austria Austria
# France France
# Greece Greece
# Italy Italy

# %%
countries2 = reconciliation_function(countriesDict, wd_query, wikidata_endpoint, q_class="Q6256")
print(countriesDict)
# Out:
# Germany resulting q class is http://www.wikidata.org/entity/Q183
# Austria resulting q class is http://www.wikidata.org/entity/Q40
# United Kingdom resulting q class is http://www.wikidata.org/entity/Q145
# France resulting q class is http://www.wikidata.org/entity/Q142
# Greece resulting q class is http://www.wikidata.org/entity/Q41
# Italy resulting q class is http://www.wikidata.org/entity/Q38
# Jordan resulting q class is http://www.wikidata.org/entity/Q810

# %%
finalCountries = rumor_removal(countriesDict)
print(countriesDict)
country_headings = ["Country", "CountryLink"]
store = store_dict_in_csv("countriesAligned.csv", country_headings, countriesDict)
# Out:
# {'Germany': 'http://icondataset.org/places/germany', 'Germany rec': ['http://vocab.getty.edu/tgn/7000084', 'http://www.wikidata.org/entity/Q183'], 'Austria': 'http://icondataset.org/places/austria', 'Austria rec': ['http://vocab.getty.edu/tgn/1000062', 'http://www.wikidata.org/entity/Q40'], 'United Kingdom': 'http://icondataset.org/places/united-kingdom', 'United Kingdom rec': ['http://www.wikidata.org/entity/Q145'], 'France': 'http://icondataset.org/places/france', 'France rec': ['http://vocab.getty.edu/tgn/1000070', 'http://www.wikidata.org/entity/Q142'], 'Greece': 'http://icondataset.org/places/greece', 'Greece rec': ['http://vocab.getty.edu/tgn/1000074', 'http://www.wikidata.org/entity/Q41'], 'Italy': 'http://icondataset.org/places/italy', 'Italy rec': ['http://vocab.getty.edu/tgn/1000080', 'http://www.wikidata.org/entity/Q38'], 'Crimea': 'http://icondataset.org/places/crimea', 'Crimea rec': [], 'Jordan': 'http://icondataset.org/places/jordan', 'Jordan rec': ['http://www.wikidata.org/entity/Q810'], 'Vatican City': 'http://icondataset.org/places/vatican-city', 'Vatican City rec': []}

# %%
# getty cities 
name = ""
getty_cities_variables = ["Label", "City"]
getty_cities_query = """

select ?City ?Label {
  
  # ?City luc:term "ToBeReplaced";
         gvp:placeType [rdfs:label "cities"@en]
  optional {?City xl:prefLabel [xl:literalForm ?Label; dct:language gvp_lang:en]}
}
      """
getty_endpoint = "http://vocab.getty.edu/sparql"
cities = reconciliation_function(citiesDict, getty_cities_query, getty_endpoint, getty_cities_variables)


wd_query = { # nb:applying only to wikidata. Every API has its own parameters. 
        "action": "wbsearchentities",
        "format": "json",
        "language": "en",
        "search": "toBeReplaced"
    }

countries2 = reconciliation_function(citiesDict, wd_query, wikidata_endpoint, q_class="Q515")
# Out:
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300435698'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cypro-Archaic'}, 'Parents': {'type': 'literal', 'value': 'Cypriote styles, Cypriote, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Style and culture that developed in Cyprus ca. 750–450 BCE.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300016747'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Northern Archaic'}, 'Parents': {'type': 'literal', 'value': 'Pre-Columbian Maritime area styles, Pre-Columbian Western Eskimo styles, ... Styles and Periods Facet'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300107784'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Archaic (Persian pottery style)'}, 'Parents': {'type': 'literal', 'value': 'Persian pottery styles, Persian styles, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to the pottery style found in Persia around 6000 BCE. The style is characterized by fine, plain buff pottery tempered with straw that is sometimes decorated with simple red or orange painted designs.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300016661'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Eastern Archaic'}, 'Parents': {'type': 'literal', 'value': 'Archaic (North American), Pre-Columbian North American periods, ... Styles and Periods Facet'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300016665'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Western Archaic'}, 'Parents': {'type': 'literal', 'value': 'Archaic (North American), Pre-Columbian North American periods, ... Styles and Periods Facet'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300016820'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Boreal Archaic'}, 'Parents': {'type': 'literal', 'value': 'Pre-Columbian Northeastern North American styles, Pre-Columbian Eastern North American styles, ... Styles and Periods Facet'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300107742'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hassuna archaic'}, 'Parents': {'type': 'literal', 'value': 'Mesopotamian pottery styles, Mesopotamian (culture or style), ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to a pottery style found in northern Mesopotamia during the Hassuna period, from about 6200 to 5700 BCE. The style is characterized by a red paint and a glossy surface finish.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300016666'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Desert Tradition'}, 'Parents': {'type': 'literal', 'value': 'Western Archaic, Archaic (North American), ... Styles and Periods Facet'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300016660'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Archaic (North American)'}, 'Parents': {'type': 'literal', 'value': 'Pre-Columbian North American periods, <Pre-Columbian North American styles and periods>, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Culture in North America from around 8000 BCE to 2000 BCE, ending with the adoption of sedentary farming, which varies from place to place in the Americas.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300020086'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Archaic (Greek culture or period)'}, 'Parents': {'type': 'literal', 'value': 'Ancient Greek (culture or style), Aegean periods, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to the period, culture, and art of ancient Greece that begins around the mid-eighth century BCE and ends in the early fifth century BCE, with the Persian invasion. It is characterized by the introduction of the alphabet from Phoenicia, the establishment of important city states and colonies, the establishment of the open square, or agora, in city planning, and distinctive styles in painting, sculpture, and architecture. In vase painting, the stylized beasts of the Orientalizing period were replaced by more naturalistic figures in Black-figure and then Red-figure styles. In sculpture, more naturalistic forms developed from the stiff, canonical Egyptian figures of the Orientalizing period. In architecture, the Doric and Ionic orders were developed.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300020265'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Early Dynastic (Egyptian)'}, 'Parents': {'type': 'literal', 'value': 'Egyptian periods, Egyptian (ancient), ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to the period in Egypt from about 2925 to 2650 BCE during the First and Second Dynasties; some sources also include the Third Dynasty ending about 2575 BCE. Works of art include pottery, wall paintings, sculpture and reliefs. During this period artistic conventions were formalized effecting the pose of the human figure, the arrangement of pictorial elements in register, and in sculpture, a rigid formal depiction of the figure that preserves the quality of the stone and the shape of the block. Architecture is distinguished by the development of tomb superstructures.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300106990'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Early Archaic'}, 'Parents': {'type': 'literal', 'value': 'Archaic (Greek culture or period), Ancient Greek (culture or style), ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to the first phase of the Greek Archaic period, from around 660 BCE to around 580 BCE. It is characterized in sculpture by the creation of more large-scale stone sculpture than in earlier periods, and by a style that is close to the Egyptian prototypes. In vase painting it is characterized by the Black-figure method used to depict more naturalistic figures than those of the Orientalizing period.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300106993'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Middle Archaic'}, 'Parents': {'type': 'literal', 'value': 'Archaic (Greek culture or period), Ancient Greek (culture or style), ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to a phase of the Greek Archaic period, from around 580 BCE to around 535 BCE. It is characterized in sculpture and vase painting by figures that are more naturalistic than in the Early Archaic phase.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300106995'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Late Archaic'}, 'Parents': {'type': 'literal', 'value': 'Archaic (Greek culture or period), Ancient Greek (culture or style), ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to the last phase of the Greek Archaic period, from around 540 BCE to around 480 BCE. It is characterized in vase painting by the introduction of the Red-figure method, and in both vase painting and sculpture by the development of figures that are more naturalistic and that have more fluid movements than in earlier phases.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300016967'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Preclassic'}, 'Parents': {'type': 'literal', 'value': 'Mesoamerican periods, Mesoamerican, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers generally to the period in Mesoamerica from about 2000 BCE to 250 CE characterized  by major achievements in iconography and architecture by many distinct societies. It often refers specifically to early prehistoric Mesoamerican Olmec culture featuring monumental and intricate art in stone, jewels, and feathers.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300417602'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Byzantine chants'}, 'Parents': {'type': 'literal', 'value': 'chants, songs (musical compositions), ... Objects Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Liturgical chants that are monophonic, or unison, used in the Greek Orthodox church during the Byzantine Empire (330–1453) and down to the 16th century; in modern Greece the term refers to ecclesiastical music of any period.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300438687'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Byzantine Greek (transliterated) (Latin)'}, 'Parents': {'type': 'literal', 'value': '<Greek in transliteration>, Greek (language), ... Associated Concepts Facet'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300388050'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Byzantine Greek (language)'}, 'Parents': {'type': 'literal', 'value': 'Greek (language), Indo-European (language family), ... Associated Concepts Facet'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300379797'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Post-Byzantine'}, 'Parents': {'type': 'literal', 'value': 'Byzantine (culture and style), <Early Christian-Byzantine styles, cultures, periods>, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to art produced  by Orthodox Christians living in lands once part of the Byzantine empire.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300020732'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Russian Byzantine styles'}, 'Parents': {'type': 'literal', 'value': 'Byzantine regional styles, Byzantine (culture and style), ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Styles belonging to Russian Byzantine cultures.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300020678'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Byzantine regional styles'}, 'Parents': {'type': 'literal', 'value': 'Byzantine (culture and style), <Early Christian-Byzantine styles, cultures, periods>, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Regional styles belonging to Byzantine cultures.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300020720'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Italo-Byzantine'}, 'Parents': {'type': 'literal', 'value': 'Byzantine regional styles, Byzantine (culture and style), ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to the style and period that developed after the conquest of Constantinople by the armies of the Fourth Crusade in 1204 and lasted into the early 14th century. The style is particularly evident in southern and central Italy, and was fertilized by the import of Byzantine portable objects, by Greek artists in Italy, and by western artists returning from Byzantine territiories. Italo-Byzantine style is characterized by the merging of Byzantine themes, figural types, and decorative elements with Hellenistic-Roman illusionism, Gothic fluency of line, and local Italian traditions.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300020674'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Middle Byzantine'}, 'Parents': {'type': 'literal', 'value': 'Byzantine (culture and style), <Early Christian-Byzantine styles, cultures, periods>, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to the style following the Iconoclastic crisis, from the mid-ninth century through the early 13th century. The style is mainly evident in the eastern Roman empire, and spread along with the Orthodox faith to the Balkans and Russia after the loss of Asia Minor to the Seljuk Turks in 1071. The style is characterized by its evolution from earlier Byzantine art, including a reduction in the size of churches and monasteries, frequent use of the Greek cross plan, interiors encrusted with rich marble, mosaics, painting, and ivory carvings, which were typically more austere, linear, and abstract compositions in a rigid iconographic system.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300021446'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Byzantine Revival'}, 'Parents': {'type': 'literal', 'value': 'modern European revival styles, <modern European styles and movements>, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers mainly to the style in architecture and decorative arts in Europe and the United States during the second half of the 19th century and the beginning of the 20th century. Influenced by publications on Byzantine architecture, it is characterized by the round arches, barrel vaults, densely carved foilage, and mosaic decoration typical of that architecture.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300106792'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Early Byzantine'}, 'Parents': {'type': 'literal', 'value': 'Byzantine (culture and style), <Early Christian-Byzantine styles, cultures, periods>, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to the early stages of the Byzantine period that began when the Emperor Constantine made the city of Byzantium the new capital of the Roman Empire in 330 CE. The style is sometimes grouped with Early Christian art, because there was at that time no official split between the eastern and western Roman empires.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300020676'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Late Byzantine'}, 'Parents': {'type': 'literal', 'value': 'Byzantine (culture and style), <Early Christian-Byzantine styles, cultures, periods>, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to the revival of Byzantine style and western influence that evolved after the Crusades in Byzantium and eastern Europe in the late 13th century. Architecture of the period is remarkable for multi-colored materials, decorative details, and the variety of types, generally variants on old themes. In manuscript illuminations, mosaics, wall painting, panel painting, ivories, and luxury arts the style is characterized by strong color, more naturalistic depictions of light on forms, and often imaginative compositional and stylistic solutions.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300020658'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': '<Early Christian-Byzantine styles, cultures, periods>'}, 'Parents': {'type': 'literal', 'value': 'European, <styles, periods, and cultures by region>, ... Styles and Periods Facet'}, 'Type': {'type': 'literal', 'value': 'GuideTerm'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300020701'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Palaeologan'}, 'Parents': {'type': 'literal', 'value': 'Late Byzantine, Byzantine (culture and style), ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to the revival of the Byzantine style in Byzantium and eastern Europe under the Palaeologue dynasty (1261-1453). The style differs from earlier styles in sacrificing formality for greater freedom, and is noted for a preference for wall paintings to mosaics, more complex compositions that often cover entire walls, and a change in iconography to often prefer themes from the Apocryphal Gospels.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300020669'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Byzantine (culture and style)'}, 'Parents': {'type': 'literal', 'value': '<Early Christian-Byzantine styles, cultures, periods>, European, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Culture, style, and period of the Christian states of the eastern Mediterranean during the rule of the Byzantine Empire (330 - 1453 CE). Byzantine art and culture was carried throughout much of the Christian world, and lasted into the 16th century in eastern Europe. The style is characterized by imperial and religious subject matter, and a movement away from the original Greek naturalistic forms to favor ritualistic stylization, intended to suggest the spiritual. For the culture and style of the Italian and western Mediterranean Christian world roughly from the third to the mid-ninth century CE, use "Early Christian."'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300310584'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Orthodox crosses'}, 'Parents': {'type': 'literal', 'value': 'crosses (motifs), motifs, ... Physical Attributes Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Crosses having three crossbars on a longer vertical bar, where the upper bar represents the INRI title of the cross, the second longer crossbar designating arms of the cross, and the lowest crossbar, which is always inclined at an angle, signifying the suppedaneum or foot rest.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300001053'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'horseshoe arches'}, 'Parents': {'type': 'literal', 'value': '<arches by form>, arches, ... Objects Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Arches in which the curves are carried below the springing line so that the opening at the bottom of the arch is less than its greatest span.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300106975'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Carolingian styles'}, 'Parents': {'type': 'literal', 'value': 'Northern European Medieval styles, Medieval regional styles, ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Styles belonging to Carolingian cultures.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300195207'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Caroline minuscule'}, 'Parents': {'type': 'literal', 'value': '<Latin and Greek alphabet scripts>, <scripts by form>, ... Objects Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'A script of great clarity, used in both books and documents, that combined characteristics of cursive and half-uncial; developed in Carolingian centers in the late 8th century and then predominant throughout Europe until the 13th century.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}
# {'Subject': {'type': 'uri', 'value': 'http://vocab.getty.edu/aat/300020764'}, 'Term': {'xml:lang': 'en', 'type': 'literal', 'value': 'Carolingian (culture or style)'}, 'Parents': {'type': 'literal', 'value': 'Early Medieval, Medieval (European), ... Styles and Periods Facet'}, 'ScopeNote': {'xml:lang': 'en', 'type': 'literal', 'value': 'Refers to the culture, period, and style surrounding the reign of Charlemagne (768-814) and his successors through about 900 CE. The style is characterized by a renewal of the culture of the Roman Empire as it existed under Constantine and Theodosius.'}, 'Type': {'type': 'literal', 'value': 'Concept'}}

# %% [markdown]
# ## People reconciliation with Wikidata, ULAN, VIAF

# %%
# wikidata
wd_query = { # nb:applying only to wikidata. Every API has its own parameters. 
        "action": "wbsearchentities",
        "format": "json",
        "language": "en",
        "search": "toBeReplaced"
    }


people = reconciliation_function(peopleDict, wd_query, wikidata_endpoint, q_class="Q5")
# Out:
# A.E. Popp ['http://viaf.org/viaf/20715488']
# Abu Ma'sar ['http://viaf.org/viaf/17355947']
# resulting q class is http://www.wikidata.org/entity/Q11373
# Achilles Bocchius ['http://viaf.org/viaf/149878']
# resulting q class is http://www.wikidata.org/entity/Q3604350
# Adam Friedrich Oeser ['http://vocab.getty.edu/ulan/500115770']
# resulting q class is http://www.wikidata.org/entity/Q215129
# Agesander ['http://vocab.getty.edu/page/500021781']
# resulting q class is http://www.wikidata.org/entity/Q983432
# Athenodoros ['http://vocab.getty.edu/ulan/500007132']
# resulting q class is http://www.wikidata.org/entity/Q280432
# Polydorus ['http://vocab.getty.edu/ulan/500031985']
# Agnolo Bronzino ['http://vocab.getty.edu/ulan/500004362']
# resulting q class is http://www.wikidata.org/entity/Q7803
# Albrecht Dürer ['http://vocab.getty.edu/ulan/500115493']
# resulting q class is http://www.wikidata.org/entity/Q5580
# Alexandre de Laborde ['http://viaf.org/viaf/121808105']
# resulting q class is http://www.wikidata.org/entity/Q2362791
# Alfred Stevens ['http://vocab.getty.edu/ulan/500000844']
# resulting q class is http://www.wikidata.org/entity/Q773855
# Alphonse Louis Duc ['http://viaf.org/viaf/47035383']
# Ambrogio Lorenzetti ['http://vocab.getty.edu/ulan/500012547']
# resulting q class is http://www.wikidata.org/entity/Q211562
# Andrea Alciati ['http://vocab.getty.edu/ulan/500048282']
# resulting q class is http://www.wikidata.org/entity/Q464471
# Andrea del Castagno ['http://vocab.getty.edu/ulan/500004603']
# resulting q class is http://www.wikidata.org/entity/Q240737
# Andrea Mantegna ['http://vocab.getty.edu/ulan/500004218']
# resulting q class is http://www.wikidata.org/entity/Q5681
# Annibale Carracci ['http://vocab.getty.edu/ulan/500115350']
# resulting q class is http://www.wikidata.org/entity/Q7824
# Anthony van Dyck ['http://vocab.getty.edu/ulan/500115190']
# resulting q class is http://www.wikidata.org/entity/Q150679
# Antonio Federighi ['http://vocab.getty.edu/ulan/500022519']
# resulting q class is http://www.wikidata.org/entity/Q291201
# Antonio Pollaiuolo ['http://vocab.getty.edu/ulan/500013242']
# resulting q class is http://www.wikidata.org/entity/Q318640
# Apollonio di Giovanni ['http://vocab.getty.edu/ulan/500019165']
# resulting q class is http://www.wikidata.org/entity/Q2858468
# Artus Quellinus the Elder ['http://viaf.org/viaf/52492507']
# resulting q class is http://www.wikidata.org/entity/Q651461
# Aubrey Beardsley ['http://viaf.org/viaf/88739636']
# resulting q class is http://www.wikidata.org/entity/Q272566
# B. de Montfaucon ['http://vocab.getty.edu/ulan/500272624']
# Baccio Bandinelli ['http://vocab.getty.edu/ulan/500008366']
# resulting q class is http://www.wikidata.org/entity/Q358348
# Benedetto Antelami ['http://vocab.getty.edu/ulan/500007220']
# resulting q class is http://www.wikidata.org/entity/Q560114
# Benozzo Gozzoli ['http://vocab.getty.edu/ulan/500000246']
# resulting q class is http://www.wikidata.org/entity/Q248615
# C. Nodier ['http://viaf.org/viaf/64009895']
# Cesare Ripa ['http://vocab.getty.edu/ulan/500236250']
# resulting q class is http://www.wikidata.org/entity/Q721704
# Charles Edouard de Beaumont ['http://vocab.getty.edu/ulan/500011622']
# resulting q class is http://www.wikidata.org/entity/Q2958342
# Christine Pisan ['https://viaf.org/viaf/100188547/']
# Konrad Peutinger ['http://viaf.org/viaf/56776766']
# resulting q class is http://www.wikidata.org/entity/Q60958
# Correggio ['http://vocab.getty.edu/ulan/500006208']
# resulting q class is http://www.wikidata.org/entity/Q8457
# Cosimo de' Medici []
# resulting q class is http://www.wikidata.org/entity/Q48547
# Cristoforo Robetta ['http://vocab.getty.edu/ulan/500033090']
# Cyriacus of Ancona ['http://vocab.getty.edu/ulan/00031944']
# resulting q class is http://www.wikidata.org/entity/Q558074
# David Le Marchand []
# Domenico Beccafumi []
# resulting q class is http://www.wikidata.org/entity/Q455712
# Donatello ['http://vocab.getty.edu/ulan/00026022']
# resulting q class is http://www.wikidata.org/entity/Q37562
# Duccio di Buoninsegna ['http://vocab.getty.edu/ulan/00029165']
# resulting q class is http://www.wikidata.org/entity/Q15792
# F. D'Ostervald ['http://viaf.org/viaf/303877486']
# Filarete ['http://vocab.getty.edu/ulan/00031755']
# resulting q class is http://www.wikidata.org/entity/Q449961
# Filippino Lippi ['http://vocab.getty.edu/ulan/00018029']
# resulting q class is http://www.wikidata.org/entity/Q296265
# Filippo Brunelleschi ['http://vocab.getty.edu/ulan/00018169']
# resulting q class is http://www.wikidata.org/entity/Q174330
# Flemish School []
# Florentine Master []
# Francesco Barberino ['http://viaf.org/viaf/88671516']
# resulting q class is http://www.wikidata.org/entity/Q20056517
# Francesco Cossa ['http://vocab.getty.edu/ulan/00028661']
# resulting q class is http://www.wikidata.org/entity/Q454892
# Francesco Maffei ['http://vocab.getty.edu/ulan/00003207']
# resulting q class is http://www.wikidata.org/entity/Q3289164
# Francesco Terribilia []
# resulting q class is http://www.wikidata.org/entity/Q14823536
# Francesco Traini ['http://vocab.getty.edu/ulan/00004742']
# resulting q class is http://www.wikidata.org/entity/Q673516
# Francesco Vanni ['http://vocab.getty.edu/ulan/00012526']
# resulting q class is http://www.wikidata.org/entity/Q960581
# Franchinus Gaforius ['http://viaf.org/viaf/71536697']
# Francisco de Ollanda ['http://viaf.org/viaf/68951231']
# Franco Cardini []
# resulting q class is http://www.wikidata.org/entity/Q167125
# François Charles Savinien Petit ['http://vocab.getty.edu/ulan/500096835']
# resulting q class is http://www.wikidata.org/entity/Q56025054
# François Perrier ['http://viaf.org/viaf/88062009']
# resulting q class is http://www.wikidata.org/entity/Q82566
# Frédéric de Clarac ['http://viaf.org/viaf/22357212']
# resulting q class is http://www.wikidata.org/entity/Q1960518
# Fritz Saxl ['http://vocab.getty.edu/ulan/500288493']
# resulting q class is http://www.wikidata.org/entity/Q78900
# G. B. Fulgosus ['http://viaf.org/viaf/74284252']
# G. Wingendorp []
# resulting q class is http://www.wikidata.org/entity/Q112455120
# Galeazzo Maria Sforza []
# resulting q class is http://www.wikidata.org/entity/Q317894
# Georg Wilhelm Kolbe []
# Gherardo Silvani []
# resulting q class is http://www.wikidata.org/entity/Q1107769
# Giacomo Barozzi da Vignola []
# resulting q class is http://www.wikidata.org/entity/Q297565
# Giambologna []
# resulting q class is http://www.wikidata.org/entity/Q220136
# Gian Lorenzo Bernini ['http://vocab.getty.edu/ulan/00032022']
# resulting q class is http://www.wikidata.org/entity/Q160538
# Giorgio Vasari ['http://vocab.getty.edu/ulan/00017608']
# resulting q class is http://www.wikidata.org/entity/Q128027
# Giotto ['http://vocab.getty.edu/ulan/00010766']
# resulting q class is http://www.wikidata.org/entity/Q7814
# Giovanni Battista Cipriani []
# resulting q class is http://www.wikidata.org/entity/Q2687759
# Giovanni Paolo Pannini ['http://vocab.getty.edu/ulan/00018296']
# resulting q class is http://www.wikidata.org/entity/Q286670
# Giovanni Pisano ['http://vocab.getty.edu/ulan/00017740']
# resulting q class is http://www.wikidata.org/entity/Q314932
# Giovanni Rost ['http://vocab.getty.edu/ulan/00102719']
# Giovanni Stradano ['http://vocab.getty.edu/ulan/500011304']
# resulting q class is http://www.wikidata.org/entity/Q143595
# Giovanni Zacchi ['http://vocab.getty.edu/ulan/500123449']
# resulting q class is http://www.wikidata.org/entity/Q97853365
# Girolamo Olgiati ['http://vocab.getty.edu/ulan/00093176']
# resulting q class is http://www.wikidata.org/entity/Q19985008
# Giulio Romano ['http://vocab.getty.edu/ulan/00115304']
# resulting q class is http://www.wikidata.org/entity/Q215305
# Giuseppe Arcimboldo ['http://vocab.getty.edu/ulan/00028171']
# resulting q class is http://www.wikidata.org/entity/Q7751
# Gregorio de Gregorii ['http://viaf.org/viaf/34610850']
# Guercino ['http://vocab.getty.edu/ulan/500021925']
# resulting q class is http://www.wikidata.org/entity/Q334262
# Hans Holbein the Younger ['http://vocab.getty.edu/ulan/00005259']
# resulting q class is http://www.wikidata.org/entity/Q48319
# Honoré Fragonard []
# resulting q class is http://www.wikidata.org/entity/Q127171
# Hrabanus Maurus ['http://viaf.org/viaf/95147534']
# resulting q class is http://www.wikidata.org/entity/Q160441
# J. Eck ['https://bp16.bnf.fr/12519521/johannes_eck/']
# resulting q class is http://www.wikidata.org/entity/Q13474163
# J. M. S. Bence ['no']
# Jacobus Typotius ['http://viaf.org/viaf/37350321']
# resulting q class is http://www.wikidata.org/entity/Q6119895
# Jacopo Capcasa di Codeca []
# Jacopo Caraglio ['http://vocab.getty.edu/ulan/00455967']
# resulting q class is http://www.wikidata.org/entity/Q705640
# Jacopo del Sellaio ['http://vocab.getty.edu/ulan/00023242']
# resulting q class is http://www.wikidata.org/entity/Q2525549
# Jacopo Pesellino []
# Jacquemart de Hesdin ['http://vocab.getty.edu/ulan/00018216']
# resulting q class is http://www.wikidata.org/entity/Q2211325
# Jan Collaert ['http://vocab.getty.edu/ulan/500355195']
# resulting q class is http://www.wikidata.org/entity/Q571313
# Jan van Campen ['http://vocab.getty.edu/ulan/500115589']
# resulting q class is http://www.wikidata.org/entity/Q6265913
# Jan van Eyck ['http://vocab.getty.edu/ulan/00116209']
# resulting q class is http://www.wikidata.org/entity/Q102272
# Jean Bondol ['http://vocab.getty.edu/ulan/00121790']
# resulting q class is http://www.wikidata.org/entity/Q1370613
# Jean Jérôme Baugean ['http://vocab.getty.edu/ulan/500003653']
# resulting q class is http://www.wikidata.org/entity/Q3166576
# Jean Pucelle ['http://vocab.getty.edu/ulan/00115647']
# resulting q class is http://www.wikidata.org/entity/Q175888
# Johannes Vermeer []
# resulting q class is http://www.wikidata.org/entity/Q41264
# John Theodore Heins ['http://vocab.getty.edu/ulan/500004409']
# resulting q class is http://www.wikidata.org/entity/Q16842181
# John VIII Palaiologos []
# resulting q class is http://www.wikidata.org/entity/Q37062
# Keith Christiansen []
# resulting q class is http://www.wikidata.org/entity/Q6384197
# L. Begerus ['http://worldcat.org/identities/np-begerus,%20laurentius/']
# Leon Battista Alberti ['http://vocab.getty.edu/ulan/00002025']
# resulting q class is http://www.wikidata.org/entity/Q182046
# Limbourg brothers ['http://vocab.getty.edu/ulan/00486541']
# Lorenzo de' Medici ['http://vocab.getty.edu/ulan/500114960']
# resulting q class is http://www.wikidata.org/entity/Q177854
# Lucas Cranach the Elder ['http://vocab.getty.edu/ulan/00115364']
# resulting q class is http://www.wikidata.org/entity/Q191748
# Ludovico Cigoli ['http://vocab.getty.edu/ulan/00115264']
# resulting q class is http://www.wikidata.org/entity/Q928350
# Lysippus ['http://vocab.getty.edu/ulan/00012332']
# resulting q class is http://www.wikidata.org/entity/Q192222
# M. Welser []
# Maerten van Heemskerck ['http://vocab.getty.edu/ulan/00124291']
# resulting q class is http://www.wikidata.org/entity/Q538350
# Maitre des Heures du Maréchal de Boucicaut ['http://vocab.getty.edu/ulan/00019456']
# resulting q class is http://www.wikidata.org/entity/Q894982
# Maitre des Heures du Maréchal de Boucicaut (workshop) []
# Marcantonio Raimondi ['http://vocab.getty.edu/ulan/00030773']
# resulting q class is http://www.wikidata.org/entity/Q728375
# Masaccio ['http://vocab.getty.edu/ulan/00026649']
# resulting q class is http://www.wikidata.org/entity/Q5811
# Master Gilabertus ['http://viaf.org/viaf/95701300']
# resulting q class is http://www.wikidata.org/entity/Q98673410
# Master Wiligelmus []
# Medeo da Siena []
# Member of the Zacchia Family []
# Michael Scotus ['http://viaf.org/viaf/37028785']
# resulting q class is http://www.wikidata.org/entity/Q559548
# Michelangelo ['http://vocab.getty.edu/ulan/00010654']
# resulting q class is http://www.wikidata.org/entity/Q5592
# Niccolò Fiorentino ['http://vocab.getty.edu/ulan/00002432']
# resulting q class is http://www.wikidata.org/entity/Q16582310
# Niccolò Soggi ['http://vocab.getty.edu/ulan/00000363']
# resulting q class is http://www.wikidata.org/entity/Q1347662
# Nicola Pisano ['http://vocab.getty.edu/ulan/00004862']
# resulting q class is http://www.wikidata.org/entity/Q364413
# Nicolas Béatrizet ['http://vocab.getty.edu/ulan/00013977']
# resulting q class is http://www.wikidata.org/entity/Q461143
# Nicolas Poussin ['http://vocab.getty.edu/ulan/00005036']
# resulting q class is http://www.wikidata.org/entity/Q41554
# North Italian Master []
# Opicinus de Canistris ['http://vocab.getty.edu/ulan/00066578']
# resulting q class is http://www.wikidata.org/entity/Q3354174
# Otho Venius ['http://vocab.getty.edu/ulan/00005170']
# resulting q class is http://www.wikidata.org/entity/Q785355
# Ovidius ['http://viaf.org/viaf/88342447']
# Pietro Santi Bartoli ['http://viaf.org/viaf/120695133']
# resulting q class is http://www.wikidata.org/entity/Q1106798
# Palladio ['http://vocab.getty.edu/ulan/00021650']
# resulting q class is http://www.wikidata.org/entity/Q177692
# Paris Bordone ['http://vocab.getty.edu/ulan/00018343']
# resulting q class is http://www.wikidata.org/entity/Q366081
# Paul Decker []
# resulting q class is http://www.wikidata.org/entity/Q1798811
# Petrarch []
# resulting q class is http://www.wikidata.org/entity/Q1401
# Petrus Apianus []
# resulting q class is http://www.wikidata.org/entity/Q58662
# Pierio Valeriano []
# resulting q class is http://www.wikidata.org/entity/Q710070
# Piero de' Medici ['http://vocab.getty.edu/ulan/500356780']
# resulting q class is http://www.wikidata.org/entity/Q299663
# Piero della Francesca ['http://vocab.getty.edu/ulan/00006339']
# resulting q class is http://www.wikidata.org/entity/Q5822
# Piero di Cosimo ['http://vocab.getty.edu/ulan/00007508']
# resulting q class is http://www.wikidata.org/entity/Q280851
# Pieter Brueghel the Elder ['http://vocab.getty.edu/ulan/00013247']
# resulting q class is http://www.wikidata.org/entity/Q43270
# Pietro Lorenzetti ['http://vocab.getty.edu/ulan/00030946']
# resulting q class is http://www.wikidata.org/entity/Q309635
# Pietro Lorenzetti (workshop) []
# Prudentius []
# resulting q class is http://www.wikidata.org/entity/Q347250
# Raphael ['http://vocab.getty.edu/ulan/00023578']
# resulting q class is http://www.wikidata.org/entity/Q5597
# Remigius of Auxerre ['http://viaf.org/viaf/121885360']
# resulting q class is http://www.wikidata.org/entity/Q1383306
# Roelof van Straten []
# resulting q class is http://www.wikidata.org/entity/Q93234030
# Rogier van der Weyden ['http://vocab.getty.edu/ulan/00008384']
# resulting q class is http://www.wikidata.org/entity/Q68631
# Rossellino (school of) []
# Rosso Fiorentino ['http://vocab.getty.edu/ulan/00014451']
# resulting q class is http://www.wikidata.org/entity/Q312617
# Rubens ['http://vocab.getty.edu/ulan/00002921']
# resulting q class is http://www.wikidata.org/entity/Q5599
# Sandro Botticelli ['http://vocab.getty.edu/ulan/00015254']
# resulting q class is http://www.wikidata.org/entity/Q5669
# Sebastiano Serlio []
# resulting q class is http://www.wikidata.org/entity/Q452318
# Sigismondo Malatesta []
# resulting q class is http://www.wikidata.org/entity/Q7512161
# Sigismund of Luxemburg []
# resulting q class is http://www.wikidata.org/entity/Q57124
# Sofia Baroncini []
# St. Augustine ['http://viaf.org/viaf/66806872']
# resulting q class is http://www.wikidata.org/entity/Q8018
# Stephan Arndes ['http://viaf.org/viaf/89028883']
# resulting q class is http://www.wikidata.org/entity/Q104068
# Stephen Hawes []
# resulting q class is http://www.wikidata.org/entity/Q2919718
# Sufi []
# Taddeo Gaddi ['http://vocab.getty.edu/ulan/00115669']
# resulting q class is http://www.wikidata.org/entity/Q315835
# Thomas Regnaudin []
# resulting q class is http://www.wikidata.org/entity/Q1069787
# Thomasin von Zerclaere []
# resulting q class is http://www.wikidata.org/entity/Q95615
# Tiziano Vecellio ['http://vocab.getty.edu/ulan/00031075']
# resulting q class is http://www.wikidata.org/entity/Q47551
# Tiziano Vecellio (and helpers) []
# Tommaso Laureti []
# resulting q class is http://www.wikidata.org/entity/Q357886
# Victor Texier ['http://viaf.org/viaf/229817826']
# Villard de Honnecourt ['http://vocab.getty.edu/ulan/00030504']
# resulting q class is http://www.wikidata.org/entity/Q366502
# Vincenzo Cartari ['http://vocab.getty.edu/ulan/00315492']
# resulting q class is http://www.wikidata.org/entity/Q2526869
# Vincenzo Valgrisi ['http://viaf.org/viaf/38966046']
# resulting q class is http://www.wikidata.org/entity/Q4013565
# Vitruvius []
# resulting q class is http://www.wikidata.org/entity/Q47163
# Wechel []
# William Hogarth ['http://vocab.getty.edu/ulan/500004242']
# resulting q class is http://www.wikidata.org/entity/Q171344
# Erwin Panofsky []
# resulting q class is http://www.wikidata.org/entity/Q57656
# I. J. S. Taylor []
# Homerus []
# Gaius Valerius Catullus ['http://viaf.org/viaf/100218993']
# resulting q class is http://www.wikidata.org/entity/Q163079
# Sidonius []
# Claudianus ['http://viaf.org/viaf/246763674']
# resulting q class is http://www.wikidata.org/entity/Q205947
# Jodocus Hondius []
# resulting q class is http://www.wikidata.org/entity/Q454603
# Walter Liedtke []
# resulting q class is http://www.wikidata.org/entity/Q18968254
# Cesare Vecellio ['http://viaf.org/viaf/17378621']
# resulting q class is http://www.wikidata.org/entity/Q549400
# Giovanni Giacomo De Rossi []
# resulting q class is http://www.wikidata.org/entity/Q12631500
# Un Père Capucin []
# Gioanna da Piacenza ['https://www.wikidata.org/wiki/Q3766265']
# Aratus []
# resulting q class is http://www.wikidata.org/entity/Q180671
# Saint Luke []
# resulting q class is http://www.wikidata.org/entity/Q128538
# Yrjö Hirn []
# resulting q class is http://www.wikidata.org/entity/Q5400516
# Pier Donato Cesi []
# resulting q class is http://www.wikidata.org/entity/Q1772401
# Irving Lavin []
# resulting q class is http://www.wikidata.org/entity/Q19753933
# Rudolf Wittkower []
# resulting q class is http://www.wikidata.org/entity/Q215999
# Virgil []
# resulting q class is http://www.wikidata.org/entity/Q1398
# Isaiah []
# Lorenzo Lotto []
# resulting q class is http://www.wikidata.org/entity/Q310973
# Remigus []
# resulting q class is http://www.wikidata.org/entity/Q2142997
# Benoît de Sainte-Maure []
# resulting q class is http://www.wikidata.org/entity/Q435578
# Guido da Colonna []
# Jacopino di Francesco []
# resulting q class is http://www.wikidata.org/entity/Q65781402
# Orazio Vecellio []
# resulting q class is http://www.wikidata.org/entity/Q7099974
# Marco Vecellio []
# resulting q class is http://www.wikidata.org/entity/Q1232470
# Filippo Baldinucci []
# resulting q class is http://www.wikidata.org/entity/Q979574
# Cimabue []
# resulting q class is http://www.wikidata.org/entity/Q15790
# Albrecht Dürer (workshop) []
# Aby Warburg []
# resulting q class is http://www.wikidata.org/entity/Q60185
# Lorenzo di Pierfrancesco de' Medici []
# resulting q class is http://www.wikidata.org/entity/Q1379683
# Francesco del Pugliese []
# resulting q class is http://www.wikidata.org/entity/Q3749898
# Giovanni Vespucci []
# resulting q class is http://www.wikidata.org/entity/Q17064119
# Goya []
# resulting q class is http://www.wikidata.org/entity/Q5432
# Nino Pisano []
# resulting q class is http://www.wikidata.org/entity/Q2273927
# Tommaso Cavalieri []
# resulting q class is http://www.wikidata.org/entity/Q538960
# Atalanta Baglioni []
# resulting q class is http://www.wikidata.org/entity/Q21529483
# J. Wilde []
# resulting q class is http://www.wikidata.org/entity/Q1375268
# Conrad Celtis []
# Eusthatius Makrembolites []
# Angelo Poliziano []
# resulting q class is http://www.wikidata.org/entity/Q250414
# Horapollo []
# resulting q class is http://www.wikidata.org/entity/Q364379
# Servius []
# resulting q class is http://www.wikidata.org/entity/Q355350
# Cristoforo Landino []
# resulting q class is http://www.wikidata.org/entity/Q711964
# Hieronymus Tetius []
# resulting q class is http://www.wikidata.org/entity/Q29348142
# Pico della Mirandola []
# resulting q class is http://www.wikidata.org/entity/Q182128
# Lucretius []
# resulting q class is http://www.wikidata.org/entity/Q47154
# Petrus Berchorius []
# resulting q class is http://www.wikidata.org/entity/Q1370726
# Statius []
# Boccaccio []
# resulting q class is http://www.wikidata.org/entity/Q1402
# Marsilio Ficino []
# resulting q class is http://www.wikidata.org/entity/Q192374
# Lucianus []
# resulting q class is http://www.wikidata.org/entity/Q177847
# Hesiod []
# resulting q class is http://www.wikidata.org/entity/Q44233
# Pausanias []
# resulting q class is http://www.wikidata.org/entity/Q192931
# Sannazzaro []
# Berchorius []
# resulting q class is http://www.wikidata.org/entity/Q1370726
# Theocritus []
# resulting q class is http://www.wikidata.org/entity/Q219484
# Saint Matthew []
# Hugh of St.-Victor []
# A. E. Austin []
# resulting q class is http://www.wikidata.org/entity/Q104286270
# R. van Marle []
# L. Venturi []
# The bride []
# The husband []

# %%
# store the first reconciliation with wd in a json
with open('people_wd_match.json', mode='w', encoding="utf-8") as jsonfile:
    json.dump(peopleDict, jsonfile)

# %% [markdown]
# ### Manual check of the alignment
# from the list printed, manually check if the aligned term is correct. If not, remove the aligned term from the dictionary.

# %%
# if the vocabulary is opened from the json
with open('people_wd_match.json', mode='r', encoding="utf-8") as jsonfile:
    people = json.load(jsonfile) # use as a dictionary
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-4b1e0611b869> in <module>
#       1 # if the vocabulary is opened from the json
# ----> 2 with open('people_wd_match.json', mode='r', encoding="utf-8") as jsonfile:
#       3     people = json.load(jsonfile) # use as a dictionary
#
# FileNotFoundError: [Errno 2] No such file or directory: 'people_wd_match.json'

# %%
# a hand check of the correctness of the aligned classes is needed. first error: J. Eck, "https://www.wikidata.org/entity/Q13474163"

to_be_removed = []
to_be_removed.append(("J. Eck rec", "http://www.wikidata.org/entity/Q13474163"))
# to_be_removed.append(("J. Eck rec", "http://www.wikidata.org/entity/Q280432"))
to_be_removed.append(("Francesco Barberino rec", "http://www.wikidata.org/entity/Q20056517"))
to_be_removed.append(("Girolamo Olgiati rec", "http://www.wikidata.org/entity/Q19985008"))
to_be_removed.append(("Jan Collaert rec", "http://vocab.getty.edu/ulan/500355195")) # changed in spreadsheet in Jan Collaert II
to_be_removed.append(("Jan Collaert rec", "http://www.wikidata.org/entity/Q571313"))
to_be_removed.append(("Jan van Campen rec", "http://vocab.getty.edu/ulan/500115589"))
to_be_removed.append(("Jan van Campen rec", "http://www.wikidata.org/entity/Q6265913"))
to_be_removed.append(("Keith Christiansen rec", "http://www.wikidata.org/entity/Q6384197"))
to_be_removed.append(("Paul Decker rec", "http://www.wikidata.org/entity/Q1798811"))
to_be_removed.append(("Remigus rec", "http://www.wikidata.org/entity/Q2142997"))
to_be_removed.append(("J. Wilde rec", "http://www.wikidata.org/entity/Q1375268"))
to_be_removed.append(("A. E. Austin rec", "http://www.wikidata.org/entity/Q104286270"))


peopleDict2 = remove_add_terms(peopleDict, to_be_removed, "remove")

to_be_added = []
to_be_added.append(("Jan Collaert rec", "http://vocab.getty.edu/ulan/500040711"))
to_be_added.append(("Jan van Campen rec", "http://vocab.getty.edu/page/ulan/500115589"))
peopleDict3 = remove_add_terms(peopleDict2, to_be_added, "add")

# %% [markdown]
# Second reconciliation: if we have the WD term, we align also ULAN and VIAF

# %%
ulan_query = """SELECT ?term WHERE{<toBeReplaced> wdt:P245 ?term.}""" # verify if the resulting wd term is a link or is with wd prefix
viaf_query = """SELECT ?term WHERE{<toBeReplaced> wdt:P214 ?term.}""" 
variables = ["term"]

def alignments_through_wd(dictionary, query, variable_list, endpoint, url_string): 
  all_items = dictionary.items() # ordered dict of tuples
  for item in all_items: # tuple with key-value pairs
    if type(item[1]) == list: 
      for el in item[1]: # item[1]
        if el.startswith("http://www.wikidata.org/entity/"): # in this way, we also filter automatically also the " rec" keys
          print(el, item[0])
          cleaned_el = el.replace("\"","")
          final_query = query.replace("toBeReplaced", cleaned_el)
          res = sparql_query_setting(final_query, endpoint)
          for result in res["results"]["bindings"]:
            for var in variable_list: 
              aligned = url_string+result[var]["value"]
              print(aligned)
              if aligned not in dictionary[item[0]]: 
                dictionary[item[0]].append(aligned)
  return(dictionary)

        # idea: if the wd term was reconciled, than we take the ulan or viaf alignment
#ulan_aligned = alignments_through_wd(peopleDict, ulan_query, variables, wikidata_endpoint, "http://vocab.getty.edu/ulan/")

# %%
ulan_aligned = alignments_through_wd(peopleDict3, ulan_query, variables, wikidata_endpoint, "http://vocab.getty.edu/ulan/")
viaf_aligned = alignments_through_wd(peopleDict3, viaf_query, variables, wikidata_endpoint, "http://viaf.org/viaf/")

# %%
print(peopleDict3)

# %%
# one link was wrong: final fixing
to_be_removed = []
to_be_removed.append(("Agesander rec", "http://vocab.getty.edu/page/500021781"))

peopleDict4 = remove_add_terms(peopleDict3, to_be_removed, "remove")

# %%
# stop words and others removal. After this passage: ready to reconcile

def rumor_removal(dictionary):
  for item in dictionary.items(): 
    if type(item[1]) == list: 
      for element in item[1]: 
        if not element.startswith("http"): 
          item[1].remove(element)
  return(dictionary)

peopleDictFinal = rumor_removal(peopleDict4)

# %%
print(peopleDictFinal)

# %%
# store the first reconciliation with wd in a json
with open('people_final_match.json', mode='w', encoding="utf-8") as jsonfile:
    json.dump(peopleDictFinal, jsonfile)

# %% [markdown]
# ## Characters reconciliation with Wikidata, VIAF, Getty IA, Iconclass

# %%
#characterDict5 = rumor_removal(characterDict4)
print(characterDict5)
characterDict6 = rumor_removal(characterDict5)
storage = store_in_json("character_wd_first_alignment.json", characterDict6)
# Out:
# {'Adam': 'http://icondataset.org/adam', 'Adam rec': ['https://iconclass.org/11I62(ADAM)', 'http://www.wikidata.org/entity/Q69488', 'stop wd'], 'Aeneas': 'http://icondataset.org/aeneas', 'Aeneas rec': ['https://iconclass.org/96C(AENEAS)', 'http://www.wikidata.org/entity/Q82732', 'stop wd'], 'Aeolus': 'http://icondataset.org/aeolus', 'Aeolus rec': ['http://www.wikidata.org/entity/Q172549', 'stop wd'], 'Aglauros': 'http://icondataset.org/aglauros', 'Aglauros rec': ['http://www.wikidata.org/entity/Q368994', 'stop wd'], 'Aion/Phanes': 'http://icondataset.org/aion/phanes', 'Aion/Phanes rec': ['http://www.iconclass.org/rkd/91A14%28AION%29/', 'stop wd'], 'Anteros': 'http://icondataset.org/anteros', 'Anteros rec': ['http://www.iconclass.org/rkd/92D1911/', 'http://www.wikidata.org/entity/Q572133', 'stop wd'], 'Antiphas, son of Laoocoon': 'http://icondataset.org/antiphas-son-of-laoocoon', 'Antiphas, son of Laoocoon rec': ['stop wd'], 'Antoninus Pius': 'http://icondataset.org/antoninus-pius', 'Antoninus Pius rec': ['http://www.wikidata.org/entity/Q1429', 'stop wd'], 'Apollo': 'http://icondataset.org/apollo', 'Apollo rec': ['https://iconclass.org/92B3', 'stop wd', 'http://www.wikidata.org/entity/Q37340'], 'Apollo god of Sun': 'http://icondataset.org/apollo-god-of-sun', 'Apollo god of Sun rec': ['stop wd'], 'Apollo Medicus or Aesculapius': 'http://icondataset.org/apollo-medicus-or-aesculapius', 'Apollo Medicus or Aesculapius rec': ['stop wd'], 'Apostles': 'http://icondataset.org/apostles', 'Apostles rec': ['stop wd', 'http://www.wikidata.org/entity/Q4155679'], 'Archangel Gabriel': 'http://icondataset.org/archangel-gabriel', 'Archangel Gabriel rec': ['stop wd', 'http://www.wikidata.org/entity/Q81989'], 'Argus': 'http://icondataset.org/argus', 'Argus rec': ['stop wd', 'http://www.wikidata.org/entity/Q189821'], 'Ariadne': 'http://icondataset.org/ariadne', 'Ariadne rec': ['https://iconclass.org/95B(ARIADNE)', 'stop wd', 'http://www.wikidata.org/entity/Q184874'], 'Athene': 'http://icondataset.org/athene', 'Athene rec': ['stop wd', 'http://www.wikidata.org/entity/Q37122'], 'bacchant': 'http://icondataset.org/bacchant', 'bacchant rec': ['https://iconclass.org/92L1912', 'stop wd', 'http://www.wikidata.org/entity/Q2878203'], 'Bacchus': 'http://icondataset.org/bacchus', 'Bacchus rec': ['https://iconclass.org/92L1', 'stop wd', 'http://www.wikidata.org/entity/Q645312'], 'Bishop Simone Saltarelli': 'http://icondataset.org/bishop-simone-saltarelli', 'Bishop Simone Saltarelli rec': ['stop wd'], 'Blindfold Cupid': 'http://icondataset.org/blindfold-cupid', 'Blindfold Cupid rec': ['http://www.iconclass.org/rkd/92D18%28BLINDFOLD%29/', 'stop wd'], 'Cacus': 'http://icondataset.org/cacus', 'Cacus rec': ['stop wd', 'http://www.wikidata.org/entity/Q754686'], 'Cerberus': 'http://icondataset.org/cerberus', 'Cerberus rec': ['stop wd', 'http://www.wikidata.org/entity/Q83496'], 'Christ': 'http://icondataset.org/christ', 'Christ rec': ['stop wd', 'http://www.wikidata.org/entity/Q302'], 'Christ as a child': 'http://icondataset.org/christ-as-a-child', 'Christ as a child rec': ['stop wd', 'http://www.wikidata.org/entity/Q104586046'], 'Companion of Serapis': 'http://icondataset.org/companion-of-serapis', 'Companion of Serapis rec': ['stop wd'], 'crocodile': 'http://icondataset.org/crocodile', 'crocodile rec': ['https://iconclass.org/25F43', 'stop wd', 'http://www.wikidata.org/entity/Q2535664'], 'Cybele': 'http://icondataset.org/cybele', 'Cybele rec': ['stop wd', 'http://www.wikidata.org/entity/Q188236'], 'David': 'http://icondataset.org/david', 'David rec': ['https://iconclass.org/71H', 'stop wd', 'http://www.wikidata.org/entity/Q83155'], 'Devil': 'http://icondataset.org/devil', 'Devil rec': ['stop wd', 'http://www.wikidata.org/entity/Q6674'], 'Diana': 'http://icondataset.org/diana', 'Diana rec': ['https://iconclass.org/92C3', 'stop wd', 'http://www.wikidata.org/entity/Q132543'], 'Dido': 'http://icondataset.org/dido', 'Dido rec': ['https://iconclass.org/96D(DIDO)', 'stop wd ...

# %%
wd_character_query = { # nb:applying only to wikidata. Every API has its own parameters. 
        "action": "wbsearchentities",
        "format": "json",
        "language": "en",
        "search": "toBeReplaced"
    }


character = reconciliation_function(characterDict5, wd_character_query, wikidata_endpoint)
# Out:
# Apollo resulting q class is http://www.wikidata.org/entity/Q37340
# Apostles resulting q class is http://www.wikidata.org/entity/Q4155679
# Archangel Gabriel resulting q class is http://www.wikidata.org/entity/Q81989
# Argus resulting q class is http://www.wikidata.org/entity/Q189821
# Ariadne resulting q class is http://www.wikidata.org/entity/Q184874
# Athene resulting q class is http://www.wikidata.org/entity/Q37122
# bacchant resulting q class is http://www.wikidata.org/entity/Q2878203
# Bacchus resulting q class is http://www.wikidata.org/entity/Q645312
# Cacus resulting q class is http://www.wikidata.org/entity/Q754686
# Cerberus resulting q class is http://www.wikidata.org/entity/Q83496
# Christ resulting q class is http://www.wikidata.org/entity/Q302
# Christ as a child resulting q class is http://www.wikidata.org/entity/Q104586046
# crocodile resulting q class is http://www.wikidata.org/entity/Q2535664
# Cybele resulting q class is http://www.wikidata.org/entity/Q188236
# David resulting q class is http://www.wikidata.org/entity/Q83155
# Devil resulting q class is http://www.wikidata.org/entity/Q6674
# Diana resulting q class is http://www.wikidata.org/entity/Q132543
# Dido resulting q class is http://www.wikidata.org/entity/Q905162
# Dionysus resulting q class is http://www.wikidata.org/entity/Q41680
# Erato resulting q class is http://www.wikidata.org/entity/Q104413
# Erymanthian Boar resulting q class is http://www.wikidata.org/entity/Q334456
# Europa resulting q class is http://www.wikidata.org/entity/Q3143
# Eve resulting q class is http://www.wikidata.org/entity/Q830183
# Fedro resulting q class is http://www.wikidata.org/entity/Q52166
# Flora resulting q class is http://www.wikidata.org/entity/Q131449
# Four Saints resulting q class is http://www.wikidata.org/entity/Q3927386
# Ganymede resulting q class is http://www.wikidata.org/entity/Q3169
# Giuliano de' Medici resulting q class is http://www.wikidata.org/entity/Q298877
# God resulting q class is http://www.wikidata.org/entity/Q178885
# God's hand resulting q class is http://www.wikidata.org/entity/Q58728036
# Hecuba resulting q class is http://www.wikidata.org/entity/Q193433
# Helen resulting q class is http://www.wikidata.org/entity/Q164061
# Hercules resulting q class is http://www.wikidata.org/entity/Q10448
# Herse resulting q class is http://www.wikidata.org/entity/Q16968
# Hylas resulting q class is http://www.wikidata.org/entity/Q332752
# Ixion resulting q class is http://www.wikidata.org/entity/Q271891
# Jest resulting q class is http://www.wikidata.org/entity/Q371174
# Joachim resulting q class is http://www.wikidata.org/entity/Q4926961
# Judith resulting q class is http://www.wikidata.org/entity/Q5954149
# Jupiter resulting q class is http://www.wikidata.org/entity/Q34201
# Jupiter as an eagle resulting q class is http://www.wikidata.org/entity/Q63851811
# Laocoon resulting q class is http://www.wikidata.org/entity/Q151100
# Leach resulting q class is http://www.wikidata.org/entity/Q472470
# Lorenzo de' Medici resulting q class is http://www.wikidata.org/entity/Q177854
# Marine snakes resulting q class is http://www.wikidata.org/entity/Q101635953
# Mars resulting q class is http://www.wikidata.org/entity/Q111
# Mary resulting q class is http://www.wikidata.org/entity/Q345
# Mercury resulting q class is http://www.wikidata.org/entity/Q308
# Mida resulting q class is http://www.wikidata.org/entity/Q24769763
# Minerva resulting q class is http://www.wikidata.org/entity/Q126916
# Moses resulting q class is http://www.wikidata.org/entity/Q9077
# Muses resulting q class is http://www.wikidata.org/entity/Q66016
# Mithras resulting q class is http://www.wikidata.org/entity/Q219903
# Neptune resulting q class is http://www.wikidata.org/entity/Q332
# Noah resulting q class is http://www.wikidata.org/entity/Q81422
# Nymphs resulting q class is http://www.wikidata.org/entity/Q373916
# Olympian Gods resulting q class is http://www.wikidata.org/entity/Q3012134
# Orpheus resulting q class is http://www.wikidata.org/entity/Q174353
# Pan resulting q class is http://www.wikidata.org/entity/Q651690
# Paris resulting q class is http://www.wikidata.org/entity/Q90
# Perseus resulting q class is http://www.wikidata.org/entity/Q10511
# Phaeton resulting q class is http://www.wikidata.org/entity/Q203480
# Pluto resulting q class is http://www.wikidata.org/entity/Q339
# Polyxena resulting q class is http://www.wikidata.org/entity/Q750236
# Pope Julius II resulting q class is http://www.wikidata.org/entity/Q80516
# Prometheus resulting q class is http://www.wikidata.org/entity/Q83160
# Prophet resulting q class is http://www.wikidata.org/entity/Q42857
# Proserpina resulting q class is http://www.wikidata.org/entity/Q14515330
# puer mingens resulting q class is http://www.wikidata.org/entity/Q85702867
# Pygmalion resulting q class is http://www.wikidata.org/entity/Q192343
# Rachel resulting q class is http://www.wikidata.org/entity/Q935489
# Rhea resulting q class is http://www.wikidata.org/entity/Q15050
# Roman emperors resulting q class is http://www.wikidata.org/entity/Q7361956
# Saint Anne resulting q class is http://www.wikidata.org/entity/Q164294
# Saint Basilius resulting q class is http://www.wikidata.org/entity/Q112163561
# Saint Cosmas resulting q class is http://www.wikidata.org/entity/Q27697297
# Saint Damian resulting q class is http://www.wikidata.org/entity/Q11841130
# Saint John the Evangelist resulting q class is http://www.wikidata.org/entity/Q328804
# Saint Luke resulting q class is http://www.wikidata.org/entity/Q128538
# Saint Mark resulting q class is http://www.wikidata.org/entity/Q31966
# Saint Paul resulting q class is http://www.wikidata.org/entity/Q9200
# Saint Peter resulting q class is http://www.wikidata.org/entity/Q33923
# Salamander resulting q class is http://www.wikidata.org/entity/Q53663
# Satan resulting q class is http://www.wikidata.org/entity/Q35230
# Saturn resulting q class is http://www.wikidata.org/entity/Q193
# Satyr resulting q class is http://www.wikidata.org/entity/Q163709
# Serapis resulting q class is http://www.wikidata.org/entity/Q214554
# Silenus resulting q class is http://www.wikidata.org/entity/Q464091
# Simeon resulting q class is http://www.wikidata.org/entity/Q33923
# Sol Invictus resulting q class is http://www.wikidata.org/entity/Q214494
# Sybil resulting q class is http://www.wikidata.org/entity/Q4851022
# Sisyphus resulting q class is http://www.wikidata.org/entity/Q102561
# Tantalus resulting q class is http://www.wikidata.org/entity/Q182101
# The resurrected resulting q class is http://www.wikidata.org/entity/Q4126299
# The three Graces resulting q class is http://www.wikidata.org/entity/Q2268524
# Thisbe resulting q class is http://www.wikidata.org/entity/Q109954
# Tityus resulting q class is http://www.wikidata.org/entity/Q1933958
# Troilus resulting q class is http://www.wikidata.org/entity/Q867342
# Venus Pudica resulting q class is http://www.wikidata.org/entity/Q618535
# Venus Verticordia resulting q class is http://www.wikidata.org/entity/Q24055777
# Virgil resulting q class is http://www.wikidata.org/entity/Q1398
# Vulcan resulting q class is http://www.wikidata.org/entity/Q4640
# Zeus resulting q class is http://www.wikidata.org/entity/Q34201
# Venus resulting q class is http://www.wikidata.org/entity/Q313
# Cupid resulting q class is http://www.wikidata.org/entity/Q5011
# Angel resulting q class is http://www.wikidata.org/entity/Q235113
# Centaur resulting q class is http://www.wikidata.org/entity/Q83203
# Lapiths resulting q class is http://www.wikidata.org/entity/Q334794
# Angels resulting q class is http://www.wikidata.org/entity/Q743309
# Centaurs resulting q class is http://www.wikidata.org/entity/Q83203

# %%
characterDict = open_json("character_wd_first_alignment.json")

# %%
to_be_removed = []
to_be_removed.append(("Christ as a child rec", "http://www.wikidata.org/entity/Q104586046"))
to_be_removed.append(("Four Saints rec", "http://www.wikidata.org/entity/Q3927386"))
to_be_removed.append(("Ganymede rec", "http://www.wikidata.org/entity/Q3169"))
to_be_removed.append(("God rec", "http://www.wikidata.org/entity/Q178885"))
to_be_removed.append(("God's hand rec", "http://www.wikidata.org/entity/Q58728036"))
to_be_removed.append(("Hercules rec", "http://www.wikidata.org/entity/Q10448"))
to_be_removed.append(("Herse rec", "http://www.wikidata.org/entity/Q16968"))
to_be_removed.append(("Jest rec", "http://www.wikidata.org/entity/Q371174"))
to_be_removed.append(("Joachim rec", "http://www.wikidata.org/entity/Q4926961"))
to_be_removed.append(("Judith rec", "http://www.wikidata.org/entity/Q5954149"))
to_be_removed.append(("Jupiter rec", "http://www.wikidata.org/entity/Q63851811"))
to_be_removed.append(("Laocoon rec", "http://www.wikidata.org/entity/Q151100"))
to_be_removed.append(("Leach rec", "http://www.wikidata.org/entity/Q472470"))
to_be_removed.append(("Marine snakes rec", "http://www.wikidata.org/entity/Q101635953"))
to_be_removed.append(("Mars rec", "http://www.wikidata.org/entity/Q111"))
to_be_removed.append(("Mercury rec", "http://www.wikidata.org/entity/Q308"))
to_be_removed.append(("Mida rec", "http://www.wikidata.org/entity/Q24769763"))
to_be_removed.append(("Mithras rec", "http://www.wikidata.org/entity/Q219903"))
to_be_removed.append(("Neptune rec", "http://www.wikidata.org/entity/Q332Q332"))
to_be_removed.append(("Olympian Gods rec", "http://www.wikidata.org/entity/Q3012134"))
to_be_removed.append(("Pan rec", "http://www.wikidata.org/entity/Q651690"))
to_be_removed.append(("Paris rec", "http://www.wikidata.org/entity/Q90"))
to_be_removed.append(("Perseus rec", "http://www.wikidata.org/entity/Q10511"))
to_be_removed.append(("Pluto rec", "http://www.wikidata.org/entity/Q339"))
to_be_removed.append(("Rachel rec", "http://www.wikidata.org/entity/Q935489"))
to_be_removed.append(("Rhea rec", "http://www.wikidata.org/entity/Q15050"))
to_be_removed.append(("Roman emperors rec", "http://www.wikidata.org/entity/Q7361956"))
to_be_removed.append(("Saint Basilius rec", "http://www.wikidata.org/entity/Q112163561"))
to_be_removed.append(("Saint Cosmas rec", "http://www.wikidata.org/entity/Q27697297"))
to_be_removed.append(("Saturn rec", "http://www.wikidata.org/entity/Q193"))
to_be_removed.append(("Sybil rec", "http://www.wikidata.org/entity/Q4851022"))
to_be_removed.append(("The resurrected rec", "http://www.wikidata.org/entity/Q4126299"))
to_be_removed.append(("The three Graces rec", "http://www.wikidata.org/entity/Q2268524"))
to_be_removed.append(("Thisbe rec", "http://www.wikidata.org/entity/Q109954"))
to_be_removed.append(("Tityus rec", "http://www.wikidata.org/entity/Q1933958"))
to_be_removed.append(("Venus Pudica rec", "http://www.wikidata.org/entity/Q618535"))
to_be_removed.append(("Venus Verticordia rec", "http://www.wikidata.org/entity/Q24055777"))
to_be_removed.append(("Venus rec", "http://www.wikidata.org/entity/Q313"))
to_be_removed.append(("Angels rec", "http://www.wikidata.org/entity/Q743309"))
to_be_removed.append(("David rec", "http://www.wikidata.org/entity/Q83155"))
to_be_removed.append(("Europa rec", "http://www.wikidata.org/entity/Q3143"))
to_be_removed.append(("Flora rec", "http://www.wikidata.org/entity/Q131449"))



characterDict2 = remove_add_terms(characterDict, to_be_removed, "remove")

# add: 
to_be_added = []
to_be_added.append(("Flora rec", "https://www.wikidata.org/entity/Q209644"))
to_be_added.append(("God rec", "https://www.wikidata.org/entity/Q825"))
to_be_added.append(("Hercules rec", "https://www.wikidata.org/entity/Q122248"))
to_be_added.append(("Joachim rec", "https://www.wikidata.org/entity/Q314700"))
to_be_added.append(("Judith rec", "https://www.wikidata.org/entity/Q28532552"))
to_be_added.append(("Laocoon rec", "https://www.wikidata.org/entity/Q22878"))
to_be_added.append(("Mars rec", "https://www.wikidata.org/entity/Q112"))
to_be_added.append(("Mercury rec", "https://www.wikidata.org/entity/Q1150"))
to_be_added.append(("Mithras rec", "http://www.wikidata.org/entity/Q6497135"))
to_be_added.append(("Neptune rec", "http://www.wikidata.org/entity/Q3954"))
to_be_added.append(("Olympian Gods rec", "https://www.wikidata.org/entity/Q101609"))
to_be_added.append(("Pan rec", "http://www.wikidata.org/entity/Q132582"))
to_be_added.append(("Paris rec", "http://www.wikidata.org/entity/Q167646"))
to_be_added.append(("Perseus rec", "http://www.wikidata.org/entity/Q130832"))
to_be_added.append(("Pluto rec", "http://www.wikidata.org/entity/Q152262"))
to_be_added.append(("Rachel rec", "http://www.wikidata.org/entity/Q207389"))
to_be_added.append(("Rhea rec", "http://www.wikidata.org/entity/Q108419"))
to_be_added.append(("Saturn rec", "http://www.wikidata.org/entity/Q134388"))
to_be_added.append(("The three Graces rec", "http://www.wikidata.org/entity/Q184353"))
to_be_added.append(("Thisbe rec", "http://www.wikidata.org/entity/Q10696861"))
to_be_added.append(("Tityus rec", "http://www.wikidata.org/entity/Q656887"))
to_be_added.append(("Venus rec", "http://www.wikidata.org/entity/Q47652v"))

characterDict3 = remove_add_terms(characterDict2, to_be_added, "add")

# %%
# Second reconciliation: if we have the WD term, we align also ULAN and VIAF

ulan_query = """SELECT ?term WHERE{<toBeReplaced> wdt:P245 ?term.}""" # verify if the resulting wd term is a link or is with wd prefix
viaf_query = """SELECT ?term WHERE{<toBeReplaced> wdt:P214 ?term.}""" 
variables = ["term"]


        # idea: if the wd term was reconciled, than we take the ulan or viaf alignment
#ulan_aligned = alignments_through_wd(peopleDict, ulan_query, variables, wikidata_endpoint, "http://vocab.getty.edu/ulan/")

ulan_aligned = alignments_through_wd(characterDict4, ulan_query, variables, wikidata_endpoint, "http://vocab.getty.edu/ulan/")
viaf_aligned = alignments_through_wd(characterDict4, viaf_query, variables, wikidata_endpoint, "http://viaf.org/viaf/")

print(viaf_aligned)
# Out:
# http://www.wikidata.org/entity/Q69488 Adam rec
# http://www.wikidata.org/entity/Q82732 Aeneas rec
# http://www.wikidata.org/entity/Q172549 Aeolus rec
# http://www.wikidata.org/entity/Q368994 Aglauros rec
# http://www.wikidata.org/entity/Q572133 Anteros rec
# http://www.wikidata.org/entity/Q1429 Antoninus Pius rec
# http://vocab.getty.edu/ulan/500115700
# http://www.wikidata.org/entity/Q37340 Apollo rec
# http://www.wikidata.org/entity/Q4155679 Apostles rec
# http://www.wikidata.org/entity/Q81989 Archangel Gabriel rec
# http://www.wikidata.org/entity/Q189821 Argus rec
# http://www.wikidata.org/entity/Q184874 Ariadne rec
# http://www.wikidata.org/entity/Q37122 Athene rec
# http://www.wikidata.org/entity/Q2878203 bacchant rec
# http://www.wikidata.org/entity/Q645312 Bacchus rec
# http://www.wikidata.org/entity/Q754686 Cacus rec
# http://www.wikidata.org/entity/Q83496 Cerberus rec
# http://www.wikidata.org/entity/Q302 Christ rec
# http://www.wikidata.org/entity/Q2535664 crocodile rec
# http://www.wikidata.org/entity/Q188236 Cybele rec
# http://www.wikidata.org/entity/Q6674 Devil rec
# http://www.wikidata.org/entity/Q132543 Diana rec
# http://www.wikidata.org/entity/Q905162 Dido rec
# http://www.wikidata.org/entity/Q41680 Dionysus rec
# http://www.wikidata.org/entity/Q104413 Erato rec
# http://www.wikidata.org/entity/Q334456 Erymanthian Boar rec
# http://www.wikidata.org/entity/Q830183 Eve rec
# http://www.wikidata.org/entity/Q52166 Fedro rec
# http://www.wikidata.org/entity/Q298877 Giuliano de' Medici rec
# http://vocab.getty.edu/ulan/500356779
# http://www.wikidata.org/entity/Q193433 Hecuba rec
# http://www.wikidata.org/entity/Q164061 Helen rec
# http://www.wikidata.org/entity/Q332752 Hylas rec
# http://www.wikidata.org/entity/Q271891 Ixion rec
# http://www.wikidata.org/entity/Q34201 Jupiter rec
# http://www.wikidata.org/entity/Q63851811 Jupiter as an eagle rec
# http://www.wikidata.org/entity/Q177854 Lorenzo de' Medici rec
# http://vocab.getty.edu/ulan/500114960
# http://www.wikidata.org/entity/Q345 Mary rec
# http://www.wikidata.org/entity/Q126916 Minerva rec
# http://www.wikidata.org/entity/Q9077 Moses rec
# http://www.wikidata.org/entity/Q66016 Muses rec
# http://www.wikidata.org/entity/Q6497135 Mithras rec
# http://www.wikidata.org/entity/Q332 Neptune rec
# http://www.wikidata.org/entity/Q81422 Noah rec
# http://www.wikidata.org/entity/Q373916 Nymphs rec
# http://www.wikidata.org/entity/Q174353 Orpheus rec
# http://www.wikidata.org/entity/Q132582 Pan rec
# http://www.wikidata.org/entity/Q167646 Paris rec
# http://www.wikidata.org/entity/Q130832 Perseus rec
# http://www.wikidata.org/entity/Q203480 Phaeton rec
# http://www.wikidata.org/entity/Q152262 Pluto rec
# http://www.wikidata.org/entity/Q750236 Polyxena rec
# http://www.wikidata.org/entity/Q80516 Pope Julius II rec
# http://vocab.getty.edu/ulan/500281862
# http://www.wikidata.org/entity/Q83160 Prometheus rec
# http://www.wikidata.org/entity/Q42857 Prophet rec
# http://www.wikidata.org/entity/Q14515330 Proserpina rec
# http://www.wikidata.org/entity/Q85702867 puer mingens rec
# http://www.wikidata.org/entity/Q192343 Pygmalion rec
# http://www.wikidata.org/entity/Q207389 Rachel rec
# http://www.wikidata.org/entity/Q108419 Rhea rec
# http://www.wikidata.org/entity/Q164294 Saint Anne rec
# http://www.wikidata.org/entity/Q11841130 Saint Damian rec
# http://www.wikidata.org/entity/Q328804 Saint John the Evangelist rec
# http://www.wikidata.org/entity/Q128538 Saint Luke rec
# http://www.wikidata.org/entity/Q31966 Saint Mark rec
# http://www.wikidata.org/entity/Q9200 Saint Paul rec
# http://vocab.getty.edu/ulan/500372067
# http://www.wikidata.org/entity/Q33923 Saint Peter rec
# http://www.wikidata.org/entity/Q53663 Salamander rec
# http://www.wikidata.org/entity/Q35230 Satan rec
# http://www.wikidata.org/entity/Q134388 Saturn rec
# http://www.wikidata.org/entity/Q163709 Satyr rec
# http://www.wikidata.org/entity/Q214554 Serapis rec
# http://www.wikidata.org/entity/Q464091 Silenus rec
# http://www.wikidata.org/entity/Q33923 Simeon rec
# http://www.wikidata.org/entity/Q214494 Sol Invictus rec
# http://www.wikidata.org/entity/Q102561 Sisyphus rec
# http://www.wikidata.org/entity/Q182101 Tantalus rec
# http://www.wikidata.org/entity/Q184353 The three Graces rec
# http://www.wikidata.org/entity/Q10696861 Thisbe rec
# http://www.wikidata.org/entity/Q656887 Tityus rec
# http://www.wikidata.org/entity/Q867342 Troilus rec
# http://www.wikidata.org/entity/Q1398 Virgil rec
# http://vocab.getty.edu/ulan/500337098
# http://www.wikidata.org/entity/Q4640 Vulcan rec
# http://www.wikidata.org/entity/Q34201 Zeus rec
# http://www.wikidata.org/entity/Q47652v Venus rec
# http://www.wikidata.org/entity/Q5011 Cupid rec
# http://www.wikidata.org/entity/Q334794 Lapiths rec
# http://www.wikidata.org/entity/Q235113 Angel(s) rec
# http://www.wikidata.org/entity/Q83203 Centaur(s) rec
# http://www.wikidata.org/entity/Q69488 Adam rec
# http://www.wikidata.org/entity/Q82732 Aeneas rec
# http://viaf.org/viaf/18151776751918010050
# http://viaf.org/viaf/310624824
# http://www.wikidata.org/entity/Q172549 Aeolus rec
# http://viaf.org/viaf/242146936577813780265
# http://viaf.org/viaf/316444023
# http://www.wikidata.org/entity/Q368994 Aglauros rec
# http://www.wikidata.org/entity/Q572133 Anteros rec
# http://viaf.org/viaf/203920381
# http://viaf.org/viaf/69739212
# http://www.wikidata.org/entity/Q1429 Antoninus Pius rec
# http://viaf.org/viaf/282104028
# http://viaf.org/viaf/82144648308918710777
# http://www.wikidata.org/entity/Q37340 Apollo rec
# http://viaf.org/viaf/3261638
# http://www.wikidata.org/entity/Q4155679 Apostles rec
# http://www.wikidata.org/entity/Q81989 Archangel Gabriel rec
# http://viaf.org/viaf/286452690
# http://www.wikidata.org/entity/Q189821 Argus rec
# http://viaf.org/viaf/73149617096403752423
# http://viaf.org/viaf/77495947
# http://www.wikidata.org/entity/Q184874 Ariadne rec
# http://viaf.org/viaf/24151776820418012464
# http://viaf.org/viaf/77109359
# http://www.wikidata.org/entity/Q37122 Athene rec
# http://viaf.org/viaf/74643725
# http://www.wikidata.org/entity/Q2878203 bacchant rec
# http://www.wikidata.org/entity/Q645312 Bacchus rec
# http://viaf.org/viaf/27864934
# http://www.wikidata.org/entity/Q754686 Cacus rec
# http://viaf.org/viaf/13451695
# http://viaf.org/viaf/188476461
# http://www.wikidata.org/entity/Q83496 Cerberus rec
# http://www.wikidata.org/entity/Q302 Christ rec
# http://viaf.org/viaf/38323081
# http://www.wikidata.org/entity/Q2535664 crocodile rec
# http://www.wikidata.org/entity/Q188236 Cybele rec
# http://viaf.org/viaf/10639267
# http://www.wikidata.org/entity/Q6674 Devil rec
# http://www.wikidata.org/entity/Q132543 Diana rec
# http://viaf.org/viaf/122737933
# http://www.wikidata.org/entity/Q905162 Dido rec
# http://viaf.org/viaf/57406084
# http://viaf.org/viaf/71151776728918010792
# http://www.wikidata.org/entity/Q41680 Dionysus rec
# http://viaf.org/viaf/10152079049807110114
# http://www.wikidata.org/entity/Q104413 Erato rec
# http://viaf.org/viaf/316444024
# http://viaf.org/viaf/35392257
# http://viaf.org/viaf/39151776820018012560
# http://www.wikidata.org/entity/Q334456 Erymanthian Boar rec
# http://www.wikidata.org/entity/Q830183 Eve rec
# http://viaf.org/viaf/30876049
# http://www.wikidata.org/entity/Q52166 Fedro rec
# http://viaf.org/viaf/100219115
# http://viaf.org/viaf/17198433
# http://viaf.org/viaf/100219094
# http://viaf.org/viaf/100219143
# http://viaf.org/viaf/100219127
# http://viaf.org/viaf/403159474047527660543
# http://viaf.org/viaf/19686565
# http://viaf.org/viaf/424144647678173972242
# http://viaf.org/viaf/158151776733818010358
# http://viaf.org/viaf/2000164191780218740003
# http://viaf.org/viaf/412154387132530970002
# http://viaf.org/viaf/23158790751438852887
# http://www.wikidata.org/entity/Q298877 Giuliano de' Medici rec
# http://viaf.org/viaf/57418691
# http://www.wikidata.org/entity/Q193433 Hecuba rec
# http://viaf.org/viaf/155536230
# http://viaf.org/viaf/188642795
# http://viaf.org/viaf/309842556
# http://viaf.org/viaf/59151110811837062627
# http://www.wikidata.org/entity/Q164061 Helen rec
# http://viaf.org/viaf/45094221
# http://viaf.org/viaf/184144782718285280518
# http://viaf.org/viaf/285390062
# http://viaf.org/viaf/309842564
# http://viaf.org/viaf/49152380127801762208
# http://www.wikidata.org/entity/Q332752 Hylas rec
# http://viaf.org/viaf/868820
# http://viaf.org/viaf/12150686573312542059
# http://viaf.org/viaf/190568563
# http://viaf.org/viaf/8516159478245827990006
# http://www.wikidata.org/entity/Q271891 Ixion rec
# http://viaf.org/viaf/105157340587209920668
# http://viaf.org/viaf/40151776766418012003
# http://viaf.org/viaf/77146513237432210217
# http://www.wikidata.org/entity/Q34201 Jupiter rec
# http://viaf.org/viaf/3266770
# http://www.wikidata.org/entity/Q63851811 Jupiter as an eagle rec
# http://www.wikidata.org/entity/Q177854 Lorenzo de' Medici rec
# http://viaf.org/viaf/54169908
# http://www.wikidata.org/entity/Q345 Mary rec
# http://viaf.org/viaf/207159474183027661574
# http://viaf.org/viaf/86913753
# http://www.wikidata.org/entity/Q126916 Minerva rec
# http://viaf.org/viaf/13107718
# http://www.wikidata.org/entity/Q9077 Moses rec
# http://viaf.org/viaf/805492
# http://www.wikidata.org/entity/Q66016 Muses rec
# http://viaf.org/viaf/115156010065049582325
# http://viaf.org/viaf/5727734
# http://www.wikidata.org/entity/Q6497135 Mithras rec
# http://viaf.org/viaf/72187436
# http://www.wikidata.org/entity/Q332 Neptune rec
# http://viaf.org/viaf/237238941
# http://www.wikidata.org/entity/Q81422 Noah rec
# http://viaf.org/viaf/11187922
# http://www.wikidata.org/entity/Q373916 Nymphs rec
# http://www.wikidata.org/entity/Q174353 Orpheus rec
# http://viaf.org/viaf/16157523295827031631
# http://viaf.org/viaf/19151776725018010146
# http://viaf.org/viaf/210146284417915331769
# http://viaf.org/viaf/214026792
# http://viaf.org/viaf/309825473
# http://viaf.org/viaf/649158790546138850506
# http://www.wikidata.org/entity/Q132582 Pan rec
# http://viaf.org/viaf/8183772
# http://viaf.org/viaf/6341151778228718130007
# http://www.wikidata.org/entity/Q167646 Paris rec
# http://viaf.org/viaf/807597
# http://viaf.org/viaf/8147965857884081763
# http://www.wikidata.org/entity/Q130832 Perseus rec
# http://viaf.org/viaf/22937584
# http://viaf.org/viaf/22151776775518011318
# http://www.wikidata.org/entity/Q203480 Phaeton rec
# http://viaf.org/viaf/817398
# http://viaf.org/viaf/190786822
# http://viaf.org/viaf/61151776731218010122
# http://viaf.org/viaf/9157523178027030793
# http://www.wikidata.org/entity/Q152262 Pluto rec
# http://www.wikidata.org/entity/Q750236 Polyxena rec
# http://viaf.org/viaf/18363473
# http://viaf.org/viaf/316444046
# http://www.wikidata.org/entity/Q80516 Pope Julius II rec
# http://viaf.org/viaf/51697938
# http://www.wikidata.org/entity/Q83160 Prometheus rec
# http://viaf.org/viaf/3263350
# http://viaf.org/viaf/100146284356615331230
# http://viaf.org/viaf/10157523402927032364
# http://viaf.org/viaf/173145621
# http://viaf.org/viaf/307461775
# http://viaf.org/viaf/316807867
# http://www.wikidata.org/entity/Q42857 Prophet rec
# http://www.wikidata.org/entity/Q14515330 Proserpina rec
# http://viaf.org/viaf/190479477
# http://viaf.org/viaf/25393445
# http://viaf.org/viaf/309846750
# http://www.wikidata.org/entity/Q85702867 puer mingens rec
# http://www.wikidata.org/entity/Q192343 Pygmalion rec
# http://viaf.org/viaf/18151776777618011359
# http://viaf.org/viaf/214026666
# http://viaf.org/viaf/49146284332915330822
# http://viaf.org/viaf/54940935
# http://www.wikidata.org/entity/Q207389 Rachel rec
# http://viaf.org/viaf/16251571
# http://www.wikidata.org/entity/Q108419 Rhea rec
# http://viaf.org/viaf/316434487
# http://www.wikidata.org/entity/Q164294 Saint Anne rec
# http://viaf.org/viaf/120155150
# http://www.wikidata.org/entity/Q11841130 Saint Damian rec
# http://viaf.org/viaf/60326622
# http://www.wikidata.org/entity/Q328804 Saint John the Evangelist rec
# http://viaf.org/viaf/40648922
# http://viaf.org/viaf/101370748
# http://www.wikidata.org/entity/Q128538 Saint Luke rec
# http://viaf.org/viaf/128165029
# http://viaf.org/viaf/305863610
# http://www.wikidata.org/entity/Q31966 Saint Mark rec
# http://viaf.org/viaf/264405984
# http://www.wikidata.org/entity/Q9200 Saint Paul rec
# http://viaf.org/viaf/100178816
# http://viaf.org/viaf/100178828
# http://viaf.org/viaf/72147118118426340361
# http://viaf.org/viaf/775154381057130292520
# http://viaf.org/viaf/8145857075922922066
# http://www.wikidata.org/entity/Q33923 Saint Peter rec
# http://viaf.org/viaf/13581141
# http://www.wikidata.org/entity/Q53663 Salamander rec
# http://www.wikidata.org/entity/Q35230 Satan rec
# http://www.wikidata.org/entity/Q134388 Saturn rec
# http://viaf.org/viaf/67261976
# http://www.wikidata.org/entity/Q163709 Satyr rec
# http://viaf.org/viaf/9485159477655227990005
# http://www.wikidata.org/entity/Q214554 Serapis rec
# http://viaf.org/viaf/805519
# http://www.wikidata.org/entity/Q464091 Silenus rec
# http://viaf.org/viaf/214069435
# http://www.wikidata.org/entity/Q33923 Simeon rec
# http://viaf.org/viaf/13581141
# http://www.wikidata.org/entity/Q214494 Sol Invictus rec
# http://viaf.org/viaf/50166625
# http://www.wikidata.org/entity/Q102561 Sisyphus rec
# http://viaf.org/viaf/135146284441115332092
# http://viaf.org/viaf/137156009831949580675
# http://viaf.org/viaf/198736888
# http://viaf.org/viaf/309840666
# http://viaf.org/viaf/67258418
# http://www.wikidata.org/entity/Q182101 Tantalus rec
# http://viaf.org/viaf/72197787
# http://www.wikidata.org/entity/Q184353 The three Graces rec
# http://viaf.org/viaf/67260127
# http://viaf.org/viaf/7414157884838560620003
# http://www.wikidata.org/entity/Q10696861 Thisbe rec
# http://viaf.org/viaf/316444292
# http://www.wikidata.org/entity/Q656887 Tityus rec
# http://viaf.org/viaf/77401349
# http://www.wikidata.org/entity/Q867342 Troilus rec
# http://viaf.org/viaf/30334623
# http://viaf.org/viaf/220146817
# http://viaf.org/viaf/30157413127916050348
# http://www.wikidata.org/entity/Q1398 Virgil rec
# http://viaf.org/viaf/8194433
# http://viaf.org/viaf/2158158792840839040009
# http://viaf.org/viaf/2676159248164504870004
# http://viaf.org/viaf/8069158070687608780002
# http://www.wikidata.org/entity/Q4640 Vulcan rec
# http://viaf.org/viaf/24157523407427032518
# http://viaf.org/viaf/42633769
# http://www.wikidata.org/entity/Q34201 Zeus rec
# http://viaf.org/viaf/3266770
# http://www.wikidata.org/entity/Q47652v Venus rec
# http://www.wikidata.org/entity/Q5011 Cupid rec
# http://viaf.org/viaf/311314174
# http://www.wikidata.org/entity/Q334794 Lapiths rec
# http://www.wikidata.org/entity/Q235113 Angel(s) rec
# http://www.wikidata.org/entity/Q83203 Centaur(s) rec
# {'Adam': 'http://icondataset.org/adam', 'Adam rec': ['https://iconclass.org/11I62(ADAM)', 'http://www.wikidata.org/entity/Q69488'], 'Aeneas': 'http://icondataset.org/aeneas', 'Aeneas rec': ['https://iconclass.org/96C(AENEAS)', 'http://www.wikidata.org/entity/Q82732', 'http://viaf.org/viaf/18151776751918010050', 'http://viaf.org/viaf/310624824'], 'Aeolus': 'http://icondataset.org/aeolus', 'Aeolus rec': ['http://www.wikidata.org/entity/Q172549', 'http://viaf.org/viaf/242146936577813780265', 'http://viaf.org/viaf/316444023'], 'Aglauros': 'http://icondataset.org/aglauros', 'Aglauros rec': ['http://www.wikidata.org/entity/Q368994'], 'Aion/Phanes': 'http://icondataset.org/aion/phanes', 'Aion/Phanes rec': ['http://www.iconclass.org/rkd/91A14%28AION%29/'], 'Anteros': 'http://icondataset.org/anteros', 'Anteros rec': ['http://www.iconclass.org/rkd/92D1911/', 'http://www.wikidata.org/entity/Q572133', 'http://viaf.org/viaf/203920381', 'http://viaf.org/viaf/69739212'], 'Antiphas, son of Laoocoon': 'http://icondataset.org/antiphas-son-of-laoocoon', 'Antiphas, son of Laoocoon rec': [], 'Antoninus Pius': 'http://icondataset.org/antoninus-pius', 'Antoninus Pius rec': ['http://www.wikidata.org/entity/Q1429', 'http://vocab.getty.edu/ulan/500115700', 'http://viaf.org/viaf/282104028', 'http://viaf.org/viaf/82144648308918710777'], 'Apollo': 'http://icondataset.org/apollo', 'Apollo rec': ['https://iconclass.org/92B3', 'http://www.wikidata.org/entity/Q37340', 'http://viaf.org/viaf/3261638'], 'Apollo god of Sun': 'http://icondataset.org/apollo-god-of-sun', 'Apollo god of Sun rec': [], 'Apollo Medicus or Aesculapius': 'http://icondataset.org/apollo-medicus-or-aesculapius', 'Apollo Medicus or Aesculapius rec': [], 'Apostles': 'http://icondataset.org/apostles', 'Apostles rec': ['http://www.wikidata.org/entity/Q4155679'], 'Archangel Gabriel': 'http://icondataset.org/archangel-gabriel', 'Archangel Gabriel rec': ['http://www.wikidata.org/entity/Q81989', 'http://viaf.org/viaf/286452690'], 'Argus': 'http://icondataset.org/argus', 'Argus rec': ['http://www.wikidata.org/entity/Q189821', 'http://viaf.org/viaf/73149617096403752423', 'http://viaf.org/viaf/77495947'], 'Ariadne': 'http://icondataset.org/ariadne', 'Ariadne rec': ['https://iconclass.org/95B(ARIADNE)', 'http://www.wikidata.org/entity/Q184874', 'http://viaf.org/viaf/24151776820418012464', 'http://viaf.org/viaf/77109359'], 'Athene': 'http://icondataset.org/athene', 'Athene rec': ['http://www.wikidata.org/entity/Q37122', 'http://viaf.org/viaf/74643725'], 'bacchant': 'http://icondataset.org/bacchant', 'bacchant rec': ['https://iconclass.org/92L1912', 'http://www.wikidata.org/entity/Q2878203'], 'Bacchus': 'http://icondataset.org/bacchus', 'Bacchus rec': ['https://iconclass.org/92L1', 'http://www.wikidata.org/entity/Q645312', 'http://viaf.org/viaf/27864934'], 'Bishop Simone Saltarelli': 'http://icondataset.org/bishop-simone-saltarelli', 'Bishop Simone Saltarelli rec': [], 'Blindfold Cupid': 'http://icondataset.org/blindfold-cupid', 'Blindfold Cupid rec': ['http://www.iconclass.org/rkd/92D18%28BLINDFOLD%29/'], 'Cacus': 'http://icondataset.org/cacus', 'Cacus rec': ['http://www.wikidata.org/entity/Q754686', 'http://viaf.org/viaf/13451695', 'http://viaf.org/viaf/188476461'], 'Cerberus': 'http://icondataset.org/cerberus', 'Cerberus rec': ['http://www.wikidata.org/entity/Q83496'], 'Christ': 'http://icondataset.org/christ', 'Christ rec': ['http://www.wikidata.org/entity/Q302', 'http://viaf.org/viaf/38323081'], 'Christ as a child': 'http://icondataset.org/christ-as-a-child', 'Christ as a child rec': [], 'Companion of Serapis': 'http://icondataset.org/companion-of-serapis', 'Companion of Serapis rec': [], 'crocodile': 'http://icondataset.org/crocodile', 'crocodile rec': ['https://iconclass.org/25F43', 'http://www.wikidata.org/entity/Q2535664'], 'Cybele': 'http://icondataset.org/cybele', 'Cybele rec': ['http://www.wikidata.org/entity/Q188236', 'http://viaf.org/viaf/10639267'], 'David': 'http://icondataset.org/david',  ...

# %%
print(characterDict4)
# Out:
# {'Adam': 'http://icondataset.org/adam', 'Adam rec': ['https://iconclass.org/11I62(ADAM)', 'http://www.wikidata.org/entity/Q69488'], 'Aeneas': 'http://icondataset.org/aeneas', 'Aeneas rec': ['https://iconclass.org/96C(AENEAS)', 'http://www.wikidata.org/entity/Q82732', 'http://viaf.org/viaf/18151776751918010050', 'http://viaf.org/viaf/310624824'], 'Aeolus': 'http://icondataset.org/aeolus', 'Aeolus rec': ['http://www.wikidata.org/entity/Q172549', 'http://viaf.org/viaf/242146936577813780265', 'http://viaf.org/viaf/316444023'], 'Aglauros': 'http://icondataset.org/aglauros', 'Aglauros rec': ['http://www.wikidata.org/entity/Q368994'], 'Aion/Phanes': 'http://icondataset.org/aion/phanes', 'Aion/Phanes rec': ['http://www.iconclass.org/rkd/91A14%28AION%29/'], 'Anteros': 'http://icondataset.org/anteros', 'Anteros rec': ['http://www.iconclass.org/rkd/92D1911/', 'http://www.wikidata.org/entity/Q572133', 'http://viaf.org/viaf/203920381', 'http://viaf.org/viaf/69739212'], 'Antiphas, son of Laoocoon': 'http://icondataset.org/antiphas-son-of-laoocoon', 'Antiphas, son of Laoocoon rec': [], 'Antoninus Pius': 'http://icondataset.org/antoninus-pius', 'Antoninus Pius rec': ['http://www.wikidata.org/entity/Q1429', 'http://vocab.getty.edu/ulan/500115700', 'http://viaf.org/viaf/282104028', 'http://viaf.org/viaf/82144648308918710777'], 'Apollo': 'http://icondataset.org/apollo', 'Apollo rec': ['https://iconclass.org/92B3', 'http://www.wikidata.org/entity/Q37340', 'http://viaf.org/viaf/3261638'], 'Apollo god of Sun': 'http://icondataset.org/apollo-god-of-sun', 'Apollo god of Sun rec': [], 'Apollo Medicus or Aesculapius': 'http://icondataset.org/apollo-medicus-or-aesculapius', 'Apollo Medicus or Aesculapius rec': [], 'Apostles': 'http://icondataset.org/apostles', 'Apostles rec': ['http://www.wikidata.org/entity/Q4155679'], 'Archangel Gabriel': 'http://icondataset.org/archangel-gabriel', 'Archangel Gabriel rec': ['http://www.wikidata.org/entity/Q81989', 'http://viaf.org/viaf/286452690'], 'Argus': 'http://icondataset.org/argus', 'Argus rec': ['http://www.wikidata.org/entity/Q189821', 'http://viaf.org/viaf/73149617096403752423', 'http://viaf.org/viaf/77495947'], 'Ariadne': 'http://icondataset.org/ariadne', 'Ariadne rec': ['https://iconclass.org/95B(ARIADNE)', 'http://www.wikidata.org/entity/Q184874', 'http://viaf.org/viaf/24151776820418012464', 'http://viaf.org/viaf/77109359'], 'Athene': 'http://icondataset.org/athene', 'Athene rec': ['http://www.wikidata.org/entity/Q37122', 'http://viaf.org/viaf/74643725'], 'bacchant': 'http://icondataset.org/bacchant', 'bacchant rec': ['https://iconclass.org/92L1912', 'http://www.wikidata.org/entity/Q2878203'], 'Bacchus': 'http://icondataset.org/bacchus', 'Bacchus rec': ['https://iconclass.org/92L1', 'http://www.wikidata.org/entity/Q645312', 'http://viaf.org/viaf/27864934'], 'Bishop Simone Saltarelli': 'http://icondataset.org/bishop-simone-saltarelli', 'Bishop Simone Saltarelli rec': [], 'Blindfold Cupid': 'http://icondataset.org/blindfold-cupid', 'Blindfold Cupid rec': ['http://www.iconclass.org/rkd/92D18%28BLINDFOLD%29/'], 'Cacus': 'http://icondataset.org/cacus', 'Cacus rec': ['http://www.wikidata.org/entity/Q754686', 'http://viaf.org/viaf/13451695', 'http://viaf.org/viaf/188476461'], 'Cerberus': 'http://icondataset.org/cerberus', 'Cerberus rec': ['http://www.wikidata.org/entity/Q83496'], 'Christ': 'http://icondataset.org/christ', 'Christ rec': ['http://www.wikidata.org/entity/Q302', 'http://viaf.org/viaf/38323081'], 'Christ as a child': 'http://icondataset.org/christ-as-a-child', 'Christ as a child rec': [], 'Companion of Serapis': 'http://icondataset.org/companion-of-serapis', 'Companion of Serapis rec': [], 'crocodile': 'http://icondataset.org/crocodile', 'crocodile rec': ['https://iconclass.org/25F43', 'http://www.wikidata.org/entity/Q2535664'], 'Cybele': 'http://icondataset.org/cybele', 'Cybele rec': ['http://www.wikidata.org/entity/Q188236', 'http://viaf.org/viaf/10639267'], 'David': 'http://icondataset.org/david',  ...

# %%
save = store_in_json("Final/characterAlignedFinal.json", characterDict4)

# %% [markdown]
# store in csv: name, string that contains all the reconciled values separated by " @ "
# use it to save as csv and filter the reconciled terms directly in the spreadsheet. In this way, the reconciliation is always up to date.

# %%
# make it a function. 
# input: a list of tuples, where tup[0] is always the name
# output: a list of lists where the first term is the name, the second is a join of all the reconciled terms. 

def from_tup_to_csv(list_of_tup, file_name, first_line): 
    list_of_lists = []
    tot_dict = {}
    for tup in list_of_tup: 
        if tup[0] not in tot_dict: 
            tot_dict[tup[0]] = []
        tot_dict[tup[0]].append(tup[2])

    for item in tot_dict.items(): 
        list_of_lists.append([item[0], ' @ '.join(item[1])])
        
    with open(file_name, mode='w', newline='') as my_file:
        file = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
        file.writerow(first_line) 
        for l in list_of_lists: 
            file.writerow(l) 
    return(file_name) 

import csv

with open('character_wd_broader.csv', mode='w', newline='') as my_file:
  char_file = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
  char_file.writerow(['Name', 'WikidataBroader']) 
  for l in final_broader: 
    char_file.writerow(l) 
    
def store_csv(file_name, first_line, list_of_lists): 
    with open(file_name, mode='w', newline='') as my_file:
    file = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
    file.writerow(first_line) 
    for l in list_of_lists: 
        file.writerow(l) 
    return(file_name)

# %%
peopleDict = open_json("people_final_match.json") 
peopleList = []
headings = ["Name", "Link"]
for tup in peopleDict.items(): 
    if tup[0].endswith(" rec"): 
        col1 = tup[0].replace(" rec", "")
        col2 = ' @ '.join(tup[1])
        peopleList.append([col1, col2])
print(peopleList)
   
char = store_csv("PeopleAligned.csv", headings , peopleList)
# Out:
# [['A.E. Popp', 'http://viaf.org/viaf/20715488'], ["Abu Ma'sar", 'http://viaf.org/viaf/17355947 @ http://www.wikidata.org/entity/Q11373'], ['Achilles Bocchius', 'http://viaf.org/viaf/149878 @ http://www.wikidata.org/entity/Q3604350'], ['Adam Friedrich Oeser', 'http://vocab.getty.edu/ulan/500115770 @ http://www.wikidata.org/entity/Q215129 @ http://viaf.org/viaf/74126113'], ['Agesander', 'http://www.wikidata.org/entity/Q983432 @ http://vocab.getty.edu/ulan/500021781 @ http://viaf.org/viaf/35898854'], ['Athenodoros', 'http://vocab.getty.edu/ulan/500007132 @ http://www.wikidata.org/entity/Q280432 @ http://viaf.org/viaf/42230050'], ['Polydorus', 'http://vocab.getty.edu/ulan/500031985'], ['Agnolo Bronzino', 'http://vocab.getty.edu/ulan/500004362 @ http://www.wikidata.org/entity/Q7803 @ http://viaf.org/viaf/106963584 @ http://viaf.org/viaf/59354048'], ['Albrecht Dürer', 'http://vocab.getty.edu/ulan/500115493 @ http://www.wikidata.org/entity/Q5580 @ http://viaf.org/viaf/54146999'], ['Alexandre de Laborde', 'http://viaf.org/viaf/121808105 @ http://www.wikidata.org/entity/Q2362791 @ http://vocab.getty.edu/ulan/500254596 @ http://viaf.org/viaf/27074419'], ['Alfred Stevens', 'http://vocab.getty.edu/ulan/500000844 @ http://www.wikidata.org/entity/Q773855 @ http://viaf.org/viaf/10025104'], ['Alphonse Louis Duc', 'http://viaf.org/viaf/47035383'], ['Ambrogio Lorenzetti', 'http://vocab.getty.edu/ulan/500012547 @ http://www.wikidata.org/entity/Q211562 @ http://viaf.org/viaf/100916572'], ['Andrea Alciati', 'http://vocab.getty.edu/ulan/500048282 @ http://www.wikidata.org/entity/Q464471 @ http://viaf.org/viaf/51699991'], ['Andrea del Castagno', 'http://vocab.getty.edu/ulan/500004603 @ http://www.wikidata.org/entity/Q240737 @ http://viaf.org/viaf/95708912'], ['Andrea Mantegna', 'http://vocab.getty.edu/ulan/500004218 @ http://www.wikidata.org/entity/Q5681 @ http://viaf.org/viaf/27084155'], ['Annibale Carracci', 'http://vocab.getty.edu/ulan/500115350 @ http://www.wikidata.org/entity/Q7824 @ http://viaf.org/viaf/12405951'], ['Anthony van Dyck', 'http://vocab.getty.edu/ulan/500115190 @ http://www.wikidata.org/entity/Q150679 @ http://viaf.org/viaf/17231738'], ['Antonio Federighi', 'http://vocab.getty.edu/ulan/500022519 @ http://www.wikidata.org/entity/Q291201 @ http://viaf.org/viaf/52774174'], ['Antonio Pollaiuolo', 'http://vocab.getty.edu/ulan/500013242 @ http://www.wikidata.org/entity/Q318640 @ http://viaf.org/viaf/309812814 @ http://viaf.org/viaf/79398580'], ['Apollonio di Giovanni', 'http://vocab.getty.edu/ulan/500019165 @ http://www.wikidata.org/entity/Q2858468 @ http://viaf.org/viaf/95798943'], ['Artus Quellinus the Elder', 'http://viaf.org/viaf/52492507 @ http://www.wikidata.org/entity/Q651461 @ http://vocab.getty.edu/ulan/500012120'], ['Aubrey Beardsley', 'http://viaf.org/viaf/88739636 @ http://www.wikidata.org/entity/Q272566 @ http://vocab.getty.edu/ulan/500032068'], ['B. de Montfaucon', 'http://vocab.getty.edu/ulan/500272624'], ['Baccio Bandinelli', 'http://vocab.getty.edu/ulan/500008366 @ http://www.wikidata.org/entity/Q358348 @ http://viaf.org/viaf/88820562'], ['Benedetto Antelami', 'http://vocab.getty.edu/ulan/500007220 @ http://www.wikidata.org/entity/Q560114 @ http://viaf.org/viaf/50019028 @ http://viaf.org/viaf/6922149489170593810001'], ['Benozzo Gozzoli', 'http://vocab.getty.edu/ulan/500000246 @ http://www.wikidata.org/entity/Q248615 @ http://viaf.org/viaf/49498139'], ['C. Nodier', 'http://viaf.org/viaf/64009895'], ['Cesare Ripa', 'http://vocab.getty.edu/ulan/500236250 @ http://www.wikidata.org/entity/Q721704 @ http://viaf.org/viaf/100173686'], ['Charles Edouard de Beaumont', 'http://vocab.getty.edu/ulan/500011622 @ http://www.wikidata.org/entity/Q2958342 @ http://viaf.org/viaf/22922551 @ http://viaf.org/viaf/90433463'], ['Christine Pisan', 'https://viaf.org/viaf/100188547/'], ['Konrad Peutinger', 'http://viaf.org/viaf/56776766 @ http://www.wikidata.org/entity/Q60958 @ http://vocab.getty.edu/ulan/500353274'], ['Correggio', 'http://vocab. ...

# %% [markdown]
# ## Add the reconciled terms to the triples
# procedure: open the serialized file containing all the dataset as a graph. If the internal link is in the graph, then add the triples.

# %%
#g = Graph()
def reconciled_triples_addition(dictionary_json, newg, graph_ttl_serialized): 
  with open(dictionary_json, mode='r', encoding="utf-8") as jsonfile:
    dictionary = json.load(jsonfile)
  newg.parse(graph_ttl_serialized, format="ttl")
  for name in dictionary: 
    if not name.endswith(" rec"): 
      if dictionary[name] in g: # if the internal link is already in the graph
        name_rec = name+" rec"
        print(dictionary[name])
        if dictionary[name_rec] != []: # if there are reconciled terms
          for reconciled in dictionary[name_rec]:
            g.add((URIRef(dictionary[name]), owl.sameAs, URIRef(reconciled)))
            print(dictionary[name], "has reconciled term", reconciled)
  return newg

# %%
g = Graph()

# %%
for name in peopleDictFinal: 
  if not name.endswith(" rec"): 
    if peopleDictFinal[name] in g: 
      name_rec = name+" rec"
      if peopleDictFinal[name_rec] != []: 
        for reconciled in peopleDictFinal[name_rec]:
          g.add((URIRef(peopleDictFinal[name]), owl.sameAs, URIRef(reconciled)))

# %%
g.serialize(destination = "People_reconciled.ttl", format="turtle")
# Out:
# <Graph identifier=N86d4c16a0d0942e2badb6bffad8f9ca7 (<class 'rdflib.graph.Graph'>)>

# %%
# test for string search efficacy

wd_query = { # nb:applying only to wikidata. Every API has its own parameters. 
        "action": "wbsearchentities",
        "format": "json",
        "language": "en",
        "search": "Bargello National Museum"
    }

API_WD = "https://www.wikidata.org/w/api.php"
r =    requests.get(API_WD, params = wd_query).json()

print(r) # json with all the classes to be filtered
# res = wikidata_reconciliation(r, endpoint, q_class)
# people = reconciliation_function(peopleDict, wd_query, wikidata_endpoint, q_class="Q5")
# Out:
# {'searchinfo': {'search': 'Bargello National Museum'}, 'search': [{'id': 'Q388448', 'title': 'Q388448', 'pageid': 369638, 'display': {'label': {'value': 'Bargello National Museum', 'language': 'en'}, 'description': {'value': 'Art museum in Florence, Italy', 'language': 'en'}}, 'repository': 'wikidata', 'url': '//www.wikidata.org/wiki/Q388448', 'concepturi': 'http://www.wikidata.org/entity/Q388448', 'label': 'Bargello National Museum', 'description': 'Art museum in Florence, Italy', 'match': {'type': 'label', 'language': 'en', 'text': 'Bargello National Museum'}}], 'success': 1}
