# %% [markdown]
# pip install rdflib

# %%
import rdflib
from rdflib.namespace import CSVW, DC, DCAT, DCTERMS, DOAP, FOAF, ODRL2, ORG, OWL, \
                           PROF, PROV, RDF, RDFS, SDO, SH, SKOS, SOSA, SSN, TIME, \
                           VOID, XMLNS, XSD
from rdflib import Namespace
from rdflib import URIRef

import csv
from pymantic import sparql

# %%
newg = rdflib.Graph() # we create a new graph
newg.parse("210622_output2.ttl", format="ttl")
# Out:
# <Graph identifier=Nf883893d510d42d3aee63a7869abbfa0 (<class 'rdflib.graph.Graph'>)>

# %%
# nb: to run it, you must run your local blazegraph first
server = sparql.SPARQLServer('http://127.0.0.1:9999/bigdata/sparql')

# Loading data to Blazegraph
server.update('load <file:///210622_output2.ttl>')
# Out:
# <Response [200]>

# %% [markdown]
# # General CQ

# %% [markdown]
# ## overview
#
# 1.  **cultural phenomena**: their occurrences, the number and type of evidence supporting them, chains of iconological interpretations supporting each other; <br/>
# 2.  **symbols** and the symbolical relationships they have with other symbols in different contexts, their relationship with the identified source, the evolution of how concepts are expressed; <br/>
# 3.  the most common and most rare **attributes** allowing to identify a subject and their dependence from a cited **source**, along with the role that other objects not recognized as attributes can have; <br/>
# 4. study of the presence of **portraits** and verify if sponsors are depicted; <br/>
# 5. subjects: their **diachronic evolution**, rare iconographies detection and their characteristics since the less common ones can be interesting for further studies<br/>
# 6. if the **type of artwork** (e.g. miniature, painting, sculpture, etc.) influences the interpretation of the subject, and, in general, if the same subject depicted by artworks having different types presents significative differences; <br/>
# 7. study of the objects recognized as **sources for the interpretation**, seeking which role do they have in the findings of an interpretation act;

# %%
cultural phenomena: their occurrences, the number and type of evidence supporting them, chains of iconological interpretations supporting each other;

# %% [markdown]
# ## 1 Cultural phenomena
# Select artworks related to the same cultural phenomenon, and, if present, their date and place of production

# %%
### 1.1.Which cultural phenomena has multiple artworks related?

# %%
cq1 = '''
prefix data: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT ?meaning (count(distinct ?artwork) as ?tot) ?time WHERE {
# ?iconol icon:aboutWorkOfArt ?artwork;
  a icon:IconologicalRecognition;
  icon:recognizedIntrinsicMeaning ?intrinsic.
# ?intrinsic (icon:recognizedConceptualObject | icon:recognizedCulturalPhenomenon) ?meaning.
# ?meaning a icon:CulturalPhenomenon. 
OPTIONAL {?cultObj crm:P65_shows_visual_item ?artwork.
          # ?production crm:P108_has_produced ?cultObj;
          crm:P4_has_time_span ?time}

}
GROUP BY ?meaning 
ORDER BY DESC(?tot)
'''

cq1res = newg.query(cq1)

for row in cq1res:
    print(row)
# Out:
# (rdflib.term.URIRef('http://icondataset.org/CF1242'), rdflib.term.Literal('26', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1240'), rdflib.term.Literal('23', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/first-half-of-ix-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1231'), rdflib.term.Literal('13', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1538-1539'))
# (rdflib.term.URIRef('http://icondataset.org/CF1144'), rdflib.term.Literal('12', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1135'), rdflib.term.Literal('12', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1036'), rdflib.term.Literal('11', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1040'), rdflib.term.Literal('10', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1518'))
# (rdflib.term.URIRef('http://icondataset.org/CF1327'), rdflib.term.Literal('10', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1230'))
# (rdflib.term.URIRef('http://icondataset.org/CF1167'), rdflib.term.Literal('9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1220-1225'))
# (rdflib.term.URIRef('http://icondataset.org/CF1205'), rdflib.term.Literal('9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1485-1490'))
# (rdflib.term.URIRef('http://icondataset.org/CF1134'), rdflib.term.Literal('8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/end-of-the-xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1088'), rdflib.term.Literal('8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1425'))
# (rdflib.term.URIRef('http://icondataset.org/CF1087'), rdflib.term.Literal('8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1008'), rdflib.term.Literal('8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1305'))
# (rdflib.term.URIRef('http://icondataset.org/CF1236'), rdflib.term.Literal('7', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/middle-xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1116'), rdflib.term.Literal('7', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/middle-xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1194'), rdflib.term.Literal('7', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1470-1475'))
# (rdflib.term.URIRef('http://icondataset.org/CF1289'), rdflib.term.Literal('7', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1243'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1100'))
# (rdflib.term.URIRef('http://icondataset.org/CF1062'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1127'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1325-1328'))
# (rdflib.term.URIRef('http://icondataset.org/CF1014'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1485-1490'))
# (rdflib.term.URIRef('http://icondataset.org/CF1173'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1485-1490'))
# (rdflib.term.URIRef('http://icondataset.org/CF1203'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1485-1490'))
# (rdflib.term.URIRef('http://icondataset.org/CF1190'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1485-1490'))
# (rdflib.term.URIRef('http://icondataset.org/CF1364'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1532'))
# (rdflib.term.URIRef('http://icondataset.org/CF1346'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1195'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1314'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1380'))
# (rdflib.term.URIRef('http://icondataset.org/CF1238'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1098'))
# (rdflib.term.URIRef('http://icondataset.org/CF1117'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/middle-xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1089'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1172-1189'))
# (rdflib.term.URIRef('http://icondataset.org/CF1204'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1485-1490'))
# (rdflib.term.URIRef('http://icondataset.org/CF1103'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1485-1490'))
# (rdflib.term.URIRef('http://icondataset.org/CF1333'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1485-1490'))
# (rdflib.term.URIRef('http://icondataset.org/CF1223'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1493'))
# (rdflib.term.URIRef('http://icondataset.org/CF1379'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1493'))
# (rdflib.term.URIRef('http://icondataset.org/CF1131'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1496'))
# (rdflib.term.URIRef('http://icondataset.org/CF1352'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1532'))
# (rdflib.term.URIRef('http://icondataset.org/CF1313'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1621-1623'))
# (rdflib.term.URIRef('http://icondataset.org/CF1059'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1317'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1162'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1017'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1226'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1023'))
# (rdflib.term.URIRef('http://icondataset.org/CF1229'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1430'))
# (rdflib.term.URIRef('http://icondataset.org/CF1039'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1300'))
# (rdflib.term.URIRef('http://icondataset.org/CF1275'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/820-830'))
# (rdflib.term.URIRef('http://icondataset.org/CF1227'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/third-quarter-of-the-xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1344'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/third-quarter-of-the-xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1166'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1280'))
# (rdflib.term.URIRef('http://icondataset.org/CF1146'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1215'))
# (rdflib.term.URIRef('http://icondataset.org/CF1061'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1305'))
# (rdflib.term.URIRef('http://icondataset.org/CF1137'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1485'))
# (rdflib.term.URIRef('http://icondataset.org/CF1136'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1000'))
# (rdflib.term.URIRef('http://icondataset.org/CF1169'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1320-25'))
# (rdflib.term.URIRef('http://icondataset.org/CF1047'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1143'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/early-xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1156'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1200'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1045'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/before-1464'))
# (rdflib.term.URIRef('http://icondataset.org/CF1046'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/before-1464'))
# (rdflib.term.URIRef('http://icondataset.org/CF1202'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1269'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1368'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1350-1360'))
# (rdflib.term.URIRef('http://icondataset.org/CF1214'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1098'))
# (rdflib.term.URIRef('http://icondataset.org/CF1237'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1121'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1380'))
# (rdflib.term.URIRef('http://icondataset.org/CF1343'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1172-1189'))
# (rdflib.term.URIRef('http://icondataset.org/CF1306'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1172-1189'))
# (rdflib.term.URIRef('http://icondataset.org/CF1262'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1391-1396'))
# (rdflib.term.URIRef('http://icondataset.org/CF1326'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1340'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1403'))
# (rdflib.term.URIRef('http://icondataset.org/CF1267'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1322'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1534'))
# (rdflib.term.URIRef('http://icondataset.org/CF1329'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/ante-1533'))
# (rdflib.term.URIRef('http://icondataset.org/CF1319'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1361'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/late-xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1374'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1348'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1303'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1073'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1370'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1181'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1310'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1031'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/middle-ix-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1049'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1215'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1029'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1670-72'))
# (rdflib.term.URIRef('http://icondataset.org/CF1079'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/before-1464'))
# (rdflib.term.URIRef('http://icondataset.org/CF1316'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1209'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/ix-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1000'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/early-xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1222'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/middle-xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1042'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/first-half-of-ix-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1129'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1023'))
# (rdflib.term.URIRef('http://icondataset.org/CF1154'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1032'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1072'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1100'))
# (rdflib.term.URIRef('http://icondataset.org/CF1342'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1241'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1300'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1465'))
# (rdflib.term.URIRef('http://icondataset.org/CF1367'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1380'))
# (rdflib.term.URIRef('http://icondataset.org/CF1155'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1300'))
# (rdflib.term.URIRef('http://icondataset.org/CF1033'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1225-1245'))
# (rdflib.term.URIRef('http://icondataset.org/CF1318'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1289'))
# (rdflib.term.URIRef('http://icondataset.org/CF1030'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1289'))
# (rdflib.term.URIRef('http://icondataset.org/CF1228'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/first-half-of-ix-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1168'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1230'))
# (rdflib.term.URIRef('http://icondataset.org/CF1334'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1470'))
# (rdflib.term.URIRef('http://icondataset.org/CF1371'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1380'))
# (rdflib.term.URIRef('http://icondataset.org/CF1104'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/end-of-the-xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1124'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1280'))
# (rdflib.term.URIRef('http://icondataset.org/CF1011'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1280'))
# (rdflib.term.URIRef('http://icondataset.org/CF1165'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1280'))
# (rdflib.term.URIRef('http://icondataset.org/CF1126'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1324'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1024'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/first-half-of-the-xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1148'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1342'))
# (rdflib.term.URIRef('http://icondataset.org/CF1093'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1344'))
# (rdflib.term.URIRef('http://icondataset.org/CF1113'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1305'))
# (rdflib.term.URIRef('http://icondataset.org/CF1140'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1305'))
# (rdflib.term.URIRef('http://icondataset.org/CF1110'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1330'))
# (rdflib.term.URIRef('http://icondataset.org/CF1175'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1411-1412'))
# (rdflib.term.URIRef('http://icondataset.org/CF1060'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1425-1427'))
# (rdflib.term.URIRef('http://icondataset.org/CF1208'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1425-1427'))
# (rdflib.term.URIRef('http://icondataset.org/CF1153'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1485-1490'))
# (rdflib.term.URIRef('http://icondataset.org/CF1163'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1485-1490'))
# (rdflib.term.URIRef('http://icondataset.org/CF1224'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1498'))
# (rdflib.term.URIRef('http://icondataset.org/CF1069'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1525-1530'))
# (rdflib.term.URIRef('http://icondataset.org/CF1009'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1480'))
# (rdflib.term.URIRef('http://icondataset.org/CF1363'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1509-1511'))
# (rdflib.term.URIRef('http://icondataset.org/CF1123'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/middle-xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1216'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/middle-xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1100'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1445-1450'))
# (rdflib.term.URIRef('http://icondataset.org/CF1307'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1403'))
# (rdflib.term.URIRef('http://icondataset.org/CF1380'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1321'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1108'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1475'))
# (rdflib.term.URIRef('http://icondataset.org/CF1170'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1320-25'))
# (rdflib.term.URIRef('http://icondataset.org/CF1070'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1496'))
# (rdflib.term.URIRef('http://icondataset.org/CF1071'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1496'))
# (rdflib.term.URIRef('http://icondataset.org/CF1043'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1219'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xi-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1191'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1299'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1213'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1192'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1187'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1536-1541'))
# (rdflib.term.URIRef('http://icondataset.org/CF1076'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1077'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1337'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1345'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1362'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1349'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1288'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1118'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1065'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1015'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1525'))
# (rdflib.term.URIRef('http://icondataset.org/CF1176'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1022'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1211'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1081'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1621-1623'))
# (rdflib.term.URIRef('http://icondataset.org/CF1290'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1107'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1160'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1139'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1266'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1636-1638'))
# (rdflib.term.URIRef('http://icondataset.org/CF1207'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1425-1427'))
# (rdflib.term.URIRef('http://icondataset.org/CF1021'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xi-xii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1028'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xi-xii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1122'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xviii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1366'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1365'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1233'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1515'))
# (rdflib.term.URIRef('http://icondataset.org/CF1180'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1106'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1250'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1245'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1109'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1490'))
# (rdflib.term.URIRef('http://icondataset.org/CF1281'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/early-xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1212'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/early-xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1210'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/middle-xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1037'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1128'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1023'))
# (rdflib.term.URIRef('http://icondataset.org/CF1283'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1023'))
# (rdflib.term.URIRef('http://icondataset.org/CF1220'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1100'))
# (rdflib.term.URIRef('http://icondataset.org/CF1158'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1100'))
# (rdflib.term.URIRef('http://icondataset.org/CF1171'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1420'))
# (rdflib.term.URIRef('http://icondataset.org/CF1286'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1465'))
# (rdflib.term.URIRef('http://icondataset.org/CF1276'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1265'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1020'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1350-1360'))
# (rdflib.term.URIRef('http://icondataset.org/CF1019'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1538-1539'))
# (rdflib.term.URIRef('http://icondataset.org/CF1311'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/third-quarter-of-the-xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1232'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1335'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1235'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1291'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1066'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1102'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1053'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1552'))
# (rdflib.term.URIRef('http://icondataset.org/CF1125'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/middle-viii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1004'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/completed-754'))
# (rdflib.term.URIRef('http://icondataset.org/CF1034'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1041'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/820-830'))
# (rdflib.term.URIRef('http://icondataset.org/CF1297'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/third-quarter-of-the-xii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1296'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1140'))
# (rdflib.term.URIRef('http://icondataset.org/CF1115'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1260'))
# (rdflib.term.URIRef('http://icondataset.org/CF1254'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1230'))
# (rdflib.term.URIRef('http://icondataset.org/CF1221'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/second-quarter-of-the-xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1372'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1480'))
# (rdflib.term.URIRef('http://icondataset.org/CF1320'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1230'))
# (rdflib.term.URIRef('http://icondataset.org/CF1005'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1230'))
# (rdflib.term.URIRef('http://icondataset.org/CF1249'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1230'))
# (rdflib.term.URIRef('http://icondataset.org/CF1351'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1100'))
# (rdflib.term.URIRef('http://icondataset.org/CF1305'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1674'))
# (rdflib.term.URIRef('http://icondataset.org/CF1304'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1674'))
# (rdflib.term.URIRef('http://icondataset.org/CF1111'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1305'))
# (rdflib.term.URIRef('http://icondataset.org/CF1112'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1094'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/second-half-of-ix-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1239'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/second-half-of-ix-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1378'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/second-half-of-ix-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1055'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/fourth-decade-of-the-xiv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1056'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1342'))
# (rdflib.term.URIRef('http://icondataset.org/CF1150'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1342'))
# (rdflib.term.URIRef('http://icondataset.org/CF1152'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1342'))
# (rdflib.term.URIRef('http://icondataset.org/CF1151'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1415'))
# (rdflib.term.URIRef('http://icondataset.org/CF1091'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1344'))
# (rdflib.term.URIRef('http://icondataset.org/CF1147'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1320-1330'))
# (rdflib.term.URIRef('http://icondataset.org/CF1141'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1350'))
# (rdflib.term.URIRef('http://icondataset.org/CF1142'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1391-1396'))
# (rdflib.term.URIRef('http://icondataset.org/CF1172'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1308-1311'))
# (rdflib.term.URIRef('http://icondataset.org/CF1244'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1325-1328'))
# (rdflib.term.URIRef('http://icondataset.org/CF1338'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1371'))
# (rdflib.term.URIRef('http://icondataset.org/CF1339'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1371'))
# (rdflib.term.URIRef('http://icondataset.org/CF1347'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/before-1402'))
# (rdflib.term.URIRef('http://icondataset.org/CF1174'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1413-1416'))
# ...
# (rdflib.term.URIRef('http://icondataset.org/CF1086'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1341-1342'))
# (rdflib.term.URIRef('http://icondataset.org/CF1085'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/post-1194'))
# (rdflib.term.URIRef('http://icondataset.org/CF1328'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1513'))
# (rdflib.term.URIRef('http://icondataset.org/CF1096'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1532'))
# (rdflib.term.URIRef('http://icondataset.org/CF1075'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1532'))
# (rdflib.term.URIRef('http://icondataset.org/CF1095'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1532'))
# (rdflib.term.URIRef('http://icondataset.org/CF1006'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1532'))
# (rdflib.term.URIRef('http://icondataset.org/CF1184'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1533'))
# (rdflib.term.URIRef('http://icondataset.org/CF1355'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1185'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1161'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/early-xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1271'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1272'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1120'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1119'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xiii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1013'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1235'))
# (rdflib.term.URIRef('http://icondataset.org/CF1358'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1360'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1357'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1359'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1523'))
# (rdflib.term.URIRef('http://icondataset.org/CF1353'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1279'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/early-xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1315'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1105'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xvi-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1230'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xvi-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1302'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1759'))
# (rdflib.term.URIRef('http://icondataset.org/CF1012'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1044'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1280'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1052'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1377'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1217'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1054'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1282'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1023'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1225'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1067'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1064'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1495'))
# (rdflib.term.URIRef('http://icondataset.org/CF1257'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1255'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1258'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1268'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1525'))
# (rdflib.term.URIRef('http://icondataset.org/CF1341'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1621-1623'))
# (rdflib.term.URIRef('http://icondataset.org/CF1084'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1621-1623'))
# (rdflib.term.URIRef('http://icondataset.org/CF1080'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1082'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1293'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1078'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1083'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1261'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1518-1519'))
# (rdflib.term.URIRef('http://icondataset.org/CF1259'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1501-1502'))
# (rdflib.term.URIRef('http://icondataset.org/CF1253'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1309'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1501-1504'))
# (rdflib.term.URIRef('http://icondataset.org/CF1285'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1501-1504'))
# (rdflib.term.URIRef('http://icondataset.org/CF1301'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1501-1504'))
# (rdflib.term.URIRef('http://icondataset.org/CF1063'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1501-1504'))
# (rdflib.term.URIRef('http://icondataset.org/CF1048'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1182'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1496-1500'))
# (rdflib.term.URIRef('http://icondataset.org/CF1164'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1278'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1240'))
# (rdflib.term.URIRef('http://icondataset.org/CF1074'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1263'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1145'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1672-78'))
# (rdflib.term.URIRef('http://icondataset.org/CF1097'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1542-1545'))
# (rdflib.term.URIRef('http://icondataset.org/CF1251'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1260'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1018'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1369'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1035'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1426'))
# (rdflib.term.URIRef('http://icondataset.org/CF1183'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/middle-xv-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1007'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1099'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1325'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1058'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/xii-century'))
# (rdflib.term.URIRef('http://icondataset.org/CF1354'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1376'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1759'))
# (rdflib.term.URIRef('http://icondataset.org/CF1138'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1356'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1525'))
# (rdflib.term.URIRef('http://icondataset.org/CF1130'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1114'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1240'))
# (rdflib.term.URIRef('http://icondataset.org/CF1092'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1003'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1542-1545'))
# (rdflib.term.URIRef('http://icondataset.org/CF1274'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.URIRef('http://icondataset.org/1546'))
# (rdflib.term.URIRef('http://icondataset.org/CF1256'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)
# (rdflib.term.URIRef('http://icondataset.org/CF1101'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), None)

# %% [markdown]
# ### Selection of a phenomenon with multiple artworks related to do a more qualitative analysis
# ### 1.2 what is the date of production of the artworks related to the CF CF1242?
# CF1242: Representation of classical content with contemporary formal motifs

# %%
cq1 = '''
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?artwork ?time ?timeStart ?timeEnd WHERE {
# ?iconol icon:aboutWorkOfArt ?artwork;
  a icon:IconologicalRecognition;
  icon:recognizedIntrinsicMeaning ?intrinsic.
# ?intrinsic icon:recognizedCulturalPhenomenon d:CF1242.
# ?cultObj crm:P65_shows_visual_item ?artwork.
          # ?production crm:P108_has_produced ?cultObj;
          crm:P4_has_time_span ?time. 
# ?time crm:P82a_begin_of_the_begin ?timeStart; 
    crm:P82b_end_of_the_end ?timeEnd. 

} ORDER BY ?timeStart

'''

cq1res = newg.query(cq1)

for row in cq1res:
    print(row)
# Out:
# (rdflib.term.URIRef('http://icondataset.org/ART1043'), rdflib.term.URIRef('http://icondataset.org/1100'), rdflib.term.Literal('1100-01-01T0:00:00'), rdflib.term.Literal('1100-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1014'), rdflib.term.URIRef('http://icondataset.org/xii-century'), rdflib.term.Literal('1101-01-01T0:00:00'), rdflib.term.Literal('1200-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1141'), rdflib.term.URIRef('http://icondataset.org/1215'), rdflib.term.Literal('1215-01-01T0:00:00'), rdflib.term.Literal('1215-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1142'), rdflib.term.URIRef('http://icondataset.org/1227'), rdflib.term.Literal('1227-01-01T0:00:00'), rdflib.term.Literal('1227-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1143'), rdflib.term.URIRef('http://icondataset.org/1257'), rdflib.term.Literal('1257-01-01T0:00:00'), rdflib.term.Literal('1257-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1064'), rdflib.term.URIRef('http://icondataset.org/1289'), rdflib.term.Literal('1289-01-01T0:00:00'), rdflib.term.Literal('1289-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1055'), rdflib.term.URIRef('http://icondataset.org/1300'), rdflib.term.Literal('1300-01-01T0:00:00'), rdflib.term.Literal('1300-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1056'), rdflib.term.URIRef('http://icondataset.org/1300'), rdflib.term.Literal('1300-01-01T0:00:00'), rdflib.term.Literal('1300-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1058'), rdflib.term.URIRef('http://icondataset.org/1300'), rdflib.term.Literal('1300-01-01T0:00:00'), rdflib.term.Literal('1300-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1042'), rdflib.term.URIRef('http://icondataset.org/xiv-century'), rdflib.term.Literal('1301-01-01T0:00:00'), rdflib.term.Literal('1400-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1057'), rdflib.term.URIRef('http://icondataset.org/early-xiv-century'), rdflib.term.Literal('1301-01-01T0:00:00'), rdflib.term.Literal('1334-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1053'), rdflib.term.URIRef('http://icondataset.org/middle-xiv-century'), rdflib.term.Literal('1335-01-01T0:00:00'), rdflib.term.Literal('1367-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1054'), rdflib.term.URIRef('http://icondataset.org/1350-1360'), rdflib.term.Literal('1350-01-01T0:00:00'), rdflib.term.Literal('1360-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1066'), rdflib.term.URIRef('http://icondataset.org/third-quarter-of-the-xiv-century'), rdflib.term.Literal('1351-01-01T0:00:00'), rdflib.term.Literal('1375-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1052'), rdflib.term.URIRef('http://icondataset.org/1380'), rdflib.term.Literal('1380-01-01T0:00:00'), rdflib.term.Literal('1380-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1004test'), rdflib.term.URIRef('http://icondataset.org/xv-century'), rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1500-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1034'), rdflib.term.URIRef('http://icondataset.org/early-xv-century'), rdflib.term.Literal('1401-01-01T0:00:00'), rdflib.term.Literal('1434-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1147'), rdflib.term.URIRef('http://icondataset.org/1403'), rdflib.term.Literal('1403-01-01T0:00:00'), rdflib.term.Literal('1403-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/1420'), rdflib.term.Literal('1420-01-01T0:00:00'), rdflib.term.Literal('1420-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1045'), rdflib.term.URIRef('http://icondataset.org/1430'), rdflib.term.Literal('1430-01-01T0:00:00'), rdflib.term.Literal('1430-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1048'), rdflib.term.URIRef('http://icondataset.org/middle-xv-century'), rdflib.term.Literal('1435-01-01T0:00:00'), rdflib.term.Literal('1467-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1050'), rdflib.term.URIRef('http://icondataset.org/1465'), rdflib.term.Literal('1465-01-01T0:00:00'), rdflib.term.Literal('1465-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1033'), rdflib.term.URIRef('http://icondataset.org/1490'), rdflib.term.Literal('1490-01-01T0:00:00'), rdflib.term.Literal('1490-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1005test'), rdflib.term.URIRef('http://icondataset.org/1622'), rdflib.term.Literal('1622-01-01T0:00:00'), rdflib.term.Literal('1622-12-31T23:59:59'))
# (rdflib.term.URIRef('http://icondataset.org/ART1240'), rdflib.term.URIRef('http://icondataset.org/x-century'), rdflib.term.Literal('901-01-01T0:00:00'), rdflib.term.Literal('1000-12-31T23:59:59'))

# %%
century_dict = { 9: "X", 10: "XI", 11: "XII", 12: "XIII", 13:"XIV", 14: "XV", 15: "XVI", 16: "XVII" }
with open("CF1242Analysis.csv", mode="w") as my_file: 
    my_writer = csv.writer(my_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
    # write the column names
    my_writer.writerow(['Artwork', 'Year', 'Century', 'TimeSpan'])
    for artwork, timeSpan, timeStart, timeEnd in cq1res:
        timeSpan_cleaned = timeSpan.replace("http://icondataset.org/", "")
        timeSpan_cleaned2 = timeSpan_cleaned.replace("-", " ")
        artwork_cleaned = artwork.replace("http://icondataset.org/", "")
        if timeStart[3] != "-": 
            start = int(timeStart[:4])
        else: 
            start = int(timeStart[:3])
        end = int(timeEnd[:4])
        
        if start != end: 
            time = str(int((start+end)/2))
        else: 
            time = str(start)
        if len(time) == 4:
            year = int(time[:2])
        elif len(time) == 3:
            year = int(time[:1]) # for the cases in which the year has 3 numbers and not 4
        if time[2:] == "00": 
            year-= 1
        print(artwork, start, end, time)
        century = century_dict[year]
        
        # write in the cv
        my_writer.writerow([artwork, year, century, timeSpan_cleaned2])
# Out:
# http://icondataset.org/ART1043 1100 1100 1100
# http://icondataset.org/ART1014 1101 1200 1150
# http://icondataset.org/ART1141 1215 1215 1215
# http://icondataset.org/ART1142 1227 1227 1227
# http://icondataset.org/ART1143 1257 1257 1257
# http://icondataset.org/ART1064 1289 1289 1289
# http://icondataset.org/ART1055 1300 1300 1300
# http://icondataset.org/ART1056 1300 1300 1300
# http://icondataset.org/ART1058 1300 1300 1300
# http://icondataset.org/ART1042 1301 1400 1350
# http://icondataset.org/ART1057 1301 1334 1317
# http://icondataset.org/ART1053 1335 1367 1351
# http://icondataset.org/ART1054 1350 1360 1355
# http://icondataset.org/ART1066 1351 1375 1363
# http://icondataset.org/ART1052 1380 1380 1380
# http://icondataset.org/ART1004test 1401 1500 1450
# http://icondataset.org/ART1034 1401 1434 1417
# http://icondataset.org/ART1147 1403 1403 1403
# http://icondataset.org/ART1021 1420 1420 1420
# http://icondataset.org/ART1045 1430 1430 1430
# http://icondataset.org/ART1048 1435 1467 1451
# http://icondataset.org/ART1050 1465 1465 1465
# http://icondataset.org/ART1033 1490 1490 1490
# http://icondataset.org/ART1005test 1622 1622 1622
# http://icondataset.org/ART1240 901 1000 950

# %%
import pandas as pd
# parse the csv into a dataframe
data = pd.read_csv("CF1242Analysis.csv")
# print the first 5 rows
data.head()
# Out:
#                           Artwork  Year Century     TimeSpan
# 0  http://icondataset.org/ART1043    10      XI         1100
# 1  http://icondataset.org/ART1014    11     XII  xii century
# 2  http://icondataset.org/ART1141    12    XIII         1215
# 3  http://icondataset.org/ART1142    12    XIII         1227
# 4  http://icondataset.org/ART1143    12    XIII         1257

# %% [markdown]
# possible visualization of these data: count how many artworks are in the same century (=how many times the century is repeated), make a column histogram with with x= time, y= numb of artworks

# %% [markdown]
# ### 1.3 what are the level 2 subjects represented by the artworks linked to the cultural phenomenon selected?
# i.e. the representation of classical content with contemporary formal motifs?

# %%
#too much time. try on Blazegraph 
cq1 = '''
prefix d: <http://icondataset.org/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?artwork ?subj2 WHERE {
VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
# ?iconol icon:aboutWorkOfArt ?artwork;
  a icon:IconologicalRecognition;
  icon:recognizedIntrinsicMeaning ?intrinsic.
# ?intrinsic icon:recognizedCulturalPhenomenon d:CF1242.
# ?cultObj crm:P65_shows_visual_item ?artwork.
# ?icrec icon:aboutWorkOfArt ?artwork;
  a icon:IconographicalRecognition;
  icon:recognizedImage ?image.
# ?image ?rel ?subj2. 
OPTIONAL {
# ?icrec icon:aboutWorkOfArt ?artwork;
  a icon:IconographicalRecognition;
  icon:recognizedInvenzione ?subj2.
}

} ORDER BY ?artwork

'''

cq1res = newg.query(cq1)

for row in cq1res:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\SOFIAB~1\AppData\Local\Temp/ipykernel_6512/1268459496.py in <module>
#      29 cq1res = newg.query(cq1)
#      30
# ---> 31 for row in cq1res:
#      32     print(row)
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\query.py in __iter__(self)
#     290
#     291             if self._genbindings:
# --> 292                 for b in self._genbindings:
#     293                     if b:  # don't add a result row in case of empty binding {}
#     294                         self._bindings.append(b)
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalDistinct(ctx, part)
#     496
#     497 def evalDistinct(ctx, part):
# --> 498     res = evalPart(ctx, part.p)
#     499
#     500     done = set()
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalPart(ctx, part)
#     267
#     268     elif part.name == "Project":
# --> 269         return evalProject(ctx, part)
#     270     elif part.name == "Slice":
#     271         return evalSlice(ctx, part)
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalProject(ctx, project)
#     506
#     507 def evalProject(ctx, project):
# --> 508     res = evalPart(ctx, project.p)
#     509
#     510     return (row.project(project.PV) for row in res)
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalPart(ctx, part)
#     276
#     277     elif part.name == "OrderBy":
# --> 278         return evalOrderBy(ctx, part)
#     279     elif part.name == "Group":
#     280         return evalGroup(ctx, part)
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalOrderBy(ctx, part)
#     440
#     441         reverse = bool(e.order and e.order == "DESC")
# --> 442         res = sorted(
#     443             res, key=lambda x: _val(value(x, e.expr, variables=True)), reverse=reverse
#     444         )
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalLeftJoin(ctx, join)
#     146 def evalLeftJoin(ctx, join):
#     147     # import pdb; pdb.set_trace()
# --> 148     for a in evalPart(ctx, join.p1):
#     149         ok = False
#     150         c = ctx.thaw(a)
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalLazyJoin(ctx, join)
#     112     for a in evalPart(ctx, join.p1):
#     113         c = ctx.thaw(a)
# --> 114         for b in evalPart(c, join.p2):
#     115             yield b.merge(a)  # merge, as some bindings may have been forgotten
#     116
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalBGP(ctx, bgp)
#      84             continue
#      85
# ---> 86         for x in evalBGP(c, bgp[1:]):
#      87             yield x
#      88
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalBGP(ctx, bgp)
#      84             continue
#      85
# ---> 86         for x in evalBGP(c, bgp[1:]):
#      87             yield x
#      88
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalBGP(ctx, bgp)
#      84             continue
#      85
# ---> 86         for x in evalBGP(c, bgp[1:]):
#      87             yield x
#      88
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\evaluate.py in evalBGP(ctx, bgp)
#      63     _o = ctx[o]
#      64
# ---> 65     for ss, sp, so in ctx.graph.triples((_s, _p, _o)):
#      66         if None in (_s, _p, _o):
#      67             c = ctx.push()
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\graph.py in triples(self, triple)
#     446                 yield _s, p, _o
#     447         else:
# --> 448             for (s, p, o), cg in self.__store.triples((s, p, o), context=self):
#     449                 yield s, p, o
#     450
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\stores\memory.py in triples(self, triple_pattern, context)
#     305     def triples(self, triple_pattern, context=None):
#     306         """A generator over all the triples matching"""
# --> 307         req_ctx = self.__ctx_to_str(context)
#     308         subject, predicate, object_ = triple_pattern
#     309
#
# ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\stores\memory.py in __ctx_to_str(self, ctx)
#     526             ctx_str = "{}:{}".format(ctx.identifier.__class__.__name__, ctx.identifier)
#     527             self.__context_obj_map[ctx_str] = ctx
# --> 528             return ctx_str
#     529         except AttributeError:
#     530             # otherwise, ctx should be a URIRef or BNode or str
#
# KeyboardInterrupt:

# %%
cq1 = '''

prefix d: <http://icondataset.org/>
PREFIX icon: <https://w3id.org/icon/ontology/>
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?artwork ?subj2 
WHERE {
  VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
  # ?intrinsic icon:recognizedCulturalPhenomenon d:CF1242; 
      ^icon:recognizedIntrinsicMeaning / icon:aboutWorkOfArt ?artwork .

   # ?artwork ^crm:P65_shows_visual_item ?cultObj ;
   ^icon:aboutWorkOfArt ?icrec . # IconographicalRecognition
   # ?icrec icon:recognizedImage ?image. ?image ?rel ?subj2.

  OPTIONAL {
    # ?icrec icon:aboutWorkOfArt ?artwork;
    a icon:IconographicalRecognition;
    icon:recognizedInvenzione ?subj2.
  }

} ORDER BY ?artwork
  '''

cq1res = newg.query(cq1)

for row in cq1res:
    print(row)
# Out:
# (rdflib.term.URIRef('http://icondataset.org/ART1004test'), rdflib.term.URIRef('http://icondataset.org/cerberus'))
# (rdflib.term.URIRef('http://icondataset.org/ART1004test'), rdflib.term.URIRef('http://icondataset.org/pluto'))
# (rdflib.term.URIRef('http://icondataset.org/ART1004test'), rdflib.term.URIRef('http://icondataset.org/proserpina'))
# (rdflib.term.URIRef('http://icondataset.org/ART1004test'), rdflib.term.URIRef('http://icondataset.org/rape'))
# (rdflib.term.URIRef('http://icondataset.org/ART1005test'), rdflib.term.URIRef('http://icondataset.org/cerberus'))
# (rdflib.term.URIRef('http://icondataset.org/ART1005test'), rdflib.term.URIRef('http://icondataset.org/pluto'))
# (rdflib.term.URIRef('http://icondataset.org/ART1005test'), rdflib.term.URIRef('http://icondataset.org/proserpina'))
# (rdflib.term.URIRef('http://icondataset.org/ART1005test'), rdflib.term.URIRef('http://icondataset.org/rape'))
# (rdflib.term.URIRef('http://icondataset.org/ART1014'), rdflib.term.URIRef('http://icondataset.org/the-constellation-hercules'))
# (rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/argus'))
# (rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/mercury'))
# (rdflib.term.URIRef('http://icondataset.org/ART1021'), rdflib.term.URIRef('http://icondataset.org/caduceus'))
# (rdflib.term.URIRef('http://icondataset.org/ART1033'), rdflib.term.URIRef('http://icondataset.org/mercury'))
# (rdflib.term.URIRef('http://icondataset.org/ART1033'), rdflib.term.URIRef('http://icondataset.org/the-children-of-mercury'))
# (rdflib.term.URIRef('http://icondataset.org/ART1033'), rdflib.term.URIRef('http://icondataset.org/the-virgin-constellation'))
# (rdflib.term.URIRef('http://icondataset.org/ART1034'), rdflib.term.URIRef('http://icondataset.org/mercury'))
# (rdflib.term.URIRef('http://icondataset.org/ART1034'), rdflib.term.URIRef('http://icondataset.org/the-children-of-mercury'))
# (rdflib.term.URIRef('http://icondataset.org/ART1034'), rdflib.term.URIRef('http://icondataset.org/heaven'))
# (rdflib.term.URIRef('http://icondataset.org/ART1040'), rdflib.term.URIRef('http://icondataset.org/crucifixion'))
# (rdflib.term.URIRef('http://icondataset.org/ART1040'), rdflib.term.URIRef('http://icondataset.org/sun'))
# (rdflib.term.URIRef('http://icondataset.org/ART1040'), rdflib.term.URIRef('http://icondataset.org/moon'))
# (rdflib.term.URIRef('http://icondataset.org/ART1042'), rdflib.term.URIRef('http://icondataset.org/laocoon'))
# (rdflib.term.URIRef('http://icondataset.org/ART1042'), rdflib.term.URIRef('http://icondataset.org/thymbraeus-son-of-laoocoon'))
# (rdflib.term.URIRef('http://icondataset.org/ART1042'), rdflib.term.URIRef('http://icondataset.org/antiphas-son-of-laoocoon'))
# (rdflib.term.URIRef('http://icondataset.org/ART1042'), rdflib.term.URIRef('http://icondataset.org/marine-snakes'))
# (rdflib.term.URIRef('http://icondataset.org/ART1042'), rdflib.term.URIRef('http://icondataset.org/sacrifice-of-a-bull-ancient-greek-religion'))
# (rdflib.term.URIRef('http://icondataset.org/ART1043'), rdflib.term.URIRef('http://icondataset.org/saturn'))
# (rdflib.term.URIRef('http://icondataset.org/ART1043'), rdflib.term.URIRef('http://icondataset.org/jupiter'))
# (rdflib.term.URIRef('http://icondataset.org/ART1043'), rdflib.term.URIRef('http://icondataset.org/apollo'))
# (rdflib.term.URIRef('http://icondataset.org/ART1043'), rdflib.term.URIRef('http://icondataset.org/the-three-graces'))
# (rdflib.term.URIRef('http://icondataset.org/ART1043'), rdflib.term.URIRef('http://icondataset.org/dragon-biting-its-tail-time'))
# (rdflib.term.URIRef('http://icondataset.org/ART1054'), rdflib.term.URIRef('http://icondataset.org/hecuba'))
# (rdflib.term.URIRef('http://icondataset.org/ART1054'), rdflib.term.URIRef('http://icondataset.org/troilus'))
# (rdflib.term.URIRef('http://icondataset.org/ART1055'), rdflib.term.URIRef('http://icondataset.org/polyxena'))
# (rdflib.term.URIRef('http://icondataset.org/ART1056'), rdflib.term.URIRef('http://icondataset.org/polyxena'))
# (rdflib.term.URIRef('http://icondataset.org/ART1064'), rdflib.term.URIRef('http://icondataset.org/thisbe'))
# (rdflib.term.URIRef('http://icondataset.org/ART1064'), rdflib.term.URIRef('http://icondataset.org/thisbe-waits-pyramus-at-the-tomb-of-king-ninus'))
# (rdflib.term.URIRef('http://icondataset.org/ART1064'), rdflib.term.URIRef('http://icondataset.org/the-tomb-of-king-ninus'))
# (rdflib.term.URIRef('http://icondataset.org/ART1066'), rdflib.term.URIRef('http://icondataset.org/europas-companions'))
# (rdflib.term.URIRef('http://icondataset.org/ART1066'), rdflib.term.URIRef('http://icondataset.org/the-abduction-of-europa'))
# (rdflib.term.URIRef('http://icondataset.org/ART1066'), rdflib.term.URIRef('http://icondataset.org/europa-human-soul'))
# (rdflib.term.URIRef('http://icondataset.org/ART1066'), rdflib.term.URIRef('http://icondataset.org/bull-christ'))
# (rdflib.term.URIRef('http://icondataset.org/ART1141'), rdflib.term.URIRef('http://icondataset.org/virgil'))
# (rdflib.term.URIRef('http://icondataset.org/ART1142'), rdflib.term.URIRef('http://icondataset.org/virgil'))
# (rdflib.term.URIRef('http://icondataset.org/ART1143'), rdflib.term.URIRef('http://icondataset.org/virgil'))
# (rdflib.term.URIRef('http://icondataset.org/ART1147'), rdflib.term.URIRef('http://icondataset.org/mercury'))
# (rdflib.term.URIRef('http://icondataset.org/ART1240'), rdflib.term.URIRef('http://icondataset.org/aeneas'))
# (rdflib.term.URIRef('http://icondataset.org/ART1240'), rdflib.term.URIRef('http://icondataset.org/dido'))

# %%
# create a df form the results, merge the data in this df with the previous one by the artwork. 

import pandas as pd
# parse the csv into a dataframe
dataTime = pd.read_csv("CF1242Analysis.csv")
# print the first 5 rows
dataTime.head() 

dataSubj = pd.read_csv("cf1242subjectsLev2.csv")
# print the first 5 rows 
dataSubj.head()
# Out:
#                               Artwork                            Subject
# 0  http://icondataset.org/ART1004test    http://icondataset.org/cerberus
# 1  http://icondataset.org/ART1004test       http://icondataset.org/pluto
# 2  http://icondataset.org/ART1004test  http://icondataset.org/proserpina
# 3  http://icondataset.org/ART1004test        http://icondataset.org/rape
# 4  http://icondataset.org/ART1005test    http://icondataset.org/cerberus

# %%
merged = pd.merge(
    dataSubj,
    dataTime,
    how="inner",
    on="Artwork",
    left_on=None,
    right_on=None,
    left_index=False,
    right_index=False,
    sort=True,
    suffixes=("_x", "_y"),
    copy=True,
    indicator=False,
    validate=None,
)

# %%
print(merged)
# Out:
#                                Artwork  \
# 0   http://icondataset.org/ART1004test
# 1   http://icondataset.org/ART1004test
# 2   http://icondataset.org/ART1004test
# 3   http://icondataset.org/ART1004test
# 4   http://icondataset.org/ART1005test
# 5   http://icondataset.org/ART1005test
# 6   http://icondataset.org/ART1005test
# 7   http://icondataset.org/ART1005test
# 8       http://icondataset.org/ART1014
# 9       http://icondataset.org/ART1021
# 10      http://icondataset.org/ART1021
# 11      http://icondataset.org/ART1021
# 12      http://icondataset.org/ART1033
# 13      http://icondataset.org/ART1033
# 14      http://icondataset.org/ART1033
# 15      http://icondataset.org/ART1034
# 16      http://icondataset.org/ART1034
# 17      http://icondataset.org/ART1034
# 18      http://icondataset.org/ART1042
# 19      http://icondataset.org/ART1042
# 20      http://icondataset.org/ART1042
# 21      http://icondataset.org/ART1042
# 22      http://icondataset.org/ART1042
# 23      http://icondataset.org/ART1043
# 24      http://icondataset.org/ART1043
# 25      http://icondataset.org/ART1043
# 26      http://icondataset.org/ART1043
# 27      http://icondataset.org/ART1043
# 28      http://icondataset.org/ART1054
# 29      http://icondataset.org/ART1054
# 30      http://icondataset.org/ART1055
# 31      http://icondataset.org/ART1056
# 32      http://icondataset.org/ART1064
# 33      http://icondataset.org/ART1064
# 34      http://icondataset.org/ART1064
# 35      http://icondataset.org/ART1066
# 36      http://icondataset.org/ART1066
# 37      http://icondataset.org/ART1066
# 38      http://icondataset.org/ART1066
# 39      http://icondataset.org/ART1141
# 40      http://icondataset.org/ART1142
# 41      http://icondataset.org/ART1143
# 42      http://icondataset.org/ART1147
# 43      http://icondataset.org/ART1240
# 44      http://icondataset.org/ART1240
#
#                                               Subject  Year Century  \
# 0                     http://icondataset.org/cerberus    14      XV
# 1                        http://icondataset.org/pluto    14      XV
# 2                   http://icondataset.org/proserpina    14      XV
# 3                         http://icondataset.org/rape    14      XV
# 4                     http://icondataset.org/cerberus    16    XVII
# 5                        http://icondataset.org/pluto    16    XVII
# 6                   http://icondataset.org/proserpina    16    XVII
# 7                         http://icondataset.org/rape    16    XVII
# 8   http://icondataset.org/the-constellation-hercules    11     XII
# 9                      http://icondataset.org/mercury    14      XV
# 10                       http://icondataset.org/argus    14      XV
# 11                    http://icondataset.org/caduceus    14      XV
# 12                     http://icondataset.org/mercury    14      XV
# 13    http://icondataset.org/the-virgin-constellation    14      XV
# 14     http://icondataset.org/the-children-of-mercury    14      XV
# 15                     http://icondataset.org/mercury    14      XV
# 16     http://icondataset.org/the-children-of-mercury    14      XV
# 17                      http://icondataset.org/heaven    14      XV
# 18                     http://icondataset.org/laocoon    13     XIV
# 19  http://icondataset.org/sacrifice-of-a-bull-anc...    13     XIV
# 20  http://icondataset.org/thymbraeus-son-of-laoocoon    13     XIV
# 21    http://icondataset.org/antiphas-son-of-laoocoon    13     XIV
# 22               http://icondataset.org/marine-snakes    13     XIV
# 23                      http://icondataset.org/saturn    10      XI
# 24                     http://icondataset.org/jupiter    10      XI
# 25                      http://icondataset.org/apollo    10      XI
# 26            http://icondataset.org/the-three-graces    10      XI
# 27  http://icondataset.org/dragon-biting-its-tail-...    10      XI
# 28                      http://icondataset.org/hecuba    13     XIV
# 29                     http://icondataset.org/troilus    13     XIV
# 30                    http://icondataset.org/polyxena    12    XIII
# 31                    http://icondataset.org/polyxena    12    XIII
# 32                      http://icondataset.org/thisbe    12    XIII
# 33  http://icondataset.org/thisbe-waits-pyramus-at...    12    XIII
# 34      http://icondataset.org/the-tomb-of-king-ninus    12    XIII
# 35           http://icondataset.org/europa-human-soul    13     XIV
# 36                 http://icondataset.org/bull-christ    13     XIV
# 37          http://icondataset.org/europas-companions    13     XIV
# 38     http://icondataset.org/the-abduction-of-europa    13     XIV
# 39                      http://icondataset.org/virgil    12    XIII
# 40                      http://icondataset.org/virgil    12    XIII
# 41                      http://icondataset.org/virgil    12    XIII
# 42                     http://icondataset.org/mercury    14      XV
# 43                      http://icondataset.org/aeneas     9       X
# 44                        http://icondataset.org/dido     9       X
#
#                             TimeSpan
# 0                         xv century
# 1                         xv century
# 2                         xv century
# 3                         xv century
# 4                               1622
# 5                               1622
# 6                               1622
# 7                               1622
# 8                        xii century
# 9                               1420
# 10                              1420
# 11                              1420
# 12                              1490
# 13                              1490
# 14                              1490
# 15                  early xv century
# 16                  early xv century
# 17                  early xv century
# 18                       xiv century
# 19                       xiv century
# 20                       xiv century
# 21                       xiv century
# 22                       xiv century
# 23                              1100
# 24                              1100
# 25                              1100
# 26                              1100
# 27                              1100
# 28                         1350 1360
# 29                         1350 1360
# 30                              1300
# 31                              1300
# 32                              1289
# 33                              1289
# 34                              1289
# 35  third quarter of the xiv century
# 36  third quarter of the xiv century
# 37  third quarter of the xiv century
# 38  third quarter of the xiv century
# 39                              1215
# 40                              1227
# 41                              1257
# 42                              1403
# 43                         x century
# 44                         x century

# %%
merged.to_csv('cf1242_with_subject.csv', index=False)

# %%
#1. 4 among the artworks having this cf, are there subjects that are more frequent? 
# make a dict with subj: count. every time the subj appears again, add 1
subj_count = {}
for index, row in dataSubj.iterrows():
    art = row["Artwork"]
    subj1 = row["Subject"].replace("http://icondataset.org/", "")
    subj = subj1.replace("-", " ") # update: select also the labels of the subjects. 
    if subj not in subj_count: 
        subj_count[subj] = 1
    else: 
        subj_count[subj] += 1
print(subj_count)
# Out:
# {'cerberus': 2, 'pluto': 2, 'proserpina': 2, 'rape': 2, 'the constellation hercules': 1, 'mercury': 4, 'argus': 1, 'caduceus': 1, 'the virgin constellation': 1, 'the children of mercury': 2, 'heaven': 1, 'sun': 1, 'moon': 1, 'crucifixion': 1, 'laocoon': 1, 'sacrifice of a bull ancient greek religion': 1, 'thymbraeus son of laoocoon': 1, 'antiphas son of laoocoon': 1, 'marine snakes': 1, 'saturn': 1, 'jupiter': 1, 'apollo': 1, 'the three graces': 1, 'dragon biting its tail time': 1, 'hecuba': 1, 'troilus': 1, 'polyxena': 2, 'thisbe': 1, 'thisbe waits pyramus at the tomb of king ninus': 1, 'the tomb of king ninus': 1, 'europa human soul': 1, 'bull christ': 1, 'europas companions': 1, 'the abduction of europa': 1, 'virgil': 3, 'aeneas': 1, 'dido': 1}

# %%
# retrieve the results of the previous query and count how many times a subj appears

# %%
1. 5 how are the subjects distributed according to the time? 
# count how many subj. per century
# visualize as you did for mercury

# %% [markdown]
# 5 can be said that there are representational differences between the same second level subject, when it is linked to the phenomenon and when it is not?
# 6 which are the styles involved?
# 7 is there an influence of the medium on the phenomenon (i.e. artworks on manuscpripts or on stone are more likely to present the phenomenon)?

# %% [markdown]
# 1. 5 can be said that there are representational differences between the same second level subject, when it is linked to the phenomenon and when it is not?

# %% [markdown]
# retrieve all the level 1 subj having the same cf (the one chosen) and the same subject. Calculate the variation between 1) subjects having the cf 2) subjects not having the cf 3) the gropup of subj having it and the group of subj not having it. This allow to see if there is a variation in the differences.
# Understand how to calculate the difference. Any coefficient?
# Alternative: see the solution adopted in icon website

# %% [markdown]
# 1.8 Co-occurrence of level 1 and 2 subjects and cultural phenomena

# %%
from pymantic import sparql
cf_and_subj = []
server = sparql.SPARQLServer('http://127.0.0.1:9999/bigdata/sparql')

# Loading data to Blazegraph
server.update('load <file:///210622_output2.ttl>')

# Executing query
result = server.query("""
prefix d: <http://icondataset.org/>
PREFIX icon: <https://w3id.org/icon/ontology/>
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

select ?cf ?subj1  where {
  # ?intrinsic icon:recognizedCulturalPhenomenon ?cfUrl; 
      ^icon:recognizedIntrinsicMeaning / icon:aboutWorkOfArt ?artwork .
    # ?cfUrl rdfs:label ?cf. 
   # ?artwork ^icon:aboutWorkOfArt ?preicrec . # IconographicalRecognition
   # ?preicrec icon:recognizedArtisticMotif ?am. 
   # ?am icon:hasFactualMeaning |icon:hasExpressionalMeaning ?subj1Url.
   # ?subj1Url rdfs:label ?subj1. 
  
}  ORDER BY ?cf



    """)
for b in result['results']['bindings']:
   # print (b["cf"]["value"], b["subj1"]["value"])
    cf_and_subj.append([b["cf"]["value"], b["subj1"]["value"]])
    
print(cf_and_subj)
# Out:
# [['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'man'], ['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'man'], ['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'man'], ['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'sarcophagus'], ['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'woman'], ['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'woman'], ['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'woman'], ['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'woman'], ['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'child'], ['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'first platform'], ['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'niche'], ['"Failure of the Neoplatonic system to achieve a lasting harmony between the divergent tendencies in post-medieval culture"', 'niche'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'man'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'man'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'halo'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'chart'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'girls'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'holding a nosegay'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'man'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'throne'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'clothes'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'crown'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'dragon biting its tail'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance of Saturn develops from the fantastic into the terrifying and repulsive"', 'eagle'], ['"In the mythographical illustrations which were exclusively out of textual sources the appearance o ...

# %%
# same, with level 2 subjects. we append them to the same list

cf_subj_dict = {}
artwork_desc_dict = {}
# Executing query
result = server.query("""
prefix d: <http://icondataset.org/>
PREFIX icon: <https://w3id.org/icon/ontology/>
prefix sim: <https://w3id.org/simulation/ontology/>
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>

select ?artwork ?cf ?subj1 ?subj2  where {
    VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol}
  # ?intrinsic icon:recognizedCulturalPhenomenon ?cfUrl; 
      ^icon:recognizedIntrinsicMeaning / icon:aboutWorkOfArt ?artwork .
    # ?cfUrl rdfs:label ?cf. 
  optional{ ?artwork ^icon:aboutWorkOfArt ?icrec . # IconographicalRecognition
   # ?icrec icon:recognizedImage ?image. 
   # ?image ?rel ?subj2Url.
   # ?subj2Url rdfs:label ?subj2. }
   optional {   ?artwork ^icon:aboutWorkOfArt ?preicrec . # IconographicalRecognition
   # ?preicrec icon:recognizedArtisticMotif ?am. 
   # ?am icon:hasFactualMeaning |icon:hasExpressionalMeaning ?subj1Url.
   # ?subj1Url rdfs:label ?subj1. }
  
}  ORDER BY ?artwork



    """)
for b in result['results']['bindings']:
   # print (b["cf"]["value"], b["subj1"]["value"])
    #cf_and_subj.append([b["cf"]["value"], b["subj2"]["value"]])
    cf = b["cf"]["value"]
    art = b["artwork"]["value"]
   # subj1 = b["subj1"]["value"]
   # subj2 = b["subj2"]["value"]
    
    if cf not in cf_subj_dict: 
        cf_subj_dict[cf] = {art : set()}
    else: 
        if art not in cf_subj_dict[cf]:
            cf_subj_dict[cf][art] = set()
        if "subj1" in b: 
            cf_subj_dict[cf][art].add(b["subj1"]["value"])
        if "subj2" in b: 
            cf_subj_dict[cf][art].add(b["subj2"]["value"])

            
print(cf_subj_dict.values())
# Out:
# dict_values([{'http://icondataset.org/ART1000': {'eagle', 'Venus', 'man', 'woman', 'Jupiter', 'doves'}, 'http://icondataset.org/ART1001': {'man', 'fighting', 'lion', 'Hercules'}, 'http://icondataset.org/ART1011': {'club', 'The Constellation Hercules', 'lion skin', 'man', 'constellation'}, 'http://icondataset.org/ART1039': {'amphora', 'nursing', 'Sun', 'Oceanus', 'sun', 'quarter moon', 'woman', 'Crucifixion', 'Moon', 'cornucopia', 'cross', 'quadriga', 'oxen', 'biga', 'water', 'horses', 'crown', 'Tellus', 'man', 'serpents'}, 'http://icondataset.org/ART1051': {'cloak', 'flying', 'man', 'wings at the heels', 'Mercury'}, 'http://icondataset.org/ART1062': set(), 'http://icondataset.org/ART1065': {'beauty', 'Beauty', 'woman', 'The three Graces'}, 'http://icondataset.org/ART1079': {'The Twins constellation', 'men'}, 'http://icondataset.org/ART1144': {'dignity', 'proud', 'man', 'Virgil', 'toga'}, 'http://icondataset.org/ART1188': set()}, {'http://icondataset.org/ART1001test': {'Divine Justice', 'symbolical weighing with balance', 'pearl and gold necklaces', 'clothes', 'jewelry box', 'mirror-introspection', 'allusion to last judgement', 'table', 'mirror', 'symbolical weighing of souls', 'act of weighing', 'woman', 'cloth', 'painting', 'home interior', 'jewelry-earthly goods', 'balance'}, 'http://icondataset.org/ART1017test': {'glass sphere-heaven', 'ceiling', 'cloth', 'blue-hue of heaven', 'Catholic Faith', 'hand raised to the heart', 'woman', 'bitten apple', 'original-sin', 'chalice', 'altar', 'glass sphere', 'faith has the world under her feet', 'crucifix', 'crushing', 'serpent', 'table', 'hanging', 'resting one foot on a globe', 'heart-source of living faith', 'floor', 'white-purity', 'missal', 'book', 'glass-sphere-as-a-popular-decorative-curiosity', 'cornerstone of a church', 'glass sphere-God', 'altarpiece', 'bible', 'Christ', 'revealing a secluded space', 'Satan'}}, {'http://icondataset.org/ART1002': {'halo', 'Orpheus', 'natural landscape', 'playing music', 'man', 'lyre'}}, {'http://icondataset.org/ART1002': {'halo', 'Orpheus', 'natural landscape', 'playing music', 'man', 'lyre'}}, {'http://icondataset.org/ART1003test': {'animals', 'The young Mago Caspar', 'boy', 'Member of the procession', 'mule', 'man', 'hilly landscape', 'procession', 'riding a horse', 'young Mago-future time', 'clothes', 'horse', 'riding a mule'}}, {'http://icondataset.org/ART1004': {'stepping on-defeating devil', 'carrying on shoulders', 'dragoon-devil', 'dragoon', 'stepping on', 'deer', 'man', 'deer-souls', 'Christ', 'cloth', 'carrying on shoulders-saving souls'}, 'http://icondataset.org/ART1060': set(), 'http://icondataset.org/ART1061': {'Archangel Gabriel', 'Mary', 'boy', 'woman'}, 'http://icondataset.org/ART1102': {'male head', 'Saint Peter'}, 'http://icondataset.org/ART1105': {'battling monsters'}, 'http://icondataset.org/ART1113': {'looking down at his right', 'Simeon', 'raising the right arm halfway', 'beard', 'man', 'Simeon witnesses the presentation of Christ'}, 'http://icondataset.org/ART1114': set(), 'http://icondataset.org/ART1150': {'figures', 'gesture of grief', 'Saint John the Evangelist', 'man', 'Lamentation of Christ'}, 'http://icondataset.org/ART1166': {'Amorini pointing out to Death her first victims', 'displaying', 'putti', 'torch', 'wings', 'hortatory verses', 'man', 'scroll', 'lady', 'pointing at'}, 'http://icondataset.org/ART1236': {'throne', 'supporting', 'spheres of clouds', 'man', 'effort', 'Saint John the Evangelist'}, 'http://icondataset.org/ART1523': {'figure', 'gesture of grief'}}, {'http://icondataset.org/ART1004': {'stepping on-defeating devil', 'carrying on shoulders', 'dragoon-devil', 'dragoon', 'stepping on', 'deer', 'man', 'deer-souls', 'Christ', 'cloth', 'carrying on shoulders-saving souls'}, 'http://icondataset.org/ART1060': set(), 'http://icondataset.org/ART1061': {'Archangel Gabriel', 'Mary', 'boy', 'woman'}, 'http://icondataset.org/ART1236': {'throne', 'supporting', 'spheres of clouds', 'man', 'effort', 'Saint John th ...

# %%
print(cf_subj_dict)
# Out:
# {'Classical subject matter represented in classical form': {'http://icondataset.org/ART1000': {'eagle', 'man', 'woman', 'Venus', 'Jupiter', 'doves'}, 'http://icondataset.org/ART1001': {'lion', 'man', 'fighting', 'Hercules'}, 'http://icondataset.org/ART1011': {'club', 'man', 'constellation', 'The Constellation Hercules', 'lion skin'}, 'http://icondataset.org/ART1039': {'Sun', 'cornucopia', 'sun', 'Crucifixion', 'nursing', 'Oceanus', 'amphora', 'man', 'crown', 'cross', 'biga', 'horses', 'woman', 'serpents', 'quadriga', 'water', 'Tellus', 'oxen', 'quarter moon', 'Moon'}, 'http://icondataset.org/ART1051': {'man', 'Mercury', 'flying', 'cloak', 'wings at the heels'}, 'http://icondataset.org/ART1062': set(), 'http://icondataset.org/ART1065': {'woman', 'beauty', 'Beauty', 'The three Graces'}, 'http://icondataset.org/ART1079': {'The Twins constellation', 'men'}, 'http://icondataset.org/ART1144': {'Virgil', 'proud', 'man', 'toga', 'dignity'}, 'http://icondataset.org/ART1188': set()}, 'Catholic worship practiced in the private home interior due to the prohibition of its public profession': {'http://icondataset.org/ART1001test': {'symbolical weighing with balance', 'Divine Justice', 'symbolical weighing of souls', 'mirror', 'woman', 'act of weighing', 'mirror-introspection', 'balance', 'cloth', 'allusion to last judgement', 'home interior', 'jewelry box', 'painting', 'table', 'jewelry-earthly goods', 'pearl and gold necklaces', 'clothes'}, 'http://icondataset.org/ART1017test': {'Christ', 'glass sphere-heaven', 'bible', 'crucifix', 'glass sphere', 'resting one foot on a globe', 'cloth', 'hanging', 'altarpiece', 'heart-source of living faith', 'revealing a secluded space', 'missal', 'glass sphere-God', 'cornerstone of a church', 'serpent', 'hand raised to the heart', 'table', 'Satan', 'bitten apple', 'floor', 'woman', 'book', 'ceiling', 'faith has the world under her feet', 'altar', 'blue-hue of heaven', 'Catholic Faith', 'original-sin', 'crushing', 'glass-sphere-as-a-popular-decorative-curiosity', 'white-purity', 'chalice'}}, 'Assimilation of Orpheus to Christ in Early Christian Art': {'http://icondataset.org/ART1002': {'man', 'halo', 'lyre', 'natural landscape', 'playing music', 'Orpheus'}}, 'Byzantine theological manuscripts show examples of the genuine classical representational tradition of mythological characters': {'http://icondataset.org/ART1002': {'man', 'halo', 'lyre', 'natural landscape', 'playing music', 'Orpheus'}}, 'Self-celebration expressed through portraits in the Florentine Renaissance context': {'http://icondataset.org/ART1003test': {'Member of the procession', 'man', 'young Mago-future time', 'hilly landscape', 'riding a horse', 'boy', 'The young Mago Caspar', 'mule', 'animals', 'horse', 'procession', 'clothes', 'riding a mule'}}, 'Classical motifs recovery': {'http://icondataset.org/ART1004': {'Christ', 'man', 'carrying on shoulders', 'stepping on-defeating devil', 'carrying on shoulders-saving souls', 'dragoon-devil', 'cloth', 'dragoon', 'stepping on', 'deer', 'deer-souls'}, 'http://icondataset.org/ART1060': set(), 'http://icondataset.org/ART1061': {'woman', 'boy', 'Archangel Gabriel', 'Mary'}, 'http://icondataset.org/ART1102': {'Saint Peter', 'male head'}, 'http://icondataset.org/ART1105': {'battling monsters'}, 'http://icondataset.org/ART1113': {'man', 'Simeon witnesses the presentation of Christ', 'looking down at his right', 'beard', 'raising the right arm halfway', 'Simeon'}, 'http://icondataset.org/ART1114': set(), 'http://icondataset.org/ART1150': {'man', 'Saint John the Evangelist', 'gesture of grief', 'Lamentation of Christ', 'figures'}, 'http://icondataset.org/ART1166': {'pointing at', 'displaying', 'wings', 'man', 'Amorini pointing out to Death her first victims', 'hortatory verses', 'lady', 'putti', 'scroll', 'torch'}, 'http://icondataset.org/ART1236': {'spheres of clouds', 'man', 'throne', 'effort', 'supporting', 'Saint John the Evangelist'}, 'http://icondataset.org/ART1523': {'figure', 'gesture of grief'} ...

# %%
cf0_subj = [] # list of subjects descripted in the artwork where there is the corresponding cf in the list_cf
list_cf = list(cf_subj_dict.keys())

for art in cf_subj_dict[list_cf[0]]: 
    l = list(cf_subj_dict[list_cf[0]][art])
    if l != []:
        cf0_subj.append(l)
    
print(cf0_subj)
# Out:
# [['eagle', 'Venus', 'man', 'woman', 'Jupiter', 'doves'], ['man', 'fighting', 'lion', 'Hercules'], ['club', 'The Constellation Hercules', 'lion skin', 'man', 'constellation'], ['amphora', 'nursing', 'Sun', 'Oceanus', 'sun', 'quarter moon', 'woman', 'Crucifixion', 'Moon', 'cornucopia', 'cross', 'quadriga', 'oxen', 'biga', 'water', 'horses', 'crown', 'Tellus', 'man', 'serpents'], ['cloak', 'flying', 'man', 'wings at the heels', 'Mercury'], ['beauty', 'Beauty', 'woman', 'The three Graces'], ['The Twins constellation', 'men'], ['dignity', 'proud', 'man', 'Virgil', 'toga']]

# %%
print(list_cf)
# Out:
# ['Classical subject matter represented in classical form', 'Catholic worship practiced in the private home interior due to the prohibition of its public profession', 'Assimilation of Orpheus to Christ in Early Christian Art', 'Byzantine theological manuscripts show examples of the genuine classical representational tradition of mythological characters', 'Self-celebration expressed through portraits in the Florentine Renaissance context', 'Classical motifs recovery', 'Direct borrowings of classical motifs while the pagan themes were changed into Christian ones in Italian and French art during XII and XIII Centuries', 'Medieval Western art was unable to retain a classical prototype without destroying its original meaning', 'The medieval mind was incapable of realizing the unity of classical form and classical subject matter', 'Representation of classical content with contemporary formal motifs', 'Greek mythology at the intermediate phase of its evolution: not all the constellations have a mythological meaning', 'Transmission of the antique astronomical pictures to the Islamic world through the Byzantine tradition', 'Transmission of the antique astronomical pictures to the Byzantine world', "The idea that the Immaculate Conception occurred through Mary's head", 'classical content represented more akin to the classical form', 'Contemporary Marvels of the East beliefs are so strong that the illuminator does not respect Marco Polo’s report when it contradicts them', 'Stylistic and intellectual evolution of the medieval representations', 'Influence of the Arabian East representations', 'Assimilation by the West of the Arabian scientific literature during the XII and the XIII Centuries', 'Assimilation of Arabian sources in the Spanish context', 'Constellations described with scientific accuracy by Arabs, deprived of the classical mythological content', 'Constellations reinterpreted with Arabian traits', 'Precise scientific attitude', 'Erroneous reinterpretation of the classical mythological representation of constellations in the Arabic context', 'Reintegration of the classical astrological type with scientific and mythological antiquity', "The literal tradition of pagan mythography described the deities' attributes and meaning", 'Pagan mythology content and description reinterpreted in Middle Ages', 'Planetary deities represented as the usual Greek and Roman representations of the Olympic deities', 'Medieval planetary deities are new medieval elaborations of ancient oriental conceptions', 'Saturn depicted as a soldier due to a misinterpretation of the text ("caput galeatum" rather than "caput glauco")', 'Genuine classical types are abandoned', 'The belief that the planets influenced people born under their presence (the children of each planet)', "Representation of the Planet's children having an Oriental origin", 'German pictures used to represent the planets on horseback', 'A celestial emanation governs the minds and behaviour of human beings', "The compositional scheme of the planets children's representation evolves from the Arabian table to a unified pictorial space in the northern XV century art", "Planets children's representation compositional structure is influenced by the religious scenes representing the Descendent of the Holy Ghost", 'pseudo-Renaissance on the basis of the Carolingian manuscripts', 'planetary deities represented more similarly to the classical representations', 'Classical themes, forms and style reproduced during Carolingian renovatio', 'Classical personifications represented with their classical iconography during Carolingian renovatio', 'The copyist misunderstood some representation of the original Carolingian', 'Reception of classical deities in the Middle Ages', "Hrabanus Maurus deities' illustrations derive from classical models since they include classical attributes not described by the text", 'Hrabanus Maurus deities illustrations have some curious attributes motivated by the text corruption', 'Cl ...

# %%
cf_subj = []
for value in cf_subj_dict.values(): 
    cf_subj.append(list(value))
print(cf_subj)
# Out:
# [['http://icondataset.org/ART1000', 'http://icondataset.org/ART1001', 'http://icondataset.org/ART1011', 'http://icondataset.org/ART1039', 'http://icondataset.org/ART1051', 'http://icondataset.org/ART1062', 'http://icondataset.org/ART1065', 'http://icondataset.org/ART1079', 'http://icondataset.org/ART1144', 'http://icondataset.org/ART1188'], ['http://icondataset.org/ART1001test', 'http://icondataset.org/ART1017test'], ['http://icondataset.org/ART1002'], ['http://icondataset.org/ART1002'], ['http://icondataset.org/ART1003test'], ['http://icondataset.org/ART1004', 'http://icondataset.org/ART1060', 'http://icondataset.org/ART1061', 'http://icondataset.org/ART1102', 'http://icondataset.org/ART1105', 'http://icondataset.org/ART1113', 'http://icondataset.org/ART1114', 'http://icondataset.org/ART1150', 'http://icondataset.org/ART1166', 'http://icondataset.org/ART1236', 'http://icondataset.org/ART1523'], ['http://icondataset.org/ART1004', 'http://icondataset.org/ART1060', 'http://icondataset.org/ART1061', 'http://icondataset.org/ART1236'], ['http://icondataset.org/ART1004', 'http://icondataset.org/ART1236'], ['http://icondataset.org/ART1004', 'http://icondataset.org/ART1064', 'http://icondataset.org/ART1236', 'http://icondataset.org/ART1240'], ['http://icondataset.org/ART1004test', 'http://icondataset.org/ART1005test', 'http://icondataset.org/ART1014', 'http://icondataset.org/ART1021', 'http://icondataset.org/ART1033', 'http://icondataset.org/ART1034', 'http://icondataset.org/ART1040', 'http://icondataset.org/ART1042', 'http://icondataset.org/ART1043', 'http://icondataset.org/ART1045', 'http://icondataset.org/ART1048', 'http://icondataset.org/ART1050', 'http://icondataset.org/ART1052', 'http://icondataset.org/ART1053', 'http://icondataset.org/ART1054', 'http://icondataset.org/ART1055', 'http://icondataset.org/ART1056', 'http://icondataset.org/ART1057', 'http://icondataset.org/ART1058', 'http://icondataset.org/ART1064', 'http://icondataset.org/ART1066', 'http://icondataset.org/ART1141', 'http://icondataset.org/ART1142', 'http://icondataset.org/ART1143', 'http://icondataset.org/ART1147', 'http://icondataset.org/ART1240'], ['http://icondataset.org/ART1005'], ['http://icondataset.org/ART1006'], ['http://icondataset.org/ART1007'], ['http://icondataset.org/ART1008test', 'http://icondataset.org/ART1009test'], ['http://icondataset.org/ART1010', 'http://icondataset.org/ART1036'], ['http://icondataset.org/ART1013test', 'http://icondataset.org/ART1014test'], ['http://icondataset.org/ART1014'], ['http://icondataset.org/ART1015', 'http://icondataset.org/ART1016', 'http://icondataset.org/ART1024', 'http://icondataset.org/ART1145'], ['http://icondataset.org/ART1016', 'http://icondataset.org/ART1017', 'http://icondataset.org/ART1024', 'http://icondataset.org/ART1145'], ['http://icondataset.org/ART1017'], ['http://icondataset.org/ART1017', 'http://icondataset.org/ART1018', 'http://icondataset.org/ART1020'], ['http://icondataset.org/ART1017', 'http://icondataset.org/ART1018', 'http://icondataset.org/ART1020'], ['http://icondataset.org/ART1017', 'http://icondataset.org/ART1031'], ['http://icondataset.org/ART1018', 'http://icondataset.org/ART1024'], ['http://icondataset.org/ART1019'], ['http://icondataset.org/ART1021', 'http://icondataset.org/ART1044'], ['http://icondataset.org/ART1021', 'http://icondataset.org/ART1044', 'http://icondataset.org/ART1046'], ['http://icondataset.org/ART1028', 'http://icondataset.org/ART1029'], ['http://icondataset.org/ART1030'], ['http://icondataset.org/ART1030'], ['http://icondataset.org/ART1030'], ['http://icondataset.org/ART1031', 'http://icondataset.org/ART1032', 'http://icondataset.org/ART1034'], ['http://icondataset.org/ART1032'], ['http://icondataset.org/ART1033'], ['http://icondataset.org/ART1034', 'http://icondataset.org/ART1035'], ['http://icondataset.org/ART1034'], ['http://icondataset.org/ART1034'], ['http://icondataset.org/ART1036', 'http://icondataset.org/ART1045'], ['http://icondataset.org/ART1036'], ['http:// ...

# %%
# attempt 4. list of all the 

# artwork_desc_dict = {artwork_id : {cf_name : (<cf_name>, <lev1>, <lev2>)}}
artwork_desc_dict = {}


for b in result['results']['bindings']: # the ones of the query above
   # print (b["cf"]["value"], b["subj1"]["value"])
    #cf_and_subj.append([b["cf"]["value"], b["subj2"]["value"]])
    cf = b["cf"]["value"]
    art = b["artwork"]["value"]
   # subj1 = b["subj1"]["value"]
   # subj2 = b["subj2"]["value"]
    
    if art not in artwork_desc_dict: 
        artwork_desc_dict[art] = {cf : set()}
        artwork_desc_dict[art][cf].add(cf)
    else: 
        if cf not in artwork_desc_dict[art]:
            artwork_desc_dict[art][cf] = set()
        if "subj1" in b: 
            artwork_desc_dict[art][cf].add(b["subj1"]["value"])
        if "subj2" in b: 
            artwork_desc_dict[art][cf].add(b["subj2"]["value"])

            
print(artwork_desc_dict.values())
# Out:
# dict_values([{'Classical subject matter represented in classical form': {'eagle', 'Classical subject matter represented in classical form', 'Venus', 'man', 'woman', 'Jupiter', 'doves'}}, {'Classical subject matter represented in classical form': {'Classical subject matter represented in classical form', 'fighting', 'man', 'Hercules', 'lion'}}, {'Catholic worship practiced in the private home interior due to the prohibition of its public profession': {'Divine Justice', 'symbolical weighing with balance', 'pearl and gold necklaces', 'clothes', 'jewelry box', 'mirror-introspection', 'allusion to last judgement', 'table', 'mirror', 'symbolical weighing of souls', 'act of weighing', 'woman', 'cloth', 'painting', 'Catholic worship practiced in the private home interior due to the prohibition of its public profession', 'home interior', 'jewelry-earthly goods', 'balance'}}, {'Assimilation of Orpheus to Christ in Early Christian Art': {'halo', 'Orpheus', 'natural landscape', 'playing music', 'man', 'lyre', 'Assimilation of Orpheus to Christ in Early Christian Art'}, 'Byzantine theological manuscripts show examples of the genuine classical representational tradition of mythological characters': {'halo', 'Orpheus', 'natural landscape', 'playing music', 'man', 'lyre'}}, {'Self-celebration expressed through portraits in the Florentine Renaissance context': {'Self-celebration expressed through portraits in the Florentine Renaissance context', 'animals', 'The young Mago Caspar', 'boy', 'Member of the procession', 'mule', 'man', 'hilly landscape', 'procession', 'riding a horse', 'young Mago-future time', 'clothes', 'horse', 'riding a mule'}}, {'Classical motifs recovery': {'stepping on-defeating devil', 'carrying on shoulders', 'dragoon-devil', 'dragoon', 'stepping on', 'Classical motifs recovery', 'deer', 'deer-souls', 'Christ', 'cloth', 'man', 'carrying on shoulders-saving souls'}, 'Direct borrowings of classical motifs while the pagan themes were changed into Christian ones in Italian and French art during XII and XIII Centuries': {'stepping on-defeating devil', 'carrying on shoulders', 'dragoon-devil', 'dragoon', 'stepping on', 'deer', 'man', 'deer-souls', 'Christ', 'cloth', 'carrying on shoulders-saving souls'}, 'Medieval Western art was unable to retain a classical prototype without destroying its original meaning': {'stepping on-defeating devil', 'carrying on shoulders', 'dragoon-devil', 'dragoon', 'stepping on', 'deer', 'man', 'deer-souls', 'Christ', 'cloth', 'carrying on shoulders-saving souls'}, 'The medieval mind was incapable of realizing the unity of classical form and classical subject matter': {'stepping on-defeating devil', 'carrying on shoulders', 'dragoon-devil', 'dragoon', 'stepping on', 'deer', 'man', 'deer-souls', 'Christ', 'cloth', 'carrying on shoulders-saving souls'}}, {'Representation of classical content with contemporary formal motifs': {'gathering flowers', 'lending both hands to a woman', 'flowers', 'lending one hand to a man', 'court dress', 'knight', 'Proserpina', 'natural landscape', 'woman', 'rape', 'three dog heads', 'armor', 'courteous attitude', 'Cerberus', 'sitting down', 'man', 'cart', 'Representation of classical content with contemporary formal motifs', 'Pluto'}}, {'Greek mythology at the intermediate phase of its evolution: not all the constellations have a mythological meaning': {'Greek mythology at the intermediate phase of its evolution: not all the constellations have a mythological meaning', 'cutten head', 'The Constellation Eridanus', 'river', 'The Constellation Orion', 'sword', 'The Constellation Perseus', 'man', 'celestial-map', 'The Constellation Hercules (Engonasin)', 'medusas-head', 'constellations'}}, {'Representation of classical content with contemporary formal motifs': {'Cerberus', 'grabbing and lifting a woman', 'crying', 'dog', 'three heads', 'woman', 'rape', 'man', 'force', 'raising arms upwards', 'Representation of classical content with contemporary formal motifs', 'Pluto', 'Proserp ...

# %%
art_subj = []
for key, value in artwork_desc_dict.items(): 
    for k, v in value.items(): 
        art_subj.append(list(v))
  #  content = value.values()
   # print(list(content))
   # art_subj.append(list(value.values()))
    #for content in value.values(): 
    #    cf_subj.append(list(content))
print(art_subj)
# Out:
# [['eagle', 'Classical subject matter represented in classical form', 'Venus', 'man', 'woman', 'Jupiter', 'doves'], ['Classical subject matter represented in classical form', 'fighting', 'man', 'Hercules', 'lion'], ['Divine Justice', 'symbolical weighing with balance', 'pearl and gold necklaces', 'clothes', 'jewelry box', 'mirror-introspection', 'allusion to last judgement', 'table', 'mirror', 'symbolical weighing of souls', 'act of weighing', 'woman', 'cloth', 'painting', 'Catholic worship practiced in the private home interior due to the prohibition of its public profession', 'home interior', 'jewelry-earthly goods', 'balance'], ['halo', 'Orpheus', 'natural landscape', 'playing music', 'man', 'lyre', 'Assimilation of Orpheus to Christ in Early Christian Art'], ['halo', 'Orpheus', 'natural landscape', 'playing music', 'man', 'lyre'], ['Self-celebration expressed through portraits in the Florentine Renaissance context', 'animals', 'The young Mago Caspar', 'boy', 'Member of the procession', 'mule', 'man', 'hilly landscape', 'procession', 'riding a horse', 'young Mago-future time', 'clothes', 'horse', 'riding a mule'], ['stepping on-defeating devil', 'carrying on shoulders', 'dragoon-devil', 'dragoon', 'stepping on', 'Classical motifs recovery', 'deer', 'deer-souls', 'Christ', 'cloth', 'man', 'carrying on shoulders-saving souls'], ['stepping on-defeating devil', 'carrying on shoulders', 'dragoon-devil', 'dragoon', 'stepping on', 'deer', 'man', 'deer-souls', 'Christ', 'cloth', 'carrying on shoulders-saving souls'], ['stepping on-defeating devil', 'carrying on shoulders', 'dragoon-devil', 'dragoon', 'stepping on', 'deer', 'man', 'deer-souls', 'Christ', 'cloth', 'carrying on shoulders-saving souls'], ['stepping on-defeating devil', 'carrying on shoulders', 'dragoon-devil', 'dragoon', 'stepping on', 'deer', 'man', 'deer-souls', 'Christ', 'cloth', 'carrying on shoulders-saving souls'], ['gathering flowers', 'lending both hands to a woman', 'flowers', 'lending one hand to a man', 'court dress', 'knight', 'Proserpina', 'natural landscape', 'woman', 'rape', 'three dog heads', 'armor', 'courteous attitude', 'Cerberus', 'sitting down', 'man', 'cart', 'Representation of classical content with contemporary formal motifs', 'Pluto'], ['Greek mythology at the intermediate phase of its evolution: not all the constellations have a mythological meaning', 'cutten head', 'The Constellation Eridanus', 'river', 'The Constellation Orion', 'sword', 'The Constellation Perseus', 'man', 'celestial-map', 'The Constellation Hercules (Engonasin)', 'medusas-head', 'constellations'], ['Cerberus', 'grabbing and lifting a woman', 'crying', 'dog', 'three heads', 'woman', 'rape', 'man', 'force', 'raising arms upwards', 'Representation of classical content with contemporary formal motifs', 'Pluto', 'Proserpina', 'backward gaze', 'crown'], ['Transmission of the antique astronomical pictures to the Islamic world through the Byzantine tradition', 'concentric circles', 'constellations', 'central circle'], ['constellations', 'concentric circles', 'central circle', 'Transmission of the antique astronomical pictures to the Byzantine world'], ['cloak', 'scroll', "The idea that the Immaculate Conception occurred through Mary's head", 'globe', 'smiling', 'blowing in a tube-fertilising', 'act of blessing', 'wings', 'girl', 'right hand on the heart', 'God', 'blowing in a tube', 'tube', 'holding a book', 'Mary welcomes the Holy Spirit', 'Mary', 'holding a globe', 'Archangel Gabriel pronounces the Ave Maria', 'boy', 'book', 'man', 'Archangel Gabriel', 'looking at'], ['cloak', 'white lilium-virginity', 'raising open hands to chest height', "beams of light - God's word", 'lilies', "The idea that the Immaculate Conception occurred through Mary's head", 'floor decoration', 'indicating the ceiling with the right hand', 'dove flying in the beams of light', 'beams of light', 'girl', 'wings', 'dove', 'dresses', 'speaking', 'Mary welcomes the Holy Spirit', 'Mary', "flying towards Mary's h ...

# %%
from collections import OrderedDict


frequency_dict = {}
for l in cf_and_subj: 
    key = str(l[0]+" @ "+l[1])
    if key not in frequency_dict: 
        frequency_dict[key] = 1
    else: 
        frequency_dict[key] += 1
# print(frequency_dict)

# %%
final = []
ordered = OrderedDict(sorted(frequency_dict.items(), key=lambda t: t[1], reverse=True))
for key, value in ordered.items(): 
    if value >= 5: 
        couple = key.split(" @ ")
        final.append([couple[0], couple[1], value])

print(final)
# Out:
# [['Representation of classical content with contemporary formal motifs', 'man', 18], ['Reintegration of classical style and content in the Italian Renaissance', 'man', 14], ['Piero di Cosimo\'s representation of the primitive world is an "extreme and unique manifestation of the general tendency to retrieve the sacrosancta vetustas"', 'man', 13], ['Iconographic evolution of the representation of the three-headed companion of Serapis', 'head of a dog', 11], ['Iconographic evolution of the representation of the three-headed companion of Serapis', 'head of a lion', 11], ['Iconographic evolution of the representation of the three-headed companion of Serapis', 'head of a wolf', 11], ['Representation of classical content with contemporary formal motifs', 'woman', 10], ['Iconographic evolution of blind Cupid: it developed in different fashions according to historical conditions', 'bow', 9], ['Iconographic evolution of classical subjects', 'man', 9], ['Reintegration of classical style and content in the Italian Renaissance', 'woman', 9], ['Representation of classical content with contemporary formal motifs', 'clothes', 9], ['The phenomenon called Principle of disjunction: whenever in the high and later Middle Ages a work of art borrows its form from a classical model, this form is almost invariably invested with a non-classical, normally Christian, significance; whenever in the high and later Middle Ages a work of art borrows its theme from classical poetry, legend, history or mythology, this theme is quite invariably presented in a non-classical, normally contemporary, form.', 'man', 9], ['Traditional mythological subjects are invested with a symbolic meaning', 'man', 9], ['Classical subject matter represented in classical form', 'man', 8], ['Dürer assimilated classical art through the intermediate of Italian Renaissance art, comprehending it better than them', 'man', 8], ['Iconographic evolution of classical subjects', 'head of a dog', 8], ['Iconographic evolution of classical subjects', 'head of a lion', 8], ['Iconographic evolution of classical subjects', 'head of a wolf', 8], ['Neoplatonic apotheosis: "the ascension of the soul through the hierarchies of the Neoplatonic universe"', 'man', 8], ['The four elements (air, fire, earth, and water) are considered unanimously coessential with the four humours which constituted the human body', 'man', 8], ["The traditional allegorical meaning of a mythological subject reflects Michelangelo's passion for Tommaso Cavalieri", 'man', 8], ['"Piero conceived of human evolution as a process due to the inborn faculties and talents of the race"', 'satyr', 8], ['"Piero conceived of human evolution as a process due to the inborn faculties and talents of the race"', 'Satyr', 8], ['Archaeological research paralleled only in scientific illustrations', 'satyr', 8], ['Archaeological research paralleled only in scientific illustrations', 'Satyr', 8], ['Evolution of the Iconography of Saturn', 'Saturn', 8], ['For Piero "civilization meant a realm of beauty and happiness as long as men kept in close contact with Nature"', 'satyr', 8], ['For Piero "civilization meant a realm of beauty and happiness as long as men kept in close contact with Nature"', 'Satyr', 8], ['Iconographic evolution of the representation of the three-headed companion of Serapis', 'Companion of Serapis', 8], ['Lack of idealization in the representation of the first stages of the world', 'satyr', 8], ['Lack of idealization in the representation of the first stages of the world', 'Satyr', 8], ['Piero di Cosimo\'s representation of the primitive world is an "extreme and unique manifestation of the general tendency to retrieve the sacrosancta vetustas"', 'satyr', 8], ['Piero di Cosimo\'s representation of the primitive world is an "extreme and unique manifestation of the general tendency to retrieve the sacrosancta vetustas"', 'Satyr', 8], ['Reintegration of classical style and content in the Italian Renaissance', 'satyr', 8], ['Reintegration  ...

# %%
df = pd.DataFrame(final, columns = ['Cultural Phenomenon', 'Subject', 'Frequency'])
df.sort_values(by=['Cultural Phenomenon'])
# Out:
#                                   Cultural Phenomenon      Subject  Frequency
# 37  "Piero conceived of human evolution as a proce...          man          7
# 22  "Piero conceived of human evolution as a proce...        Satyr          8
# 21  "Piero conceived of human evolution as a proce...        satyr          8
# 64  An evolutionistic aspect of Ovid's tale on the...        Satyr          6
# 63  An evolutionistic aspect of Ovid's tale on the...        satyr          6
# ..                                                ...          ...        ...
# 20  The traditional allegorical meaning of a mytho...          man          8
# 60  The traditional allegorical meaning of a mytho...  falling off          6
# 61  Three human heads: one of the Medieval and Ren...    male head          6
# 12  Traditional mythological subjects are invested...          man          9
# 62  Traditional mythological subjects are invested...  falling off          6
#
# [92 rows x 3 columns]

# %%
# non funziona. forse le liste vanno fatte diversamente?
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
import pandas as pd

dataset = cf0_subj

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df, min_support=0.12, use_colnames=True)
frequent_itemsets
# Out:
#          support                                           itemsets
# 0          0.125                                           (Beauty)
# 1          0.125                                      (Crucifixion)
# 2          0.125                                         (Hercules)
# 3          0.125                                          (Jupiter)
# 4          0.125                                          (Mercury)
# ...          ...                                                ...
# 1048751    0.125  (cornucopia, sun, Crucifixion, nursing, Oceanu...
# 1048752    0.125  (Sun, cornucopia, sun, Crucifixion, nursing, a...
# 1048753    0.125  (Sun, cornucopia, sun, Crucifixion, nursing, O...
# 1048754    0.125  (Sun, cornucopia, sun, nursing, Oceanus, ampho...
# 1048755    0.125  (Sun, cornucopia, sun, Crucifixion, nursing, O...
#
# [1048756 rows x 2 columns]

# %%
# non funziona. forse le liste vanno fatte diversamente?
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
import pandas as pd

dataset = art_subj

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df, min_support=0.05, use_colnames=True)
frequent_itemsets
# Out:
#      support                                         itemsets
# 0   0.063830                                          (Cupid)
# 1   0.053191                                         (Saturn)
# 2   0.065012                                            (bow)
# 3   0.062648                                            (boy)
# 4   0.053191                                        (clothes)
# 5   0.057920                                          (crown)
# 6   0.054374                                  (head of a dog)
# 7   0.054374                                 (head of a lion)
# 8   0.054374                                 (head of a wolf)
# 9   0.053191                            (holding with a hand)
# 10  0.439716                                            (man)
# 11  0.050827                              (natural landscape)
# 12  0.104019                                          (wings)
# 13  0.205674                                          (woman)
# 14  0.054374                  (head of a lion, head of a dog)
# 15  0.054374                  (head of a wolf, head of a dog)
# 16  0.054374                 (head of a lion, head of a wolf)
# 17  0.085106                                     (man, woman)
# 18  0.054374  (head of a lion, head of a wolf, head of a dog)

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.08)
# Out:
#                          antecedents                       consequents  \
# 0                   (head of a lion)                   (head of a dog)
# 1                    (head of a dog)                  (head of a lion)
# 2                   (head of a wolf)                   (head of a dog)
# 3                    (head of a dog)                  (head of a wolf)
# 4                   (head of a lion)                  (head of a wolf)
# 5                   (head of a wolf)                  (head of a lion)
# 6                              (man)                           (woman)
# 7                            (woman)                             (man)
# 8   (head of a lion, head of a wolf)                   (head of a dog)
# 9    (head of a lion, head of a dog)                  (head of a wolf)
# 10   (head of a wolf, head of a dog)                  (head of a lion)
# 11                  (head of a lion)   (head of a wolf, head of a dog)
# 12                  (head of a wolf)   (head of a lion, head of a dog)
# 13                   (head of a dog)  (head of a lion, head of a wolf)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.054374            0.054374  0.054374    1.000000  18.391304
# 1             0.054374            0.054374  0.054374    1.000000  18.391304
# 2             0.054374            0.054374  0.054374    1.000000  18.391304
# 3             0.054374            0.054374  0.054374    1.000000  18.391304
# 4             0.054374            0.054374  0.054374    1.000000  18.391304
# 5             0.054374            0.054374  0.054374    1.000000  18.391304
# 6             0.439716            0.205674  0.085106    0.193548   0.941046
# 7             0.205674            0.439716  0.085106    0.413793   0.941046
# 8             0.054374            0.054374  0.054374    1.000000  18.391304
# 9             0.054374            0.054374  0.054374    1.000000  18.391304
# 10            0.054374            0.054374  0.054374    1.000000  18.391304
# 11            0.054374            0.054374  0.054374    1.000000  18.391304
# 12            0.054374            0.054374  0.054374    1.000000  18.391304
# 13            0.054374            0.054374  0.054374    1.000000  18.391304
#
#     leverage  conviction
# 0   0.051417         inf
# 1   0.051417         inf
# 2   0.051417         inf
# 3   0.051417         inf
# 4   0.051417         inf
# 5   0.051417         inf
# 6  -0.005332    0.984965
# 7  -0.005332    0.955778
# 8   0.051417         inf
# 9   0.051417         inf
# 10  0.051417         inf
# 11  0.051417         inf
# 12  0.051417         inf
# 13  0.051417         inf

# %% [markdown]
# ## 2 symbolical meaning attibution
# Which elements are involved in a symbolical meaning?

# %% [markdown]
# ## 3 evidence supporting iconological interpretation
# a)
# What is the evidence supporting the relationship between the artwork and the cultural phenomenon/meaning?
#
# b)
# Analysis of the structure of the cultural phenomenon or meaning recognition: how many evidences does support it on average? Of which type? How many of them are external resources and not elements of the considered artworks?

# %% [markdown]
# ## 4 authors of interpretations
#
# Select the names of all the authors who are responsible for an iconological recognition, both of third level (individuating a meaning or role) and fourth level (individuating a cultural phenomenon)

# %% [markdown]
# ## 5 subjects and their attributes
# a) What are the subjects represented? Which attributes allow us to identify representations?
#
# b)What are the most common and most rare attributes allowing to identify a subject?

# %%
cqa = '''
prefix data: <http://icondataset.org/> 
prefix symb: <http://symbont.org/> 
prefix symbont: <http://simulationontology.org/> 
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix crm: <http://www.cidoc-crm.org/cidoc-crm/>
prefix cito: <http://purl.org/spar/cito/>

SELECT ?subject ?type ?nameAttr WHERE {

  VALUES ?has {symb:hasCharacter symb:hasEvent symb:hasNamedObject symb:hasPlace symb:hasSymbol symb:hasPersonification}
  # ?img symb:hasRecAttribute ?attr.
  # ?img ?has ?subject.
  # ?img a symb:Image. 
  VALUES ?nameAttr {symb:NaturalElement	symb:ExpressionalQuality	symb:Action	symb:LinguisticObject}
  # ?attr ?has2 ?nameAttr.
  # ?subject a ?type. 



}
GROUP BY ?subject ?type ?nameAttr
ORDER BY ?subject ?type ?nameAttr
'''

cqres = newg.query(cqa)

for row in cqres:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2881                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2882                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2883             finally:
#
# <ipython-input-6-0e9d165af431> in <module>()
#      25
# ---> 26 cqres = newg.query(cqa)
#      27
#
# /usr/local/lib/python3.7/dist-packages/rdflib/graph.py in query(self, query_object, processor, result, initNs, initBindings, use_store_provided, **kwargs)
#    1319
# -> 1320         return result(processor.query(query_object, initBindings, initNs, **kwargs))
#    1321
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/processor.py in query(self, strOrQuery, initBindings, initNs, base, DEBUG)
#      74             query = strOrQuery
# ---> 75         return evalQuery(self.graph, query, initBindings, base)
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalQuery(graph, query, initBindings, base)
#     585
# --> 586     return evalPart(ctx, main)
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalPart(ctx, part)
#     284     elif part.name == "SelectQuery":
# --> 285         return evalSelectQuery(ctx, part)
#     286     elif part.name == "AskQuery":
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalSelectQuery(ctx, query)
#     516     res["type_"] = "SELECT"
# --> 517     res["bindings"] = evalPart(ctx, query.p)
#     518     res["vars_"] = query.PV
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalPart(ctx, part)
#     268     elif part.name == "Project":
# --> 269         return evalProject(ctx, part)
#     270     elif part.name == "Slice":
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalProject(ctx, project)
#     507 def evalProject(ctx, project):
# --> 508     res = evalPart(ctx, project.p)
#     509
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalPart(ctx, part)
#     277     elif part.name == "OrderBy":
# --> 278         return evalOrderBy(ctx, part)
#     279     elif part.name == "Group":
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalOrderBy(ctx, part)
#     442         res = sorted(
# --> 443             res, key=lambda x: _val(value(x, e.expr, variables=True)), reverse=reverse
#     444         )
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalExtend(ctx, extend)
#      92
# ---> 93     for c in evalPart(ctx, extend.p):
#      94         try:
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalExtend(ctx, extend)
#      92
# ---> 93     for c in evalPart(ctx, extend.p):
#      94         try:
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalExtend(ctx, extend)
#      92
# ---> 93     for c in evalPart(ctx, extend.p):
#      94         try:
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalAggregateJoin(ctx, agg)
#     407     # import pdb ; pdb.set_trace()
# --> 408     p = evalPart(ctx, agg.p)
#     409     # p is always a Group, we always get a dict back
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalPart(ctx, part)
#     279     elif part.name == "Group":
# --> 280         return evalGroup(ctx, part)
#     281     elif part.name == "AggregateJoin":
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalGroup(ctx, group)
#     402     # grouping should be implemented by evalAggregateJoin
# --> 403     return evalPart(ctx, group.p)
#     404
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalPart(ctx, part)
#     253     elif part.name == "Join":
# --> 254         return evalJoin(ctx, part)
#     255     elif part.name == "LeftJoin":
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalJoin(ctx, join)
#     126         a = evalPart(ctx, join.p1)
# --> 127         b = set(evalPart(ctx, join.p2))
#     128         return _join(a, b)
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalBGP(ctx, bgp)
#      85
# ---> 86         for x in evalBGP(c, bgp[1:]):
#      87             yield x
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalBGP(ctx, bgp)
#      85
# ---> 86         for x in evalBGP(c, bgp[1:]):
#      87             yield x
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/evaluate.py in evalBGP(ctx, bgp)
#      55     if not bgp:
# ---> 56         yield ctx.solution()
#      57         return
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/sparql.py in solution(self, vars)
#     334         else:
# --> 335             return FrozenBindings(self, self.bindings.items())
#     336
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/sparql.py in __init__(self, ctx, *args, **kwargs)
#     159     def __init__(self, ctx, *args, **kwargs):
# --> 160         FrozenDict.__init__(self, *args, **kwargs)
#     161         self.ctx = ctx
#
# /usr/local/lib/python3.7/dist-packages/rdflib/plugins/sparql/sparql.py in __init__(self, *args, **kwargs)
#     104     def __init__(self, *args, **kwargs):
# --> 105         self._d = dict(*args, **kwargs)
#     106         self._hash = None
#
# /usr/lib/python3.7/_collections_abc.py in __iter__(self)
#     741
# --> 742     def __iter__(self):
#     743         for key in self._mapping:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %% [markdown]
# ## 6 concepts and symbols
# Which third-level meanings (i.e. concepts and symbols) are expressed in the artwork? by which objects?

# %% [markdown]
# What events symbolically refer to another event in the two artworks? What representations are referring to?

# %% [markdown]
# What are the characters and symbols invested with a common meaning?

# %% [markdown]
# ## 7 symbol sources
# a)If present, what is the provenance of the attribution of symbolic meanings in the artwork? i.e. the bibliographic reference in which a historian has claimed the attribution.
#
# b) Find the most common sources of symbols

# %% [markdown]
# ## 8 Analysis of portrait.
# Select all the artworks where there are portraits of historical persons; check if they correspond to the buyer if known; check if the portrayed person is linked to a cultural phenomenon or third level meaning

# %%
cq1 = '''
prefix data: <http://icondataset.org/> 
prefix symb: <http://symbont.org/> 
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix cito: <http://purl.org/spar/cito/>

SELECT DISTINCT ?artwork ?char ?personLabel ?meaning
WHERE {
# ?icrec symb:aboutWorkOfArt ?artwork; 
  symb:recognizedImage ?img. 
# ?img symb:hasCharacter ?char; 
  symb:hasCharacter ?person.
# ?person a crm:E21_Person; rdfs:label ?personLabel.
?
FILTER (?char != ?person) 
}
ORDER BY ?artwork ?char ?personLabel
'''

cq2 = '''
prefix data: <http://icondataset.org/> 
prefix symb: <http://symbont.org/> 
prefix dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
prefix cito: <http://purl.org/spar/cito/>

SELECT DISTINCT ?artwork ?char ?personLabel ?meaning
WHERE {
# ?icrec symb:aboutWorkOfArt ?artwork; 
  symb:recognizedImage ?img. 
# ?img symb:hasCharacter ?char; 
  symb:hasCharacter ?person.
# ?person a crm:E21_Person; rdfs:label ?personLabel.
# ?iconol symb:aboutWorkOfArt ?artwork;
  a symb:IconologicalRecognition;
  symb:hasImage ?img;
  symb:recognizedIntrinsicMeaning ?intrinsic. 
# ?intrinsic (symb:recognizedConceptualObject | symb:recognizedCulturalPhenomenon) ?meaning 
FILTER (?char != ?person) 
}
ORDER BY ?artwork ?char ?personLabel
'''

cq1res = newg.query(cq1)

for row in cq1res:
    print(row)
# Out:
# (rdflib.term.URIRef('http://icondataset.org/ART1003test'), rdflib.term.URIRef('http://icondataset.org/member-of-the-procession'), rdflib.term.Literal("Cosimo de' Medici"), rdflib.term.URIRef('http://icondataset.org/self-celebration-expressed-through-portraits-in-the-florentine-renaissance-context'))
# (rdflib.term.URIRef('http://icondataset.org/ART1003test'), rdflib.term.URIRef('http://icondataset.org/member-of-the-procession'), rdflib.term.Literal("Cosimo de' Medici"), rdflib.term.URIRef('http://icondataset.org/political-aspirations-of-the-medici-family'))
# (rdflib.term.URIRef('http://icondataset.org/ART1003test'), rdflib.term.URIRef('http://icondataset.org/member-of-the-procession'), rdflib.term.Literal('Galeazzo Maria Sforza'), rdflib.term.URIRef('http://icondataset.org/self-celebration-expressed-through-portraits-in-the-florentine-renaissance-context'))
# (rdflib.term.URIRef('http://icondataset.org/ART1003test'), rdflib.term.URIRef('http://icondataset.org/member-of-the-procession'), rdflib.term.Literal('Galeazzo Maria Sforza'), rdflib.term.URIRef('http://icondataset.org/political-aspirations-of-the-medici-family'))
# (rdflib.term.URIRef('http://icondataset.org/ART1003test'), rdflib.term.URIRef('http://icondataset.org/member-of-the-procession'), rdflib.term.Literal("Piero de' Medici"), rdflib.term.URIRef('http://icondataset.org/self-celebration-expressed-through-portraits-in-the-florentine-renaissance-context'))
# (rdflib.term.URIRef('http://icondataset.org/ART1003test'), rdflib.term.URIRef('http://icondataset.org/member-of-the-procession'), rdflib.term.Literal("Piero de' Medici"), rdflib.term.URIRef('http://icondataset.org/political-aspirations-of-the-medici-family'))
# (rdflib.term.URIRef('http://icondataset.org/ART1003test'), rdflib.term.URIRef('http://icondataset.org/member-of-the-procession'), rdflib.term.Literal('Sigismondo Malatesta'), rdflib.term.URIRef('http://icondataset.org/self-celebration-expressed-through-portraits-in-the-florentine-renaissance-context'))
# (rdflib.term.URIRef('http://icondataset.org/ART1003test'), rdflib.term.URIRef('http://icondataset.org/member-of-the-procession'), rdflib.term.Literal('Sigismondo Malatesta'), rdflib.term.URIRef('http://icondataset.org/political-aspirations-of-the-medici-family'))
# (rdflib.term.URIRef('http://icondataset.org/ART1003test'), rdflib.term.URIRef('http://icondataset.org/the-young-mago-caspar'), rdflib.term.Literal("Lorenzo de' Medici"), rdflib.term.URIRef('http://icondataset.org/lorenzo-de-medici-presented-as-princeps-of-the-empire'))
# (rdflib.term.URIRef('http://icondataset.org/ART1003test'), rdflib.term.URIRef('http://icondataset.org/the-young-mago-caspar'), rdflib.term.Literal("Lorenzo de' Medici"), rdflib.term.URIRef('http://icondataset.org/self-celebration-expressed-through-portraits-in-the-florentine-renaissance-context'))
# (rdflib.term.URIRef('http://icondataset.org/ART1003test'), rdflib.term.URIRef('http://icondataset.org/the-young-mago-caspar'), rdflib.term.Literal("Lorenzo de' Medici"), rdflib.term.URIRef('http://icondataset.org/political-aspirations-of-the-medici-family'))

# %% [markdown]
# ## 9 Chains of recognitions
# to which deep meaning lead recognitions supporting other ones?

# %% [markdown]
# ## 10 representations of classical content
# Try to verify in a quantitative way what Panofsky says: the classical subjects are represented during the Middle Ages but with a different representation. Do artworks with the same subject present significative differences? Do they have a different symbolical meaning? Do they have a different declared style? On the basis of this trend, there’s something else to discover that Panofsky didn’t take into account?
# hp: suggest a style completion of artworks when they have different times and different representations?

# %% [markdown]
# ## 11 Specific iconographies detection
# Retrieve all the iconographies that appear less, along with their attributes and (optionally) sources

# %% [markdown]
# ## 12 elements involved in an iconological meaning recognition
# Analysis of the difference between the recognizing attributes and the non-recognizing ones, but that are involved in an iconological meaning recognition

# %% [markdown]
# ## 13 Analysis of the artworks linked by common visual motifs
# i.e. find the chains of copied motifs.

# %% [markdown]
# ## 14 Analysis of the meaning of attributes
# a) why do they have a certain meaning? Select attributes which symbolical meaning is determined by a cited source
#
# b) Retrieve all the attributes depicting a cone shell along with its representation and eventual meaning
#
# c) Retrieve all the artworks in which the subject “dragoon” appears, with its optional attributes and meanings
#
# d)Analysis of the meaning of attributes: how and where does the meaning change? are there patterns (e.g.: same meaning in the same geographical area/time)

# %% [markdown]
# ## 14 concepts
#
# a) What objects depict the concept of “love” in what artworks?
#
# b) Analysis of how a concept is represented (object, personification etc); detect if there are patterns (geography; time; common source)
